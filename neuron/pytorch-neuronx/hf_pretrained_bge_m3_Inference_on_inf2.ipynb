# %% [markdown]
# # HuggingFace Pretrained BGE M3 Inference on Inf2

# %% [markdown]
# ## Introduction
#
# This notebook demonstrates how to compile and run a HuggingFace 🤗 BGE-M3(xlm-roberta) model for accelerated inference on Neuron. This notebook will use the ['BAAI/bge-m3'](https://huggingface.co/BAAI/bge-m3) model, which is primarily used for word embeddings.
#
# This Jupyter notebook should be run on a Inf2 instance (`inf2.8xlarge` or larger).

# %% [markdown]
# Verify that this Jupyter notebook is running the Python kernel environment that was set up according to the [PyTorch Installation Guide](https://awsdocs-neuron.readthedocs-hosted.com/en/latest/general/setup/torch-neuronx.html#setup-torch-neuronx). You can select the kernel from the 'Kernel -> Change Kernel' option on the top of this Jupyter notebook page.

# %% [markdown]
# ## Install Dependencies
# This tutorial requires the following pip packages:
#
# - `torch-neuronx`
# - `neuronx-cc`
# - `transformers`
#
# Most of these packages will be installed when configuring your environment using the Trn1 setup guide. The additional dependencies must be installed here:

# %%
# %env TOKENIZERS_PARALLELISM=True #Supresses tokenizer warnings making errors easier to detect
# !pip install -U transformers
# Out:
# env: TOKENIZERS_PARALLELISM=True #Supresses tokenizer warnings making errors easier to detect
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting transformers
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (3.13.4)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 15.2 MB/s eta 0:00:00:00:0100:01
# Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 4.3 MB/s eta 0:00:00:00:01
# Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (775 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.1/775.1 kB 8.7 MB/s eta 0:00:00:00:01
# Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.2 MB/s eta 0:00:00:00:01
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 15.4 MB/s eta 0:00:00:00:01
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.23.0 regex-2024.5.15 safetensors-0.4.3 tokenizers-0.19.1 transformers-4.41.0

# %% [markdown]
# ## Compile the model into an AWS Neuron optimized TorchScript

# %% [markdown]
# In the following section, we load the model and tokenizer, get s sample input, run inference on CPU, compile the model for Neuron using `torch_neuronx.trace()` and save the optimized model as `TorchScript`.
#
# `torch_neuronx.trace()` expects a tensor or tuple of tensor inputs to use for tracing, so we unpack the tokenzier output. Additionally, the input shape that's used duing compilation must match the input shape that's used during inference. To handle this, we pad the inputs to the maximum size that we will see during inference.

# %%
import torch
import torch_neuronx
from transformers import AutoTokenizer, AutoModel


def cls_pooling(model_output, attention_mask):
    return model_output[0][:,0]



# Create the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('BAAI/bge-m3')
model = AutoModel.from_pretrained('BAAI/bge-m3')

# Get an example input
sentences = ['This is an example sentence', 'Each sentence is converted']

# Tokenize sentences
encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output_cpu = model(**encoded_input)

# Perform pooling. In this case, cls pooling.
sentence_embeddings_cpu = cls_pooling(model_output_cpu, encoded_input['attention_mask'])

print("Sentence embeddings cpu:")
print(sentence_embeddings_cpu)

encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')
example = (
    encoded_input['input_ids'],
    encoded_input['attention_mask'],
)

# Compile the model
model_neuron = torch_neuronx.trace(model,example)

# Save the TorchScript for inference deployment
filename = 'model.pt'
torch.jit.save(model_neuron, filename)
# Out:
# /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Sentence embeddings cpu:
# tensor([[-0.3375,  1.2365, -1.0101,  ..., -0.6634, -0.0480, -0.3944],
#         [ 0.3626, -0.0248, -0.4376,  ..., -0.0577, -0.8273,  1.4676]])
# 2024-05-21T16:15:40Z Running DoNothing
# 2024-05-21T16:15:40Z DoNothing finished after 0.000 seconds
# 2024-05-21T16:15:40Z Running AliasDependencyInduction
# 2024-05-21T16:15:40Z AliasDependencyInduction finished after 0.006 seconds
# 2024-05-21T16:15:40Z Running CanonicalizeIR
# 2024-05-21T16:15:40Z CanonicalizeIR finished after 0.026 seconds
# 2024-05-21T16:15:40Z Running LegalizeCCOpLayout
# 2024-05-21T16:15:40Z LegalizeCCOpLayout finished after 0.027 seconds
# 2024-05-21T16:15:40Z Running ResolveComplicatePredicates
# 2024-05-21T16:15:40Z ResolveComplicatePredicates finished after 0.024 seconds
# 2024-05-21T16:15:40Z Running AffinePredicateResolution
# 2024-05-21T16:15:40Z AffinePredicateResolution finished after 0.026 seconds
# 2024-05-21T16:15:40Z Running EliminateDivs
# 2024-05-21T16:15:40Z EliminateDivs finished after 0.025 seconds
# 2024-05-21T16:15:40Z Running PerfectLoopNest
# 2024-05-21T16:15:40Z PerfectLoopNest finished after 0.025 seconds
# 2024-05-21T16:15:40Z Running Simplifier
# 2024-05-21T16:15:41Z Simplifier finished after 0.117 seconds
# 2024-05-21T16:15:41Z Running GenericAccessSimplifier
# 2024-05-21T16:15:41Z GenericAccessSimplifier finished after 0.022 seconds
# 2024-05-21T16:15:41Z Running TCTransform
# 2024-05-21T16:15:41Z TCTransform finished after 0.022 seconds
# 2024-05-21T16:15:41Z Running CommuteConcat
# 2024-05-21T16:15:41Z CommuteConcat finished after 0.022 seconds
# 2024-05-21T16:15:41Z Running LowerTensorOp
# 2024-05-21T16:15:41Z LowerTensorOp finished after 0.228 seconds
# 2024-05-21T16:15:41Z Running ExpandBatchNorm
# 2024-05-21T16:15:41Z ExpandBatchNorm finished after 0.061 seconds
# 2024-05-21T16:15:41Z Running TCTransform
# 2024-05-21T16:15:41Z TCTransform finished after 0.083 seconds
# 2024-05-21T16:15:41Z Running EliminateDivs
# 2024-05-21T16:15:41Z EliminateDivs finished after 0.051 seconds
# 2024-05-21T16:15:41Z Running GenericAccessSimplifier
# 2024-05-21T16:15:41Z GenericAccessSimplifier finished after 0.054 seconds
# 2024-05-21T16:15:41Z Running CanonicalizeIR
# 2024-05-21T16:15:41Z CanonicalizeIR finished after 0.050 seconds
# 2024-05-21T16:15:41Z Running TensorOpFusion
# 2024-05-21T16:15:41Z TensorOpFusion finished after 0.075 seconds
# 2024-05-21T16:15:41Z Running TensorOpTransform
# 2024-05-21T16:15:42Z TensorOpTransform finished after 0.221 seconds
# 2024-05-21T16:15:42Z Running LateLowerTensorOp
# 2024-05-21T16:15:42Z LateLowerTensorOp finished after 0.079 seconds
# 2024-05-21T16:15:42Z Running MemcpyElimination
# 2024-05-21T16:15:45Z MemcpyElimination finished after 3.732 seconds
# 2024-05-21T16:15:45Z Running LoopFusion
# 2024-05-21T16:15:48Z LoopFusion finished after 2.633 seconds
# 2024-05-21T16:15:48Z Running Rematerialization
# 2024-05-21T16:15:48Z Rematerialization finished after 0.097 seconds
# 2024-05-21T16:15:48Z Running Simplifier
# 2024-05-21T16:15:48Z Simplifier finished after 0.351 seconds
# 2024-05-21T16:15:48Z Running Delinearization
# 2024-05-21T16:15:49Z Delinearization finished after 0.071 seconds
# 2024-05-21T16:15:49Z Running AliasDependencyElimination
# 2024-05-21T16:15:49Z AliasDependencyElimination finished after 0.027 seconds
# 2024-05-21T16:15:49Z Running DeadStoreElimination
# 2024-05-21T16:15:52Z DeadStoreElimination finished after 2.951 seconds
# 2024-05-21T16:15:52Z Running AliasDependencyInduction
# 2024-05-21T16:15:52Z AliasDependencyInduction finished after 0.006 seconds
# 2024-05-21T16:15:52Z Running Simplifier
# 2024-05-21T16:15:52Z Simplifier finished after 0.170 seconds
# 2024-05-21T16:15:52Z Running LICM
# 2024-05-21T16:15:52Z LICM finished after 0.052 seconds
# 2024-05-21T16:15:52Z Running Delinearization
# 2024-05-21T16:15:52Z Delinearization finished after 0.038 seconds
# 2024-05-21T16:15:52Z Running LoopFusion
# 2024-05-21T16:15:52Z LoopFusion finished after 0.426 seconds
# 2024-05-21T16:15:52Z Running SimplifySlice
# 2024-05-21T16:15:52Z SimplifySlice finished after 0.026 seconds
# 2024-05-21T16:15:52Z Running LICM
# 2024-05-21T16:15:52Z LICM finished after 0.038 seconds
# 2024-05-21T16:15:52Z Running Simplifier
# 2024-05-21T16:15:52Z Simplifier finished after 0.166 seconds
# 2024-05-21T16:15:52Z Running ValueNumbering
# 2024-05-21T16:15:53Z ValueNumbering finished after 0.059 seconds
# 2024-05-21T16:15:53Z Running LICM
# 2024-05-21T16:15:53Z LICM finished after 0.037 seconds
# 2024-05-21T16:15:53Z Running PadElimination
# 2024-05-21T16:15:53Z PadElimination finished after 0.002 seconds
# 2024-05-21T16:15:53Z Running Delinearization
# 2024-05-21T16:15:53Z Delinearization finished after 0.039 seconds
# 2024-05-21T16:15:53Z Running LoopFusion
# 2024-05-21T16:15:53Z LoopFusion finished after 0.324 seconds
# 2024-05-21T16:15:53Z Running GenericAccessSimplifier
# 2024-05-21T16:15:53Z GenericAccessSimplifier finished after 0.026 seconds
# 2024-05-21T16:15:53Z Running Simplifier
# 2024-05-21T16:15:53Z Simplifier finished after 0.167 seconds
# 2024-05-21T16:15:53Z Running LICM
# 2024-05-21T16:15:53Z LICM finished after 0.039 seconds
# 2024-05-21T16:15:53Z Running ValueNumbering
# 2024-05-21T16:15:53Z ValueNumbering finished after 0.052 seconds
# 2024-05-21T16:15:53Z Running TCTransform
# 2024-05-21T16:15:53Z TCTransform finished after 0.024 seconds
# 2024-05-21T16:15:53Z Running CommuteConcat
# 2024-05-21T16:15:53Z CommuteConcat finished after 0.025 seconds
# 2024-05-21T16:15:53Z Running RecognizeOpIdiom
# 2024-05-21T16:15:53Z RecognizeOpIdiom finished after 0.078 seconds
# 2024-05-21T16:15:53Z Running MaskPropagation
# 2024-05-21T16:15:53Z MaskPropagation finished after 0.041 seconds
# 2024-05-21T16:15:53Z Running Recompute
# 2024-05-21T16:15:53Z Recompute finished after 0.003 seconds
# 2024-05-21T16:15:53Z Running DeadCodeElimination
# 2024-05-21T16:15:53Z DeadCodeElimination finished after 0.027 seconds
# 2024-05-21T16:15:53Z Running DoNothing
# 2024-05-21T16:15:53Z DoNothing finished after 0.000 seconds
# 2024-05-21T16:15:53Z Running MutateDataType
# 2024-05-21T16:15:54Z MutateDataType finished after 0.019 seconds
# 2024-05-21T16:15:54Z Running AutoCastTCInputs
# 2024-05-21T16:15:54Z AutoCastTCInputs finished after 0.055 seconds
# 2024-05-21T16:15:54Z Running GenericAccessSimplifier
# 2024-05-21T16:15:54Z GenericAccessSimplifier finished after 0.028 seconds
# 2024-05-21T16:15:54Z Running Simplifier
# 2024-05-21T16:15:54Z Simplifier finished after 0.187 seconds
# 2024-05-21T16:15:54Z Running AliasDependencyElimination
# 2024-05-21T16:15:54Z AliasDependencyElimination finished after 0.029 seconds
# 2024-05-21T16:15:54Z Running DelinearIndices
# 2024-05-21T16:15:54Z DelinearIndices finished after 0.103 seconds
# 2024-05-21T16:15:54Z Running Delinearization
# 2024-05-21T16:15:54Z Delinearization finished after 0.038 seconds
# 2024-05-21T16:15:54Z Running DelinearIndices
# 2024-05-21T16:15:54Z DelinearIndices finished after 0.099 seconds
# 2024-05-21T16:15:54Z Running DeadCodeElimination
# 2024-05-21T16:15:54Z DeadCodeElimination finished after 0.029 seconds
# 2024-05-21T16:15:54Z Running InferIntrinsicOnCC
# 2024-05-21T16:15:54Z InferIntrinsicOnCC finished after 0.229 seconds
# 2024-05-21T16:15:54Z Running ResolveAccessConflict
# 2024-05-21T16:15:55Z ResolveAccessConflict finished after 0.151 seconds
# 2024-05-21T16:15:55Z Running LICM
# 2024-05-21T16:15:55Z LICM finished after 0.045 seconds
# 2024-05-21T16:15:55Z Running LocalLayoutOpt
# 2024-05-21T16:15:55Z LocalLayoutOpt finished after 0.251 seconds
# 2024-05-21T16:15:55Z Running DelinearIndices
# 2024-05-21T16:15:55Z DelinearIndices finished after 0.114 seconds
# 2024-05-21T16:15:55Z Running OrigLayoutTilingPipeline
# 2024-05-21T16:15:55Z Running GlobalLayoutOpt
# 2024-05-21T16:15:58Z GlobalLayoutOpt finished after 3.126 seconds
# 2024-05-21T16:15:58Z Running CanonicalizeDAG
# 2024-05-21T16:15:58Z CanonicalizeDAG finished after 0.043 seconds
# 2024-05-21T16:15:58Z Running FlattenAxesForTiling
# 2024-05-21T16:15:58Z FlattenAxesForTiling finished after 0.179 seconds
# 2024-05-21T16:15:58Z Running SundaSizeTiling
# 2024-05-21T16:16:01Z SundaSizeTiling finished after 3.025 seconds
# 2024-05-21T16:16:01Z OrigLayoutTilingPipeline finished after 6.535 seconds
# 2024-05-21T16:16:01Z Running TilingProfiler
# 2024-05-21T16:16:02Z TilingProfiler finished after 0.183 seconds
# 2024-05-21T16:16:02Z Running FlattenMacroLoop
# 2024-05-21T16:16:02Z FlattenMacroLoop finished after 0.213 seconds
# 2024-05-21T16:16:02Z Running InferNeuronTensor
# 2024-05-21T16:16:03Z InferNeuronTensor finished after 0.988 seconds
# 2024-05-21T16:16:03Z Running NeuronSimplifier
# 2024-05-21T16:16:03Z NeuronSimplifier finished after 0.222 seconds
# 2024-05-21T16:16:03Z Running LICM
# 2024-05-21T16:16:03Z LICM finished after 0.091 seconds
# 2024-05-21T16:16:03Z Running RewriteReplicationMatmul
# 2024-05-21T16:16:03Z RewriteReplicationMatmul finished after 0.050 seconds
# 2024-05-21T16:16:03Z Running FlattenMacroLoop
# 2024-05-21T16:16:03Z FlattenMacroLoop finished after 0.137 seconds
# 2024-05-21T16:16:03Z Running SimplifyMacroPredicates
# 2024-05-21T16:16:04Z SimplifyMacroPredicates finished after 0.385 seconds
# 2024-05-21T16:16:04Z Running DataLocalityOpt
# 2024-05-21T16:16:11Z DataLocalityOpt finished after 6.547 seconds
# 2024-05-21T16:16:11Z Running DMATilingProfiler
# 2024-05-21T16:16:11Z DMATilingProfiler finished after 0.044 seconds
# 2024-05-21T16:16:11Z Running NeuronSimplifier
# 2024-05-21T16:16:12Z NeuronSimplifier finished after 0.258 seconds
# 2024-05-21T16:16:12Z Running LegalizeSundaMacro
# 2024-05-21T16:16:13Z LegalizeSundaMacro finished after 0.115 seconds
# 2024-05-21T16:16:13Z Running NeuronSimplifier
# 2024-05-21T16:16:14Z NeuronSimplifier finished after 0.257 seconds
# 2024-05-21T16:16:14Z Running PerfectLoopNest
# 2024-05-21T16:16:16Z PerfectLoopNest finished after 0.066 seconds
# 2024-05-21T16:16:16Z Running FlattenMacroLoop
# 2024-05-21T16:16:17Z FlattenMacroLoop finished after 0.154 seconds
# 2024-05-21T16:16:17Z Running RewriteWeights
# 2024-05-21T16:16:22Z RewriteWeights finished after 5.144 seconds
# 2024-05-21T16:16:22Z Running ReshapeWeights
# 2024-05-21T16:16:23Z ReshapeWeights finished after 0.017 seconds
# 2024-05-21T16:16:23Z Running FlattenMacroLoop
# 2024-05-21T16:16:23Z FlattenMacroLoop finished after 0.082 seconds
# 2024-05-21T16:16:23Z Running SimplifyMacroPredicates
# 2024-05-21T16:16:24Z SimplifyMacroPredicates finished after 0.536 seconds
# 2024-05-21T16:16:24Z Running InferInitValue
# 2024-05-21T16:16:27Z InferInitValue finished after 3.025 seconds
# 2024-05-21T16:16:27Z Running NeuronSimplifier
# 2024-05-21T16:16:28Z NeuronSimplifier finished after 0.260 seconds
# 2024-05-21T16:16:28Z Running SimplifyTensor
# 2024-05-21T16:16:28Z SimplifyTensor finished after 0.215 seconds
# 2024-05-21T16:16:28Z Running LICM
# 2024-05-21T16:16:28Z LICM finished after 0.095 seconds
# 2024-05-21T16:16:28Z Running SundaISel
# 2024-05-21T16:16:29Z SundaISel finished after 0.847 seconds
# 2024-05-21T16:16:29Z Running PreprocessNkiKernels
# 2024-05-21T16:16:30Z PreprocessNkiKernels finished after 0.027 seconds
# 2024-05-21T16:16:30Z Running NeuronLoopInterchange
# 2024-05-21T16:16:30Z NeuronLoopInterchange finished after 0.028 seconds
# 2024-05-21T16:16:30Z Running NeuronSimplifyPredicates
# 2024-05-21T16:16:30Z NeuronSimplifyPredicates finished after 0.028 seconds
# 2024-05-21T16:16:30Z Running NeuronLoopFusion
# 2024-05-21T16:16:31Z NeuronLoopFusion finished after 0.455 seconds
# 2024-05-21T16:16:31Z Running NeuronLoopInterchange
# 2024-05-21T16:16:31Z NeuronLoopInterchange finished after 0.025 seconds
# 2024-05-21T16:16:31Z Running NeuronLICM
# 2024-05-21T16:16:32Z NeuronLICM finished after 0.079 seconds
# 2024-05-21T16:16:32Z Running FactorizeBlkDims
# 2024-05-21T16:16:32Z FactorizeBlkDims finished after 0.478 seconds
# 2024-05-21T16:16:32Z Running NeuronInstComb
# 2024-05-21T16:16:33Z NeuronInstComb finished after 0.573 seconds
# 2024-05-21T16:16:33Z Running NeuronValueNumbering
# 2024-05-21T16:16:33Z NeuronValueNumbering finished after 0.115 seconds
# 2024-05-21T16:16:33Z Running NeuronInstComb
# 2024-05-21T16:16:34Z NeuronInstComb finished after 0.090 seconds
# 2024-05-21T16:16:34Z Running VectorizeDMA
# 2024-05-21T16:16:34Z VectorizeDMA finished after 0.066 seconds
# 2024-05-21T16:16:34Z Running NeuronSimplifyPredicates
# 2024-05-21T16:16:34Z NeuronSimplifyPredicates finished after 0.023 seconds
# 2024-05-21T16:16:34Z Running LegalizePartitionReduce
# 2024-05-21T16:16:35Z LegalizePartitionReduce finished after 0.024 seconds
# 2024-05-21T16:16:35Z Running DeConcat
# 2024-05-21T16:16:35Z DeConcat finished after 0.018 seconds
# 2024-05-21T16:16:35Z Running PartialSimdFusion
# 2024-05-21T16:16:35Z PartialSimdFusion finished after 0.232 seconds
# 2024-05-21T16:16:35Z Running TritiumFusion
# 2024-05-21T16:16:36Z TritiumFusion finished after 0.524 seconds
# 2024-05-21T16:16:36Z Running CCOpFusion
# 2024-05-21T16:16:37Z CCOpFusion finished after 0.266 seconds
# 2024-05-21T16:16:37Z Running VectorizeMatMult
# 2024-05-21T16:16:37Z VectorizeMatMult finished after 0.011 seconds
# 2024-05-21T16:16:37Z Running PartialLoopFusion
# 2024-05-21T16:16:37Z PartialLoopFusion finished after 0.398 seconds
# 2024-05-21T16:16:37Z Running NeuronLICM
# 2024-05-21T16:16:38Z NeuronLICM finished after 0.075 seconds
# 2024-05-21T16:16:38Z Running LowerTranspose
# 2024-05-21T16:16:38Z LowerTranspose finished after 0.196 seconds
# 2024-05-21T16:16:38Z Running LateNeuronInstComb
# 2024-05-21T16:16:39Z LateNeuronInstComb finished after 0.789 seconds
# 2024-05-21T16:16:39Z Running SplitAccGrp
# 2024-05-21T16:16:40Z SplitAccGrp finished after 0.024 seconds
# 2024-05-21T16:16:40Z Running SpillPSum
# 2024-05-21T16:16:40Z SpillPSum finished after 0.268 seconds
# 2024-05-21T16:16:40Z Running LowerIntrinsics
# 2024-05-21T16:16:40Z LowerIntrinsics finished after 0.025 seconds
# 2024-05-21T16:16:40Z Running LegalizeType
# 2024-05-21T16:16:42Z LegalizeType finished after 1.856 seconds
# 2024-05-21T16:16:42Z Running NeuronLICM
# 2024-05-21T16:16:43Z NeuronLICM finished after 0.083 seconds
# 2024-05-21T16:16:43Z Running InferPSumTensor
# 2024-05-21T16:16:43Z InferPSumTensor finished after 0.220 seconds
# 2024-05-21T16:16:43Z Running WeightCoalescing
# 2024-05-21T16:16:43Z WeightCoalescing finished after 0.105 seconds
# 2024-05-21T16:16:43Z Running LegalizeSundaAccess
# 2024-05-21T16:16:44Z LegalizeSundaAccess finished after 0.138 seconds
# 2024-05-21T16:16:44Z Running RelaxPredicates
# 2024-05-21T16:16:44Z RelaxPredicates finished after 0.037 seconds
# 2024-05-21T16:16:44Z Running TensorInitialization
# 2024-05-21T16:16:44Z TensorInitialization finished after 0.018 seconds
# 2024-05-21T16:16:44Z Running NeuronSimplifyPredicates
# 2024-05-21T16:16:44Z NeuronSimplifyPredicates finished after 0.021 seconds
# 2024-05-21T16:16:44Z Running ExpandISAMacro
# 2024-05-21T16:16:45Z ExpandISAMacro finished after 0.381 seconds
# 2024-05-21T16:16:45Z Running SimplifyNeuronTensor
# 2024-05-21T16:16:45Z SimplifyNeuronTensor finished after 0.091 seconds
# 2024-05-21T16:16:45Z Running DMALocalityOpt
# 2024-05-21T16:16:45Z DMALocalityOpt finished after 0.011 seconds
# 2024-05-21T16:16:45Z Running DataStreaming
# 2024-05-21T16:16:45Z DataStreaming finished after 0.055 seconds
# 2024-05-21T16:16:45Z Running SFKVectorizer
# 2024-05-21T16:16:48Z SFKVectorizer finished after 3.301 seconds
# 2024-05-21T16:16:48Z Running LateLegalizeInst
# 2024-05-21T16:16:48Z LateLegalizeInst finished after 0.029 seconds
# 2024-05-21T16:16:48Z Running CoalesceCCOp
# 2024-05-21T16:16:48Z CoalesceCCOp finished after 0.029 seconds
# 2024-05-21T16:16:48Z Running SimpleAllReduceTiling
# 2024-05-21T16:16:48Z SimpleAllReduceTiling finished after 0.028 seconds
# 2024-05-21T16:16:48Z Running StaticProfiler
# 2024-05-21T16:16:48Z StaticProfiler finished after 0.064 seconds
# 2024-05-21T16:16:48Z Running SplitAPUnionSets
# 2024-05-21T16:16:49Z SplitAPUnionSets finished after 0.192 seconds
# 2024-05-21T16:16:49Z Running DumpGraphAndMetadata
# 2024-05-21T16:16:49Z DumpGraphAndMetadata finished after 0.062 seconds
# 2024-05-21T16:16:49Z Running BirCodeGenLoop
# 2024-05-21T16:16:49Z BirCodeGenLoop finished after 0.707 seconds
# 2024-05-21T16:16:51Z Running mod_parallel_pass
# 2024-05-21T16:16:51Z Running rewrite_matmult_sparse
# 2024-05-21T16:16:51Z rewrite_matmult_sparse finished after 0.000 seconds
# 2024-05-21T16:16:51Z Running birverifier
# 2024-05-21T16:16:51Z birverifier finished after 0.041 seconds
# 2024-05-21T16:16:51Z Running expand_replication
# 2024-05-21T16:16:51Z expand_replication finished after 0.000 seconds
# 2024-05-21T16:16:51Z Running unroll
# 2024-05-21T16:16:52Z unroll finished after 0.141 seconds
# 2024-05-21T16:16:52Z Running psum_legalization
# 2024-05-21T16:16:52Z psum_legalization finished after 0.003 seconds
# 2024-05-21T16:16:52Z Running error_injector
# 2024-05-21T16:16:52Z error_injector finished after 0.000 seconds
# 2024-05-21T16:16:52Z Running constant_propagate
# 2024-05-21T16:16:52Z constant_propagate finished after 0.162 seconds
# 2024-05-21T16:16:52Z Running vn_splitter
# 2024-05-21T16:16:52Z vn_splitter finished after 0.013 seconds
# 2024-05-21T16:16:52Z Running lower_ac
# 2024-05-21T16:16:52Z lower_ac finished after 0.002 seconds
# 2024-05-21T16:16:52Z Running input_dma_coalescing
# 2024-05-21T16:16:52Z input_dma_coalescing finished after 0.005 seconds
# 2024-05-21T16:16:52Z Running early_peephole_opts
# 2024-05-21T16:16:52Z early_peephole_opts finished after 0.001 seconds
# 2024-05-21T16:16:52Z Running pre_sched
# 2024-05-21T16:16:52Z pre_sched finished after 0.134 seconds
# 2024-05-21T16:16:52Z Running tensor_copy_elim
# 2024-05-21T16:16:52Z tensor_copy_elim finished after 0.016 seconds
# 2024-05-21T16:16:52Z Running mm_packing
# 2024-05-21T16:16:52Z mm_packing finished after 0.098 seconds
# 2024-05-21T16:16:52Z Running coloring_allocator_psum
# 2024-05-21T16:16:52Z coloring_allocator_psum finished after 0.070 seconds
# 2024-05-21T16:16:52Z Running dma_optimization_psum
# 2024-05-21T16:16:52Z dma_optimization_psum finished after 0.010 seconds
# 2024-05-21T16:16:52Z Running address_rotation_psum
# 2024-05-21T16:16:52Z address_rotation_psum finished after 0.047 seconds
# 2024-05-21T16:16:52Z Running coloring_allocator_sb
# 2024-05-21T16:16:52Z coloring_allocator_sb finished after 0.060 seconds
# 2024-05-21T16:16:52Z Running address_rotation_sb
# 2024-05-21T16:16:52Z address_rotation_sb finished after 0.016 seconds
# 2024-05-21T16:16:52Z Running dma_optimization_sb
# 2024-05-21T16:16:52Z dma_optimization_sb finished after 0.079 seconds
# 2024-05-21T16:16:52Z Running address_rotation_sb
# 2024-05-21T16:16:52Z address_rotation_sb finished after 0.093 seconds
# 2024-05-21T16:16:52Z Running coloring_allocator_dram
# 2024-05-21T16:16:52Z coloring_allocator_dram finished after 0.023 seconds
# 2024-05-21T16:16:52Z Running address_rotation_dram
# 2024-05-21T16:16:52Z address_rotation_dram finished after 0.011 seconds
# 2024-05-21T16:16:52Z Running tensorcopy_accel
# 2024-05-21T16:16:52Z tensorcopy_accel finished after 0.001 seconds
# 2024-05-21T16:16:52Z Running peephole_opts
# 2024-05-21T16:16:52Z peephole_opts finished after 0.009 seconds
# 2024-05-21T16:16:52Z Running lower_kernel
# 2024-05-21T16:16:52Z lower_kernel finished after 0.001 seconds
# 2024-05-21T16:16:52Z Running build_fdeps
# 2024-05-21T16:16:52Z build_fdeps finished after 0.048 seconds
# 2024-05-21T16:16:52Z Running remove_redundancies
# 2024-05-21T16:16:52Z remove_redundancies finished after 0.007 seconds
# 2024-05-21T16:16:52Z Running anti_dependency_analyzer
# 2024-05-21T16:16:53Z anti_dependency_analyzer finished after 0.124 seconds
# 2024-05-21T16:16:53Z Running tensor_copy_elim
# 2024-05-21T16:16:53Z tensor_copy_elim finished after 0.018 seconds
# 2024-05-21T16:16:53Z Running post_sched
# 2024-05-21T16:16:53Z post_sched finished after 0.637 seconds
# 2024-05-21T16:16:53Z Running address_rotation_sb
# 2024-05-21T16:16:53Z address_rotation_sb finished after 0.282 seconds
# 2024-05-21T16:16:53Z Running anti_dependency_analyzer
# 2024-05-21T16:16:54Z anti_dependency_analyzer finished after 0.126 seconds
# 2024-05-21T16:16:54Z Running dep_opt
# 2024-05-21T16:16:54Z dep_opt finished after 0.066 seconds
# 2024-05-21T16:16:54Z Running report_stats
# 2024-05-21T16:16:54Z report_stats finished after 0.002 seconds
# 2024-05-21T16:16:54Z Running assign_trigger_engine
# 2024-05-21T16:16:54Z assign_trigger_engine finished after 0.003 seconds
# 2024-05-21T16:16:54Z Running alloc_queues
# 2024-05-21T16:16:54Z alloc_queues finished after 0.001 seconds
# 2024-05-21T16:16:54Z mod_parallel_pass finished after 2.368 seconds
# 2024-05-21T16:16:54Z Running dep_reduction
# 2024-05-21T16:16:54Z dep_reduction finished after 0.185 seconds
# 2024-05-21T16:16:54Z Running bir_racecheck
# 2024-05-21T16:16:54Z bir_racecheck finished after 0.170 seconds
# 2024-05-21T16:16:54Z Running lower_dma
# 2024-05-21T16:16:54Z lower_dma finished after 0.028 seconds
# 2024-05-21T16:16:54Z Running coalesce_dma_blocks
# 2024-05-21T16:16:54Z coalesce_dma_blocks finished after 0.007 seconds
# 2024-05-21T16:16:54Z Running alloc_semaphores
# 2024-05-21T16:16:54Z alloc_semaphores finished after 0.019 seconds
# 2024-05-21T16:16:54Z Running expand_inst_late
# 2024-05-21T16:16:54Z expand_inst_late finished after 0.001 seconds
# 2024-05-21T16:16:54Z Running lower_sync
# 2024-05-21T16:16:54Z lower_sync finished after 0.006 seconds
# 2024-05-21T16:16:54Z Running lower_act
# 2024-05-21T16:16:54Z lower_act finished after 0.002 seconds
# 2024-05-21T16:16:54Z Running lower_dve
# 2024-05-21T16:16:54Z lower_dve finished after 0.044 seconds
# 2024-05-21T16:16:54Z Running lower_ap
# 2024-05-21T16:16:54Z lower_ap finished after 0.007 seconds
# 2024-05-21T16:16:54Z Running alloc_regs
# 2024-05-21T16:16:54Z alloc_regs finished after 0.000 seconds
# 2024-05-21T16:16:54Z Running birverifier
# 2024-05-21T16:16:54Z birverifier finished after 0.035 seconds
# 2024-05-21T16:16:54Z Running codegen
# 2024-05-21T16:16:54Z isa_gen finished after 0.134 seconds
# 2024-05-21T16:16:54Z dma_desc_gen finished after 0.019 seconds
# 2024-05-21T16:16:54Z debug_info_gen finished after 0.061 seconds
# 2024-05-21T16:16:54Z codegen finished after 0.224 seconds
# 2024-05-21T16:16:54Z Running neff_packager
# 2024-05-21T16:17:37Z neff_packager finished after 42.343 seconds
# 2024-05-21T16:17:39Z Compiler status PASS

# %% [markdown]
# ## Run inference and compare results
#
# In this section we load the compiled model, run inference on Neuron, and compare the CPU and Neuron outputs.

# %%
# Load the TorchScript compiled model
model_neuron = torch.jit.load(filename)

# Run inference using the Neuron model
output_neuron = model_neuron(*example)
print(f"CPU last_hidden_state:    {model_output_cpu['last_hidden_state'][0][0][:10]}")
print(f"Neuron last_hidden_state: {output_neuron['last_hidden_state'][0][0][:10]}")
# Out:
# CPU last_hidden_state:    tensor([-0.3375,  1.2365, -1.0101, -0.2161, -0.7159, -1.2892,  1.6885,  1.4007,
#          0.2508, -0.1514])
# Neuron last_hidden_state: tensor([-0.3359,  1.2321, -1.0102, -0.2110, -0.7203, -1.2865,  1.6864,  1.4100,
#          0.2467, -0.1557])
