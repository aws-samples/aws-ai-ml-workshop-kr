# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile .env
#
# TAVILY_API_KEY = your_key
# JINA_API_KEY = your_key
# CHROME_INSTANCE_PATH = /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# BROWSER_HEADLESS=False
# Out:
# Overwriting .env

# %%
import sys
from src.workflow import run_agent_workflow
# Out:
# sdsdsd BROWSER_HEADLESS False
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# INFO     [browser_use] BrowserUse logging setup complete with level info
# INFO     [telemetry] Anonymized telemetry enabled. See https://docs.browser-use.com/development/telemetry for more information.

# %%
# user_query = '''
#     I would like to analyze Amazon product sales data.
#     The target for analysis is the './data/Amazon_Sale_Report.csv' file.
#     Please conduct an analysis to extract marketing insights based on this data.
#     Please perform various analytical techniques starting from basic data attribute exploration, product sales trends, variable relationships, variable combinations, etc.
#     If there are any additional analyses needed to extract insights after the data analysis, please perform those as well.
#     Please include detailed analysis in the report along with supporting images and charts.
#     Please save the final report in PDF format.
# '''

user_query = '''
    이것은 아마존 상품판매 데이터를 분석하고 싶습니다.
    분석대상은 "./data/Amazon_Sale_Report.csv" 파일 입니다.
    데이터를 기반으로 마케팅 인사이트 추출을 위한 분석을 진행해 주세요.
    분석은 기본적인 데이터 속성 탐색 부터, 상품 판매 트렌드, 변수 관계, 변수 조합 등 다양한 분석 기법을 수행해 주세요.
    데이터 분석 후 인사이트 추출에 필요한 사항이 있다면 그를 위한 추가 분석도 수행해 주세요.
    분석 리포트는 상세 분석과 그 것을 뒷받침 할 수 있는 이미지 및 차트를 함께 삽입해 주세요.
    최종 리포트는 html 형태로 저장해 주세요.
'''

# user_query = '''
#     영문으로 작성된 pptx 파일을 한글로 변환하고 싶습니다.
#     대상은 "./data/bedrock.pptx" 파일 입니다.
#     슬라이드의 영문을 한글로 번역하고 슬라이드 structure는 유지해 주세요.
# '''

# user_query = '''
#     주어진 프로젝트 소스코드는 "Bedrock-Manus: AI automation framework optimized for Amazon Bedrock and business use cases 입니다."
#     프로젝트 소스코드는 "./data/08_bedrock_manus.tar.gz" 파일 입니다.
#     나는 Streamlit을 이용해서 이 소스코드에 대한 UI를 만들고 싶습니다. 
#     제가 원하는 요구사항은
#     1. 현재 스텝이 무엇인지 (coodinator, supervisor, planner 등등) 보이는 곳이 있으면 좋겠습니다.
#         - 스텝에 대한 자세한 정보는 "./README.md"를 참고하시면 됩니다. 
#     2. 각 스텝에서 진행되는 것이 보였으면 좋겠습니다. 즉, 각 스텝에서 llm이 생성하는 토큰들을 실시간으로 볼 수 있으면 좋겠습니다. 
#     3. "app.py" 파일만 생성하지 말고, 필요하다면 기존의 다른 파일 (workflow.py 등)들도  수정하세요. 
#     4. 수정된 파일은 모두 ./artifacts 에 넣어주세요.
#     참고할 사항이 있습니다. 
#     1. 소스코드 수행은 "main.py"로 수행됩니다. 
#     2. "./src/service/workflow_service.py" 이 파일은 참고하지 마세요. 

#     UI 생성을 위한 프로젝트 코드를 작성해주세요
#     결과물은 ./artifacts 에 넣어주세요.
# '''

# %%
import os
import shutil

def remove_artifact_folder(folder_path="./artifacts/"):
    """
    ./artifact/ 폴더가 존재하면 삭제하는 함수
    
    Args:
        folder_path (str): 삭제할 폴더 경로
    """
    if os.path.exists(folder_path):
        print(f"'{folder_path}' 폴더를 삭제합니다...")
        try:
            # 폴더와 그 내용을 모두 삭제
            shutil.rmtree(folder_path)
            print(f"'{folder_path}' 폴더가 성공적으로 삭제되었습니다.")
        except Exception as e:
            print(f"오류 발생: {e}")
    else:
        print(f"'{folder_path}' 폴더가 존재하지 않습니다.")


#import nest_asyncio
#nest_asyncio.apply()

remove_artifact_folder()

result = run_agent_workflow(
    user_input=user_query,
    debug=False
)

# Print the conversation history
print("\n=== Conversation History ===")
print ("result", result)
for history in result["history"]:

    print ("===")
    print (f'agent: {history["agent"]}')
    print (f'message: {history["message"]}')
# Out:
# INFO [src.workflow] ===== Starting workflow =====
#
# INFO [src.workflow]
# user input:
#     이것은 아마존 상품판매 데이터를 분석하고 싶습니다.
#     분석대상은 "./data/Amazon_Sale_Report.csv" 파일 입니다.
#     데이터를 기반으로 마케팅 인사이트 추출을 위한 분석을 진행해 주세요.
#     분석은 기본적인 데이터 속성 탐색 부터, 상품 판매 트렌드, 변수 관계, 변수 조합 등 다양한 분석 기법을 수행해 주세요.
#     데이터 분석 후 인사이트 추출에 필요한 사항이 있다면 그를 위한 추가 분석도 수행해 주세요.
#     분석 리포트는 상세 분석과 그 것을 뒷받침 할 수 있는 이미지 및 차트를 함께 삽입해 주세요.
#     최종 리포트는 html 형태로 저장해 주세요.
#
#
# INFO [src.graph.nodes] ===== Coordinator talking...... =====
# './artifacts/' 폴더가 존재하지 않습니다.
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# handoff_to_planner: I'll need to consult our planning system for this request.
#
# 이 요청은 아마존 판매 데이터 분석과 관련된 복잡한 작업을 포함하고 있어 플래너 시스템의 도움이 필요합니다. 데이터 분석, 시각화, HTML 리포트 생성 등 전문적인 작업이 요구되기 때문입니다.
# INFO [src.graph.nodes] ===== Coordinator completed task =====
#
# INFO [src.graph.nodes] ===== Planner generating full plan =====
#
# INFO [src.graph.nodes] ===== Planner - Deep thinking mode: True =====
#
# INFO [src.graph.nodes] ===== Planner - Search before planning: False =====
# Stop reason: end_turn
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# Let me analyze the user's request:
#
# 1. They want to analyze Amazon product sales data stored in "./data/Amazon_Sale_Report.csv"
# 2. The purpose is to extract marketing insights
# 3. Analysis should include:
#    - Basic data exploration
#    - Product sales trends
#    - Variable relationships
#    - Variable combinations
#    - Additional analyses as needed
# 4. The final report should include detailed analysis with supporting images/charts
# 5. The report should be saved in HTML format
#
# The request is in Korean, so I'll develop a plan in Korean as well.
#
# This task requires several steps involving different agents:
# 1. Coder to load, process, and analyze the data, as well as create visualizations
# 2. Reporter to compile the final insights and create an HTML report
#
# Let me develop a detailed plan:
#
# 1. Coder: Data loading, exploration, and analysis
#    - Load the CSV file and check its structure
#    - Perform data cleaning and preprocessing
#    - Perform basic exploratory data analysis (EDA)
#    - Analyze product sales trends
#    - Investigate relationships between variables
#    - Perform additional analyses based on initial findings
#    - Create visualizations and charts
#    - Save all visualizations to be used in the report
#
# 2. Reporter: Final report compilation in HTML format
#    - Compile all insights from the data analysis
#    - Structure the report with appropriate sections
#    - Insert all the visualizations created by the Coder
#    - Format the report in HTML
#    - Save the final HTML report
#
# This division of labor ensures that:
# 1. Coder handles all the technical data work in one step
# 2. Reporter compiles the final report with insights and visualizations
#
# Let's write this plan in Korean since the user's request was in Korean:# Plan
#
# ## thought
# 사용자는 아마존 상품판매 데이터를 분석하고 마케팅 인사이트를 추출하길 원합니다. "./data/Amazon_Sale_Report.csv" 파일을 기반으로 기본 데이터 탐색부터 상품 판매 트렌드, 변수 관계, 변수 조합 등 다양한 분석을 수행하고 결과를 HTML 형식으로 제공해야 합니다. 이를 위해 Coder가 데이터 분석과 시각화를 수행하고, Reporter가 최종 HTML 보고서를 작성하는 구조로 계획을 수립하겠습니다.
#
# ## title:
# 아마존 판매 데이터 분석 및 마케팅 인사이트 도출 프로젝트
#
# ## steps:
# ### 1. Coder: 아마존 판매 데이터 분석 및 시각화
# - [ ] CSV 파일 로딩 및 데이터 구조 파악
# - [ ] 데이터 전처리 및 정제 (결측치, 이상치 처리)
# - [ ] 기본 데이터 탐색적 분석(EDA) 수행
# - [ ] 상품 판매 트렌드 분석 (시계열, 계절성, 카테고리별 성과)
# - [ ] 변수 간 상관관계 분석
# - [ ] 판매 성과에 영향을 미치는 주요 요인 도출
# - [ ] 고객 세그먼트 및 구매 패턴 분석
# - [ ] 지역별/카테고리별 판매 비교 분석
# - [ ] 다양한 시각화 차트 생성 (막대, 선, 파이, 히트맵 등)
# - [ ] 추가 데이터 인사이트 도출을 위한 심화 분석
# - [ ] 분석 결과 및 시각화 자료 저장
#
# ### 2. Reporter: 마케팅 인사이트 최종 보고서 작성
# - [ ] 데이터 분석 결과 종합 및 구조화
# - [ ] 주요 마케팅 인사이트 도출 및 정리
# - [ ] 시각화 자료를 활용한 인사이트 설명
# - [ ] 판매 성과 향상을 위한 제안사항 작성
# - [ ] 보고서를 HTML 형식으로 작성 및 저장
# - [ ] 최종 보고서 검토 및 완성
# INFO [src.graph.nodes] ===== Planner completed task =====
#
# INFO [src.graph.nodes] ===== Supervisor evaluating next action =====
# Stop reason: end_turn
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# {"next": "coder"}
# INFO [src.graph.nodes] Supervisor delegating to: coder
#
# INFO [src.graph.nodes] ===== Supervisor completed task =====
#
# INFO [src.graph.nodes] ===== Code agent starting task =====
# Stop reason: end_turn
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# --- 대화 턴 1 ---
# 계획에 따라 첫 번째 단계인 데이터 로딩과 구조 파악부터 시작하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport lovelyplots\nimport os\nfrom datetime import datetime\n\n# Style 설정\nplt.style.use([\'ipynb\', \'use_mathtext\',\'colors5-light\'])\nplt.rc(\'font\', family=\'NanumGothic\')\n\n# 데이터 로드\ndf = pd.read_csv(\'./data/Amazon_Sale_Report.csv\')\n\n# 기본 데이터 정보 확인\nprint("=== 데이터 기본 정보 ===")\nprint("\\n1. 데이터 크기:")\nprint(df.shape)\n\nprint("\\n2. 컬럼 목록:")\nprint(df.columns.tolist())\n\nprint("\\n3. 데이터 타입:")\nprint(df.dtypes)\n\nprint("\\n4. 결측치 현황:")\nprint(df.isnull().sum())\n\nprint("\\n5. 데이터 미리보기:")\nprint(df.head())\n\n# 결과 저장\nos.makedirs(\'./artifacts\', exist_ok=True)\n\n# Result file path\nresults_file = \'./artifacts/all_results.txt\'\nbackup_file = \'./artifacts/all_results_backup_{}.txt\'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))\n\n# Current analysis parameters\nstage_name = "Initial Data Loading and Structure Analysis"\nresult_description = f"""\n데이터셋 기본 정보:\n- 데이터 크기: {df.shape[0]}행 x {df.shape[1]}열\n- 컬럼 목록: {\', \'.join(df.columns.tolist())}\n- 데이터 타입 정보: \n{df.dtypes.to_string()}\n- 결측치 현황:\n{df.isnull().sum().to_string()}\n"""\n\n# Direct generation of result text\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\n# Add new results\nwith open(results_file, \'a\', encoding=\'utf-8\') as f:\n    f.write(current_result_text)'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
# Stop reason: tool_use
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import lovelyplots
# import os
# from datetime import datetime
#
# # Style 설정
# plt.style.use(['ipynb', 'use_mathtext','colors5-light'])
# plt.rc('font', family='NanumGothic')
#
# # 데이터 로드
# df = pd.read_csv('./data/Amazon_Sale_Report.csv')
#
# # 기본 데이터 정보 확인
# print("=== 데이터 기본 정보 ===")
# print("\n1. 데이터 크기:")
# print(df.shape)
#
# print("\n2. 컬럼 목록:")
# print(df.columns.tolist())
#
# print("\n3. 데이터 타입:")
# print(df.dtypes)
#
# print("\n4. 결측치 현황:")
# print(df.isnull().sum())
#
# print("\n5. 데이터 미리보기:")
# print(df.head())
#
# # 결과 저장
# os.makedirs('./artifacts', exist_ok=True)
#
# # Result file path
# results_file = './artifacts/all_results.txt'
# backup_file = './artifacts/all_results_backup_{}.txt'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))
#
# # Current analysis parameters
# stage_name = "Initial Data Loading and Structure Analysis"
# result_description = f"""
# 데이터셋 기본 정보:
# - 데이터 크기: {df.shape[0]}행 x {df.shape[1]}열
# - 컬럼 목록: {', '.join(df.columns.tolist())}
# - 데이터 타입 정보:
# {df.dtypes.to_string()}
# - 결측치 현황:
# {df.isnull().sum().to_string()}
# """
#
# # Direct generation of result text
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# # Add new results
# with open(results_file, 'a', encoding='utf-8') as f:
#     f.write(current_result_text)
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: Traceback (most recent call last):
#   File "<string>", line 4, in <module>
# ModuleNotFoundError: No module named 'seaborn'
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 2 ---
#
#
# 죄송합니다. seaborn 모듈이 설치되어 있지 않아 오류가 발생했네요. 필요한 라이브러리를 설치하고 다시 시도하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: bash_tool, Input: {'cmd': 'pip install seaborn'}
#
# INFO [src.tools.bash_tool] ===== Executing Bash =====
#
# INFO [src.tools.bash_tool] ===== Coder - Command: pip install seaborn =====
# Stop reason: tool_use
# INFO [src.tools.decorators]
# Coder - Tool handle_bash_tool returned:
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.11/site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.11/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.11/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 3 ---
#
#
# 이제 다시 데이터 분석을 시작하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport os\nfrom datetime import datetime\n\n# Style 설정\nplt.style.use([\'ipynb\', \'use_mathtext\',\'colors5-light\'])\nplt.rc(\'font\', family=\'NanumGothic\')\n\n# 데이터 로드\ndf = pd.read_csv(\'./data/Amazon_Sale_Report.csv\')\n\n# 기본 데이터 정보 확인\nprint("=== 데이터 기본 정보 ===")\nprint("\\n1. 데이터 크기:")\nprint(df.shape)\n\nprint("\\n2. 컬럼 목록:")\nprint(df.columns.tolist())\n\nprint("\\n3. 데이터 타입:")\nprint(df.dtypes)\n\nprint("\\n4. 결측치 현황:")\nprint(df.isnull().sum())\n\nprint("\\n5. 데이터 미리보기:")\nprint(df.head())\n\nprint("\\n6. 기술통계 정보:")\nprint(df.describe())'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
# Stop reason: tool_use
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import os
# from datetime import datetime
#
# # Style 설정
# plt.style.use(['ipynb', 'use_mathtext','colors5-light'])
# plt.rc('font', family='NanumGothic')
#
# # 데이터 로드
# df = pd.read_csv('./data/Amazon_Sale_Report.csv')
#
# # 기본 데이터 정보 확인
# print("=== 데이터 기본 정보 ===")
# print("\n1. 데이터 크기:")
# print(df.shape)
#
# print("\n2. 컬럼 목록:")
# print(df.columns.tolist())
#
# print("\n3. 데이터 타입:")
# print(df.dtypes)
#
# print("\n4. 결측치 현황:")
# print(df.isnull().sum())
#
# print("\n5. 데이터 미리보기:")
# print(df.head())
#
# print("\n6. 기술통계 정보:")
# print(df.describe())
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: Traceback (most recent call last):
#   File "<string>", line 4, in <module>
# ModuleNotFoundError: No module named 'seaborn'
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 4 ---
#
#
# 죄송합니다. seaborn 관련 문제가 계속되고 있네요. seaborn을 제외하고 기본적인 분석을 진행하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport os\nfrom datetime import datetime\n\n# Style 설정\nplt.style.use([\'ipynb\', \'use_mathtext\',\'colors5-light\'])\nplt.rc(\'font\', family=\'NanumGothic\')\n\n# 데이터 로드\ndf = pd.read_csv(\'./data/Amazon_Sale_Report.csv\')\n\n# 기본 데이터 정보 확인\nprint("=== 데이터 기본 정보 ===")\nprint("\\n1. 데이터 크기:")\nprint(df.shape)\n\nprint("\\n2. 컬럼 목록:")\nprint(df.columns.tolist())\n\nprint("\\n3. 데이터 타입:")\nprint(df.dtypes)\n\nprint("\\n4. 결측치 현황:")\nprint(df.isnull().sum())\n\nprint("\\n5. 데이터 미리보기:")\nprint(df.head())\n\nprint("\\n6. 기술통계 정보:")\nprint(df.describe())'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
# Stop reason: tool_use
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# from datetime import datetime
#
# # Style 설정
# plt.style.use(['ipynb', 'use_mathtext','colors5-light'])
# plt.rc('font', family='NanumGothic')
#
# # 데이터 로드
# df = pd.read_csv('./data/Amazon_Sale_Report.csv')
#
# # 기본 데이터 정보 확인
# print("=== 데이터 기본 정보 ===")
# print("\n1. 데이터 크기:")
# print(df.shape)
#
# print("\n2. 컬럼 목록:")
# print(df.columns.tolist())
#
# print("\n3. 데이터 타입:")
# print(df.dtypes)
#
# print("\n4. 결측치 현황:")
# print(df.isnull().sum())
#
# print("\n5. 데이터 미리보기:")
# print(df.head())
#
# print("\n6. 기술통계 정보:")
# print(df.describe())
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: Traceback (most recent call last):
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/style/core.py", line 129, in use
#     style = _rc_params_in_file(style)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/__init__.py", line 903, in _rc_params_in_file
#     with _open_file_or_url(fname) as fd:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/contextlib.py", line 137, in __enter__
#     return next(self.gen)
#            ^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/__init__.py", line 880, in _open_file_or_url
#     with open(fname, encoding='utf-8') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'ipynb'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<string>", line 8, in <module>
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/style/core.py", line 131, in use
#     raise OSError(
# OSError: 'ipynb' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 5 ---
#
#
# 스타일 설정에서 오류가 발생했네요. 기본 스타일로 변경하여 다시 시도하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport os\nfrom datetime import datetime\n\n# Style 설정\nplt.style.use(\'default\')\n\n# 데이터 로드\ndf = pd.read_csv(\'./data/Amazon_Sale_Report.csv\')\n\n# 기본 데이터 정보 확인\nprint("=== 데이터 기본 정보 ===")\nprint("\\n1. 데이터 크기:")\nprint(df.shape)\n\nprint("\\n2. 컬럼 목록:")\nprint(df.columns.tolist())\n\nprint("\\n3. 데이터 타입:")\nprint(df.dtypes)\n\nprint("\\n4. 결측치 현황:")\nprint(df.isnull().sum())\n\nprint("\\n5. 데이터 미리보기:")\nprint(df.head())\n\nprint("\\n6. 기술통계 정보:")\nprint(df.describe())\n\n# 결과 저장\nos.makedirs(\'./artifacts\', exist_ok=True)\n\n# Result file path\nresults_file = \'./artifacts/all_results.txt\'\nbackup_file = \'./artifacts/all_results_backup_{}.txt\'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))\n\n# Current analysis parameters\nstage_name = "Initial Data Loading and Structure Analysis"\nresult_description = f"""\n데이터셋 기본 정보:\n- 데이터 크기: {df.shape[0]}행 x {df.shape[1]}열\n- 컬럼 목록: {\', \'.join(df.columns.tolist())}\n- 데이터 타입 정보: \n{df.dtypes.to_string()}\n- 결측치 현황:\n{df.isnull().sum().to_string()}\n\n기술통계 정보:\n{df.describe().to_string()}\n"""\n\n# Direct generation of result text\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\n# Add new results\nwith open(results_file, \'a\', encoding=\'utf-8\') as f:\n    f.write(current_result_text)'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
# Stop reason: tool_use
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# from datetime import datetime
#
# # Style 설정
# plt.style.use('default')
#
# # 데이터 로드
# df = pd.read_csv('./data/Amazon_Sale_Report.csv')
#
# # 기본 데이터 정보 확인
# print("=== 데이터 기본 정보 ===")
# print("\n1. 데이터 크기:")
# print(df.shape)
#
# print("\n2. 컬럼 목록:")
# print(df.columns.tolist())
#
# print("\n3. 데이터 타입:")
# print(df.dtypes)
#
# print("\n4. 결측치 현황:")
# print(df.isnull().sum())
#
# print("\n5. 데이터 미리보기:")
# print(df.head())
#
# print("\n6. 기술통계 정보:")
# print(df.describe())
#
# # 결과 저장
# os.makedirs('./artifacts', exist_ok=True)
#
# # Result file path
# results_file = './artifacts/all_results.txt'
# backup_file = './artifacts/all_results_backup_{}.txt'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))
#
# # Current analysis parameters
# stage_name = "Initial Data Loading and Structure Analysis"
# result_description = f"""
# 데이터셋 기본 정보:
# - 데이터 크기: {df.shape[0]}행 x {df.shape[1]}열
# - 컬럼 목록: {', '.join(df.columns.tolist())}
# - 데이터 타입 정보:
# {df.dtypes.to_string()}
# - 결측치 현황:
# {df.isnull().sum().to_string()}
#
# 기술통계 정보:
# {df.describe().to_string()}
# """
#
# # Direct generation of result text
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# # Add new results
# with open(results_file, 'a', encoding='utf-8') as f:
#     f.write(current_result_text)
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: === 데이터 기본 정보 ===
#
# 1. 데이터 크기:
# (128975, 24)
#
# 2. 컬럼 목록:
# ['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ', 'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN', 'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids', 'B2B', 'fulfilled-by', 'Unnamed: 22']
#
# 3. 데이터 타입:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object
#
# 4. 결측치 현황:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64
#
# 5. 데이터 미리보기:
#    index             Order ID      Date  ...    B2B fulfilled-by Unnamed: 22
# 0      0  405-8078784-5731545  04-30-22  ...  False    Easy Ship         NaN
# 1      1  171-9198151-1101146  04-30-22  ...  False    Easy Ship         NaN
# 2      2  404-0687676-7273146  04-30-22  ...   True          NaN         NaN
# 3      3  403-9615377-8133951  04-30-22  ...  False    Easy Ship         NaN
# 4      4  407-1069790-7240320  04-30-22  ...  False          NaN         NaN
#
# [5 rows x 24 columns]
#
# 6. 기술통계 정보:
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 6 ---
#
#
# 데이터의 기본 구조를 파악했습니다. 이제 데이터 전처리와 정제 작업을 진행하겠습니다. 주요 발견사항과 다음 단계 계획은 다음과 같습니다:
#
# 1. 데이터 구조 분석 결과:
# - 총 128,975개의 행과 24개의 열이 있습니다.
# - 주요 결측치가 있는 컬럼:
#   * Courier Status: 6,872개
#   * currency & Amount: 7,795개
#   * ship-city/state/postal-code/country: 각 33개
#   * promotion-ids: 49,153개
#   * fulfilled-by: 89,698개
#   * Unnamed: 22: 49,050개
#
# 2. 다음 단계 계획:
# - Date 컬럼을 datetime 형식으로 변환
# - 불필요한 컬럼 제거 (index, Unnamed: 22)
# - 결측치 처리
# - Amount와 관련된 기본 통계 분석
# - 카테고리별 판매 분석
#
# 이제 이러한 전처리 작업을 수행하겠습니다:
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom datetime import datetime\n\n# 데이터 로드\ndf = pd.read_csv(\'./data/Amazon_Sale_Report.csv\')\n\n# 1. Date 컬럼 datetime으로 변환\ndf[\'Date\'] = pd.to_datetime(df[\'Date\'], format=\'%m-%d-%y\')\n\n# 2. 불필요한 컬럼 제거\ndf = df.drop([\'index\', \'Unnamed: 22\'], axis=1)\n\n# 3. 기본 통계 분석\nprint("=== 판매 금액 기본 통계 ===")\nprint(df[\'Amount\'].describe())\n\n# 4. 카테고리별 판매 분석\ncategory_sales = df.groupby(\'Category\')[\'Amount\'].agg([\'count\', \'sum\', \'mean\']).round(2)\ncategory_sales = category_sales.sort_values(\'sum\', ascending=False)\n\nprint("\\n=== 카테고리별 판매 현황 ===")\nprint(category_sales)\n\n# 5. 월별 판매 트렌드\ndf[\'Month\'] = df[\'Date\'].dt.to_period(\'M\')\nmonthly_sales = df.groupby(\'Month\')[\'Amount\'].agg([\'count\', \'sum\', \'mean\']).round(2)\n\nprint("\\n=== 월별 판매 트렌드 ===")\nprint(monthly_sales)\n\n# 시각화: 카테고리별 총 판매액\nplt.figure(figsize=(15, 6))\nplt.bar(range(len(category_sales)), category_sales[\'sum\'])\nplt.xticks(range(len(category_sales)), category_sales.index, rotation=45, ha=\'right\')\nplt.title(\'카테고리별 총 판매액\')\nplt.xlabel(\'카테고리\')\nplt.ylabel(\'총 판매액\')\nplt.tight_layout()\nplt.savefig(\'./artifacts/category_sales.png\')\nplt.close()\n\n# 결과 저장\nstage_name = "Data Preprocessing and Basic Analysis"\nresult_description = f"""\n전처리 및 기본 분석 결과:\n\n1. 판매 금액 기본 통계:\n{df[\'Amount\'].describe().to_string()}\n\n2. 카테고리별 판매 현황:\n{category_sales.to_string()}\n\n3. 월별 판매 트렌드:\n{monthly_sales.to_string()}\n\n생성된 시각화:\n- 카테고리별 총 판매액 차트 (category_sales.png)\n"""\n\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\n# 결과 저장\nwith open(\'./artifacts/all_results.txt\', \'a\', encoding=\'utf-8\') as f:\n    f.write(current_result_text)\n\n# 판매 상태 분석\nprint("\\n=== 판매 상태 분석 ===")\nprint(df[\'Status\'].value_counts())'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
# Stop reason: tool_use
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from datetime import datetime
#
# # 데이터 로드
# df = pd.read_csv('./data/Amazon_Sale_Report.csv')
#
# # 1. Date 컬럼 datetime으로 변환
# df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')
#
# # 2. 불필요한 컬럼 제거
# df = df.drop(['index', 'Unnamed: 22'], axis=1)
#
# # 3. 기본 통계 분석
# print("=== 판매 금액 기본 통계 ===")
# print(df['Amount'].describe())
#
# # 4. 카테고리별 판매 분석
# category_sales = df.groupby('Category')['Amount'].agg(['count', 'sum', 'mean']).round(2)
# category_sales = category_sales.sort_values('sum', ascending=False)
#
# print("\n=== 카테고리별 판매 현황 ===")
# print(category_sales)
#
# # 5. 월별 판매 트렌드
# df['Month'] = df['Date'].dt.to_period('M')
# monthly_sales = df.groupby('Month')['Amount'].agg(['count', 'sum', 'mean']).round(2)
#
# print("\n=== 월별 판매 트렌드 ===")
# print(monthly_sales)
#
# # 시각화: 카테고리별 총 판매액
# plt.figure(figsize=(15, 6))
# plt.bar(range(len(category_sales)), category_sales['sum'])
# plt.xticks(range(len(category_sales)), category_sales.index, rotation=45, ha='right')
# plt.title('카테고리별 총 판매액')
# plt.xlabel('카테고리')
# plt.ylabel('총 판매액')
# plt.tight_layout()
# plt.savefig('./artifacts/category_sales.png')
# plt.close()
#
# # 결과 저장
# stage_name = "Data Preprocessing and Basic Analysis"
# result_description = f"""
# 전처리 및 기본 분석 결과:
#
# 1. 판매 금액 기본 통계:
# {df['Amount'].describe().to_string()}
#
# 2. 카테고리별 판매 현황:
# {category_sales.to_string()}
#
# 3. 월별 판매 트렌드:
# {monthly_sales.to_string()}
#
# 생성된 시각화:
# - 카테고리별 총 판매액 차트 (category_sales.png)
# """
#
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# # 결과 저장
# with open('./artifacts/all_results.txt', 'a', encoding='utf-8') as f:
#     f.write(current_result_text)
#
# # 판매 상태 분석
# print("\n=== 판매 상태 분석 ===")
# print(df['Status'].value_counts())
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: === 판매 금액 기본 통계 ===
# count    121180.000000
# mean        648.561465
# std         281.211687
# min           0.000000
# 25%         449.000000
# 50%         605.000000
# 75%         788.000000
# max        5584.000000
# Name: Amount, dtype: float64
#
# === 카테고리별 판매 현황 ===
#                count          sum    mean
# Category
# Set            47042  39204124.03  833.39
# kurta          46717  21299546.70  455.93
# Western Dress  14704  11216072.69  762.79
# Top            10165   5347792.30  526.10
# Ethnic Dress    1093    791217.66  723.90
# Blouse           881    458408.18  520.33
# Bottom           420    150667.98  358.73
# Saree            155    123933.76  799.57
# Dupatta            3       915.00  305.00
#
# === 월별 판매 트렌드 ===
#          count          sum    mean
# Month
# 2022-03    162    101683.85  627.68
# 2022-04  46068  28838708.32  626.00
# 2022-05  39536  26226476.75  663.36
# 2022-06  35414  23425809.38  661.48
#
# === 판매 상태 분석 ===
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 7 ---
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3384, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3380 exec_count = self.execution_count
#    3381 if result.error_in_exec:
#    3382     # Store formatted traceback and error details
#    3383     self.history_manager.exceptions[exec_count] = (
# -> 3384         self._format_exception_for_storage(result.error_in_exec)
#    3385     )
#    3387 # Each cell is a *single* input, regardless of how many lines it has
#    3388 self.execution_count += 1
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3438, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3435         stb = evalue._render_traceback_()
#    3436     else:
#    3437         # Otherwise, use InteractiveTB to format the traceback.
# -> 3438         stb = self.InteractiveTB.structured_traceback(
#    3439             etype, evalue, tb, tb_offset=1
#    3440         )
#    3441 except Exception:
#    3442     # In case formatting fails, fallback to Python's built-in formatting.
#    3443     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/ultratb.py:773, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     763         frames.append(
#     764             theme_table[self._theme_name].format(
#     765                 [
#    (...)    770             )
#     771         )
#     772         skipped = 0
# --> 773     frames.append(self.format_record(record))
#     774 if skipped:
#     775     frames.append(
#     776         theme_table[self._theme_name].format(
#     777             [
#    (...)    782         )
#     783     )
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/ultratb.py:652, in VerboseTB.format_record(self, frame_info)
#     648 result += ", " if call else ""
#     649 result += f"{call}\n"
#     650 result += theme_table[self._theme_name].format(
#     651     _format_traceback_lines(
# --> 652         frame_info.lines,
#     653         theme_table[self._theme_name],
#     654         self.has_colors,
#     655         lvals_toks,
#     656     )
#     657 )
#     658 return result
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/IPython/core/tbtools.py:355, in FrameInfo.lines(self)
#     353 assert self._sd is not None
#     354 try:
# --> 355     return self._sd.lines  # type: ignore[misc]
#     356 except NotOneValueFound:
#     358     class Dummy:
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/core.py:734, in FrameInfo.lines(self)
#     718 @cached_property
#     719 def lines(self) -> List[Union[Line, LineGap, BlankLineRange]]:
#     720     """
#     721     A list of lines to display, determined by options.
#     722     The objects yielded either have type Line, BlankLineRange
#    (...)    732     The Line objects are all within the ranges from .included_pieces.
#     733     """
# --> 734     pieces = self.included_pieces
#     735     if not pieces:
#     736         return []
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/core.py:677, in FrameInfo.included_pieces(self)
#     666 @cached_property
#     667 def included_pieces(self) -> List[range]:
#     668     """
#     669     The list of pieces (ranges of lines) to display for this frame.
#     670     Consists of .executing_piece, surrounding context pieces
#    (...)    675     Always a subset of .scope_pieces.
#     676     """
# --> 677     scope_pieces = self.scope_pieces
#     678     if not self.scope_pieces:
#     679         return []
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/core.py:614, in FrameInfo.scope_pieces(self)
#     611 if not self.scope:
#     612     return self.source.pieces
# --> 614 scope_start, scope_end = self.source.line_range(self.scope)
#     615 return [
#     616     piece
#     617     for piece in self.source.pieces
#     618     if scope_start <= piece.start and piece.stop <= scope_end
#     619 ]
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/core.py:178, in Source.line_range(self, node)
#     177 def line_range(self, node: ast.AST) -> Tuple[int, int]:
# --> 178     return line_range(self.asttext(), node)
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/stack_data/utils.py:40, in line_range(atok, node)
#      38     return start, end
#      39 else:
# ---> 40     (start, _), (end, _) = atok.get_text_positions(node, padded=False)
#      41     return start, end + 1
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/asttokens/asttokens.py:401, in ASTText.get_text_positions(self, node, padded)
#     398   return (1, 0), (1, 0)
#     400 if supports_tokenless(node):
# --> 401   return self._get_text_positions_tokenless(node, padded)
#     403 return self.asttokens.get_text_positions(node, padded)
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/asttokens/asttokens.py:371, in ASTText._get_text_positions_tokenless(self, node, padded)
#     369   start_col_offset = 0
#     370 else:
# --> 371   start_col_offset = self._line_numbers.from_utf8_col(start_lineno, start_node.col_offset)
#     373 start = (start_lineno, start_col_offset)
#     375 # To match the token-using behaviour, we exclude trailing semicolons and comments.
#     376 # This means that for blocks containing multiple statements, we have to use the last one
#     377 # instead of the actual node for end_lineno and end_col_offset.
#
# File ~/.conda/envs/bedrock-manus/lib/python3.12/site-packages/asttokens/line_numbers.py:51, in LineNumbers.from_utf8_col(self, line, utf8_column)
#      48   offsets.append(len(line_text))
#      49   self._utf8_offset_cache[line] = offsets
# ---> 51 return offsets[max(0, min(len(offsets)-1, utf8_column))]
#
# KeyboardInterrupt:
