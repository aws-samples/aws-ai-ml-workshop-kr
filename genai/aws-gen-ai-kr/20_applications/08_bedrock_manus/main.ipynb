# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %%writefile .env
#
# TAVILY_API_KEY = your_key
# JINA_API_KEY = your_key
# CHROME_INSTANCE_PATH = /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# BROWSER_HEADLESS=False
# Out:
# Overwriting .env

# %%
import sys
from src.workflow import run_agent_workflow
# Out:
# sdsdsd BROWSER_HEADLESS False
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# INFO     [browser_use] BrowserUse logging setup complete with level info
# INFO     [telemetry] Anonymized telemetry enabled. See https://docs.browser-use.com/development/telemetry for more information.

# %%
# user_query = '''
#     I would like to analyze Amazon product sales data.
#     The target for analysis is the './data/Amazon_Sale_Report.csv' file.
#     Please conduct an analysis to extract marketing insights based on this data.
#     Please perform various analytical techniques starting from basic data attribute exploration, product sales trends, variable relationships, variable combinations, etc.
#     If there are any additional analyses needed to extract insights after the data analysis, please perform those as well.
#     Please include detailed analysis in the report along with supporting images and charts.
#     Please save the final report in PDF format.
# '''

user_query = '''
    이것은 아마존 상품판매 데이터를 분석하고 싶습니다.
    분석대상은 "./data/Amazon_Sale_Report.csv" 파일 입니다.
    데이터를 기반으로 마케팅 인사이트 추출을 위한 분석을 진행해 주세요.
    분석은 기본적인 데이터 속성 탐색 부터, 상품 판매 트렌드, 변수 관계, 변수 조합 등 다양한 분석 기법을 수행해 주세요.
    데이터 분석 후 인사이트 추출에 필요한 사항이 있다면 그를 위한 추가 분석도 수행해 주세요.
    분석 리포트는 상세 분석과 그 것을 뒷받침 할 수 있는 이미지 및 차트를 함께 삽입해 주세요.
    최종 리포트는 html 형태로 저장해 주세요.
'''

# user_query = '''
#     영문으로 작성된 pptx 파일을 한글로 변환하고 싶습니다.
#     대상은 "./data/bedrock.pptx" 파일 입니다.
#     슬라이드의 영문을 한글로 번역하고 슬라이드 structure는 유지해 주세요.
# '''

# user_query = '''
#     주어진 프로젝트 소스코드는 "Bedrock-Manus: AI automation framework optimized for Amazon Bedrock and business use cases 입니다."
#     프로젝트 소스코드는 "./data/08_bedrock_manus.tar.gz" 파일 입니다.
#     나는 Streamlit을 이용해서 이 소스코드에 대한 UI를 만들고 싶습니다. 
#     제가 원하는 요구사항은
#     1. 현재 스텝이 무엇인지 (coodinator, supervisor, planner 등등) 보이는 곳이 있으면 좋겠습니다.
#         - 스텝에 대한 자세한 정보는 "./README.md"를 참고하시면 됩니다. 
#     2. 각 스텝에서 진행되는 것이 보였으면 좋겠습니다. 즉, 각 스텝에서 llm이 생성하는 토큰들을 실시간으로 볼 수 있으면 좋겠습니다. 
#     3. "app.py" 파일만 생성하지 말고, 필요하다면 기존의 다른 파일 (workflow.py 등)들도  수정하세요. 
#     4. 수정된 파일은 모두 ./artifacts 에 넣어주세요.
#     참고할 사항이 있습니다. 
#     1. 소스코드 수행은 "main.py"로 수행됩니다. 
#     2. "./src/service/workflow_service.py" 이 파일은 참고하지 마세요. 

#     UI 생성을 위한 프로젝트 코드를 작성해주세요
#     결과물은 ./artifacts 에 넣어주세요.
# '''

# %%
import os
import shutil

def remove_artifact_folder(folder_path="./artifacts/"):
    """
    ./artifact/ 폴더가 존재하면 삭제하는 함수
    
    Args:
        folder_path (str): 삭제할 폴더 경로
    """
    if os.path.exists(folder_path):
        print(f"'{folder_path}' 폴더를 삭제합니다...")
        try:
            # 폴더와 그 내용을 모두 삭제
            shutil.rmtree(folder_path)
            print(f"'{folder_path}' 폴더가 성공적으로 삭제되었습니다.")
        except Exception as e:
            print(f"오류 발생: {e}")
    else:
        print(f"'{folder_path}' 폴더가 존재하지 않습니다.")


#import nest_asyncio
#nest_asyncio.apply()

remove_artifact_folder()

result = run_agent_workflow(
    user_input=user_query,
    debug=False
)

# Print the conversation history
print("\n=== Conversation History ===")
print ("result", result)
for history in result["history"]:

    print ("===")
    print (f'agent: {history["agent"]}')
    print (f'message: {history["message"]}')
# Out:
# INFO [src.workflow] ===== Starting workflow =====
#
# INFO [src.workflow]
# user input:
#     이것은 아마존 상품판매 데이터를 분석하고 싶습니다.
#     분석대상은 "./data/Amazon_Sale_Report.csv" 파일 입니다.
#     데이터를 기반으로 마케팅 인사이트 추출을 위한 분석을 진행해 주세요.
#     분석은 기본적인 데이터 속성 탐색 부터, 상품 판매 트렌드, 변수 관계, 변수 조합 등 다양한 분석 기법을 수행해 주세요.
#     데이터 분석 후 인사이트 추출에 필요한 사항이 있다면 그를 위한 추가 분석도 수행해 주세요.
#     분석 리포트는 상세 분석과 그 것을 뒷받침 할 수 있는 이미지 및 차트를 함께 삽입해 주세요.
#     최종 리포트는 html 형태로 저장해 주세요.
#
#
# INFO [src.graph.nodes] ===== Coordinator talking...... =====
# './artifacts/' 폴더가 존재하지 않습니다.
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# handoff_to_planner: I'll need to consult our planning system for this request.
#
# 이 요청은 아마존 판매 데이터 분석과 관련된 복잡한 작업을 포함하고 있어 플래너 시스템의 도움이 필요합니다. 데이터 분석, 시각화, HTML 리포트 생성 등의 상세한 계획이 필요한 작업입니다.
# INFO [src.graph.nodes] ===== Coordinator completed task =====
#
# INFO [src.graph.nodes] ===== Planner generating full plan =====
#
# INFO [src.graph.nodes] ===== Planner - Deep thinking mode: True =====
#
# INFO [src.graph.nodes] ===== Planner - Search before planning: False =====
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# Let's analyze the user request carefully:
#
# 1. The user wants to analyze Amazon product sales data.
# 2. The data file is located at "./data/Amazon_Sale_Report.csv".
# 3. The goal is to extract marketing insights from this data.
# 4. The analysis should include:
#    - Basic data exploration
#    - Product sales trends
#    - Variable relationships
#    - Variable combinations
#    - Additional analyses as needed for insights
# 5. The final report should include:
#    - Detailed analysis
#    - Supporting images and charts
#    - The report should be saved as HTML
#
# Now, let's create a detailed plan for this task:
#
# 1. First, we need the Coder to perform the data analysis. The Coder will:
#    - Load the CSV file
#    - Explore the data structure (columns, data types, missing values, etc.)
#    - Perform descriptive statistics
#    - Analyze sales trends over time
#    - Examine relationships between variables
#    - Create visualizations (charts and graphs)
#    - Generate insights based on the analysis
#    - Save all the findings and visualizations for the report
#
# 2. After the analysis is complete, we'll have the Reporter create a comprehensive HTML report that includes:
#    - Introduction to the analysis
#    - Data overview
#    - Detailed findings from each analysis
#    - Visualizations and charts
#    - Marketing insights and recommendations
#    - Conclusion
#    - Save the final report as HTML
#
# Let me formulate this into a structured plan:# Plan
#
# ## thought
# 이 요청은 아마존 상품판매 데이터 분석과 마케팅 인사이트 추출을 요구합니다. "./data/Amazon_Sale_Report.csv" 파일을 분석해야 하며, 기본 데이터 탐색부터 판매 트렌드, 변수 관계 등의 분석이 필요합니다. 분석은 코더를 통해 수행하고, 최종 리포트는 리포터를 통해 HTML 형태로 작성해야 합니다.
#
# ## title:
# 아마존 상품판매 데이터 분석 및 마케팅 인사이트 추출
#
# ## steps:
# ### 1. Coder: 아마존 판매 데이터 분석 및 시각화
# - [ ] "./data/Amazon_Sale_Report.csv" 파일 로드 및 데이터 구조 확인
# - [ ] 기본 데이터 속성 탐색 (데이터 타입, 결측치, 통계 요약, 분포 등)
# - [ ] 판매 트렌드 분석 (시간별, 월별, 분기별 판매 추이)
# - [ ] 인기 제품 및 카테고리 분석
# - [ ] 가격대별 판매 분포 및 수익성 분석
# - [ ] 변수 간 상관관계 분석 (가격과 판매량, 카테고리와 수익 등)
# - [ ] 지역별/시장별 판매 성과 비교 분석
# - [ ] 할인 전략 효과 분석 (해당 데이터가 있는 경우)
# - [ ] 마케팅 인사이트 도출을 위한 추가 분석 수행
# - [ ] 모든 분석 결과 및 시각화 자료 준비
#
# ### 2. Reporter: 최종 HTML 리포트 작성
# - [ ] 데이터 분석 개요 및 목적 소개
# - [ ] 데이터셋 구조 및 특성 설명
# - [ ] 주요 판매 트렌드 및 패턴 요약
# - [ ] 제품/카테고리/가격대별 성과 분석 결과 정리
# - [ ] 변수 간 관계 및 인사이트 설명
# - [ ] 마케팅 전략에 활용 가능한 핵심 인사이트 도출
# - [ ] 시각화 자료 및 차트 포함
# - [ ] 결론 및 액션 아이템 제안
# - [ ] HTML 형태로 최종 리포트 저장
# INFO [src.graph.nodes] ===== Planner completed task =====
#
# INFO [src.graph.nodes] ===== Supervisor evaluating next action =====
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# {"next": "coder"}
# INFO [src.graph.nodes] Supervisor delegating to: coder
#
# INFO [src.graph.nodes] ===== Supervisor completed task =====
#
# INFO [src.graph.nodes] ===== Code agent starting task =====
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)
# --- 대화 턴 1 ---
# 계획에 따라 첫 번째 단계인 데이터 로드와 기본 데이터 속성 탐색부터 시작하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport lovelyplots\nimport os\nfrom datetime import datetime\n\n# 스타일 설정\nplt.style.use([\'ipynb\', \'use_mathtext\',\'colors5-light\'])\nplt.rc(\'font\', family=\'NanumGothic\')\n\n# 데이터 로드\ndf = pd.read_csv("./data/Amazon_Sale_Report.csv")\n\n# 기본 데이터 정보 확인\nprint("=== 데이터셋 기본 정보 ===")\nprint("\\n[데이터 크기]")\nprint(df.shape)\n\nprint("\\n[컬럼 목록]")\nprint(df.columns.tolist())\n\nprint("\\n[데이터 타입]")\nprint(df.dtypes)\n\nprint("\\n[결측치 현황]")\nprint(df.isnull().sum())\n\nprint("\\n[기술 통계량]")\nprint(df.describe())\n\n# 결과 저장\nos.makedirs(\'./artifacts\', exist_ok=True)\n\n# Result accumulation storage\nstage_name = "Initial Data Exploration"\nresult_description = f"""\n데이터셋 기본 정보 분석 결과:\n1. 데이터 크기: {df.shape}\n2. 컬럼 수: {len(df.columns)}\n3. 결측치 현황: \n{df.isnull().sum().to_string()}\n4. 기술 통계량:\n{df.describe().to_string()}\n"""\n\nresults_file = \'./artifacts/all_results.txt\'\nbackup_file = \'./artifacts/all_results_backup_{}.txt\'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))\n\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\nif os.path.exists(results_file):\n    try:\n        if os.path.getsize(results_file) > 0:\n            with open(results_file, \'r\', encoding=\'utf-8\') as f_src:\n                with open(backup_file, \'w\', encoding=\'utf-8\') as f_dst:\n                    f_dst.write(f_src.read())\n            print("Created backup of existing results file: {}".format(backup_file))\n    except Exception as e:\n        print("Error occurred during file backup: {}".format(e))\n\ntry:\n    with open(results_file, \'a\', encoding=\'utf-8\') as f:\n        f.write(current_result_text)\n    print("Results successfully saved.")\nexcept Exception as e:\n    print("Error occurred while saving results: {}".format(e))'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import lovelyplots
# import os
# from datetime import datetime
#
# # 스타일 설정
# plt.style.use(['ipynb', 'use_mathtext','colors5-light'])
# plt.rc('font', family='NanumGothic')
#
# # 데이터 로드
# df = pd.read_csv("./data/Amazon_Sale_Report.csv")
#
# # 기본 데이터 정보 확인
# print("=== 데이터셋 기본 정보 ===")
# print("\n[데이터 크기]")
# print(df.shape)
#
# print("\n[컬럼 목록]")
# print(df.columns.tolist())
#
# print("\n[데이터 타입]")
# print(df.dtypes)
#
# print("\n[결측치 현황]")
# print(df.isnull().sum())
#
# print("\n[기술 통계량]")
# print(df.describe())
#
# # 결과 저장
# os.makedirs('./artifacts', exist_ok=True)
#
# # Result accumulation storage
# stage_name = "Initial Data Exploration"
# result_description = f"""
# 데이터셋 기본 정보 분석 결과:
# 1. 데이터 크기: {df.shape}
# 2. 컬럼 수: {len(df.columns)}
# 3. 결측치 현황:
# {df.isnull().sum().to_string()}
# 4. 기술 통계량:
# {df.describe().to_string()}
# """
#
# results_file = './artifacts/all_results.txt'
# backup_file = './artifacts/all_results_backup_{}.txt'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))
#
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# if os.path.exists(results_file):
#     try:
#         if os.path.getsize(results_file) > 0:
#             with open(results_file, 'r', encoding='utf-8') as f_src:
#                 with open(backup_file, 'w', encoding='utf-8') as f_dst:
#                     f_dst.write(f_src.read())
#             print("Created backup of existing results file: {}".format(backup_file))
#     except Exception as e:
#         print("Error occurred during file backup: {}".format(e))
#
# try:
#     with open(results_file, 'a', encoding='utf-8') as f:
#         f.write(current_result_text)
#     print("Results successfully saved.")
# except Exception as e:
#     print("Error occurred while saving results: {}".format(e))
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: Traceback (most recent call last):
#   File "<string>", line 4, in <module>
# ModuleNotFoundError: No module named 'seaborn'
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 2 ---
#
#
# 죄송합니다. seaborn 모듈이 설치되어 있지 않아 오류가 발생했네요. 필요한 라이브러리를 설치하고 다시 시도하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: bash_tool, Input: {'cmd': 'pip install seaborn'}
#
# INFO [src.tools.bash_tool] ===== Executing Bash =====
#
# INFO [src.tools.bash_tool] ===== Coder - Command: pip install seaborn =====
#
# INFO [src.tools.decorators]
# Coder - Tool handle_bash_tool returned:
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.11/site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.11/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.11/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 3 ---
#
#
# 이제 데이터 분석을 다시 시도하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nimport os\nfrom datetime import datetime\n\n# 스타일 설정\nplt.style.use([\'ipynb\', \'use_mathtext\',\'colors5-light\'])\nplt.rc(\'font\', family=\'NanumGothic\')\n\n# 데이터 로드\ndf = pd.read_csv("./data/Amazon_Sale_Report.csv")\n\n# 기본 데이터 정보 확인\nprint("=== 데이터셋 기본 정보 ===")\nprint("\\n[데이터 크기]")\nprint(df.shape)\n\nprint("\\n[컬럼 목록]")\nprint(df.columns.tolist())\n\nprint("\\n[데이터 샘플]")\nprint(df.head())\n\nprint("\\n[데이터 타입]")\nprint(df.dtypes)\n\nprint("\\n[결측치 현황]")\nprint(df.isnull().sum())\n\nprint("\\n[기술 통계량]")\nprint(df.describe())\n\n# 결과 저장\nos.makedirs(\'./artifacts\', exist_ok=True)\n\n# Result accumulation storage\nstage_name = "Initial Data Exploration"\nresult_description = f"""\n데이터셋 기본 정보 분석 결과:\n1. 데이터 크기: {df.shape}\n2. 컬럼 수: {len(df.columns)}\n3. 결측치 현황: \n{df.isnull().sum().to_string()}\n4. 기술 통계량:\n{df.describe().to_string()}\n"""\n\nresults_file = \'./artifacts/all_results.txt\'\nbackup_file = \'./artifacts/all_results_backup_{}.txt\'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))\n\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\nif os.path.exists(results_file):\n    try:\n        if os.path.getsize(results_file) > 0:\n            with open(results_file, \'r\', encoding=\'utf-8\') as f_src:\n                with open(backup_file, \'w\', encoding=\'utf-8\') as f_dst:\n                    f_dst.write(f_src.read())\n            print("Created backup of existing results file: {}".format(backup_file))\n    except Exception as e:\n        print("Error occurred during file backup: {}".format(e))\n\ntry:\n    with open(results_file, \'a\', encoding=\'utf-8\') as f:\n        f.write(current_result_text)\n    print("Results successfully saved.")\nexcept Exception as e:\n    print("Error occurred while saving results: {}".format(e))'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# import os
# from datetime import datetime
#
# # 스타일 설정
# plt.style.use(['ipynb', 'use_mathtext','colors5-light'])
# plt.rc('font', family='NanumGothic')
#
# # 데이터 로드
# df = pd.read_csv("./data/Amazon_Sale_Report.csv")
#
# # 기본 데이터 정보 확인
# print("=== 데이터셋 기본 정보 ===")
# print("\n[데이터 크기]")
# print(df.shape)
#
# print("\n[컬럼 목록]")
# print(df.columns.tolist())
#
# print("\n[데이터 샘플]")
# print(df.head())
#
# print("\n[데이터 타입]")
# print(df.dtypes)
#
# print("\n[결측치 현황]")
# print(df.isnull().sum())
#
# print("\n[기술 통계량]")
# print(df.describe())
#
# # 결과 저장
# os.makedirs('./artifacts', exist_ok=True)
#
# # Result accumulation storage
# stage_name = "Initial Data Exploration"
# result_description = f"""
# 데이터셋 기본 정보 분석 결과:
# 1. 데이터 크기: {df.shape}
# 2. 컬럼 수: {len(df.columns)}
# 3. 결측치 현황:
# {df.isnull().sum().to_string()}
# 4. 기술 통계량:
# {df.describe().to_string()}
# """
#
# results_file = './artifacts/all_results.txt'
# backup_file = './artifacts/all_results_backup_{}.txt'.format(datetime.now().strftime("%Y%m%d_%H%M%S"))
#
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# if os.path.exists(results_file):
#     try:
#         if os.path.getsize(results_file) > 0:
#             with open(results_file, 'r', encoding='utf-8') as f_src:
#                 with open(backup_file, 'w', encoding='utf-8') as f_dst:
#                     f_dst.write(f_src.read())
#             print("Created backup of existing results file: {}".format(backup_file))
#     except Exception as e:
#         print("Error occurred during file backup: {}".format(e))
#
# try:
#     with open(results_file, 'a', encoding='utf-8') as f:
#         f.write(current_result_text)
#     print("Results successfully saved.")
# except Exception as e:
#     print("Error occurred while saving results: {}".format(e))
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: Traceback (most recent call last):
#   File "<string>", line 4, in <module>
# ModuleNotFoundError: No module named 'seaborn'
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 4 ---
#
#
# 죄송합니다. seaborn 관련 문제가 계속되고 있네요. seaborn 없이 기본적인 분석을 진행하도록 하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport os\nfrom datetime import datetime\n\n# 스타일 설정\nplt.style.use([\'ipynb\', \'use_mathtext\',\'colors5-light\'])\nplt.rc(\'font\', family=\'NanumGothic\')\n\n# 데이터 로드\ndf = pd.read_csv("./data/Amazon_Sale_Report.csv")\n\n# 기본 데이터 정보 확인\nprint("=== 데이터셋 기본 정보 ===")\nprint("\\n[데이터 크기]")\nprint(df.shape)\n\nprint("\\n[컬럼 목록]")\nprint(df.columns.tolist())\n\nprint("\\n[데이터 샘플]")\nprint(df.head())\n\nprint("\\n[데이터 타입]")\nprint(df.dtypes)\n\nprint("\\n[결측치 현황]")\nprint(df.isnull().sum())\n\nprint("\\n[기술 통계량]")\nprint(df.describe())'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# from datetime import datetime
#
# # 스타일 설정
# plt.style.use(['ipynb', 'use_mathtext','colors5-light'])
# plt.rc('font', family='NanumGothic')
#
# # 데이터 로드
# df = pd.read_csv("./data/Amazon_Sale_Report.csv")
#
# # 기본 데이터 정보 확인
# print("=== 데이터셋 기본 정보 ===")
# print("\n[데이터 크기]")
# print(df.shape)
#
# print("\n[컬럼 목록]")
# print(df.columns.tolist())
#
# print("\n[데이터 샘플]")
# print(df.head())
#
# print("\n[데이터 타입]")
# print(df.dtypes)
#
# print("\n[결측치 현황]")
# print(df.isnull().sum())
#
# print("\n[기술 통계량]")
# print(df.describe())
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: Traceback (most recent call last):
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/style/core.py", line 129, in use
#     style = _rc_params_in_file(style)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/__init__.py", line 903, in _rc_params_in_file
#     with _open_file_or_url(fname) as fd:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/contextlib.py", line 137, in __enter__
#     return next(self.gen)
#            ^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/__init__.py", line 880, in _open_file_or_url
#     with open(fname, encoding='utf-8') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'ipynb'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<string>", line 8, in <module>
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/style/core.py", line 131, in use
#     raise OSError(
# OSError: 'ipynb' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 5 ---
#
#
# 죄송합니다. matplotlib 스타일 설정에도 문제가 있네요. 기본 설정으로 진행하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport os\nfrom datetime import datetime\n\n# 데이터 로드\ndf = pd.read_csv("./data/Amazon_Sale_Report.csv")\n\n# 기본 데이터 정보 확인\nprint("=== 데이터셋 기본 정보 ===")\nprint("\\n[데이터 크기]")\nprint(df.shape)\n\nprint("\\n[컬럼 목록]")\nprint(df.columns.tolist())\n\nprint("\\n[데이터 샘플]")\nprint(df.head())\n\nprint("\\n[데이터 타입]")\nprint(df.dtypes)\n\nprint("\\n[결측치 현황]")\nprint(df.isnull().sum())\n\nprint("\\n[기술 통계량]")\nprint(df.describe())'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# from datetime import datetime
#
# # 데이터 로드
# df = pd.read_csv("./data/Amazon_Sale_Report.csv")
#
# # 기본 데이터 정보 확인
# print("=== 데이터셋 기본 정보 ===")
# print("\n[데이터 크기]")
# print(df.shape)
#
# print("\n[컬럼 목록]")
# print(df.columns.tolist())
#
# print("\n[데이터 샘플]")
# print(df.head())
#
# print("\n[데이터 타입]")
# print(df.dtypes)
#
# print("\n[결측치 현황]")
# print(df.isnull().sum())
#
# print("\n[기술 통계량]")
# print(df.describe())
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: === 데이터셋 기본 정보 ===
#
# [데이터 크기]
# (128975, 24)
#
# [컬럼 목록]
# ['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ', 'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN', 'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids', 'B2B', 'fulfilled-by', 'Unnamed: 22']
#
# [데이터 샘플]
#    index             Order ID      Date  ...    B2B fulfilled-by Unnamed: 22
# 0      0  405-8078784-5731545  04-30-22  ...  False    Easy Ship         NaN
# 1      1  171-9198151-1101146  04-30-22  ...  False    Easy Ship         NaN
# 2      2  404-0687676-7273146  04-30-22  ...   True          NaN         NaN
# 3      3  403-9615377-8133951  04-30-22  ...  False    Easy Ship         NaN
# 4      4  407-1069790-7240320  04-30-22  ...  False          NaN         NaN
#
# [5 rows x 24 columns]
#
# [데이터 타입]
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object
#
# [결측치 현황]
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64
#
# [기술 통계량]
#                index            Qty         Amount  ship-postal-code
# count  128975.000000  128975.000000  121180.000000     128942.000000
# mean    64487.000000       0.904431     648.561465     463966.236509
# std     37232.019822       0.313354     281.211687     191476.764941
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 6 ---
#
#
# 데이터의 기본 특성을 파악했으니, 이제 주요 분석을 진행하겠습니다. 먼저 판매 트렌드를 분석하기 위해 날짜 데이터를 처리하고 시계열 분석을 수행하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom datetime import datetime\n\n# Date 컬럼을 datetime 형식으로 변환\ndf[\'Date\'] = pd.to_datetime(df[\'Date\'], format=\'%m-%d-%y\')\n\n# 일별 판매량 및 매출액 계산\ndaily_sales = df.groupby(\'Date\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).reset_index()\n\n# 월별 판매량 및 매출액 계산\nmonthly_sales = df.groupby(df[\'Date\'].dt.to_period(\'M\')).agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).reset_index()\nmonthly_sales[\'Date\'] = monthly_sales[\'Date\'].astype(str)\n\n# 카테고리별 판매량 및 매출액\ncategory_sales = df.groupby(\'Category\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).sort_values(\'Amount\', ascending=False)\n\nprint("=== 판매 트렌드 분석 ===")\nprint("\\n[월별 판매 현황]")\nprint(monthly_sales)\n\nprint("\\n[카테고리별 판매 현황]")\nprint(category_sales)\n\n# 시각화: 월별 판매량 추이\nplt.figure(figsize=(12, 6))\nplt.plot(monthly_sales[\'Date\'], monthly_sales[\'Qty\'], marker=\'o\')\nplt.title(\'Monthly Sales Quantity Trend\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/monthly_sales_trend.png\')\nplt.close()\n\n# 시각화: 카테고리별 매출액\nplt.figure(figsize=(12, 6))\ncategory_sales[\'Amount\'].plot(kind=\'bar\')\nplt.title(\'Sales Amount by Category\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/category_sales.png\')\nplt.close()\n\n# 결과 저장\nstage_name = "Sales Trend Analysis"\nresult_description = f"""\n판매 트렌드 분석 결과:\n\n1. 월별 판매 현황:\n{monthly_sales.to_string()}\n\n2. 카테고리별 판매 현황:\n{category_sales.to_string()}\n\n3. 주요 발견사항:\n- 월별 판매량 추이 차트: ./artifacts/monthly_sales_trend.png\n- 카테고리별 매출액 차트: ./artifacts/category_sales.png\n"""\n\nresults_file = \'./artifacts/all_results.txt\'\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\ntry:\n    with open(results_file, \'a\', encoding=\'utf-8\') as f:\n        f.write(current_result_text)\n    print("Results successfully saved.")\nexcept Exception as e:\n    print("Error occurred while saving results: {}".format(e))'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from datetime import datetime
#
# # Date 컬럼을 datetime 형식으로 변환
# df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')
#
# # 일별 판매량 및 매출액 계산
# daily_sales = df.groupby('Date').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).reset_index()
#
# # 월별 판매량 및 매출액 계산
# monthly_sales = df.groupby(df['Date'].dt.to_period('M')).agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).reset_index()
# monthly_sales['Date'] = monthly_sales['Date'].astype(str)
#
# # 카테고리별 판매량 및 매출액
# category_sales = df.groupby('Category').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).sort_values('Amount', ascending=False)
#
# print("=== 판매 트렌드 분석 ===")
# print("\n[월별 판매 현황]")
# print(monthly_sales)
#
# print("\n[카테고리별 판매 현황]")
# print(category_sales)
#
# # 시각화: 월별 판매량 추이
# plt.figure(figsize=(12, 6))
# plt.plot(monthly_sales['Date'], monthly_sales['Qty'], marker='o')
# plt.title('Monthly Sales Quantity Trend')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/monthly_sales_trend.png')
# plt.close()
#
# # 시각화: 카테고리별 매출액
# plt.figure(figsize=(12, 6))
# category_sales['Amount'].plot(kind='bar')
# plt.title('Sales Amount by Category')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/category_sales.png')
# plt.close()
#
# # 결과 저장
# stage_name = "Sales Trend Analysis"
# result_description = f"""
# 판매 트렌드 분석 결과:
#
# 1. 월별 판매 현황:
# {monthly_sales.to_string()}
#
# 2. 카테고리별 판매 현황:
# {category_sales.to_string()}
#
# 3. 주요 발견사항:
# - 월별 판매량 추이 차트: ./artifacts/monthly_sales_trend.png
# - 카테고리별 매출액 차트: ./artifacts/category_sales.png
# """
#
# results_file = './artifacts/all_results.txt'
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# try:
#     with open(results_file, 'a', encoding='utf-8') as f:
#         f.write(current_result_text)
#     print("Results successfully saved.")
# except Exception as e:
#     print("Error occurred while saving results: {}".format(e))
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: Traceback (most recent call last):
#   File "<string>", line 7, in <module>
# NameError: name 'df' is not defined
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 7 ---
#
#
# 죄송합니다. 데이터프레임을 다시 로드하고 분석을 진행하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nfrom datetime import datetime\n\n# 데이터 로드\ndf = pd.read_csv("./data/Amazon_Sale_Report.csv")\n\n# Date 컬럼을 datetime 형식으로 변환\ndf[\'Date\'] = pd.to_datetime(df[\'Date\'], format=\'%m-%d-%y\')\n\n# 일별 판매량 및 매출액 계산\ndaily_sales = df.groupby(\'Date\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).reset_index()\n\n# 월별 판매량 및 매출액 계산\nmonthly_sales = df.groupby(df[\'Date\'].dt.to_period(\'M\')).agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).reset_index()\nmonthly_sales[\'Date\'] = monthly_sales[\'Date\'].astype(str)\n\n# 카테고리별 판매량 및 매출액\ncategory_sales = df.groupby(\'Category\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).sort_values(\'Amount\', ascending=False)\n\nprint("=== 판매 트렌드 분석 ===")\nprint("\\n[월별 판매 현황]")\nprint(monthly_sales)\n\nprint("\\n[카테고리별 판매 현황]")\nprint(category_sales)\n\n# 시각화: 월별 판매량 추이\nplt.figure(figsize=(12, 6))\nplt.plot(monthly_sales[\'Date\'], monthly_sales[\'Qty\'], marker=\'o\')\nplt.title(\'Monthly Sales Quantity Trend\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/monthly_sales_trend.png\')\nplt.close()\n\n# 시각화: 카테고리별 매출액\nplt.figure(figsize=(12, 6))\ncategory_sales[\'Amount\'].plot(kind=\'bar\')\nplt.title(\'Sales Amount by Category\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/category_sales.png\')\nplt.close()\n\n# 결과 저장\nos.makedirs(\'./artifacts\', exist_ok=True)\nstage_name = "Sales Trend Analysis"\nresult_description = f"""\n판매 트렌드 분석 결과:\n\n1. 월별 판매 현황:\n{monthly_sales.to_string()}\n\n2. 카테고리별 판매 현황:\n{category_sales.to_string()}\n\n3. 주요 발견사항:\n- 월별 판매량 추이 차트: ./artifacts/monthly_sales_trend.png\n- 카테고리별 매출액 차트: ./artifacts/category_sales.png\n"""\n\nresults_file = \'./artifacts/all_results.txt\'\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\ntry:\n    with open(results_file, \'a\', encoding=\'utf-8\') as f:\n        f.write(current_result_text)\n    print("Results successfully saved.")\nexcept Exception as e:\n    print("Error occurred while saving results: {}".format(e))'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from datetime import datetime
#
# # 데이터 로드
# df = pd.read_csv("./data/Amazon_Sale_Report.csv")
#
# # Date 컬럼을 datetime 형식으로 변환
# df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')
#
# # 일별 판매량 및 매출액 계산
# daily_sales = df.groupby('Date').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).reset_index()
#
# # 월별 판매량 및 매출액 계산
# monthly_sales = df.groupby(df['Date'].dt.to_period('M')).agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).reset_index()
# monthly_sales['Date'] = monthly_sales['Date'].astype(str)
#
# # 카테고리별 판매량 및 매출액
# category_sales = df.groupby('Category').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).sort_values('Amount', ascending=False)
#
# print("=== 판매 트렌드 분석 ===")
# print("\n[월별 판매 현황]")
# print(monthly_sales)
#
# print("\n[카테고리별 판매 현황]")
# print(category_sales)
#
# # 시각화: 월별 판매량 추이
# plt.figure(figsize=(12, 6))
# plt.plot(monthly_sales['Date'], monthly_sales['Qty'], marker='o')
# plt.title('Monthly Sales Quantity Trend')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/monthly_sales_trend.png')
# plt.close()
#
# # 시각화: 카테고리별 매출액
# plt.figure(figsize=(12, 6))
# category_sales['Amount'].plot(kind='bar')
# plt.title('Sales Amount by Category')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/category_sales.png')
# plt.close()
#
# # 결과 저장
# os.makedirs('./artifacts', exist_ok=True)
# stage_name = "Sales Trend Analysis"
# result_description = f"""
# 판매 트렌드 분석 결과:
#
# 1. 월별 판매 현황:
# {monthly_sales.to_string()}
#
# 2. 카테고리별 판매 현황:
# {category_sales.to_string()}
#
# 3. 주요 발견사항:
# - 월별 판매량 추이 차트: ./artifacts/monthly_sales_trend.png
# - 카테고리별 매출액 차트: ./artifacts/category_sales.png
# """
#
# results_file = './artifacts/all_results.txt'
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# try:
#     with open(results_file, 'a', encoding='utf-8') as f:
#         f.write(current_result_text)
#     print("Results successfully saved.")
# except Exception as e:
#     print("Error occurred while saving results: {}".format(e))
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: Error: <string>:7: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
# Traceback (most recent call last):
#   File "<string>", line 45, in <module>
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/pyplot.py", line 1243, in savefig
#     res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/figure.py", line 3490, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/backend_bases.py", line 2184, in print_figure
#     result = print_method(
#              ^^^^^^^^^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/backend_bases.py", line 2040, in <lambda>
#     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#                                                                  ^^^^^
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py", line 481, in print_png
#     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py", line 430, in _print_pil
#     mpl.image.imsave(
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/matplotlib/image.py", line 1644, in imsave
#     image.save(fname, **pil_kwargs)
#   File "/home/sagemaker-user/.conda/envs/bedrock-manus/lib/python3.12/site-packages/PIL/Image.py", line 2576, in save
#     fp = builtins.open(filename, "w+b")
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: './artifacts/monthly_sales_trend.png'
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 8 ---
#
#
#
#
# 죄송합니다. artifacts 디렉토리를 먼저 생성하고 다시 시도하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport os\nfrom datetime import datetime\n\n# artifacts 디렉토리 생성\nos.makedirs(\'./artifacts\', exist_ok=True)\n\n# 데이터 로드\ndf = pd.read_csv("./data/Amazon_Sale_Report.csv", low_memory=False)\n\n# Date 컬럼을 datetime 형식으로 변환\ndf[\'Date\'] = pd.to_datetime(df[\'Date\'], format=\'%m-%d-%y\')\n\n# 일별 판매량 및 매출액 계산\ndaily_sales = df.groupby(\'Date\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).reset_index()\n\n# 월별 판매량 및 매출액 계산\nmonthly_sales = df.groupby(df[\'Date\'].dt.to_period(\'M\')).agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).reset_index()\nmonthly_sales[\'Date\'] = monthly_sales[\'Date\'].astype(str)\n\n# 카테고리별 판매량 및 매출액\ncategory_sales = df.groupby(\'Category\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).sort_values(\'Amount\', ascending=False)\n\nprint("=== 판매 트렌드 분석 ===")\nprint("\\n[월별 판매 현황]")\nprint(monthly_sales)\n\nprint("\\n[카테고리별 판매 현황]")\nprint(category_sales)\n\n# 시각화: 월별 판매량 추이\nplt.figure(figsize=(12, 6))\nplt.plot(monthly_sales[\'Date\'], monthly_sales[\'Qty\'], marker=\'o\')\nplt.title(\'Monthly Sales Quantity Trend\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/monthly_sales_trend.png\')\nplt.close()\n\n# 시각화: 카테고리별 매출액\nplt.figure(figsize=(12, 6))\ncategory_sales[\'Amount\'].plot(kind=\'bar\')\nplt.title(\'Sales Amount by Category\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/category_sales.png\')\nplt.close()\n\n# 추가 분석: 판매 채널별 분석\nchannel_sales = df.groupby(\'Sales Channel \').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).sort_values(\'Amount\', ascending=False)\n\nprint("\\n[판매 채널별 현황]")\nprint(channel_sales)\n\n# 시각화: 판매 채널별 매출액\nplt.figure(figsize=(10, 6))\nchannel_sales[\'Amount\'].plot(kind=\'bar\')\nplt.title(\'Sales Amount by Channel\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/channel_sales.png\')\nplt.close()\n\n# 결과 저장\nstage_name = "Sales Trend Analysis"\nresult_description = f"""\n판매 트렌드 분석 결과:\n\n1. 월별 판매 현황:\n{monthly_sales.to_string()}\n\n2. 카테고리별 판매 현황:\n{category_sales.to_string()}\n\n3. 판매 채널별 현황:\n{channel_sales.to_string()}\n\n4. 주요 발견사항:\n- 월별 판매량 추이 차트: ./artifacts/monthly_sales_trend.png\n- 카테고리별 매출액 차트: ./artifacts/category_sales.png\n- 판매 채널별 매출액 차트: ./artifacts/channel_sales.png\n"""\n\nresults_file = \'./artifacts/all_results.txt\'\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\ntry:\n    with open(results_file, \'a\', encoding=\'utf-8\') as f:\n        f.write(current_result_text)\n    print("Results successfully saved.")\nexcept Exception as e:\n    print("Error occurred while saving results: {}".format(e))'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# from datetime import datetime
#
# # artifacts 디렉토리 생성
# os.makedirs('./artifacts', exist_ok=True)
#
# # 데이터 로드
# df = pd.read_csv("./data/Amazon_Sale_Report.csv", low_memory=False)
#
# # Date 컬럼을 datetime 형식으로 변환
# df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')
#
# # 일별 판매량 및 매출액 계산
# daily_sales = df.groupby('Date').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).reset_index()
#
# # 월별 판매량 및 매출액 계산
# monthly_sales = df.groupby(df['Date'].dt.to_period('M')).agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).reset_index()
# monthly_sales['Date'] = monthly_sales['Date'].astype(str)
#
# # 카테고리별 판매량 및 매출액
# category_sales = df.groupby('Category').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).sort_values('Amount', ascending=False)
#
# print("=== 판매 트렌드 분석 ===")
# print("\n[월별 판매 현황]")
# print(monthly_sales)
#
# print("\n[카테고리별 판매 현황]")
# print(category_sales)
#
# # 시각화: 월별 판매량 추이
# plt.figure(figsize=(12, 6))
# plt.plot(monthly_sales['Date'], monthly_sales['Qty'], marker='o')
# plt.title('Monthly Sales Quantity Trend')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/monthly_sales_trend.png')
# plt.close()
#
# # 시각화: 카테고리별 매출액
# plt.figure(figsize=(12, 6))
# category_sales['Amount'].plot(kind='bar')
# plt.title('Sales Amount by Category')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/category_sales.png')
# plt.close()
#
# # 추가 분석: 판매 채널별 분석
# channel_sales = df.groupby('Sales Channel ').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).sort_values('Amount', ascending=False)
#
# print("\n[판매 채널별 현황]")
# print(channel_sales)
#
# # 시각화: 판매 채널별 매출액
# plt.figure(figsize=(10, 6))
# channel_sales['Amount'].plot(kind='bar')
# plt.title('Sales Amount by Channel')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/channel_sales.png')
# plt.close()
#
# # 결과 저장
# stage_name = "Sales Trend Analysis"
# result_description = f"""
# 판매 트렌드 분석 결과:
#
# 1. 월별 판매 현황:
# {monthly_sales.to_string()}
#
# 2. 카테고리별 판매 현황:
# {category_sales.to_string()}
#
# 3. 판매 채널별 현황:
# {channel_sales.to_string()}
#
# 4. 주요 발견사항:
# - 월별 판매량 추이 차트: ./artifacts/monthly_sales_trend.png
# - 카테고리별 매출액 차트: ./artifacts/category_sales.png
# - 판매 채널별 매출액 차트: ./artifacts/channel_sales.png
# """
#
# results_file = './artifacts/all_results.txt'
# current_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# current_result_text = f"""
# ==================================================
# ## Analysis Stage: {stage_name}
# ## Execution Time: {current_time}
# --------------------------------------------------
# Result Description:
# {result_description}
# ==================================================
# """
#
# try:
#     with open(results_file, 'a', encoding='utf-8') as f:
#         f.write(current_result_text)
#     print("Results successfully saved.")
# except Exception as e:
#     print("Error occurred while saving results: {}".format(e))
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: === 판매 트렌드 분석 ===
#
# [월별 판매 현황]
#       Date    Qty       Amount
# 0  2022-03    156    101683.85
# 1  2022-04  44206  28838708.32
# 2  2022-05  38011  26226476.75
# 3  2022-06  34276  23425809.38
#
# [카테고리별 판매 현황]
#                  Qty       Amount
# Category
# Set            45289  39204124.03
# kurta          45045  21299546.70
# Western Dress  13943  11216072.69
# Top             9903   5347792.30
# Ethnic Dress    1053    791217.66
# Blouse           863    458408.18
# Bottom           398    150667.98
# Saree            152    123933.76
# Dupatta            3       915.00
#
# [판매 채널별 현황]
#                    Qty      Amount
# Sales Channel
# Amazon.in       116482  78592678.3
# Non-Amazon         167         0.0
# Results successfully saved.
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 9 ---
#
#
# 이제 추가적인 분석을 수행하겠습니다. 가격대별 분석과 지역별 분석을 진행하겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: python_repl_tool, Input: {'code': 'import pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport os\nfrom datetime import datetime\n\n# 가격대 구간 설정\ndf[\'Price_Range\'] = pd.qcut(df[\'Amount\'], q=5, labels=[\'Very Low\', \'Low\', \'Medium\', \'High\', \'Very High\'])\n\n# 가격대별 판매량 및 매출액\nprice_range_analysis = df.groupby(\'Price_Range\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': [\'sum\', \'mean\', \'count\']\n}).round(2)\n\n# 지역별(state) 판매 분석\nstate_sales = df.groupby(\'ship-state\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': \'sum\'\n}).sort_values(\'Amount\', ascending=False).head(10)  # Top 10 states\n\nprint("=== 가격대별 및 지역별 분석 ===")\nprint("\\n[가격대별 판매 현황]")\nprint(price_range_analysis)\n\nprint("\\n[상위 10개 주(state)별 판매 현황]")\nprint(state_sales)\n\n# 시각화: 가격대별 판매량\nplt.figure(figsize=(10, 6))\nprice_range_analysis[\'Qty\'].plot(kind=\'bar\')\nplt.title(\'Sales Quantity by Price Range\')\nplt.xlabel(\'Price Range\')\nplt.ylabel(\'Quantity\')\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/price_range_sales.png\')\nplt.close()\n\n# 시각화: 상위 10개 주별 매출액\nplt.figure(figsize=(12, 6))\nstate_sales[\'Amount\'].plot(kind=\'bar\')\nplt.title(\'Sales Amount by State (Top 10)\')\nplt.xlabel(\'State\')\nplt.ylabel(\'Amount\')\nplt.xticks(rotation=45)\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/state_sales.png\')\nplt.close()\n\n# B2B vs B2C 분석\nb2b_analysis = df.groupby(\'B2B\').agg({\n    \'Qty\': \'sum\',\n    \'Amount\': [\'sum\', \'mean\', \'count\']\n}).round(2)\n\nprint("\\n[B2B vs B2C 판매 현황]")\nprint(b2b_analysis)\n\n# 시각화: B2B vs B2C 매출액 비교\nplt.figure(figsize=(8, 6))\nb2b_analysis[\'Amount\'][\'sum\'].plot(kind=\'bar\')\nplt.title(\'Sales Amount: B2B vs B2C\')\nplt.xlabel(\'B2B\')\nplt.ylabel(\'Amount\')\nplt.grid(True, alpha=0.3)\nplt.tight_layout()\nplt.savefig(\'./artifacts/b2b_sales.png\')\nplt.close()\n\n# 결과 저장\nstage_name = "Price Range and Regional Analysis"\nresult_description = f"""\n가격대별 및 지역별 분석 결과:\n\n1. 가격대별 판매 현황:\n{price_range_analysis.to_string()}\n\n2. 상위 10개 주(state)별 판매 현황:\n{state_sales.to_string()}\n\n3. B2B vs B2C 판매 현황:\n{b2b_analysis.to_string()}\n\n4. 주요 발견사항:\n- 가격대별 판매량 차트: ./artifacts/price_range_sales.png\n- 주별 매출액 차트: ./artifacts/state_sales.png\n- B2B vs B2C 매출액 비교 차트: ./artifacts/b2b_sales.png\n"""\n\nresults_file = \'./artifacts/all_results.txt\'\ncurrent_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")\ncurrent_result_text = f"""\n==================================================\n## Analysis Stage: {stage_name}\n## Execution Time: {current_time}\n--------------------------------------------------\nResult Description: \n{result_description}\n==================================================\n"""\n\ntry:\n    with open(results_file, \'a\', encoding=\'utf-8\') as f:\n        f.write(current_result_text)\n    print("Results successfully saved.")\nexcept Exception as e:\n    print("Error occurred while saving results: {}".format(e))'}
#
# INFO [src.tools.python_repl] ===== Executing Python code =====
#
# INFO [src.tools.python_repl] ===== Code execution successful =====
#
# INFO [src.tools.decorators] Coder - Successfully executed:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import os
# from datetime import datetime
#
# # 가격대 구간 설정
# df['Price_Range'] = pd.qcut(df['Amount'], q=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])
#
# # 가격대별 판매량 및 매출액
# price_range_analysis = df.groupby('Price_Range').agg({
#     'Qty': 'sum',
#     'Amount': ['sum', 'mean', 'count']
# }).round(2)
#
# # 지역별(state) 판매 분석
# state_sales = df.groupby('ship-state').agg({
#     'Qty': 'sum',
#     'Amount': 'sum'
# }).sort_values('Amount', ascending=False).head(10)  # Top 10 states
#
# print("=== 가격대별 및 지역별 분석 ===")
# print("\n[가격대별 판매 현황]")
# print(price_range_analysis)
#
# print("\n[상위 10개 주(state)별 판매 현황]")
# print(state_sales)
#
# # 시각화: 가격대별 판매량
# plt.figure(figsize=(10, 6))
# price_range_analysis['Qty'].plot(kind='bar')
# plt.title('Sales Quantity by Price Range')
# plt.xlabel('Price Range')
# plt.ylabel('Quantity')
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/price_range_sales.png')
# plt.close()
#
# # 시각화: 상위 10개 주별 매출액
# plt.figure(figsize=(12, 6))
# state_sales['Amount'].plot(kind='bar')
# plt.title('Sales Amount by State (Top 10)')
# plt.xlabel('State')
# plt.ylabel('Amount')
# plt.xticks(rotation=45)
# plt.grid(True, alpha=0.3)
# plt.tight_layout()
# plt.savefig('./artifacts/state_sales.png')
# plt.close()
#
# # B2B vs B2C 분석
# b2b_analysis = df.groupby('B2B').agg({
#     'Qty': 'sum',
#     'Amount': ['sum', 'mean', 'count']
# }).round(2)
#
# print("\n[B2B vs B2C 판매 현황]")
# print(b2b_analysis)
#
# # 시각화: B2B vs B2C 매출액 비교
# plt.figure(figsize=(8, 6))
# b2b_analysis['Amount']['sum'].plot(kind='bar')
# plt.title('Sales Amount: B2B vs B2C')
# plt.xlabel('B2B')
# ...
#         artifacts = []
#         artifacts_section = block.split("Generated Files:", 1)
#         if len(artifacts_section) > 1:
#             artifacts_text = artifacts_section[1]
#             artifact_lines = re.findall(r'- (.*?) : (.*?)$', artifacts_text, re.MULTILINE)
#             artifacts = artifact_lines
#         else:
#             # Try to extract artifact information from the results text
#             artifact_paths = re.findall(r'(./artifacts/[\w_]+\.png)', results_text)
#             for path in artifact_paths:
#                 desc = path.split('/')[-1].replace('.png', '').replace('_', ' ')
#                 artifacts.append((path, desc))
#
#         analyses.append({
#             "name": analysis_name,
#             "time": execution_time,
#             "results": results_text,
#             "artifacts": artifacts
#         })
#
# # 마케팅 인사이트 섹션을 추출
# marketing_insights = ""
# for analysis in analyses:
#     if "Marketing Insights" in analysis["name"]:
#         # Find insights section in the text
#         insights_match = re.search(r'7\. 마케팅 인사이트:(.*?)$', analysis["results"], re.DOTALL)
#         if insights_match:
#             marketing_insights = insights_match.group(1).strip()
#             break
#
#
# # HTML 리포트 생성 함수
# def generate_html_report(analyses):
#     # Current date for the report
#     today = datetime.now().strftime("%Y년 %m월 %d일")
#
#     # HTML 헤더 시작
#     html = f"""<!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>아마존 상품판매 데이터 분석 리포트</title>
#     <style>
#         body {{
#             font-family: 'Malgun Gothic', 'Nanum Gothic', sans-serif;
#             line-height: 1.6;
#             color: #333;
#             max-width: 1200px;
#             margin: 0 auto;
#             padding: 20px;
#         }}
#         h1, h2, h3, h4 {{
#             color: #1a5276;
#         }}
#         h1 {{
#             border-bottom: 2px solid #1a5276;
#             padding-bottom: 10px;
#         }}
#         h2 {{
#             border-bottom: 1px solid #aed6f1;
#             padding-bottom: 5px;
#             margin-top: 30px;
#         }}
#         .header {{
#             text-align: center;
#             margin-bottom: 40px;
#         }}
#         .section {{
#             margin-bottom: 30px;
#         }}
#         .insight {{
#             background-color: #f9f9f9;
#             border-left: 4px solid #3498db;
#             padding: 15px;
#             margin: 15px 0;
#         }}
#         .fig-container {{
#             text-align: center;
#             margin: 25px 0;
#         }}
#         .fig-container img {{
#             max-width: 100%;
#             border: 1px solid #ddd;
#             box-shadow: 0 3px 5px rgba(0,0,0,0.1);
#         }}
#         .fig-caption {{
#             font-style: italic;
#             margin-top: 10px;
#             color: #555;
#         }}
#         table {{
#             border-collapse: collapse;
#             width: 100%;
#             margin: 20px 0;
#         }}
#         th, td {{
#             text-align: left;
#             padding: 12px;
#             border-bottom: 1px solid #ddd;
#         }}
#         th {{
#             background-color: #f2f2f2;
#             font-weight: bold;
#         }}
#         tr:hover {{
#             background-color: #f5f5f5;
#         }}
#         .summary-box {{
#             background-color: #eaf2f8;
#             border: 1px solid #aed6f1;
#             border-radius: 5px;
#             padding: 15px;
#             margin: 20px 0;
#         }}
#         .recommendations {{
#             background-color: #e8f8f5;
#             border-radius: 5px;
#             padding: 15px;
#             margin: 20px 0;
#         }}
#         .key-insight {{
#             font-weight: bold;
#             color: #2874a6;
#         }}
#         .footer {{
#             margin-top: 50px;
#             text-align: center;
#             font-size: 0.9em;
#             color: #777;
#             border-top: 1px solid #ddd;
#             padding-top: 20px;
#         }}
#     </style>
# </head>
# <body>
#     <div class="header">
#         <h1>아마존 상품판매 데이터 분석 리포트</h1>
#         <p>작성일: {today}</p>
#     </div>
#
#     <div class="section">
#         <h2>📊 분석 개요</h2>
#         <p>이 리포트는 아마존 판매 데이터(Amazon_Sale_Report.csv)를 분석하여 마케팅 인사이트를 도출하고자 수행된 분석 결과입니다. 제품 카테고리, 판매 채널, 가격대, 지역, 제품 특성 등 다양한 측면에서 판매 데이터를 분석하여 효과적인 마케팅 전략 수립에 필요한 핵심 정보를 제공합니다.</p>
#
#         <div class="summary-box">
#             <h3>핵심 분석 영역</h3>
#             <ul>
#                 <li>판매 트렌드 분석: 월별, 카테고리별, 채널별 판매 추이</li>
#                 <li>가격대 및 지역별 분석: 가격 범위별 판매 성과, 주(State)별 판매 현황, B2B/B2C 비교</li>
#                 <li>제품 특성 분석: 사이즈별, 스타일별, 배송 방식별 판매 현황</li>
#                 <li>마케팅 인사이트 분석: 카테고리별 가격-판매량 관계, 판매 채널별 성과, 요일별 판매 패턴</li>
#             </ul>
#         </div>
#     </div>
#
#     <div class="section">
#         <h2>🔍 데이터셋 특성</h2>
#         <p>분석에 사용된 데이터셋은 아마존 판매 보고서로, 2022년 3월부터 6월까지의 판매 데이터를 포함하고 있습니다. 주요 변수로는 제품 카테고리, 스타일, 사이즈, 가격, 판매량, 판매 채널, 배송 상태, 지역 정보 등이 포함되어 있습니다.</p>
#     </div>
# """
#
#     # Executive Summary - Key Findings
#     html += """
#     <div class="section">
#         <h2>💡 핵심 발견사항</h2>
#         <div class="insight">
#             <h3>제품 및 카테고리</h3>
#             <ul>
#                 <li><span class="key-insight">Set과 kurta 제품군</span>이 전체 판매량의 대부분을 차지하며, 특히 Set 제품은 평균 판매가격이 가장 높고(833.39) 판매량도 가장 많음(45,289)</li>
#                 <li>Western Dress는 중간 정도의 판매량(13,943)이지만 높은 평균 가격(762.79)을 보여 수익성이 높은 카테고리</li>
#             </ul>
#         </div>
#
#         <div class="insight">
#             <h3>판매 채널 효율성</h3>
#             <ul>
#                 <li>Amazon.in이 압도적인 주요 판매 채널(116,482건)로, 모든 카테고리에서 높은 성과를 보임</li>
#                 <li>Non-Amazon 채널의 매출이 현저히 낮아 채널 다각화의 필요성이 제기됨</li>
#             </ul>
#         </div>
#
#         <div class="insight">
#             <h3>사이즈 및 스타일 트렌드</h3>
#             <ul>
#                 <li>M, L, XL 사이즈가 가장 높은 판매량을 보이며, 특히 M 사이즈가 가장 높은 매출(13,906,754.37)을 기록</li>
#                 <li>XS와 대형 사이즈(4XL-6XL)의 수요는 상대적으로 낮음</li>
#                 <li>JNE3797, J0230 스타일이 상위 인기 스타일로 나타남</li>
#             </ul>
#         </div>
#
#         <div class="insight">
#             <h3>물류 및 배송</h3>
#             <ul>
#                 <li>Expedited 배송(83,004건)이 Standard 배송(33,645건)보다 2배 이상 높은 매출을 기록</li>
#                 <li>취소된 주문(Cancelled)이 5,657건으로 상당수 존재하여 주문 취소율 개선 필요</li>
#                 <li>Amazon Fulfillment(84,087건)가 Merchant Fulfillment(32,562건)보다 2배 이상 많은 주문 처리</li>
#             </ul>
#         </div>
#
#         <div class="insight">
#             <h3>지역 및 시간 패턴</h3>
#             <ul>
#                 <li>MAHARASHTRA, KARNATAKA, TELANGANA가 상위 3개 주(state)로 나타남</li>
#                 <li>주말(토,일)의 판매가 평일보다 약간 높은 경향을 보임</li>
#             </ul>
#         </div>
#
#         <div class="insight">
#             <h3>비즈니스 모델</h3>
#             <ul>
#                 <li>B2C 거래(115,809건)가 압도적으로 많으며, B2B 거래(840건)는 상대적으로 미미</li>
#                 <li>B2B 거래의 평균 판매가격(678.78)이 B2C(608.89)보다 높게 나타남</li>
#             </ul>
#         </div>
#     </div>
#     """
#
#     # Detailed Analysis Sections
#     html += """
#     <div class="section">
#         <h2>📈 상세 분석 결과</h2>
#     """
#
#     # 각 분석 단계별 상세 결과 추가
#     for analysis in analyses:
#         html += f"""
#         <div class="section">
#             <h3>{analysis["name"]}</h3>
#             <p><em>분석 시간: {analysis["time"]}</em></p>
#
#             <div class="analysis-content">
#                 <pre>{analysis["results"]}</pre>
#             </div>
#
#             <!-- 이미지 표시 -->
#             <div class="fig-container">
#         """
#
#         # 분석에 포함된 이미지 추가
#         for img_path, img_desc in analysis["artifacts"]:
#             if os.path.exists(img_path):
#                 # 이미지 설명에서 파일명만 추출하여 좀 더 읽기 좋게 변환
#                 if img_desc == img_path.split('/')[-1].replace('.png', '').replace('_', ' '):
#                     # 기본 생성된 설명이면 더 의미 있는 설명으로 교체
#                     if "monthly_sales_trend" in img_path:
#                         img_desc = "월별 판매 트렌드 분석"
#                     elif "category_sales" in img_path:
#                         img_desc = "카테고리별 판매량 및 매출액"
#                     elif "channel_sales" in img_path:
#                         img_desc = "판매 채널별 성과 비교"
#                     elif "price_range_sales" in img_path:
#                         img_desc = "가격대별 판매 분포"
#                     elif "state_sales" in img_path:
#                         img_desc = "주(State)별 판매 현황"
#                     elif "b2b_sales" in img_path:
#                         img_desc = "B2B vs B2C 판매 비교"
#                     elif "size_sales" in img_path:
#                         img_desc = "사이즈별 판매 분포"
#                     elif "style_sales" in img_path:
#                         img_desc = "상위 스타일별 판매 현황"
#                     elif "fulfillment_sales" in img_path:
#                         img_desc = "배송 방식별 판매 성과"
#                     elif "category_price_qty_correlation" in img_path:
#                         img_desc = "카테고리별 가격-판매량 상관관계"
#                     elif "channel_category_performance" in img_path:
#                         img_desc = "판매 채널별 카테고리 성과"
#                     elif "day_of_week_sales" in img_path:
#                         img_desc = "요일별 판매 패턴"
#
#                 html += f"""
#                 <figure>
#                     <img src="{img_path}" alt="{img_desc}">
#                     <figcaption class="fig-caption">{img_desc}</figcaption>
#                 </figure>
#                 """
#
#         html += """
#             </div>
#         </div>
#         """
#
#     html += """
#     </div>
#     """
#
#     # 마케팅 인사이트 및 제안 섹션
#     html += """
#     <div class="section">
#         <h2>🎯 마케팅 인사이트 및 전략적 제안</h2>
#
#         <div class="recommendations">
#             <h3>제품 전략</h3>
#             <ul>
#                 <li><strong>Set 및 kurta 제품군 강화:</strong> 현재 가장 높은 판매량과 매출을 보이는 Set과 kurta 제품군의 품질을 강화하고 다양성을 확대하여 시장 리더십을 유지</li>
#                 <li><strong>Western Dress 프리미엄화:</strong> 높은 평균 판매가격을 보이는 Western Dress 카테고리에서 프리미엄 라인을 확대하여 수익성 증대</li>
#                 <li><strong>중간 사이즈(M-XL) 집중:</strong> 판매량이 가장 높은 M, L, XL 사이즈의 재고 관리를 최적화하고, 다양한 디자인 옵션을 제공</li>
#                 <li><strong>인기 스타일 확장:</strong> JNE3797, J0230 등 상위 판매 스타일의 변형 제품을 개발하여 성공 모델 확장</li>
#             </ul>
#         </div>
#
#         <div class="recommendations">
#             <h3>가격 및 프로모션 전략</h3>
#             <ul>
#                 <li><strong>카테고리별 최적 가격대 설정:</strong> 각 카테고리별 판매량과 가격 관계를 분석하여 최적의 가격 포인트 설정</li>
#                 <li><strong>주말 프로모션 강화:</strong> 주말(토,일)에 판매량이 더 높은 점을 활용하여 주말 특별 할인 및 프로모션 진행</li>
#                 <li><strong>번들 상품 전략:</strong> 판매량이 많은 Set 제품과 보완 제품(예: 액세서리)을 번들로 구성하여 객단가 향상</li>
#                 <li><strong>B2B 특별 할인:</strong> 현재 비중이 낮은 B2B 거래를 확대하기 위한 대량 구매 할인 프로그램 도입</li>
#             </ul>
#         </div>
#
#         <div class="recommendations">
#             <h3>채널 및 물류 전략</h3>
#             <ul>
#                 <li><strong>Amazon.in 플랫폼 최적화:</strong> 현재 주요 판매 채널인 Amazon.in에서의 상품 노출, 리뷰 관리, 광고 전략을 최적화</li>
#                 <li><strong>Non-Amazon 채널 개발:</strong> 현재 Non-Amazon 채널의 매출이 미미한 점을 개선하기 위해 자체 웹사이트 또는 타 마켓플레이스로 채널 다각화</li>
#                 <li><strong>Expedited 배송 서비스 홍보:</strong> 고객들이 선호하는 Expedited 배송의 장점을 강조하는 마케팅 메시지 개발</li>
#                 <li><strong>주문 취소율 감소 방안:</strong> 취소 주문(5,657건)의 원인을 분석하고 이를 감소시키기 위한 프로세스 개선</li>
#             </ul>
#         </div>
#
#         <div class="recommendations">
#             <h3>지역별 맞춤 전략</h3>
#             <ul>
#                 <li><strong>상위 3개 주 집중 투자:</strong> MAHARASHTRA, KARNATAKA, TELANGANA 지역에 마케팅 예산을 우선 배정하고 지역 맞춤형 프로모션 진행</li>
#                 <li><strong>저성과 지역 분석:</strong> 판매가 저조한 지역의 원인을 파악하고 맞춤형 접근 전략 수립</li>
#                 <li><strong>도시별 타겟팅:</strong> 인구 밀집도와 구매력이 높은 도시 지역에 집중된 디지털 광고 캠페인 진행</li>
#             </ul>
#         </div>
#
#         <div class="recommendations">
#             <h3>운영 효율성 개선</h3>
#             <ul>
#                 <li><strong>Amazon Fulfillment 확대:</strong> 현재 높은 성과를 보이는 Amazon Fulfillment 이용 비중을 더욱 확대하여 배송 효율성 향상</li>
#                 <li><strong>사이즈별 재고 최적화:</strong> 판매량이 많은 M-XL 사이즈의 재고는 충분히 확보하고, 판매가 저조한 사이즈(XS, 4XL-6XL)는 주문 생산 방식 도입 고려</li>
#                 <li><strong>시즌별 예측 모델 개발:</strong> 월별, 계절별 판매 데이터를 활용해 수요 예측 모델을 개발하여 재고 관리 최적화</li>
#             </ul>
#         </div>
#     </div>
#     """
#
#     # Conclusion
#     html += """
#     <div class="section">
#         <h2>📝 결론</h2>
#         <p>아마존 판매 데이터 분석 결과, Set과 kurta 제품군을 중심으로 M-XL 사이즈에 집중된 판매 패턴이 확인되었습니다. Amazon.in이 압도적인 판매 채널로, Expedited 배송과 Amazon Fulfillment 서비스가 높은 효율성을 보였습니다.</p>
#
#         <p>마케팅 전략 수립 시 주요 고려사항으로는 1) 인기 카테고리 및 사이즈에 대한 재고 최적화, 2) 주말 및 지역 맞춤형 프로모션 강화, 3) Non-Amazon 채널 다각화, 4) 주문 취소율 감소를 위한 프로세스 개선, 5) B2B 시장 확대를 위한 전략 수립 등이 있습니다.</p>
#
#         <p>이러한 인사이트를 바탕으로 마케팅 전략을 최적화한다면 판매량 증대와 수익성 향상을 기대할 수 있을 것입니다.</p>
#     </div>
#
#     <div class="footer">
#         <p>아마존 상품판매 데이터 분석 리포트 | 작성일: {today}</p>
#     </div>
# </body>
# </html>
# """
#
#     return html
#
# # HTML 리포트 생성 및 저장
# html_report = generate_html_report(analyses)
# report_path = './amazon_sales_analysis_report.html'
#
# with open(report_path, 'w', encoding='utf-8') as f:
#     f.write(html_report)
#
# print(f"HTML 리포트가 성공적으로 생성되었습니다: {report_path}")
#
# # 생성된 HTML 파일 크기 확인
# import os
# file_size = os.path.getsize(report_path) / 1024  # KB 단위
# print(f"생성된 HTML 파일 크기: {file_size:.2f} KB")
# ```
#
#
# INFO [src.tools.decorators]
# Stdout: HTML 리포트가 성공적으로 생성되었습니다: ./amazon_sales_analysis_report.html
# 생성된 HTML 파일 크기: 23.54 KB
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 5 ---
#
#
#
#
# 리포트가 성공적으로 생성되었습니다. 생성된 HTML 파일을 확인하고 내용을 살펴보겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: bash_tool, Input: {'cmd': 'ls -la ./amazon_sales_analysis_report.html'}
#
# INFO [src.tools.bash_tool] ===== Executing Bash =====
#
# INFO [src.tools.bash_tool] ===== Coder - Command: ls -la ./amazon_sales_analysis_report.html =====
#
# INFO [src.tools.decorators]
# Coder - Tool handle_bash_tool returned:
# -rw-r--r-- 1 sagemaker-user users 24102 May  2 11:39 ./amazon_sales_analysis_report.html
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 6 ---
#
#
#
#
# 생성된 HTML 리포트의 일부 내용을 확인해보겠습니다.
# INFO [src.agents.agents]
# ToolUse - Tool Name: bash_tool, Input: {'cmd': 'head -30 ./amazon_sales_analysis_report.html'}
#
# INFO [src.tools.bash_tool] ===== Executing Bash =====
#
# INFO [src.tools.bash_tool] ===== Coder - Command: head -30 ./amazon_sales_analysis_report.html =====
#
# INFO [src.tools.decorators]
# Coder - Tool handle_bash_tool returned:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>아마존 상품판매 데이터 분석 리포트</title>
#     <style>
#         body {
#             font-family: 'Malgun Gothic', 'Nanum Gothic', sans-serif;
#             line-height: 1.6;
#             color: #333;
#             max-width: 1200px;
#             margin: 0 auto;
#             padding: 20px;
#         }
#         h1, h2, h3, h4 {
#             color: #1a5276;
#         }
#         h1 {
#             border-bottom: 2px solid #1a5276;
#             padding-bottom: 10px;
#         }
#         h2 {
#             border-bottom: 1px solid #aed6f1;
#             padding-bottom: 5px;
#             margin-top: 30px;
#         }
#         .header {
#             text-align: center;
#             margin-bottom: 40px;
#
#
# INFO [src.agents.agents] ToolUse - 도구 실행 결과를 대화에 추가했습니다.
# --- 대화 턴 7 ---
#
#
#
#
# HTML 리포트가 성공적으로 생성되었습니다. 이제 이 리포트를 사용자가 요청한 대로 최종 결과물로 제시하겠습니다.
#
# ## 아마존 상품판매 데이터 분석 요약
#
# 아마존 판매 데이터(Amazon_Sale_Report.csv)를 분석하여 다음과 같은 주요 마케팅 인사이트를 도출했습니다:
#
# ### 주요 분석 결과
#
# 1. **제품 및 카테고리 분석**
#    - Set과 kurta 제품군이 전체 판매량의 대부분을 차지
#    - Set 제품은 평균 판매가격이 가장 높고(833.39) 판매량도 가장 많음(45,289)
#    - Western Dress는 중간 정도 판매량(13,943)이지만 높은 평균 가격(762.79) 보유
#
# 2. **판매 채널 효율성**
#    - Amazon.in이 압도적인 주요 판매 채널(116,482건)
#    - Non-Amazon 채널의 매출이 현저히 낮음
#
# 3. **사이즈 및 스타일 트렌드**
#    - M, L, XL 사이즈가 가장 높은 판매량 보임
#    - 특히 M 사이즈가 가장 높은 매출(13,906,754.37) 기록
#    - JNE3797, J0230 스타일이 상위 인기 스타일
#
# 4. **물류 및 배송 성과**
#    - Expedited 배송(83,004건)이 Standard 배송(33,645건)보다 2배 이상 높은 매출
#    - 취소된 주문(Cancelled)이 5,657건으로 상당수 존재
#    - Amazon Fulfillment(84,087건)가 Merchant Fulfillment(32,562건)보다 2배 이상 많은 주문 처리
#
# 5. **지역 및 시간 패턴**
#    -
