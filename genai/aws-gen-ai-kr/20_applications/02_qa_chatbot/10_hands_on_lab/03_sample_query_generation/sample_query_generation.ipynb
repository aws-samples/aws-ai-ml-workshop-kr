# %% [markdown]
# # Sample query generator
# - This is for generating sample queries to easy understand each retrieval method.

# %% [markdown]
# ## Setting
#  - Auto Reload
#  - path for utils

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os
module_path = "../../../.."
sys.path.append(os.path.abspath(module_path))

# %% [markdown]
# ## 1. Creatr Bedrock client

# %%
import json
import boto3
from pprint import pprint
from termcolor import colored
from utils import bedrock, print_ww
from utils.bedrock import bedrock_info

# %% [markdown]
# ### ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----
# - os.environ["AWS_DEFAULT_REGION"] = "<REGION_NAME>"  # E.g. "us-east-1"
# - os.environ["AWS_PROFILE"] = "<YOUR_PROFILE>"
# - os.environ["BEDROCK_ASSUME_ROLE"] = "<YOUR_ROLE_ARN>"  # E.g. "arn:aws:..."
# - os.environ["BEDROCK_ENDPOINT_URL"] = "<YOUR_ENDPOINT_URL>"  # E.g. "https://..."

# %%
boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    endpoint_url=os.environ.get("BEDROCK_ENDPOINT_URL", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
)

print (colored("\n== FM lists ==", "green"))
pprint (bedrock_info.get_list_fm_models(verbose=False))
# Out:
# Create new client
#   Using region: None
#   Using profile: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
#
# == FM lists ==
# {'Claude-Instant-V1': 'anthropic.claude-instant-v1',
#  'Claude-V1': 'anthropic.claude-v1',
#  'Claude-V2': 'anthropic.claude-v2',
#  'Claude-V2-1': 'anthropic.claude-v2:1',
#  'Claude-V3-Haiku': 'anthropic.claude-3-haiku-20240307-v1:0',
#  'Claude-V3-Sonnet': 'anthropic.claude-3-sonnet-20240229-v1:0',
#  'Cohere-Embeddings-En': 'cohere.embed-english-v3',
#  'Cohere-Embeddings-Multilingual': 'cohere.embed-multilingual-v3',
#  'Command': 'cohere.command-text-v14',
#  'Command-Light': 'cohere.command-light-text-v14',
#  'Jurassic-2-Mid': 'ai21.j2-mid-v1',
#  'Jurassic-2-Ultra': 'ai21.j2-ultra-v1',
#  'Llama2-13b-Chat': 'meta.llama2-13b-chat-v1',
#  'Titan-Embeddings-G1': 'amazon.titan-embed-text-v1',
#  'Titan-Text-G1': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Light': 'amazon.titan-text-lite-v1'}

# %% [markdown]
# ## 2. Load LLM

# %% [markdown]
# ### LLM 로딩 (Claude-v3-sonnet)

# %%
from langchain_aws import ChatBedrock
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm_text = ChatBedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-V3-Sonnet"),
    client=boto3_bedrock,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
    model_kwargs={
        "max_tokens": 1024,
        "stop_sequences": ["\n\nHuman"],
        # "temperature": 0,
        # "top_k": 350,
        # "top_p": 0.999
    }
)
llm_text
# Out:
# ChatBedrock(callbacks=[<langchain_core.callbacks.streaming_stdout.StreamingStdOutCallbackHandler object at 0x7fb9ca6073d0>], client=<botocore.client.BedrockRuntime object at 0x7fb9ca474100>, model_id='anthropic.claude-3-sonnet-20240229-v1:0', model_kwargs={'max_tokens': 1024, 'stop_sequences': ['\n\nHuman']}, streaming=True)

# %% [markdown]
# ## 3. LangChainOpenSearch VectorStore 정의
# ### 선수 조건
# - 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 OpenSearch Index 가 생성이 되어 있어야 합니다.
# #### [중요] 아래에 aws parameter store 에 아래 인증정보가 먼저 입력되어 있어야 합니다.
# - 01_preprocess_docs/01_parameter_store_example.ipynb 참고

# %%
import boto3
from utils.ssm import parameter_store

# %%
region=boto3.Session().region_name
pm = parameter_store(region)

# %%
opensearch_domain_endpoint = pm.get_params(
    key="opensearch_domain_endpoint",
    enc=False
)

opensearch_user_id = pm.get_params(
    key="opensearch_user_id",
    enc=False
)

opensearch_user_password = pm.get_params(
    key="opensearch_user_password",
    enc=True
)

# %%
opensearch_domain_endpoint = opensearch_domain_endpoint
rag_user_name = opensearch_user_id
rag_user_password = opensearch_user_password

http_auth = (rag_user_name, rag_user_password) # Master username, Master password

# %% [markdown]
# ### Index 이름 셋팅
# - 이전 노트북 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 생성된 OpenSearch Index name 입력

# %%
index_name = opensearch_user_password = pm.get_params(
    key="opensearch_index_name",
    enc=True
)

print (f'index_name: {index_name}')
# Out:
# index_name: summit-workshop-index

# %%
index_name = "summit-workshop-index"

# %% [markdown]
# ### OpenSearch Client 생성

# %%
from utils.opensearch import opensearch_utils

# %%
aws_region = os.environ.get("AWS_DEFAULT_REGION", None)
os_client = opensearch_utils.create_aws_opensearch_client(
    aws_region,
    opensearch_domain_endpoint,
    http_auth
)

# %% [markdown]
# ## 4. Query generation

# %%
from termcolor import colored
from langchain_core.tracers import ConsoleCallbackHandler
from langchain.schema.output_parser import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, SystemMessagePromptTemplate

# %% [markdown]
# ### prompt

# %%
#You are asked to create a question that cannot be answered using lexical search, but can be answered using semantic search. 
#to create questions that given retrieval methods can answer well.
Read the contexts carefully, This is because you will be asked to create a question that cannot be answered using semantic search, but can be answered using lexical search in the given context.
- lexical search: Lexical search relies on matching the literal or surface-level representation of words and phrases in the query with the content in the search index. It primarily involves looking for exact matches of keywords without considering the broader meaning or context of the words. Lexical search can be precise but might lead to missed results if the exact terms aren’t present in the document. If a user searches for “apple pie recipes,” a lexical search engine returns results that specifically contain the words “apple,” “pie,” and “recipes.”
                - semantic search: Semantic search focuses on understanding the meaning of the query and the context of the information rather than just matching keywords. It uses natural language processing (NLP), machine learning (ML), and other advanced techniques to comprehend the intent behind a user’s query. Semantic search considers synonyms, related concepts, and the relationship between words to provide more contextually relevant results. If a user searches for “healthy recipes,” a semantic search engine might also include recipes that use terms like “nutritious meals” or “wholesome cooking.”
                - rag fusion: RAG-Fusion is able to provide accurate and comprehensive answers due to the generated queries contextualizing the original query from various perspectives. However, some answers strayed off topic when the generated queries' relevance to the original query is insufficient. 
                - hyde: Occasionally, when faced with a question that lacks specificity or lacks easily identifiable elements to derive an answer from a given context, it can be quite challenging. HyDE uses a Language Learning Model, like Claude, to create a theoretical document when responding to a query, as opposed to using the query and its computed vector to directly seek in the vector database. Rather than seeking embedding similarity for questions or queries, it focuses on answer-to-answer embedding similarity.

# %%
system_prompt = '''
                You are a master answer bot designed to create sample questions for someone to easily understand rerieval methods.
                I'm going to give you the description of retrieval method and contexts.
                Read the contexts carefully, This is because you will be asked to create a question that can be answered using parent document in the given context.
                Here is the descriptions of retrieval methods respectively.
                <description>
                - parent document: When splitting documents for retrieval, there are often conflicting desires: \n You may want to have small documents, so that their embeddings can most accurately reflect their meaning. If too long, then the embeddings can lose meaning.
You want to have long enough documents that the context of each chunk is retained. \n The ParentDocumentRetriever strikes that balance by splitting and storing small chunks of data. During retrieval, it first fetches the small chunks but then looks up the parent ids for those chunks and returns those larger documents. \nNote that “parent document” refers to the document that a small chunk originated from. This can either be the whole raw document OR a larger chunk.
                </description>
                
                '''
human_prompt = """
               Here is the contexts as texts: <contexts>{contexts}</contexts>

               First, find a few paragraphs or sentences from the contexts that can revel difference among retrieval methods well. 
               Then, create the question and its answer as much as you can.

               Skip the preamble and go straight into the answer and reason why you create.
               Don't insert any XML tag such as <contexts> and </contexts> when answering.
               Answer in Korean.

               """
system_message_template = SystemMessagePromptTemplate.from_template(system_prompt)
human_message_template = HumanMessagePromptTemplate.from_template(human_prompt)
prompt = ChatPromptTemplate.from_messages(
    [system_message_template, human_message_template]
)

# %% [markdown]
# ### chain

# %%
chain = prompt | llm_text | StrOutputParser()

verbose = False
invoke_args = {
    "contexts": "상록수(3H) 중점 교육활동 수(秀),Head 록(綠),Health 상(常), Heart 중점 교육 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 수(秀),Head 록(綠),Health 상(常), Heart 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 수(秀),Head 록(綠),Health 상(常), Heart 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 수(秀),Head 록(綠),Health 상(常), Heart 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 © © © 62 3 © 3 62 © . © . © 참여와 즐거운 배움의 열기로 신나는 학교 학교상 참여와 즐거운 배움의 열기로 신나는 학교 교사상 학생상 학부모상 큰 꿈을 키워가는 어린이 건강한 인성 감성을 가진 어린이 미래를 키워주는 교사 사랑과 열정으로 가르치는 교사 신뢰받는 교사 참여하는 학부모 믿음을 갖는 학부모 학교상 교사상 학생상 학부모상 1 - 상(常) 1. 바른 인성으로 존중과 나눔을 실천하는 자주적인 어린이"
}
response = chain.invoke(
    invoke_args,
    config={'callbacks': [ConsoleCallbackHandler()]} if verbose else {}
)
# Out:
# 문맥 속에서 "상록수(3H) 중점 교육활동 수(秀),Head 록(綠),Health 상(常), Heart"라는 구절이 보입니다. 이는 상록수라는 교육 기관의 핵심 가치와 교육 방향을 요약하고 있습니다. 이 구절을 활용하여 부모 문서 검색 방법에 대한 예시 질문을 만들어보겠습니다.
#
# 질문: 상록수 교육 기관에서 강조하는 핵심 가치와 교육 방향은 무엇인가요?
#
# 답변: 상록수 교육 기관은 수(秀), 록(綠), 상(常), 하트(Heart)라는 4가지 핵심 가치를 중시하며, 이를 바탕으로 소통하는 공동체, 세계시민교육, 예술교육, 디지털 시민 역량 강화, 독서인문교육, 놀이와 쉼이 있는 교육, 진로 교육, 체험중심 생태환경교육, 인성교육 등을 중점 교육활동으로 삼고 있습니다.
#
# 이 질문을 통해 상록수 교육 기관의 교육 철학과 방향성을 포괄적으로 파악할 수 있으며, 제시된 문맥 안에서 답변할 수 있습니다. 부모 문서 검색 방법을 이해하는 데 도움이 될 것입니다.

# %%
is_done = False
fetched_count = 0
loop_count = 0
offset = 0
count = 0
limit = docs_per_request = 5

query = {"query": {"match_all": {}}}

while not is_done:
    try:
        fetched_count += 1
        fetched_docs = os_client.search(
            index=index_name,
            body=query,
            size=limit,
            from_=offset
        )
        fetched_count = 0
    except Exception as e:
        if fetched_count == 3:
            print("Terminating script as connection is timeout more than 3 times.")
            break
        print ("{} Couldn't get records trying again for limit:{} and offset:{}".format(e, limit, offset))
        continue

    fetched_docs = fetched_docs["hits"]["hits"]
    loop_count += 1

    for index, doc in enumerate(fetched_docs):
        # Process the doc here.
        doc_id = doc["_id"]
        doc_text = doc["_source"]["text"]
        doc_metadata = doc["_source"]["metadata"]
        
        if doc_metadata["family_tree"] == "child":
        
            print (colored(f'DOC ID: {doc_id}', "green"))
            print (colored(f'TEXT: {doc_text}', "blue"))
            print (colored(f'FAMILY_TREE: {doc_metadata["family_tree"]}', "red"))
            
            invoke_args = {
                "contexts": doc_text
            }

            response = chain.invoke(
                invoke_args,
                config={'callbacks': [ConsoleCallbackHandler()]} if verbose else {}
            )
        print ("1")

#         questions = llm_chain_retriever.predict(context=doc_text, num_questions_per_chunk=str(num_questions_per_chunk))
#         #print (questions)
#         questions = questions.split("\n\n-")
#         if len(questions) <= num_questions_per_chunk + 1:

#             if len(questions) == num_questions_per_chunk:
#                 questions = list(map(lambda x:x.strip(), questions))
#             else:
#                 questions = list(map(lambda x:x.strip(), questions[1:]))
#             for q in questions:
#                 answer = llm_chain_generation.predict(question=q, context=doc_text)
#                 answer = answer.strip()
#                 #answer = answer[1:-1].strip()
#                 #print (colored(f'question: {q}', "green"))
#                 #print (colored(f'answer: {answer}', "blue"))
#                 gt.append([q, answer, doc_id, doc_text])
#         else:
#             print ("err")
#             print (questions)

#         #print ("==")
#     #break
    #if loop_count == 3: break
    offset += docs_per_request
    if len(fetched_docs) < docs_per_request:
        print("This is last batch.")
        is_done = True

    print("batch {} completed".format(count))
# Out:
# 1
# 1
# 1
# DOC ID: 5d9dcf1a-a93b-4d22-bb58-091cc9d02958
# TEXT: 2024학년도 학 교 교 육 과 정 설 명 회 연 수 자 료 일시: 2024년 3월 20일 (수) 바른 인성, 건강한 감성, 즐거운 배움으로 미래를 가꾸는 바른 인성, 건강한 감성, 즐거운 배움으로 미래를 가꾸는 학부모 연수 순서 학부모 연수 순서 1. 상록 교육목표 및 구현계획 2. 2024학년도 학사 일정 안내 3. 출결 관련 확인 제출자료 안내 4. 학교교육평가 5. 선행교육 예방(공교육정상화법) 6. 학생 안전 교육 7. 성폭력 예방 교육 8. 흡연 및 음주 예방 교육 9. 학생 인권조례 및 교권보호 10. 방과후학교 운영 11. 초등돌봄교실(오후돌봄) 운영 12. 학부모 서비스 신청 안내 13. 정보통신윤리교육 14. 정보보안 및 개인정보보호 운영 계획 15. 불법찬조금 근절 16. 아동학대 예방 교육 17. 가정폭력 예방 교육 18. 생명 존중 및 생명 살림(자살 예방) 교육 19. 교육활동 참여자 안전교육(녹색, 학부모폴리스) 20. 학교폭력 예방 교육 21. 감염병 예방 교육 22. 청탁금지법 23. 공익제보자 보호 및 공익 신고 보상 안내 24. 존중과 배려의 교육환경 조성 예방 교육(갑질 근절) 25. 교육활동보호예방교육 1 상록 교육 목표 및 구현 계획 비전 바른 인성, 건강한 감성, 즐거운 배움으로 미래를 가꾸는 어린이
# FAMILY_TREE: child
# 1) 질문: 상록 교육과정 설명회에서 다룰 주요 내용은 무엇인가요?
# 답변: 학부모 연수 순서에 따르면 상록 교육목표 및 구현계획, 2024학년도 학사 일정, 출결 관련 확인 제출자료, 학교교육평가, 선행교육 예방, 학생 안전교육, 성폭력/흡연/음주 예방교육, 학생 인권조례 및 교권보호, 방과후학교/돌봄교실 운영, 학부모 서비스, 정보통신윤리/개인정보보호, 불법찬조금/아동학대/가정폭력/생명존중/자살예방 교육, 안전교육, 학교폭력/감염병 예방교육, 청탁금지법, 공익제보자 보호, 갑질 근절 등 다양한 내용을 다룰 예정입니다.
#
# 이유: 본문에 제시된 학부모 연수 순서에 소개된 내용들을 종합적으로 제시하여 상록 교육과정 설명회에서 다룰 주요 내용을 요약하였습니다.
#
# 2) 질문: 상록 교육과정의 비전은 무엇인가요?
# 답변: 상록 교육과정의 비전은 "바른 인성, 건강한 감성, 즐거운 배움으로 미래를 가꾸는 어린이"입니다.
#
# 이유: 본문 마지막 부분에 상록 교육과정의 비전이 명시되어 있습니다.1
# DOC ID: a1348958-da9a-4965-a71e-c6925bdb12d7
# TEXT: 학 교 학 교 6학년은 초등학교 마무리 및 중학교 적응을 위한 학교 자율과정 운영 학년말 6학년 - 4 - 2024학년도 학사 일정 ※ 겨울방학 중 석면교체 및 LED설치 공기 확보(70일) 위해 여름방학 단축 및 겨울방학 70일 운영 1. 1학기 수업일수
# FAMILY_TREE: child
# 샘플 질문: 부모 문서 검색기는 어떤 방식으로 작동하나요?
#
# 답변: 부모 문서 검색기는 긴 문서를 작은 조각으로 나누어 저장하지만, 검색 시에는 원래의 긴 문서를 반환합니다. 이렇게 함으로써 작은 조각의 의미를 잡아내면서도 전체 문맥을 유지할 수 있습니다.
#
# 이 방식을 사용한 이유는 너무 짧은 조각은 의미를 제대로 포착하기 어렵고, 너무 긴 문서는 데이터 저장 및 처리에 비효율적이기 때문입니다. 부모 문서 검색기는 이 두 가지 요구사항을 균형있게 만족시키는 방법입니다.1
# batch 0 completed
# DOC ID: e0455eec-c7ac-49a2-b0d5-d23ca8dc5e67
# TEXT: 1. 교통사고 예방 - 횡단보도, 건널목 신호등 지키기, 우측통행 준수 지도 - 인라인스케이트 및 자전거 안전사고 예방 지도(보호 장구 착용) - 어린이 보호 구역(School Zone)에서의 교통안전 지도 및 홍보 가. 등하굣길 안전사고 예방법 ① 좁은 길, 골목길에서 넓은 도로로 나올 때는 일단 멈추어 좌우를 확인해야 함. 널 는 로 단 고 ② 길을 건널 때는 도로 횡단 5원칙을 지키고 횡단보도에서는 우측통행을 함. ③ 무단 횡단하지 않고, 초록불의 중간에는 건너지 않고 다음 신호를 기다림. . ④ 초록불이 들어오더라도 급하기 뛰어 건너지 않고 좌․우를 살핀 후 길을 건너기. ⑤ 차에서 내릴 때는 자전거, 오토바이, 차량에 주의하며, 정차된 차량 앞뒤로 길을 건너지 않기 ⑥ 비가 오는 날에는 밝은색 계통의 비옷, 모자, 장화, 우산이 눈에 잘 띔. ⑦ 눈이 오는 날에는 양손을 주머니에 넣지 않으며, 목도리 • 털모자를 착용하여 넘어졌을 때 신체를 보호할 수 있음. 나
# FAMILY_TREE: child
# 교통사고 예방 관련 문구들이 있어서 이를 활용하여 문제를 만들어보겠습니다.
#
# 문제: 길을 건널 때 도로 횡단 5원칙을 지켜야 하는 이유는 무엇일까요?
# 답변: 도로를 안전하게 건너기 위해서입니다. 문구 "길을 건널 때는 도로 횡단 5원칙을 지키고 횡단보도에서는 우측통행을 함"에서 도로 횡단 5원칙을 지키라고 명시되어 있습니다.
#
# 문제: 등하굣길에서 안전사고를 예방하기 위해 골목길에서 큰길로 나올 때 어떻게 해야 할까요?
# 답변: 일단 멈춰 서서 좌우를 살펴야 합니다. 문구 "좁은 길, 골목길에서 넓은 도로로 나올 때는 일단 멈추어 좌우를 확인해야 함"에서 이를 명시하고 있습니다.
#
# 이렇게 문맥에 맞는 교통안전 관련 질문을 만들 수 있습니다. 주어진 문서를 잘 활용하면 다양한 질문을 만들 수 있을 것 같습니다.1
# DOC ID: 0c863d53-4d6b-4890-80bb-78b551721cf6
# TEXT: . . ④ 초록불이 들어오더라도 급하기 뛰어 건너지 않고 좌․우를 살핀 후 길을 건너기. ⑤ 차에서 내릴 때는 자전거, 오토바이, 차량에 주의하며, 정차된 차량 앞뒤로 길을 건너지 않기 ⑥ 비가 오는 날에는 밝은색 계통의 비옷, 모자, 장화, 우산이 눈에 잘 띔. ⑦ 눈이 오는 날에는 양손을 주머니에 넣지 않으며, 목도리 • 털모자를 착용하여 넘어졌을 때 신체를 보호할 수 있음. 나. 자전거 안전사고 예방법 부 의 H1EN 에 는 택 : 한 착 룡 몸 가 ① 몸에 맞는 자전거 선택: 발 앞부분의 반 정도가 땅에 닿는 자전거를 의미 시 ② 안전한 복장 착용: 몸에 붙는 옷, 밝은색 옷, 운동화 착용(스커트, 펄럭거리는 바지, 슬리퍼, 샌들 금지) 들 지 ) ③ 보호장구 착용: 안전모(머리손상으로 인한 사망자 70% 이상)와 보호장구(팔꿈치․무릎 보호대) 를 반드시 착용 ④ 안전 상태 확인: 타이어의 바람상태 및 브레이크 작동, 체인 등 확인 (‘픽시’의 경우에도 브레이크 달기) ⑤ 자전거도 ‘차’: 교통안전표지, 교통신호 준수하기, 반드시 시야가 좋은 도로의 우측 가장자리 에서 주행하기 - 11 - ⑥ 야간에 라이트 켜기: 라이트를 켜지 않은 자전거는 상대방에게 보이지 않아 매우 위험함 ⑦ 휴대폰/이어폰 자전거 운전 시 사용 금지: 이어폰을 꽂으면 주변의 소리를 들을 수 없어 매우 위험 ⑧ 횡단보도에서는 자전거에서 내려서 자전거를 끌고 걸어서 건너기 ⑨ 눈, 비가 오거나 짙은 안개가 낀 날에는 자전거 이용 금지 ⑩ 교내에서는 자전거 탑승 및 주행 금지 다. 출입지점 관리 1) 학생은 정해진 보행로로 등하교: 차량 출입이 많은 경사로는 학생 출입 통제 2) 등하교 학생을 위해 교내 외부 차량(학부모 차량 포함) 진입 금지, 교문 앞 주․정차 금지 3) 학생들의 교육활동 시간에는 외부인(학부모 포함)을 통제 ① 방문객은 배움터지킴실에서 관리대장에 성명 및 방문목적을 기재하고 방문증을 교부받는다. (신분증 지참) ② 교내에서는 반드시 방문증을 패용하고 용무 후에는 방문증을 배움터지킴이실에 반납한다. 2
# FAMILY_TREE: child
# 문서와 관련된 내용을 바탕으로 다음과 같은 질문을 만들 수 있습니다.
#
# 질문: 부모 문서 검색 방법은 긴 문서의 맥락을 유지하면서도 작은 문서 조각의 의미 전달력을 높이려는 목적을 가지고 있습니다. 제시된 문서에서 부모 문서 검색 방법의 장점을 보여주는 구체적인 예시를 찾아보세요.
#
# 답변: "⑦ 눈이 오는 날에는 양손을 주머니에 넣지 않으며, 목도리 • 털모자를 착용하여 넘어졌을 때 신체를 보호할 수 있음."
# 이 문장은 짧으면서도 눈이 오는 날 보행 안전을 위한 구체적인 조언을 담고 있습니다. 하지만 이 조언의 전체 맥락은 "가. 보행 안전수칙"이라는 부모 문서에 포함되어 있습니다. 부모 문서 검색 방법은 이렇게 짧은 문서 조각을 검색하면서도 부모 문서의 전체 맥락을 유지할 수 있게 해줍니다.
#
# 이 질문을 만든 이유는 부모 문서 검색 방법의 핵심 개념인 작은 문서 조각과 부모 문서 맥락 유지라는 두 가지 측면을 모두 잘 보여주는 예시를 찾아내기 위해서입니다.1
# DOC ID: f81dc8b7-1cfb-44c6-afdb-0aba5ab18aea
# TEXT: □7 성폭력 예방 교육 보건교사 김○혜 1. 아동·청소년 성폭력 현황: 하루 25명 성폭력 피해(2018년도 국감자료) 가 근 간 자 해 령 : 균 해 로 : 저 , 최근 5년간 꾸준한 증가 아동 청소년: 남자 피해자 4.1% 피해 연령: 평균 14.6세 은 을 피해 경로: SNS 메신저, 어플리케이션 등이 가장 많은 비중을 차지함. 지 . 성폭력은 아는 사람에 의한 경우가 63.3%로 가장 높음 2. 성폭력이란? 성과 관련하여 상대방의 동의 없이 행해지는 모든 신체적, 언어적, 정신적 폭력 3. 자주 발생하는 ‘또래 성폭력·성희롱’ 행동은? 가. 야한 말이나 사진, 동영상을 카카오톡, 밴드, SNS로 보냄 이 른 . . 정 유 의 에 해 에 나. 성장이 빠른 친구의 몸에 대해 지속적으로 놀리거나 특정 신체 부위에 대해 수시로 언급 서 다. 여학생의 치마 속 등을 휴대폰으로 찍어서 친구들에게 공유 로 급 라. 장난치는 척하면서 슬쩍 가슴이나 상대방의 생식기를 만짐 ☞ 장난이라고 생각하는 행동들이 성폭력 범죄이며, 가해자 행동임을 자녀들에게 반드시 지도 하여야 합니다. 4. 성폭력·성희롱 예방을 위한 좋은 습관 - ~ Safe! 안 전 하 게 친 구 들 과 생 활 하 려 면 ... 평 소 차 신 의 생 각 과 느 낌 을 정 확 하 게 표 현 하 는 습 관 을 가 져 요 . "“ 좋 으 면 좋 다 ”, “ 싫 으 면 실 다 !” 확 실 하 게 표 현 해 요 . - 스 킨 십 을 하 고 싶 다 면 먼 저 허 락 을 구 해 야 해 요 . - 청 적 인 농 담 이 나 놀 이 , 불 필 요 한 신 체 첨 촉 은 안 돼 요 . - 여 러 사 람 이 " 뽀 뽀 해 !'” 등과 같 은 성 적 인 행 동 을 시 키 거 나 강 요 하 면 안 돼 요 . - 친 체 노 출 이 나 성 적 인 행 동 을 사 진 찍 공 유 하 거 나 인 터 넷 에 올 리 면 안 돼 요 . I It‘l[)! 피 해 자 가 주 변 에 있 다 면 ..
# FAMILY_TREE: child
# 답변:
#
# Q1) "ParentDocumentRetriever는 문서를 작은 청크로 나누어 저장하지만, 검색 시에는 원본 문서 또는 큰 청크를 반환합니다. 이를 통해 작은 청크의 정확한 의미 파악과 큰 문맥 유지 사이의 균형을 이룰 수 있습니다." 이 질문을 만든 이유는 부모 문서 검색기의 핵심인 작은 청크와 원본 문서 반환 방식을 설명하고 있기 때문입니다.
#
# Q2) 제시된 문맥에서 "성폭력은 아는 사람에 의한 경우가 63.3%로 가장 높음"이라는 문장이 있습니다. "부모 문서 검색기는 이렇게 작은 청크만으로는 파악하기 어려운 배경 정보를 원본 문서를 통해 제공할 수 있습니다." 이렇게 질문을 만들었습니다. 작은 문장 청크로는 성폭력의 가해자 유형에 대한 배경 정보를 얻기 어려운데, 원본 문서를 활용하면 이런 중요한 맥락을 유지할 수 있음을 보여주기 때문입니다.
#
# Q3) 또한 "가. 야한 말이나 사진, 동영상을 카카오톡, 밴드, SNS로 보냄" 등의 문장이 있습니다. "부모 문서 검색기는 이런 구체적인 사례를 통해 학생들에게 주의해야 할 행동 유형을 자세히 설명할 수 있습니다." 원본 문서의 장점인 구체적인 사례와 세부 내용 유지를 강조하는 질문입니다.1
# DOC ID: 1e339b71-b54b-476b-b435-5638f377dfd7
# TEXT: . 경기도 학생인권옹호관 : 경기도 학생인권 조례에 따라 학교에서 발생하는 인권 침해에 대한 상담 및 구제를 위해 마련된 제도 학생인권문제의 상담과 도움 학생인권 보장의 시작: 학생인권과 관련하여 궁금한 것이 있으면 언제든지 물어볼 수 있음 학생인권문제에 대해서는 학생과 학부모, 선생님 모두 이용 가능 2. 학생의 권리 차별 받지 않을 권리, 폭력 및 위험으로부터의 자유 교육에 과한 권리(학습에 관한 권리, 정규교과 이외의 교육활동의 권리, 휴식을 취할 권리) 사생활의 비밀과 자유를 보장 받을 권리(사생활의 자유, 비밀의 보호받을 권리, 정보에 관한 권리) 양심, 종교의 자유에 따른 의사표현의 자유 B9 자치 및 참여의 권리(자치활동의 권리, 학칙 등 학교규정의 재․개정에 참여할 권리, 정책 결정의 권리) 복지에 과한 권리(교육환경에 대한 권리, 문화활동을 향유할 권리, 급식 및 건강에 관한 권리) e 3. 학생의 의무 학교 규칙을 준수해야 하는 의무 조례를 악용하여 교사의 교육, 연구 활동을 방해하거나 학내 질서를 문란하게 해서는 안 됨 4. 경기도 학생인권조례 기본정신 준수 학생 인권이 교육과정에서 실현될 수 있도록 지향 학생 인권과 교사 교권의 상호존중 및 배려 학생의 존엄과 가치 및 자유와 권리 보장 인권교육: 교육과정 내 교과 관련 인권교육 및 학기 당 2시간 이상 운영(연간 4시간) 5. 상록초등학교 학교생활인권규정
# FAMILY_TREE: child
# 답변: 제시된 문맥에서는 정작 검색 방법에 대한 차이를 잘 보여주지 못합니다. 따라서 부모 문서 검색 방법에 대한 질문을 만들기 어렵습니다. 대신 학생 인권 조례의 내용과 관련된 질문을 만들어볼 수 있겠습니다.
#
# 예시 질문:
# 1) 경기도 학생인권옹호관의 역할은 무엇인가?
# 답: 경기도 학생인권옹호관은 학교에서 발생하는 인권 침해에 대한 상담 및 구제를 담당한다.
#
# 2) 학생 인권 조례에서 보장하는 학생의 권리에는 어떤 것이 있는가?
# 답: 차별받지 않을 권리, 폭력 및 위험으로부터 자유, 교육받을 권리, 사생활 비밀과 자유 보장, 양심과 종교의 자유, 의사표현의 자유, 자치 및 참여의 권리, 복지에 대한 권리 등이 있다.
#
# 이렇게 주어진 맥락에 기반하여 관련 주제에 대한 질문을 만들 수 있습니다.1
# DOC ID: 7d515a3e-8a82-4d83-b63c-ea7ce2ebc2ad
# TEXT: 2. 학 부 모 서 비 스 이 용 방 법 (1) 회원가입 및 로그인 〇 학부모서비스(https://parents.neis.go.kr)에 접속하여 학부모서비스 회원가입을 합니다. ※ (구)학부모서비스의 회원은 기존 아이디로 자녀정보 등록 후 바로 서비스 이용이 가능합니다. ※ 행안부 디지털원패스, 간편인증에 이미 가입된 경우 인증 후 학부모서비스에 가입하면 됩니다. ▣ 디지털원패스(https://onepass.go.kr) 행정안전부에서 제공하는 인증서비스로, 전자정부의 여러 서비스를 이용할 수 있음 ※ 모바일 앱 다운 : (안드로이드) Play스토어, 원스토어 / (아이폰) 앱스토어에서 ‘학부모서비스’를 검색합니다. (2) 학부모서비스 로그인 (방법1) 아이디, 패스워드 로그인 ※ 이 경우 일부 자료 열람이 제한됩니다. (방법2) 디지털원패스 로그인 (방법3) 간편인증 로그인 (카카오톡, 네이버, PASS 등) (3) 학부모서비스의 자녀등록 및 정보제공 요청 - (학부모) 학부모서비스 로그인 ➜ ‘자녀 등록하기’에서 자녀 학적 정보 입력 후 조회(소속교육청, 학교명, 학년, 반, 번호, 이름 등) ➜ 자녀등록 및 정보제공 요청 - (자녀) 나이스플러스(https://neisplus.kr) 학생 선 가입 후 로그인 ➜ ‘나의 정보 관리( 학부모 정보 확인 후 정보 열람 ‘동의’(자녀가 나이스플러스 가입해야 사용 가능합니다
# FAMILY_TREE: child
# 답변: 문서 내에서 학부모 서비스 이용 방법에 대한 자세한 설명이 나와 있습니다. 여기에서는 회원 가입, 로그인, 자녀 정보 등록 등의 과정을 단계별로 안내하고 있습니다. 그러나 문서 전체를 보면 이 과정이 부모 문서 검색 방식과는 직접적인 관련이 없습니다.
#
# 따라서 이 문서로는 검색 방식의 차이를 잘 보여주는 질문을 만들기 어렵습니다. 부모 문서 검색 방식에 대한 설명이 추가로 주어진다면 그 차이를 이해하고 관련 문제를 만들 수 있을 것입니다.
#
# 질문 예시: (해당 없음)1
# batch 0 completed
# DOC ID: e6668f9f-76e6-4fd9-8460-2d441257b60a
# TEXT: 이 66 66 아동학대 신고 전화번호 112(경찰서), 031-402-0442(안산시아동보호전문기관): 아동학대 상담 및 현장 출동·조사 등 • 129(보건복지상담센터), 182(경찰민원콜센터) : 아동학대 상담 -누구든지 아동학대를 알게된 때에는 수사기관 또는 아동보호전문기관에 신고할 수 있음 J 긍정적인 양육태도를 갖도록 노력하세요. J 화가 났을 때에는 말이나 행동을 하기 전 꼭 10을 세고, 정말 안 되는 건은 단호하게 ‘안돼’라 고 말해주세요. - 27 - 17 가정폭력 예방 교육 교사 서○희 11 11 가정폭력의 개념 일반적 정의: 가족 구성원간의 갈등 양상을 띠어 국가 개입이 불가피한 경우 가정폭력 처벌법 2조: 가족 구성원 사이의 신체적․정신적․재산상 피해를 수반하는 행위 22 -신체적 폭력 뿐만 아니라 성폭력(성적 학대), 정서적 학대, 유기, 방임(태만, 의무불이 행), 경제적 학대, 언어폭력 등을 포함함 가정폭력의 유형 신 제 적 폭 혁 정 서 적 폭 혁 섬 적 34 경 제 적 5 폭 행 자 유 구 속 언 어 적 ' 정 산 적 학 대 206 엘 정 권 침 해 . 검 제 적 활 동 통제 (00 이 언 | - ( 부 부 강 간 ) 경 제 적 방임 간 접 목 력 기 물 따 손 등 。 、 심 각 한 욕 설 간 섭 등 33 「가정폭력 범죄의 처벌 등에 관한 특례법」제4조에 의하면, 누구든지 가정폭력을 알게 된 가정폭력 신고의무 규정 때에는 이를 수사기관에 신고할 수 있고, 신고한 자에 대하여 그 신고행위를 이유로 불이익 을 주어서는 아니됨을 명시하고 있습니다. 특히 아동, 노인, 장애인 등의 보호시설이나 상담 소, 교육기관, 의료기관 종사자는 가정폭력 범죄를 알게 된 경우에 즉시 신고해야 할 법적 의무가 있습니다. a 44 44 가정폭력 발생시 대처법 | -경찰의 도움이 필요할 때 먼저 112에 신고 : 가정폭력 신고를 받고 경찰관이 출동하 면, 폭력 행위를 제지하고 피해자 동의 시 상담소·보호시설·의료기관 치료 연계 등이 이루어짐
# FAMILY_TREE: child
# 1) 문제: 부모 문서 검색 방법에 대한 설명을 토대로, 아동학대 신고 전화번호와 가정폭력 예방 교육 자료를 통해 부모 문서 검색 방법을 잘 설명할 수 있는 질문을 만들어 보세요.
#
# 답변: 아동학대 신고 전화번호 112, 031-402-0442와 가정폭력 예방 교육 자료에는 작은 단위의 정보 조각들(전화번호, 가정폭력 개념 및 유형 등)과 큰 단위의 정보(아동학대 신고 방법, 가정폭력 대처법 등)가 혼재되어 있습니다. 이런 경우 부모 문서 검색 방법은 작은 단위의 정보를 먼저 검색한 후, 그 정보가 속한 원본 문서나 더 큰 단위의 문서(부모 문서)를 찾아 반환하는 방식입니다. 따라서 "아동학대 신고 전화번호와 가정폭력 예방 교육 자료에서 부모 문서 검색 방법을 활용한다면 어떤 식으로 검색이 이루어질까?"라는 질문을 만들 수 있습니다.
#
# 2) 문제: 위 자료에서 실제로 부모 문서 검색 방법을 적용해 보세요. 작은 단위의 정보를 검색하고, 그것이 포함된 더 큰 단위의 문서를 찾아 제시해 주세요.
#
# 답변: "031-402-0442"라는 작은 단위의 정보를 검색하면, 이것이 "아동학대 신고 전화번호 112(경찰서), 031-402-0442(안산시아동보호전문기관): 아동학대 상담 및 현장 출동·조사 등"이라는 더 큰 문서에 포함되어 있음을 알 수 있습니다. 또한 "가정폭력의 개념"이라는 작은 정보를 검색하면 "가정폭력 예방 교육" 문서의 일부임을 확인할 수 있습니다.
#
# 이렇게 부모 문서 검색 방법을 통해 작은 단위의 정보만으로는 확인하기 어려웠던 전체 문맥을 파악할 수 있습니다.1
# DOC ID: 1d1268c4-847e-4b5f-9746-ff8aacb5c345
# TEXT: 18 생명존중 및 생명살림(자살예방) 교육 자살은 치명적인 결과를 초래하는 자해 행위로 어느 정도 자살 의도를 갖고 그 동기를 인지하면서 자 기 자신에게 가한 상해라고 정의합니다. (WHO, 1968) 2020년, 청소년 건강행태 온라인 조사에 따르면 10.9%의 학생은 자살 생각을 가지고 있고 2.0%는 자살 시도를 하였습니다. 많은 아이들은 초등학교 때부터 이런 생각이 시작되었다고 하며, 다양한 방법으로 도움을 요청하지만 어른들은 미처 알아차리지 못하기도 합니다. 조금만 예민하게 살펴보면 자녀의 극단적인 선택은 막을 수 있습니다. 소중한 자녀들 이 죽고 싶다는 절망적인 생각을 할 때 보이는 언어, 행동, 정서 표현의 신호들이 무엇인지 알아보고 이런 징후가 감지되었을 때는 즉각적, 적극적인 도움이 필요합니다. 11 죽음에 대한 개념이 확립되는 시기 : 만 10세 경 -만 10세 이전의 자녀가 죽고 싶다는 말을 할 때는 어른들이 생각하는 죽음의 개념이 아니라, 너무 힘들다는 호소일 수 있습니다. -죽고 싶다는 자녀의 호소를 무시하거나 야단치지 않습니다. 22 청소년기 우울증의 특징 - 심한 짜증, 분노, 기분의 변덕이 심함 - 학업 성적 저하 - 또래관계 위축, 등교 거부 - 과도한 수면, 폭식 - 비행과 중독, 성적 문제 33 청소년기에 자살이 많은 이유 -급격한 신체적, 정서적, 지적 변화 -자아발달의 미숙, 과도한 입시 경쟁 -급격한 사회변화에 따른 가치관의 갈등 -가족 구성원 간의 결속력 약화 -자살에 대한 태도의 변화 44 죽음을 생각하는 아이들이 보이는 징후 1) 식사와 수면 습관이 변합니다. 식사를 잘 하지 못하거나 잠을 잘 자지 못 합니다. 2) 짜증이 늘어나고 침울하고 우울하게 보입니다. 3) 두통, 복통, 소화불량 등 신체 증상을 호소합니다. 4) 일기장이나 SNS에 죽고 싶다는 표현을 하기도 합니다. 5) 지각, 등교 거부 등 평상시 해오던 일상 활동을 제대로 하지 못합니다. 6) 집에서 대화를 거부하고 무기력하게 누워만 있을 수 있습니다
# FAMILY_TREE: child
# 질문 1: 부모문서 검색 방법은 작은 문서 조각과 원본 긴 문서를 모두 활용하는 방식입니다. 어떤 이점이 있는지 위 맥락에서 문장을 찾아 설명해보세요.
#
# 답변: "소중한 자녀들이 죽고 싶다는 절망적인 생각을 할 때 보이는 언어, 행동, 정서 표현의 신호들이 무엇인지 알아보고 이런 징후가 감지되었을 때는 즉각적, 적극적인 도움이 필요합니다."
# 부모문서 검색 방식은 작은 문서 조각으로부터 관련 정보를 빠르게 검색할 수 있으며, 동시에 원문 맥락을 활용해 더 정확한 이해가 가능합니다. 위 문장에서 자살 징후를 포착하는 작은 정보 조각과 그에 대한 대응 방안의 맥락이 함께 제시되어 있습니다.
#
# 질문 2: "1)식사와 수면 습관이 변합니다. 2)짜증이 늘어나고 침울하고 우울하게 보입니다." 등의 문장이 자살 징후를 설명하고 있습니다. 이런 작은 문서 조각만으로도 의미 있는 정보 검색이 가능할까요? 아니면 원문 맥락이 필요한 이유는 무엇일까요?
#
# 답변: 작은 문서 조각만으로는 정확한 이해가 어렵습니다. 위 문장들은 자살 징후에 대한 설명이지만, 그 징후들이 왜 중요한지, 어떤 상황에서 발생하는지 등의 맥락이 부족합니다. 원문 맥락 "자녀의 극단적인 선택은 막을 수 있습니다. 소중한 자녀들이 죽고 싶다는 절망적인 생각을..."을 고려하면 자살 예방을 위해 주의 깊게 살펴봐야 할 징후임을 알 수 있습니다.
#
# 이렇듯 부모문서 검색 방식은 작은 문서 조각에서 빠른 검색이 가능하면서도 원문 맥락을 활용해 의미를 정확히 파악할 수 있는 장점이 있습니다.1
# DOC ID: 70d1b65e-66da-43ae-969b-e1bd5694f557
# TEXT: 19 교육활동 참여자 안전교육(녹색, 폴리스) 교사 이○혜 1.1. 목적목적 어린이들의 통학로 안전성을 확보하고, 안전하게 등하교 할 수 있도록 도와주며, 아동 대상 범죄 및 학 교 주변에서 자주 발생하는 학교폭력과 유해환경에서 어린이들을 안전하게 보호하기 위함임. 2. 다양한 발생 사례 2. 다양한 발생 사례 가. 스쿨존 내 학생 교통사고 사례 : 아이들은 잘 뛰어다녀요 r\/\QU CICRONCORES . 교 ① 무단횡단을 하는 어른을 보고 따라하는 경우 ② 초록불이 들어오자마자 갑자기 뛰어드는 경우 ③ 인도가 없는 이면도로를 지다가는 경우 ④ 횡단보도 앞에 주‧정차된 차 앞을 지나가는 경우 ⑤ 통학버스 또는 부모님 차량에서 내려 급하게 횡단보도를 건너가는 경우 보 요 . 아 험 례 : 고 는 나. 학교 교육활동 중 위험 사례 : 아이들은 몸집이 작아 잘 안보여요 ① 차도로 굴러가는 공을 쫒아가는 아이 ▶ 어른의 도움을 받도록 함. ② 차 밑에서 공(물건)을 빼고 있는 아이 ▶ 어른의 도움을 받도록 함. ③ 차 뒤에서 놀고 있는 아이 ▶ 위험한 장소에서 놀지 않도록 함. ④ 공사장 옆에서 놀고 있는 아이 ▶ 위험한 장소에서 놀지 않도록 함. ※ 사고 발생 시 이렇게 대처해주세요 →119 신고 및 사고 2차 피해 방지 최초 발견자 →학교 교직원(담당교사 등)에 즉시 연락 ※ 어린 학생들은 사고가 나면 혼이 날까봐 얘기를 잘 못하는 경우가 있는데요. 경미한 사고라도 꼭 선생님 또는 부모님께 연락하고 치료를 받도록 해요. 다
# FAMILY_TREE: child
# 문서에서 "어린이들의 통학로 안전성을 확보하고, 안전하게 등하교할 수 있도록 도와주며, 아동 대상 범죄 및 학교 주변에서 자주 발생하는 학교폭력과 유해환경에서 어린이들을 안전하게 보호하기 위함임."라는 문장이 부모 문서 검색기의 목적을 잘 설명하고 있습니다. 이 문장을 바탕으로 다음과 같은 질문을 만들 수 있습니다.
#
# 질문: 부모 문서 검색기의 목적은 무엇입니까?
# 답변: 부모 문서 검색기의 목적은 어린이들의 통학로 안전을 확보하고, 아동 대상 범죄와 학교폭력, 유해환경으로부터 어린이들을 보호하는 것입니다.
#
# 또한 문서에는 다양한 사고 사례들이 제시되어 있어, 이를 활용하여 다음과 같은 질문을 만들 수 있습니다.
#
# 질문: 문서에 제시된 학교 주변 위험 사례로는 어떤 것들이 있습니까?
# 답변: 문서에 제시된 학교 주변 위험 사례로는 차도로 굴러가는 공을 쫓아가는 아이, 차 밑에서 물건을 빼는 아이, 차 뒤나 공사장 옆에서 노는 아이 등이 있습니다.
#
# 이렇게 문서의 핵심 내용을 잘 반영한 질문을 만들어 부모 문서 검색기의 역할과 필요성을 이해할 수 있습니다.1
# DOC ID: 7b52c4ab-ed5d-4159-865b-a2caafa953c4
# TEXT: . 경미한 사고라도 꼭 선생님 또는 부모님께 연락하고 치료를 받도록 해요. 다. 학교 재난 발생 사례 학교 화재, 수상한 사람이 학교에 진입(테러, 유괴 등), 지진, 폭발, 붕괴 등 ※ 재난 발생 시 이렇게 대처해주세요 ◦ 화재발생 최초 목격자는 “불이야!”하고 외치고 비상벨을 누른 화재 후, 119에 신고(담당교사에게 즉시 연락) ◦ 초기 진화가 가능한 경우, 소화기(소화전 등)을 이용하여 진화 시도(단, 개인의 안전과 학생 대피 우선) ◦ 건물 안에서 대피할 때에는 젖은 수건으로 코와 입을 막고 낮은 자세로 신속히 대피(승강기는 질식 우려, 계단 이용) 테러 지진 ◦ 학교 방문자는 반드시 방문대장 기록 및 방문증 수령 ◦ 폭발물이 의심되는 수상한 가방은 열어보지 말고 112에 신고(담당 교사에게 즉시 연락) ◦ 테러범 발견 시, 112 신고, 교내에 즉시 알림 (개인의 안전 확보 필수) ◦ 지진 발생 시, 가방 및 방석 등으로 머리를 보호 ◦ 건물 안에 있을 시, 머리를 보호하며 운동장으로 대피(계단 이용) ◦ 건물 밖에 있을 시, 떨어지는 물건에 대비 머리를 보호하고 건물과 거리를 두고 넓은 공간으로 대피 ◦ 엘리베이터 안에 있을 시, 모든 층의 버튼을 눌러 가장 먼저 열리는 층에서 내린 후 계단으로 이동 ◦ 해안에서는 해일에 대비하여 높은 곳으로 이동 - 32 - ◦ 폭발물 및 붕괴 위험 시설물 발견 시, 즉시 교육행정실 또는 담당교사에게 폭발 붕괴 연락(개인의 안전 확보 필수) ◦ 유리 파편이나 낙하물에 대비하여 머리와 얼굴을 보호 ◦ 부상자는 추가 폭발, 붕괴 등 2차 피해에 대비하여 가능한 빨리 안전 한 곳으로 대피 후 응급처치(119 신고, 담당교사 연락 등) ※ 안전한 근무를 위해 이렇게 대처하세요 여름철 폭염 <폭염 대비 3대 건강 수칙> ◦ 물 자주 마시기 ◦ 시원하게 지내기(그늘, 실내 등) ◦ 더운 시간대에 휴식하기 겨울철 빙판길 ※ 학교 정문 및 진입로에 빙판길 발견 시에는 학교 담당 교직원에 연락하여 안전사고에 예방합니다
# FAMILY_TREE: child
# 문서에서 '재난 발생 시' 대처 방법에 대한 내용이 자세히 나와 있으므로, 이를 활용하여 질문을 만들 수 있습니다.
#
# 질문: 학교에서 화재가 발생했을 때 어떻게 대처해야 하나요?
# 답변: 최초 목격자는 "불이야!"라고 외치고 비상벨을 누릅니다. 그리고 119에 신고하고 담당교사에게 즉시 연락합니다. 초기 진화가 가능하다면 소화기나 소화전을 이용해 진화를 시도하되, 개인 안전과 학생 대피가 우선입니다. 건물 안에서 대피할 때는 젖은 수건으로 코와 입을 막고 낮은 자세로 신속히 계단을 이용해 대피합니다.
#
# 이 질문은 부모 문서에서 화재 발생 시 대처 방법을 구체적으로 설명하고 있기 때문에 만들었습니다. 이를 통해 부모 문서 검색 방식의 장점을 잘 보여줄 수 있습니다.1
# DOC ID: 3dfd3468-8854-4b11-bfc8-bc535b530a43
# TEXT: 줄 생각이 없으면서 돈을 요구하는 행위 ▪ 옷, 문구류 등을 빌린다며 되돌려주지 않는 행위 ▪ 일부러 물품을 망가뜨리는 행위 ▪ 돈을 걷어오라고 하는 행위 등 ▪ 속칭 빵 셔틀, 와이파이 셔틀, 과제대행, 게임대행, 심부름 강요 등 의사에 반하는 행동을 강요하는 행 강요 위 따돌림 성폭력 ▪ 폭행 또는 협박으로 상대방의 권리행사를 방해하거나 해야 할 의무가 없는 일을 하게 하는 행위(강요) ▪ 집단적으로 상대방을 의도적이고, 반복적으로 피하는 행위 ▪ 지속적으로 싫어하는 말로 바보취급 등 놀리기, 빈정거림, 면박주기, 겁주는 행동, 골탕 먹이기, 비웃기 ▪ 다른 학생들과 어울리지 못하도록 막는 행위 ▪ 상대방에게 폭행과 협박을 하면서 정적 모멸감을 느끼도록 신체적 접촉을 하는 행위 ▪ 성적인 말과 행동을 함으로써 상대방이 성적 굴욕감, 수치감을 느끼도록 하는 행위 ➜ 「아동·청소년의 성보호에 관한 법률」에 따라 성폭력에 대해서는 반드시 수사기관에 신고해야 함 ▪ 특정인에 대해 모욕적 언사나 욕설 등을 인터넷 게시판,채팅,카페 등에 올리는 행위, 특정인에 대한 ‘저격 글’ 사이버 폭력 ▪ 특정인에 대한 허위 글이나 개인의 사생활에 관한 사실을 인터넷, SNS, 카카오톡 등을 통해 불특정 다 수에 공개하는 행위 ▪ 성적 수치심을 주거나,위협하는 내용, 조롱하는 글, 그림, 동영상 등을 정보통신망을 통해 유포하는 행 위 ▪ 공포심이나 불안감을 유발하는 문자, 음향, 영상 등을 정보통신망을 통해 반복적으로 보내는 행위 이렇게 예방해요 ➠ 초등학생 학교폭력 피해 유형 중 언어폭력(34
# FAMILY_TREE: child
# 문서를 가져올 때 부모 문서 검색기(ParentDocumentRetriever)는 작은 문서 조각들을 먼저 검색한 후, 그 조각들의 원본 부모 문서를 찾아서 반환합니다. 이를 통해 문맥을 유지하면서도 embedding의 정확도를 높일 수 있습니다.
#
# 이 방법을 설명하는 질문으로는 다음과 같은 것들이 있습니다:
#
# 1) 작은 문서 조각들의 검색 결과만으로는 문맥을 잃을 수 있습니다. 이를 해결하기 위해 ParentDocumentRetriever는 어떤 방식을 사용합니까?
# 답: ParentDocumentRetriever는 작은 문서 조각들을 먼저 검색한 후, 그 조각들의 원본 부모 문서를 찾아 반환합니다. 이를 통해 문맥을 유지할 수 있습니다.
#
# 2) 긴 문서를 그대로 사용하면 embedding의 정확도가 낮아질 수 있습니다. ParentDocumentRetriever는 이 문제를 어떻게 해결합니까?
# 답: ParentDocumentRetriever는 문서를 작은 조각으로 나누어 embedding을 수행하므로, 긴 문서를 사용할 때보다 정확도가 높아집니다.
#
# 질문들은 ParentDocumentRetriever의 장점인 문맥 유지와 정확도 개선을 잘 설명하고 있습니다.1
# batch 0 completed
# DOC ID: 4bfc0e30-159d-465b-b42c-464068a4ec79
# TEXT: 피 해 학 생 - 가 해 학 생 지 원 ( 학 교 , 안 산 교 육 지 원 청 )
# FAMILY_TREE: child
# 질문: 문맥을 잘 유지하면서도 의미를 정확히 반영할 수 있는 적절한 문서 분할 방식은 무엇일까요?
#
# 답변: ParentDocumentRetriever는 문서를 작은 청크로 분할하여 저장하지만, 검색 시에는 해당 청크의 상위 문서(원본 문서 또는 큰 청크)를 반환합니다. 이를 통해 각 청크의 의미는 작은 단위로 인코딩되어 정확도가 높아지면서도, 상위 문서의 전체 문맥을 유지할 수 있습니다. 따라서 ParentDocumentRetriever는 문서 분할과 문맥 유지 간의 균형을 잡는 효과적인 방법입니다.
#
# 이유: 제시된 내용에서 작은 청크로 분할하면 임베딩이 의미를 정확히 반영할 수 있지만, 전체 문맥이 손실될 수 있다는 점을 언급했습니다. ParentDocumentRetriever는 이런 두 가지 요구사항을 모두 만족시키는 방식이므로, 이에 대한 질문을 만들고 ParentDocumentRetriever의 원리를 답변으로 제시했습니다.1
# DOC ID: 561fde90-79df-4855-bba1-a61c00534dc9
# TEXT: 학생, 학부모, 교직원 대상 예방교육(학기당 1회) ∙또래활동, 체육·예술활동 등 활동중심 예방활동 ∙어울림(사이버어울림)프로그램 교육과정 반영(연 8차시 이상, 사이버폭력예방 2차시 이상 포함) CCTV, 학생보호인력 등 안전인프라 구축 ∙신고방법 홍보: 112,117,학교전담경찰관,담임교사 등) □ 학교폭력 관련 외부 상담기관: 117(학교폭력 신고·상담센터), 1388(청소년 상담), 상록초등학교 학교전담경찰관 □ 학교폭력 신고 및 갈등조정 관련 문의: 상록초등학교 학교폭력전담기구((031-487-5743) □ 학교폭력 사안 심의 및 조치 불복 관련 문의: 안산교육지원청 학생지원센터(031-412-4555~4557) - 35 - | 21 감염병 예방 교육 보건교사 김○혜 1. 학교에서 자주 발생하는 감염병
# FAMILY_TREE: child
# 질문: 학교폭력 예방 교육 활동에 대한 내용이 포함되어 있습니다. 이를 바탕으로 학부모와 학생들이 학교폭력 예방 교육에 참여할 수 있는 방법에 대한 질문을 만들 수 있습니다.
#
# 예시 질문: 학부모와 학생들은 어떤 학교폭력 예방 교육 활동에 참여할 수 있나요?
#
# 답변: 학생, 학부모, 교직원 대상으로 학기당 1회 예방교육이 있고, 또래활동, 체육·예술활동 등 활동중심 예방활동과 어울림(사이버어울림) 프로그램 교육과정(연 8차시 이상, 사이버폭력예방 2차시 이상 포함)이 있습니다.
#
# 이유: 제시된 문맥에는 학교폭력 예방을 위한 다양한 교육 활동이 설명되어 있기 때문에, 이를 바탕으로 참여 방법에 대한 질문과 답변을 만들 수 있습니다.1
# DOC ID: 1ddf7282-d334-4508-9849-c2c05ea3f01a
# TEXT: . 적용 대상 가. 적용 대상 기관 ○ 공공기관, 언론기관, 금융 등 나. 적용 대상자 : 공직자 등, 공적 업무 종사자 ○ 적용 대상 기관의 직원과 배우자 ○ 공공기관의 의사결정 등에 참여하는 민간인 ○ 공직자 등에게 부정 청탁을 하거나 수수 금지 금품 등을 제공한 자 2. 부정 청탁의 금지(제5조) ○ 누구든지 직무를 수행하는 공직자 등에게 직접 또는 제삼자를 통한 부정 청탁을 금지 - 법에 열거된 14가지 대상 직무에 관하여 법령을 위반하거나 지위·권한을 남용하게 하는 행 위 3. 금품 등의 수수 금지(제8조, 제9조, 제10조) 가. 공직자 등의 금품 등 수수 금지 ○ 수수 금지 금품 등 - 동일인으로부터 1회 100만 원 초과 매 회계연도 300만 원 초과 금품 등 수수 - 직무와 관련하여 1회 100만 원 이하 금품 등 수수 - 배우자가 수수 금지 금품 등을 받은 경우 - 외부 강의 시 대통령령으로 정하는 금액을 초과하는 사례금 수수 ○ 공직자 등 배우자의 금품 등 수수 금지 나. 직무 관련 외부 강의 등의 사례금 수수 제한(제10조) ○ 우회적인 금품 등 수수로 악용될 소지가 있는 직무 관련 외부 강의 등의 사례금 수수 제한 4. 위반행위 신고·처리 및 신고자 보호·보상 가. 위반행위 신고·처리 절차 이 Ui | 니 10 퍼 0 <E K K Z 허 더 [ 이 R ujo ㅠ I Ex 둥 룬 과게 째 == -_ N =N 7 버 4 Ho < 버 i < ㅠ g o (2 급 z oo 2 3 더 권 기 관 , 감 독 기 관 , 감 사 원 , 수 사 기 관 , 국 민 권 익 위 원 회 에 신 고 고 고 ㅎ S g 1 2 잡 g ~ 기 하 페 1 나. 신고자 보호 · 보상 ○ 보상금 또는 포상금 지급 ○ 불이익 조치 금지 및 원상회복 조치 ○ 신분 비밀보호, 신변 보호 및 책임감면 5. 징계 및 벌칙
# FAMILY_TREE: child
# 제공된 문서의 내용을 살펴보면 법 집행 기관 및 공공 기관에서 부정 행위를 신고하고 처리하는 절차, 신고자 보호 조치, 위반 시 징계 및 벌칙 등에 대해 설명하고 있습니다. 이는 부모 문서 검색기와 직접적인 관련이 없기 때문에 적절한 질문을 만들기가 어렵습니다.
#
# 그래도 문서 분할 및 검색 방식과 관련된 질문을 만들어 보겠습니다.
#
# 질문: 부모 문서 검색기(ParentDocumentRetriever)는 어떤 방식으로 문서를 분할하고 검색하나요?
#
# 답변: 부모 문서 검색기는 먼저 긴 문서를 작은 청크(chunk)로 분할하여 저장합니다. 검색 시에는 먼저 관련된 작은 청크들을 찾은 후, 그 청크들이 원래 속해 있던 부모 문서(원문 또는 보다 큰 문서 청크)를 찾아 반환합니다. 이렇게 함으로써 정확한 의미 파악을 위해 짧은 청크를 사용하면서도 전체 문맥을 유지할 수 있습니다.
#
# 이 방식을 사용한 이유는 문서를 너무 작게 분할하면 문맥이 손실될 수 있고, 너무 크게 분할하면 의미를 정확히 파악하기 어려워지기 때문입니다.1
# DOC ID: 5e887fee-3b93-40d9-a8af-57e228dfbc95
# TEXT: .12,? 2wl 필램륭몰 훼 슨 한 행 위 공 직 비 리 신 고 아 -2) hotine@goe.gokr / 031-2490-5999 * 궁 기 도 교 육 정 - 38 - 24 존중과 배려의 교육환경 조성 예방 교육(갑질 근절) 교감 김○식 1. 갑질 개념 사회·경제적 관계에서 상대방보다 우월적 지위에 있는 갑이 권한을 남용하여 을에게 부당한 요구나 처우 ○ 위법 또는 재량권 일탈·남용에 해당하는 행위 ○ 적법 또는 재량권 내의 행위라도 인격적 모멸감을 유발하는 경우 2. 유형 (이익 추구형) 갑(甲)이 우월적 지위를 활용하여 유무형의 이익을 취하는 행위 ※ 금품향응 수수, 사적 심부름 편의 요구, 상대 기관에 책임·비용전가 동 (불이익 처우형) 을(乙)에게 업무적 또는 인격적 불이익을 주는 행위 ※ 부당한 인·허가 불허·지연, 부당한 전보 발령, 승진 누락, 불필요한 업무 지시 ※ 폭언 폭행 등 인격모독, 성희롱·성추행 성폭력 등
# FAMILY_TREE: child
# 문서를 작은 조각으로 나누어 색인하면 각 조각의 의미를 정확히 반영할 수 있지만, 원래 문서의 전체 맥락을 잃어버릴 수 있습니다. 따라서 부모 문서 검색 방식은 이를 보완하기 위해 도입되었습니다. 부모 문서 검색 방식에서는 먼저 짧은 조각으로 색인하고, 검색 시에는 해당 조각의 원래 부모 문서를 찾아 반환합니다. 이렇게 함으로써 조각의 의미는 유지하면서도 원래 문서의 맥락도 살릴 수 있습니다.
#
# 질문 1) 문서를 짧은 조각으로 나누면 어떤 이점이 있나요?
# 답변: 짧은 조각의 임베딩이 그 의미를 잘 반영할 수 있습니다.
#
# 질문 2) 하지만 짧은 조각으로만 검색하면 어떤 문제가 발생할 수 있나요?
# 답변: 원래 문서의 전체 맥락을 잃어버릴 수 있습니다.
#
# 질문 3) 부모 문서 검색 방식은 이런 문제를 어떻게 해결하나요?
# 답변: 짧은 조각으로 검색한 후에 그 조각이 속한 원래 부모 문서를 찾아 반환함으로써 조각의 의미와 원래 문서의 맥락을 모두 살립니다.
#
# 위 질문과 답변을 만든 이유는 주어진 문맥에서 부모 문서 검색 방식의 장단점을 잘 설명하고 있어, 이를 바탕으로 질문과 답변을 구성할 수 있기 때문입니다.1
# DOC ID: 03f05f39-e019-4e2e-88cd-76f126a2aa46
# TEXT: . Ⅲ. 가정에서의 교육활동 침해행위 예방교육 1. 가정교육의 중요성 인식하기: 가정교육은 학교교육의 성패에 중요한 영향을 미치며, 가정교육이 튼튼하지 못하면 학교교육이 위험해질 수 있습니다. 학교교육을 통해서 얻을 수 있는 인성교육이나 생활습관 개선, 관계성 교육 등은 가정교육을 통해 내면화하는 것이 필요합니다. 2. 교원과 학부모의 관계 재정립하기: 학부모와 학생이 교원과 학교를 신뢰할수록 학생의 전인적 성장이 가속됩니다. 교원의 교육활동을 존중하면 학생의 학습권과 학부모의 교육권이 함께 존중되는 바람직한 상호관계가 조성될 수 있습니다. - 41 -
# FAMILY_TREE: child
# 문제: 가정교육이 학교교육에 미치는 영향에 대해 설명하고 있는 문장을 찾아 질문을 만들어보세요.
#
# 답변: 가정교육이 학교교육의 성패에 중요한 영향을 미치며, 가정교육이 튼튼하지 못하면 학교교육이 위험해질 수 있습니다.
#
# 질문: 문맥에 따르면 가정교육이 학교교육에 어떤 영향을 미칩니까?
#
# 이유: 주어진 문맥에서 가정교육이 학교교육의 성공 여부에 중요한 역할을 한다고 명시적으로 언급하고 있기 때문에, 이를 바탕으로 가정교육이 학교교육에 미치는 영향에 대한 질문을 만들 수 있습니다.1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# DOC ID: 7cc07f34-801d-4871-b8b5-4af38c5b7fc2
# TEXT: 상록수(3H) 중점 교육활동 수(秀),Head 록(綠),Health 상(常), Heart 중점 교육 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 수(秀),Head 록(綠),Health 상(常), Heart 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 수(秀),Head 록(綠),Health 상(常), Heart 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 수(秀),Head 록(綠),Health 상(常), Heart 소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육 © © © 62 3 © 3 62 © . © . © 참여와 즐거운 배움의 열기로 신나는 학교 학교상 참여와 즐거운 배움의 열기로 신나는 학교 교사상 학생상 학부모상 큰 꿈을 키워가는 어린이 건강한 인성 감성을 가진 어린이 미래를 키워주는 교사 사랑과 열정으로 가르치는 교사 신뢰받는 교사 참여하는 학부모 믿음을 갖는 학부모 학교상 교사상 학생상 학부모상 1 - 상(常) 1. 바른 인성으로 존중과 나눔을 실천하는 자주적인 어린이
# FAMILY_TREE: child
# 문서에서 "상록수(3H) 중점 교육활동 수(秀),Head 록(綠),Health 상(常), Heart" 부분과 "소통하는 공동체 하나되는 세계시민교육 나눔, 배려, 함께하는 감성이 자라는 예술교육 디지털 시민 역량 강화 독서인문교육 놀이와 쉼이 있는 교육 디양한 진로 교육 운영 체험중심 생태환경교육 인성교육" 부분을 보면 parent document retrieval 방식의 특징을 잘 보여줍니다.
#
# 문서를 작은 청크로 분할하면 전체 문맥을 잃을 수 있지만, 부모 문서를 함께 반환하면 작은 청크의 정확한 의미를 파악할 수 있습니다. 따라서 다음과 같은 질문을 만들 수 있습니다.
#
# 질문: 상록수 학교의 중점 교육활동은 무엇인가?
# 답변: 소통하는 공동체, 하나되는 세계시민교육, 나눔, 배려, 함께하는 감성이 자라는 예술교육, 디지털 시민 역량 강화, 독서인문교육, 놀이와 쉼이 있는 교육, 다양한 진로 교육 운영, 체험중심 생태환경교육, 인성교육 등입니다.
#
# 이 질문은 작은 청크인 "상록수(3H) 중점 교육활동 수(秀),Head 록(綠),Health 상(常), Heart"만 가지고는 답변하기 어렵지만, 부모 문서 전체 문맥을 활용하면 답변할 수 있습니다.1
# batch 0 completed
# DOC ID: a1403b93-9a84-4f17-b740-b714d594de4e
# TEXT: 교사 나○철 코로나 백신 접종 ▸접종 당일에 대해 출석인정결석처리 ▸이상반응 발생 시 2일까지 출석인정 처리 가능 ▸접종 후 3일부터 질병결석 처리 결석계와 담임교사확인서+증빙서류 (예 방 접 종 확 인 서 ,의 사 소 견 서 등 ) 19 코로나19 학교장 허가교외 체험학습 ▸확진(양성) 시에는 격리 권고 기간 5일 출석 인정 ▸음성 시에는 당일 1일 출석 인정 당 ' 습 + 가 정 습 통 ▸기존 교외체험학습+가정학습 통합하여 연간 20일 이내(해당 학년도) ▸국외 신청시 비행기나 배편 e-ticket(왕복) 사본 첨부(증빙자료) ▸국가 감염병 심각 단계에서만 가정학습 포함 (감염병 위기경보단계확인 : https://naver.me/55yVhEUd) ▸4시간 미만은 반일 운영(단, 반일은 당일 수업 참여한 경우에 한하여 허가) | | ㅣ , 결석계와 담임교사확인서+증빙서류 (의 사 소 견 서 ,검 사 확 인 서 ,PCR양 성 결 과 통 보 메 시 지 ) 신청서(국외 시 e-ticket 첨부)+결과 보고서 * 3일 전 신청서 제출하여 사전 허가 후 내 솔 실시, 종료 후 7일 이내 제출 (사전 미허가 실시, 보고서 미제출, 허가 일 수 초과 등: 미인정결석처리) 7 - 〈서식1〉 담 임 보건(협조) 감염병,고위험군 관련시만 학 년 부 장 전결 결 재
# FAMILY_TREE: child
# 답변: 텍스트에 "부모 문서(parent document)" 개념을 잘 설명하는 구절은 없습니다. 하지만 '교사 나○철 코로나 백신 접종'에 관한 세부 사항들이 나열되어 있어, 이 단락을 부모 문서로 간주하고 질문을 만들 수 있습니다.
#
# 예시 질문:
# 1) 교사가 코로나 백신 접종 후 며칠부터 질병결석 처리를 해야 합니까?
# 답변: 접종 후 3일부터 질병결석 처리
#
# 2) 백신 접종 후 이상반응이 발생할 경우 며칠까지 출석인정이 가능합니까?
# 답변: 2일까지 출석인정 처리 가능
#
# 이렇게 세부 사항을 질문으로 만들어 부모 문서의 내용을 이해할 수 있습니다. 부모 문서에서 관련 정보를 찾아 질문에 답변할 수 있습니다.1
# DOC ID: 4bdd2728-2751-42ff-a7fa-f01c4eb240c3
# TEXT: . 방침 가. 학생의 삶과 연계한 교육과정, 수업, 평가의 운영으로 학생 개개인의 삶의 역량을 키운다. 나. 학생의 학습 수준을 확인하고 결과만이 아니라 결과에 이르기까지의 학습과정을 중시한다. 다. 학생의 학습 과정과 결과에 대한 맞춤형 피드백을 제공하여 학생의 학습을 지원한다. 라. 평가의 목표를 학생에게 미리 안내(매 학기 초 사전 안내)하여 학습 과정에서 학생이 주도적으로 자신의 학습과정을 성찰하고, 스스로 조정할 수 있도록 한다. 마. 학습한 지식과 기능을 바탕으로 종합하여 판단하거나 새로운 변화를 만들어 낼 수 있는지를 평가한다. 바. 학습과 평가의 과정에서 얻은 경험을 바탕으로 실생활 맥락 속의 문제를 해결 할 수 있는 역량을 함양할 수 있도록 한다. 3. 추진내용
# FAMILY_TREE: child
# 답변:
#
# 1) 질문: 학생의 평가 과정에서 중시해야 할 점은 무엇인가요?
# 답변: 나. 학생의 학습 수준을 확인하고 결과만이 아니라 결과에 이르기까지의 학습 과정을 중시한다.
# 이 문장은 학생 평가 시 결과뿐만 아니라 과정 자체도 중요하게 다루어야 함을 보여줍니다.
#
# 2) 질문: 학생 개개인의 삶과 연계하여 어떤 식으로 교육과정을 운영해야 하나요?
# 답변: 가. 학생의 삶과 연계한 교육과정, 수업, 평가의 운영으로 학생 개개인의 삶의 역량을 키운다.
# 이 문장은 학생 개인의 삶과 연계하여 교육과정을 운영함으로써 삶의 역량을 기를 수 있음을 보여줍니다.
#
# 3) 질문: 평가에서 학생에게 어떤 피드백을 제공해야 하나요?
# 답변: 다. 학생의 학습 과정과 결과에 대한 맞춤형 피드백을 제공하여 학생의 학습을 지원한다.
# 이 문장은 학생 개개인의 학습 과정과 결과에 맞춘 피드백을 제공해야 함을 나타냅니다.
#
# 이 문장들은 학생 평가의 중요 원칙과 방향성을 잘 보여주어 평가 관련 질문에 적절히 활용할 수 있습니다.1
# DOC ID: 7ad3e328-0f6c-4146-ac75-ae4b79c2fe86
# TEXT: 수행평가 ‧ 창의적 체험활동의 영역별 활동내용, 평가방법 및 기준은 교육과정을 근 설정하여 수시로 관찰 기록한 후 종합적인 행동 특성을 문장으로 기술 - 9 - □5 선행교육 예방 (공교육정상화법) 교사 우○주 ❍ 선행교육 -「초‧중등교육법」제23조제2항에 따라 교육부장관이 정한 초․중등학교 교육과정(국가교육과정) 및 교육감이 정한 초․중등학교 교육과정(시․도교육과정), 「초‧중등교육법」제23조제1항에 근거하여 편성․운영되는 단위학교 교육과정(학교 교육과정) 국가교육과정-시․도교육과정-학교 교육과정에 앞서서 편성 또는 제공하는 교육 일반 ❍ 선행학습 - 학습자가 국가교육과정, 시․도교육과정, 학교 교육과정에 앞서서 하는 학습 1. 추진 근거 및 목적 가. 근거 Ÿ 「공교육 정상화 촉진 및 선행교육 규제에 관한 특별법」(공교육정상화법) Ÿ 2024년 선행학습 유발 관행 근절 사업 추진계획(교육부 기초학력진로교육과-379, 2024.1.31.) { 력 진 로 교 육 가 -379, 2024.1.31.) 흐 기 진 계 획 ( 교 육 눅 T ) 적 사어 H 은 한 } 으 박 괴 * 2024 년 선 행 학 습 모 저 . 나. 목적 Ÿ 학교의 정상적인 교육과정 운영을 위한 여건 조성 및 공교육 정상화 실현 Ÿ 선행교육과 선행학습 유발 관행 근절을 위한 학생, 교원, 학부모 인식 개선 연수 및 홍보 강화 Ÿ 교육과정 편성 운영 및 선행출제 점검·컨설팅을 통해 학생의 발달단계에 맞는 교육 실시 2. 추진 계획 가. 연수 추진 계획
# FAMILY_TREE: child
# 문서에는 선행 교육과 선행 학습의 정의와 예방 목적 및 계획에 대해 서술되어 있습니다. 하지만 검색 방법론에 대한 내용은 포함되어 있지 않습니다. 따라서 이 문서를 활용해 검색 방법론과 관련된 질문을 만들기는 어렵습니다.1
# DOC ID: d0aafbae-ebb6-466a-a31a-a61075a003ac
# TEXT: . - 스 킨 십 을 하 고 싶 다 면 먼 저 허 락 을 구 해 야 해 요 . - 청 적 인 농 담 이 나 놀 이 , 불 필 요 한 신 체 첨 촉 은 안 돼 요 . - 여 러 사 람 이 " 뽀 뽀 해 !'” 등과 같 은 성 적 인 행 동 을 시 키 거 나 강 요 하 면 안 돼 요 . - 친 체 노 출 이 나 성 적 인 행 동 을 사 진 찍 공 유 하 거 나 인 터 넷 에 올 리 면 안 돼 요 . I It‘l[)! 피 해 자 가 주 변 에 있 다 면 ... - 이런 말 은 친 구 를 더 힘 들 게 해 요 !( 덮 어 두 어 라 , 나 라 면 안 그 랬 을 텐 데 , 너 도 잘 못 했 네 .) - 이 야 기 를 잘 들 어 주 고 절 대 로 소 문 내 면 안 돼 요 . - 친 구 말 을 믿 어 주 고 전 문 기 관 의 도 움 을 받 도 록 꼭 권 하 세 요 . 5. 성폭력 발생 시 도움을 받을 수 있는 곳 여성 긴급전화 국번 없이 『1366』, 학교폭력(성폭력) 신고 『112』, 『117』 경기해바라기 아동센터 www.sunflower1375.or.kr, 031) 708-1375~6 성범죄알림e 사이트(http://sexoffender.go.kr), 스마트폰 성범죄알림e 앱 다운 설치 성매매 알선 권유행위 신고하기(경찰서 112, 경찰청 홈페이지 www.police.go.kr 사이버 범죄 신고) 6. 성범죄 예방을 위한 부모님의 역할 ① 자녀가 자주 다니는 곳, 집을 오가는 길에 위험요소가 있는지 미리 둘러보십시오. ② 아는 사람이라도 원하지 않는 신체 접촉을 하면 참고 있지 말고 단호하게 “싫다!”는 의사 표현을 하며 즉시 자리를 피하도록 알려줍니다. 신체 접촉 전 상대의 의사를 항상 먼저 물어보도록 알려줍 면 이 가 니다. 상대가 대답하지 않으면 yes라고 생각하는 경우 때문에 사안이 발생하는 경우가 많습니다. 무 다 . - 13 - 가 니 다 . 응답은 yes가 아니라 NO일 수 있습니다
# FAMILY_TREE: child
# 부모님의 역할에 관한 내용의 일부를 통해 retrieval 방법의 차이를 잘 보여줄 수 있는 질문을 만들 수 있습니다.
#
# 질문: 자녀의 안전을 위해 부모가 해야 할 일은 무엇입니까?
#
# 답변: ① 자녀가 자주 다니는 곳, 집을 오가는 길에 위험요소가 있는지 미리 둘러보십시오. ② 아는 사람이라도 원하지 않는 신체 접촉을 하면 참고 있지 말고 단호하게 "싫다!"는 의사 표현을 하며 즉시 자리를 피하도록 알려줍니다.
#
# 이 질문은 주어진 context의 일부분만을 활용하여 답변할 수 있습니다. 즉, retrieval 방법 중 'parent document'를 사용하여 원본 문서에서 관련 내용을 찾아 답변할 수 있습니다.1
# DOC ID: 640276a6-311e-4707-b79d-498e8da7eb8b
# TEXT: . ③ 부부간에 존중하고 사랑하는 모습을 자녀 앞에서 자연스럽게 표현하도록 합니다. ④ 질문에 답할 때는 당황하거나 회피하지 말고 불충분한 대답이라도 좋으나 거짓말은 하지 말아야 합니다. - 성에 관한 설명은 구체적, 직접적으로 표현해야 합니다. 그 질문을 왜 했는지 알아보세요. ⑤ 성교육은 과학적인 면과 사회적, 윤리적인 면을 병행하여 가르쳐야 합니다. ⑥ 부모가 해결하기 어려운 문제는 전문교사나 상담기관을 찾습니다. 8. 디지털 성범죄 예방 디지터 서버시 안 전 하 고 자 유 로 운 세 상 을 위해 우 리 가 할 수 있 는 것 들 = OH™ 디 지 털 장 비 , 정 보 통 신 망 올 매 개 로 제삭 배포 유 통 되 는 형 식 의 범 죄 0 2} 8 사 이버 공 간 에 서는 다 른 사 람 의 개 인 정 보 나 타 인이 나 오 는 구 체 적 으 로는 Ol LTI 4891 9 SR 몰 래 카 메 라 제 작 물 _ ㅣ PUBIOME | |ceame Ay ｜ e “ 나 의 개 인 정 보 를 보 내 거 나 허 락 없 이 게 시 하 거 나 58 사 이 버 공 간 에 서 불 특 정 다 수 에 전 달 하 는 행 위 로 03 R |\ 밝 메 랄 트 . / 관 비 화 트다 / . 토 sewn s 형 , 참 여 형 , 소 비 형 이 있 음 . 안 전 하 고 자 유 로 운 세 상 을 위해 우 리 가 할 수 있 는 것 들 0 2} 8 사 이버 공 간 에 서는 다 른 사 람 의 개 인 정 보 나 타 인이 나 오 는 ㅣ PUBIOME | |ceame Ay ｜ e 나 의 개 인 정 보 를 보 내 거 나 허 락 없 이 게 시 하 거 나 |\ 밝 메 랄 트 . / 관 비 화 트다 /
# FAMILY_TREE: child
# 문맥에서 부모가 자녀에게 성교육을 제공할 때의 방법과 유의사항이 나와 있습니다. 이를 바탕으로 다음과 같은 질문을 만들 수 있습니다.
#
# 질문: 부모가 자녀에게 성교육을 할 때 유의해야 할 점은 무엇입니까?
#
# 답변: ③ 부부 간의 존중과 사랑의 모습을 자연스럽게 보여주어야 한다. ④ 질문에 거짓말하지 말고 불충분하더라도 진실하게 대답해야 한다. 성에 대한 설명은 구체적이고 직접적으로 해야 하며, 질문 이유를 알아봐야 한다. ⑤ 과학적인 면과 사회적, 윤리적인 면을 병행하여 가르쳐야 한다. ⑥ 어려운 문제는 전문가나 상담기관을 찾아야 한다.
#
# 이렇게 질문을 만든 이유는 문맥에서 부모가 자녀에게 성교육을 제공할 때의 구체적인 방법과 주의사항을 담고 있기 때문입니다. 이를 통해 부모가 자녀 성교육 시 고려해야 할 사항을 잘 파악할 수 있습니다.1
# batch 0 completed
# DOC ID: 99679545-bba6-4227-b496-b9528a91d5c5
# TEXT: .goe.go.kr → 전자민원 → 신고 센터 → 공익제보센터→불법찬조금 신고 - 전 화 : 경기도교육청 감사관 031) 820-0852 ○ 안산교육지원청 : www.goeas.kr→ 열린공간 → 사이버신고센터 - 전 화 : 031) 412-4620 ○ 참교육을 위한 전국학부모회 : www.hakbumo.or.kr →학교길라잡이→ 불법찬조금 ○ 국민신문고 :www.epeople.gr.kr → 민원 16 아동학대 예방 교육 11 “아동은 한 인간으로서 고유한 존재이며, 스스로가 권리의 주체자임을 인식하고 적극 적인 참여를 통해 자신의 권리를 온전하게 보장받을 수 있어야 함” (UN아동권리협약) 아동 인권의 보장 22 22 아동의 4가지 권리 생 촌 권 아 동 이 생 명 을 유 지 하 고 건 강 하 게 자 랄 수 있 도록 + 동 미 재 능 과 능 력 을 펼 칠 수 있 도록 고 늘 이 와 여 가 를 즐 길 권 리 명 양 가 있 는 음 식 을 먹 고 깨 끗 하 고 안 전 한 환 경 메 서 = 보 호 받 으 며 아 플 때 치 료 받 을 수 있 는 권 리 = 보 호 권 마 동 의 몽 과 마 음 을 아 프 게 하 는 마 동 이 자 신과 관 련된 문 제에 관 하 여 모 든 해 로 운 것 으 로 부 터 보 호 받 을 권 리 의 견 을 말 하 고 참 여 할 권 리 33 아동학대의 개념 33 보호자를 포함한 성인이 아동의 건강 또는 복지를 해치거나 정상적 발달을 저해할 수 있는 신 체적, 정신적, 성적 폭력이나 가혹행위를 하는 것 아동의 보호자가 아동을 유기하거나 방임하는 것 ‘보호자’란 친권자, 후견인, 아동을 보호·양육·교육하거나 그러한 의무가 있는 자 또는 업 무· 고용 등의 관계로 사실상 아동을 보호·감독하는 자를 말함 ※「아동복지법」 제3조 44 44 아동학대 유형
# FAMILY_TREE: child
# 대답: 이 문서에는 부모 문서 검색기에 대한 설명이 없지만, 다음과 같은 질문을 만들어볼 수 있습니다.
#
# 질문1) 아동 문서를 작은 청크로 나누어 저장하고, 검색 시 청크 뿐만 아니라 청크가 속한 원본 문서 전체를 반환하는 검색 방식의 이름은 무엇일까요?
# 답변1) 부모 문서 검색기(ParentDocumentRetriever)
#
# 이유: 부모 문서 검색기는 문서를 작은 청크로 나누어 저장하지만, 검색할 때는 관련 청크뿐만 아니라 그 청크가 원래 속해있던 원본 문서 전체를 반환합니다. 이를 통해 청크의 의미를 보다 정확히 파악할 수 있습니다.
#
# 질문2) 부모 문서 검색기를 사용하면 어떤 이점이 있을까요?
# 답변2) 부모 문서 검색기를 사용하면 검색 결과의 의미를 보다 명확히 파악할 수 있고, 청크만으로는 파악하기 어려운 문맥 정보를 얻을 수 있습니다.
#
# 이 문서에는 부모 문서 검색기에 대한 직접적인 설명이 없지만, 이와 같은 질문을 통해 검색 방식의 특징과 장점을 이해할 수 있습니다.1
# DOC ID: 416162e3-b493-48d7-9276-b1d84e4c5fa1
# TEXT: . 특히 아동, 노인, 장애인 등의 보호시설이나 상담 소, 교육기관, 의료기관 종사자는 가정폭력 범죄를 알게 된 경우에 즉시 신고해야 할 법적 의무가 있습니다. a 44 44 가정폭력 발생시 대처법 | -경찰의 도움이 필요할 때 먼저 112에 신고 : 가정폭력 신고를 받고 경찰관이 출동하 면, 폭력 행위를 제지하고 피해자 동의 시 상담소·보호시설·의료기관 치료 연계 등이 이루어짐. ▻ 피해자 긴급구호 : 여성긴급전화 (☎ 1366), 가정폭력 상담·신고(☎ 117) ▻ 무료 법률지원 : 대한법률구조공단(☎ 132), 한국가정법률상담소(☎ 1644-7077) ▻ 피해치료 지원 : 지자체, 여성긴급전화1366센터, 보호시설, 상담소, 원스톱지원센터 등 - 28 - 가정폭력 발생시 대처법 55 -가정폭력 재발 우려 시 경찰관에게 긴급임시조치 및 임시조치 신청이 가능합니다. ► 긴급임시조치란? 가정폭력의 재발우려가 있고 긴급한 경우 경찰관에게 ① 주거 등에서 가해자 격리 ② 주거, 직 장에서 100m 내 접근금지 ③ 전화, 전자 우편 등 접근금지를 신청할 수 있습니다. ► 임시조치란? 가정폭력 재발 우려시 경찰 신청, 검사 청구에 의해 법원으로부터 ① 주거 등에서 가해자 격리 ② 주거, 직장에서 100m 내 접근금지 ③ 전화, 전자 우편 등 접근금지 ④ 의료기관에의 치료 위탁 ⑤ 유치장(또는 구치소) 유치 결정을 받을 수 있습니다. ※ 법원의 임시조치 결정(1호~3호)를 위반할 경우 500만원 이하의 과태료가 부과되거나 임시조치 5호 (유치장‧구치소 유치)가 결정될 수 있습니다. -가정폭력 재발 우려 시 형사절차와 별개로 피해자 또는 법정대리인이 직접 법원에 피 해자보호명령을 청구할 수 있습니다. 경찰 등 수사기관을 거치지 않고 피해자가 직접 가정법원에 ① 주거 등에서 가해자 격리 ② 주거, 직 장에서 100m 내 접근금지 ③ 전화, 전자 우편 등 접근금지 ④ 친권행사제한을 신청할 수 있습니다 ※ 가해자가 법원의 피해자보호명령을 위반할 경우 징역 또는 벌금이 부과될 수 있습니다
# FAMILY_TREE: child
# 1. 질문: 가정폭력 사건 발생 시 피해자가 직접 법원에 신청할 수 있는 보호명령에는 어떤 것들이 있나요?
# 답변: 가정폭력 재발 우려 시 피해자 또는 법정대리인이 직접 법원에 피해자보호명령을 청구할 수 있습니다. ① 주거 등에서 가해자 격리 ② 주거, 직장에서 100m 내 접근금지 ③ 전화, 전자우편 등 접근금지 ④ 친권행사제한을 신청할 수 있습니다.
#
# 이 문제는 문맥 내에서 피해자가 직접 법원에 신청할 수 있는 보호명령 유형들을 구체적으로 열거하고 있어 이를 질문과 답변으로 만들 수 있습니다.
#
# 2. 질문: 가정폭력 재발 우려 시 긴급임시조치와 임시조치의 차이점은 무엇인가요?
# 답변: 긴급임시조치는 가정폭력 재발 우려가 있고 긴급한 경우 경찰관에게 신청할 수 있는 것입니다. 임시조치는 가정폭력 재발 우려 시 경찰 신청 또는 검사 청구에 의해 법원으로부터 결정을 받는 것입니다.
#
# 이 문제는 긴급임시조치와 임시조치의 차이점을 묻고 있으며, 문맥에서 각각의 정의와 절차를 설명하고 있어 이를 대비하여 답변할 수 있습니다.
#
# 이렇게 문맥 내의 구체적인 정보를 활용하여 질문과 답변을 만들 수 있습니다. 부모 문서 검색기법은 긴 문서에서 작은 단위의 문맥을 검색한 뒤 그것의 원문을 제공함으로써 상세한 답변이 가능하도록 돕습니다.1
# DOC ID: 5d3e8349-d597-4316-b33e-ef32ca14d198
# TEXT: . -‘죽겠다’는 자녀의 말이 단순한 투정으로 느껴지더라도 자녀의 입장에서는 그 문제는 삶과 죽음의 문제일 수 있습니다. 자녀의 입장에 서서 진지하게 이해하고 고통을 나누려고 노력해야 합니다. “엄마(아빠)가 널 어떻게 도우면 좋을까?” “그런 일이 있어서 네가 죽고 싶은 생각까지 들었던 거구나. 그 일을 엄마(아빠)가 도와줄테니 함께 해결해 보자.” “내가 보기엔 네가 많이 힘들어하는 것 같은데, 함께 병원에 가보지 않을래?” 4) 자녀의 긍정적인 측면을 지지해 줍니다. “너는 이 어려움을 이겨낼 힘이 있어. 도와줄게” “네 생각보다 우리 가족은 너에게 관심을 갖고 있고 너에겐 친구들도 있잖아.” 5) 스트레스를 건강하게 해소하는 활동을 찾을 수 있도록 도와주세요. 아이가 하고 싶 어 하고 잘하는 활동을 독려하되 압력을 가하지 않는 것이 좋습니다. 6) 신속한 조치를 취합니다. -만일 어느 시점에서 자살을 감행하려는 전조나 불안한 기분을 느낀다면, 주저하지 말고 전문가의 도 움을 요청합니다. - 31 -
# FAMILY_TREE: child
# 제시된 맥락에서 검색 방법의 차이를 잘 설명할 수 있는 부분은 없습니다. 주어진 텍스트는 자녀의 자살 징후에 대한 대처법을 설명하고 있기 때문입니다.
#
# 그래서 주어진 설명을 바탕으로 ParentDocumentRetriever 방법에 대한 질문을 만들어 보겠습니다.
#
# 질문: 부모 문서 검색기(ParentDocumentRetriever)는 어떤 방식으로 작동합니까? 이 방법의 장단점은 무엇입니까?
#
# 답변: 부모 문서 검색기는 문서를 작은 청크로 나누어 저장하지만, 검색 시에는 해당 청크의 부모 문서 전체를 반환합니다. 이를 통해 청크의 의미를 정확히 파악할 수 있는 장점이 있지만, 전체 문서를 반환하므로 관련 없는 정보도 포함될 수 있는 단점이 있습니다. 따라서 적절한 문서 분할 크기를 설정하는 것이 중요합니다.
#
# 이 질문을 만든 이유는 ParentDocumentRetriever 방법의 작동 원리와 장단점을 이해하는 것이 중요하기 때문입니다. 이를 통해 데이터 전처리와 검색 전략을 효과적으로 설계할 수 있습니다.1
# DOC ID: 94b1b3c9-2bab-4977-903e-386e0835c76a
# TEXT: . <행동요령> ◦ 얇은 옷을 여러 벌 겹쳐 입기 ◦ 장갑을 끼고 손을 주머니에 넣지 않기 ◦ 평소보다 보폭을 10~20% 좁게 걷기 봄철 미세먼지 <행동요령> ◦ 매일 아침 기상상황 확인 ◦ 외출 시 마스크 착용, 외출 후 손과 얼굴 씻기 ◦ 충분한 수분 섭취 여름 및 가을 호우, 태풍 응급처치 <행동요령> ◦ 시설물 파손이나 누수 발견 시, 담당교직원에 연락 ◦ 집중호우 또는 태풍 등으로 인해 발생하는 고인 웅덩이, 낙하물 등에 유의 ◦ 걷는 중에는 스마트폰 사용 자제, 주변 경계 ※ 학교에서 쓰러져있거나, 크게 다친 사람을 발견했다면 즉시 119에 신고하고 담당교직원에게 반드시 연락 - 소정의 응급처치교육을 받아 응급처치가 가능하다면 아 래의 주의사항을 숙지하고 상황에 따라 조치하고, 그렇지 않다면 119 또는 학교 교직원의 도움을 받음 <응급처치 시 주의사항> ◦ 본인의 안전을 우선적으로 확보한다.(2차 피해, 상황에 대한 오해의 소지 등) ◦ 응급 상황일 때는 즉시 119에 연락한다. ◦ 함부로 물이나 음식물, 약을 먹이지 않는다. ◦ 환자에 대한 생사의 판정을 하지 않는다. ◦ 환자의 몸에서 나온 구토물이나 혈액 등이 자신의 몸에 닿지 않도록 주의한다. ◦ 환자를 안전한 지역으로 옮기되, 이로 인해 2차 손상이 우려될 경우에는 옮기지 않는다. ◦ 최종적으로는 전문 의료인의 처치에 맡긴다. P = m\b ※ 응급상황 발생 시 119 신고 방법 (환자의 상태가 위급할 때 즉시 119에 도움 요청) ◦전달 내용 : 사고 장소 (가능하다면 명확한 주소), 주요 건물, 사고 종류, 환자 상태, 부상자 수 등 통보(일반적으로 부상자 1명에 구급차 1명) ◦구급차 도착 전까지 전화로 응급처치 요령을 지도 받을 수 있음. ◦신고 후에는 구급차 도착 전까지 연락유지를 위해 다른 통화는 자제하고 먼저 전화를 끊지 않음. - 33 -
# FAMILY_TREE: child
# 응급처치에 대한 문단을 바탕으로 다음과 같은 질문을 만들 수 있습니다.
#
# 질문: 응급상황이 발생했을 때 환자에게 물이나 음식, 약을 먹이면 안 되는 이유는 무엇일까요?
# 답변: 함부로 물이나 음식물, 약을 먹이면 응급 상황에서 더 위험해질 수 있기 때문입니다. 전문 의료진의 판단 없이 이를 섭취하게 하면 오히려 해가 될 수 있습니다.
#
# 질문: 응급상황 시 환자의 생사 여부를 판단해서는 안 되는 이유는 무엇일까요?
# 답변: 비전문가가 생사 여부를 잘못 판단할 경우 소중한 생명을 구할 기회를 놓칠 수 있기 때문입니다. 전문 의료진에게 맡기는 것이 안전합니다.
#
# 이 문단에서는 응급상황 발생 시 올바른 대처 방법을 알려주고 있습니다. 따라서 이를 바탕으로 응급상황에서 주의해야 할 점들에 대한 질문을 만들 수 있습니다.1
# DOC ID: 819500c2-8681-4e89-9812-1c98cb5c6e4e
# TEXT: 37 - 23 공익제보자 보호 및 공익 신고 보상 안내 교감 김○식 1. 경기도교육청은 공익제보를 활성화하기 위해 비밀보장, 불이익 조치금지, 책임의 감면, 인사 조처 의 우선적 고려 등으로 공익제보자를 보호하고 있습니다. < 공익제보자 보호 및 공익 신고 보상 안내> 031-249-0999 / e-mail : hotline@goe.go.kr 경기도교육청 홈페이지 (http://www.goe.go.kr/) -> 부조리 신고 및 상담 > ○ 관계 법령: 「부패방지권익위법」 제64조 및 「공익신고자 보호법」 제12조 ○ 내용: 누구든지 신고자라는 사정을 알면서 그의 인적 사항이나 그가 신고자임을 미루어 알 수 있는 사실을 다른 사람에게 알려주거나 공개 또는 보도해서는 안 되며 이를 위반하였을 경우 형사처벌 대상이 됨. ○ 비밀보장 대상 및 벌칙 사항
# FAMILY_TREE: child
# 답변: 부모 문서 검색 방법은 문서를 작은 청크로 나누어 저장하지만, 검색 시에는 원본 문서 전체를 반환합니다. 이를 통해 의미 손실 없이 문맥을 유지할 수 있습니다.
#
# 예시 질문:
# 1) 문서를 청크로 나누는 이유는 무엇인가요?
# 답변: 작은 청크로 나누면 의미를 더 정확하게 반영할 수 있기 때문입니다.
#
# 2) 부모 문서 검색 방법은 청크와 원본 문서를 어떻게 활용하나요?
# 답변: 검색 시 작은 청크를 먼저 찾은 후, 그 청크가 속한 원본 문서 전체를 반환합니다.
#
# 3) 부모 문서 검색 방법의 장점은 무엇인가요?
# 답변: 작은 청크로 검색의 정확도를 높이면서도 원본 문서의 문맥을 유지할 수 있습니다.
#
# 이렇게 질문을 만들었습니다. 부모 문서 검색 방법의 핵심인 작은 청크와 원본 문서 활용 방식, 그 장단점을 중심으로 질문을 구성하였습니다.1
# batch 0 completed
# DOC ID: 73d6966a-8df6-4d89-8a91-798a5c1231a5
# TEXT: 청 렴 경 기 교 육 , 를 통 한 당 신 의 용 기 가 필 요 합 니 다 . 공 익 제 보 란 ? 2 e v 말 은 영 국 경 찰 관 이 호 루 라 기를 돋이 시민의 위 법 행 위 와 동 료 의 비 리 를 경 계 하 던 것 에 서 유 래 되 었 습 니 다 따 라 서 곡 익 제 보 재 빠 테 ㅎ 0는 공 익 을 위해 용 기 있 게 정 의 의 호 루 라 기를 부는 사 람 을 말 합 니 타 . 당 신 의 용 기 가 청 렴 한 경 기 교 육 을 만 들 수 있 습 니 다 . ‘ 누 구 든 지 신 고 할 수 있 습 니 다 . — 신 고 대상 공 익 침 해 행 위 《 경 기 도 교 육 청 공 익 제보 보 호 와 지 원 에 관 한 =2 제 2 조 ) 경 기 도 교 육 청 교 직 원 S ㅜ 『 공 역 신 고 자 보 호 법 」 에 따 른 공 익 침 해 행 위 — 『 부 패 방 지 권 익 위 법 」 에 따 른 부 패 행 위 — 『 경 기 도 교 육 청 공 무 원 행 동 강 령 」』 위 반 행 위 — 그 밖 의 경 기 도 교 육 청 의 청 렴 도 를 훼 손 하 는 행 위 | 4 ※ 『 부 패 밤 지 권 약 위 법 」 개 정 (20'7.4.58.) 으 로 사 립 학 교 교 직 원 및 학 교 법 인 임 직 원 의 부 패 행 위 도 보 호 - 보 상 제 도 적 용 대 상 에 포 함 공 익 제 보 는 이 렇 게 신 고 방 법 . 판 며 -6] - 전 화 031) 2490-999 ＊ 이 메 일 "007209@906.90. [ 경 기 도 교 육 청 홈 폐 이 지] = hito: /fwww.goe gokr 『 부 조 리 신 고 및 상 담 』 = 공 익 제 보 자 보 호 합 니 다
# FAMILY_TREE: child
# 문서를 보면 '공익제보'에 대한 설명과 신고 방법이 나와 있습니다. 이를 통해 부모 문서 검색 방법에 대한 질문을 만들 수 있습니다.
#
# 질문: 공익제보 때 제보자의 신분을 보호하기 위해서는 어떤 검색 방식이 적절할까요?
#
# 답변: 부모 문서 검색 방법이 적절할 것입니다. 이 방법은 작은 문서 조각들을 먼저 검색한 후, 그 조각들이 원래 어떤 부모 문서에서 왔는지를 찾아 전체 문서를 반환합니다. 이렇게 하면 제보 내용의 맥락을 유지하면서도 제보자의 신원을 가릴 수 있습니다.
#
# 이유: 공익제보 내용에는 민감한 개인정보나 기밀 사항이 포함될 수 있기 때문에, 작은 문서 조각만 보여주면 제보자의 신원을 노출하기 쉽습니다. 하지만 부모 문서 검색 방식을 사용하면 전체 문맥을 유지하면서도 제보자 신원은 가릴 수 있습니다.1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# DOC ID: cd1816a8-53b0-4b64-8ef4-6ee33b9d5e7a
# TEXT: 결 석 계 □ 예방접종확인서(증명서, 내역서) □ 의사소견서(진단서) □ 양성:의사소견서(PCR양성결과 통보 메시지 등)(5일 출석인정) □ 음성:검사 확인서(당일 1일 출석인정) □ 학 부 모 확 인 서 (월 1 일 출 석 인 정 ) 2. 질병 이외의 결석 또는 출석인정 결석인 경우 ① 1~2일: [경조사] 결석계와 담임교사확인서 + 청첩장·부고장(문자, 카톡 포함), 사망신고서 중 1부 [미인정 결석 및 기타 결석] 결석계와 담임교사확인서 ② 경조사로 인한 출석인정 결석 3일 이상: 결석계와 담임교사확인서 + 사망신고서(사본 가능) ③ 경조사 이외 출석인정 결석: 결석계와 담임교사확인서 + 증빙서류 ④ ‘①~③’ 에 해당되지 않는 결석 3일 이상: 결석계와 담임교사확인서 + 학부모확인서 ※ 학교장허가교외체험학습은 별도의 체험학습 신청서와 보고서 제출 ------------------------------------ 교사 작성 -------------------------------------- 담임교사 확인서 1. 해당 결석 및 사유 □ 질병 결석 □ 미인정 결석 □ 출석인정 결석 □ 기타 결석 사 유 2. 확인 방법 □하이톡 확인 □하이콜 확인 □가정방문 □학부형 내교 □기 타 ( ) 3. 비 고 : 202 년 월 일 담임교사 : (인) - 8 - □4 학생평가-학습으로의 평가 교사 우○주 1. 학습으로서의 평가의 특징 학습으로서의 평가는 학습 과정과 결과에 대해 학생 스스로 성찰하고, 자기 주도적인 학습 경험을 통해 학습 내용을 실생활 맥락의 문제 해결에 적용할 수 있는 역량을 키우는 평가 2. 방침 가. 학생의 삶과 연계한 교육과정, 수업, 평가의 운영으로 학생 개개인의 삶의 역량을 키운다. 나. 학생의 학습 수준을 확인하고 결과만이 아니라 결과에 이르기까지의 학습과정을 중시한다. 다. 학생의 학습 과정과 결과에 대한 맞춤형 피드백을 제공하여 학생의 학습을 지원한다. 라
# FAMILY_TREE: child
# 학생의 출석 인정 결석에 대한 제반 사항을 확인할 수 있는 문서이므로, 부모 문서 검색 방법에 대한 질문을 다음과 같이 만들 수 있습니다.
#
# 질문: 학생의 출결 관리를 위해 여러 서류를 제출해야 하는데, 이때 작은 문서 조각들을 먼저 검색한 뒤 원본 문서를 찾아볼 수 있는 부모 문서 검색 방법은 어떤 장점이 있을까요?
#
# 답변: 부모 문서 검색 방법은 작은 문서 조각들의 의미를 효과적으로 반영하면서도 전체 문맥을 유지할 수 있다는 장점이 있습니다. 처음에는 작은 문서 조각들을 검색하여 관련 정보를 빠르게 찾고, 이후 해당 조각들의 원본 문서를 찾아 전체 문맥을 파악할 수 있습니다. 이를 통해 문서의 의미 손실을 방지하면서도 검색 효율성을 높일 수 있습니다.
#
# 이유: 주어진 문서에는 학생의 출결 관리를 위해 제출해야 하는 여러 가지 서류에 대한 내용이 담겨 있습니다. 이러한 문서에서 특정 키워드나 조건에 맞는 부분만 먼저 검색한 후, 해당 부분의 원본 문서를 찾아보는 방식이 부모 문서 검색 방법입니다. 이 방법의 장점은 작은 문서 조각의 의미는 유지하면서도 전체 문맥을 파악할 수 있다는 것입니다.1
# DOC ID: 9a73a2cd-6023-49be-99ba-5d7a32acdf26
# TEXT: 나. 세부계획 Ÿ 교과별·학년별 교육과정과 평가 내용 일치 실천 Ÿ 선행교육 사전 예방을 위한 출제관리 및 자율점검 (학기별 1회) Ÿ 교원, 학부모 대상 선행교육 예방 관련 연수 및 홍보(연 1회) 다. 교육공동체의 책무 제5조(학교의 장의 책무) ② 학교의 장은 해당 학교에서 선행교육을 실시하지 아니하도록 지도・감독하여야 한다. . ③ 학교의 장은 학부모・학생・교원에게 선행교육 및 선행학습을 예방하기 위한 교육을 정기적으로 실시하여야 한다. ④ 학교의 장은 제3항의 내용을 포함한 선행교육 및 선행학습 예방에 관한 계획을 수립・시행하여 야 한다. 제5조의 2(교원의 책무) 교원은 학생의 학습권 보호를 위하여 학생의 선행학습을 전제로 수업을 하 여서는 아니 된다. - 10 - □6 학생 안전 교육 교사 김○희 □ 교육부 안전교육 7대 영역 표준안(나.침.반 안전교육실시)
# FAMILY_TREE: child
# 답변:
#
# 질문 1) 학교의 장이 선행교육 및 선행학습을 예방하기 위해 해야 할 책무는 무엇인가?
#
# "제5조(학교의 장의 책무) ② 학교의 장은 해당 학교에서 선행교육을 실시하지 아니하도록 지도・감독하여야 한다. ③ 학교의 장은 학부모・학생・교원에게 선행교육 및 선행학습을 예방하기 위한 교육을 정기적으로 실시하여야 한다. ④ 학교의 장은 제3항의 내용을 포함한 선행교육 및 선행학습 예방에 관한 계획을 수립・시행하여야 한다."
#
# 이 문단에서 학교의 장이 선행교육과 선행학습을 예방하기 위해 지도감독, 정기교육 실시, 예방계획 수립 및 시행 등의 책무를 명시하고 있기 때문에 이를 질문으로 만들었습니다.
#
# 질문 2) 교원의 선행학습 관련 책무는 무엇인가?
#
# "제5조의 2(교원의 책무) 교원은 학생의 학습권 보호를 위하여 학생의 선행학습을 전제로 수업을 하여서는 아니 된다."
#
# 이 문장에서 교원이 학생의 선행학습을 전제로 수업해서는 안 된다고 명시하고 있기 때문에 이를 질문으로 만들었습니다.
#
# 이렇게 본문의 핵심 내용을 반영한 질문을 만들면 retrieval method의 성능을 평가하는 데 도움이 될 것입니다.1
# batch 0 completed
# DOC ID: beb98327-bae2-4343-a847-6cabe9b463ce
# TEXT: . 3. 불조심 예방 가. 화재 발생 시 대피요령 1) 낮은 자세로 기어서 피난해야 합니다. 2) 수건이나 휴지 등으로 코와 입을 막고 열과 연기로부터 멀리 떨어져야 합니다. 나. 피난을 위한 복도, 계단에 적치된 물건은 없나요? 복도, 계단 등은 화재 발생 등 유사시 피난 통로로 사용됩니다. 계단에 문을 설치하거나 물건을 적치 하는 행위는 피난 시 장애가 되어 인명피해가 발생할 수 있습니다. 다. 가정에서 알아야 하는 상식 1) 가정과 차량에는 소화기가 비치되어 있나요? 2) 화재 발생 등 유사시 피난 대피로는 알고 있나요? 피난 장소는 있나요? 3) 1회 누전차단기의 시험 스위치를 눌러보는 것으로도 전기화재는 예방됩니다. 4) 가스레인지 밸브와 중간밸브는 사용 후 항상 잠그고, 월 1회 누설여부를 확인하세요. ▶ 작은 관심과 노력! 화재로부터 생명과 재산을 지킵니다. 화재 신고는 전국 국번 없이 119 - 12 -
# FAMILY_TREE: child
# 답변: 화재 발생 시 대피 요령과 관련된 문장을 활용해 질문을 만들 수 있습니다.
#
# 질문: 화재 발생 시 연기로부터 안전하게 대피하려면 어떻게 해야 합니까?
# 답변: 낮은 자세로 기어서 피난해야 하며, 수건이나 휴지 등으로 코와 입을 막고 열과 연기로부터 멀리 떨어져야 합니다.
#
# 이 질문은 문서 내에서 화재 대피 방법에 대한 구체적인 지침을 제공하고 있기 때문에, 부모 문서 검색 방식을 통해 답변할 수 있습니다. 작은 문서 조각만으로는 대피 요령을 완전히 파악하기 어렵지만, 부모 문서를 활용하면 상세한 설명을 확인할 수 있습니다.1
# DOC ID: 9f5e31cf-1763-4318-b9ed-d8d7d1dca973
# TEXT: . ② 아는 사람이라도 원하지 않는 신체 접촉을 하면 참고 있지 말고 단호하게 “싫다!”는 의사 표현을 하며 즉시 자리를 피하도록 알려줍니다. 신체 접촉 전 상대의 의사를 항상 먼저 물어보도록 알려줍 면 이 가 니다. 상대가 대답하지 않으면 yes라고 생각하는 경우 때문에 사안이 발생하는 경우가 많습니다. 무 다 . - 13 - 가 니 다 . 응답은 yes가 아니라 NO일 수 있습니다. ③ 호의를 베푼다고 모르는 사람을 따라가거나, 아는 사람이라도 가족이 아닌 경우 단 둘이 집에 있게 하거나 차를 타지 않도록 알려줍니다. 에 려 주 고 를 해 일 이 ④ 평소 성 지식에 대해 자연스럽게 알려주고 무엇이 성폭력인지 정확히 알게 해주십시오. @ ⑤ 평소 자녀와 충분한 대화를 통해 무슨 일이든지 부모님께 말할 수 있게 해주십시오. ⑥ 휴대폰 채팅 어플 사용자제: 청소년 대상으로 하는 휴대폰 채팅 어플의 종류가 많습니다. 실제로 청 소년에게 성범죄 등의 영향을 미치는 경우가 있으니 채팅 어플 사용 자제를 권유합니다 7. 성교육에 임하는 부모님의 자세 ① 자연스러운 대화의 분위기를 만들어 성교육을 합니다. ② 정확한 성지식을 알고 있어야 잘 지도하므로 부모님들도 올바른 성에 대해 공부해야 합니다. ③ 부부간에 존중하고 사랑하는 모습을 자녀 앞에서 자연스럽게 표현하도록 합니다. ④ 질문에 답할 때는 당황하거나 회피하지 말고 불충분한 대답이라도 좋으나 거짓말은 하지 말아야 합니다. - 성에 관한 설명은 구체적, 직접적으로 표현해야 합니다. 그 질문을 왜 했는지 알아보세요. ⑤ 성교육은 과학적인 면과 사회적, 윤리적인 면을 병행하여 가르쳐야 합니다. ⑥ 부모가 해결하기 어려운 문제는 전문교사나 상담기관을 찾습니다. 8
# FAMILY_TREE: child
# 질문: 부모-자식 간 성에 대한 올바른 대화와 교육의 중요성에 대한 문단을 골라 그 이유를 설명하고 관련 질문을 만들어 보세요.
#
# 대답: 아래 문단이 부모-자식 간 성교육의 중요성을 잘 나타내고 있습니다.
#
# "⑦ 질문에 답할 때는 당황하거나 회피하지 말고 불충분한 대답이라도 좋으나 거짓말은 하지 말아야 합니다. 성에 관한 설명은 구체적, 직접적으로 표현해야 합니다. 그 질문을 왜 했는지 알아보세요."
#
# 이 문단은 자녀의 성 관련 질문에 대해 솔직하고 구체적으로 답해야 함을 강조하고 있습니다. 자녀의 궁금증을 외면하거나 거짓으로 일관하면 오히려 더 큰 혼란을 줄 수 있기 때문입니다.
#
# 관련 질문:
# 1) 자녀가 성에 대해 물었을 때 어떻게 대답해야 할까요?
# 2) 자녀의 성 질문에 당황하거나 회피하는 것이 왜 좋지 않을까요?
# 3) 자녀에게 성에 대해 구체적으로 설명하는 것이 왜 중요할까요?1
# DOC ID: d209808b-5fcf-4af9-964e-bab04efdf8e1
# TEXT: . - 14 - □8 흡연 및 음주 예방 교육 보건교사 김○혜 1. 학생 흡연의 피해 일산화탄소 영향으로 두뇌 활동이 저하되고, 학습능력이 떨어집니다. 성인에 비해 폐 용적이 작아 담배연기로 인한 피해가 더 크고, 폐 성숙에 장애를 가져옵니다. 성장기는 세포분열이 왕성하게 일어나는 시기이므로 흡연으로 인해 세포의 성장이 방해받을 수 있습니다. 어릴 때부터 시작하는 경우는 니코틴 중독이 더 심해 금연하는 것이 더욱 힘들어집니다. 15세 이전 흡연은 25세 이후 흡연자보다 폐암 등 흡연으로 인한 사망률이 2~3배 더 높습니다. 어린 시기의 흡연은 유전자변형을 일으켜 2세에게 나쁜 유전자를 전달합니다. 2. 어린이 간접흡연의 피해 성장에 영향을 미쳐 키가 잘 자라지 않습니다. 켓 > g ¥ Cale) P moo oz 겐스 랜에흐넨짐짝쁘 기를 1차 흡연 흡연자 본인의 피해 ▪ 백내장, 치매, 뇌졸중, 류마티스 관절염, 췌장염 ▪ 폐암, 유방암, 신장암, 고혈압, 고지혈증, 심장병 ▪ 우울증, 만성스트레스, 정자 손상 등 초래 2차 흡연 비흡연자의 간접흡연 피해 ▪ 우울증, 당뇨병, 고혈압, 동맥 손상 ▪ 성대 손상, 유방암 등 3차 흡연 옷․ 벽면에 붙은 연기로 인한 피해 ▪ 실내 유해물질과 결합 - 발암 물질 생성 ▪ 어린이, 유아, 태아에게 피해 집중 ▪ 니코틴 중독, 태아 폐 발달 저해, 천식 등 급성 호흡기 질환 감염률이 5.7배 높습니다. 폐암에 걸릴 가능성이 2배 높아집니다. 천식, 중이염, 폐렴에 걸릴 확률이 6배 높습니다. 뇌세포 파괴로 기억력, 학습 능력이 떨어집니다. 장기적으로 청력이 떨어집니다. 3. 알코올의 작용 뇌기능을 억제시켜 대담하고 편안한 느낌으로 기분을 좋게 합니다. 구강점막, 식도, 위로 흡수되어 혈액으로 들어가 각 장기와 조직에 머물면서 해를 줍니다. 우리 몸 세포의 산소 신진대사와 영양물질의 흡수를 방해하여 영양장애를 <) 초래합니다. 꿈꾸는 시간을 감소시켜 숙면을 방해하고 수면장애를 일으킵니다
# FAMILY_TREE: child
# 이 문서에는 청소년 흡연과 음주의 피해에 대한 내용이 포함되어 있습니다. 부모 문서 검색 방법에 대한 질문을 만들기에는 적절한 컨텍스트가 아닙니다. 대신 다음과 같은 질문을 제안할 수 있습니다.
#
# 질문: 흡연이 청소년에게 미치는 직접적인 피해는 무엇입니까?
# 답변: 1) 학습능력 저하, 2) 폐 성장 장애 및 폐암 위험 증가, 3) 니코틴 중독으로 금연 어려움 등이 있습니다.
#
# 질문: 간접흡연으로 인해 어린이가 겪을 수 있는 피해는 무엇입니까?
# 답변: 1) 성장 지연, 2) 급성 호흡기 질환 감염률 증가, 3) 뇌세포 파괴로 기억력, 학습능력 저하 등입니다.
#
# 이렇게 문서에 제시된 구체적인 내용을 활용하여 질문과 답변을 만들 수 있습니다.1
# DOC ID: a7438856-8c35-452b-b60a-33e2b908294e
# TEXT: . 천식, 중이염, 폐렴에 걸릴 확률이 6배 높습니다. 뇌세포 파괴로 기억력, 학습 능력이 떨어집니다. 장기적으로 청력이 떨어집니다. 3. 알코올의 작용 뇌기능을 억제시켜 대담하고 편안한 느낌으로 기분을 좋게 합니다. 구강점막, 식도, 위로 흡수되어 혈액으로 들어가 각 장기와 조직에 머물면서 해를 줍니다. 우리 몸 세포의 산소 신진대사와 영양물질의 흡수를 방해하여 영양장애를 <) 초래합니다. 꿈꾸는 시간을 감소시켜 숙면을 방해하고 수면장애를 일으킵니다. 알코올은 내성이 있어 마실수록 주량이 점점 증가하고 안마시면 금단 증상이 나타납니다. 4. 음주의 신체적 피해 가. 알코올성 치매 과음하거나 장기간 남용 또는 과용하면 뇌세포 파괴를 촉진시켜 '뇌의 영양실조'를 일으킵니다. 노 인성 치매와 비슷하게 심한 기억상실 증세를 보이는데 바로 전날에 한 일에 대한 기억이 없을 만 큼 기억력이 현저히 떨어집니다. 알코올성 치매는 감정을 조절하는 전두엽 쪽에서 먼저 시작되기 때문에 감정 조절이 어렵습니다. 흔히 충동적이며 화를 잘 내고 폭력적이 되는 경향을 보입니다. 니.。:†이 i 30 e ey 3
# FAMILY_TREE: child
# 알코올성 치매에 대한 질문을 만들어 보겠습니다.
#
# 1. 질문: 알코올이 뇌에 미치는 영향으로 인한 피해 중 하나는 무엇인가?
# 답변: 알코올은 뇌세포를 파괴하여 기억력과 학습능력이 저하되는 '알코올성 치매'를 유발할 수 있습니다.
#
# 이 질문과 답변은 "뇌세포 파괴로 기억력, 학습 능력이 떨어집니다."라는 문장에서 알코올이 뇌 기능에 미치는 영향을 언급하고 있기 때문에 출제했습니다.
#
# 2. 질문: 알코올성 치매 환자들에게서 나타나는 특징적인 증상은 무엇인가?
# 답변: 알코올성 치매 환자들은 심한 기억상실 증세를 보이며, 전날 일에 대한 기억이 전혀 없을 정도로 기억력이 현저히 떨어집니다. 또한 감정 조절 장애로 인해 충동적이고 화를 잘 내며 폭력적인 경향이 있습니다.
#
# 이 질문과 답변은 "노인성 치매와 비슷하게 심한 기억상실 증세를 보이는데 바로 전날에 한 일에 대한 기억이 없을 만큼 기억력이 현저히 떨어집니다. 알코올성 치매는 감정을 조절하는 전두엽 쪽에서 먼저 시작되기 때문에 감정 조절이 어렵습니다. 흔히 충동적이며 화를 잘 내고 폭력적이 되는 경향을 보입니다."라는 문장에서 알코올성 치매 환자의 특징적인 증상을 설명하고 있기 때문에 출제했습니다.1
# DOC ID: 5f32d463-e647-4e92-b5af-16ebd27aa1b0
# TEXT: .privacy.go.kr)에 개인정보파일등록 (파일명에 따른 보유건수, 보유기관, 담당자 등) ❍ 개인정보 수집이용 및 제3자 정보제공 동의서 발송 및 수합 - 대상: 전교생 - 일시: 3월 초 ❍ 정보보안과 개인정보보호 교직원 연수 실시 - 일시 : 4월 - 연수 내용: 개인정보 보호 및 정보보안 - 교육 방법 : 비대면 시청각 자료 및 쌍방향 프로그램 이용 ❍ 주요 정보통신 시설 관리 - 학내망 장비 및 서버 관리실 통제구역 설정 - 시스템 및 장비별 관리 책임자 지정, 시스템의 주기적 점검 - 무선통신 보안 관리(업무용 pc에서 무선 접속장치 사용금지) ❍ 기타 - 외부용역업체 보안관리 - 학교홈페이지 개인정보 처리방침 내용 수정 관리 (개인정보 책임자 또는 담당자가 변경되었을 경우이거나 개인정보 파일명과 보유기간 등의 변경 사 항을 최대한 빠른 기간에 반영) 4) 기대 효과 ❍ 정보보안 활동으로 각종 정보보안 사고를 예방하고, 사이버 공격 대응태세 갖추기 ❍ 개인정보가 분실, 도난, 누출, 변조, 훼손, 남용되지 않도록 노력하는 학교문화 만들기 - 23 - 15 불법찬조금 근절을 위한 학부모 연수 교감 김○식 Ⅰ 불법찬조금 처분 기준 불법찬조금 관련 처분기준(2020. 3. 1. 시행) 처분기준 금액
# FAMILY_TREE: child
# 답변: 주어진 문서에서 검색 방법의 차이를 잘 보여줄 수 있는 부분을 찾기 어렵습니다. 그래서 다음과 같은 질문을 만들었습니다.
#
# 질문: 개인정보 보호와 관련된 학교의 주요 활동은 무엇인가요?
#
# 답변: 문서에서 개인정보 보호와 관련된 학교의 주요 활동으로 다음과 같은 것들을 찾을 수 있습니다.
# - 개인정보파일등록(개인정보 보유건수, 보유기관, 담당자 등)
# - 개인정보 수집이용 및 제3자 정보제공 동의서 발송 및 수합
# - 정보보안과 개인정보보호 교직원 연수 실시
# - 정보통신 시설 및 장비 보안 관리
# - 학교홈페이지 개인정보 처리방침 내용 수정 관리
#
# 이 질문은 문서 전체를 살펴보고 개인정보 보호와 관련된 내용을 찾아 답변할 수 있습니다.1
# batch 0 completed
# DOC ID: 9ab7a71d-6154-4628-b011-5c48bb709736
# TEXT: . -가정폭력 재발 우려 시 형사절차와 별개로 피해자 또는 법정대리인이 직접 법원에 피 해자보호명령을 청구할 수 있습니다. 경찰 등 수사기관을 거치지 않고 피해자가 직접 가정법원에 ① 주거 등에서 가해자 격리 ② 주거, 직 장에서 100m 내 접근금지 ③ 전화, 전자 우편 등 접근금지 ④ 친권행사제한을 신청할 수 있습니다 ※ 가해자가 법원의 피해자보호명령을 위반할 경우 징역 또는 벌금이 부과될 수 있습니다. -가정폭력으로부터 보호 가능한 지원제도 : 보호시설(쉼터)입소지원, 무료 법류지원(대 한법률구조공단(☎132), 한국가정법률상담소(☎1644-7077), 의료지원, 아동 취학지원 , 주민등록 열람제한, 주거지원 a_pw&a 66 66 가정폭력 대처법 아동기의 중요성 인식 - 아동기의 가정폭력·아동학대는 아동에게 심각한 스트레스를 주는 사건 으로서 아동의 건강, 발달, 복지에 심각한 영향을 줍니다. 특히 가정폭력 및 아동학대는 세대 간 전이가 될 수 있습니다. 연령 별 아동 특성 이해 - 자녀가 가진 능력이나 발달 이상으로 부모의 기대 수준에 맞게 행동해 주기를 원하는데 이처럼 높은 기대는 아동학대의 가능성을 높이는 원인이 되기도 합니다. 이에 다 양한 아동 발달에 대한 지식을 습득하도록 노력하여야 합니다. 올바른 자녀양육방법 습득 - 아동을 소유물로 생각하지 않고 아동의 권리를 존중하여 체벌과 훈 육을 혼동하지 않도록 해야 합니다. 부모의 스트레스 관리 - 부모들은 자신의 욕구가 충족되지 못하거나 스트레스를 받을 때 아동에 게 그 불만을 터뜨리게 되는 경우가 발생할 수 있으므로 적절하게 정서적 욕구불만을 해소할 수 있는 방법을 찾아봅니다. - 29 -
# FAMILY_TREE: child
# 답변: 가정폭력 피해자가 직접 법원에 피해자보호명령을 청구할 수 있다는 내용에서 부모문서 검색기법과 관련된 질문을 만들 수 있습니다.
#
# 질문: 가정폭력 피해자가 경찰이나 수사기관을 거치지 않고 직접 법원에 신청할 수 있는 조치에는 어떤 것들이 있나요?
#
# 답변: 주거 등에서 가해자 격리, 주거나 직장에서 100m 이내 접근금지, 전화나 전자우편 등으로의 접근금지, 친권 행사 제한 등을 신청할 수 있습니다.
#
# 이 질문을 만든 이유는 부모문서에 상세한 내용이 포함되어 있어 작은 단위로 분할된 데이터만 가지고는 충분한 답변을 하기 어렵기 때문입니다. 부모문서 검색 기법을 활용하면 전체 문서 맥락을 보존하면서도 검색 성능은 유지할 수 있습니다.1
# DOC ID: d6353b7c-bc6d-4512-a09f-6d303661794a
# TEXT: .2%)이 가장 높습니다.(최근 사이버폭력 비율 증가) 가정, 학교에서의 언어순화교육에 힘써야 합니다. ➠ 따뜻한 격려와 칭찬으로 학생의 자존감을 키워줍니다. ➠ ‘몰라서, 장난으로, 욱해서’ 괴롭혀도 폭력임을 가르칩니다. ➠ 사소한 괴롭힘, 장난이라고 여기는 행위도 학교폭력이 될 수 있음을 분명하게 가르쳐야 합니다. ➠ 쌍방사안 주의 : 폭력에 대해 폭력으로 대응하면 자신도 피해자이자 가해자가 되므로 상황을 피 하고 부모님이나 선생님께 도움을 청하도록 가르칩니다. ➠ 학생, 학부모, 교사 모든 공동체의 관심과 노력이 있을 때 예방할 수 있습니다. - 34 - 교 폭 력 정 학교폭력 사안처리 과정 안내(상세) □ 학교폭력 사안처리의 과정 사 전 예 방 생 활 지도 ( 상 시 ) ( 상 시 ) * 예 방 교 육 * 갈 등 조 정 - 학 업 및 진 로 - 보 건 및 안전 * 상 담 / 순 찰 - 위 0\/62) 클 래스 - 교 내 지도 - 교 외 지도 학 교 폭 력 접 수 및 초 기 사 실 확 인 * 접 수 / 초 기 대 응 - 신 고 - 접 수 대 장 기록 - 피 해 가 해 학 생 상 태 확 인 - 최 초 학 생 작 성 확 인 서 접 수 - 접 수 보 고 서 작 성 - 학 교 장 부 고 - 보 추 자 및 해 당 학 교 통 보 분 리 / 긴 급 조 치 ( 필 요 시 ) - 피 해 - 가 해 학 생 분 리 - 피 해 학 생 긴 급 조 치 - 가 해 학 생 긴 급 조 치 교 육 ( 지 원 ) 청 보 고 ( 사 안 접 수 보 고 서 ) - 신 고 개 요 - 피 가 해 학 생 상 태 - 분 리 및 긴 급 조 치 여 부 학 교 폭 력 제 로 센 터 조 사 관 배 정 * 학 교 방 문 - 피 - 가 해 학 생 및 학 부 모 면 담 - 추 가 학 생 작 성 * 접 수 내 용 분 석 보 고 5 - 학 셈 의 연 령 등 * 조 사 관 배 정 - 학 교 방 문 일 확 인 - 배 정 적 합성 검 토 떠 학 년
# FAMILY_TREE: child
# 문맥 안에는 학교폭력 사건 처리 절차에 대한 자세한 설명이 있습니다. 이를 통해 부모 문서 검색 방법의 차이점을 잘 드러낼 수 있는 질문을 만들 수 있습니다.
#
# 질문: 학교폭력 사건이 발생했을 때, 문서에 제시된 절차에 따르면 초기 대응 단계에서 어떤 조치를 취해야 합니까?
#
# 답변: 초기 대응 단계에서는 신고 접수, 피해·가해 학생 상태 확인, 최초 학생 작성 확인서 접수, 접수 보고서 작성, 학교장 보고, 보호자 및 해당 학교 통보를 해야 합니다. 또한 필요할 경우 피해 학생과 가해 학생을 분리하고 긴급 조치를 취해야 합니다.
#
# 이 질문을 통해 작은 단위의 문서 조각만으로는 전체 절차를 이해하기 어렵지만, 부모 문서를 검색하면 초기 대응에 대한 전체 맥락을 파악할 수 있음을 보여줄 수 있습니다.1
# DOC ID: 7528f946-f2ab-4019-844a-228665810258
# ...
# FAMILY_TREE: child
# 문서에 나오는 "나. 지방간, 간염, 간경화, 간암"과 "다. 위염, 위궤양" 문단을 활용하여 다음과 같은 질문을 만들 수 있습니다.
#
# 질문: 술이 우리 몸에 미치는 해로운 영향은 무엇입니까?
# 답변: 술은 간과 신장을 손상시키고, 소화기관의 점막에 손상을 가해 염증과 궤양을 일으킬 수 있습니다.
#
# 이 질문과 답변을 만든 이유는 부모 문서 검색기가 문서를 작은 단위로 나누어 저장하고, 검색 시 이를 결합하여 원래의 문서 형태로 제시하기 때문입니다. 작은 문단들을 보고 술이 신체에 미치는 영향을 추론할 수 있으므로, 부모 문서 검색 방식의 특징을 잘 보여줄 수 있습니다.1
# DOC ID: b79560b9-05af-4746-983a-962676ef0d48
# TEXT: 3. 교권 침해 그 이후 모습
# FAMILY_TREE: child
# 답변: 제시된 문맥에서 '교권 침해'에 관련된 이야기가 나오므로, 이를 바탕으로 부모 문서 검색 방식에 대한 질문을 만들 수 있습니다.
#
# 예시 질문: 교사의 교권이 침해되었을 때, 관련 사건을 제대로 파악하기 위해서는 어떤 문서 검색 방식이 가장 적절할까요?
#
# 답변: 부모 문서 검색 방식이 가장 적절할 것입니다. 왜냐하면 이 방식은 작은 문서 조각들을 먼저 검색한 뒤, 그 조각들이 원래 속해 있던 보다 큰 문서(부모 문서)를 찾아 전체 맥락을 파악할 수 있기 때문입니다. 교권 침해 사건을 제대로 이해하려면 해당 문서 조각뿐만 아니라 주변 상황까지 알아야 하므로 부모 문서를 함께 참고할 필요가 있습니다.
#
# 이 질문을 만든 이유는 주어진 문맥이 교권 침해에 관한 내용이었기 때문입니다. 교권 침해 사건을 이해하려면 전후 맥락을 잡는 것이 중요합니다. 부모 문서 검색이 이러한 요구사항을 잘 만족시킬 수 있어 적절한 질문이 되었습니다.1
# DOC ID: f2eb4fd2-9dcb-4daf-9134-4f80e916a5d7
# TEXT: 방 4. 예방 ☞ 교권 보호가 곧 학생의 학습권 보장임 모 두 의 권 권 생 중 요 ☞ 학생과 학부모 교사 모두 교원의 교권 및 학생 인권 상호 존중 필요 17 - 10 방과후학교 운영 교사 전○연 1. 목적 ㅎ © 어린이들의 소질, 적성, 창의력을 계발하고 취미, 특기신장 교육기회 제공 학교 밖의 과외 욕구를 학교 안으로 흡수하여 사교육비 절감 학교 시설 및 지역사회 인적자원의 활용을 극대화하여 다양한 학습기회 제공 2. 상록 방과후 학교 운영 상황 황 특기적성 운영 프로그램
# FAMILY_TREE: child
# 질문: 부모 문서 검색 방식의 장점은 무엇입니까?
#
# 답변: 부모 문서 검색 방식의 장점은 작은 문서 조각들의 의미를 효과적으로 유지하면서도 더 큰 문맥도 고려할 수 있다는 것입니다. 작은 문서 조각만 사용하면 문맥 정보가 부족해질 수 있고, 너무 큰 문서를 사용하면 의미가 모호해질 수 있습니다. 부모 문서 검색 방식은 이 둘의 균형을 잡아주어 효과적인 정보 검색이 가능합니다.
#
# 이유: 주어진 상황에서 부모 문서 검색 방식은 작은 문서 조각과 큰 문서(부모 문서)의 장점을 모두 활용할 수 있어 효과적입니다. 문서의 길이에 따른 문제점을 해결하면서 전체 문맥도 고려할 수 있기 때문입니다.1
# DOC ID: 4c2d0891-9640-4a87-b6ac-4d299776b9d3
# TEXT: 18 - 3.운영계획 가. 운영 기간 2024년 3월 11일 ~ 2024년 12월 23일
# FAMILY_TREE: child
# 답변: "18 - 3.운영계획 가. 운영 기간 2024년 3월 11일 ~ 2024년 12월 23일"라는 문맥에서, 부모 문서 검색 방법의 차이를 보여줄 수 있는 질문은 다음과 같습니다.
#
# 질문: 2024년 운영 기간 중 특정 날짜의 운영 계획을 찾으려면 어떤 검색 방법이 가장 적절할까요?
#
# 이유: 주어진 문맥은 2024년의 운영 기간만을 명시하고 있습니다. 따라서 특정 날짜의 운영 계획을 찾기 위해서는 전체 문서에서 관련 내용을 추출할 수 있는 부모 문서 검색 방법이 효과적일 것입니다. 부모 문서를 통해 전체 맥락을 파악하고 원하는 날짜의 운영 계획을 찾을 수 있기 때문입니다.1
# DOC ID: d8e98dec-fb02-455f-b2b6-126236913b41
# TEXT: . 부 천 나. 세부 실천 내용 용
# FAMILY_TREE: child
# 답변: 해당 컨텍스트에는 검색 방법에 대한 정보가 포함되어 있지 않기 때문에 관련 질문을 만들기 어렵습니다. 제공된 정보가 매우 적고 단순한 문장만 있기 때문입니다. 하지만 parent document 검색 방식의 특징을 잘 설명할 수 있는 질문 한 가지를 만들어 보겠습니다.
#
# 질문: 문서를 작은 청크로 나누면서도 전체 문맥을 유지하는 검색 방법은 무엇인가요?
#
# 이유: Parent document 검색 방식은 먼저 작은 청크로 문서를 분할하여 저장하지만, 실제 검색 시에는 해당 청크의 원본 문서 전체를 반환합니다. 이를 통해 작은 청크의 장점과 전체 문맥 유지의 장점을 모두 취할 수 있습니다.1
# batch 0 completed
# DOC ID: 1e43ac44-7aae-436e-95a9-952380de4aa2
# TEXT: 20 - 12 학부모 서비스 신청 안내 교사 사○○원 1. 학 부 모 서 비 스 및 나 이 스 플 러 스 학교생활 정보를 인터넷이나 모바일로 편리하게 확인할 수 있는 서비스입니다. 기존 학부 모 서비스가 4세대 나이스 전환과 함께 학부모 서비스 및 나이스플러스로 일부 변경되었습 니다. 학부모 서비스는 초등학교 입학할 때부터 고등학교 졸업할 때까지 체계적으로 사용할 수 있습니다. 본교는 학부모서비스에서 제공하는 방과후학교 프로그램 신청, 교외체험학습 신청의 기능을 사용하지 않음을 공지드립니다.
# FAMILY_TREE: child
# 답변: 주어진 문맥에는 부모 문서 검색 방식을 설명하는 내용이 없습니다. 그러나 이 방식의 핵심 개념인 작은 문서 청크와 원본 부모 문서의 관계를 묻는 질문을 만들 수 있습니다.
#
# 예시 질문: 학부모 서비스에서 제공하는 정보는 어떤 방식으로 저장되고 제공될까요? 작은 문서 청크로 분할되어 저장되고, 필요할 때 원본 부모 문서의 정보를 함께 제공하는 방식일까요?
#
# 이 질문은 부모 문서 검색 방식의 핵심인 작은 문서 청크와 원본 문서의 관계를 질문하고 있습니다. 학습자가 이 방식의 개념을 이해했는지 확인할 수 있습니다.1
# DOC ID: 039158c6-0d6a-420c-9b02-31655be639f8
# TEXT: 금 액 비위유형 찬조금 찬조금 - 24 - 2 불법찬조금 관련 처분기준 적용원칙(2014.09.01.시행) ⎆ 모금·조성단계에서의 처분기준 금액은 “연간 모금액”누계, 집행단계에서의 처분기준 금액은 “연 간 집행액” 누계를 적용 ⎆ 찬조금 모금·조성단계와 집행단계 중에서 처분은 높은 양정을 적용 ⎆ “모금강요”행위에 있어서 “직접개입”은 Œ 학부모들을 대상으로 학교 교직원이 불법찬조금 모금 또는 납부를 직접 요구한 경우, 가정통신문이나 인터넷홈페이지 등을 통하여 학교에서 직접 금액 을 할당한 경우, Ž 고액의 기금 납부자의 자녀에게 포상 등 혜택을 주거나 기금을 납부하지 않는 학생에게 불이익을 주는 경우, 학교 교직원이 불법찬조금을 직접 관리하거나 관련 장부 등을 관리하는 경우 등이며, ⎆ “간접개입”은 Œ 특정 학부모 등을 통하여 모금·할당을 조장 또는 지시·요청하는 경우, 학교와 관련된 금원사용을 위하여 불법모금하는 과정을 사전에 인지하고도 이을 방관 또는 묵인한 경우 등이며, ⎆ “모금을 인지하지 못한 경우”는 학교 교직원이 모금과정을 전혀 모르고 금원을 제공받은 경우에 해당함 ⇦ 찬조금을 집행했을 경우에만 해당됨 ⎆ 불법찬조금관련 처분기준은 문책순위 1순위자에 해당하며, 문책순위는 “공무원 징계령 시행규칙” 을 적용 ⎆ 불법찬조금 관련 징계는 감경배제 ⎆ 학교운동부의 경우 불법찬조금이란 학교운동부 학부모(개인, 단체)가 교육활동 지원 목적으로 당초 학교운영위원회 심의를 거쳐 학교발전기금회계(또는 학교회계)에 편입 사용하기로 결정한 금품을 학교운동부 학부모(개인, 단체)가 결정을 따르지 않고, 교육활동 지원 목적으로 임의로 모금(또는 할당을 통하여 모금)·사용하는 경우에는‘불법찬조금관련 처분기준’을 적용하지 않음 불법찬조금 신고 채널 운영 활성화 [불법찬조금 신고처] ○ 경기도교육청 : www.goe.go.kr → 전자민원 → 신고 센터 → 공익제보센터→불법찬조금 신고 - 전 화 : 경기도교육청 감사관 031) 820-0852 ○ 안산교육지원청 : www.goeas
# FAMILY_TREE: child
# 1. 질문: 불법찬조금 모금단계와 집행단계에서 처분기준은 어떻게 다르게 적용되나요?
# 답변: 모금·조성단계에서의 처분기준 금액은 "연간 모금액" 누계를, 집행단계에서의 처분기준 금액은 "연간 집행액" 누계를 적용합니다. 또한 모금단계와 집행단계 중에서 더 높은 처분기준을 적용합니다.
#
# 이유: 문맥에서 "모금·조성단계에서의 처분기준 금액은 '연간 모금액'누계, 집행단계에서의 처분기준 금액은 '연간 집행액' 누계를 적용"과 "찬조금 모금·조성단계와 집행단계 중에서 처분은 높은 양정을 적용"이라고 설명하고 있기 때문입니다.
#
# 2. 질문: 불법찬조금 관련 '직접 개입'의 사례에는 어떤 것이 있나요?
# 답변: '직접 개입'의 사례로는 1) 교직원이 학부모에게 직접 불법찬조금 모금이나 납부를 요구한 경우, 2) 학교에서 직접 금액을 할당한 경우, 3) 고액 기부자 자녀에게 혜택을 주거나 비기부 학생에게 불이익을 준 경우, 4) 교직원이 직접 불법찬조금을 관리하거나 관련 장부를 관리한 경우 등이 있습니다.
#
# 이유: 문맥에서 이러한 행위들을 '직접 개입'의 예로 들고 있기 때문입니다.1
# DOC ID: 2445b728-fa7f-4c1f-a8ef-6ec4b8050ace
# TEXT: .4.58.) 으 로 사 립 학 교 교 직 원 및 학 교 법 인 임 직 원 의 부 패 행 위 도 보 호 - 보 상 제 도 적 용 대 상 에 포 함 공 익 제 보 는 이 렇 게 신 고 방 법 . 판 며 -6] - 전 화 031) 2490-999 ＊ 이 메 일 "007209@906.90. [ 경 기 도 교 육 청 홈 폐 이 지] = hito: /fwww.goe gokr 『 부 조 리 신 고 및 상 담 』 = 공 익 제 보 자 보 호 합 니 다 . 오 — 제 보 자 등에 대 한 보 호 < 경 기 도 교 육 청 공 익 제보 보 호 와 지 뭔 에 관 한 조 례 제 !2 조 ) ㅡ 비 밀 보 장 및 불 이 역 조 치 금 지 - 제 보 와 관 련 한 위 법 행 위 발 견 시 제 보 쟈 에 대 한 책 임 감 면 가 능 — 인 사 조 치 의 우 선 적 고 려 | 4 — 제 보 자 에 대 한 보 상 기 준 ( 지 급 한 도 액 최 대 30 억 원 ) ( 경 기 도 교 육 청 공 익 신 고 보 상 금 지 급 에 관 한 조 례 제 !2 조 } 지 급 기 준 맥 수 수 액 의 106 미 내 추 장 액 또 는 환 수 액 의 20% 미 내 신 고 유 형 28 수 수 W 향 응 을 제 공 받 는 행 위 부 당 한 미 득 을 연 거 나 경 개 도 교 육 청 재 줘 에 츠 시 을 끼 치 는 행 위 대 가 수 수 액 의 10 빼 미 내 공 정 한 직 무 수 행 을 방 해 하 는 갈 선 ㆍ 청 틱 행 위 @ - 정 탁 행 위 신 고 300 만 원 이 내 부 조 리 근 절 을 죄 기 적 므 로 기며 부 조 리 =308 기며 ＊ 신 고 기 한 : 부 조 리 행 위 발 생 일 부 터 3 년 ( 횡 령 - 유 용 은 5 년 》 ! 고 자 의 신 청에 따 라 경 기 도 교 육 청 공 익 신 고 보 상 금 지 급 심 의 위 원 회 에 서 의 결 하 여 최 종 결 정 된 금 액 을 지 급 %’ =4 ?’7/.12,? 2wl 필램륭몰 훼 슨 한 행 위 공 직 비 리 신 고 아 -2) hotine@goe
# FAMILY_TREE: child
# 문맥에서 발견할 수 있는 적절한 질문과 답변은 다음과 같습니다.
#
# 질문: 부모 문서 검색 방법에서 '부모 문서'는 무엇을 의미합니까?
# 답변: 부모 문서는 작은 문서 조각이 원래 속해 있던 전체 문서 또는 더 큰 문서 조각을 말합니다. 문서를 작은 조각으로 나누어 저장하지만, 검색 시에는 해당 조각의 부모 문서까지 함께 반환하는 방식입니다. 이렇게 함으로써 문서 조각 자체의 의미는 유지하면서도 전체 문맥을 이해할 수 있게 됩니다.
#
# 질문: 부모 문서 검색 방법의 장점은 무엇입니까?
# 답변: 문서를 작은 조각으로 나누어 저장함으로써 각 조각의 의미를 정확히 반영할 수 있고, 동시에 부모 문서까지 반환받아 전체 문맥을 파악할 수 있습니다. 이를 통해 작은 문서 조각이기에 의미 손실 우려는 줄이면서도 충분한 문맥 정보를 제공할 수 있습니다.
#
# 이런 질문들을 만든 이유는 문서 검색 방식의 핵심 아이디어와 장단점을 잘 이해할 수 있도록 하기 위함입니다. 부모 문서 개념과 이를 활용하는 장점을 직접적으로 물어봄으로써 해당 검색 방식에 대한 이해도를 높일 수 있습니다.1
# DOC ID: 28a025d0-79d8-4bb6-9ed8-c75889ec37a3
# TEXT: 3. 주요 사례 o 공익의 목적이 아닌 개인적인 불만 사항에 대하여 본인이 원하는 대로 들어주지 않았다고 악의적으로 반복적 민원을 제기하는 등의 행위 o 민원 제기 시 직원들에게 고성이나 반말, 화풀이하는 식의 행위 o 정당한 훈육에 대해 무조건 항의 및 질책하는 행위 o 사적 심부름을 시키는 행위 o 강압적인 말투로 상대의 자존감을 떨어뜨리는 행위 - 39 - 25 교육활동보호 예방 교육 교사 나○철 2024년 달라지는 점 1. 교육지원청 교권보호위원회 설치 ⇒ 교권보호위원회 전문성·객관성 강화 2. 학부모의 교육활동 침해행위에 대한 조치 부과 ⇒ 학부모에 의한 부당한 간섭 억제 Ⅰ. 교육활동 보호의 필요 1. 교육활동보호는 교원의 수업권과 학생의 인권을 보장함으로써 교원·학생·학부모 모두가 행복한 학교 만들기의 밑거름이 됩니다. 가. 학생의 학습권 보호 슬 4 블 블 심 블 밤 블 빌 암 블 U u 질 이 유 지 되 고 학 생 들 의 학 습 효 과 를 기 대 할 수 있 습 니 다 . 교 육 활 동 보 호 의 주 목 적 은 안 정 적 교 원 이 안 심 하 고 교 육 활 동 에 집 중 할 때 수 업 의 인 수 업과 학 습 권 의 보 장 입 니 다 . 나. 배움과 실천의 인성교육: 인성교육은 학습한 내용을 일상생활에서 내면화·인격화하는 과정이 연계 되어야 합니다. 교원은 제자를 사랑하고 학생은 스승을 존경하는 문화는 학생의 올바른 인격 성장에 중요한 배경이 됩니다. 다. 행복한 학교문화 조성: 선생님이 행복하면 학생이 행복합니다. 교원의 교육활동이 위축되지 않고 학생지도에 매진할 때 학생의 전인적 성장과 안정된 학교생활을 기대할 수 있습니다. Ⅱ. 교육활동 침해행위의 이해 1. 교육활동 침해행위란? 소속 학교의 학생 또는 그 보호자 등이 교육활동 중인 교원에 대하여 다음 각 호의 어느 하나에 해당하는 행위를 하는 것 항 [교원지위법 제19조 제1항] 1. 다음 각 목의 어느 하나에 해당하는 범죄 행위 가
# FAMILY_TREE: child
# 제시된 문서에는 검색 방법에 대한 설명이 없으므로, 이를 잘 보여줄 수 있는 질문을 만들기 어렵습니다. 그러나 주어진 문서의 내용을 바탕으로 다음과 같은 질문을 생성할 수 있습니다.
#
# 질문: 교육활동 중 교원에 대한 침해행위의 예시로는 어떤 것들이 있나요?
# 답변: 교원에 대한 침해행위의 예시로는 "공익의 목적이 아닌 개인적인 불만 사항에 대하여 본인이 원하는 대로 들어주지 않았다고 악의적으로 반복적 민원을 제기하는 행위", "민원 제기 시 직원들에게 고성이나 반말, 화풀이하는 식의 행위", "정당한 훈육에 대해 무조건 항의 및 질책하는 행위" 등이 있습니다.
#
# 질문: 교육활동 보호의 필요성에는 어떤 것들이 있나요?
# 답변: 교육활동 보호의 필요성으로는 "학생의 학습권 보호", "배움과 실천의 인성교육", "행복한 학교문화 조성" 등이 있습니다.
#
# 이러한 질문들은 주어진 문서의 내용을 잘 반영하고 있으며, 독자들이 문서의 핵심 내용을 이해하는 데 도움이 될 것입니다.1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# 1
# 1
# 1
# 1
# 1
# batch 0 completed
# DOC ID: acdff8f2-f598-4035-bca6-f67a2bf69145
# TEXT: 11. 소통하는 133. 생명존중교육 ◦자살예방교육 및 예방활동 실시 ◦교과 및 창체 연계 생명존중교육, 환경지킴 연중 1~6학년 생활인권 이 교육 실시 - 2 - 록(綠) 2. 몸과 마음이 건강하고 예술을 향유하는 문화적인 어린이
# FAMILY_TREE: child
# 답변: 제시된 문맥에서는 다양한 검색 방법들 중 '부모 문서 검색기'에 대한 예시를 잘 보여줄 수 있는 내용이 없습니다. 주어진 문맥은 교육 활동에 관한 내용으로, 검색 방법의 차이를 설명하기에 적절하지 않습니다.
#
# 대신 다음과 같은 질문을 만들 수 있습니다:
#
# 질문: 문서를 작은 단위로 나누어 검색할 때, 문맥을 유지하면서도 정확성을 높이기 위해서는 어떤 방식을 사용하는 것이 좋을까요?
#
# 답변: 부모 문서 검색기를 사용하는 것이 좋습니다. 이 방식은 먼저 작은 단위로 문서를 나누어 검색한 다음, 그 작은 단위들이 원래 어떤 부모 문서에서 나왔는지를 추적하여 부모 문서 전체를 반환합니다. 이렇게 하면 작은 단위로 검색하여 정확성을 높이면서도, 원래 문서의 전체 문맥을 유지할 수 있습니다.
#
# 이 질문을 통해 부모 문서 검색기의 장점인 정확성과 문맥 유지 능력을 잘 설명할 수 있습니다.1
# DOC ID: 98c4adc1-774c-4d1e-a377-a688aa7cf46e
# TEXT: 233. 절약교실 실시 ◦학용품 아껴쓰기 ◦에너지 절약 교육 ◦쓰레기 감량 및 분리배출 교육 연중 전교생 생활인권 - 3 - 수(秀) 3. 특기와 소질을 가꾸어 미래를 준비하는 창의적인 어린이
# FAMILY_TREE: child
# 질문: 학교에서는 학생들의 절약 교육을 위해 어떤 활동을 하고 있나요?
#
# 답변: 233번 문단에 따르면, 학교에서는 학용품 아껴쓰기, 에너지 절약 교육, 쓰레기 감량 및 분리배출 교육을 통해 학생들이 절약 습관을 기르도록 지도하고 있습니다.
#
# 이유: 주어진 문맥 중 "절약교실 실시 ◦학용품 아껴쓰기 ◦에너지 절약 교육 ◦쓰레기 감량 및 분리배출 교육"이라는 구절이 학교에서 실시하는 절약 교육 내용을 잘 보여주고 있기 때문입니다.
#
# 질문: 학교에서는 학생들의 미래를 위해 어떤 교육을 하고 있나요?
#
# 답변: 233번 문단의 마지막 부분에 "특기와 소질을 가꾸어 미래를 준비하는 창의적인 어린이"라고 언급되어 있습니다. 이를 통해 학교에서는 학생들의 특기와 소질을 계발하여 미래를 대비할 수 있도록 창의성 교육을 하고 있음을 알 수 있습니다.
#
# 이유: 문맥 중 "특기와 소질을 가꾸어 미래를 준비하는 창의적인 어린이"라는 구절이 학교에서 실시하는 창의성 교육의 목적을 잘 드러내고 있기 때문입니다.1
# DOC ID: 923be7f5-9eb3-4ce9-9813-3c85501dbe11
# TEXT: 0 14 11.04.∼11.08. 3 9 0 15 11.11.∼11.15. 10 11 12 13 14 15 16 0 16 11.18.∼11.22. 17 18 19 20 21 22 23 17 11.25.∼11.29. 24 25 26 27 28 29 30 0 18 12.02.∼12.06. 2 0 5 19 12.09.∼12.13. 9 10 11 12 13 14 0 20 12.16.∼12.20. 15 16 17 18 19 20 21 0 21 12.23.∼12.27. 22 23 0 7 2 학 기 합 계 3 1 학 기 합 계 0 총 계 12.3.(화 )장 애 이 해 교 육 12.5.(목 ) 2025년 1학 기 전 교 임 원 선 거 12.23.(월) 종업식(1~5학년 2교시) 졸업식(6학년 4교시) (급 식 미 실 시 ) 1 1 1 90 78 79 2 5 100 100 100 0 10 10 1 | ㅣ | 기 | 기 | | 간 ｜ | ｜ 1학기 2학기 합 계 100일 90일 190일 연 간 수 업 일 수 | 겨 울 방 학 석면 제거 공사 기간 2024. 12. 24.(화)~2025. 03. 03(월) 70일 2024. 12. 24.(화)~2025. 03. 03.(월) 70일 - 6 - □3 출결 관련 확인 제출자료 안내
# FAMILY_TREE: child
# 질문: "24 25 26 27 28 29 30 0 18 12.02.∼12.06. 2 0 5 19 12.09.∼12.13." 이 문장에서, 작은 청크들과 그것들의 원본 문서가 모두 나타납니다. 이것이 부모 문서 검색 방법의 핵심인 이유는 무엇입니까?
#
# 답변: 이 문장은 부모 문서 검색 방법의 특징을 잘 보여줍니다. 작은 청크들("24 25 26 27 28 29 30", "0 18 12.02.∼12.06.", "2 0 5 19 12.09.∼12.13.")이 먼저 검색되고, 그 다음에 원본 문서의 컨텍스트("12.02.∼12.06.", "12.09.∼12.13.")가 함께 제공됩니다. 이렇게 함으로써 작은 청크의 정확성과 원본 문서의 컨텍스트를 모두 활용할 수 있습니다.
#
# 질문: 다음 문장도 부모 문서 검색 방법을 설명하는 예시가 될 수 있습니까? "0 14 11.04.∼11.08. 3 9 0 15 11.11.∼11.15. 10 11 12 13 14 15 16" 그렇다면 어떤 측면에서 그렇습니까?
#
# 답변: 네, 그 문장도 부모 문서 검색 방법의 예시가 될 수 있습니다. 작은 청크들("0 14", "3 9", "10 11 12 13 14 15 16")과 그것들의 원본 문서 컨텍스트("11.04.∼11.08.", "11.11.∼11.15.")가 함께 나타나기 때문입니다. 이를 통해 청크의 정확성과 원본 문맥을 모두 살릴 수 있습니다.1
# DOC ID: d9e72b88-6816-4a6c-a67b-18f35613b167
# TEXT: . / 관 비 화 트다 / . 토 sewn s 형 , 참 여 형 , 소 비 형 이 있 음 . 안 전 하 고 자 유 로 운 세 상 을 위해 우 리 가 할 수 있 는 것 들 0 2} 8 사 이버 공 간 에 서는 다 른 사 람 의 개 인 정 보 나 타 인이 나 오 는 ㅣ PUBIOME | |ceame Ay ｜ e 나 의 개 인 정 보 를 보 내 거 나 허 락 없 이 게 시 하 거 나 |\ 밝 메 랄 트 . / 관 비 화 트다 / . 토 sewn s 디지터 서버시 = OH™ 디 지 털 장 비 , 정 보 통 신 망 올 매 개 로 제삭 배포 유 통 되 는 형 식 의 범 죄 구 체 적 으 로는 Ol LTI 4891 9 SR 몰 래 카 메 라 제 작 물 _ “ 58 사 이 버 공 간 에 서 불 특 정 다 수 에 전 달 하 는 행 위 로 03 R 형 , 참 여 형 , 소 비 형 이 있 음 .
# FAMILY_TREE: child
# 답변: 문서에서 "토서재" 유형의 범죄를 설명하는 부분을 보면 제작형, 참여형, 소비형이 있다고 언급되어 있습니다. 이를 바탕으로 다음과 같은 문제를 출제할 수 있습니다.
#
# 질문: 사이버 공간에서의 불법 콘텐츠 유통 행위는 어떤 유형으로 나뉠 수 있는가?
# 답변: 제작형, 참여형, 소비형
#
# 이유: 문서에서 직접적으로 세 가지 유형을 언급하고 있기 때문에, 이를 활용하여 불법 콘텐츠 유통 행위의 유형을 묻는 문제를 만들 수 있습니다. 제시된 맥락 정보를 바탕으로 하여 적절한 문제와 답변을 구성할 수 있습니다.1
# DOC ID: d171e3da-d009-41b3-be8a-a2f24d8bf741
# TEXT: 9. 청소년 인터넷 음란물 중독 예방 청소년 인터넷 음란물 중독 예방 음란물은 매우 선정적이고 자극적이기 때문에 특히 청소년기에 이런 음란물에 빠지게 되면 점점 더 현실과 환상을 혼돈하게 되고 자신도 모르게 점점 빠져들게 되면서 무감각해집니다. 우리 아이들이 음란 물에 물들어 되돌릴 수 없는 행동을 하게 되지 않도록 가정에서 음란물에 대한 적극적인 관리가 필요합 니다. • 컴퓨터에 저장돼 있는 음란물을 모두 삭제하고 유해차단 프로그램을 설치합니다. - 그린 I-Net www.greeninet.or.kr 에서 무료로 다운 받아 사용가능 • 공부방에 컴퓨터가 있다면 거실로 컴퓨터를 옮기세요. • 하루 중 컴퓨터를 켜고 끄는 시간을 일정하게 정하고 꼭 지키세요. 음란물을 보는 아이들 ‘판별법’ • 인터넷에 접속하는 시간이 갑자기 많아지거나 한밤중에 잠을 자지 않고 인터넷을 하는 경우가 잦다. • 컴퓨터에 수록된 파일 가운데 확장자가 ‘GIF'나 ’JPG' 등으로 끝나는 그래픽 파일이 많다. • 신용카드 청구서에 알지 못하는 내용과 금액이 청구된다. - 청구업체의 이름이 명시되어 있지 않고 ‘web.site' 등으로만 적혀 있는 경우 (음란물업체들은 회사명을 명확히 표시하지 않음) • 방으로 들어가면 순간적으로 컴퓨터를 끄거나 화면을 바꾸는 등 당황해 한다. ○ 아이가 음란물을 보고 있는 걸 알았을 때는? 음란물은 우연히 접하지만 다음부터는 의도적으로 찾게 되는 것이 문제입니다. 하지만 청소년기의 자연 스러운 모습으로 받아들이고, 다그치기보다는 열린 마음으로 자녀들과 자연스럽게 대화하며 음란물이 왜 나쁜지 서로 이야기하는 것이 좋습니다. - 14 - □8 흡연 및 음주 예방 교육 보건교사 김○혜 1. 학생 흡연의 피해 일산화탄소 영향으로 두뇌 활동이 저하되고, 학습능력이 떨어집니다. 성인에 비해 폐 용적이 작아 담배연기로 인한 피해가 더 크고, 폐 성숙에 장애를 가져옵니다. 성장기는 세포분열이 왕성하게 일어나는 시기이므로 흡연으로 인해 세포의 성장이 방해받을 수 있습니다
# FAMILY_TREE: child
# 부모 문서 검색기법에 대한 예시 질문입니다.
#
# 질문: 청소년이 인터넷 음란물에 중독되는 것을 예방하기 위해 부모가 취할 수 있는 조치로 적절한 것은 무엇인가?
#
# 답변: "• 컴퓨터에 저장돼 있는 음란물을 모두 삭제하고 유해차단 프로그램을 설치합니다. - 그린 I-Net www.greeninet.or.kr 에서 무료로 다운 받아 사용가능
# • 공부방에 컴퓨터가 있다면 거실로 컴퓨터를 옮기세요.
# • 하루 중 컴퓨터를 켜고 끄는 시간을 일정하게 정하고 꼭 지키세요."
#
# 이 질문은 주어진 문맥에서 청소년 인터넷 음란물 중독 예방을 위한 구체적인 대책들을 제시하고 있기 때문에, 관련 내용을 잘 검색할 수 있습니다.
#
# 질문: 청소년이 인터넷 음란물에 중독되었는지 판별하는 방법은 무엇인가?
#
# 답변: "• 인터넷에 접속하는 시간이 갑자기 많아지거나 한밤중에 잠을 자지 않고 인터넷을 하는 경우가 잦다.
# • 컴퓨터에 수록된 파일 가운데 확장자가 'GIF'나 'JPG' 등으로 끝나는 그래픽 파일이 많다.
# • 신용카드 청구서에 알지 못하는 내용과 금액이 청구된다.
# • 방으로 들어가면 순간적으로 컴퓨터를 끄거나 화면을 바꾸는 등 당황해 한다."
#
# 이 질문 역시 문맥 내에서 청소년의 인터넷 음란물 중독 여부를 판별할 수 있는 방법들을 구체적으로 제시하고 있어 관련 내용을 쉽게 찾을 수 있습니다.1
# batch 0 completed
# DOC ID: 62fe9c77-77ea-4906-bdaf-9a3763f8ebb4
# TEXT: 학생 포상, 징계, 징계 외의 지도방법, 두발, 복장 등 용모, 교육 목적상 필요한 소지품 학교 규칙 ※ 상록초 학교생활인권규정 : 학교홈페이지→공지사항→학교생활인권규정 참고 6. 인권 친화적 학교문화를 위해서 학생 인권과 교권은 함께 만들어지는 것이며, 인권의 시작은 상대방에 대한 배려 인권친화적 학교 문화의 시작은 학생과 교사가 서로에 대한 이해와 존중을 바탕으로 이루어짐을 인식 - 16 - 교권보호 「교원의 지위 향상 및 교육활동 보호를 위한 특별법」 일부개정(2019.4.16., 공포) ▸ 법률지원단의 구성 및 운영, 교육활동 침해행위 정의 등 시행령 일부 내용이 법률로 상향됨 ▸ 교육활동 침해행위자 수사기관 고발, 피해교원 보호조치 비용 관할청 先 부담 後 구상권 행사, 과태료 부과 내용이 신설 ▸ 교원의 교육활동 침해 학생에 대한 조치로 특별교육 이수 및 심리치료 외 학교봉사, 사회봉사, 출석정지, 학급교체, 전학, 퇴학처분이 추가된 내용 등을 규정한 「교원의 지위 향상 및 교육활동 보호를 위한 특별법 시행령」 일부개정령(대통령령 제30119호)이 공포·시행되었습니다. 1. 학부모에 의한 교권 침해의 유형
# FAMILY_TREE: child
# 문맥에서 적절한 예시를 찾기는 어려우나, 학생 징계와 교권 보호에 관한 내용이 있어 이를 활용해 질문을 만들어 보겠습니다.
#
# 문맥 중 "교원의 지위 향상 및 교육활동 보호를 위한 특별법 시행령이 공포·시행되었습니다."라는 내용을 바탕으로 다음 질문을 만들 수 있습니다:
#
# 질문: 교원의 교육활동을 보호하기 위해 새로 시행된 법령은 무엇인가?
# 답변: 교원의 지위 향상 및 교육활동 보호를 위한 특별법 시행령
#
# 이 질문은 문맥 내에서 직접적으로 답변을 찾을 수 있으므로 parent document 검색 방식에 적합합니다.
#
# 한편 "학생에 대한 조치로 특별교육 이수 및 심리치료 외에 학교봉사, 사회봉사, 출석정지, 학급교체, 전학, 퇴학처분이 추가된 내용"이라는 문구를 활용하여 다음 질문을 만들 수 있습니다:
#
# 질문: 교원의 교육활동 침해 학생에 대한 새로운 조치에는 어떤 것들이 있는가?
# 답변: 특별교육 이수, 심리치료, 학교봉사, 사회봉사, 출석정지, 학급교체, 전학, 퇴학처분
#
# 이 질문에 답하기 위해서는 문맥 전반을 이해하고 관련 정보를 통합해야 하므로, 문맥 전체를 parent document로 검색하는 방식이 적합할 것입니다.1
# DOC ID: efb4784a-1024-4e91-bf19-47a8bad2524a
# TEXT: 2. 교육활동 침해행위에 대한 조치
# FAMILY_TREE: child
# 답변:
#
# 질문: 부모 문서 검색기는 어떤 경우에 유용할까요?
# 답변: 문서의 일부분만 관련이 있는 경우에 부모 문서 검색기가 유용합니다. 작은 단위로 문서를 나누어 저장하고 검색에서 관련 있는 부분만 찾아낸 뒤, 해당 부분이 속한 원본 문서 전체를 반환하기 때문입니다. 이렇게 하면 문맥을 유지하면서도 불필요한 정보는 제외할 수 있습니다.
#
# 이유: 주어진 문맥에는 부모 문서 검색기에 대한 설명이 포함되어 있습니다. 부모 문서 검색기가 작은 단위로 문서를 나누어 저장하고, 검색 시에는 관련 있는 부분의 원문 전체를 반환한다고 설명하고 있습니다. 이를 통해 관련 문맥을 유지하면서도 불필요한 정보는 제외할 수 있다는 장점을 알 수 있습니다.1
# DOC ID: b18a4a61-9b66-4b1b-abe5-a6cf658cb76c
# TEXT: 4. 방과후학교 공개 - 1학기: 5.13(월)~ 17(금) 방과후 학교 공개수업 - 2학기: 11.11(월)~ 15(금) 상록문화예술의 날 기간(전시회) 예정 - 추후 학교 사정에 의해 변경될 수 있음. - 19 - 11 2023 초등돌봄교실 운영 (오후돌봄) 담당 김○영 1.「초등돌봄교실」이란? 1.1.1.1.1.1.1.「「「「「「「초등돌봄교실 초등돌봄교실」」」」」」」이란이란이란이란이란이란이란??????? 초등돌봄교실 초등돌봄교실 초등돌봄교실 초등돌봄교실 초등돌봄교실 「초등돌봄교실」이란, 초등학교에서 방과후 돌봄이 필요한 1~2학년 학생들을 대상으로 운영하는 프로그 램을 말합니다. ※ 기구축 되어 운영되고 있는 초등돌봄교실에서 1~2학년 저소득층, 한부모, 맞벌이, 조손가정 자녀 등 돌 봄이 필요한 학생 중심으로 운영 2. 추진 목적 가. 맞벌이와 저소득층 ․ 한부모 ․ 조손 가정 등 취약계층 자녀를 위한 돌봄 서비스 나. 여성의 사회진출을 위한 돌봄․교육 지원으로 여성 인력 활용 극대화 다. 돌봄 서비스 제공으로 학부모의 사교육비 부담 경감 3. 본교 돌봄교실 운영 현황 가. 오후돌봄: 3학급 운영 (돌봄1반, 2반, 3반) 나. 돌봄교실 운영 세부내역
# FAMILY_TREE: child
# 제시된 문서에는 retrieval method와 관련된 내용이 없습니다. 그러나 문서 내용을 바탕으로 다음과 같은 질문과 답변을 만들 수 있습니다.
#
# 질문: 초등돌봄교실은 어떤 프로그램인가요?
# 답변: 초등돌봄교실은 초등학교에서 방과후 돌봄이 필요한 1~2학년 학생들을 대상으로 운영하는 프로그램입니다.
#
# 질문: 초등돌봄교실
