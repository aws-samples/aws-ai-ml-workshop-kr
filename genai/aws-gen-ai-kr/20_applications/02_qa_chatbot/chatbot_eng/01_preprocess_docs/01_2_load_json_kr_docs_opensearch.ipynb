# %% [markdown]
# # 한글 문서를 위한 스키마 정의 후 Vector Store 생성
#
# 이 노트북은 오픈 서치 인덱스를 정의하고, 한글 전체 문서를 청킹하여 인덱스를 생성을 하는 노트북 입니다. 이후에 렉시컬, 시멘틱, 하이브리드 검색을 통하여 인덱스의 동작을 확인 합니다.
# 이후에 전체 문서의 일부를 검증 인덱스로 생성하여, 검증용으로 사용을 합니다.
#
#
# ---

# %% [markdown]
# ## [중요] 사전 실행 노트북
# 이 노트북은 아래 두개의 셋업 노트북이 먼저 실행이 되어야 합니다.
# - (1) Setup 노트북
#     - 경로는 aws-ai-ml-workshop-kr/genai/aws-gen-ai-kr/00_setup/setup.ipynb 와 같습니다.
#     -  [Setup Notebook](https://github.com/aws-samples/aws-ai-ml-workshop-kr/blob/master/genai/aws-gen-ai-kr/00_setup/setup.ipynb)
# - (2) Amazon OpenSearch 설치 노트북
#     - 경로는 aws-ai-ml-workshop-kr/genai/aws-gen-ai-kr/00_setup/setup_opensearch.ipynb 와 같습니다.
#     - [Setup OpenSearch](https://github.com/aws-samples/aws-ai-ml-workshop-kr/blob/master/genai/aws-gen-ai-kr/00_setup/setup_opensearch.ipynb)

# %% [markdown]
# # 0. Setting

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
def add_python_path(module_path):
    if os.path.abspath(module_path) not in sys.path:
        sys.path.append(os.path.abspath(module_path))
        print(f"python path: {os.path.abspath(module_path)} is added")
    else:
        print(f"python path: {os.path.abspath(module_path)} already exists")
    print("sys.path: ", sys.path)

module_path = ".."
add_python_path(module_path)
# Out:
# python path: /home/sagemaker-user/aws-ai-ml-workshop-kr/genai/aws-gen-ai-kr/20_applications/02_qa_chatbot is added
# sys.path:  ['/home/sagemaker-user/aws-ai-ml-workshop-kr/genai/aws-gen-ai-kr/20_applications/02_qa_chatbot/01_preprocess_docs', '/opt/conda/lib/python310.zip', '/opt/conda/lib/python3.10', '/opt/conda/lib/python3.10/lib-dynload', '', '/opt/conda/lib/python3.10/site-packages', '/home/sagemaker-user/aws-ai-ml-workshop-kr/genai/aws-gen-ai-kr/20_applications/02_qa_chatbot']

# %% [markdown]
# # 1. Bedrock Client 생성

# %%
import json
import boto3
from pprint import pprint
from termcolor import colored
from local_utils import bedrock, print_ww
from local_utils.bedrock import bedrock_info

# ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----

# os.environ["AWS_DEFAULT_REGION"] = "<REGION_NAME>"  # E.g. "us-east-1"
# os.environ["AWS_PROFILE"] = "<YOUR_PROFILE>"
# os.environ["BEDROCK_ASSUME_ROLE"] = "<YOUR_ROLE_ARN>"  # E.g. "arn:aws:..."
# os.environ["BEDROCK_ENDPOINT_URL"] = "<YOUR_ENDPOINT_URL>"  # E.g. "https://..."


boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    endpoint_url=os.environ.get("BEDROCK_ENDPOINT_URL", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
)

print(colored("\n== FM lists ==", "green"))
pprint(bedrock_info.get_list_fm_models())
# Out:
# Create new client
#   Using region: us-east-1
#   Using profile: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
#
# == FM lists ==
# {'Claude-Instant-V1': 'anthropic.claude-instant-v1',
#  'Claude-V1': 'anthropic.claude-v1',
#  'Claude-V2': 'anthropic.claude-v2',
#  'Claude-V2-1': 'anthropic.claude-v2:1',
#  'Cohere-Embeddings-En': 'cohere.embed-english-v3',
#  'Cohere-Embeddings-Multilingual': 'cohere.embed-multilingual-v3',
#  'Command': 'cohere.command-text-v14',
#  'Command-Light': 'cohere.command-light-text-v14',
#  'Jurassic-2-Mid': 'ai21.j2-mid-v1',
#  'Jurassic-2-Ultra': 'ai21.j2-ultra-v1',
#  'Llama2-13b-Chat': 'meta.llama2-13b-chat-v1',
#  'Titan-Embeddings-G1': 'amazon.titan-embed-text-v1',
#  'Titan-Text-G1': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Light': 'amazon.titan-text-lite-v1'}

# %% [markdown]
# # 2. Titan Embedding 모델 로딩

# %%
# We will be using the Titan Embeddings Model to generate our Embeddings.
from langchain.embeddings import BedrockEmbeddings

llm_emb = BedrockEmbeddings(
    client=boto3_bedrock,
    model_id=bedrock_info.get_model_id(
        model_name="Titan-Embeddings-G1"
    )
)
print("Bedrock Embeddings Model Loaded")
# Out:
# Bedrock Embeddings Model Loaded

# %% [markdown]
# # 3. Load all Json files

# %%
import glob
from local_utils.proc_docs import get_load_json, show_doc_json

# %%
# Specify the directory and file pattern for .txt files
folder_path = 'data/poc/preprocessed_json/*data_ko.json'

# List all .txt files in the specified folder
json_files = glob.glob(folder_path)
# json_files = ['data/poc/customer_EFOTA.json']

# Load each item per json file and append to a list
doc_json_list = []
for file_path in json_files:
    print (json_files)
    doc_json = get_load_json(file_path)
    doc_json_list.append(doc_json)

print("all json files: ", len(doc_json_list))    
# Flatten the list of lists into a single list
all_docs = []
for item in doc_json_list:
    all_docs.extend(item)
        
print("all items: ", len(all_docs))
# Out:
# ['data/poc/preprocessed_json/all_processed_data_ko.json']
# .[]
# all json files:  1
# all items:  1732

# %%
all_docs[0:2]
# Out:
# [Document(page_content='사용 방법 동영상.Knox E-FOTA를 사용하는 방법에 대한 비디오가 포함되어 있습니다.이 섹션에는 Knox E-FOTA를 사용하는 방법에 대한 비디오가 포함되어 있습니다.Knox E-FOTA 시작하기 이 동영상은 Knox E-FOTA 콘솔을 안내하며 리셀러 등록, 디바이스 승인, 캠페인 생성, 캠페인 할당, 디바이스 상태 모니터링 방법을 보여줍니다.Knox E-FOTA에서 캠페인 만들기 다음 동영상은 삼성 디바이스에 Knox E-FOTA 캠페인을 만들고 적용하는 방법에 대한 심층적인 정보를 제공합니다.Knox E-FOTA를 VMware Workspace ONE에 연결하기 다음 비디오에서는 Knox E-FOTA를 VMware Workspace ONE과 연결하는 동시에 워크스페이스 1에서 디바이스 그룹을 추가하는 간단한 단계를 설명합니다.', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 1, 'title': '사용 방법 동영상', 'url': 'https://docs.samsungknox.com/admin/efota-one/how-to-videos', 'project': 'EFOTA', 'last_updated': '2023-09-27'}),
#  Document(page_content='녹스 E-FOTA.Knox E-FOTA를 사용하면 기업 IT 관리자가 사용자 개입 없이 OS 버전과 보안 업데이트를 기업 디바이스에 원격으로 배포할 수 있습니다.배포 전에 업데이트를 테스트하여 사내 앱과 새 OS 버전 간의 호환성을 확인하고, 최신 보안 패치를 일정에 따라 배포하여 엔터프라이즈 디바이스의 보안을 강화하세요.대상 고객 무료 체험하기 이 문서의 대상: 시스템 보안 설계자 — Knox E-FOTA의 작동 원리와 Knox E-FOTA를 사용하여 엔터프라이즈 디바이스를 업데이트하는 방법을 알아보세요.IT 관리자 - 엔터프라이즈 디바이스의 무선 업데이트를 관리하는 방법을 알아보세요.솔루션을 사용해 보세요. Knox E-FOTA를 사용하여 모바일 업데이트 워크플로를 간소화하세요.버전 제어 관리를 활성화하고 업무 시간 외에 업데이트가 발생하도록 설정하여 OS 업데이트를 배포하여 생산성에 지장을 주지 않도록 하세요.튜토리얼 시작하기 Knox E-FOTA 소개 Knox E-FOTA"는 삼성 모바일 디바이스의 OS 버전을 제어하여 비용 효율성을 극대화하는 엔터프라이즈 솔루션입니다.IT 관리자는 이를 통해 다음과 같은 작업을 수행할 수 있습니다. 일정에 따라 최신 보안 패치를 디바이스에 배포하세요.배포 전에 업데이트를 테스트하여 사내 앱과 새 OS 버전 간의 호환성을 확인하십시오.주요 기능, 강제 업데이트 - 모든 장치에서 동일한 OS 버전을 사용할 수 있도록 강제 업데이트를 배포하여 장치 관리 환경을 간소화합니다.사용자 개입 없이 업데이트를 푸시할 수 있습니다.선택적 OS"버전 - 최신 OS 버전이 사내 앱과 항상 호환되는 것은 아닙니다.디바이스에 배포할 OS 버전을 제어하여 운영 연속성을 보장하세요.최신 OS 버전을 배포할 준비가 될 때까지 해당 버전으로 잠글 수 있습니다.정기 업데이트 - 업무 시간 외에 펌웨어 업데이트가 이루어지도록 예약하여 업무 중단을 최소화합니다.모든 기능의 전체 목록을 보려면 Knox E-FOTA의 제품 페이지를 방문하십시오.이점 1.소프트웨어 호환성 테스트 - 내부 앱과 새 OS 버전 간의 호환성을 보장하기 위해 소프트웨어를 테스트한 후에만 업데이트를 적용합니다.이를 통해 호환성 문제에 대한 IT 지원의 필요성을 최소화할 수 있습니다. 2.장치 보안 - 검증된 최신 펌웨어를 보안 유지관리 릴리스 (SMR) 라고도 하는 최신 보안 패치와 함께 사용자 개입 없이 즉시 회사에서 사용할 수 있는 모든 장치에 배포합니다. 3.효율적인 배포 - 디바이스가 업데이트를 다운로드하고 설치하는 시간을 지정하여 업무 중단을 최소화함으로써 생산성을 유지합니다.IT 관리자는 운영 연속성을 보장하기 위해 시차를 두고 업데이트 (예: 지역별) 를 배포할 수 있습니다. 4.효율적인 장치 관리 - 강제 업데이트를 원격으로 배포하면 모든 엔터프라이즈 장치에서 항상 검증된 최신 OS 버전을 실행할 수 있습니다.모든 디바이스를 한 눈에 파악할 수 있어 IT 관리자가 디바이스를 더 효율적으로 관리할 수 있습니다.사일런트 업데이트는 사용자 개입이 필요하지 않으므로 연기하거나 거부할 수 없습니다.Knox E-FOTA는 어떻게 작동하나요?FOTA (Firmware-over-the-Air) 는 IT 관리자가 효율적이고 안전하게 펌웨어 업데이트를 엔터프라이즈 모바일 디바이스에 푸시할 수 있는 서비스입니다.일반적으로 서비스 제공업체는 삼성 B2C (Business-to-Consumer) FOTA 서버를 통해 최신 펌웨어 업데이트를 디바이스에 푸시합니다.문제는 최신 펌웨어가 회사의 사내 앱과 항상 호환되는 것은 아니라는 점입니다.Knox E-FOTA가 없는 기업은 다음을 수행해야만 이 문제를 해결할 수 있습니다. 항상 최신 OS 버전으로 업데이트하고, EMM Knox E-FOTA를 사용하여 모든 OS 업데이트를 차단하십시오."관리자가 최신 버전이 아니더라도 배포할 펌웨어 버전을 선택할 수 있습니다.그러면 디바이스가 해당 버전으로 잠깁니다.관리자는 최신 펌웨어 버전에서 호환성 테스트를 수행한 후 기기를 테스트된 버전으로 업데이트할 수 있습니다.Knox E-FOTA를 통해 기업은 삼성 B2B (Business-to-Business) FOTA"서버에서 펌웨어 업데이트를 푸시합니다. 하지만 삼성의 Knox E-FOTA 서비스를 통하지 않고 자체 서버에서 펌웨어 업데이트를 제공하는 AT&T 및 Verizon과 같은 예외도 있습니다.그러면 B2B FOTA 서버가 디바이스 정보를 B2C FOTA 서버와 동기화합니다.#Downloading 펌웨어 버전 Knox E-FOTA를 통해 지난 12개월 이내에 일반 삼성 FOTA 서비스를 통해 출시된 공식 펌웨어 목록에 액세스할 수 있습니다.추가 상담을 통해 추가 펌웨어 목록을 제공할 수 있습니다.펌웨어 업데이트를 푸시할 때 삼성은 현재 펌웨어 버전에서 대상 버전으로 업데이트하기 위한 델타 파일 또는 변경 파일을 생성합니다.그런 다음 일반 Samsung FOTA 서버를 통해 릴리스되고 무선으로 엔터프라이즈 장치에 전달됩니다.펌웨어 파일은 Knox E-FOTA 서버에서 평균 12개월 동안 사용할 수 있습니다.경우에 따라, 특히 주요 Android OS 버전으로 디바이스를 업그레이드할 때 대상 펌웨어 버전에 도달하기 위해 여러 델타 파일을 다운로드해야 할 수 있습니다.Knox E-FOTA"Advanced에서는 대상 버전에 도달하기 위해 여러 캠페인을 점진적으로 실행해야 할 수 있습니다.Knox E-FOTA와 MDM의 “Knox E-FOTA”에서는 하나의 캠페인만 필요합니다. 필요한 델타 파일은 순차적으로 자동으로 설치됩니다.사용 중인 Knox E-FOTA 에디션에 관계없이 이 경우 디바이스가 여러 번 재부팅됩니다.Knox E-FOTA 에디션 비교하기 Knox E-FOTA 서비스에는 Knox E-FOTA, Knox E-FOTA"어드밴스드, MDM용 Knox E-FOTA의 세 가지 에디션이 있습니다. 이 섹션에서는 Knox E-FOTA 서비스의 주요 차별화 기능에 대해 설명합니다.MDM에서 Knox E-FOTA 기능 사용 Knox E-FOTA Advanced Knox E-FOTA 설명 선택적 OS 버전 ✔ ✔ ✔ 디바이스에 배포할 OS 버전을 선택하고, 내부 앱으로 검증되지 않은 OS 버전에 대한 업데이트를 방지합니다.강제 업데이트 (무음) ✔ ✔ ✔ 사용자 개입 없이 장치에 OS 업데이트를 배포할 수 있습니다.예약 업데이트 ✔ ✔ ✔ OS 업데이트를 다운로드하고 설치할 특정 날짜 및 시간 범위 (예: 업무 시간 외) 를 설정합니다.강제 업데이트 (중요) ✔ ✔ 중요한 작업이 진행 중인 동안 사용자가 업데이트를 연기할 수 있도록 허용합니다 (최대 지연 기간 포함).사용자는 업데이트를 거부할 수 없습니다.추가 캠페인 옵션 ✔ ✔ 다음 옵션 설정: 로밍 중 펌웨어 다운로드 허용.충전 도크에 연결된 경우에만 설치를 허용합니다.캠페인 상태 보기 기능 ✔ ✔ 캠페인 운영 상태 보기.디바이스 및 캠페인 상태에 대한 모니터링 대시보드 위젯은 Knox E-FOTA Advanced에서 사용할 수 있습니다. ✔ 대시보드를 통해 Knox E-FOTA의 다양한 영역을 모니터링할 수 있습니다.독립 웹 콘솔 ✔ ✔ 웹 포털을 통해 관리 작업을 수행합니다.네트워크 대역폭 제어 ✔ ✔ 설정된 최대 대역폭 내에서 펌웨어 업데이트를 배포합니다.Wi-Fi 전용 모드 ✔ ✔ Wi-Fi를 통해서만 다운로드 및 업데이트가 이루어지도록 설정하여 셀룰러 사용 비용을 절감할 수 있습니다.캠페인당 여러 모델 업데이트 가능 ✔ 단일 캠페인에서 여러 장치 모델을 서로 다른 펌웨어 릴리스에 할당할 수 있습니다.캠페인당 순차 업데이트 ✔ ✔ 단 하나의 캠페인으로 모든 버전에서 대상 버전으로 업데이트.즉, 기기를 현재 버전에서 대상 버전으로 점진적으로 업데이트하기 위해 여러 캠페인을 만들 필요가 없습니다.장치 그룹 및 조직 정보를 EMM과 동기화하는 기능 ✔ ✔ EMM에서 장치 그룹을 가져와서 장치 관리 작업을 간소화합니다.Knox E-FOTA를 EMM에 연결하면 디바이스 그룹이 동기화되지 않도록 할 수 있습니다.디바이스 정보는 EMM에서  ...

# %% [markdown]
# # 4. Chunking JSON Doc

# %% [markdown]
# ## Chunk Size and Chunk Overlap Size 결정

# %%
chunk_size = 1024
chunk_overlap = 512

# %% [markdown]
# ## Chunking

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, SpacyTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size = chunk_size,
    chunk_overlap  = chunk_overlap,
    separators=["\n\n", "\n", ".", " ", ""],
    length_function = len,
)

chunk_docs = text_splitter.split_documents(all_docs)
print(f"Number of chunk_docs after split and chunking= {len(chunk_docs)}")
# Out:
# Number of chunk_docs after split and chunking= 4909

# %%
chunk_docs[0:2]
# Out:
# [Document(page_content='사용 방법 동영상.Knox E-FOTA를 사용하는 방법에 대한 비디오가 포함되어 있습니다.이 섹션에는 Knox E-FOTA를 사용하는 방법에 대한 비디오가 포함되어 있습니다.Knox E-FOTA 시작하기 이 동영상은 Knox E-FOTA 콘솔을 안내하며 리셀러 등록, 디바이스 승인, 캠페인 생성, 캠페인 할당, 디바이스 상태 모니터링 방법을 보여줍니다.Knox E-FOTA에서 캠페인 만들기 다음 동영상은 삼성 디바이스에 Knox E-FOTA 캠페인을 만들고 적용하는 방법에 대한 심층적인 정보를 제공합니다.Knox E-FOTA를 VMware Workspace ONE에 연결하기 다음 비디오에서는 Knox E-FOTA를 VMware Workspace ONE과 연결하는 동시에 워크스페이스 1에서 디바이스 그룹을 추가하는 간단한 단계를 설명합니다.', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 1, 'title': '사용 방법 동영상', 'url': 'https://docs.samsungknox.com/admin/efota-one/how-to-videos', 'project': 'EFOTA', 'last_updated': '2023-09-27'}),
#  Document(page_content='녹스 E-FOTA.Knox E-FOTA를 사용하면 기업 IT 관리자가 사용자 개입 없이 OS 버전과 보안 업데이트를 기업 디바이스에 원격으로 배포할 수 있습니다.배포 전에 업데이트를 테스트하여 사내 앱과 새 OS 버전 간의 호환성을 확인하고, 최신 보안 패치를 일정에 따라 배포하여 엔터프라이즈 디바이스의 보안을 강화하세요.대상 고객 무료 체험하기 이 문서의 대상: 시스템 보안 설계자 — Knox E-FOTA의 작동 원리와 Knox E-FOTA를 사용하여 엔터프라이즈 디바이스를 업데이트하는 방법을 알아보세요.IT 관리자 - 엔터프라이즈 디바이스의 무선 업데이트를 관리하는 방법을 알아보세요.솔루션을 사용해 보세요. Knox E-FOTA를 사용하여 모바일 업데이트 워크플로를 간소화하세요.버전 제어 관리를 활성화하고 업무 시간 외에 업데이트가 발생하도록 설정하여 OS 업데이트를 배포하여 생산성에 지장을 주지 않도록 하세요.튜토리얼 시작하기 Knox E-FOTA 소개 Knox E-FOTA"는 삼성 모바일 디바이스의 OS 버전을 제어하여 비용 효율성을 극대화하는 엔터프라이즈 솔루션입니다.IT 관리자는 이를 통해 다음과 같은 작업을 수행할 수 있습니다. 일정에 따라 최신 보안 패치를 디바이스에 배포하세요.배포 전에 업데이트를 테스트하여 사내 앱과 새 OS 버전 간의 호환성을 확인하십시오.주요 기능, 강제 업데이트 - 모든 장치에서 동일한 OS 버전을 사용할 수 있도록 강제 업데이트를 배포하여 장치 관리 환경을 간소화합니다.사용자 개입 없이 업데이트를 푸시할 수 있습니다.선택적 OS"버전 - 최신 OS 버전이 사내 앱과 항상 호환되는 것은 아닙니다.디바이스에 배포할 OS 버전을 제어하여 운영 연속성을 보장하세요.최신 OS 버전을 배포할 준비가 될 때까지 해당 버전으로 잠글 수 있습니다.정기 업데이트 - 업무 시간 외에 펌웨어 업데이트가 이루어지도록 예약하여 업무 중단을 최소화합니다.모든 기능의 전체 목록을 보려면 Knox E-FOTA의 제품 페이지를 방문하십시오.이점 1', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 2, 'title': '녹스 E-FOTA', 'url': 'https://docs.samsungknox.com/admin/efota-one', 'project': 'EFOTA', 'last_updated': '2023-07-26'})]

# %% [markdown]
# ## Sampling

# %%
len(chunk_docs)
chunk_docs = chunk_docs[:1000]
len(chunk_docs)
# Out:
# 1000

# %% [markdown]
# # 5. Index 생성

# %% [markdown]
# ## Index 이름 결정
# - 아래에 원하는 인덱스 이름을 기술 해주세요

# %%
# index_name = "<your index name>"
index_name = "knox-korean-v22"

# %% [markdown]
# ## Index 스키마 정의

# %%
index_body = {
    'settings': {
        'analysis': {'analyzer': {'my_analyzer': {'char_filter': ['html_strip'],
                                                    'tokenizer': 'nori',
                                                       'filter': [
                                                                   'my_nori_part_of_speech'
                                                                 ],
                                                       'type': 'custom'}},
                                   'tokenizer': {'nori': {
                                                  'decompound_mode': 'mixed',
                                                  'discard_punctuation': 'true',
                                                  'type': 'nori_tokenizer'}
                                                },
                                    "filter": {
                                          "my_nori_part_of_speech": {
                                                "type": "nori_part_of_speech",
                                                "stoptags": [
                                                    "J", "XSV", "E", "IC","MAJ","NNB",
                                                    "SP", "SSC", "SSO",
                                                    "SC","SE","XSN","XSV",
                                                    "UNA","NA","VCP","VSV",
                                                    "VX"
                                                ]
                                          }
                                    }
                    },        
        'index': {
            'knn': True,
            'knn.space_type': 'cosinesimil'  # Example space type
        }
    },
    'mappings': {
        'properties': {
            'metadata': {
                'properties': {
                               'source' : {'type': 'keyword'},                    
                               'last_updated': {'type': 'date'},
                               'project': {'type': 'keyword'},
                               'seq_num': {'type': 'long'},
                               'title': {'type': 'text'},  # For full-text search
                               'url': {'type': 'text'},  # For full-text search
                            }
            },            
            'text': {
                'analyzer': 'my_analyzer',
                'search_analyzer': 'my_analyzer',
                'type': 'text'
            },
            'vector_field': {
                'type': 'knn_vector',
                'dimension': 1536  # Replace with your vector dimension
            }
        }
    }
}

# %% [markdown]
# # 5. LangChain OpenSearch VectorStore 생성
# ## 선수 조건

# %% [markdown]
# ## 오픈 서치 도메인 및 인증 정보 세팅
#
# - [langchain.vectorstores.opensearch_vector_search.OpenSearchVectorSearch](https://api.python.langchain.com/en/latest/vectorstores/langchain.vectorstores.opensearch_vector_search.OpenSearchVectorSearch.html)

# %% [markdown]
# #### [중요] 아래에 aws parameter store 에 아래 인증정보가 먼저 입력되어 있어야 합니다.

# %%
import boto3
from local_utils.proc_docs import get_parameter

# %%
ssm = boto3.client('ssm', 'us-east-1')

opensearch_domain_endpoint = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_domain_endpoint',
)

opensearch_user_id = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_userid',
)

opensearch_user_password = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_password',
)

# %%
opensearch_domain_endpoint = opensearch_domain_endpoint
rag_user_name = opensearch_user_id
rag_user_password = opensearch_user_password

http_auth = (rag_user_name, rag_user_password) # Master username, Master password

# %% [markdown]
# ## OpenSearch Client 생성

# %%
from local_utils.opensearch import opensearch_utils

# %%
aws_region = os.environ.get("AWS_DEFAULT_REGION", None)

os_client = opensearch_utils.create_aws_opensearch_client(
    aws_region,
    opensearch_domain_endpoint,
    http_auth
)

# %% [markdown]
# ## 오픈 서치 인덱스 생성
# - 오픈 서치에 해당 인덱스가 존재하면, 삭제 합니다.

# %%
index_exists = opensearch_utils.check_if_index_exists(
    os_client,
    index_name
)

if index_exists:
    opensearch_utils.delete_index(
        os_client,
        index_name
    )

opensearch_utils.create_index(os_client, index_name, index_body)
index_info = os_client.indices.get(index=index_name)
print("Index is created")
pprint(index_info)
# Out:
# index_name=knox-korean-v22, exists=False
#
# Creating index:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'knox-korean-v22'}
# Index is created
# {'knox-korean-v22': {'aliases': {},
#                      'mappings': {'properties': {'metadata': {'properties': {'last_updated': {'type': 'date'},
#                                                                              'project': {'type': 'keyword'},
#                                                                              'seq_num': {'type': 'long'},
#                                                                              'source': {'type': 'keyword'},
#                                                                              'title': {'type': 'text'},
#                                                                              'url': {'type': 'text'}}},
#                                                  'text': {'analyzer': 'my_analyzer',
#                                                           'type': 'text'},
#                                                  'vector_field': {'dimension': 1536,
#                                                                   'type': 'knn_vector'}}},
#                      'settings': {'index': {'analysis': {'analyzer': {'my_analyzer': {'char_filter': ['html_strip'],
#                                                                                       'filter': ['my_nori_part_of_speech'],
#                                                                                       'tokenizer': 'nori',
#                                                                                       'type': 'custom'}},
#                                                          'filter': {'my_nori_part_of_speech': {'stoptags': ['J',
#                                                                                                             'XSV',
#                                                                                                             'E',
#                                                                                                             'IC',
#                                                                                                             'MAJ',
#                                                                                                             'NNB',
#                                                                                                             'SP',
#                                                                                                             'SSC',
#                                                                                                             'SSO',
#                                                                                                             'SC',
#                                                                                                             'SE',
#                                                                                                             'XSN',
#                                                                                                             'XSV',
#                                                                                                             'UNA',
#                                                                                                             'NA',
#                                                                                                             'VCP',
#                                                                                                             'VSV',
#                                                                                                             'VX'],
#                                                                                                'type': 'nori_part_of_speech'}},
#                                                          'tokenizer': {'nori': {'decompound_mode': 'mixed',
#                                                                                 'discard_punctuation': 'true',
#                                                                                 'type': 'nori_tokenizer'}}},
#                                             'creation_date': '1708851107362',
#                                             'knn': 'true',
#                                             'knn.space_type': 'cosinesimil',
#                                             'number_of_replicas': '1',
#                                             'number_of_shards': '5',
#                                             'provided_name': 'knox-korean-v22',
#                                             'replication': {'type': 'DOCUMENT'},
#                                             'uuid': '9UtXOObWQ3CuJzlgjZ5QAw',
#                                             'version': {'created': '136327827'}}}}}

# %% [markdown]
# ## 랭체인 인덱스 연결 오브젝트 생성
#
# - [langchain.vectorstores.opensearch_vector_search.OpenSearchVectorSearch](https://api.python.langchain.com/en/latest/vectorstores/langchain.vectorstores.opensearch_vector_search.OpenSearchVectorSearch.html)

# %%
from langchain.vectorstores import OpenSearchVectorSearch

# %%
vector_db = OpenSearchVectorSearch(
    index_name=index_name,
    opensearch_url=opensearch_domain_endpoint,
    embedding_function=llm_emb,
    http_auth=http_auth, # http_auth
    is_aoss =False,
    engine="faiss",
    space_type="l2",
    bulk_size=100000,
    timeout=60
)
vector_db

# %% [markdown]
# ## OpenSearch 에 문서 삽입

# %%
# %%time

vector_db.add_documents(
    documents = chunk_docs, 
    vector_field = "vector_field",
    bulk_size = 1000000
)
# Out:
# CPU times: user 2.28 s, sys: 129 ms, total: 2.41 s
# Wall time: 1min 53s
# ['5e65f55b-76c7-40a3-aedb-75bd388ac130',
#  'f5f0a5a0-7ce2-42a2-86e6-d066191a29c5',
#  '131b3438-3393-4e30-9b06-eb8c644ce4d9',
#  '5daea659-836e-4d9c-b7fc-ec0ecbceeede',
#  '931c3081-0edb-427c-bb18-b90896ea5c3d',
#  'cc4c3153-0da4-42d0-9655-540ae0ab088b',
#  '835064b2-b258-4470-81d7-6d65fce9445c',
#  'c01b0cbd-f5ee-4a47-8b1f-9d7dd5456fe4',
#  'ba711a6b-7604-4fa8-a18a-2fc3694582ef',
#  'dc3521fb-56db-4c52-8805-bb06e4a1b8bc',
#  '8479ab32-bf09-4cd3-b991-f7fda44c26c6',
#  '02bfff24-9bf0-41a5-a7b7-e7d2c26fd59f',
#  '5a716b8d-08af-46ff-9c96-0e4c82c74ea6',
#  'e90adc95-9710-46ec-9e8f-dfd85826767b',
#  'e09e4768-447c-448c-b2a6-772d898066a4',
#  '3d165c6a-9313-4b0e-aa7e-711c8d32b740',
#  '38248e39-70d3-4ffa-a081-2db97ff19d8c',
#  '39dd9252-90dc-40f9-a99d-87050d4176d8',
#  'a97172fe-b0b1-4c38-9a45-9bd8d37d20fd',
#  '4d40c833-a188-4e5b-a67c-314e0355320a',
#  'b0c9412f-c702-4883-a1d1-87f0982f0190',
#  '57d94a38-eb1e-4ac0-9ca5-f37bb4bfa391',
#  '575aaa55-fda2-4c28-a1ba-8f8ba6637761',
#  '5763fc40-6783-4030-8636-847b7ba0b637',
#  'c539b02a-6ea1-4f14-9f47-2cb3b6666b7d',
#  '5e035291-3a78-4abe-8704-242a08a01f3f',
#  'cbeff0fe-a65c-4835-b5e7-b21751a029f2',
#  '485fb071-753a-4c4e-ada2-f5b3bfbca1da',
#  'def86720-8d5c-41ee-bb05-f531f54d33d0',
#  'd6ca3308-e115-445b-bc93-67290749eb5e',
#  '8e3c5b0b-e25d-4a0c-8dc0-8a18eae10955',
#  '2d806576-1c40-46c9-ac15-e3af866a87d7',
#  'f4d21909-32bf-4fd6-bf3c-d9c288e354ab',
#  '7810a0d7-561a-4298-bab3-a3901758b0d8',
#  'f3eb2240-05ff-49c5-b577-65998f8cf90d',
#  '7495d318-72aa-4844-8789-35121ba37e1a',
#  '2bee99ad-eb9b-44ff-9ffa-29462188e142',
#  '88a70d53-e9e7-4fe1-b15d-9fb69f94450b',
#  '3151bc94-5116-457e-aabf-5d242c7ebb46',
#  'f3b2f474-00e3-483c-8a25-91e64807ea19',
#  'f730aa26-6791-4f27-b8a3-40860d810f2c',
#  'c28d052f-7517-4bb3-9470-1b8cd7fe7461',
#  'c19d2a61-6fd7-4b46-99ba-238f42ff88cf',
#  '56cbe97f-a70d-441a-a1ae-b4d7d7fc0624',
#  '536e5856-0bbe-4f4e-a786-34040179b398',
#  'f8f715b7-bd89-45b8-b3d9-7aa7149bf9d6',
#  'd0ecb799-401f-42e0-97c3-ddba1cd3e3a4',
#  '620d30ff-114b-45e2-8324-efd2c845b484',
#  'c9f69833-813a-41d4-94c2-33a6903c73d4',
#  'b0e253c8-0563-4d1f-873c-91da6afa9eca',
#  'a15ef3e5-df0b-4cd0-a0ef-88345cb58c10',
#  '33940201-3315-4897-bef6-8a72ea72a539',
#  'a585e7dd-c7ef-44ec-b8e6-b6b85678fb81',
#  '892f314f-0c89-4352-a1be-912b256d7d2d',
#  '7a01422f-5044-4ff2-8a00-67bbc1f30146',
#  '0f269f42-cb21-404f-86e2-036287044d44',
#  'a79cc0d9-5f57-4e12-a4b6-461a1fa99ce6',
#  'c697a510-d1b0-4bfb-ac9d-589409aa2f96',
#  '9ab29c8a-2d0c-4142-baec-08be04b8cb49',
#  'a00ae3f9-01fb-41d7-90ce-6f536329a316',
#  'dd1df307-526a-4b02-a278-f2922bfd7e02',
#  '23f6d1d3-bece-4fe8-afcc-e62592d0add3',
#  'd31b3fb6-5c5c-4f56-8243-0833c193822a',
#  'd550f4ae-83b5-48e5-a334-e19c4ae54fac',
#  '74260cfb-04c1-4679-83b9-59dc82afd267',
#  '42b46463-007c-41c4-a438-3978c97a504b',
#  '6b63bca2-c547-4bd7-a7ac-bb23b5d6e544',
#  '2be2ad2d-16c3-4dad-a1b8-9c513d9e5a8a',
#  'c37cf450-d178-4e0f-b6f6-2e4a548c3d17',
#  'cd0ce7ff-8568-48d4-a832-14ac68bf363d',
#  'b609b0c4-22b6-427a-af3f-3d69e5f6d35c',
#  '0fad1a85-12d9-4ab2-aa05-406e4e75c796',
#  '900ddb5c-31f3-4d78-a127-85ae2b628a22',
#  'cc37ce40-ad99-4b43-bfbd-a8980cf917e2',
#  '33a45493-0c4f-40cc-ad2a-ca19dfe7db8a',
#  'e0055de1-78ca-4bbc-a91c-f7bce60db9c0',
#  '9ec992a4-c807-49ab-89a1-5f8a15dc4d64',
#  'e2c6e0f1-c4ff-4de8-8bcf-e0d45d0a37b6',
#  'c8b27f90-d3d7-43dc-aff6-4e3cca012083',
#  '1b78c9c1-5464-4785-b25b-f14c6da93810',
#  '760de1bb-7061-4ab2-a8ff-3720e8fb01e4',
#  'f198e05d-a8b6-4d69-bbf1-ea61613bef36',
#  '69375643-d4d2-4da4-b977-05689f4bdd0d',
#  'cff03784-9686-4f20-b51d-7933eaa68225',
#  '6f1611df-de2e-4d9e-ac44-0105e8487218',
#  'c35bd92a-502b-4111-a5a7-3a562d252049',
#  '29686b2b-1b03-4b96-8daa-e9d0a577e47a',
#  '7ce94e0e-a7bc-4b7c-9f11-2b197590bf83',
#  '55002546-c70d-4055-bdd8-b5809bbf48cc',
#  '16c064dc-df94-4140-b6ae-07fd42e0ee26',
#  '45b29287-6174-45b7-aaba-9eade66a247b',
#  'a80a6e2c-0020-4306-8d38-186698b2e561',
#  '5dcb3512-62a2-47e3-ad2f-76f1aad3c308',
#  'e72eeb3d-2a9f-4b40-9525-8c465dea2ba7',
#  'ab09faaf-e95a-4e3a-bb4c-8b413b177a02',
#  'f43a6c17-7f47-464b-a1ae-e0f17dd446be',
#  'c1295bab-1d0b-4570-a415-97a34a8155b5',
#  '7037f4d4-e635-4edc-bc59-9511300b9bfc',
#  '0a7298fc-35de-4d5c-9ecd-ef64388cbd21',
#  'a3d16532-ce7c-4464-81db-00a86c6a369c',
#  '27eebd2f-3acf-481a-a442-ebc51bc66437',
#  'a4d8e478-d7f5-4bee-a60e-be5ae91abb5b',
#  'ab5c868b-bc95-41b5-aef1-83fc2112b3aa',
#  'b00b84f5-f444-410c-97f5-45793ec0c1c4',
#  'c1f78b2c-b97a-4731-bfad-ee068f551b85',
#  '34048e17-c1cc-432a-9352-0414a50e3a72',
#  'f42d03ea-64a1-4f08-ac7d-caf20d07f930',
#  '512acb7e-bb3b-490b-8b2d-fd2d8e8d6c15',
#  'c48ab89b-99e2-416e-97f9-f370477cb246',
#  '2cab963e-37be-4591-8c5b-7a7d8ca3e4a5',
#  '16ba7661-89c7-4e0a-bbb5-1d28a61d56bc']

# %% [markdown]
# # 6. 검색 테스트

# %%
from local_utils.rag import retriever_utils
from local_utils.rag import show_context_used

# %% [markdown]
# ## Lexical 검색

# %%
query = "Knox란 무엇인가요?"

search_filter=[
    #{"term": {"metadata.seq_num": "256"}},
    #{"term": {"metadata.project": "KM"}},
]

# %%
similar_docs_lexical = retriever_utils.get_lexical_similar_docs(
    index_name=index_name,
    os_client=os_client,
    query=query,
    k=5,
    filter=search_filter
)
show_context_used(similar_docs_lexical)
# Out:
# -----------------------------------------------
# 1. Chunk: 163 Characters
# -----------------------------------------------
# 슈퍼 어드민이란 무엇인가요?.슈퍼 관리자 또는 기본 관리자는 SamsungKnox.com, Knox 클라우드 서비스 또는 Knox 파트너 프로그램에 처음으로 등록한 사용자를
# 말합니다.최고 관리자는 추가 관리자를 초대하여 각 Knox 서비스의 관리 콘솔 내에서 기능을 보고 관리할 수 있습니다.
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 217, 'title': '슈퍼 어드민이란 무엇인가요?', 'url':
# 'https://docs.samsungknox.com/admin/fundamentals/knox-faq/#what-is-a-super-admin', 'project': 'USP',
# 'last_updated': '2023-07-26', 'id': 'd44583ef-a30c-45d6-a80e-79adf26e94c1'}
# -----------------------------------------------
# 2. Chunk: 168 Characters
# -----------------------------------------------
# 녹스 애셋 인텔리전스의 목적은 무엇입니까?Knox Asset Intelligence는 실행 가능한 가시성과 운영 통찰력을 제공하는 클라우드 기반 데이터 분석 솔루션입니다.세부
# 디바이스 사용에 대한 가시성을 통해 IT 관리자는 생산성을 극대화하고 안정성을 보장하며 자산 관리를 미리 계획할 수 있습니다.
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 310, 'title': '녹스 애셋 인텔리전스의 목적은 무엇인가요?', 'url':
# 'https://docs.samsungknox.com/admin/knox-asset-intelligence/faq/#purpose-of-kai', 'project': 'KAI',
# 'last_updated': '2023-07-26', 'id': 'f3405fc4-ead9-436a-87ff-1db6e7318afd'}
# -----------------------------------------------
# 3. Chunk: 363 Characters
# -----------------------------------------------
# 녹스 스위트는 무엇인가요?Knox Suite는 기업 IT 관리자가 디바이스를 더 잘 관리할 수 있도록 설계된 번들 오퍼링입니다.여기에는 엔터프라이즈용 Knox 플랫폼, Knox
# 모바일 등록, Knox Manage, Knox E-FOTA, Knox 에셋 인텔리전스와 같은 개별 서비스가 포함됩니다.Knox Suite의 주요 기능은 다음과 같습니다. 보안 -
# 사용자가 제어할 수 있는 관리형 보안 기능으로 비즈니스 데이터를 보호하세요.배포 - 기업 디바이스를 즉시 EMM에 자동으로 안전하게 등록할 수 있습니다.관리 - 기업 장치 및 OS
# 버전을 포괄적으로 관리할 수 있습니다.분석 - 모바일 생산성과 자산 관리를 위한 심층적인 장치 분석을 강화합니다.
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 133, 'title': '녹스 스위트는 무엇인가요?', 'url':
# 'https://docs.samsungknox.com/admin/knox-suite/faq/#what-is-knox-suite', 'project': 'KS',
# 'last_updated': '2023-07-26', 'id': 'abe72055-1ed0-48d6-bd22-51e5ad155306'}
# -----------------------------------------------
# 4. Chunk: 94 Characters
# -----------------------------------------------
# Knox 에셋 인텔리전스를 사용하기 위한 전제 조건은 무엇입니까?Knox 에셋 인텔리전스를 사용하려면 삼성 Knox 계정, Knox Suite 라이선스 키가 필요합니다.
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 312, 'title': 'Knox 에셋 인텔리전스를 사용하기 위한 전제 조건은
# 무엇인가요?', 'url': 'https://docs.samsungknox.com/admin/knox-asset-intelligence/faq/#prerequisites-for-
# kai', 'project': 'KAI', 'last_updated': '2023-07-26', 'id': 'eb3e656b-9af1-4e5e-8353-85f843c3fd63'}
# -----------------------------------------------
# 5. Chunk: 195 Characters
# -----------------------------------------------
# 90일 무료 평가판에는 무엇이 포함되어 있나요?Knox Asset Intelligence는 엔터프라이즈 모빌리티 솔루션 번들인 Knox Suite에 포함되어 있습니다.평가판
# 라이선스를 통해 90일 동안 최대 30개 디바이스에서 Knox Asset Intelligence 콘솔을 비롯한 모든 Knox Suite 제품과 해당 기능을 이용할 수 있습니다.
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 313, 'title': '90일 무료 평가판에는 무엇이 포함되어 있나요?',
# 'url': 'https://docs.samsungknox.com/admin/knox-asset-intelligence/faq/#what-is-in-trial',
# 'project': 'KAI', 'last_updated': '2023-07-26', 'id': '559e82da-7f6f-4ccc-aef1-e9b1b45a5a22'}

# %% [markdown]
# ## 시멘틱 검색

# %%
query = "Knox란 무엇인가요?"

search_filter=[
    #{"term": {"metadata.seq_num": "256"}},
    #{"term": {"metadata.project": "KM"}},
]

# %%
similar_docs_semantic = retriever_utils.get_semantic_similar_docs(
    index_name=index_name,
    os_client=os_client,
    llm_emb=llm_emb,
    query=query,
    k=5,
    boolean_filter=search_filter,
    hybrid=False
)
show_context_used(similar_docs_semantic)
# Out:
# -----------------------------------------------
# 1. Chunk: 973 Characters
# -----------------------------------------------
# 삼성 Knox 계정을 만드세요.가입하기 전에, 특히 디바이스를 해외에 등록할 계획인 IT 관리자인 경우 시작하기 전에 반드시 읽어보시기 바랍니다.Knox 계정 등록 삼성 Knox
# 계정은 무료이며 단 몇 분 만에 만들 수 있습니다.삼성 Knox 계정이 있으면 Knox 서비스에 등록하고 Knox 관리 포털에 액세스할 수 있습니다. Knox 관리 포털을 통해 각
# Knox 서비스의 디바이스, 관리자, 라이선스를 쉽게 관리할 수 있습니다.삼성 Knox 계정을 등록하려면 계정을 삼성 계정에 연결해야 합니다.아직 삼성 계정이 없는 경우
# SamsungKnox.com에 가입할 때 계정을 만들라는 메시지가 표시됩니다.Knox 계정을 만들려면: 1.삼성녹스닷컴으로 이동하세요. 2.오른쪽 상단에서 시작하기를 클릭하세요.
# 3.비즈니스 이메일에서 업무에 사용하는 이메일 주소를 입력합니다.미국 및 EU 서버 모두에서 장치를 관리하는 데 두 개의 계정이 필요한 경우 이메일 사용자 이름에 +us 또는
# +eu 또는 인식할 수 있는 다른 태그를 추가하세요.이렇게 하면 별도의 이메일 주소를 만들지 않고도 두 지역 계정에 모두 쉽게 액세스할 수 있습니다.자세한 내용은 시작하기 전에를
# 참조하십시오. 4.액세스하려는 Knox 솔루션 (Knox Suite, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 또는 기타 제품 및 서비스) 을
# 선택하세요.Knox 모바일 등록과 같은 개별 Knox Suite 서비스에 액세스하려면 Knox Suite를 선택하세요. 5.내 계정 생성을 클릭합니다.삼성 계정이 없는 경우 계정을
# 만들라는 메시지가 표시됩니다.삼성 계정을 생성한 후 수신한 확인 이메일을 열고 링크를 클릭합니다.그러면 자동으로 SamsungKnox.com으로 리디렉션되어 등록을 계속할 수
# 있습니다. 6.등록 시 입력한 삼성 계정 세부 정보를 확인하십시오.정보가 정확하면 다음을 클릭하십시오: 회사 정보. 7.회사 세부 정보를 입력하세요
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 154, 'title': '삼성 Knox 계정 만들기', 'url':
# 'https://docs.samsungknox.com/admin/fundamentals/register-for-samsung-knox/create-a-samsung-knox-
# account', 'project': 'USP', 'last_updated': '2023-10-25', 'id':
# '99ea459d-9079-4586-a79f-ffa8b91e45c0'}
# -----------------------------------------------
# 2. Chunk: 982 Characters
# -----------------------------------------------
# Knox 지식 기반 문서.서비스별 기사, Knox Suite, 엔터프라이즈용 Knox 플랫폼, Knox 서비스 플러그인, Knox 모바일 등록, Knox 모바일 등록 다이렉트,
# Knox 캡처, Knox Asset Intelligence, Knox Manage, Knox E-FOTA, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+
# 일반 기사 삼성 Knox, 삼성 Knox 디바이스 수리를 위한 사용자 경험 연구 요구 사항 삼성 디바이스의 문제를 해결하기 위한 로그 캡처 방법 레거시 One UI Core 플랫폼
# 문제 해결을 위해 브라우저 로그를 수집하는 방법 삼성에서 dumpstate 로그를 수집하는 방법웨어러블 디바이스 정보 Secure by Knox, Android, 기타 및
# Android Go 디바이스 관련 Knox 지원 버전에 대한 정책 업데이트 삼성 계정을 등록할 때 인증 이메일을 받지 못하면 어떻게 해야 하나요?Knox 클라우드 서비스 Knox
# Suite 라이선스를 Knox Remote Support에서 복구할 수 없습니다. Knox 라이선스 키에서 디바이스를 분리하는 방법 Knox 라이선스 키의 사용자 수를 확인하는
# 방법 Knox 클라우드 서비스에서 사용자를 다시 초대하거나 차단을 해제하는 방법 삼성 Knox Cloud Services에서 슈퍼 관리자를 변경하는 방법 Knox Cloud
# Services와 삼성 디바이스와의 호환성 Knox Deployment 앱에서만 디바이스 추가 가능 필수 2단계 인증 Knox 배포 앱을 사용하는 모든 IT 관리자가 등록 중에 +
# 제스처를 사용하면 오류가 발생합니다.”태블릿/휴대폰이 이미 등록됨” Knox Cloud Services (KCS) 솔루션이 시작되지 않습니다. 삼성 계정을 변경한 후
# SamsungKnox.com에 로그인할 수 없습니다. Knox 클라우드 서비스에 관리자를 초대할 수 없습니다 Knox 클라우드 서비스 포털은 모바일용으로 지원되지 않습니다
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 256, 'title': 'Knox 지식베이스 문서', 'url':
# 'https://docs.samsungknox.com/admin/fundamentals/kbas', 'project': 'USP', 'last_updated':
# '2023-07-26', 'id': 'b0488e51-b307-4590-84c4-654f827c7708'}
# -----------------------------------------------
# 3. Chunk: 834 Characters
# -----------------------------------------------
# .완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox 모바일 등록 디바이스 소유자 (DO), 녹스 에셋 인텔리전스
# 녹스 모바일 등록 DO Knox E-FOTA Knox 에셋 인텔리전스 Knox 모바일 등록 DO 등록 DO 등록 및 디바이스 설정 마법사가 완료되면 KES가 Knox E-FOTA
# 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA,
# Knox Configure, Knox 모바일 등록 및 Knox 에셋 인텔리전스 Knox 구성 Knox E-FOTA Knox 모바일 등록 Knox 에셋 인텔리전스 Knox
# Configure 등록 및 디바이스 설정 마법사가 끝나면 KES는 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 Knox 모바일
# 등록 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox Configure, Knox 모바일 등록
# DO 및 Knox 에셋 인텔리전스 녹스 모바일 등록 DO Knox 구성 Knox E-FOTA Knox 에셋 인텔리전스 구성 Knox 모바일 등록 DO Knox 모바일 등록 DO
# 등록, Knox Configure 등록 및 디바이스 설정 마법사가 끝나면 KES가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면
# KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 116, 'title': '조직에 Knox 클라우드 서비스가 여러 개 있는 경우
# Knox 클라우드 서비스 등록 순서', 'url': 'https://docs.samsungknox.com/admin/efota-one/kbas/kba-738-what-order-
# are-the-knox-services-enrolled', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id':
# 'a6e261c5-05a9-47ce-8fd7-2a1170e13198'}
# -----------------------------------------------
# 4. Chunk: 933 Characters
# -----------------------------------------------
# 삼성 계정으로 로그인합니다.Knox 계정 등록 삼성 Knox 계정은 무료이며 단 몇 분 만에 만들 수 있습니다.삼성 Knox 계정이 있으면 Knox 서비스에 등록하고 Knox 관리
# 포털에 액세스할 수 있습니다. Knox 관리 포털을 통해 각 Knox 서비스의 디바이스, 관리자, 라이선스를 쉽게 관리할 수 있습니다.삼성 Knox 계정을 등록하려면 계정을 삼성
# 계정에 연결해야 합니다.아직 삼성 계정이 없는 경우 SamsungKnox.com에 가입할 때 계정을 만들라는 메시지가 표시됩니다.Knox 계정을 만들려면: 1.삼성녹스닷컴으로
# 이동하세요. 2.오른쪽 상단에서 시작하기를 클릭하세요. 3.비즈니스 이메일에서 업무용으로 사용하는 이메일 주소를 입력합니다. 4.액세스하려는 Knox 솔루션 (Knox Suite,
# Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 또는 기타 제품 및 서비스) 을 선택합니다.Knox 모바일 등록과 같은 개별 Knox Suite 서비스에
# 액세스하려면 Knox Suite를 선택하세요. 5.내 계정 생성을 클릭합니다.이미 삼성 계정이 있는 경우 회사 세부 정보가 포함된 양식을 작성하라는 메시지가 자동으로
# 표시됩니다.삼성 계정이 없는 경우 계정을 만들라는 메시지가 표시됩니다.삼성 계정을 생성한 후 수신한 확인 이메일을 열고 링크를 클릭합니다.그러면 자동으로
# SamsungKnox.com으로 리디렉션되어 회사 세부 정보가 포함된 양식을 작성하고 Knox 서비스 신청서를 제출합니다.삼성 Knox 1에
# 로그인하세요.SamsungKnox.com의 오른쪽 상단에서 로그인 위로 마우스를 가져갑니다.그런 다음 삼성 계정에서 로그인을 클릭합니다. 2.삼성 계정 이메일을 입력한 후 다음을
# 클릭합니다. 3.삼성 계정 암호를 입력한 다음 로그인을 클릭합니다.이제 로그인하여 Knox 서비스 및 제품을 사용할 준비가 되었습니다.
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 162, 'title': '삼성 계정으로 로그인', 'url':
# 'https://docs.samsungknox.com/admin/fundamentals/sign-up-for-samsung-knox/sign-in-with-a-samsung-
# account', 'project': 'USP', 'last_updated': '2023-08-23', 'id':
# '75e63bd9-ae43-4ef2-b5b0-9132389b0452'}
# -----------------------------------------------
# 5. Chunk: 1001 Characters
# -----------------------------------------------
# 조직에 여러 Knox 클라우드 서비스가 있는 경우 Knox 클라우드 서비스 등록 순서입니다.조직에 Knox 클라우드 서비스가 여러 개 있는 경우 Knox 클라우드 서비스의 등록
# 순서는 다음과 같습니다. 제품 시퀀스 플로우 Knox E-FOTA, Knox 구성 및 Knox 에셋 인텔리전스 Knox E-FOTA Knox 에셋 인텔리전스 구성 Knox 등록 및
# 디바이스 설정 마법사가 완료되면 Knox 등록 서비스 (KES) 가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는
# Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.녹스 E-FOTA, 녹스 모바일 등록, 녹스 에셋 인텔리전스 녹스 E-FOTA 녹스 모바일 등록 녹스 에셋
# 인텔리전스 디바이스 설정 마법사가 끝나면 KES는 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 Knox 모바일 등록 등록이
# 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox 모바일 등록 디바이스 소유자 (DO), 녹스 에셋
# 인텔리전스 녹스 모바일 등록 DO Knox E-FOTA Knox 에셋 인텔리전스 Knox 모바일 등록 DO 등록 DO 등록 및 디바이스 설정 마법사가 완료되면 KES가 Knox
# E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox
# E-FOTA, Knox Configure, Knox 모바일 등록 및 Knox 에셋 인텔리전스 Knox 구성 Knox E-FOTA Knox 모바일 등록 Knox 에셋 인텔리전스
# Knox Configure 등록 및 디바이스 설정 마법사가 끝나면 KES는 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 Knox
# 모바일 등록 등록이 시작됩니다
# metadata:
#  {'source': 'all_processed_data_ko.json', 'seq_num': 116, 'title': '조직에 Knox 클라우드 서비스가 여러 개 있는 경우
# Knox 클라우드 서비스 등록 순서', 'url': 'https://docs.samsungknox.com/admin/efota-one/kbas/kba-738-what-order-
# are-the-knox-services-enrolled', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id':
# '3a410911-2c89-48e0-b328-f6eb037fb295'}

# %% [markdown]
# ## 하이브리드 검색

# %%
query = "Knox란 무엇인가요?"

search_filter=[
    #{"term": {"metadata.seq_num": "256"}},
    #{"term": {"metadata.project": "KM"}},
]

# %%
# %%time
similar_docs_hybrid = retriever_utils.search_hybrid(
    query=query,
    k=5,
    index_name=index_name,
    os_client=os_client,
    filter=search_filter,
    fusion_algorithm="RRF", # ["RRF", "simple_weighted"]
    ensemble_weights=[0.51, 0.49], # semantic, lexical
    async_mode=True,
    llm_emb=llm_emb,
    verbose=True
)
# Out:
# ##############################
# async_mode
# ##############################
# True
# ##############################
# reranker
# ##############################
# False
# ##############################
# rag_fusion
# ##############################
# False
# ##############################
# HyDE
# ##############################
# False
# ##############################
# parent_document
# ##############################
# False
# ##############################
# similar_docs_semantic
# ##############################
#
# Score: 1.0
# ['삼성 Knox 계정을 만드세요.가입하기 전에, 특히 디바이스를 해외에 등록할 계획인 IT 관리자인 경우 시작하기 전에 반드시 읽어보시기 바랍니다.Knox 계정 등록 삼성 Knox 계정은 무료이며 단 몇 분 만에 만들 수 있습니다.삼성 Knox 계정이 있으면 Knox 서비스에 등록하고 Knox 관리 포털에 액세스할 수 있습니다. Knox 관리 포털을 통해 각 Knox 서비스의 디바이스, 관리자, 라이선스를 쉽게 관리할 수 있습니다.삼성 Knox 계정을 등록하려면 계정을 삼성 계정에 연결해야 합니다.아직 삼성 계정이 없는 경우 SamsungKnox.com에 가입할 때 계정을 만들라는 메시지가 표시됩니다.Knox 계정을 만들려면: 1.삼성녹스닷컴으로 이동하세요. 2.오른쪽 상단에서 시작하기를 클릭하세요. 3.비즈니스 이메일에서 업무에 사용하는 이메일 주소를 입력합니다.미국 및 EU 서버 모두에서 장치를 관리하는 데 두 개의 계정이 필요한 경우 이메일 사용자 이름에 +us 또는 +eu 또는 인식할 수 있는 다른 태그를 추가하세요.이렇게 하면 별도의 이메일 주소를 만들지 않고도 두 지역 계정에 모두 쉽게 액세스할 수 있습니다.자세한 내용은 시작하기 전에를 참조하십시오. 4.액세스하려는 Knox 솔루션 (Knox Suite, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 또는 기타 제품 및 서비스) 을 선택하세요.Knox 모바일 등록과 같은 개별 Knox Suite 서비스에 액세스하려면 Knox Suite를 선택하세요. 5.내 계정 생성을 클릭합니다.삼성 계정이 없는 경우 계정을 만들라는 메시지가 표시됩니다.삼성 계정을 생성한 후 수신한 확인 이메일을 열고 링크를 클릭합니다.그러면 자동으로 SamsungKnox.com으로 리디렉션되어 등록을 계속할 수 있습니다. 6.등록 시 입력한 삼성 계정 세부 정보를 확인하십시오.정보가 정확하면 다음을 클릭하십시오: 회사 정보. 7.회사 세부 정보를 입력하세요']
# {'source': 'all_processed_data_ko.json', 'seq_num': 154, 'title': '삼성 Knox 계정 만들기', 'url': 'https://docs.samsungknox.com/admin/fundamentals/register-for-samsung-knox/create-a-samsung-knox-account', 'project': 'USP', 'last_updated': '2023-10-25', 'id': '99ea459d-9079-4586-a79f-ffa8b91e45c0'}
#
# Score: 0.9984989377002658
# ['Knox 지식 기반 문서.서비스별 기사, Knox Suite, 엔터프라이즈용 Knox 플랫폼, Knox 서비스 플러그인, Knox 모바일 등록, Knox 모바일 등록 다이렉트, Knox 캡처, Knox Asset Intelligence, Knox Manage, Knox E-FOTA, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 일반 기사 삼성 Knox, 삼성 Knox 디바이스 수리를 위한 사용자 경험 연구 요구 사항 삼성 디바이스의 문제를 해결하기 위한 로그 캡처 방법 레거시 One UI Core 플랫폼 문제 해결을 위해 브라우저 로그를 수집하는 방법 삼성에서 dumpstate 로그를 수집하는 방법웨어러블 디바이스 정보 Secure by Knox, Android, 기타 및 Android Go 디바이스 관련 Knox 지원 버전에 대한 정책 업데이트 삼성 계정을 등록할 때 인증 이메일을 받지 못하면 어떻게 해야 하나요?Knox 클라우드 서비스 Knox Suite 라이선스를 Knox Remote Support에서 복구할 수 없습니다. Knox 라이선스 키에서 디바이스를 분리하는 방법 Knox 라이선스 키의 사용자 수를 확인하는 방법 Knox 클라우드 서비스에서 사용자를 다시 초대하거나 차단을 해제하는 방법 삼성 Knox Cloud Services에서 슈퍼 관리자를 변경하는 방법 Knox Cloud Services와 삼성 디바이스와의 호환성 Knox Deployment 앱에서만 디바이스 추가 가능 필수 2단계 인증 Knox 배포 앱을 사용하는 모든 IT 관리자가 등록 중에 + 제스처를 사용하면 오류가 발생합니다.”태블릿/휴대폰이 이미 등록됨” Knox Cloud Services (KCS) 솔루션이 시작되지 않습니다. 삼성 계정을 변경한 후 SamsungKnox.com에 로그인할 수 없습니다. Knox 클라우드 서비스에 관리자를 초대할 수 없습니다 Knox 클라우드 서비스 포털은 모바일용으로 지원되지 않습니다']
# {'source': 'all_processed_data_ko.json', 'seq_num': 256, 'title': 'Knox 지식베이스 문서', 'url': 'https://docs.samsungknox.com/admin/fundamentals/kbas', 'project': 'USP', 'last_updated': '2023-07-26', 'id': 'b0488e51-b307-4590-84c4-654f827c7708'}
#
# Score: 0.9885398230657212
# ['.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox 모바일 등록 디바이스 소유자 (DO), 녹스 에셋 인텔리전스 녹스 모바일 등록 DO Knox E-FOTA Knox 에셋 인텔리전스 Knox 모바일 등록 DO 등록 DO 등록 및 디바이스 설정 마법사가 완료되면 KES가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox Configure, Knox 모바일 등록 및 Knox 에셋 인텔리전스 Knox 구성 Knox E-FOTA Knox 모바일 등록 Knox 에셋 인텔리전스 Knox Configure 등록 및 디바이스 설정 마법사가 끝나면 KES는 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 Knox 모바일 등록 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox Configure, Knox 모바일 등록 DO 및 Knox 에셋 인텔리전스 녹스 모바일 등록 DO Knox 구성 Knox E-FOTA Knox 에셋 인텔리전스 구성 Knox 모바일 등록 DO Knox 모바일 등록 DO 등록, Knox Configure 등록 및 디바이스 설정 마법사가 끝나면 KES가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 116, 'title': '조직에 Knox 클라우드 서비스가 여러 개 있는 경우 Knox 클라우드 서비스 등록 순서', 'url': 'https://docs.samsungknox.com/admin/efota-one/kbas/kba-738-what-order-are-the-knox-services-enrolled', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id': 'a6e261c5-05a9-47ce-8fd7-2a1170e13198'}
#
# Score: 0.9873395464693476
# ['삼성 계정으로 로그인합니다.Knox 계정 등록 삼성 Knox 계정은 무료이며 단 몇 분 만에 만들 수 있습니다.삼성 Knox 계정이 있으면 Knox 서비스에 등록하고 Knox 관리 포털에 액세스할 수 있습니다. Knox 관리 포털을 통해 각 Knox 서비스의 디바이스, 관리자, 라이선스를 쉽게 관리할 수 있습니다.삼성 Knox 계정을 등록하려면 계정을 삼성 계정에 연결해야 합니다.아직 삼성 계정이 없는 경우 SamsungKnox.com에 가입할 때 계정을 만들라는 메시지가 표시됩니다.Knox 계정을 만들려면: 1.삼성녹스닷컴으로 이동하세요. 2.오른쪽 상단에서 시작하기를 클릭하세요. 3.비즈니스 이메일에서 업무용으로 사용하는 이메일 주소를 입력합니다. 4.액세스하려는 Knox 솔루션 (Knox Suite, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 또는 기타 제품 및 서비스) 을 선택합니다.Knox 모바일 등록과 같은 개별 Knox Suite 서비스에 액세스하려면 Knox Suite를 선택하세요. 5.내 계정 생성을 클릭합니다.이미 삼성 계정이 있는 경우 회사 세부 정보가 포함된 양식을 작성하라는 메시지가 자동으로 표시됩니다.삼성 계정이 없는 경우 계정을 만들라는 메시지가 표시됩니다.삼성 계정을 생성한 후 수신한 확인 이메일을 열고 링크를 클릭합니다.그러면 자동으로 SamsungKnox.com으로 리디렉션되어 회사 세부 정보가 포함된 양식을 작성하고 Knox 서비스 신청서를 제출합니다.삼성 Knox 1에 로그인하세요.SamsungKnox.com의 오른쪽 상단에서 로그인 위로 마우스를 가져갑니다.그런 다음 삼성 계정에서 로그인을 클릭합니다. 2.삼성 계정 이메일을 입력한 후 다음을 클릭합니다. 3.삼성 계정 암호를 입력한 다음 로그인을 클릭합니다.이제 로그인하여 Knox 서비스 및 제품을 사용할 준비가 되었습니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 162, 'title': '삼성 계정으로 로그인', 'url': 'https://docs.samsungknox.com/admin/fundamentals/sign-up-for-samsung-knox/sign-in-with-a-samsung-account', 'project': 'USP', 'last_updated': '2023-08-23', 'id': '75e63bd9-ae43-4ef2-b5b0-9132389b0452'}
#
# Score: 0.9844103497427474
# ['조직에 여러 Knox 클라우드 서비스가 있는 경우 Knox 클라우드 서비스 등록 순서입니다.조직에 Knox 클라우드 서비스가 여러 개 있는 경우 Knox 클라우드 서비스의 등록 순서는 다음과 같습니다. 제품 시퀀스 플로우 Knox E-FOTA, Knox 구성 및 Knox 에셋 인텔리전스 Knox E-FOTA Knox 에셋 인텔리전스 구성 Knox 등록 및 디바이스 설정 마법사가 완료되면 Knox 등록 서비스 (KES) 가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.녹스 E-FOTA, 녹스 모바일 등록, 녹스 에셋 인텔리전스 녹스 E-FOTA 녹스 모바일 등록 녹스 에셋 인텔리전스 디바이스 설정 마법사가 끝나면 KES는 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 Knox 모바일 등록 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox 모바일 등록 디바이스 소유자 (DO), 녹스 에셋 인텔리전스 녹스 모바일 등록 DO Knox E-FOTA Knox 에셋 인텔리전스 Knox 모바일 등록 DO 등록 DO 등록 및 디바이스 설정 마법사가 완료되면 KES가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox Configure, Knox 모바일 등록 및 Knox 에셋 인텔리전스 Knox 구성 Knox E-FOTA Knox 모바일 등록 Knox 에셋 인텔리전스 Knox Configure 등록 및 디바이스 설정 마법사가 끝나면 KES는 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 Knox 모바일 등록 등록이 시작됩니다']
# {'source': 'all_processed_data_ko.json', 'seq_num': 116, 'title': '조직에 Knox 클라우드 서비스가 여러 개 있는 경우 Knox 클라우드 서비스 등록 순서', 'url': 'https://docs.samsungknox.com/admin/efota-one/kbas/kba-738-what-order-are-the-knox-services-enrolled', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id': '3a410911-2c89-48e0-b328-f6eb037fb295'}
# None
# ##############################
# similar_docs_keyword
# ##############################
#
# Score: 1.0
# ['슈퍼 어드민이란 무엇인가요?.슈퍼 관리자 또는 기본 관리자는 SamsungKnox.com, Knox 클라우드 서비스 또는 Knox 파트너 프로그램에 처음으로 등록한 사용자를 말합니다.최고 관리자는 추가 관리자를 초대하여 각 Knox 서비스의 관리 콘솔 내에서 기능을 보고 관리할 수 있습니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 217, 'title': '슈퍼 어드민이란 무엇인가요?', 'url': 'https://docs.samsungknox.com/admin/fundamentals/knox-faq/#what-is-a-super-admin', 'project': 'USP', 'last_updated': '2023-07-26', 'id': 'd44583ef-a30c-45d6-a80e-79adf26e94c1'}
#
# Score: 0.9828847324952038
# ['녹스 애셋 인텔리전스의 목적은 무엇입니까?Knox Asset Intelligence는 실행 가능한 가시성과 운영 통찰력을 제공하는 클라우드 기반 데이터 분석 솔루션입니다.세부 디바이스 사용에 대한 가시성을 통해 IT 관리자는 생산성을 극대화하고 안정성을 보장하며 자산 관리를 미리 계획할 수 있습니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 310, 'title': '녹스 애셋 인텔리전스의 목적은 무엇인가요?', 'url': 'https://docs.samsungknox.com/admin/knox-asset-intelligence/faq/#purpose-of-kai', 'project': 'KAI', 'last_updated': '2023-07-26', 'id': 'f3405fc4-ead9-436a-87ff-1db6e7318afd'}
#
# Score: 0.8966990602775784
# ['녹스 스위트는 무엇인가요?Knox Suite는 기업 IT 관리자가 디바이스를 더 잘 관리할 수 있도록 설계된 번들 오퍼링입니다.여기에는 엔터프라이즈용 Knox 플랫폼, Knox 모바일 등록, Knox Manage, Knox E-FOTA, Knox 에셋 인텔리전스와 같은 개별 서비스가 포함됩니다.Knox Suite의 주요 기능은 다음과 같습니다. 보안 - 사용자가 제어할 수 있는 관리형 보안 기능으로 비즈니스 데이터를 보호하세요.배포 - 기업 디바이스를 즉시 EMM에 자동으로 안전하게 등록할 수 있습니다.관리 - 기업 장치 및 OS 버전을 포괄적으로 관리할 수 있습니다.분석 - 모바일 생산성과 자산 관리를 위한 심층적인 장치 분석을 강화합니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 133, 'title': '녹스 스위트는 무엇인가요?', 'url': 'https://docs.samsungknox.com/admin/knox-suite/faq/#what-is-knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'id': 'abe72055-1ed0-48d6-bd22-51e5ad155306'}
#
# Score: 0.8904975615414554
# ['Knox 에셋 인텔리전스를 사용하기 위한 전제 조건은 무엇입니까?Knox 에셋 인텔리전스를 사용하려면 삼성 Knox 계정, Knox Suite 라이선스 키가 필요합니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 312, 'title': 'Knox 에셋 인텔리전스를 사용하기 위한 전제 조건은 무엇인가요?', 'url': 'https://docs.samsungknox.com/admin/knox-asset-intelligence/faq/#prerequisites-for-kai', 'project': 'KAI', 'last_updated': '2023-07-26', 'id': 'eb3e656b-9af1-4e5e-8353-85f843c3fd63'}
#
# Score: 0.882704060467449
# ['90일 무료 평가판에는 무엇이 포함되어 있나요?Knox Asset Intelligence는 엔터프라이즈 모빌리티 솔루션 번들인 Knox Suite에 포함되어 있습니다.평가판 라이선스를 통해 90일 동안 최대 30개 디바이스에서 Knox Asset Intelligence 콘솔을 비롯한 모든 Knox Suite 제품과 해당 기능을 이용할 수 있습니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 313, 'title': '90일 무료 평가판에는 무엇이 포함되어 있나요?', 'url': 'https://docs.samsungknox.com/admin/knox-asset-intelligence/faq/#what-is-in-trial', 'project': 'KAI', 'last_updated': '2023-07-26', 'id': '559e82da-7f6f-4ccc-aef1-e9b1b45a5a22'}
# None
# ##############################
# similar_docs
# ##############################
#
# Score: 0.008360655737704918
# ['삼성 Knox 계정을 만드세요.가입하기 전에, 특히 디바이스를 해외에 등록할 계획인 IT 관리자인 경우 시작하기 전에 반드시 읽어보시기 바랍니다.Knox 계정 등록 삼성 Knox 계정은 무료이며 단 몇 분 만에 만들 수 있습니다.삼성 Knox 계정이 있으면 Knox 서비스에 등록하고 Knox 관리 포털에 액세스할 수 있습니다. Knox 관리 포털을 통해 각 Knox 서비스의 디바이스, 관리자, 라이선스를 쉽게 관리할 수 있습니다.삼성 Knox 계정을 등록하려면 계정을 삼성 계정에 연결해야 합니다.아직 삼성 계정이 없는 경우 SamsungKnox.com에 가입할 때 계정을 만들라는 메시지가 표시됩니다.Knox 계정을 만들려면: 1.삼성녹스닷컴으로 이동하세요. 2.오른쪽 상단에서 시작하기를 클릭하세요. 3.비즈니스 이메일에서 업무에 사용하는 이메일 주소를 입력합니다.미국 및 EU 서버 모두에서 장치를 관리하는 데 두 개의 계정이 필요한 경우 이메일 사용자 이름에 +us 또는 +eu 또는 인식할 수 있는 다른 태그를 추가하세요.이렇게 하면 별도의 이메일 주소를 만들지 않고도 두 지역 계정에 모두 쉽게 액세스할 수 있습니다.자세한 내용은 시작하기 전에를 참조하십시오. 4.액세스하려는 Knox 솔루션 (Knox Suite, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 또는 기타 제품 및 서비스) 을 선택하세요.Knox 모바일 등록과 같은 개별 Knox Suite 서비스에 액세스하려면 Knox Suite를 선택하세요. 5.내 계정 생성을 클릭합니다.삼성 계정이 없는 경우 계정을 만들라는 메시지가 표시됩니다.삼성 계정을 생성한 후 수신한 확인 이메일을 열고 링크를 클릭합니다.그러면 자동으로 SamsungKnox.com으로 리디렉션되어 등록을 계속할 수 있습니다. 6.등록 시 입력한 삼성 계정 세부 정보를 확인하십시오.정보가 정확하면 다음을 클릭하십시오: 회사 정보. 7.회사 세부 정보를 입력하세요']
# {'source': 'all_processed_data_ko.json', 'seq_num': 154, 'title': '삼성 Knox 계정 만들기', 'url': 'https://docs.samsungknox.com/admin/fundamentals/register-for-samsung-knox/create-a-samsung-knox-account', 'project': 'USP', 'last_updated': '2023-10-25', 'id': '99ea459d-9079-4586-a79f-ffa8b91e45c0'}
#
# Score: 0.008225806451612904
# ['Knox 지식 기반 문서.서비스별 기사, Knox Suite, 엔터프라이즈용 Knox 플랫폼, Knox 서비스 플러그인, Knox 모바일 등록, Knox 모바일 등록 다이렉트, Knox 캡처, Knox Asset Intelligence, Knox Manage, Knox E-FOTA, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 일반 기사 삼성 Knox, 삼성 Knox 디바이스 수리를 위한 사용자 경험 연구 요구 사항 삼성 디바이스의 문제를 해결하기 위한 로그 캡처 방법 레거시 One UI Core 플랫폼 문제 해결을 위해 브라우저 로그를 수집하는 방법 삼성에서 dumpstate 로그를 수집하는 방법웨어러블 디바이스 정보 Secure by Knox, Android, 기타 및 Android Go 디바이스 관련 Knox 지원 버전에 대한 정책 업데이트 삼성 계정을 등록할 때 인증 이메일을 받지 못하면 어떻게 해야 하나요?Knox 클라우드 서비스 Knox Suite 라이선스를 Knox Remote Support에서 복구할 수 없습니다. Knox 라이선스 키에서 디바이스를 분리하는 방법 Knox 라이선스 키의 사용자 수를 확인하는 방법 Knox 클라우드 서비스에서 사용자를 다시 초대하거나 차단을 해제하는 방법 삼성 Knox Cloud Services에서 슈퍼 관리자를 변경하는 방법 Knox Cloud Services와 삼성 디바이스와의 호환성 Knox Deployment 앱에서만 디바이스 추가 가능 필수 2단계 인증 Knox 배포 앱을 사용하는 모든 IT 관리자가 등록 중에 + 제스처를 사용하면 오류가 발생합니다.”태블릿/휴대폰이 이미 등록됨” Knox Cloud Services (KCS) 솔루션이 시작되지 않습니다. 삼성 계정을 변경한 후 SamsungKnox.com에 로그인할 수 없습니다. Knox 클라우드 서비스에 관리자를 초대할 수 없습니다 Knox 클라우드 서비스 포털은 모바일용으로 지원되지 않습니다']
# {'source': 'all_processed_data_ko.json', 'seq_num': 256, 'title': 'Knox 지식베이스 문서', 'url': 'https://docs.samsungknox.com/admin/fundamentals/kbas', 'project': 'USP', 'last_updated': '2023-07-26', 'id': 'b0488e51-b307-4590-84c4-654f827c7708'}
#
# Score: 0.008095238095238095
# ['.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox 모바일 등록 디바이스 소유자 (DO), 녹스 에셋 인텔리전스 녹스 모바일 등록 DO Knox E-FOTA Knox 에셋 인텔리전스 Knox 모바일 등록 DO 등록 DO 등록 및 디바이스 설정 마법사가 완료되면 KES가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox Configure, Knox 모바일 등록 및 Knox 에셋 인텔리전스 Knox 구성 Knox E-FOTA Knox 모바일 등록 Knox 에셋 인텔리전스 Knox Configure 등록 및 디바이스 설정 마법사가 끝나면 KES는 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 Knox 모바일 등록 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.Knox E-FOTA, Knox Configure, Knox 모바일 등록 DO 및 Knox 에셋 인텔리전스 녹스 모바일 등록 DO Knox 구성 Knox E-FOTA Knox 에셋 인텔리전스 구성 Knox 모바일 등록 DO Knox 모바일 등록 DO 등록, Knox Configure 등록 및 디바이스 설정 마법사가 끝나면 KES가 Knox E-FOTA 클라이언트 앱을 다운로드합니다.녹스 E-FOTA 등록이 시작됩니다.완료되면 KES는 Knox 애셋 인텔리전스 에이전트를 다운로드하고 등록을 시작합니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 116, 'title': '조직에 Knox 클라우드 서비스가 여러 개 있는 경우 Knox 클라우드 서비스 등록 순서', 'url': 'https://docs.samsungknox.com/admin/efota-one/kbas/kba-738-what-order-are-the-knox-services-enrolled', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id': 'a6e261c5-05a9-47ce-8fd7-2a1170e13198'}
#
# Score: 0.008032786885245903
# ['슈퍼 어드민이란 무엇인가요?.슈퍼 관리자 또는 기본 관리자는 SamsungKnox.com, Knox 클라우드 서비스 또는 Knox 파트너 프로그램에 처음으로 등록한 사용자를 말합니다.최고 관리자는 추가 관리자를 초대하여 각 Knox 서비스의 관리 콘솔 내에서 기능을 보고 관리할 수 있습니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 217, 'title': '슈퍼 어드민이란 무엇인가요?', 'url': 'https://docs.samsungknox.com/admin/fundamentals/knox-faq/#what-is-a-super-admin', 'project': 'USP', 'last_updated': '2023-07-26', 'id': 'd44583ef-a30c-45d6-a80e-79adf26e94c1'}
#
# Score: 0.00796875
# ['삼성 계정으로 로그인합니다.Knox 계정 등록 삼성 Knox 계정은 무료이며 단 몇 분 만에 만들 수 있습니다.삼성 Knox 계정이 있으면 Knox 서비스에 등록하고 Knox 관리 포털에 액세스할 수 있습니다. Knox 관리 포털을 통해 각 Knox 서비스의 디바이스, 관리자, 라이선스를 쉽게 관리할 수 있습니다.삼성 Knox 계정을 등록하려면 계정을 삼성 계정에 연결해야 합니다.아직 삼성 계정이 없는 경우 SamsungKnox.com에 가입할 때 계정을 만들라는 메시지가 표시됩니다.Knox 계정을 만들려면: 1.삼성녹스닷컴으로 이동하세요. 2.오른쪽 상단에서 시작하기를 클릭하세요. 3.비즈니스 이메일에서 업무용으로 사용하는 이메일 주소를 입력합니다. 4.액세스하려는 Knox 솔루션 (Knox Suite, Knox Configure, Knox Guard, 비즈니스용 삼성 케어+ 또는 기타 제품 및 서비스) 을 선택합니다.Knox 모바일 등록과 같은 개별 Knox Suite 서비스에 액세스하려면 Knox Suite를 선택하세요. 5.내 계정 생성을 클릭합니다.이미 삼성 계정이 있는 경우 회사 세부 정보가 포함된 양식을 작성하라는 메시지가 자동으로 표시됩니다.삼성 계정이 없는 경우 계정을 만들라는 메시지가 표시됩니다.삼성 계정을 생성한 후 수신한 확인 이메일을 열고 링크를 클릭합니다.그러면 자동으로 SamsungKnox.com으로 리디렉션되어 회사 세부 정보가 포함된 양식을 작성하고 Knox 서비스 신청서를 제출합니다.삼성 Knox 1에 로그인하세요.SamsungKnox.com의 오른쪽 상단에서 로그인 위로 마우스를 가져갑니다.그런 다음 삼성 계정에서 로그인을 클릭합니다. 2.삼성 계정 이메일을 입력한 후 다음을 클릭합니다. 3.삼성 계정 암호를 입력한 다음 로그인을 클릭합니다.이제 로그인하여 Knox 서비스 및 제품을 사용할 준비가 되었습니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 162, 'title': '삼성 계정으로 로그인', 'url': 'https://docs.samsungknox.com/admin/fundamentals/sign-up-for-samsung-knox/sign-in-with-a-samsung-account', 'project': 'USP', 'last_updated': '2023-08-23', 'id': '75e63bd9-ae43-4ef2-b5b0-9132389b0452'}
# None
# CPU times: user 23.2 ms, sys: 3.96 ms, total: 27.1 ms
# Wall time: 400 ms

# %% [markdown]
# # 7. 검증 인덱스 생성

# %% [markdown]
# ## Index 이름 결정

# %%
eval_index_name = "genai-poc-knox-kr-eval-sample-0.02-1024c-256o-v23"

# %% [markdown]
# ## Sampling

# %%
import random
def get_sampling_doc(seed, ratio, docs):

    random.seed(seed)
    
    eval_docs = docs[:int(len(docs)*ratio)]
    
    return eval_docs
    
eval_docs = get_sampling_doc(seed=200, ratio=0.02, docs= all_docs)
print("eval docs: ", len(eval_docs))
eval_docs[0:2]
# Out:
# eval docs:  34
# [Document(page_content='사용 방법 동영상.Knox E-FOTA를 사용하는 방법에 대한 비디오가 포함되어 있습니다.이 섹션에는 Knox E-FOTA를 사용하는 방법에 대한 비디오가 포함되어 있습니다.Knox E-FOTA 시작하기 이 동영상은 Knox E-FOTA 콘솔을 안내하며 리셀러 등록, 디바이스 승인, 캠페인 생성, 캠페인 할당, 디바이스 상태 모니터링 방법을 보여줍니다.Knox E-FOTA에서 캠페인 만들기 다음 동영상은 삼성 디바이스에 Knox E-FOTA 캠페인을 만들고 적용하는 방법에 대한 심층적인 정보를 제공합니다.Knox E-FOTA를 VMware Workspace ONE에 연결하기 다음 비디오에서는 Knox E-FOTA를 VMware Workspace ONE과 연결하는 동시에 워크스페이스 1에서 디바이스 그룹을 추가하는 간단한 단계를 설명합니다.', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 1, 'title': '사용 방법 동영상', 'url': 'https://docs.samsungknox.com/admin/efota-one/how-to-videos', 'project': 'EFOTA', 'last_updated': '2023-09-27'}),
#  Document(page_content='녹스 E-FOTA.Knox E-FOTA를 사용하면 기업 IT 관리자가 사용자 개입 없이 OS 버전과 보안 업데이트를 기업 디바이스에 원격으로 배포할 수 있습니다.배포 전에 업데이트를 테스트하여 사내 앱과 새 OS 버전 간의 호환성을 확인하고, 최신 보안 패치를 일정에 따라 배포하여 엔터프라이즈 디바이스의 보안을 강화하세요.대상 고객 무료 체험하기 이 문서의 대상: 시스템 보안 설계자 — Knox E-FOTA의 작동 원리와 Knox E-FOTA를 사용하여 엔터프라이즈 디바이스를 업데이트하는 방법을 알아보세요.IT 관리자 - 엔터프라이즈 디바이스의 무선 업데이트를 관리하는 방법을 알아보세요.솔루션을 사용해 보세요. Knox E-FOTA를 사용하여 모바일 업데이트 워크플로를 간소화하세요.버전 제어 관리를 활성화하고 업무 시간 외에 업데이트가 발생하도록 설정하여 OS 업데이트를 배포하여 생산성에 지장을 주지 않도록 하세요.튜토리얼 시작하기 Knox E-FOTA 소개 Knox E-FOTA"는 삼성 모바일 디바이스의 OS 버전을 제어하여 비용 효율성을 극대화하는 엔터프라이즈 솔루션입니다.IT 관리자는 이를 통해 다음과 같은 작업을 수행할 수 있습니다. 일정에 따라 최신 보안 패치를 디바이스에 배포하세요.배포 전에 업데이트를 테스트하여 사내 앱과 새 OS 버전 간의 호환성을 확인하십시오.주요 기능, 강제 업데이트 - 모든 장치에서 동일한 OS 버전을 사용할 수 있도록 강제 업데이트를 배포하여 장치 관리 환경을 간소화합니다.사용자 개입 없이 업데이트를 푸시할 수 있습니다.선택적 OS"버전 - 최신 OS 버전이 사내 앱과 항상 호환되는 것은 아닙니다.디바이스에 배포할 OS 버전을 제어하여 운영 연속성을 보장하세요.최신 OS 버전을 배포할 준비가 될 때까지 해당 버전으로 잠글 수 있습니다.정기 업데이트 - 업무 시간 외에 펌웨어 업데이트가 이루어지도록 예약하여 업무 중단을 최소화합니다.모든 기능의 전체 목록을 보려면 Knox E-FOTA의 제품 페이지를 방문하십시오.이점 1.소프트웨어 호환성 테스트 - 내부 앱과 새 OS 버전 간의 호환성을 보장하기 위해 소프트웨어를 테스트한 후에만 업데이트를 적용합니다.이를 통해 호환성 문제에 대한 IT 지원의 필요성을 최소화할 수 있습니다. 2.장치 보안 - 검증된 최신 펌웨어를 보안 유지관리 릴리스 (SMR) 라고도 하는 최신 보안 패치와 함께 사용자 개입 없이 즉시 회사에서 사용할 수 있는 모든 장치에 배포합니다. 3.효율적인 배포 - 디바이스가 업데이트를 다운로드하고 설치하는 시간을 지정하여 업무 중단을 최소화함으로써 생산성을 유지합니다.IT 관리자는 운영 연속성을 보장하기 위해 시차를 두고 업데이트 (예: 지역별) 를 배포할 수 있습니다. 4.효율적인 장치 관리 - 강제 업데이트를 원격으로 배포하면 모든 엔터프라이즈 장치에서 항상 검증된 최신 OS 버전을 실행할 수 있습니다.모든 디바이스를 한 눈에 파악할 수 있어 IT 관리자가 디바이스를 더 효율적으로 관리할 수 있습니다.사일런트 업데이트는 사용자 개입이 필요하지 않으므로 연기하거나 거부할 수 없습니다.Knox E-FOTA는 어떻게 작동하나요?FOTA (Firmware-over-the-Air) 는 IT 관리자가 효율적이고 안전하게 펌웨어 업데이트를 엔터프라이즈 모바일 디바이스에 푸시할 수 있는 서비스입니다.일반적으로 서비스 제공업체는 삼성 B2C (Business-to-Consumer) FOTA 서버를 통해 최신 펌웨어 업데이트를 디바이스에 푸시합니다.문제는 최신 펌웨어가 회사의 사내 앱과 항상 호환되는 것은 아니라는 점입니다.Knox E-FOTA가 없는 기업은 다음을 수행해야만 이 문제를 해결할 수 있습니다. 항상 최신 OS 버전으로 업데이트하고, EMM Knox E-FOTA를 사용하여 모든 OS 업데이트를 차단하십시오."관리자가 최신 버전이 아니더라도 배포할 펌웨어 버전을 선택할 수 있습니다.그러면 디바이스가 해당 버전으로 잠깁니다.관리자는 최신 펌웨어 버전에서 호환성 테스트를 수행한 후 기기를 테스트된 버전으로 업데이트할 수 있습니다.Knox E-FOTA를 통해 기업은 삼성 B2B (Business-to-Business) FOTA"서버에서 펌웨어 업데이트를 푸시합니다. 하지만 삼성의 Knox E-FOTA 서비스를 통하지 않고 자체 서버에서 펌웨어 업데이트를 제공하는 AT&T 및 Verizon과 같은 예외도 있습니다.그러면 B2B FOTA 서버가 디바이스 정보를 B2C FOTA 서버와 동기화합니다.#Downloading 펌웨어 버전 Knox E-FOTA를 통해 지난 12개월 이내에 일반 삼성 FOTA 서비스를 통해 출시된 공식 펌웨어 목록에 액세스할 수 있습니다.추가 상담을 통해 추가 펌웨어 목록을 제공할 수 있습니다.펌웨어 업데이트를 푸시할 때 삼성은 현재 펌웨어 버전에서 대상 버전으로 업데이트하기 위한 델타 파일 또는 변경 파일을 생성합니다.그런 다음 일반 Samsung FOTA 서버를 통해 릴리스되고 무선으로 엔터프라이즈 장치에 전달됩니다.펌웨어 파일은 Knox E-FOTA 서버에서 평균 12개월 동안 사용할 수 있습니다.경우에 따라, 특히 주요 Android OS 버전으로 디바이스를 업그레이드할 때 대상 펌웨어 버전에 도달하기 위해 여러 델타 파일을 다운로드해야 할 수 있습니다.Knox E-FOTA"Advanced에서는 대상 버전에 도달하기 위해 여러 캠페인을 점진적으로 실행해야 할 수 있습니다.Knox E-FOTA와 MDM의 “Knox E-FOTA”에서는 하나의 캠페인만 필요합니다. 필요한 델타 파일은 순차적으로 자동으로 설치됩니다.사용 중인 Knox E-FOTA 에디션에 관계없이 이 경우 디바이스가 여러 번 재부팅됩니다.Knox E-FOTA 에디션 비교하기 Knox E-FOTA 서비스에는 Knox E-FOTA, Knox E-FOTA"어드밴스드, MDM용 Knox E-FOTA의 세 가지 에디션이 있습니다. 이 섹션에서는 Knox E-FOTA 서비스의 주요 차별화 기능에 대해 설명합니다.MDM에서 Knox E-FOTA 기능 사용 Knox E-FOTA Advanced Knox E-FOTA 설명 선택적 OS 버전 ✔ ✔ ✔ 디바이스에 배포할 OS 버전을 선택하고, 내부 앱으로 검증되지 않은 OS 버전에 대한 업데이트를 방지합니다.강제 업데이트 (무음) ✔ ✔ ✔ 사용자 개입 없이 장치에 OS 업데이트를 배포할 수 있습니다.예약 업데이트 ✔ ✔ ✔ OS 업데이트를 다운로드하고 설치할 특정 날짜 및 시간 범위 (예: 업무 시간 외) 를 설정합니다.강제 업데이트 (중요) ✔ ✔ 중요한 작업이 진행 중인 동안 사용자가 업데이트를 연기할 수 있도록 허용합니다 (최대 지연 기간 포함).사용자는 업데이트를 거부할 수 없습니다.추가 캠페인 옵션 ✔ ✔ 다음 옵션 설정: 로밍 중 펌웨어 다운로드 허용.충전 도크에 연결된 경우에만 설치를 허용합니다.캠페인 상태 보기 기능 ✔ ✔ 캠페인 운영 상태 보기.디바이스 및 캠페인 상태에 대한 모니터링 대시보드 위젯은 Knox E-FOTA Advanced에서 사용할 수 있습니다. ✔ 대시보드를 통해 Knox E-FOTA의 다양한 영역을 모니터링할 수 있습니다.독립 웹 콘솔 ✔ ✔ 웹 포털을 통해 관리 작업을 수행합니다.네트워크 대역폭 제어 ✔ ✔ 설정된 최대 대역폭 내에서 펌웨어 업데이트를 배포합니다.Wi-Fi 전용 모드 ✔ ✔ Wi-Fi를 통해서만 다운로드 및 업데이트가 이루어지도록 설정하여 셀룰러 사용 비용을 절감할 수 있습니다.캠페인당 여러 모델 업데이트 가능 ✔ 단일 캠페인에서 여러 장치 모델을 서로 다른 펌웨어 릴리스에 할당할 수 있습니다.캠페인당 순차 업데이트 ✔ ✔ 단 하나의 캠페인으로 모든 버전에서 대상 버전으로 업데이트.즉, 기기를 현재 버전에서 대상 버전으로 점진적으로 업데이트하기 위해 여러 캠페인을 만들 필요가 없습니다.장치 그룹 및 조직 정보를 EMM과 동기화하는 기능 ✔ ✔ EMM에서 장치 그룹을 가져와서 장치 관리 작업을 간소화합니다.Knox E-FOTA를 EMM에 연결하면 디바이스 그룹이 동기화되지 않도록 할 수 있습니다.디바이스 정보는 EMM에서  ...

# %%
chunk_docs = text_splitter.split_documents(eval_docs)
print(f"Number of chunk_docs after split and chunking= {len(chunk_docs)}")
# Out:
# Number of chunk_docs after split and chunking= 90

# %% [markdown]
# ## 오픈 서치 인덱스 유무에 따라 삭제
# 오픈 서치에 해당 인덱스가 존재하면, 삭제 합니다.

# %%
index_exists = opensearch_utils.check_if_index_exists(
    os_client,
    eval_index_name
)

if index_exists:
    opensearch_utils.delete_index(
        os_client,
        eval_index_name
    )
    
opensearch_utils.create_index(os_client, eval_index_name, index_body)
index_info = os_client.indices.get(index=eval_index_name)
print("Index is created")
pprint(index_info)
# Out:
# index_name=genai-poc-knox-kr-eval-sample-0.02-1024c-256o-v23, exists=False
#
# Creating index:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'genai-poc-knox-kr-eval-sample-0.02-1024c-256o-v23'}
# Index is created
# {'genai-poc-knox-kr-eval-sample-0.02-1024c-256o-v23': {'aliases': {},
#                                                        'mappings': {'properties': {'metadata': {'properties': {'last_updated': {'type': 'date'},
#                                                                                                                'project': {'type': 'keyword'},
#                                                                                                                'seq_num': {'type': 'long'},
#                                                                                                                'source': {'type': 'keyword'},
#                                                                                                                'title': {'type': 'text'},
#                                                                                                                'url': {'type': 'text'}}},
#                                                                                    'text': {'analyzer': 'my_analyzer',
#                                                                                             'type': 'text'},
#                                                                                    'vector_field': {'dimension': 1536,
#                                                                                                     'type': 'knn_vector'}}},
#                                                        'settings': {'index': {'analysis': {'analyzer': {'my_analyzer': {'char_filter': ['html_strip'],
#                                                                                                                         'filter': ['my_nori_part_of_speech'],
#                                                                                                                         'tokenizer': 'nori',
#                                                                                                                         'type': 'custom'}},
#                                                                                            'filter': {'my_nori_part_of_speech': {'stoptags': ['J',
#                                                                                                                                               'XSV',
#                                                                                                                                               'E',
#                                                                                                                                               'IC',
#                                                                                                                                               'MAJ',
#                                                                                                                                               'NNB',
#                                                                                                                                               'SP',
#                                                                                                                                               'SSC',
#                                                                                                                                               'SSO',
#                                                                                                                                               'SC',
#                                                                                                                                               'SE',
#                                                                                                                                               'XSN',
#                                                                                                                                               'XSV',
#                                                                                                                                               'UNA',
#                                                                                                                                               'NA',
#                                                                                                                                               'VCP',
#                                                                                                                                               'VSV',
#                                                                                                                                               'VX'],
#                                                                                                                                  'type': 'nori_part_of_speech'}},
#                                                                                            'tokenizer': {'nori': {'decompound_mode': 'mixed',
#                                                                                                                   'discard_punctuation': 'true',
#                                                                                                                   'type': 'nori_tokenizer'}}},
#                                                                               'creation_date': '1708851779059',
#                                                                               'knn': 'true',
#                                                                               'knn.space_type': 'cosinesimil',
#                                                                               'number_of_replicas': '1',
#                                                                               'number_of_shards': '5',
#                                                                               'provided_name': 'genai-poc-knox-kr-eval-sample-0.02-1024c-256o-v23',
#                                                                               'replication': {'type': 'DOCUMENT'},
#                                                                               'uuid': 'deDH3n1NT8m8mCal-gkaSw',
#                                                                               'version': {'created': '136327827'}}}}}

# %% [markdown]
# ## 검증 인덱스 생성

# %%
eval_vector_db = OpenSearchVectorSearch(
    index_name= eval_index_name,
    opensearch_url=opensearch_domain_endpoint,
    embedding_function=llm_emb,
    http_auth=http_auth, # http_auth
    is_aoss =False,
    engine="faiss",
    space_type="l2",
    bulk_size=100000,
    timeout=60    
)
vector_db

# %%
# %%time

eval_vector_db.add_documents(documents = chunk_docs, 
                        vector_field = "vector_field",
                        bulk_size = 1000000)
# Out:
# CPU times: user 226 ms, sys: 10.9 ms, total: 237 ms
# Wall time: 11.3 s
# ['dd900c44-530b-4353-997e-c4d8ed1dda66',
#  '62e1028a-5af1-4ec1-bcb8-f17199209d3a',
#  'b80d8eed-c084-4a3a-a707-0c7b5b0f0143',
#  '82bf40f6-c5f7-43ef-b4f5-371c5f00be45',
#  '425c4cbc-5059-4134-874d-486939107231',
#  '059e4fc4-32fd-48f0-a4de-59d0471fff07',
#  'ebaa09f5-751f-4bfc-8a8f-68b14a983893',
#  '4721036d-c146-4d38-8342-8e84df55018e',
#  'ead37fe0-c714-42ea-b767-02f8cb84c720',
#  'ac9d7fef-10f7-415c-b3da-5baa0405f6e4',
#  'edc3eb77-d9a0-49e4-885a-b0b86312aeff',
#  '1519a69b-89ab-42dc-8448-1c8e5b3027d5',
#  'b6a881a2-395e-475f-8e27-f1ffbae667ff',
#  '366acede-e763-4a56-bc03-9eda3624121d',
#  '7bc79efc-3cca-4785-91bd-8088d27e2ab6',
#  'c6162e64-3450-4315-9f32-2587e4ecfd05',
#  'c23c03cb-b79f-4d4a-b962-1076e576daf8',
#  '47f1acf1-85ee-44aa-9cf6-12d12ecf44d1',
#  'a6838dfd-af7e-431a-87a7-886b501995df',
#  'bf392ab7-123e-42bc-bf94-d4ecc02ec8cc',
#  '4adc1014-57ff-46dc-a9d9-9f567b0d4f1e',
#  '873932d1-aa07-4934-9998-e250bb858864',
#  'd3053676-c36f-4c00-8360-3222bb0ae64e',
#  'f939d1df-2db6-41b0-98f8-7408967a6579',
#  'c4deef0c-f76a-4a14-b737-783579b3f55e',
#  '8f11eefc-4bae-4060-913a-b01c959bfbbb',
#  '477e4989-fc9a-42da-af52-b29b28fd6c63',
#  'db919b98-3633-42e4-9756-84f54566b8a2',
#  '094d1f62-4e40-4b40-b55b-b0e569324809',
#  '7699dc3a-c0c3-4d77-ad60-07bd6ba418af',
#  'fb839b66-0aae-4171-8f5e-2ce3461a50ac',
#  '1c82c14d-6d97-4331-922f-12d523151ffc',
#  'c1f943a8-bca3-431a-931c-05ef015a8bea',
#  '106c8b7f-9702-49c5-aa89-bc3b530b1313',
#  '7073aa5c-7a48-444b-83b2-7895cdee978a',
#  'e52e13cc-dd45-40db-9f37-b3fa933b377d',
#  'c6b1d1b4-05c8-4ea6-82aa-9287bb067cdf',
#  '7ecb11fc-264d-4633-b1b9-3e6b6c3192de',
#  'a82705b2-7ff3-4950-ab64-7e32202c1114',
#  'f4204fe6-615e-418a-ad16-8e7246a56f9d',
#  '4a46a7ee-8641-435e-9c5e-878393d9eb90',
#  '0e743081-b89e-4cbd-8ce5-bc7624ce727c',
#  'b0becdb3-18bf-4be4-970b-5c5cb6dc3ba4',
#  '8c3ce8fe-1afa-452b-8a7c-d9e7d28e1231',
#  '0f79f608-4798-4def-9e83-2617313899ba',
#  '75a33d66-1b7a-44d5-bc2e-9a641b217aee',
#  'd7048ad7-43c7-4ce8-8bc9-ee3af058d72a',
#  '79fdd7c6-f511-4a26-9568-9284bf83bb58',
#  '4d275c69-2f58-4ab6-b835-cad0901fd3da',
#  'ea99c148-147e-46c5-ac41-8f9597e37748',
#  '24ec9ed2-ff2f-47a2-8974-caced1e6df2e',
#  '262d440c-4486-4491-8463-b59949c92059',
#  '7b68cf12-581e-49fc-8f72-2b8fddad2b2f',
#  '09819a05-0d4b-43e7-9f2a-f40011a4d029',
#  'bfa517be-f5b8-437b-a7c6-8ee931f409b0',
#  'bc813025-15aa-42f1-b04d-523f9ddbbfcc',
#  'bbc1c680-6449-4e44-b24f-71a7357ca83f',
#  '51d08e05-4fce-458d-a50f-c97dc10ad0cd',
#  '34fe256b-14a3-4c29-8524-5eee8fa18ae8',
#  '4dbd36c9-7bcd-44c3-b144-83c590bf357b',
#  'c943c960-5ef2-4b2f-94ae-2e978ef2ac19',
#  'd771c0c1-771f-4b08-8842-f0efb7d224af',
#  'ef39bc7a-3c48-496d-a97f-79a00fa2ebd0',
#  'f2d064a6-bc84-4d09-8521-093f24c0dd94',
#  '95df069b-7aa6-4a7c-be4b-1c9e73ad6533',
#  '5bf76b26-de30-458f-ad26-830836331254',
#  '0f26dc8f-32d0-416d-a0df-1e7c0253d2d9',
#  'deb506f5-3a25-4931-b576-d9b19fe83e9c',
#  '23320c08-c75f-44fe-afc0-a223098739bf',
#  'cf776bd1-0335-4a61-a632-914b983ad166',
#  '6762a951-c7d5-44b6-96e7-697672ad8616',
#  '8fee6f04-c2b6-47dc-9c44-5aadc2373d32',
#  '82cb87d7-3575-4763-bbb6-e1e3b51f8339',
#  '4daa5ea8-f90a-4ae4-a5e2-a4d2b4f66bd6',
#  '6bd9e6be-d85d-4a01-aa52-ef7351bebc79',
#  'f3b70d57-28a5-4cb7-a6e5-9eff700b2544',
#  '9b6add53-7009-48b2-9bcd-4e189e44436c',
#  '10c423d7-6c42-4542-81b5-dd797d21d80f',
#  'f5906d4f-33aa-48d0-8e38-ae9b45456feb',
#  '879cde30-7992-49fe-adcd-d8588ee25c27',
#  'd8d4be0b-0e10-4759-9e60-97690ece9e22',
#  'e510bcec-82ba-42f1-a9f8-77a87e2424ec',
#  'c619450f-0055-493d-8384-3492e135cce8',
#  '5cbe59f6-6d42-4dfe-98b9-d3dd5ded7bb2',
#  'dea72598-0b10-45e5-8776-0a70a0443975',
#  'aa4a4783-2684-44be-9ebb-f2b4f4eccc8e',
#  '91114001-d43b-44dd-b9b4-0773f68ae9dc',
#  'a63ef078-ecb2-4695-954b-4e063591eee2',
#  '52dca177-4e0e-4281-8fac-b44b3465083c',
#  '16dc3a40-8929-4e24-8d44-7269f9a09f62']

# %%
from local_utils.proc_docs import search_hybrid

# %%
# %%time


filter01 = "[]"
filter02 = "[]"

# query = "how to add image"
query = "이미지 추가 하는 방법"

search_hybrid_result = search_hybrid(
    query=query,
    vector_db= eval_vector_db,
    k=3,
    index_name= eval_index_name,
    os_client=os_client,
    filter=[
        {"term": {"metadata.type": filter01}},
        {"term": {"metadata.source": filter02}},
    ],
    Semantic_Search = False,    
    Lexical_Search = False,    
    Hybrid_Search = True,     
    minimum_should_match = 75,   
    fusion_algorithm="RRF", # ["RRF", "simple_weighted"]
    ensemble_weights=[.5, .5], # 시멘트 서치에 가중치 0.5 , 키워드 서치 가중치 0.5 부여.
    verbose=True
)
# Out:
# Query:
#  이미지 추가 하는 방법
# ##############################
# similar_docs_semantic
# ##############################
#
# Score: 1.0
# ['. 4.작업을 클릭하고 수행하려는 작업을 선택합니다.또한 장치 추가에 대한 자세한 내용은 장치 추가를 참조하십시오.기기 로그 보기 기기 로그에는 기기에서 발생한 이벤트 목록이 표시됩니다.각 이벤트에 대해 결과 디바이스 상태가 타임스탬프와 함께 표시됩니다. 1.Knox 관리 포털에 로그인하세요.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.디바이스 > 모든 디바이스로 이동합니다. 3.보려는 장치의 장치 ID를 클릭합니다. 4.장치 세부 정보 팝업에서 장치 로그 보기를 클릭합니다.장치에 태그 지정 태깅은 장치에 레이블을 지정하고 장치 목록에서 쉽게 검색하려는 경우에 유용합니다.예를 들어, 비즈니스 기능 또는 장치 사용자의 위치를 기준으로 장치에 레이블을 지정할 수 있습니다.이 섹션에서는 단일 장치에 태그를 지정하는 방법을 설명합니다.한 번에 여러 장치에 동일한 태그를 지정하려면 장치에서 일반적인 작업 수행을 참조하십시오. 1.Knox 관리 포털에 로그인하세요.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.디바이스 > 모든 디바이스로 이동합니다. 3.태그하려는 장치의 장치 ID를 클릭합니다. 4.장치 세부 정보 대화 상자의 태그 필드에 장치에 연결할 레이블을 입력합니다.예: 판매. 5.저장을 클릭합니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 25, 'title': '디바이스 관리', 'url': 'https://docs.samsungknox.com/admin/efota-one/features/manage-devices', 'project': 'EFOTA', 'last_updated': '2023-09-06'}
# --------------------------------------------------
#
# Score: 0.9975892540590087
# ['.그래프는 매주 월요일 (UTC± 00:00) 에 업데이트됩니다.펌웨어 추세를 클릭하면 펌웨어 버전, 모델, 판매 코드, CSC, 보안 패치, 장치 수 등 해당 보안 패치의 장치에 대한 추가 정보를 볼 수 있습니다.특정 캠페인, 모델, 판매 코드 또는 CSC의 장치만 표시하는 사용자 지정 필터를 사용하여 그래프를 최대 두 개까지 추가할 수 있습니다.최신 보안 패치 비율에는 최신 패치를 적용한 장치의 비율, 최신 패치 이전 패치를 적용한 장치의 비율, 이전 패치를 적용한 장치의 비율이 표시됩니다.펌웨어 트렌드는 디바이스에 설치된 패치만 고려합니다.설치되지 않은 릴리스 패치는 모두 무시합니다.OS 트렌드 그래프 OS 트렌드 그래프는 등록된 모든 장치의 다양한 OS 버전을 원형 차트로 보여줍니다.차트에는 각 OS 버전의 디바이스 수가 포함되어 있습니다.자세한 내용을 보려면 관심 있는 OS 버전 옆에 있는 장치 수를 클릭하십시오.장치 목록은 선택한 OS 버전에 맞게 필터링됩니다.활성 캠페인 활성화한 각 캠페인에 대해 대시보드에 캠페인 위젯이 표시됩니다.활성 캠페인 위젯을 여러 개 만들 수 있습니다.활성 캠페인 위젯에는 다음과 같은 세부 정보가 표시됩니다.상태 보기에는 완료율, 오류 - 오류가 발생한 장치 수가 표시됩니다.주의 - 주의가 필요한 장치의 수.이 버튼을 클릭하면 작업이 필요한 장치를 표시하도록 필터링된 장치 목록이 표시됩니다.진행 중 - 펌웨어 업데이트를 아직 다운로드 또는 설치하지 않은 장치 수.완료 - 대상 펌웨어가 최신 상태인 장치 수시작되지 않음 - 펌웨어 업데이트를 시작하지 않은 장치 수입니다.상태 보기가 실시간으로 업데이트됩니다.트렌드 보기는 지난 2주 동안의 캠페인 성공률을 보여줍니다.이 뷰는 하루에 한 번 업데이트됩니다.KCS 1.32 이전에 활성화된 캠페인에는 트렌드 보기가 표시되지 않습니다.네트워크 뷰에는 디바이스가 펌웨어를 설치할 때 사용한 네트워크를 원형 차트로 보여줍니다.다음을 수행할 수 있습니다']
# {'source': 'all_processed_data_ko.json', 'seq_num': 27, 'title': '운영 모니터링', 'url': 'https://docs.samsungknox.com/admin/efota-one/features/monitor-operations', 'project': 'EFOTA', 'last_updated': '2023-09-06'}
# --------------------------------------------------
#
# Score: 0.995629897542903
# ['.예를 들어 출시율이 20% 이면 장치의 20% 에서 첫날에 펌웨어 업데이트가 시작되고 다음 날 20% 에서 다음 날, 5일째까지 장치의 100% 가 업데이트됩니다.점진적 캠페인 출시에서는 다음과 같은 동작이 나타납니다. 1.롤아웃 속도, 대상 펌웨어 버전 또는 캠페인 상태를 변경하면 할당된 모든 장치의 롤아웃 시작 날짜가 재설정됩니다. 2.새로 할당된 장치에 캠페인을 배포해도 캠페인이 이미 할당된 장치의 출시 시작 날짜는 재설정되지 않으므로 펌웨어 업데이트 푸시가 지연되는 것을 방지할 수 있습니다.이 캠페인 기간 동안 꺼진 기기는 해당 기기가 켜질 때까지 보류 중 상태로 유지됩니다.캠페인 기간 동안 기기가 꺼져 있으면 업데이트 명령을 받을 수 없습니다.경우에 따라, 특히 주요 Android OS 버전으로 기기를 업그레이드하는 경우, 캠페인을 하나만 적용했더라도 대상 펌웨어 버전에 도달하기 위해 여러 펌웨어 업데이트가 점진적으로 설치됩니다.이 프로세스를 통해 실제로 발생한 펌웨어 업데이트 수에 따라 기기가 여러 번 자동으로 재부팅됩니다.기존 캠페인에 기기 배정 기존 캠페인에 기기를 배정할 수 있습니다: 1.디바이스로 이동합니다. 2.할당하려는 장치를 선택합니다. 3.작업 > 캠페인 할당을 클릭합니다. 4.장치를 할당할 캠페인을 선택합니다. 5.할당을 클릭합니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 32, 'title': '캠페인 만들기', 'url': 'https://docs.samsungknox.com/admin/efota-one/features/create-a-campaign/create-a-campaign', 'project': 'EFOTA', 'last_updated': '2023-09-06'}
# --------------------------------------------------
# lexical search query:
# {'query': {'bool': {'filter': [],
#                     'must': [{'match': {'text': {'minimum_should_match': '75%',
#                                                  'operator': 'or',
#                                                  'query': '이미지 추가 하는 방법'}}}]}},
#  'size': 3}
# ##############################
# similar_docs_keyword
# ##############################
#
# Score: 1.0
# ['기기 관리.Knox E-FOTA에서 도구를 사용하여 디바이스를 관리하는 방법을 설명합니다.이 섹션에서는 디바이스 탭의 도구를 사용하여 Knox E-FOTA에서 디바이스를 관리하는 방법을 설명합니다.이 탭에서 디바이스 정보를 보고, 디바이스를 편집하고, 디바이스를 삭제하고, 디바이스에 레이블을 지정할 수 있습니다.장치 정보 보기 1.Knox 관리 포털에 로그인합니다.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.디바이스 > 디바이스로 이동합니다. 3.(선택 사항) 검색 필드에 검색 문자열을 입력하여 장치 목록을 세분화합니다.기기 ID, 모델, 캠페인, 태그 4 필드를 검색할 수 있습니다.기기 목록을 검토하세요.장치 목록을 생성하려면 작업 > 장치를 CSV로 다운로드를 클릭합니다.장치를 선택하지 않은 경우 모든 장치가 CSV 파일에 포함됩니다.각 장치에는 다음과 같은 세부 정보가 있습니다. IMEI/MEID - 장치와 관련된 고유 ID.모델 - 기기 모델.펌웨어 버전 - 장치에 설치된 펌웨어 버전.OS 버전 - 장치에 설치된 Android OS 버전.에이전트 버전 - 디바이스에 설치된 Knox E-FOTA 클라이언트 앱 버전입니다.캠페인 - 디바이스가 할당된 캠페인 (있는 경우).상태 - 장치의 현재 상태.자세한 내용은 기기 상태를 참조하십시오.이동통신사 코드 - 이동통신사 코드는 이동통신사별 SIM 카드를 삽입할 때 다중 소비자 소프트웨어 사용자 지정 (다중 CSC) 에서 지정됩니다.보안 패치 정보 - 현재 기기에 적용된 Android 보안 패치입니다.추가됨 - 기기를 추가한 날짜와 기기를 추가한 사용자수정 날짜 - 장치를 마지막으로 수정한 날짜.예: 장치가 추가되었습니다.기기 상태가 변경되었습니다.캠페인이 변경되었습니다.라이선스가 변경되었습니다.출처가 변경되었습니다.EMM 그룹이 변경되었습니다.EMM 그룹 - 장치가 속한 EMM의 장치 그룹 (있는 경우)소스 - EMM, 리셀러 업로드 또는 CSV 파일 업로드를 통해 디바이스가 추가된 방법']
# {'source': 'all_processed_data_ko.json', 'seq_num': 25, 'title': '디바이스 관리', 'url': 'https://docs.samsungknox.com/admin/efota-one/features/manage-devices', 'project': 'EFOTA', 'last_updated': '2023-09-06', 'id': '09819a05-0d4b-43e7-9f2a-f40011a4d029'}
# --------------------------------------------------
#
# Score: 0.837530956098002
# ['기기 추가.Knox E-FOTA에 디바이스를 추가하는 방법을 설명합니다.활성 상태의 Knox E-FOTA 라이선스가 있으면 Knox E-FOTA에 디바이스를 추가할 수 있습니다.Knox E-FOTA에 추가하는 디바이스는 후보 디바이스 풀에 배치됩니다.이 풀에서 Knox E-FOTA에 등록하려는 디바이스를 선택할 수 있습니다.등록한 디바이스는 라이선스 시트를 사용합니다.장치를 등록한 후에는 업데이트 캠페인에 할당할 수 있습니다.디바이스를 추가하는 방법은 여러 가지가 있습니다. 리셀러를 통해, 지원되는 EMM을 통해, CSV 파일 업로드를 통해, 리셀러로부터 구매한 디바이스 추가 리셀러로부터 디바이스를 구매하는 경우 Knox 고객 ID를 해당 디바이스에 제공해야 합니다.Knox 고객 ID는 리셀러 탭에 표시됩니다.리셀러는 이 ID를 사용하여 디바이스를 Knox E-FOTA에 업로드하므로 디바이스를 직접 추가할 필요가 없습니다.리셀러의 모든 업로드를 자동 승인하거나 업로드를 수동으로 승인할 수 있습니다.Android P 이상이 설치된 리셀러로부터 구매한 디바이스에는 OOBE (OOBE) 중에 Knox E-FOTA 클라이언트 앱이 자동으로 설치됩니다.#Register a 리셀러 이 절차에서는 리셀러를 등록하고 디바이스 업로드를 자동 승인하는 방법을 설명합니다.이 절차를 진행하려면 기기를 구매한 리셀러의 리셀러 ID가 필요합니다.리셀러 ID를 받고 Knox 고객 ID를 해당 리셀러에게 제공해야 합니다. 1.Knox 관리 포털에 로그인하세요.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.리셀러로 이동한 다음 리셀러 등록을 클릭합니다. 3.리셀러 ID를 입력하고 조회를 클릭합니다. 4.리셀러를 찾으면 등록을 클릭합니다.리셀러가 등록되었습니다.다음 화면에서 이 리셀러의 기본 설정을 관리할 수 있습니다.언제든지 이 화면으로 돌아가서 기본 설정을 변경할 수 있습니다. 5.(선택 사항) 이 리셀러의 모든 업로드 자동 승인을 선택합니다. 6.(선택 사항) 기기를 할당할 기본 캠페인을 선택합니다']
# {'source': 'all_processed_data_ko.json', 'seq_num': 34, 'title': '기기 추가', 'url': 'https://docs.samsungknox.com/admin/efota-one/get-started/add-devices', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id': 'aa4a4783-2684-44be-9ebb-f2b4f4eccc8e'}
# --------------------------------------------------
#
# Score: 0.7419527526326801
# ['IBM에서 디바이스 그룹을 추가합니다.IBM 계정에 연결하고 Knox E-FOTA와 디바이스 그룹을 동기화하는 방법을 설명합니다.이 절차에서는 IBM 계정에 연결하고 Knox E-FOTA와 동기화할 디바이스 그룹을 선택하는 방법을 설명합니다.이 절차에서는 IBM에 연결하는 데 필요한 사전 절차를 수행했다고 가정합니다.IBM에서 디바이스 그룹을 추가하려면: 1.Knox 관리 포털에 로그인하세요.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.EMM 그룹으로 이동한 다음 EMM 연결을 클릭합니다. 3.IBM을 선택하세요. 4.자격 증명을 입력합니다. URL - 파트너 기본 URL (예: https\\ ://services.m3.maas360.com/)결제 ID - 계정 ID.로그인하면 IBM MaaS 360 관리 포털의 하단에서 확인할 수 있습니다.사용자 이름 - IBM MaaS 360 관리 포털에 로그인할 때 사용하는 사용자 이름입니다.비밀번호 - IBM MaaS 360 관리 포털에 로그인할 때 사용하는 비밀번호입니다.앱 ID - 생성한 액세스 키와 연결된 앱 ID입니다.앱 액세스 키 - 생성한 앱 액세스 키입니다.앱 버전 - 생성한 액세스 키와 연결된 앱 버전입니다.플랫폼 ID - 생성한 액세스 키와 연결된 플랫폼 ID입니다. 5.연결을 클릭합니다.IBM의 디바이스 그룹이 로드되었습니다. 6.Knox E-FOTA에 동기화하려는 디바이스 그룹을 선택합니다.디바이스 그룹에는 삼성 디바이스만 표시됩니다. 7.E-FOTA 그룹 추가를 클릭합니다.디바이스 그룹이 Knox E-FOTA에 추가되고 해당 세부 정보가 EMM과 동기화됩니다.동기화가 완료되면 디바이스 그룹 이름을 클릭하여 해당 그룹의 디바이스를 볼 수 있습니다.Knox E-FOTA에서는 디바이스 그룹 정보를 수정할 수 없습니다.이는 EMM 콘솔을 통해서만 가능합니다.24시간마다 디바이스 그룹 정보가 EMM에서 Knox E-FOTA로 동기화됩니다.EMM 그룹 탭의 오른쪽 상단에 있는 지금 동기화를 클릭하여 수동 동기화를 수행할 수도 있습니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 10, 'title': 'IBM의 디바이스 그룹 추가', 'url': 'https://docs.samsungknox.com/admin/efota-one/emm-integration/ibm/add-device-groups-from-ibm', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id': '1c82c14d-6d97-4331-922f-12d523151ffc'}
# --------------------------------------------------
# ##############################
# similar_docs_ensemble
# ##############################
#
# Score: 0.00819672131147541
# ['기기 관리.Knox E-FOTA에서 도구를 사용하여 디바이스를 관리하는 방법을 설명합니다.이 섹션에서는 디바이스 탭의 도구를 사용하여 Knox E-FOTA에서 디바이스를 관리하는 방법을 설명합니다.이 탭에서 디바이스 정보를 보고, 디바이스를 편집하고, 디바이스를 삭제하고, 디바이스에 레이블을 지정할 수 있습니다.장치 정보 보기 1.Knox 관리 포털에 로그인합니다.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.디바이스 > 디바이스로 이동합니다. 3.(선택 사항) 검색 필드에 검색 문자열을 입력하여 장치 목록을 세분화합니다.기기 ID, 모델, 캠페인, 태그 4 필드를 검색할 수 있습니다.기기 목록을 검토하세요.장치 목록을 생성하려면 작업 > 장치를 CSV로 다운로드를 클릭합니다.장치를 선택하지 않은 경우 모든 장치가 CSV 파일에 포함됩니다.각 장치에는 다음과 같은 세부 정보가 있습니다. IMEI/MEID - 장치와 관련된 고유 ID.모델 - 기기 모델.펌웨어 버전 - 장치에 설치된 펌웨어 버전.OS 버전 - 장치에 설치된 Android OS 버전.에이전트 버전 - 디바이스에 설치된 Knox E-FOTA 클라이언트 앱 버전입니다.캠페인 - 디바이스가 할당된 캠페인 (있는 경우).상태 - 장치의 현재 상태.자세한 내용은 기기 상태를 참조하십시오.이동통신사 코드 - 이동통신사 코드는 이동통신사별 SIM 카드를 삽입할 때 다중 소비자 소프트웨어 사용자 지정 (다중 CSC) 에서 지정됩니다.보안 패치 정보 - 현재 기기에 적용된 Android 보안 패치입니다.추가됨 - 기기를 추가한 날짜와 기기를 추가한 사용자수정 날짜 - 장치를 마지막으로 수정한 날짜.예: 장치가 추가되었습니다.기기 상태가 변경되었습니다.캠페인이 변경되었습니다.라이선스가 변경되었습니다.출처가 변경되었습니다.EMM 그룹이 변경되었습니다.EMM 그룹 - 장치가 속한 EMM의 장치 그룹 (있는 경우)소스 - EMM, 리셀러 업로드 또는 CSV 파일 업로드를 통해 디바이스가 추가된 방법']
# {'source': 'all_processed_data_ko.json', 'seq_num': 25, 'title': '디바이스 관리', 'url': 'https://docs.samsungknox.com/admin/efota-one/features/manage-devices', 'project': 'EFOTA', 'last_updated': '2023-09-06', 'id': '09819a05-0d4b-43e7-9f2a-f40011a4d029'}
# --------------------------------------------------
#
# Score: 0.00819672131147541
# ['. 4.작업을 클릭하고 수행하려는 작업을 선택합니다.또한 장치 추가에 대한 자세한 내용은 장치 추가를 참조하십시오.기기 로그 보기 기기 로그에는 기기에서 발생한 이벤트 목록이 표시됩니다.각 이벤트에 대해 결과 디바이스 상태가 타임스탬프와 함께 표시됩니다. 1.Knox 관리 포털에 로그인하세요.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.디바이스 > 모든 디바이스로 이동합니다. 3.보려는 장치의 장치 ID를 클릭합니다. 4.장치 세부 정보 팝업에서 장치 로그 보기를 클릭합니다.장치에 태그 지정 태깅은 장치에 레이블을 지정하고 장치 목록에서 쉽게 검색하려는 경우에 유용합니다.예를 들어, 비즈니스 기능 또는 장치 사용자의 위치를 기준으로 장치에 레이블을 지정할 수 있습니다.이 섹션에서는 단일 장치에 태그를 지정하는 방법을 설명합니다.한 번에 여러 장치에 동일한 태그를 지정하려면 장치에서 일반적인 작업 수행을 참조하십시오. 1.Knox 관리 포털에 로그인하세요.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.디바이스 > 모든 디바이스로 이동합니다. 3.태그하려는 장치의 장치 ID를 클릭합니다. 4.장치 세부 정보 대화 상자의 태그 필드에 장치에 연결할 레이블을 입력합니다.예: 판매. 5.저장을 클릭합니다.']
# {'source': 'all_processed_data_ko.json', 'seq_num': 25, 'title': '디바이스 관리', 'url': 'https://docs.samsungknox.com/admin/efota-one/features/manage-devices', 'project': 'EFOTA', 'last_updated': '2023-09-06'}
# --------------------------------------------------
#
# Score: 0.008064516129032258
# ['기기 추가.Knox E-FOTA에 디바이스를 추가하는 방법을 설명합니다.활성 상태의 Knox E-FOTA 라이선스가 있으면 Knox E-FOTA에 디바이스를 추가할 수 있습니다.Knox E-FOTA에 추가하는 디바이스는 후보 디바이스 풀에 배치됩니다.이 풀에서 Knox E-FOTA에 등록하려는 디바이스를 선택할 수 있습니다.등록한 디바이스는 라이선스 시트를 사용합니다.장치를 등록한 후에는 업데이트 캠페인에 할당할 수 있습니다.디바이스를 추가하는 방법은 여러 가지가 있습니다. 리셀러를 통해, 지원되는 EMM을 통해, CSV 파일 업로드를 통해, 리셀러로부터 구매한 디바이스 추가 리셀러로부터 디바이스를 구매하는 경우 Knox 고객 ID를 해당 디바이스에 제공해야 합니다.Knox 고객 ID는 리셀러 탭에 표시됩니다.리셀러는 이 ID를 사용하여 디바이스를 Knox E-FOTA에 업로드하므로 디바이스를 직접 추가할 필요가 없습니다.리셀러의 모든 업로드를 자동 승인하거나 업로드를 수동으로 승인할 수 있습니다.Android P 이상이 설치된 리셀러로부터 구매한 디바이스에는 OOBE (OOBE) 중에 Knox E-FOTA 클라이언트 앱이 자동으로 설치됩니다.#Register a 리셀러 이 절차에서는 리셀러를 등록하고 디바이스 업로드를 자동 승인하는 방법을 설명합니다.이 절차를 진행하려면 기기를 구매한 리셀러의 리셀러 ID가 필요합니다.리셀러 ID를 받고 Knox 고객 ID를 해당 리셀러에게 제공해야 합니다. 1.Knox 관리 포털에 로그인하세요.왼쪽 사이드바에서 Knox E-FOTA를 클릭합니다. 2.리셀러로 이동한 다음 리셀러 등록을 클릭합니다. 3.리셀러 ID를 입력하고 조회를 클릭합니다. 4.리셀러를 찾으면 등록을 클릭합니다.리셀러가 등록되었습니다.다음 화면에서 이 리셀러의 기본 설정을 관리할 수 있습니다.언제든지 이 화면으로 돌아가서 기본 설정을 변경할 수 있습니다. 5.(선택 사항) 이 리셀러의 모든 업로드 자동 승인을 선택합니다. 6.(선택 사항) 기기를 할당할 기본 캠페인을 선택합니다']
# {'source': 'all_processed_data_ko.json', 'seq_num': 34, 'title': '기기 추가', 'url': 'https://docs.samsungknox.com/admin/efota-one/get-started/add-devices', 'project': 'EFOTA', 'last_updated': '2023-07-26', 'id': 'aa4a4783-2684-44be-9ebb-f2b4f4eccc8e'}
# --------------------------------------------------
# CPU times: user 7.79 ms, sys: 286 µs, total: 8.08 ms
# Wall time: 116 ms

# %% [markdown]
# # A. Reference

# %% [markdown]
# - [Building a RAG AI with OpenSearch Serverless and LangChain](https://caylent.com/blog/building-a-rag-with-open-search-serverless-and-lang-chain)
