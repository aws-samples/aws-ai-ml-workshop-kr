# %% [markdown]
# # Evaluation
# - For retriever
# - For generator

# %% [markdown]
# ## Setting
#  - Auto Reload
#  - path for utils

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os
module_path = "../../.."
sys.path.append(os.path.abspath(module_path))

# %% [markdown]
# ## 1. Bedrock Client 생성

# %%
import json
import boto3
from pprint import pprint
from termcolor import colored
from utils import bedrock, print_ww
from utils.bedrock import bedrock_info

# %% [markdown]
# ### ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----
# - os.environ["AWS_DEFAULT_REGION"] = "<REGION_NAME>"  # E.g. "us-east-1"
# - os.environ["AWS_PROFILE"] = "<YOUR_PROFILE>"
# - os.environ["BEDROCK_ASSUME_ROLE"] = "<YOUR_ROLE_ARN>"  # E.g. "arn:aws:..."
# - os.environ["BEDROCK_ENDPOINT_URL"] = "<YOUR_ENDPOINT_URL>"  # E.g. "https://..."

# %%
boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    endpoint_url=os.environ.get("BEDROCK_ENDPOINT_URL", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
)

aws_region = os.environ.get("AWS_DEFAULT_REGION", None)
print (colored("\n== FM lists ==", "green"))
pprint (bedrock_info.get_list_fm_models())
# Out:
# Create new client
#   Using region: None
#   Using profile: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
#
# == FM lists ==
# {'Claude-Instant-V1': 'anthropic.claude-instant-v1',
#  'Claude-V1': 'anthropic.claude-v1',
#  'Claude-V2': 'anthropic.claude-v2',
#  'Cohere-Embeddings-En': 'cohere.embed-english-v3',
#  'Cohere-Embeddings-Multilingual': 'cohere.embed-multilingual-v3',
#  'Command': 'cohere.command-text-v14',
#  'Command-Light': 'cohere.command-light-text-v14',
#  'Jurassic-2-Mid': 'ai21.j2-mid-v1',
#  'Jurassic-2-Ultra': 'ai21.j2-ultra-v1',
#  'Llama2-13b-Chat': 'meta.llama2-13b-chat-v1',
#  'Titan-Embeddings-G1': 'amazon.titan-embed-text-v1',
#  'Titan-Text-G1': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Light': 'amazon.titan-text-lite-v1'}

# %% [markdown]
# ## 2. Titan Embedding 및 LLM 인 Claude-v2 모델 로딩

# %% [markdown]
# ### LLM 로딩 (Claude-v2)

# %%
from langchain.llms.bedrock import Bedrock
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm_text = Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-V2"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

llm_text_light = Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-Instant-V1"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %% [markdown]
# ### Embedding 모델 선택

# %%
from utils.rag import KoSimCSERobertaContentHandler, SagemakerEndpointEmbeddingsJumpStart

# %%
def get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name=None):

    if is_bedrock_embeddings:
        # We will be using the Titan Embeddings Model to generate our Embeddings.
        from langchain.embeddings import BedrockEmbeddings
        llm_emb = BedrockEmbeddings(
            client=boto3_bedrock,
            model_id=bedrock_info.get_model_id(
                model_name="Titan-Embeddings-G1"
                #model_name="Cohere-Embeddings-En"
            )
        )
        print("Bedrock Embeddings Model Loaded")

    elif is_KoSimCSERobert:
        LLMEmbHandler = KoSimCSERobertaContentHandler()
        endpoint_name_emb = endpont_name
        llm_emb = SagemakerEndpointEmbeddingsJumpStart(
            endpoint_name=endpoint_name_emb,
            region_name=aws_region,
            content_handler=LLMEmbHandler,
        )
        print("KoSimCSERobert Embeddings Model Loaded")
    else:
        llm_emb = None
        print("No Embedding Model Selected")

    return llm_emb

# %% [markdown]
# #### [중요] is_KoSimCSERobert == True 일시에 endpoint_name 을 꼭 넣어 주세요.

# %%
is_bedrock_embeddings = True
is_KoSimCSERobert = False
aws_region = os.environ.get("AWS_DEFAULT_REGION", None)

##############################
# Parameters for is_KoSimCSERobert
##############################
if is_KoSimCSERobert: endpont_name = "<endpoint-name>"
else: endpont_name = None
##############################

llm_emb = get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name)
# Out:
# Bedrock Embeddings Model Loaded

# %% [markdown]
# ## 3. Depoly ReRanker model (if needed)

# %%
import json
import sagemaker
from sagemaker.huggingface import HuggingFaceModel

# %%
depoly = False

# %%
if depoly:

    try:
        role = sagemaker.get_execution_role()
    except ValueError:
        iam = boto3.client('iam')
        role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

    # Hub Model configuration. https://huggingface.co/models
    hub = {
        'HF_MODEL_ID':'BAAI/bge-reranker-large',
        'HF_TASK':'text-classification'
    }

    # create Hugging Face Model Class
    huggingface_model = HuggingFaceModel(
        transformers_version='4.26.0',
        pytorch_version='1.13.1',
        py_version='py39',
        env=hub,
        role=role, 
    )

    # deploy model to SageMaker Inference
    predictor = huggingface_model.deploy(
        initial_instance_count=1, # number of instances
        instance_type='ml.g5.xlarge' # instance type
    )

    print(f'Accept: {predictor.accept}')
    print(f'ContentType: {predictor.content_type}')
    print(f'Endpoint: {predictor.endpoint}')

# %% [markdown]
# ### Reranker

# %%
#endpoint_name = "huggingface-pytorch-inference-2023-11-15-04-37-45-120" # ml.m5.2xlarge
endpoint_name = "huggingface-pytorch-inference-2023-11-15-07-53-21-605" # ml.g5.xlarge

# %%
runtime_client = boto3.Session().client('sagemaker-runtime')
print (f'runtime_client: {runtime_client}')
# Out:
# runtime_client: <botocore.client.SageMakerRuntime object at 0x7fbd1d0d70d0>

# %% [markdown]
# ## 4. LangChainmOpenSearch VectorStore 정의
# ### 선수 조건
# - 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 OpenSearch Index 가 생성이 되어 있어야 합니다.
# #### [중요] 아래에 aws parameter store 에 아래 인증정보가 먼저 입력되어 있어야 합니다.
# - 01_preprocess_docs/01_parameter_store_example.ipynb 참고

# %%
from utils.proc_docs import get_parameter

# %%
ssm = boto3.client("ssm", "us-east-1")

opensearch_domain_endpoint = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_domain_endpoint',
)

opensearch_user_id = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_userid',
)

opensearch_user_password = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_password',
)

http_auth = (opensearch_user_id, opensearch_user_password) # Master username, Master password

# %% [markdown]
# ### Index 이름 셋팅
# - 이전 노트북 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 생성된 OpenSearch Index name 입력

# %%
index_name = "v13-genai-poc-knox-titan-eval-sample-0.05-1024c-256o"
#index_name = "v14-genai-poc-knox-cohere-eval-sample-0.05-1024c-256o"

# %% [markdown]
# ### OpenSearch Client 생성

# %%
from utils.opensearch import opensearch_utils

# %%
os_client = opensearch_utils.create_aws_opensearch_client(
    aws_region,
    opensearch_domain_endpoint,
    http_auth
)

# %% [markdown]
# ### LangChain OpenSearch VectorStore 생성

# %%
from langchain.vectorstores import OpenSearchVectorSearch

# %%
vector_db = OpenSearchVectorSearch(
    index_name=index_name,
    opensearch_url=opensearch_domain_endpoint,
    embedding_function=llm_emb,
    http_auth=http_auth, # http_auth
    is_aoss =False,
    engine="faiss",
    space_type="l2"
)
vector_db

# %% [markdown]
# ## 5. Retriever 정의

# %%
from utils.rag import OpenSearchHybridSearchRetriever

# %%
opensearch_hybrid_retriever = OpenSearchHybridSearchRetriever(
    os_client=os_client,
    index_name=index_name,
    llm_text=llm_text_light, # used in rag_fusion, hyde and reranker(num_tokens)
    llm_emb=llm_emb,

    # option for lexical
    minimum_should_match=0,
    filter=[],

    # option for rank fusion
    fusion_algorithm="RRF", # ["RRF", "simple_weighted"], rank fusion 방식 정의
    ensemble_weights=[.5, .5], # [for lexical, for semantic], Lexical, Semantic search 결과에 대한 최종 반영 비율 정의
    reranker=True, # enable reranker with reranker model
    reranker_endpoint_name=endpoint_name, # endpoint name for reranking model
    #rag_fusion=False, # enable rag_fusion
    #query_augmentation_size=3, # query_augmentation_size in rag_fusion

    # option for async search
    async_mode=True,

    # option for output
    k=5, # 최종 Document 수 정의
    verbose=False,
)

# %%
search_hybrid_result = opensearch_hybrid_retriever.get_relevant_documents("knox")
search_hybrid_result
# Out:
# [Document(page_content='What is Knox Suite?. Knox Suite is a bundled offering designed to help enterprise IT admins better manage your fleet of devices. It includes individual services such as Knox Platform for Enterprise, Knox Mobile Enrollment, Knox Manage, Knox E-FOTA, and Knox Asset Intelligence. Key features of Knox Suite include: Secure - Ensure your business data is protected with managed security features at your control. Deploy - Enroll corporate devices to EMM automatically and securely, right out of the box. Manage - Enable comprehensive management over corporate devices and OS versions. Analyze - Strengthen in-depth device analytics for mobile productivity and asset management.', metadata={'source': 'all_processed_data.json', 'seq_num': 74, 'title': ' What is Knox Suite?', 'url': 'https://docs.samsungknox.com/admin/knox-suite/faq/#what-is-knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'id': '3e69c86f-4e05-4407-b540-298f1e3d8a9f'}),
#  Document(page_content='Knox Suite. Knox Suite is a bundled offering of Knox solutions for enterprise mobility designed to address organizations\' needs related to security and management throughout the entire device lifecycle. Learn more about Knox Suite #Audience This document is intended for IT Admins. Understand what\'s included in Knox Suite and how you can use it to manage, secure, and maintain enterprise devices. Learn where to find information on how to perform various tasks with Knox"Suite services. About Knox Suite Knox Suite is a bundled offering that includes the following Knox products: Knox Platform for Enterprise - A Knox solution that provides military-grade security to Samsung Android phones, tablets, and Tizen watches for business. Knox Mobile Enrollment - A Knox solution that allows you to enroll thousands of Samsung devices in your EMM at once. When used with a Knox Suite license, Knox Mobile Enrollment provides advanced profiles that offer IT admins additional features such as higher control over locking devices', metadata={'source': 'all_processed_data.json', 'seq_num': 65, 'title': 'Knox Suite', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'id': '200fa83e-cdc3-441b-880a-04d8014ed8bd'}),
#  Document(page_content='. With Knox E-FOTA, you create a campaign, specify the campaign period, assign devices to that campaign, and select the firmware update to be pushed to those devices during the campaign period. Knox Capture - An Android solution that lets users transform their Samsung Galaxy smartphones and tablets into powerful barcode scanners that can read, process, and output barcode information to other applications, all without requiring additional hardware or writing a single line of code. Knox Authentication Manager - A managed Android app for shared Samsung devices that provides multiuser facial biometrics and sign-in automation for increased frontline worker productivity and safety. With Knox Suite, a single license key allows you to use all included Knox products on your devices. This means that you can use the same Knox Suite license key in multiple Knox service admin portals. Benefits of Knox Suite 1. All-in-one Knox B2B package - An end-to-end solution that covers every step of your enterprise mobility journey 2', metadata={'source': 'all_processed_data.json', 'seq_num': 65, 'title': 'Knox Suite', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'id': '5b3da7a2-9b9d-4125-a805-eb74d6eb13bd'}),
#  Document(page_content='Knox Capture v1.7 release notes. New features #Launch of Samsung Knox Capture The most significant addition to Knox Capture v1.7 is the launch of a brand new, Samsung-developed scan engine that provides the same great feature-set as the Scandit engine, while also laying the foundations for Samsung to deliver exciting, industry-leading features to our customers in future releases. New customers will see an option to select their scan engine preference - either Knox Capture or Knox Capture: Scandit Edition - when launching the app for the first time and accepting the Knox Capture partner agreements. New customers can test the features of Knox Capture, and perform up to 100 free scans during their trial period, after which a valid Knox Suite license is required for commercial use. See Manage Knox Capture licenses to learn more about the new Knox Suite licensing requirements', metadata={'source': 'all_processed_data.json', 'seq_num': 34, 'title': 'Knox Capture v1.7 release notes', 'url': 'https://docs.samsungknox.com/admin/knox-capture/release-notes/v1-7', 'project': 'KCAP', 'last_updated': '2023-07-26', 'id': 'e1ef4919-61b1-4eca-8434-ae1c50ac62b8'}),
#  Document(page_content='Learn more about Knox Suite. This section describes where you can find instructions on how to perform tasks using the different products included in Knox Suite. General documentation for the Knox Suite services Knox Service , See - , - Knox Manage , Knox Manage Admin Guide Knox Platform for Enterprise , Knox Platform for Enterprise Admin Guide Knox Mobile Enrollment , Knox Mobile Enrollment Admin Guide Knox E-FOTA , Knox E-FOTA Admin Guide Knox Asset Intelligence , Knox Asset Intelligence Admin Guide Knox Capture , Knox Capture Admin Guide Knox Authentication Manager , Knox Authentication Manager Admin Guide Knox Suite operations For information on See Knox service How to set up Knox Manage with Knox Suite Workflow:"Set up Knox Manage with a Knox Suite license Knox Manage How to check your Knox Suite license usage View and modify a license Note Alternatively, you can sign in to your SamsungKnox.com dashboard and click Licenses to view all licenses you have for all your Knox services', metadata={'source': 'all_processed_data.json', 'seq_num': 64, 'title': 'Learn more about Knox Suite', 'url': 'https://docs.samsungknox.com/admin/knox-suite/learn-more-about-knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'id': '5363e4be-0d0f-4090-acd6-08cdddcabaf5'})]

# %% [markdown]
# ## 6. RAG chain 정의

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# %% [markdown]
# ### Prompting
# - [TIP] Prompt의 instruction의 경우 한글보다 영어로 했을 때 더 좋은 결과를 얻을 수 있습니다.

# %%
prompt_template = """
\n\nHuman: Here is the context, inside <context></context> XML tags.

<context>
{context}
</context>

Only using the context as above, answer the following question with the rules as below:
    - Don't insert XML tag such as <context> and </context> when answering.
    - Write as much as you can
    - Be courteous and polite
    - Only answer the question if you can find the answer in the context with certainty.

Question:
{question}

If the answer is not in the context, just say "Could not find answer in given contexts."

\n\nAssistant:"""

PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %% [markdown]
# ### Update Search Params (Optional)

# %%
opensearch_hybrid_retriever.update_search_params(
    k=5,
    minimum_should_match=0,
    filter=[],
    reranker=True,
    reranker_endpoint_name=endpoint_name,
    rag_fusion=True, # enable rag_fusion
    query_augmentation_size=3, # query_augmentation_size in rag_fusion
    hyde=False, # enable hyde
    hyde_query=["web_search"], # query type in hyde 
    llm_text=llm_text, # used in rag_fusion, hyde and reranker
    verbose=False
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm_text,
    chain_type="stuff",
    retriever=opensearch_hybrid_retriever,
    return_source_documents=True,
    chain_type_kwargs={
        "prompt": PROMPT,
        "verbose": False,
    },
    verbose=False
)

# %%
query = " - What method can a user employ to select multiple barcodes when using the camera scanning UI in Multi scan mode?"
qa_chain(query)
# Out:
# {'query': ' - What method can a user employ to select multiple barcodes when using the camera scanning UI in Multi scan mode?',
#  'result': ' The available Multi scan preferences for selecting multiple barcodes are:\n\n- Automatic (default) - Allows the user to scan multiple barcodes without having to press a scan button. \n\n- Batch - Lets the user scan multiple barcodes in a single camera frame using the scan button.\n\n- Aim and scan - Requires the user to aim the camera at a set of barcodes and tap the Scan button to capture the barcodes, one at a time.\n\n- Tap to select - Lets a user aim the camera at multiple barcodes, freeze the scanning overlay, tap to select barcodes, and tap the Scan button to capture data from the selected barcodes.',
#  'source_documents': [Document(page_content='.1 1 Device users will see a Scan button in the camera preview window when they trigger a barcode scan. Device users can simply tap Scan each time they want to capture a new barcode. As each barcode is scanned, a counter in the top-left corner of the preview window gets updated. Once the user is finished scanning, they can click Done to close the camera preview window and return to the business app. #Multi scan preferences Sets the way a user selects barcodes when interacting with the camera scanning UI in Multi scan mode. Available options: Setting Options Barcode selection Automatic (default) &mdash; Allows the user to scan multiple barcodes without having to press a scan button. Batch &mdash; Lets the user scan multiple barcodes in a single camera frame using the scan button. Aim and scan &mdash; Requires the user to aim the camera at a set of barcodes and tap the Scan button to capture the barcodes, one at a time', metadata={'source': 'all_processed_data.json', 'seq_num': 11, 'title': 'Configure scan engine settings', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-scan-engine-settings', 'project': 'KCAP', 'last_updated': '2023-10-16', 'id': '1841050e-4a01-474b-9a22-6401285b36ce'}),
#   Document(page_content='. Batch &mdash; Lets the user scan multiple barcodes in a single camera frame using the scan button. Aim and scan &mdash; Requires the user to aim the camera at a set of barcodes and tap the Scan button to capture the barcodes, one at a time. Tap to select &mdash; Lets a user aim the camera at multiple barcodes, freeze the scanning overlay, tap to select barcodes, and tap the Scan button to capture data from the selected barcodes. Scan session limit This defines the number of barcodes a user must scan before the camera preview window closes. A counter in the top-left corner of the preview window gets updated after each scan. Once the user has scanned the set number of barcodes, the camera preview window closes and the user returns to the business app. Users can exit the camera preview window at any time by tapping Done, regardless of the number of barcodes captured. You can set any integer value. By default, this value is set to 0 to indicate infinite scans', metadata={'source': 'all_processed_data.json', 'seq_num': 11, 'title': 'Configure scan engine settings', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-scan-engine-settings', 'project': 'KCAP', 'last_updated': '2023-10-16', 'id': '001867b4-8d2c-409d-91ed-6280d2e32b0d'}),
#   Document(page_content='. #Scan mode Sets the primary capture mode for scanning. Available options: Setting , Option - , - Single scan (default) , Scans and parses one barcode at a time. Multi scan , Detects multiple barcodes in the scan area at the same time. #Single scan preferences Sets the way a user selects barcodes when interacting with the camera scanning UI in Single scan mode. Available options: Setting Options Barcode selection Automatic (default) &mdash; Captures the first-detected barcode without additional user input. Aim and scan &mdash; Requires the user to aim the camera at a barcode and tap the Scan button to capture barcode data. Continuous scanning Off (default) On &mdash; Allow device users to scan several barcodes in sequence (and have each scan be registered as a single event) without having to press the camera trigger button between each scan.1 1 Device users will see a Scan button in the camera preview window when they trigger a barcode scan', metadata={'source': 'all_processed_data.json', 'seq_num': 11, 'title': 'Configure scan engine settings', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-scan-engine-settings', 'project': 'KCAP', 'last_updated': '2023-10-16', 'id': 'e23a3ec5-62d0-4f32-8863-e945544558c5'}),
#   Document(page_content='Knox Capture v1.5 release notes. Scanner overlay Starting with Knox Capture v1.5, a scanner overlay is available. This overlay appears as a scanner preview over business apps, and enables device users to immediately see scanned data entered into an app field. Functionally, the scanner overlay works much like the full-screen scanner. When the device user aims the camera at the barcode, Knox Capture then sends the scanned data to the business app depending on whether single scan or multi-scan mode is enabled, and how Barcode selection is configured. See Use the scanner overlay to learn more. Continuous scanning for single scan mode Previously, when device users scanned single barcodes, the camera preview turned on before each scan, then off again once the scan was completed. Now, in Single scan preferences, you can turn on Continuous scanning to scan back-to-back barcodes without relaunching the camera preview after every scan', metadata={'source': 'all_processed_data.json', 'seq_num': 32, 'title': 'Knox Capture v1.5 release notes', 'url': 'https://docs.samsungknox.com/admin/knox-capture/release-notes/v1-5', 'project': 'KCAP', 'last_updated': '2023-07-26', 'id': '2bf925b7-5ebe-4dc9-b5f5-8776864fd58d'}),
#   Document(page_content=". For more information, see Activate your license. Support for exporting large configurations through QR code !Multiple QR code export This Knox Capture version extends the QR code export functionality to support larger configurations. Prior to v1.2, IT admins couldn't select QR code as the export method if the configuration size was too large. Now, multiple QR codes are generated in a PDF file for the end user to scan. The device prompts the user to scan them all before the configuration can be successfully imported to Knox Capture. To learn more, see Export a scanning configuration and Import a scanning configuration. Persistent scan sessions IT admins and end users can now pick up calls, switch apps, and clear tasks during scan sessions without losing scanned data. Rebooting the device has no impact on saved scan data. In multi-scan sessions where the user leaves the business app and returns, they are prompted to either continue the original scan session or begin a new one", metadata={'source': 'all_processed_data.json', 'seq_num': 29, 'title': 'Knox Capture v1.2 release notes', 'url': 'https://docs.samsungknox.com/admin/knox-capture/release-notes/v1-2', 'project': 'KCAP', 'last_updated': '2023-07-26', 'id': '4dc7d03a-227a-454c-9ede-2fc0a677eaa2'})]}

# %% [markdown]
# ## 3.Evaluation
#  - [langchain evaluator](https://python.langchain.com/docs/guides/evaluation/string/criteria_eval_chain)

# %% [markdown]
# ### Load ground truth

# %%
import pandas as pd

# %%
ground_thruth = pd.read_csv("eval_dataset_v13.csv")

# %%
import time
import datetime
from langchain.evaluation import Criteria
from langchain.evaluation import EvaluatorType
from langchain.evaluation import load_evaluator

# %%
list(Criteria)
# Out:
# [<Criteria.CONCISENESS: 'conciseness'>,
#  <Criteria.RELEVANCE: 'relevance'>,
#  <Criteria.CORRECTNESS: 'correctness'>,
#  <Criteria.COHERENCE: 'coherence'>,
#  <Criteria.HARMFULNESS: 'harmfulness'>,
#  <Criteria.MALICIOUSNESS: 'maliciousness'>,
#  <Criteria.HELPFULNESS: 'helpfulness'>,
#  <Criteria.CONTROVERSIALITY: 'controversiality'>,
#  <Criteria.MISOGYNY: 'misogyny'>,
#  <Criteria.CRIMINALITY: 'criminality'>,
#  <Criteria.INSENSITIVITY: 'insensitivity'>,
#  <Criteria.DEPTH: 'depth'>,
#  <Criteria.CREATIVITY: 'creativity'>,
#  <Criteria.DETAIL: 'detail'>]

# %%
evaluator = load_evaluator(
    EvaluatorType.LABELED_CRITERIA,
    llm=llm_text,
    criteria=Criteria.CORRECTNESS
)

# %% [markdown]
# ### Check prompt for evaluation

# %%
print(evaluator.prompt.partial_variables)
print("==")
print(evaluator.prompt.template)
# Out:
# {'criteria': 'correctness: Is the submission correct, accurate, and factual?'}
# ==
# You are assessing a submitted answer on a given task or input based on a set of criteria. Here is the data:
# [BEGIN DATA]
# ***
# [Input]: {input}
# ***
# [Submission]: {output}
# ***
# [Criteria]: {criteria}
# ***
# [Reference]: {reference}
# ***
# [END DATA]
# Does the submission meet the Criteria? First, write out in a step by step manner your reasoning about each criterion to be sure that your conclusion is correct. Avoid simply stating the correct answers at the outset. Then print only the single character "Y" or "N" (without quotes or punctuation) on its own line corresponding to the correct answer of whether the submission meets all criteria. At the end, repeat just the letter again by itself on a new line.

# %%
ground_thruth.head()
# Out:
#                                             question  \
# 0  What are some examples of barcodes that can be...
# 1  How would an administrator configure Knox Capt...
# 2  - What are the three steps outlined in the con...
# 3  What are the two steps described to start scan...
# 4  According to the instructions, how do you sele...
#
#                                               answer  \
# 0  According to the provided context, the followi...
# 1  An administrator would configure the trigger f...
# 2  The three steps outlined to set up a default s...
# 3  Step 1: Review the scanning configuration. Ste...
# 4  To select an individual activity visually with...
#
#                                  doc_id  \
# 0  f6f534aa-9316-4232-bd37-08b68381b1b2
# 1  c1a8f827-a4f9-4137-998b-b4e974d7a6fb
# 2  446bcc38-c806-4ab7-ae73-4a07025044a2
# 3  f87907d6-b400-432d-b108-86a87837a9da
# 4  9b451f9a-acbf-4ab5-ab65-68e77df10ab4
#
#                                                  doc
# 0  AR demo barcodes. Use the following barcodes t...
# 1  . Deploy configuration to EMM/UEM - Learn abou...
# 2  . Step 2: Edit the default profile Tap Default...
# 3  . Tap the options button to view the scanning ...
# 4  . 2. An app can also be selected by tapping it...

# %%
# %%time
evaluation = []
for idx, row in enumerate(ground_thruth.itertuples()):
    try:
    
        question, answer, doc, doc_id = getattr(row, "question"), getattr(row, "answer"), getattr(row, "doc"), getattr(row, "doc_id")

        start = time.time()
        response = qa_chain(question)
        elapsed = time.time() - start

        prediction = response["result"]

        for doc_ in response["source_documents"]:
            doc_.metadata["id"]

        retrieved_docs = {doc.page_content: idx+1 for idx, doc in enumerate(response["source_documents"])}
        contexts = "\n\n".join(retrieved_docs.keys())

        payload = json.dumps(
            {
                "inputs": [
                    {"text": answer, "text_pair": prediction},
                ]
            }
        )

        response = runtime_client.invoke_endpoint(
            EndpointName=endpoint_name,
            ContentType="application/json",
            Accept="application/json",
            Body=payload
        )
        out = json.loads(response['Body'].read().decode()) ## for json

        eval_result = evaluator.evaluate_strings(
            input=question,
            prediction=prediction,
            reference=answer,
        )

        reranker_sim = out[0]["score"]
        langchain_correctness = eval_result["score"]
        if doc in retrieved_docs:
            true_context_rank = retrieved_docs[doc]
            has_right_context = 1
            mrr = 1/true_context_rank
        else:
            true_context_rank = has_right_context = 0
            mrr = 0
        total_contexts = len(retrieved_docs)
        latency = datetime.timedelta(seconds=elapsed)

        print(idx)
        print(colored("Question: ", "red"), colored(question, "red"))
        print(colored("GroundTruth: ", "green"), colored(answer, "green"))
        print(colored("Prediction: ", "blue"), colored(prediction, "blue"))
        print(f'ReRanker similarity: {reranker_sim}')
        print(f'Langchain correctness: {langchain_correctness}')
        print(f'has_right_context: {has_right_context}')
        print(f'true_context_rank: {true_context_rank}/{total_contexts}')
        print(f'mrr: {mrr:.3f}')
        print(f'latency: {latency} secs')

        evaluation.append([question, answer, prediction, \
                           has_right_context, true_context_rank, total_contexts, mrr, \
                           reranker_sim, langchain_correctness, elapsed, contexts])
    except:
        print ("err", idx)

eval_results = pd.DataFrame(
    evaluation,
    columns=["question", "true_answer", "prediction", \
             "has_right_context", "true_context_rank", "total_contexts", "mrr", \
             "reranker_sim", "langchain_correctness", "latency", "contexts"]
)
eval_results.to_csv("eval_results_rag_fusion.csv", index=False)
#eval_results.to_pickle("eval_results.pkl")
# Out:
# 0
# Question:  What are some examples of barcodes that can be used to test the Knox Capture AR features according to the context?
# GroundTruth:  According to the provided context, the following are some of the barcodes that can be used to test the Knox Capture AR features:
#
# Barcode 1, Barcode 2, Barcode 3, Barcode 4, Barcode 5 and Barcode 6
# Prediction:   Based on the given context, some examples of barcodes that can be used to test the Knox Capture AR features are:
#
# Barcode 1
# Barcode 2
# Barcode 3
# Barcode 4
# Barcode 5
# Barcode 6
#
# These barcodes are mentioned in the first paragraph of the context as being able to be used to test the Knox Capture AR features.
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.123196 secs
# 1
# Question:  How would an administrator configure Knox Capture to allow camera scanning to be triggered by a hardware button, on-screen button, or both?
# GroundTruth:  An administrator would configure the trigger for both hardware buttons and on-screen buttons using the Set camera scan trigger feature
# Prediction:   Based on the given context, to configure Knox Capture to allow camera scanning to be triggered by a hardware button, on-screen button, or both:
#
# The administrator can enable the "Floating action button" option to add an on-screen scanning button. This button can be moved around the screen and will remain in its last position.
#
# The "Hardware key setting" allows selecting a hardware key to trigger scanning. Options include XCover key, Top key, or Side key double press depending on the device. Side key double press allows using the side key (formerly Bixby or Power key) by double pressing it.
#
# By enabling both the floating action button and configuring a hardware key trigger, the administrator can allow camera scanning to be launched from either method.
# ReRanker similarity: 0.9913852214813232
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:25.213503 secs
# 2
# Question:  - What are the three steps outlined in the context to set up a default scanning profile?
# GroundTruth:  The three steps outlined to set up a default scanning profile are:
# 1. Edit the default profile
# 2. Change scan engine settings
# 3. Enable a flashlight butto
# Prediction:   Here are the three steps outlined in the context to set up a default scanning profile:
#
# 1. Tap Default scanning profile to explore and edit the profile settings.
#
# 2. Creating custom scanning profiles by modifying the default profile settings, or by creating entirely new profiles altogether.
#
# 3. Provide a profile name, then tap Done. The new profile appears in the profiles area below Default scanning profile.
# ReRanker similarity: 0.9994739890098572
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:04.805252 secs
# 3
# Question:  What are the two steps described to start scanning with Knox Capture?
# GroundTruth:  Step 1: Review the scanning configuration. Step 2: Launch a device app
# Prediction:   Step 1: Get familiar with the Knox Capture interface
#
# Step 2: View the current scanning configuration by tapping View current configuration in the options menu.
# ReRanker similarity: 0.13904519379138947
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:04.595120 secs
# 4
# Question:  According to the instructions, how do you select an individual activity visually within an app?
# GroundTruth:  To select an individual activity visually within an app:
#
# 1. Tap the wand icon in the upper-right corner of the app activities list page.
# 2. Navigate within the app to locate an activity.
# 3. Drag the blue selector overlay around the screen as needed to view the app user interface.
#
# Note: Steps 2 and 3 can be repeated as needed to select multiple activities
# Prediction:   According to the instructions, to select an individual activity visually within an app:
#
# 1. Within the app activities list page, tap the wand icon in the upper-right corner to launch the visual selection tool.
#
# 2. Navigate within the app to locate an activity. A blue selector overlay displays on each screen to name the activity associated with that screen.
#
# 3. Drag this selector around the screen as needed to view the app user interface.
#
# 4. To select an activity, tap the radio button next to the activity name within the blue overlay.
# ReRanker similarity: 0.9998418092727661
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.452251 secs
# 5
# Question:  What are the two ways to trigger a rule in Knox Capture?
# GroundTruth:  A rule in Knox Capture can be triggered by either the presence of a scanned string or by a scanned barcode that matches the required type
# Prediction:   Based on the given context, the two ways to trigger a rule in Knox Capture are:
#
# 1. Barcode type - The types of barcodes that the rule applies to.
#
# 2. String length - The required length of scanned data to trigger the rule.
# ReRanker similarity: 0.9991481304168701
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:04.642947 secs
# 6
# Question:  What method moves the cursor to the beginning of the output data?
# GroundTruth:  None Move ahead to substring &mdash; Move ahead to substring &mdash; Moves the cursor forward until a specific string is found. None Move past substring &mdash; Moves the cursor past a specific string in the output data.
# None Move ahead to substring &mdash; Move ahead to substring &mdash; Moves the cursor forward until a specific string is found. Moves the cursor past a specific string in the output data
# Prediction:   The method that moves the cursor to the beginning of the output data is:
#
# Skip to start
# ReRanker similarity: 0.15671725571155548
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.935095 secs
# 7
# Question:  - What is the default capture mode for scanning in the provided context?
# GroundTruth:  Sets the primary capture mode for scanning. Available options: Setting - Single scan (default).
#
# Could not find answer in given contexts
# Prediction:   Single scan (default)
# ReRanker similarity: 0.998796820640564
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.570507 secs
# 8
# Question:  How can a user exit the camera preview window?
# GroundTruth:  Users can exit the camera preview window at any time by tapping Done, regardless of the number of barcodes captured
# Prediction:   A user can exit the camera preview window at any time by tapping Done, regardless of the number of barcodes captured.
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:03.762936 secs
# 9
# Question:  - What setting controls the border width of the box highlighting recognized barcodes?
# GroundTruth:  The setting that controls the border width of the box highlighting recognized barcodes is "Stroke width"
# Prediction:   Stroke width sets the border width of the box highlighting the recognized barcode in pixels.
# ReRanker similarity: 0.9972589015960693
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.944932 secs
# 10
# Question:  - What regular expression syntax should be used to validate barcodes for the scanner?
# GroundTruth:  - The provided regular expression syntax should be used to validate barcodes for the scanner.
# - For reference, details are available on crafting a regular expression.
# - No regular expression is set by default
# Prediction:   Could not find answer in given contexts.
# ReRanker similarity: 0.00016557193885091692
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.524030 secs
# 11
# Question:  How wide is the default rectangular viewfinder as a percentage of the screen width?
# GroundTruth:  90%
# Prediction:   The default rectangular viewfinder width is 90% of the screen width.
# ReRanker similarity: 0.8605338335037231
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.462965 secs
# 12
# Question:  How can you check if a hardware scanner is properly connected when testing a scanner configuration?
# GroundTruth:  By going to the Test apps screen and checking if your connected scanners are listed under the apps. If no scanner is connected, a blue test overlay displays the message "Data source: No device connected"
# Prediction:   Based on the context, when testing a scanner configuration in Test mode, if a hardware scanner is properly connected, it will be shown under the list of Test apps. Specifically:
#
# If any app has the Hardware scanner setting enabled, the Test apps screen shows your connected scanners under the apps. If no hardware scanner is connected, the blue test overlay displays "Data source: No device connected". This message is not shown if a data source is identified or a hardware scanner is connected.
#
# So to check if a hardware scanner is properly connected, look for it in the list of Test apps when in Test mode. If it is not there, then no hardware scanner is connected.
# ReRanker similarity: 0.9999197721481323
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:09.959502 secs
# 13
# Question:  - What defines the barcode types to scan, how to interpret scanned data, and which business applications to pass the data to in Knox Capture?
# GroundTruth:  The Scanning profile
# Prediction:   The Scanning Profile defines the barcode types to scan, how to interpret scanned data, and which business applications to pass the data to in Knox Capture. The Scanning Profile is a configuration file created or modified by an IT admin that primarily consists of Apps and activities, Scanner engine settings, Keystroke output, and other parameters.
# ReRanker similarity: 0.999736487865448
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.144799 secs
# 14
# Question:  - How can IT admins customize barcode scanning behavior in Knox Capture?
# GroundTruth:  IT admins can change the profile's scan engine settings, data processing rules, and apps and activities behavior by creating custom scanning profiles in Knox Capture
# Prediction:   Based on the context, IT admins can customize barcode scanning behavior in Knox Capture in a few ways:
#
# - They can create custom scanning profiles that allow them to control which apps can trigger barcode scanning. The default profile allows scanning in all apps, but custom profiles let admins specify which apps can scan.
#
# - In both default and custom profiles, admins can configure scanner engine settings like barcode types, scanning methods, camera settings, etc. This lets them control the core scanning behavior.
#
# - Admins can also configure keystroke output rules that format the scanned data, like appending Tab or Enter keys, adding prefix/suffix characters, etc. This lets them control how the raw barcode data gets processed before being input.
#
# So in summary, IT admins can customize scanning behavior through custom profiles to control app scanning privileges, engine settings to control scanning methods, and output rules to format scanned data.
# ReRanker similarity: 0.9985666871070862
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.362284 secs
# 15
# Question:  According to the context, what steps should be taken on a device running the app in Admin mode to import a configuration file?
# GroundTruth:  To import a configuration file on a device running the app in Admin mode, tap the more actions menu icon within the home page to the right of the Profiles list label, select Import, acknowledge the warning message by tapping Confirm, and find a configuration file to import
# Prediction:   Here are the steps to import a configuration file on a device running the app in Admin mode according to the given context:
#
# 1. Tap the more actions menu icon within the home page to the right of the Profiles list label. Then select Import.
#
# 2. After launching the import configuration menu, acknowledge the warning message by tapping Confirm.
#
# 3. Find the configuration file to import. If the configuration is too large for one QR code, Knox Capture generates multiple QR codes in a PDF file. The end user must scan them all to complete the import process.
# ReRanker similarity: 0.9999275207519531
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.749649 secs
# 16
# Question:  - What are the two steps required before you can get a Knox Suite license for Knox Capture?
# GroundTruth:  To get a Knox Suite license for Knox Capture, you need to sign up for a Samsung Knox account and apply to gain access to Knox Suite
# Prediction:   Could not find answer in given contexts.
# ReRanker similarity: 7.649121835129336e-05
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:11.841742 secs
# 17
# Question:  How do you enter a Knox Capture license key by scanning a QR code?
# GroundTruth:  To use this method, you will first need to have a valid Knox Suite license key converted into QR code format. Once you have a QR code generated, aim the camera at the QR code and tap Done to activate the license
# Prediction:   Here are the steps to enter a Knox Capture license key by scanning a QR code:
#
# To use this method, you'll first need to have a valid Knox Suite license key converted into QR code format. Once you have a QR code generated:
#
# 1. On the home screen, tap the options button, then select License.
#
# 2. Under Enter Knox Capture license, tap the QR code button. A scanning window appears.
#
# 3. Aim the camera at the QR code, then tap Done to activate the license.
# ReRanker similarity: 0.9999109506607056
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.757137 secs
# 18
# Question:  - What is the first step to set up intent output for Knox Capture?
# GroundTruth:  1. On the Knox Capture home screen, tap on the profile you want to set intent output for.
#
# Could not find answer in given contexts
# Prediction:   The first step to set up intent output for Knox Capture is:
#
# On the Knox Capture home screen, tap on the profile you want to set intent output for.
# ReRanker similarity: 0.9999277591705322
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.996042 secs
# 19
# Question:  - What visual indicators confirm that Knox Capture's system-wide test mode is active?
# GroundTruth:  - Look for a system pop-up notification indicating "Test mode is on"
# Prediction:   Based on the given context, the visual indicators that confirm Knox Capture's system-wide test mode is active are:
#
# 1. A system pop-up notification saying "Test mode is on" after starting test mode.
#
# 2. A blue test overlay displayed in the UI of the open app showing the activity name, active profile, output, scanned data, and scanned raw values.
#
# 3. A green checkmark next to each tested activity under the profile in Admin mode.
# ReRanker similarity: 0.9697555899620056
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:06.215610 secs
# 20
# Question:  - What types of AR templates does the document describe?
# GroundTruth:  The document describes Search-and-find and View-and-update AR templates
# Prediction:   The document describes two types of AR templates:
#
# - Search-and-find templates: This template provides an overlay to help users locate and isolate a single barcode when several similar barcodes are in the camera preview window. For example, a retail worker can scan a reference barcode of an item they're searching for, and the AR overlay will highlight the matching barcode when it's in view.
#
# - View-and-update templates: This template provides an overlay to allow users to view product information and make real-time updates to a product database whenever a barcode is scanned. For example, a retail worker can scan an item to bring up additional product info, and update the inventory count.
# ReRanker similarity: 0.9995410442352295
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:06.662915 secs
# 21
# Question:  What HTTP request method would be used to retrieve a list of attributes for an item identified by a barcode using the /arcontentfields API?
# GroundTruth:  The HTTP request method for the /arcontentfields API is `GET`
# Prediction:   The /arcontentfields API uses the GET HTTP request method to retrieve a list of attributes for an item identified by a barcode.
# ReRanker similarity: 0.9990641474723816
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:02.911907 secs
# 22
# Question:  Briefly explain the purpose and functionality of the /arinfo API.
# GroundTruth:  The /arinfo API is used to retrieve a list of attribute values for a particular item identified by a barcode. It allows to update one or more values of attributes (fields) for an item identified by the barcode
# Prediction:   The /arinfo API is for retrieving a list of attribute values for an item identified by a barcode. It is a GET request that returns a JSON array of attribute values. The request requires a barcode parameter. It may also require authorization credentials. The response is a 200 success code with the JSON array in the body, or a 401 if credentials are invalid.
# ReRanker similarity: 0.9994586110115051
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:06.550742 secs
# 23
# Question:  - How can you activate your Knox Capture license through your EMM?
# GroundTruth:  Through the application configuration dialog of the EMM console
# Prediction:   To activate a Knox Capture license through your EMM:
#
# 1. Open the application configuration dialog for Knox Capture in the EMM console. In a typical EMM console, the app configuration (or App Config) screen opens as a pop-up window or modal.
#
# 2. Paste the license key within the license field.
#
# 3. Optionally include the scanning configuration as well. Refer to Deployment for more information.
#
# 4. Save the configuration.
# ReRanker similarity: 0.9858853816986084
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.303283 secs
# 24
# Question:  - What new Android version is now supported in Knox Capture v1.0.01?
# GroundTruth:  Android 11
# Prediction:   Android 11
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.175541 secs
# 25
# Question:  - What new features were added in Knox Capture v1.1?
# GroundTruth:  Knox Capture v1.1 now supports landscape mode, adds Galaxy XCover 5 to the list of supported devices, and adds customizable data formatting rules and a keyboard scan button input method
# Prediction:   Based on the context provided, the following new features were added in Knox Capture v1.1:
#
# - Landscape mode support - Knox Capture can now be used in landscape mode on all supported devices. Frontline workers can choose to scan barcodes or navigate the app UI in either portrait or landscape mode.
#
# - Added device model support - The Galaxy XCover 5 was added to the list of supported devices.
#
# - Advanced data formatting - Custom rules can be configured to trigger or block actions based on criteria. For example, sending only the last 4 digits of a barcode to a business app.
#
# - Keyboard scan button input method - A scan button was added to the device keyboard that launches the Knox Capture camera for scanning.
# ReRanker similarity: 0.999927282333374
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.248978 secs
# 26
# Question:  What new scanning features are available in Knox Capture v1.1?
# GroundTruth:  Knox Capture v1.1 adds support for intent output, work profile on company owned devices (WP-C), and Nearby Share
# Prediction:   Based on the provided context, some of the new scanning features available in Knox Capture v1.1 are:
#
# - Support for AR demo mode to test the AR feature without setting up a real server or going through profile creation.
#
# - On-screen suggestions to increase scanning success rate by notifying users when the device is too far from a barcode or at an incorrect angle.
#
# - Ability to turn on flashlight by default with Off/On/Automatic options in scan engine settings.
# ReRanker similarity: 0.6074194312095642
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:04.769856 secs
# 27
# Question:  What new functionality allows IT admins to enable or disable the default profile in Knox Capture?
# GroundTruth:  With this release, IT admins can now enable or disable the default profile in Knox Capture
# Prediction:   The context mentions that "IT admins can now enable or disable the default profile. If you create profiles for several applications and don't want the default profile's behavior to override any configurations, set the default profile to Off. The default profile setting is available on the Knox Capture main page."
# ReRanker similarity: 0.9957283139228821
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.413271 secs
# 28
# Question:  How can users move the scan button around the screen in Knox Capture?
# GroundTruth:  Users can move the scan button around the screen in Knox Capture by default, and the scan button remains in the last known position until it's toggled off
# Prediction:   Users can move the floating scan button around the screen in Knox Capture. By default, the floating scan button appears in the bottom right corner. Users can hold and drag the button to move it, and it remains in the last position until toggled off.
# ReRanker similarity: 0.999607503414154
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.541035 secs
# 29
# Question:  - What new feature in Knox Capture 1.7 allows displaying of overlays with custom information when barcodes are scanned?
# GroundTruth:  Knox Capture AR introduces a new AR feature that displays an overlay on the device screen whenever one or more barcodes are scanned. IT admins can create AR templates to customize the information that displays on the overlay, as well as the overlay behavior
# Prediction:   Knox Capture AR (Augmented Reality)
# ReRanker similarity: 0.9711878895759583
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.085170 secs
# 30
# Question:  What are two recommendations provided in the context information regarding Code 93 and Code 128 barcodes?
# GroundTruth:  Customers should use larger barcodes wheneve possible to increase the success rate of scans and move in closer to the barcodes when using multiscan
# Prediction:   Based on the context, two recommendations provided for Code 93 and Code 128 barcodes are:
#
# 1. Knox Capture may have difficulties scanning barcodes that are too small. It is recommended that customers avoid using tiny barcodes whenever possible to increase the success rate of scans.
#
# 2. For customers who use Code 93 and Code 128 barcodes specifically, Knox Capture may have difficulties scanning barcodes that are too small.
# ReRanker similarity: 0.9234914779663086
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:09.127276 secs
# 31
# Question:  What new scanning option appears in Knox Capture v1.8 that allows users to continuously scan multiple barcodes without pressing the trigger between each scan?
# GroundTruth:  Continuous scanning
# Prediction:   Continuous scanning
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.765472 secs
# 32
# Question:  What are some of the major versions of Knox Capture that have been released according to the release notes?
# GroundTruth:  Knox Capture v1.9, v1.8, v1.7, v1.6, v1.5, v1.4, v1.3, v1.2, v1.1, and v1.0
# Prediction:   Based on the context provided, the major versions of Knox Capture that have been released are:
#
# Knox Capture v1.9, v1.8, v1.7, v1.6, v1.5, v1.4, v1.3, v1.2, v1.1, v1.0.01, and v1.0.
# ReRanker similarity: 0.9999216794967651
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.270507 secs
# 33
# Question:  - Why is Knox Capture called a wedge, according to the context?
# GroundTruth:  Knox Capture is called a wedge because it acts as middleware that reads barcode data captured by the XCover Pro device, translates it into a string, formats the string, and then sends it to a third-party business app that understands the resulting data
# Prediction:   Knox Capture is called a wedge because it acts as middleware that sits between a barcode scanning device and a business application, translating the scanned barcode data into a formatted string that the application understands. Just as a wedge scanner hardware sits between a keyboard and computer to translate barcode scans into keystrokes, Knox Capture software sits between the scanning device and application to format and deliver the barcode data.
# ReRanker similarity: 0.9997884631156921
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.502442 secs
# 34
# Question:  What steps should be taken in the EMM console to program the XCover key to trigger camera scanning?
# GroundTruth:  On your EMM console, open Knox Service Plugin policies. Under Device Key Mapping (Premium), configure the mapping. Set Enable Key Mapping Controls to True
# Prediction:   Here are the steps to program the XCover key to trigger camera scanning in the EMM console:
#
# 1. Open the Knox Service Plugin policies in the EMM console.
#
# 2. Under Device-wide policies, set Enable device policy controls to True.
#
# 3. Under Device Key Mapping (Premium), configure the mapping:
#
# - Set Enable Key Mapping Controls to True.
#
# - Set Enable PTT/Side Key Mapping for Microsoft Teams to False.
#
# - For Package Name, enter com.samsung.android.app.smartscan.
#
# - For Intent for Key press, enter com.samsung.android.knox.intent.action.PTT_PRESS.
#
# - For Intent for Key release, enter com.samsung.android.knox.intent.action.PTT_RELEASE.
#
# - Set Enable Key Mapping to Launch & Exit applications to False.
#
# 4. Save and assign the configured profile to the Verizon XCover Pro devices.
# ReRanker similarity: 0.9997569918632507
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:13.483085 secs
# 35
# Question:  How can a user turn on the flashlight when using the Knox Capture scanner if the Flashlight button is not enabled in the device's Knox Capture profile?
# GroundTruth:  If the Flashlight button is not enabled in the device's Knox Capture profile, the device user will not be able to turn on the flashlight when using the Knox Capture scanner. They are required to ensure the profile has the Flashlight button feature enabled in the scan engine settings before attempting to turn on the flashlight
# Prediction:   Could not find answer in given contexts.
# ReRanker similarity: 7.63391362852417e-05
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.599423 secs
# 36
# Question:  - How can you resolve the issue of not being able to output scanned barcode data to HTML fields in Chromium-based browsers on Android 11 devices using the Advanced data formatting method?
# GroundTruth:  To resolve this issue, send a Pause command before sending the barcode data
# Prediction:   Here are the steps to resolve the issue using the Advanced data formatting method:
#
# 1. Refer to the procedure for Advanced data formatting and follow steps 1 - 6.
#
# 2. After you tap Add Actions, a list of options opens.
#
# 3. Select Send Pause and tap Add.
#
# 4. Tap Add Actions again, then select Send remaining characters and tap Add.
#
# 5. Verify that the two actions, Send Pause and Send remaining characters, are on the rule screen.
#
# 6. Close the Knox Capture app and perform a test scan in Chrome or Samsung Internet.
# ReRanker similarity: 0.6830451488494873
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.819150 secs
# 37
# Question:  - What barcode encoding standard does the example use that allows mixing of encoding schemes within a single barcode?
# GroundTruth:  Code 128
# Prediction:   Code 128
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.682922 secs
# 38
# Question:  How do you select the reseller that uploaded the new devices when generating a Knox Suite license?
# GroundTruth:  1. Contact the reseller who uploaded the new devices.
# 2. Select the reseller that uploaded the new devices
# Prediction:   According to the context, to select the reseller that uploaded the new devices when generating a Knox Suite license, you need to:
#
# Go to the Enterprise Edition dashboard. The reseller's name and ID appears in a table along with the number of devices uploaded. Select the reseller that uploaded the new devices.
# ReRanker similarity: 0.9800975918769836
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.894923 secs
# 39
# Question:  - How can you view the devices and licenses on the Enterprise Edition dashboard?
# GroundTruth:  To view the devices and licenses on the Enterprise Edition dashboard, go to the DEVICES tab
# Prediction:   Based on the context, to view the devices and licenses on the Enterprise Edition dashboard:
#
# Go to the DEVICES tab. If your device reseller uploaded devices for you, the reseller's name and ID appears in a table along with the number of devices uploaded. The table columns display the following information about your devices:
# - RESELLER (ID) - The name and ID of the device reseller that uploaded EE devices for you.
# - DEVICES LAST UPLOADED - The date that the reseller last uploaded devices for you.
# - DEVICES UPLOADED - The total number of devices that the reseller has uploaded for you.
# - LICENSES GENERATED - The number of devices that have a Knox Suite license.
# - DEVICES REMAINING - The number of devices that don't have a Knox Suite license.
# ReRanker similarity: 0.9994262456893921
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.228148 secs
# 40
# Question:  - What is the total number of devices the reseller has uploaded for you?
# GroundTruth:  The total number of devices that the reseller has uploaded for you is DEVICES UPLOADED
# Prediction:   Could not find answer in given contexts.
# ReRanker similarity: 7.631701737409458e-05
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:02.622998 secs
# 41
# Question:  - How do you confirm your tenant ID when registering for Knox Suite if your organization is not already signed up for Knox Services?
# GroundTruth:  If your organization is not signed up for Knox Services, you need to confirm that your organization's domain automatically filled the Tenant ID field during registration for Knox Suite
# Prediction:   Confirm that your organization's domain automatically filled the Tenant ID field and click Complete Registration.
# ReRanker similarity: 0.8905097246170044
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.752720 secs
# 42
# Question:  - How can you confirm that the Knox Suite license type was automatically generated and registered for you?
# GroundTruth:  In the Knox Admin Portal, you can view all the licenses registered to you, and the Knox Suite license type will be listed among them
# Prediction:   Could not find answer in given contexts. The context does not mention how to confirm that the Knox Suite license type was automatically generated and registered. It talks about navigating to the licenses page and confirming a trial license was generated, but does not specify checking the license type.
# ReRanker similarity: 0.49405649304389954
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:03.884891 secs
# 43
# Question:  How does Samsung ensure responsible data collection through its cloud solutions like Knox?
# GroundTruth:  Through SOC2 certification and a commitment to the restricted use of data
# Prediction:   Samsung ensures responsible data collection through its cloud solutions like Knox in a few key ways:
#
# - Data collection is restricted to only what is necessary. Samsung does not collect extraneous or unnecessary data.
#
# - Samsung cloud solutions are SOC2-certified, which means they adhere to strict standards for security, availability, processing integrity, confidentiality, and privacy. This provides assurance that solutions in the Knox Suite operate smoothly, securely, and reliably.
#
# - Samsung complies with data protection regulations like GDPR. They meet requirements for safely handling customer information acquired from business practices.
#
# - Location tracking of managed devices through Knox Manage and Knox Asset Intelligence is a feature to help businesses locate and analyze device movement, not something done without permission.
# ReRanker similarity: 0.41230493783950806
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:06.561374 secs
# 44
# Question:  - What functionality does Knox Capture provide in its default Admin mode?
# GroundTruth:  Knox Capture's default Admin mode allows IT administrators to utilize the full functionality of the app to create scanning profiles, test them, and export the profile settings
# Prediction:   Based on the context provided:
#
# In Admin mode, Knox Capture allows the device user - typically an enterprise IT admin - to utilize the full functionality of the app to primarily:
#
# 1. Create scanning profiles that define which apps can launch the barcode scanner, which barcode types can be scanned (QR, Code 128, EAN8, etc.), and how scanned data is formatted (append Tab or Enter key, insert special characters before or after data, etc.).
#
# 2. Test scanning profiles to ensure that appropriate business apps can launch the scanner and receive data back as keystrokes.
#
# 3. Export profile settings as a configuration file, which can then be used by EMM/UEM administrators to deploy Knox Capture as a managed app to end-user devices.
# ReRanker similarity: 0.9998058676719666
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.827348 secs
# 45
# Question:  - How can you customize apps and activities in scanning profiles in Knox Capture?
# GroundTruth:  You can customize apps and activities in scanning profiles in Knox Capture by adjusting the scan engine settings, including barcode types, scan modes, and viewfinder size. Additionally, you can test the profile's applications, barcode types, and keystroke output rules using the test mode, and export the configuration for deployment to an EMM/UEM
# Prediction:   Based on the context, to customize apps and activities in scanning profiles in Knox Capture:
#
# - Each scanning profile supports configuring a set of apps and activities to which its scanner and keystroke output settings apply.
#
# - IT admins can associate individual Android activities with different Knox Capture profiles. Activities are interactions within an app's UI, like a form or search box.
#
# - You can configure one profile for all apps, unique profiles per app, or group apps/activities into profiles.
#
# - A single profile can have multiple apps/activities, but an activity can only belong to one profile.
#
# - To refine control, consider associating a form activity with a profile that appends a Tab key, and a search box with a profile that appends an Enter key.
#
# - To override default behavior, set the default profile to Off. Then scanned apps not specified in a custom profile will not trigger scanning.
#
# - The apps and activities settings define which business apps can launch the camera scanner in each profile.
# ReRanker similarity: 0.995428204536438
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:08.969903 secs
# 46
# Question:  - What new features were added in the Knox Capture v1.9 release?
# GroundTruth:  Knox Capture v1.9 - October 16, 2023
# Knox Capture v1.9 added an AR demo page to support the new AR demo mode feature. Knox Capture v1.9 also added flashlight options and updated the Scan engine settings page
# Prediction:   Based on the provided context, the new features added in Knox Capture v1.9 release were:
#
# - Support for AR demo mode
# - On-screen suggestions for increasing scanning success rate
# - Ability to turn on flashlight by default
# - Latest release notes
# - Latest content updates
# ReRanker similarity: 0.9989149570465088
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:03.173116 secs
# 47
# Question:  - What should you do after installing and launching Knox Capture for the first time?
# GroundTruth:  After installing and launching Knox Capture for the first time, you are presented with links to numerous Terms, Conditions, and privacy policies. To proceed, you must review these documents and tap "Agree.
# Prediction:   Based on the context provided, after installing and launching Knox Capture for the first time, you should:
#
# Review the applicable Terms, Conditions, and privacy policies. If you agree to all of the documents, tap Agree.
# ReRanker similarity: 0.9999277591705322
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.225178 secs
# 48
# Question:  What setting allows you to add or remove barcode types when creating a Knox Capture profile?
# GroundTruth:  the Camera setting
# Prediction:   Based on the context provided, the setting that allows you to add or remove barcode types when creating a Knox Capture profile is:
#
# Barcode types
#
# To change the barcode types in a profile:
# 1. Tap Barcode types, then scroll down to review the selected types. Upon creation, profiles automatically use Code 128, Code 39, DataMatrix, EAN8, Interleaved 2 of 5, QR, UPCA, and UPCE.
# 2. Add or remove a barcode type of your choice.
# ReRanker similarity: 0.000325616798363626
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:07.945507 secs
# 49
# Question:  - What steps should you take to test barcode scanning using Samsung Internet and Knox Capture on a rugged device like an XCover Pro?
# GroundTruth:  To test barcode scanning using Samsung Internet and Knox Capture on a rugged device like an XCover Pro, follow these steps:
#
# 1. Select the Samsung Internet app from the Test apps list.
# 2. Tap the Scan trigger hardware key.
# 3. Aim the camera at a barcode to scan. The barcode will automatically scan once in focus
# Prediction:   Here are the steps to test barcode scanning using Samsung Internet and Knox Capture on a rugged device like an XCover Pro:
#
# 1. On the Knox Capture home screen, tap the options icon and select Test apps. This will start test mode.
#
# 2. Select the Samsung Internet app from the Test apps list, then tap Open.
#
# 3. Tap the browser's search field to bring up the on-screen keyboard.
#
# 4. Tap the Knox Capture icon on the keyboard to trigger a scan.
#
# 5. Optionally, trigger a scan using the Scan trigger hardware key on the XCover Pro.
#
# 6. Test the flashlight by tapping the button in the top-left corner.
#
# 7. Aim the camera at a barcode to scan it. The barcode will scan automatically when in focus.
#
# 8. Review the scanned data overlay to see the raw and processed values.
#
# 9. Tap the X to close the overlay and return to scanning.
#
# 10. When finished testing, close the Samsung Internet app to exit test mode.
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:10.570982 secs
# 50
# Question:  What are the two formats of scanned barcode data that can be inspected in test mode without any keystroke output rules applied?
# GroundTruth:  The scanned barcode data can be viewed in either test mode notation or hexadecimal format without any keystroke output rules applied
# Prediction:   Scanned data - The scanned barcode data in test mode notation without any keystroke output rules applied.
#
# Scanned raw - The scanned barcode data in hexadecimal format without any keystroke output rules applied.
# ReRanker similarity: 0.999573290348053
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:03.660464 secs
# 51
# Question:  What are the steps to export a scanning configuration from Knox Capture?
# GroundTruth:  To export a scanning configuration from Knox Capture, follow these steps:
#
# 1. On the home screen, tap the Share button in the lower-right corner.
# 2. Select Email and select your preferred email app. The configuration file will be attached automatically.
# 3. After sending the email with the configuration file attached, re-launch Knox Capture. A notification confirming the email submission will be displayed, followed by the date and time
# Prediction:   Based on the context, the steps to export a scanning configuration from Knox Capture are:
#
# 1. On the home screen, tap the Share button in the lower-right corner.
#
# 2. In the pop-up, select Email, then select your preferred email app. The configuration file is automatically attached.
#
# 3. After sending the email with the configuration file attached, re-launch Knox Capture. You should see a notification confirming the email submission followed by the date and time.
# ReRanker similarity: 0.9999215602874756
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:03.966219 secs
# 52
# Question:  How could an IT admin configure the Knox Capture interface to emulate a user tapping Enter on their keyboard after scanning a barcode?
# GroundTruth:  An IT admin could create a keystroke output rule to append an Enter key event after each scan. This would trigger the Knox Capture interface to emulate a user tapping Enter on their keyboard, which would then trigger a specific action or search result based on the scanned barcode
# Prediction:   The IT admin could configure the Knox Capture interface to emulate a user tapping Enter on their keyboard after scanning a barcode by:
#
# 1. Expanding the Keystroke output options, then tapping Send Enter character as.
#
# 2. In the pop-up, selecting Key event. This emulates a user hitting the Enter key on their keyboard after they type characters into a field.
#
# 3. Tapping Save to return to the Keystroke output options.
#
# 4. Scrolling down to Basic data formatting, then expanding the options.
#
# 5. Enabling the Append Enter character option by moving the slider to the right.
# ReRanker similarity: 0.9986411929130554
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.583072 secs
# 53
# Question:  - What method can a user employ to select multiple barcodes when using the camera scanning UI in Multi scan mode?
# GroundTruth:  The user can select multiple barcodes using the Batch setting in the camera scanning UI in Multi scan mode
# Prediction:   The user can employ the Batch method to select multiple barcodes when using the camera scanning UI in Multi scan mode. The context states "Batch – Lets the user scan multiple barcodes in a single camera frame using the scan button."
# ReRanker similarity: 0.9997479319572449
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.910157 secs
# 54
# Question:  According to the context, what are the two ways to remove a Bluetooth scanner that has been paired with your device?
# GroundTruth:  To remove a Bluetooth scanner, tap the gear icon next to the scanner and select Remove as a scanner. If you don't want to see the scan confirmation pop-up from Knox Capture again, select Unpair instead
# Prediction:   Based on the context, there are two ways to remove a Bluetooth scanner that has been paired with your device:
#
# 1. Tap the gear icon next to the scanner and select Remove as a scanner.
#
# 2. Tap the gear icon next to the scanner and select Unpair instead. This will also prevent the scan confirmation pop-up from appearing again.
# ReRanker similarity: 0.9998738765716553
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.582235 secs
# 55
# Question:  - How does the user import a configuration file in Knox Capture?
# GroundTruth:  To import a configuration file in Knox Capture, the user must:
# 1. Launch the import configuration menu
# 2. Acknowledge the warning message by tapping Confirm
# 3. Find the configuration file to import
# Knox Capture will import the configuration and display a success message
# Prediction:   To import a configuration file in Knox Capture:
#
# 1. Tap the more actions menu icon within the home page to the right of the Profiles list label. Then select Import.
#
# 2. After launching the import configuration menu, acknowledge the warning message by tapping Confirm.
#
# 3. Find the configuration file to import. Knox Capture will import the configuration and display a success message.
# ReRanker similarity: 0.9999252557754517
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.778950 secs
# 56
# Question:  How can a Knox Capture license be deactivated if a device is inactive for 180 days according to the passage?
# GroundTruth:  A Knox Capture license can be deactivated if a device is inactive for 180 days by using the Device Deactivation tool in the Knox Admin Portal
# Prediction:   According to the passage, if a device is inactive for 180 days, its Knox Capture license assignment is automatically released. The passage mentions 3 ways to deactivate a Knox Capture license:
#
# - Using the Device Deactivation tool in the Knox Admin Portal. You need a list of device IMEIs to either deactivate or keep.
#
# - Through your EMM. You can paste the key within the license field in the EMM console and save the configuration.
#
# - By uninstalling the Knox Capture app. Uninstalling automatically deactivates the license.
# ReRanker similarity: 0.9999276399612427
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:17.292230 secs
# 57
# Question:  According to the instructions, what are the three different methods an app can use to receive an Android intent from Knox Capture?
# GroundTruth:  The different methods an app can receive an Android intent from Knox Capture are through an activity, a foreground service, and a broadcast receiver
# Prediction:   The three different methods an app can use to receive an Android intent from Knox Capture are:
#
# 1. Using an activity to receive the intent
#
# 2. Using the foreground service to receive the intent
#
# 3. Using a broadcast receiver to receive the intent
# ReRanker similarity: 0.9999252557754517
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.093284 secs
# 58
# Question:  What key/value pair contains information about whether test mode is active for Knox Capture?
# GroundTruth:  ProfileConstants.KEY_INTENT_TEST_MODE="intent_in_testmode
# Prediction:   Key:= ProfileConstants.KEY_INTENT_TEST_MODE="intent_in_testmode"
# Value:= true/false : whether Knox Capture test mode is on.
# ReRanker similarity: 0.9991662502288818
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.890192 secs
#
# Number of chunk_docs after split and chunking= 2
#
# 59
# Question:  - What is the constant that contains the unprocessed raw scan data returned in the intent from Knox Capture?
# GroundTruth:  The constant that contains the unprocessed raw scan data returned in the intent from Knox Capture is "com.samsung.smartscan.unprocessed_raw_data"
# Prediction:   INTENT_OUTPUT_UNPROCESSED_RAW_DATA
# ReRanker similarity: 0.9638575315475464
# Langchain correctness: 0
# has_right_context: 1
# ...
# ReRanker similarity: 0.9986922144889832
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.145622 secs
# 216
# Question:  According to the context, what will Knox Capture now do if a user is paired with multiple devices in the Output path?
# GroundTruth:  Knox Capture will automatically disconnect from any previously paired devices. The user simply has to connect to the next device they want to use
# Prediction:   According to the context, if a user is paired with multiple devices in Knox Capture's Output path, they can now switch between each of their paired devices more easily. Previously, if a user had two paired devices in Output path, and Knox Capture was connected to device A, the user would first have to disconnect from device A before connecting to device B. With this release, the user simply has to connect to device B. Knox Capture automatically disconnects from any previously paired devices.
# ReRanker similarity: 0.9990882873535156
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:09.921139 secs
# 217
# Question:  - What new features were introduced in Knox Capture v1.9?
# GroundTruth:  Knox Capture v1.9 introduces the following new features:
#
# - Support for AR demo mode
# - On-screen suggestions for increasing scanning success rate
# - Ability to turn on flashlight by defaul
# Prediction:   Knox Capture v1.9 introduces the following new features:
#
# - Support for AR demo mode
# - On-screen suggestions for increasing scanning success rate
# - Ability to turn on flashlight by default
# - Latest release notes
# - Latest content updates
# - Official support for inverted-color recognition on all barcode types
# - Support for QR code license scanning
# - Knox Capture SDK v1.1.0
# ReRanker similarity: 0.9999277591705322
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.804193 secs
# 218
# Question:  - How can you configure Knox Capture to enable Managed mode on enterprise devices?
# GroundTruth:  To enforce Managed mode on enterprise devices with Knox Capture, you need to configure the app and deploy it through an EMM (Enterprise Mobility Management) console
# Prediction:   Based on the given context, to configure Knox Capture to enable Managed mode on enterprise devices:
#
# - Deploy Knox Capture as a managed app to end user devices through an EMM/UEM console. When deployed this way, the app will launch in Managed mode.
#
# - In Managed mode, end users can only perform barcode scans using permitted business apps. They cannot change scanning profiles, export settings, or switch to Admin mode.
#
# - To ensure all devices launch in Managed mode, export the configuration settings as a file from an Admin device and include it when deploying the app through the EMM.
#
# - Importing a configuration file on a device will override existing settings and switch it to Managed mode.
# ReRanker similarity: 0.9995779395103455
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:13.243207 secs
# 219
# Question:  How can a customer continue using Knox Capture after exceeding 100 free scans?
# GroundTruth:  To exceed the 100 free scans and continue using Knox Capture, a customer would need a valid Knox Suite license. Refer to the Manage license page for further information on obtaining a Knox Suite license
# Prediction:   Based on the context, a customer can continue using Knox Capture after exceeding 100 free scans by obtaining a valid Knox Suite license. The steps would be:
#
# 1. Sign up for a Samsung Knox account if they don't already have one.
#
# 2. Apply for access to Knox Suite.
#
# 3. After signing in to the Knox Admin Portal, navigate to the Licenses page to generate a Knox Capture license.
#
# 4. Use the generated Knox Suite license key to activate the Knox Capture license.
# ReRanker similarity: 0.9998705387115479
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.296971 secs
# 220
# Question:  - What technology is mentioned that can be used for scanning and data capture?
# GroundTruth:  Scandit technology is mentioned that can be used for scanning and data capture
# Prediction:   Based on the context provided, the technologies mentioned for scanning and data capture are:
#
# - QR
# - Code 128
# - UPCA
# ReRanker similarity: 0.8037041425704956
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:14.478010 secs
# 221
# Question:  How can you check the status of your Knox Capture license to see if it has expired or if your free scans have been used up?
# GroundTruth:  You can check the status of your Knox Capture license to see if it has expired or if your free scans have been used up by looking at the home screen of the Knox Capture app
# Prediction:   Based on the context, to check the status of your Knox Capture license to see if it has expired or if your free scans have been used up:
#
# - A notification displays on the home screen of the Knox Capture app with information on expiration or usage of free scans.
#
# - You can view remaining scans directly on the License page in the app. When 10 or fewer scans remain, you will be notified.
#
# - The license screen in the app confirms if your license is active or expired.
#
# - You cannot open the license menu again until expiration to prevent overwriting the license.
#
# - Uninstalling and reinstalling the app will require re-entering the license key if it had expired.
#
# - Through an EMM, you can view license status and remaining scans in the application configuration.
# ReRanker similarity: 0.9999232292175293
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.155875 secs
# 222
# Question:  What are some common reasons barcode data may not output correctly to a business app?
# GroundTruth:  1. Scan engine settings errors
# 2. Keystroke output errors
# 3. Problem with profile set u
# Prediction:   Some common reasons barcode data may not output correctly to a business app include:
#
# - Minor errors in the keystroke output and scan engine settings. Try using test mode to verify your configurations after setting up a profile.
#
# - Scanning overlay doesn't appear when launching the camera.
#
# - Cannot output scanned barcode data to HTML fields in Chromium-based web browsers.
#
# - Scan data is only partially sent to business app.
#
# - Current device software is unsupported when installing Knox Capture.
#
# - Keystroke output data sent to browser or web app instead of business app.
# ReRanker similarity: 0.7214126586914062
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.848161 secs
# 223
# Question:  What setting in Knox Capture profile can be adjusted to resolve the issue of undelivered data being sent to the scanner overlay instead of the business app?
# GroundTruth:  Keystroke output > Set key event dela
# Prediction:   The keystroke output > Set key event delay setting in the Knox Capture profile can be extended to resolve the issue of undelivered data being sent to the scanner overlay instead of the business app. By default, the key event delay is set to 0 ms. Extending the length of this delay allows more time for the key events to be sent to the business app before the focus switches back to the scanner overlay.
# ReRanker similarity: 0.9959436058998108
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.857453 secs
# 224
# Question:  - Why is the scanning overlay not appearing when launching the camera on some devices?
# GroundTruth:  - The scanning overlay isn't appearing when launching the camera on some devices because of an Android Enterprise policy that controls the DISALLOW_CREATE_WINDOWS boolean. This policy is set to "true," preventing apps like Knox Capture from creating windows for the scanner overlay when the camera launches.
#
# Additional Information:
# The resolution for this issue is to have the policy that controls this boolean set to the equivalent of "false" in your UEM profile. For Knox Manage customers, the Create Window policy should be set to "Allow." For other UEM's, check their documentation for Android Enterprise policies
# Prediction:   Based on the given context, the scanning overlay does not appear when launching the camera on some devices because the Android Enterprise policy that controls the DISALLOW_CREATE_WINDOWS boolean is set to true. This prevents apps like Knox Capture from creating a window for the scanner overlay when the camera launches. The issue can be resolved by ensuring the policy sets this value to false, allowing the creation of scanner overlay windows.
# ReRanker similarity: 0.9980717897415161
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.553929 secs
# 225
# Question:  What Knox product allows you to use facial biometrics for multiuser sign-in on shared frontline worker devices?
# GroundTruth:  Knox Authentication Manage
# Prediction:   Knox Authentication Manager - A managed Android app for shared Samsung devices that provides multiuser facial biometrics and sign-in automation for increased frontline worker productivity and safety.
# ReRanker similarity: 0.9996005892753601
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.231122 secs
# 226
# Question:  - What are the prerequisites before you can start generating Knox Suite licenses for your Enterprise Edition (EE) devices?
# GroundTruth:  You must perform the prerequisite steps described in this section before you begin generating Knox Suite licenses for your Enterprise Edition (EE) devices
# Prediction:   Here are the prerequisites that need to be completed before generating Knox Suite licenses for Enterprise Edition (EE) devices:
#
# 1. Register for the Knox Admin Portal with your Samsung account.
#
# 2. Sign in to the Knox Admin Portal.
#
# 3. Click your account icon to view your Knox Customer ID.
#
# 4. Purchase EE devices from a Samsung device reseller. Give your customer ID to your reseller. Your device reseller must be a member of the Knox Deployment Program (KDP).
#
# 5. Generate a Knox Suite license.
# ReRanker similarity: 0.9996532201766968
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:11.057607 secs
# 227
# Question:  What are the columns shown in the table on the Enterprise Edition Dashboard?
# GroundTruth:  The table columns on the Enterprise Edition Dashboard are defined as follows: Reseller (ID), Devices Last Uploaded, # of Devices Uploaded to Date, # of Devices License Generated, # of Devices Remaining, License Last Generated
# Prediction:   The table columns on the Enterprise Edition Dashboard are:
#
# - Reseller (ID) - The name and ID of the device reseller that uploaded EE devices.
#
# - Devices Last Uploaded - The date the reseller last uploaded devices.
#
# - # of Devices Uploaded to Date - The total number of devices the reseller has ever uploaded.
#
# - # of Devices License Generated - The number of devices that have a Knox Suite license.
#
# - # of Devices Remaining - The number of devices without a Knox Suite license.
#
# - License Last Generated - The date you last generated a Knox Suite license for devices from this reseller.
# ReRanker similarity: 0.9994900226593018
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.756108 secs
# 228
# Question:  When was the most recent security update released for devices in a given country?
# GroundTruth:  The most recent security update was released for the devices in a given country on the release date of the most recent security update
# Prediction:   Based on the context, the release date of the most recent security update for devices in a country can be found under the 'LATEST' column in the table under the 'SECURITY UPDATES' tab. The 'LATEST' column shows the release date of the most recent security update for the devices in each country.
# ReRanker similarity: 0.9576374292373657
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.661703 secs
# 229
# Question:  How can you confirm your Knox Suite license in the Knox Manage console?
# GroundTruth:  Launch the Knox Manage console and go to the Setting > License page. Confirm that the license key was automatically generated and registered for you with the Knox Suite license type
# Prediction:   Here are the steps to confirm your Knox Suite license in the Knox Manage console:
#
# Launch the Knox Manage console. In the navigation pane, go to Setting > License. Confirm that the license key was automatically generated and registered for you. It must have the Knox Suite license type.
# ReRanker similarity: 0.9999253749847412
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.105870 secs
# 230
# Question:  - What website do you need to go to in order to create a Samsung account?
# GroundTruth:  SamsungKnox.co
# Prediction:   Based on the given context, to create a Samsung account you need to go to SamsungKnox.com.
# ReRanker similarity: 0.6512892246246338
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.550909 secs
# 231
# Question:  - How do you create a Samsung account?
# GroundTruth:  To create a Samsung account, follow the steps outlined below. First, read the service's terms and conditions. Then, agree to all of them and select each one. After that, fill out the basic information for your account, enter the verification code sent to your email, and click Done
# Prediction:   Based on the given context, here are the steps to create a Samsung account:
#
# Go to SamsungKnox.com. Click GET STARTED in the top right corner. Enter your work email address and select Knox Suite from the list of Knox solutions. Then, click CREATE MY ACCOUNT. If your email address is already associated with a Samsung account, you're prompted to sign in to your Samsung account. Otherwise, you're prompted to create one. If you're prompted to create one, create a Samsung account. Read the service's terms and conditions. If you agree to all of them, select each one. Then, click Agree. Fill out the basic information for your account and click Next. Enter the verification code sent to your email. Click Done.
# ReRanker similarity: 0.9998515844345093
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:05.032001 secs
# 232
# Question:  - How would a device reseller typically register purchased devices to the Knox servers on behalf of a customer?
# GroundTruth:  A device reseller typically registers purchased devices to the Knox servers on behalf of the customer during initial set up of Knox Suite
# Prediction:   Based on the given context, a device reseller would typically register purchased devices to the Knox servers on behalf of a customer by:
#
# - The customer purchasing EE devices from the device reseller
# - The customer providing their Knox Customer ID to the reseller
# - The reseller must be a member of the Knox Deployment Program (KDP)
# - The reseller uploads the purchased devices to SamsungKnox.com under the customer's Knox Customer ID
# ReRanker similarity: 0.9996412992477417
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.857098 secs
# 233
# Question:  - How can enterprise customers get professional and instant support for Knox Suite issues?
# GroundTruth:  Enterprise customers can enjoy professional and instant support for Knox Suite issues by signing up for one of Samsung's paid technical support programs. These programs offer dedicated support and expedited issue resolution to ensure minimal downtime for critical systems
# Prediction:   Could not find answer in given contexts.
# ReRanker similarity: 7.651076884940267e-05
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.477299 secs
# CPU times: user 41.5 s, sys: 964 ms, total: 42.5 s
# Wall time: 51min 33s
