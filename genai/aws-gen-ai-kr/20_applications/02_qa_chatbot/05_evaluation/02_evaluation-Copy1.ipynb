# %% [markdown]
# # Evaluation
# - For retriever
# - For generator

# %% [markdown]
# ## Setting
#  - Auto Reload
#  - path for utils

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
module_path = "../../.."
sys.path.append(os.path.abspath(module_path))

# %% [markdown]
# ## 1. Bedrock Client 생성

# %%
import json
import boto3
from pprint import pprint
from termcolor import colored
from utils import bedrock, print_ww
from utils.bedrock import bedrock_info

# %% [markdown]
# ### ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----
# - os.environ["AWS_DEFAULT_REGION"] = "<REGION_NAME>"  # E.g. "us-east-1"
# - os.environ["AWS_PROFILE"] = "<YOUR_PROFILE>"
# - os.environ["BEDROCK_ASSUME_ROLE"] = "<YOUR_ROLE_ARN>"  # E.g. "arn:aws:..."
# - os.environ["BEDROCK_ENDPOINT_URL"] = "<YOUR_ENDPOINT_URL>"  # E.g. "https://..."

# %%
boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    endpoint_url=os.environ.get("BEDROCK_ENDPOINT_URL", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
)

aws_region = os.environ.get("AWS_DEFAULT_REGION", None)
print (colored("\n== FM lists ==", "green"))
pprint (bedrock_info.get_list_fm_models())
# Out:
# Create new client
#   Using region: None
#   Using profile: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
#
# == FM lists ==
# {'Claude-Instant-V1': 'anthropic.claude-instant-v1',
#  'Claude-V1': 'anthropic.claude-v1',
#  'Claude-V2': 'anthropic.claude-v2',
#  'Cohere-Embeddings-En': 'cohere.embed-english-v3',
#  'Cohere-Embeddings-Multilingual': 'cohere.embed-multilingual-v3',
#  'Command': 'cohere.command-text-v14',
#  'Command-Light': 'cohere.command-light-text-v14',
#  'Jurassic-2-Mid': 'ai21.j2-mid-v1',
#  'Jurassic-2-Ultra': 'ai21.j2-ultra-v1',
#  'Llama2-13b-Chat': 'meta.llama2-13b-chat-v1',
#  'Titan-Embeddings-G1': 'amazon.titan-embed-text-v1',
#  'Titan-Text-G1': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Light': 'amazon.titan-text-lite-v1'}

# %% [markdown]
# ## 2. Titan Embedding 및 LLM 인 Claude-v2 모델 로딩

# %% [markdown]
# ### LLM 로딩 (Claude-v2)

# %%
from langchain.llms.bedrock import Bedrock
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm_text = Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-V2"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

llm_text_light = Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-Instant-V1"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %% [markdown]
# ### Embedding 모델 선택

# %%
from utils.rag import KoSimCSERobertaContentHandler, SagemakerEndpointEmbeddingsJumpStart

# %%
def get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name=None):

    if is_bedrock_embeddings:
        # We will be using the Titan Embeddings Model to generate our Embeddings.
        from langchain.embeddings import BedrockEmbeddings
        llm_emb = BedrockEmbeddings(
            client=boto3_bedrock,
            model_id=bedrock_info.get_model_id(
                #model_name="Titan-Embeddings-G1"
                model_name="Cohere-Embeddings-En"
            )
        )
        print("Bedrock Embeddings Model Loaded")

    elif is_KoSimCSERobert:
        LLMEmbHandler = KoSimCSERobertaContentHandler()
        endpoint_name_emb = endpont_name
        llm_emb = SagemakerEndpointEmbeddingsJumpStart(
            endpoint_name=endpoint_name_emb,
            region_name=aws_region,
            content_handler=LLMEmbHandler,
        )
        print("KoSimCSERobert Embeddings Model Loaded")
    else:
        llm_emb = None
        print("No Embedding Model Selected")

    return llm_emb

# %% [markdown]
# #### [중요] is_KoSimCSERobert == True 일시에 endpoint_name 을 꼭 넣어 주세요.

# %%
is_bedrock_embeddings = True
is_KoSimCSERobert = False
aws_region = os.environ.get("AWS_DEFAULT_REGION", None)

##############################
# Parameters for is_KoSimCSERobert
##############################
if is_KoSimCSERobert: endpont_name = "<endpoint-name>"
else: endpont_name = None
##############################

llm_emb = get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name)
# Out:
# Bedrock Embeddings Model Loaded

# %% [markdown]
# ## 3. Depoly ReRanker model (if needed)

# %%
import json
import sagemaker
from sagemaker.huggingface import HuggingFaceModel

# %%
depoly = False

# %%
if depoly:

    try:
        role = sagemaker.get_execution_role()
    except ValueError:
        iam = boto3.client('iam')
        role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

    # Hub Model configuration. https://huggingface.co/models
    hub = {
        'HF_MODEL_ID':'BAAI/bge-reranker-large',
        'HF_TASK':'text-classification'
    }

    # create Hugging Face Model Class
    huggingface_model = HuggingFaceModel(
        transformers_version='4.26.0',
        pytorch_version='1.13.1',
        py_version='py39',
        env=hub,
        role=role, 
    )

    # deploy model to SageMaker Inference
    predictor = huggingface_model.deploy(
        initial_instance_count=1, # number of instances
        instance_type='ml.g5.xlarge' # instance type
    )

    print(f'Accept: {predictor.accept}')
    print(f'ContentType: {predictor.content_type}')
    print(f'Endpoint: {predictor.endpoint}')

# %% [markdown]
# ### Reranker

# %%
#endpoint_name = "huggingface-pytorch-inference-2023-11-15-04-37-45-120" # ml.m5.2xlarge
endpoint_name = "huggingface-pytorch-inference-2023-11-15-07-53-21-605" # ml.g5.xlarge

# %%
runtime_client = boto3.Session().client('sagemaker-runtime')
print (f'runtime_client: {runtime_client}')
# Out:
# runtime_client: <botocore.client.SageMakerRuntime object at 0x7fbc3a5e9c00>

# %% [markdown]
# ## 4. LangChainmOpenSearch VectorStore 정의
# ### 선수 조건
# - 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 OpenSearch Index 가 생성이 되어 있어야 합니다.
# #### [중요] 아래에 aws parameter store 에 아래 인증정보가 먼저 입력되어 있어야 합니다.
# - 01_preprocess_docs/01_parameter_store_example.ipynb 참고

# %%
from utils.proc_docs import get_parameter

# %%
ssm = boto3.client("ssm", "us-east-1")

opensearch_domain_endpoint = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_domain_endpoint',
)

opensearch_user_id = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_userid',
)

opensearch_user_password = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_password',
)

http_auth = (opensearch_user_id, opensearch_user_password) # Master username, Master password

# %% [markdown]
# ### Index 이름 셋팅
# - 이전 노트북 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 생성된 OpenSearch Index name 입력

# %%
#index_name = "v13-genai-poc-knox-titan-eval-sample-0.05-1024c-256o"
index_name = "v14-genai-poc-knox-cohere-eval-sample-0.05-1024c-256o"

# %% [markdown]
# ### OpenSearch Client 생성

# %%
from utils.opensearch import opensearch_utils

# %%
os_client = opensearch_utils.create_aws_opensearch_client(
    aws_region,
    opensearch_domain_endpoint,
    http_auth
)

# %% [markdown]
# ### LangChain OpenSearch VectorStore 생성

# %%
from langchain.vectorstores import OpenSearchVectorSearch

# %%
vector_db = OpenSearchVectorSearch(
    index_name=index_name,
    opensearch_url=opensearch_domain_endpoint,
    embedding_function=llm_emb,
    http_auth=http_auth, # http_auth
    is_aoss =False,
    engine="faiss",
    space_type="l2"
)
vector_db

# %% [markdown]
# ## 5. Retriever 정의

# %%
from utils.rag import OpenSearchHybridSearchRetriever

# %%
opensearch_hybrid_retriever = OpenSearchHybridSearchRetriever(
    os_client=os_client,
    index_name=index_name,
    llm_text=llm_text_light, # used in rag_fusion, hyde and reranker(num_tokens)
    llm_emb=llm_emb,

    # option for lexical
    minimum_should_match=0,
    filter=[],

    # option for rank fusion
    fusion_algorithm="RRF", # ["RRF", "simple_weighted"], rank fusion 방식 정의
    ensemble_weights=[.5, .5], # [for lexical, for semantic], Lexical, Semantic search 결과에 대한 최종 반영 비율 정의
    reranker=True, # enable reranker with reranker model
    reranker_endpoint_name=endpoint_name, # endpoint name for reranking model
    #rag_fusion=False, # enable rag_fusion
    #query_augmentation_size=3, # query_augmentation_size in rag_fusion

    # option for async search
    async_mode=True,

    # option for output
    k=5, # 최종 Document 수 정의
    verbose=False,
)

# %%
search_hybrid_result = opensearch_hybrid_retriever.get_relevant_documents("knox")
search_hybrid_result
# Out:
# [Document(page_content='What is Knox Suite?. Knox Suite is a bundled offering designed to help enterprise IT admins better manage your fleet of devices. It includes individual services such as Knox Platform for Enterprise, Knox Mobile Enrollment, Knox Manage, Knox E-FOTA, and Knox Asset Intelligence. Key features of Knox Suite include: Secure - Ensure your business data is protected with managed security features at your control. Deploy - Enroll corporate devices to EMM automatically and securely, right out of the box. Manage - Enable comprehensive management over corporate devices and OS versions. Analyze - Strengthen in-depth device analytics for mobile productivity and asset management.', metadata={'source': 'all_processed_data.json', 'seq_num': 74, 'title': ' What is Knox Suite?', 'url': 'https://docs.samsungknox.com/admin/knox-suite/faq/#what-is-knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'id': 'fee02e43-1df8-4b77-85b3-470442dc4e37'}),
#  Document(page_content=". From the program's point of view, data appears exactly as if someone had typed it manually using a keyboard. How Knox Capture works In a similar way, Knox Capture also acts as a wedge between a software program and keyboard. However, instead of being a physical scanning device, Knox Capture is a mobile solution built for compatible Android smartphones and tablets. Enterprise IT admins can either download the Knox Capture app from Google Play, or custom-build their own wedge scanner apps using the Knox Capture SDK (Software Development Kit). Once Knox Capture is installed and running on a device, it *wedges* between an application (for example, a business app used to track inventory) and the mobile device's on-screen keyboard. When an end-user launches their business app, they can simply tap an on-screen button or press a hardware button on their device to trigger a barcode scan using the device's camera", metadata={'source': 'all_processed_data.json', 'seq_num': 3, 'title': 'Overview', 'url': 'https://docs.samsungknox.com/admin/knox-capture/overview', 'project': 'KCAP', 'last_updated': '2023-07-26', 'id': 'b56660cf-377c-4189-a6f8-0439eb8eb48f'}),
#  Document(page_content="Configure output path. Knox Capture can send scanned data to a Bluetooth-enabled device, like a PC, as a Human Interface Device (HID) keyboard, emulating the functionality of a hardware scanner. This feature is ideal for high-security enterprises with wireless network restrictions. For example, you might want to keep track of which assets are checked in or out of a restricted facility. In that case, you can use Knox Capture to scan an asset tag and send its data directly to a PC through Bluetooth. How it works The following describes how connected devices and scanned data are handled when using Knox Capture's Bluetooth wedge functionality: If the device is connected to a PC, output data is entered at the location of the keyboard cursor. Knox Capture applies any basic and advanced data formatting rules set in the default scanning profile to the output data. Only one Bluetooth-enabled device can be connected at a time. To connect to another device, you must first disconnect the current one", metadata={'source': 'all_processed_data.json', 'seq_num': 10, 'title': 'Configure output path', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-output-path', 'project': 'KCAP', 'last_updated': '2023-07-26', 'id': '4e4dcd80-a149-4854-831a-9e82b163f6ce'}),
#  Document(page_content='Introduction to Enterprise Edition. If you have purchased Enterprise Edition (EE) devices you are entitled to a 1-year renewable Knox Suite license. This section describes how to manage Knox Suite licenses for Samsung EE licenses. When your Knox Suite for EE license expires, you can extend it by 1 or more years. Contact your reseller for more information. Section , Description - , - Before you begin , Perform the prerequisite procedures needed to generate a Knox Suite license. Generate a Knox Suite license, Generate a license for Enterprise Edition devices Merge Knox Suite licenses , Append new EE devices to an existing Knox Suite license or merge Knox Suite licenses. Use the Enterprise Edition dashboard , Explore the Enterprise Edition dashboard, which lets you view devices and licenses, as well as the security and maintenance history of devices.', metadata={'source': 'all_processed_data.json', 'seq_num': 68, 'title': 'Introduction to Enterprise Edition', 'url': 'https://docs.samsungknox.com/admin/knox-suite/enterprise-edition-devices/introduction-to-enterprise-edition', 'project': 'KS', 'last_updated': '2023-07-26', 'id': '4ad9f943-21b5-4a2c-ac79-15c85c6152ed'}),
#  Document(page_content='How do I install Knox Capture? . You can install Knox Capture from the Play Store. To install Knox Capture on multiple managed devices, use Managed Google Play in an EMM console. For more information on deploying and configuring Knox Capture across a device fleet, see Deployment.', metadata={'source': 'all_processed_data.json', 'seq_num': 42, 'title': 'How do I install Knox Capture? ', 'url': 'https://docs.samsungknox.com/admin/knox-capture/faq/#how-do-i-install-knox-capture', 'project': 'KCAP', 'last_updated': '2023-07-26', 'id': 'ef641b50-a925-404c-bd9f-7ad2a50c8a86'})]

# %% [markdown]
# ## 6. RAG chain 정의

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# %% [markdown]
# ### Prompting
# - [TIP] Prompt의 instruction의 경우 한글보다 영어로 했을 때 더 좋은 결과를 얻을 수 있습니다.

# %%
prompt_template = """
\n\nHuman: Here is the context, inside <context></context> XML tags.

<context>
{context}
</context>

Only using the context as above, answer the following question with the rules as below:
    - Don't insert XML tag such as <context> and </context> when answering.
    - Write as much as you can
    - Be courteous and polite
    - Only answer the question if you can find the answer in the context with certainty.

Question:
{question}

If the answer is not in the context, just say "Could not find answer in given contexts."

\n\nAssistant:"""

PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %% [markdown]
# ### Update Search Params (Optional)

# %%
opensearch_hybrid_retriever.update_search_params(
    k=5,
    minimum_should_match=0,
    filter=[],
    reranker=True,
    reranker_endpoint_name=endpoint_name,
    rag_fusion=True, # enable rag_fusion
    query_augmentation_size=3, # query_augmentation_size in rag_fusion
    hyde=False, # enable hyde
    hyde_query=["web_search"], # query type in hyde 
    llm_text=llm_text, # used in rag_fusion, hyde and reranker
    verbose=False
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm_text,
    chain_type="stuff",
    retriever=opensearch_hybrid_retriever,
    return_source_documents=True,
    chain_type_kwargs={
        "prompt": PROMPT,
        "verbose": False,
    },
    verbose=False
)

# %%
query = " - What method can a user employ to select multiple barcodes when using the camera scanning UI in Multi scan mode?"
qa_chain(query)
# Out:
# {'query': ' - What method can a user employ to select multiple barcodes when using the camera scanning UI in Multi scan mode?',
#  'result': ' Based on the given context, there are 3 options for selecting multiple barcodes when using the camera scanning UI in Multi scan mode:\n\n- Batch - Lets the user scan multiple barcodes in a single camera frame using the scan button. \n\n- Aim and scan - Requires the user to aim the camera at a set of barcodes and tap the Scan button to capture the barcodes, one at a time.\n\n- Tap to select - Lets a user aim the camera at multiple barcodes, freeze the scanning overlay, tap to select barcodes, and tap the Scan button to capture data from the selected barcodes.',
#  'source_documents': [Document(page_content='.1 1 Device users will see a Scan button in the camera preview window when they trigger a barcode scan. Device users can simply tap Scan each time they want to capture a new barcode. As each barcode is scanned, a counter in the top-left corner of the preview window gets updated. Once the user is finished scanning, they can click Done to close the camera preview window and return to the business app. #Multi scan preferences Sets the way a user selects barcodes when interacting with the camera scanning UI in Multi scan mode. Available options: Setting Options Barcode selection Automatic (default) &mdash; Allows the user to scan multiple barcodes without having to press a scan button. Batch &mdash; Lets the user scan multiple barcodes in a single camera frame using the scan button. Aim and scan &mdash; Requires the user to aim the camera at a set of barcodes and tap the Scan button to capture the barcodes, one at a time', metadata={'source': 'all_processed_data.json', 'seq_num': 11, 'title': 'Configure scan engine settings', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-scan-engine-settings', 'project': 'KCAP', 'last_updated': '2023-10-16', 'id': '9c147051-4eec-4bd5-b183-7643dc39a4cb'}),
#   Document(page_content='. Batch &mdash; Lets the user scan multiple barcodes in a single camera frame using the scan button. Aim and scan &mdash; Requires the user to aim the camera at a set of barcodes and tap the Scan button to capture the barcodes, one at a time. Tap to select &mdash; Lets a user aim the camera at multiple barcodes, freeze the scanning overlay, tap to select barcodes, and tap the Scan button to capture data from the selected barcodes. Scan session limit This defines the number of barcodes a user must scan before the camera preview window closes. A counter in the top-left corner of the preview window gets updated after each scan. Once the user has scanned the set number of barcodes, the camera preview window closes and the user returns to the business app. Users can exit the camera preview window at any time by tapping Done, regardless of the number of barcodes captured. You can set any integer value. By default, this value is set to 0 to indicate infinite scans', metadata={'source': 'all_processed_data.json', 'seq_num': 11, 'title': 'Configure scan engine settings', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-scan-engine-settings', 'project': 'KCAP', 'last_updated': '2023-10-16', 'id': '29c2a72d-0fc7-4971-8f9e-ff1ae6bbb8e9'}),
#   Document(page_content='. #Scan mode Sets the primary capture mode for scanning. Available options: Setting , Option - , - Single scan (default) , Scans and parses one barcode at a time. Multi scan , Detects multiple barcodes in the scan area at the same time. #Single scan preferences Sets the way a user selects barcodes when interacting with the camera scanning UI in Single scan mode. Available options: Setting Options Barcode selection Automatic (default) &mdash; Captures the first-detected barcode without additional user input. Aim and scan &mdash; Requires the user to aim the camera at a barcode and tap the Scan button to capture barcode data. Continuous scanning Off (default) On &mdash; Allow device users to scan several barcodes in sequence (and have each scan be registered as a single event) without having to press the camera trigger button between each scan.1 1 Device users will see a Scan button in the camera preview window when they trigger a barcode scan', metadata={'source': 'all_processed_data.json', 'seq_num': 11, 'title': 'Configure scan engine settings', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-scan-engine-settings', 'project': 'KCAP', 'last_updated': '2023-10-16', 'id': 'a1ff6689-8af1-4c02-a489-0657546edefa'}),
#   Document(page_content='Knox Capture v1.5 release notes. Scanner overlay Starting with Knox Capture v1.5, a scanner overlay is available. This overlay appears as a scanner preview over business apps, and enables device users to immediately see scanned data entered into an app field. Functionally, the scanner overlay works much like the full-screen scanner. When the device user aims the camera at the barcode, Knox Capture then sends the scanned data to the business app depending on whether single scan or multi-scan mode is enabled, and how Barcode selection is configured. See Use the scanner overlay to learn more. Continuous scanning for single scan mode Previously, when device users scanned single barcodes, the camera preview turned on before each scan, then off again once the scan was completed. Now, in Single scan preferences, you can turn on Continuous scanning to scan back-to-back barcodes without relaunching the camera preview after every scan', metadata={'source': 'all_processed_data.json', 'seq_num': 32, 'title': 'Knox Capture v1.5 release notes', 'url': 'https://docs.samsungknox.com/admin/knox-capture/release-notes/v1-5', 'project': 'KCAP', 'last_updated': '2023-07-26', 'id': '1e7485ca-c989-4a17-92b7-47a5ae32cd0c'}),
#   Document(page_content='Configure scan engine settings. Scan engine settings define the core Knox Capture behavior, such as how barcodes are scanned, and what happens with the data after each scan. The following settings are available: Barcode types Choose the barcode symbologies the scanner should recognize. For example, Code 39, and QR code. Available barcode types: Type , Options - , - Numeric-only (1D) , Codabar, EAN13, EAN8, Interleaved 2 of 5, UPCA, UPCE Alphanumeric (1D) , Code 128, Code 39, Code 93 2D , Data Matrix, PDF417, QR Every barcode except Codabar and Code 93 is enabled by default. Scanning settings Use scan settings to define how barcodes are scanned, selected, and parsed before Knox Capture sends them to a target business application. #Scan mode Sets the primary capture mode for scanning. Available options: Setting , Option - , - Single scan (default) , Scans and parses one barcode at a time. Multi scan , Detects multiple barcodes in the scan area at the same time', metadata={'source': 'all_processed_data.json', 'seq_num': 11, 'title': 'Configure scan engine settings', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-scan-engine-settings', 'project': 'KCAP', 'last_updated': '2023-10-16', 'id': '2b7f8e82-2b37-48f5-b5e1-d413a52f805b'})]}

# %% [markdown]
# ## 3.Evaluation
#  - [langchain evaluator](https://python.langchain.com/docs/guides/evaluation/string/criteria_eval_chain)

# %% [markdown]
# ### Load ground truth

# %%
import pandas as pd

# %%
ground_thruth = pd.read_csv("eval_dataset_v13.csv")

# %%
import time
import datetime
from langchain.evaluation import Criteria
from langchain.evaluation import EvaluatorType
from langchain.evaluation import load_evaluator

# %%
list(Criteria)
# Out:
# [<Criteria.CONCISENESS: 'conciseness'>,
#  <Criteria.RELEVANCE: 'relevance'>,
#  <Criteria.CORRECTNESS: 'correctness'>,
#  <Criteria.COHERENCE: 'coherence'>,
#  <Criteria.HARMFULNESS: 'harmfulness'>,
#  <Criteria.MALICIOUSNESS: 'maliciousness'>,
#  <Criteria.HELPFULNESS: 'helpfulness'>,
#  <Criteria.CONTROVERSIALITY: 'controversiality'>,
#  <Criteria.MISOGYNY: 'misogyny'>,
#  <Criteria.CRIMINALITY: 'criminality'>,
#  <Criteria.INSENSITIVITY: 'insensitivity'>,
#  <Criteria.DEPTH: 'depth'>,
#  <Criteria.CREATIVITY: 'creativity'>,
#  <Criteria.DETAIL: 'detail'>]

# %%
evaluator = load_evaluator(
    EvaluatorType.LABELED_CRITERIA,
    llm=llm_text,
    criteria=Criteria.CORRECTNESS
)

# %% [markdown]
# ### Check prompt for evaluation

# %%
print(evaluator.prompt.partial_variables)
print("==")
print(evaluator.prompt.template)
# Out:
# {'criteria': 'correctness: Is the submission correct, accurate, and factual?'}
# ==
# You are assessing a submitted answer on a given task or input based on a set of criteria. Here is the data:
# [BEGIN DATA]
# ***
# [Input]: {input}
# ***
# [Submission]: {output}
# ***
# [Criteria]: {criteria}
# ***
# [Reference]: {reference}
# ***
# [END DATA]
# Does the submission meet the Criteria? First, write out in a step by step manner your reasoning about each criterion to be sure that your conclusion is correct. Avoid simply stating the correct answers at the outset. Then print only the single character "Y" or "N" (without quotes or punctuation) on its own line corresponding to the correct answer of whether the submission meets all criteria. At the end, repeat just the letter again by itself on a new line.

# %%
ground_thruth.head()
# Out:
#                                             question  \
# 0  What are some examples of barcodes that can be...
# 1  How would an administrator configure Knox Capt...
# 2  - What are the three steps outlined in the con...
# 3  What are the two steps described to start scan...
# 4  According to the instructions, how do you sele...
#
#                                               answer  \
# 0  According to the provided context, the followi...
# 1  An administrator would configure the trigger f...
# 2  The three steps outlined to set up a default s...
# 3  Step 1: Review the scanning configuration. Ste...
# 4  To select an individual activity visually with...
#
#                                  doc_id  \
# 0  f6f534aa-9316-4232-bd37-08b68381b1b2
# 1  c1a8f827-a4f9-4137-998b-b4e974d7a6fb
# 2  446bcc38-c806-4ab7-ae73-4a07025044a2
# 3  f87907d6-b400-432d-b108-86a87837a9da
# 4  9b451f9a-acbf-4ab5-ab65-68e77df10ab4
#
#                                                  doc
# 0  AR demo barcodes. Use the following barcodes t...
# 1  . Deploy configuration to EMM/UEM - Learn abou...
# 2  . Step 2: Edit the default profile Tap Default...
# 3  . Tap the options button to view the scanning ...
# 4  . 2. An app can also be selected by tapping it...

# %%
# %%time
evaluation = []
for idx, row in enumerate(ground_thruth.itertuples()):
    try:
    
        question, answer, doc, doc_id = getattr(row, "question"), getattr(row, "answer"), getattr(row, "doc"), getattr(row, "doc_id")

        start = time.time()
        response = qa_chain(question)
        elapsed = time.time() - start

        prediction = response["result"]

        for doc_ in response["source_documents"]:
            doc_.metadata["id"]

        retrieved_docs = {doc.page_content: idx+1 for idx, doc in enumerate(response["source_documents"])}
        contexts = "\n\n".join(retrieved_docs.keys())

        payload = json.dumps(
            {
                "inputs": [
                    {"text": answer, "text_pair": prediction},
                ]
            }
        )

        response = runtime_client.invoke_endpoint(
            EndpointName=endpoint_name,
            ContentType="application/json",
            Accept="application/json",
            Body=payload
        )
        out = json.loads(response['Body'].read().decode()) ## for json

        eval_result = evaluator.evaluate_strings(
            input=question,
            prediction=prediction,
            reference=answer,
        )

        reranker_sim = out[0]["score"]
        langchain_correctness = eval_result["score"]
        if doc in retrieved_docs:
            true_context_rank = retrieved_docs[doc]
            has_right_context = 1
            mrr = 1/true_context_rank
        else:
            true_context_rank = has_right_context = 0
            mrr = 0
        total_contexts = len(retrieved_docs)
        latency = datetime.timedelta(seconds=elapsed)

        print(idx)
        print(colored("Question: ", "red"), colored(question, "red"))
        print(colored("GroundTruth: ", "green"), colored(answer, "green"))
        print(colored("Prediction: ", "blue"), colored(prediction, "blue"))
        print(f'ReRanker similarity: {reranker_sim}')
        print(f'Langchain correctness: {langchain_correctness}')
        print(f'has_right_context: {has_right_context}')
        print(f'true_context_rank: {true_context_rank}/{total_contexts}')
        print(f'mrr: {mrr:.3f}')
        print(f'latency: {latency} secs')

        evaluation.append([question, answer, prediction, \
                           has_right_context, true_context_rank, total_contexts, mrr, \
                           reranker_sim, langchain_correctness, elapsed, contexts])
    except:
        print ("err", idx)

eval_results = pd.DataFrame(
    evaluation,
    columns=["question", "true_answer", "prediction", \
             "has_right_context", "true_context_rank", "total_contexts", "mrr", \
             "reranker_sim", "langchain_correctness", "latency", "contexts"]
)
eval_results.to_csv("eval_results_rag_fusion.csv", index=False)
#eval_results.to_pickle("eval_results.pkl")
# Out:
# 0
# Question:  What are some examples of barcodes that can be used to test the Knox Capture AR features according to the context?
# GroundTruth:  According to the provided context, the following are some of the barcodes that can be used to test the Knox Capture AR features:
#
# Barcode 1, Barcode 2, Barcode 3, Barcode 4, Barcode 5 and Barcode 6
# Prediction:   Barcode 1
# Barcode 2
# Barcode 3
# Barcode 4
# Barcode 5
# Barcode 6
# ReRanker similarity: 0.9987139701843262
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.547707 secs
# 1
# Question:  How would an administrator configure Knox Capture to allow camera scanning to be triggered by a hardware button, on-screen button, or both?
# GroundTruth:  An administrator would configure the trigger for both hardware buttons and on-screen buttons using the Set camera scan trigger feature
# Prediction:   The administrator can configure the camera scan trigger setting to allow scanning to be launched using a hardware button, on-screen button, or both. The context mentions:
#
# "Set camera scan trigger - A feature that allows IT admins to specify whether a user can trigger a camera scan using a hardware button on the device, an on-screen floating action button, or both. Learn about the different button options, and how to configure the triggers from both the admin and end-user's point of view."
#
# It also states:
#
# "Tap the options button to view the scanning configuration details, access support, and view data about the app. To view the current scanning configuration: 1. Tap View current configuration in the options menu. 2."
#
# So the administrator can configure the camera scan trigger options to allow hardware button, on-screen button, or both to launch the Knox Capture scanning.
# ReRanker similarity: 0.9994179010391235
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.047417 secs
# 2
# Question:  - What are the three steps outlined in the context to set up a default scanning profile?
# GroundTruth:  The three steps outlined to set up a default scanning profile are:
# 1. Edit the default profile
# 2. Change scan engine settings
# 3. Enable a flashlight butto
# Prediction:   Could not find answer in given contexts.
# ReRanker similarity: 7.638734678039327e-05
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:02.648546 secs
# 3
# Question:  What are the two steps described to start scanning with Knox Capture?
# GroundTruth:  Step 1: Review the scanning configuration. Step 2: Launch a device app
# Prediction:   Based on the given context, the two steps described to start scanning with Knox Capture are:
#
# 1. Download the app from Google Play.
#
# 2. Configure scan settings according to the IT admins: Get started tutorial.
# ReRanker similarity: 0.26417094469070435
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:04.775634 secs
# 4
# Question:  According to the instructions, how do you select an individual activity visually within an app?
# GroundTruth:  To select an individual activity visually within an app:
#
# 1. Tap the wand icon in the upper-right corner of the app activities list page.
# 2. Navigate within the app to locate an activity.
# 3. Drag the blue selector overlay around the screen as needed to view the app user interface.
#
# Note: Steps 2 and 3 can be repeated as needed to select multiple activities
# Prediction:   To select an individual activity visually within an app:
#
# 1. Within the app activities list page, tap the wand icon in the upper-right corner to launch the visual selection tool.
#
# 2. Navigate within the app to locate an activity. A blue selector overlay displays on each screen to name the activity associated with that screen. Drag this selector around the screen as needed to view the app user interface.
#
# 3. To select an activity, tap the radio button next to the activity name within the blue overlay. As activities are added, the counter in the overlay, next to the DONE button, increments with each selection.
#
# 4. When completed adding activities, tap DONE to navigate back to the app activities list page.
# ReRanker similarity: 0.9997867941856384
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:06.512533 secs
# 5
# Question:  What are the two ways to trigger a rule in Knox Capture?
# GroundTruth:  A rule in Knox Capture can be triggered by either the presence of a scanned string or by a scanned barcode that matches the required type
# Prediction:   Based on the given context, the two ways to trigger a rule in Knox Capture are:
#
# 1. By scanning a barcode that meets the rule's criteria, such as barcode type or string length.
#
# 2. When the cursor reaches a certain position in the scanned string, as specified in the rule's "String position" criteria.
# ReRanker similarity: 0.999548614025116
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.689568 secs
# 6
# Question:  What method moves the cursor to the beginning of the output data?
# GroundTruth:  None Move ahead to substring &mdash; Move ahead to substring &mdash; Moves the cursor forward until a specific string is found. None Move past substring &mdash; Moves the cursor past a specific string in the output data.
# None Move ahead to substring &mdash; Move ahead to substring &mdash; Moves the cursor forward until a specific string is found. Moves the cursor past a specific string in the output data
# Prediction:   Skip to start
# ReRanker similarity: 0.0002381472004344687
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.377425 secs
# 7
# Question:  - What is the default capture mode for scanning in the provided context?
# GroundTruth:  Sets the primary capture mode for scanning. Available options: Setting - Single scan (default).
#
# Could not find answer in given contexts
# Prediction:   The default capture mode for scanning is Single scan, which scans and parses one barcode at a time.
# ReRanker similarity: 0.9776778817176819
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.997504 secs
# 8
# Question:  How can a user exit the camera preview window?
# GroundTruth:  Users can exit the camera preview window at any time by tapping Done, regardless of the number of barcodes captured
# Prediction:   Based on the given context, a user can exit the camera preview window at any time by tapping Done, regardless of the number of barcodes captured.
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:04.794411 secs
# 9
# Question:  - What setting controls the border width of the box highlighting recognized barcodes?
# GroundTruth:  The setting that controls the border width of the box highlighting recognized barcodes is "Stroke width"
# Prediction:   The setting that controls the border width of the box highlighting recognized barcodes is:
#
# Stroke width , Set the border width of the box highlighting the recognized barcode in pixels. Set to 3 pixels by default.
# ReRanker similarity: 0.9997593760490417
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.171910 secs
# 10
# Question:  - What regular expression syntax should be used to validate barcodes for the scanner?
# GroundTruth:  - The provided regular expression syntax should be used to validate barcodes for the scanner.
# - For reference, details are available on crafting a regular expression.
# - No regular expression is set by default
# Prediction:   Based on the given context, the regular expression syntax that should be used to validate barcodes for the scanner is specified in the "Custom validation" setting under "Barcode filtering":
#
# Set a regular expression (regex) used to filter scanned barcodes. Only barcodes that match the provided regular expression will be accepted.
#
# So the IT admin can configure a regular expression that will be used to validate the barcodes scanned by the device. Only barcodes matching that expression will be accepted.
# ReRanker similarity: 0.9857668876647949
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.444521 secs
# 11
# Question:  How wide is the default rectangular viewfinder as a percentage of the screen width?
# GroundTruth:  90%
# Prediction:   The default rectangular viewfinder width is 90% of the screen width.
# ReRanker similarity: 0.8605338335037231
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.792259 secs
# 12
# Question:  How can you check if a hardware scanner is properly connected when testing a scanner configuration?
# GroundTruth:  By going to the Test apps screen and checking if your connected scanners are listed under the apps. If no scanner is connected, a blue test overlay displays the message "Data source: No device connected"
# Prediction:   Here are the steps to check if a hardware scanner is properly connected when testing a scanner configuration, based on the given context:
#
# When testing configurations in Admin mode, IT admins can view a list of created app activities under the profile. Any hardware scanner connected will be listed here.
#
# If testing in Test mode, the Test apps screen will show any connected scanners under the apps with Hardware scanner setting enabled.
#
# If no hardware scanner is connected, the blue test overlay will display "Data source: No device connected". This message indicates no scanner is identified.
# ReRanker similarity: 0.9998225569725037
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.015590 secs
# 13
# Question:  - What defines the barcode types to scan, how to interpret scanned data, and which business applications to pass the data to in Knox Capture?
# GroundTruth:  The Scanning profile
# Prediction:   Scanning profiles define the barcode types to scan, how to interpret scanned data, and which business applications to pass the data to in Knox Capture. A Scanning Profile is a configuration file that gets created or modified by an IT admin using the Knox Capture application. The profile defines how Knox Capture performs a barcode scan, and primarily consists of parameters like:
#
# 1. Apps and activities - define which applications that can launch the Knox Capture scanner.
#
# 2. Scanner engine settings - specifying the barcode technologies (QR, Code 128, UPCA, etc.), scanning methods (single barcode, multi barcode), and camera behavior (enable flash, allow camera zoom).
#
# 3. Keystroke output - defines how data is formatted after each successful scan.
# ReRanker similarity: 0.9996533393859863
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.585086 secs
# 14
# Question:  - How can IT admins customize barcode scanning behavior in Knox Capture?
# GroundTruth:  IT admins can change the profile's scan engine settings, data processing rules, and apps and activities behavior by creating custom scanning profiles in Knox Capture
# Prediction:   Based on the given context:
#
# IT admins can customize barcode scanning behavior in Knox Capture through scanning profiles. Scanning profiles allow admins to control which apps can trigger barcode scans, specify barcode types and scanning methods, define camera settings like flash and zoom, and configure how scanned data gets processed into keystrokes.
#
# The default profile works out-of-the-box for basic scanning needs, but custom profiles allow admins to fine-tune behavior for different apps and use cases. Admins can modify the default profile or create entirely new profiles.
# ReRanker similarity: 0.9970819354057312
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.760009 secs
# 15
# Question:  According to the context, what steps should be taken on a device running the app in Admin mode to import a configuration file?
# GroundTruth:  To import a configuration file on a device running the app in Admin mode, tap the more actions menu icon within the home page to the right of the Profiles list label, select Import, acknowledge the warning message by tapping Confirm, and find a configuration file to import
# Prediction:   Here are the steps to import a configuration file on a device running the app in Admin mode according to the given context:
#
# 1. Tap the more actions menu icon within the home page to the right of the Profiles list label.
# 2. Select Import.
# 3. After launching the import configuration menu, acknowledge the warning message by tapping Confirm.
# 4. Find the configuration file to import.
# 5. If the configuration is too large for one QR code, Knox Capture generates multiple QR codes in a PDF file. The end user must scan them all to complete the import process.
# ReRanker similarity: 0.9999276399612427
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.839085 secs
# 16
# Question:  - What are the two steps required before you can get a Knox Suite license for Knox Capture?
# GroundTruth:  To get a Knox Suite license for Knox Capture, you need to sign up for a Samsung Knox account and apply to gain access to Knox Suite
# Prediction:   Could not find answer in given contexts. The context does not mention the specific steps required to get a Knox Suite license for Knox Capture. It only states that after 100 free scans, a valid Knox Suite license is required to continue using Knox Capture.
# ReRanker similarity: 0.6221359968185425
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:03.944359 secs
# 17
# Question:  How do you enter a Knox Capture license key by scanning a QR code?
# GroundTruth:  To use this method, you will first need to have a valid Knox Suite license key converted into QR code format. Once you have a QR code generated, aim the camera at the QR code and tap Done to activate the license
# Prediction:   Here are the steps to enter a Knox Capture license key by scanning a QR code:
#
# To use this method, you'll first need to have a valid Knox Suite license key converted into QR code format. Once you have a QR code generated:
#
# 1. On the home screen, tap the options button, then select License.
#
# 2. Under Enter Knox Capture license, tap the QR code button. A scanning window appears.
#
# 3. Aim the camera at the QR code, then tap Done to activate the license.
# ReRanker similarity: 0.9999109506607056
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.926532 secs
# 18
# Question:  - What is the first step to set up intent output for Knox Capture?
# GroundTruth:  1. On the Knox Capture home screen, tap on the profile you want to set intent output for.
#
# Could not find answer in given contexts
# Prediction:   Based on the context provided, the first step to set up intent output for Knox Capture is:
#
# On the Knox Capture home screen, tap on the profile you want to set intent output for.
# ReRanker similarity: 0.9999210834503174
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.801309 secs
# 19
# Question:  - What visual indicators confirm that Knox Capture's system-wide test mode is active?
# GroundTruth:  - Look for a system pop-up notification indicating "Test mode is on"
# Prediction:   - A system pop-up notification indicates Test mode is on.
# - A blue test overlay displays in the open app's UI when test mode is active.
# ReRanker similarity: 0.998434841632843
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.382084 secs
# 20
# Question:  - What types of AR templates does the document describe?
# GroundTruth:  The document describes Search-and-find and View-and-update AR templates
# Prediction:   Based on the given context, the document describes two types of AR templates:
#
# - Search-and-find template: This template provides an overlay to help users locate and isolate a single barcode when there are multiple similar barcodes in view. It allows users to scan a reference barcode, then searches through other barcodes to find a matching one.
#
# - View-and-update template: This template provides an overlay to allow users to view product information and update a product database whenever a barcode is scanned. It connects to a database and displays product details when barcodes are scanned.
# ReRanker similarity: 0.99931800365448
# Langchain correctness: 1
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:06.623221 secs
# 21
# Question:  What HTTP request method would be used to retrieve a list of attributes for an item identified by a barcode using the /arcontentfields API?
# GroundTruth:  The HTTP request method for the /arcontentfields API is `GET`
# Prediction:   The /arcontentfields API uses the GET HTTP request method to retrieve a list of attributes for an item identified by a barcode.
# ReRanker similarity: 0.9990641474723816
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:04.705326 secs
# 22
# Question:  Briefly explain the purpose and functionality of the /arinfo API.
# GroundTruth:  The /arinfo API is used to retrieve a list of attribute values for a particular item identified by a barcode. It allows to update one or more values of attributes (fields) for an item identified by the barcode
# Prediction:   The /arinfo API is used for retrieving a list of attribute values for an item identified by a barcode. It uses the GET method and expects a JSON response containing the attribute values. The headers should include User-Agent and optionally Authorization if required. The response codes indicate success (200) or failure due to invalid credentials (401) or other reasons. An example response is given with 3 attribute values returned.
# ReRanker similarity: 0.998314380645752
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.148222 secs
# 23
# Question:  - How can you activate your Knox Capture license through your EMM?
# GroundTruth:  Through the application configuration dialog of the EMM console
# Prediction:   To activate a Knox Capture license through your EMM:
#
# 1. Open the application configuration dialog for Knox Capture in the EMM console. In a typical EMM console, the app configuration (or App Config) screen opens as a pop-up window or modal.
#
# 2. Paste the license key within the license field. Optionally include the scanning configuration as well. Refer to Deployment for more information.
#
# 3. Save the configuration.
# ReRanker similarity: 0.9861078858375549
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.862672 secs
# 24
# Question:  - What new Android version is now supported in Knox Capture v1.0.01?
# GroundTruth:  Android 11
# Prediction:   Android 11 support
# ReRanker similarity: 0.9966341853141785
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.282317 secs
# 25
# Question:  - What new features were added in Knox Capture v1.1?
# GroundTruth:  Knox Capture v1.1 now supports landscape mode, adds Galaxy XCover 5 to the list of supported devices, and adds customizable data formatting rules and a keyboard scan button input method
# Prediction:   Based on the context provided, some of the new features added in Knox Capture v1.1 were:
#
# - Landscape mode support - Knox Capture can now be used in landscape mode on all supported devices. Frontline workers can choose to scan barcodes or navigate the app UI in either portrait or landscape mode.
#
# - Added device model support - The Galaxy XCover 5 was added to the list of supported devices.
#
# - Advanced data formatting - Custom rules can be configured to trigger or block actions based on criteria. For example, sending only the last 4 digits of a barcode to a business app.
#
# - Keyboard scan button input method - A scan button was added to the device keyboard that launches the Knox Capture camera for scanning.
# ReRanker similarity: 0.9999275207519531
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.273651 secs
# 26
# Question:  What new scanning features are available in Knox Capture v1.1?
# GroundTruth:  Knox Capture v1.1 adds support for intent output, work profile on company owned devices (WP-C), and Nearby Share
# Prediction:   Could not find answer in given contexts. The context does not mention Knox Capture v1.1 or its new scanning features. It talks about v1.8 and v1.9 features.
# ReRanker similarity: 0.01164589636027813
# Langchain correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:03.871341 secs
# 27
# Question:  What new functionality allows IT admins to enable or disable the default profile in Knox Capture?
# GroundTruth:  With this release, IT admins can now enable or disable the default profile in Knox Capture
# Prediction:   The option to enable or disable the default profile allows IT admins to enable or disable the default profile.
#
# Specifically, the context says:
# "IT admins can now enable or disable the default profile. If you create profiles for several applications and don't want the default profile's behavior to override any configurations, set the default profile to Off. The default profile setting is available on the Knox Capture main page."
# ReRanker similarity: 0.9988983869552612
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.507033 secs
# 28
# Question:  How can users move the scan button around the screen in Knox Capture?
# GroundTruth:  Users can move the scan button around the screen in Knox Capture by default, and the scan button remains in the last known position until it's toggled off
# Prediction:   Based on the context provided, the answer is:
#
# By default, the scan button appears in the bottom right corner of the device's screen. Users can move it around the screen, and it remains in the last known position until it's toggled off.
# ReRanker similarity: 0.9982362985610962
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.859745 secs
# 29
# Question:  - What new feature in Knox Capture 1.7 allows displaying of overlays with custom information when barcodes are scanned?
# GroundTruth:  Knox Capture AR introduces a new AR feature that displays an overlay on the device screen whenever one or more barcodes are scanned. IT admins can create AR templates to customize the information that displays on the overlay, as well as the overlay behavior
# Prediction:   Knox Capture AR (Augmented Reality)
# ReRanker similarity: 0.9711878895759583
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:12.217815 secs
# 30
# Question:  What are two recommendations provided in the context information regarding Code 93 and Code 128 barcodes?
# GroundTruth:  Customers should use larger barcodes wheneve possible to increase the success rate of scans and move in closer to the barcodes when using multiscan
# Prediction:   Based on the context, two recommendations provided for Code 93 and Code 128 barcodes are:
#
# 1. Knox Capture may have difficulties scanning Code 93 and Code 128 barcodes that are too small. It is recommended to avoid using tiny barcodes whenever possible to increase the success rate of scans.
#
# 2. For Code 128 specifically, there are three different encoding schemes that can be mixed within a single barcode. It's recommended to check which encoding standards your barcode data follows.
# ReRanker similarity: 0.8169683218002319
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:05.006906 secs
# 31
# Question:  What new scanning option appears in Knox Capture v1.8 that allows users to continuously scan multiple barcodes without pressing the trigger between each scan?
# GroundTruth:  Continuous scanning
# Prediction:   Continuous scanning
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.016711 secs
# 32
# Question:  What are some of the major versions of Knox Capture that have been released according to the release notes?
# GroundTruth:  Knox Capture v1.9, v1.8, v1.7, v1.6, v1.5, v1.4, v1.3, v1.2, v1.1, and v1.0
# Prediction:   Based on the release notes in the given context, some of the major versions of Knox Capture that have been released are:
#
# Knox Capture v1.9 - Released October 16, 2023. New features include AR demo mode, new flashlight options, and QR license activation.
#
# Knox Capture v1.8 - Released June 30, 2023
#
# Knox Capture v1.7 - Released March 31, 2023
#
# Knox Capture v1.6 - Released November 24, 2022
#
# Knox Capture v1.5
#
# Knox Capture v1.4
#
# Knox Capture v1.3
#
# Knox Capture v1.2
#
# Knox Capture v1.1 - New features include landscape mode support, added device model support, advanced data formatting, and keyboard scan button.
#
# Knox Capture v1.0 - This was the first release of Knox Capture.
# ReRanker similarity: 0.9991119503974915
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.532906 secs
# 33
# Question:  - Why is Knox Capture called a wedge, according to the context?
# GroundTruth:  Knox Capture is called a wedge because it acts as middleware that reads barcode data captured by the XCover Pro device, translates it into a string, formats the string, and then sends it to a third-party business app that understands the resulting data
# Prediction:   Based on the context, Knox Capture is called a wedge because:
#
# Knox Capture acts as middleware that reads barcode data captured by the XCover Pro device, translates it into a string, formats the string, and then sends it to a third-party business app that understands the resulting data. Knox Capture takes care of integrating with your business app, so that you don't have to build barcode scanning logic into your business app using a software development kit (SDK).
#
# In the same way, a wedge barcode scanner is a physical device that attaches to a keyboard or a computer. It reads barcode data and translates it to a string that is then input into the system, as if a user had manually typed the string using the keyboard.
#
# So Knox Capture wedges between the mobile device's on-screen keyboard and the business app, translating barcode data into strings that the app can understand, just like a wedge scanner translates barcode data into keyboard strings that a computer understands.
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:06.056108 secs
# 34
# Question:  What steps should be taken in the EMM console to program the XCover key to trigger camera scanning?
# GroundTruth:  On your EMM console, open Knox Service Plugin policies. Under Device Key Mapping (Premium), configure the mapping. Set Enable Key Mapping Controls to True
# Prediction:   Set the XCover key to trigger camera scanning in the EMM console:
#
# 1. On your EMM console, open the Knox Service Plugin policies. On the Knox Manage console, add or modify an Android Enterprise profile. Then, in the Samsung Knox policies, click Knox Service Plugin.
#
# 2. Under Device-wide policies, set Enable device policy controls to True.
#
# 3. Under Device Key Mapping (Premium), configure the mapping:
#
# - Set Enable Key Mapping Controls to True.
#
# - For Press action, select com.samsung.knox.kcm/com.samsung.knox.capture.ACTION_LAUNCH_SCANNER
#
# 4. Deploy the policy to your Verizon XCover Pro devices.
# ReRanker similarity: 0.9998651742935181
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.305342 secs
# 35
# Question:  How can a user turn on the flashlight when using the Knox Capture scanner if the Flashlight button is not enabled in the device's Knox Capture profile?
# GroundTruth:  If the Flashlight button is not enabled in the device's Knox Capture profile, the device user will not be able to turn on the flashlight when using the Knox Capture scanner. They are required to ensure the profile has the Flashlight button feature enabled in the scan engine settings before attempting to turn on the flashlight
# Prediction:   Step 1: Go to Knox Capture settings
# Step 2: Tap on the profile name to edit the profile
# Step 3: Scroll down to Camera Settings
# Step 4: Enable the Flashlight button by sliding it to the right
# Step 5: Save changes to the profile
#
# This will add a flashlight button to the scanner UI that the user can tap to turn on the flashlight when scanning in dark conditions.
# ReRanker similarity: 0.9990890026092529
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.790830 secs
# 36
# Question:  - How can you resolve the issue of not being able to output scanned barcode data to HTML fields in Chromium-based browsers on Android 11 devices using the Advanced data formatting method?
# GroundTruth:  To resolve this issue, send a Pause command before sending the barcode data
# Prediction:   Here are the steps to resolve the issue using the Advanced data formatting method:
#
# 1. Refer to the procedure for Advanced data formatting and follow steps 1 - 6. After you tap Add Actions, a list of options opens.
#
# 2. Select Send Pause and tap Add.
#
# 3. Tap Add Actions again, then select Send remaining characters and tap Add.
#
# 4. Verify that the two actions, Send Pause and Send remaining characters, are on the rule screen.
#
# 5. Close the Knox Capture app and perform a test scan in Chrome or Samsung Internet.
# ReRanker similarity: 0.6969327330589294
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.280590 secs
# 37
# Question:  - What barcode encoding standard does the example use that allows mixing of encoding schemes within a single barcode?
# GroundTruth:  Code 128
# Prediction:   Code 128
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.136851 secs
# 38
# Question:  How do you select the reseller that uploaded the new devices when generating a Knox Suite license?
# GroundTruth:  1. Contact the reseller who uploaded the new devices.
# 2. Select the reseller that uploaded the new devices
# Prediction:   Go to the Enterprise Edition dashboard. The reseller's name and ID appears in a table along with the number of devices uploaded. Select the reseller that uploaded the new devices.
# ReRanker similarity: 0.9601020812988281
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.267646 secs
# 39
# Question:  - How can you view the devices and licenses on the Enterprise Edition dashboard?
# GroundTruth:  To view the devices and licenses on the Enterprise Edition dashboard, go to the DEVICES tab
# Prediction:   Based on the context, to view the devices and licenses on the Enterprise Edition dashboard:
#
# Go to the DEVICES tab on the Enterprise Edition dashboard. If your device reseller uploaded devices for you, the reseller's name and ID appears in a table along with the number of devices uploaded. The table columns display information about your devices including:
# - RESELLER (ID) - The name and ID of the device reseller that uploaded EE devices.
# - DEVICES LAST UPLOADED - The date the reseller last uploaded devices.
# - DEVICES UPLOADED - The total number of devices the reseller uploaded.
# - LICENSES GENERATED - The number of devices with a Knox Suite license.
# - DEVICES REMAINING - The number of devices without a Knox Suite license.
# ReRanker similarity: 0.9995787739753723
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:06.577363 secs
# 40
# Question:  - What is the total number of devices the reseller has uploaded for you?
# GroundTruth:  The total number of devices that the reseller has uploaded for you is DEVICES UPLOADED
# Prediction:   DEVICES UPLOADED - The total number of devices that the reseller has uploaded for you.
# ReRanker similarity: 0.9992129802703857
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:02.727727 secs
# 41
# Question:  - How do you confirm your tenant ID when registering for Knox Suite if your organization is not already signed up for Knox Services?
# GroundTruth:  If your organization is not signed up for Knox Services, you need to confirm that your organization's domain automatically filled the Tenant ID field during registration for Knox Suite
# Prediction:   Confirm that your organization's domain automatically filled the Tenant ID field and click Complete Registration.
# ReRanker similarity: 0.8905097246170044
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.545686 secs
# 42
# Question:  - How can you confirm that the Knox Suite license type was automatically generated and registered for you?
# GroundTruth:  In the Knox Admin Portal, you can view all the licenses registered to you, and the Knox Suite license type will be listed among them
# Prediction:   Based on the given context, to confirm that the Knox Suite license type was automatically generated and registered for you:
#
# Go to the Licenses page in the Knox Admin Portal. The consolidated licenses page will open. Confirm that the Knox Suite trial license was automatically generated and registered for you.
#
# You can also navigate to the consolidated licenses page through the individual Licenses page in the dashboard of each Knox service.
#
# On the Knox Manage console, go to Setting > License. Confirm that the license key was automatically generated and registered for you. It must have the Knox Suite license type.
# ReRanker similarity: 0.9597218632698059
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:04.203735 secs
# 43
# Question:  How does Samsung ensure responsible data collection through its cloud solutions like Knox?
# GroundTruth:  Through SOC2 certification and a commitment to the restricted use of data
# Prediction:   Based on the context provided, Samsung ensures responsible data collection through its cloud solutions like Knox in a few key ways:
#
# - Data collection is restricted to only what is necessary.
# - Samsung cloud solutions are SOC2-certified, which provides assurance of smooth operation, security, and reliability.
# - Samsung meets all data storage and handling requirements stipulated by the GDPR.
# - Knox Suite services like Knox Manage and Knox Asset Intelligence only collect location data to help locate and analyze movement of managed devices for business purposes.
# ReRanker similarity: 0.3958115577697754
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.695011 secs
# 44
# Question:  - What functionality does Knox Capture provide in its default Admin mode?
# GroundTruth:  Knox Capture's default Admin mode allows IT administrators to utilize the full functionality of the app to create scanning profiles, test them, and export the profile settings
# Prediction:   Based on the given context, in its default Admin mode, Knox Capture allows the device user - typically an enterprise IT admin - to:
#
# 1. Create scanning profiles that define which apps can launch the barcode scanner, which barcode types can be scanned (QR, Code 128, EAN8, etc.), and how scanned data is formatted (append Tab or Enter key, insert special characters before or after data, etc.).
#
# 2. Test scanning profiles to ensure that appropriate business apps can launch the scanner and receive data back as keystrokes.
#
# 3. Export profile settings as a configuration file, which can then be used by EMM/UEM administrators to deploy Knox Capture as a managed app to end-user devices.
# ReRanker similarity: 0.9995751976966858
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.825791 secs
# 45
# Question:  - How can you customize apps and activities in scanning profiles in Knox Capture?
# GroundTruth:  You can customize apps and activities in scanning profiles in Knox Capture by adjusting the scan engine settings, including barcode types, scan modes, and viewfinder size. Additionally, you can test the profile's applications, barcode types, and keystroke output rules using the test mode, and export the configuration for deployment to an EMM/UEM
# Prediction:   Based on the context provided, here are the key points on how to customize apps and activities in scanning profiles in Knox Capture:
#
# - Each Knox Capture profile supports configuring a set of apps that the profile's scanner and keystroke output settings will apply to.
#
# - IT admins can associate individual Android activities with different Knox Capture profiles to have more refined control over each scanning context within an app. An activity refers to a specific user interaction within an app's UI, like a form or search box.
#
# - Options for configuring apps/activities in a profile include:
#
# - Set up one profile for all apps, unique profiles per app, or group apps/activities into profiles.
#
# - A single profile can have multiple apps or activities, but an activity can only belong to one profile.
#
# - Creating custom profiles involves selecting which apps and activities can trigger barcode scanning. Apps not specified will follow default behavior.
#
# - Test mode allows testing a profile's apps, barcode types and rules before deployment.
# ReRanker similarity: 0.9972755312919617
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:17.344952 secs
# 46
# Question:  - What new features were added in the Knox Capture v1.9 release?
# GroundTruth:  Knox Capture v1.9 - October 16, 2023
# Knox Capture v1.9 added an AR demo page to support the new AR demo mode feature. Knox Capture v1.9 also added flashlight options and updated the Scan engine settings page
# Prediction:   Knox Capture v1.9 introduces the following new features:
#
# - Support for AR demo mode You can now test the Knox Capture AR feature without having to set up a real server or go through any profile creation or setup process.
#
# - On-screen suggestions for increasing scanning success rate To help increase the success rate of barcode scans, Knox Capture now provides suggestions on-screen to tell end-users when their device is either too far from a barcode, or at an angle in which the barcode cannot be easily read.
#
# - Ability to turn on flashlight by default You can now choose from three different flashlight options (Off/On/Automatic) in the scan engine settings, making it easier for device users to work in all lighting conditions. Knox Capture: Scandit Edition only supports On and Off as flashlight options.
# ReRanker similarity: 0.999381422996521
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:05.912653 secs
# 47
# Question:  - What should you do after installing and launching Knox Capture for the first time?
# GroundTruth:  After installing and launching Knox Capture for the first time, you are presented with links to numerous Terms, Conditions, and privacy policies. To proceed, you must review these documents and tap "Agree.
# Prediction:   Based on the context, after installing and launching Knox Capture for the first time, it presents you with links to all of the applicable Terms, Conditions, and privacy policies. You should review these, and if you agree to all of the documents, tap Agree.
# ReRanker similarity: 0.9999217987060547
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.536303 secs
# 48
# Question:  What setting allows you to add or remove barcode types when creating a Knox Capture profile?
# GroundTruth:  the Camera setting
# Prediction:   Add or remove a barcode type of your choice. For best performance, only select the barcode types necessary when creating the profile.
# ReRanker similarity: 7.839788304409012e-05
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:02.665813 secs
# 49
# Question:  - What steps should you take to test barcode scanning using Samsung Internet and Knox Capture on a rugged device like an XCover Pro?
# GroundTruth:  To test barcode scanning using Samsung Internet and Knox Capture on a rugged device like an XCover Pro, follow these steps:
#
# 1. Select the Samsung Internet app from the Test apps list.
# 2. Tap the Scan trigger hardware key.
# 3. Aim the camera at a barcode to scan. The barcode will automatically scan once in focus
# Prediction:   Here are the steps to test barcode scanning using Samsung Internet and Knox Capture on a rugged device like an XCover Pro:
#
# 1. On the Knox Capture home screen, tap the options icon and select Test apps. This will start test mode.
#
# 2. Select the Samsung Internet app from the Test apps list, then tap Open.
#
# 3. Tap the browser's search field to bring up the on-screen keyboard.
#
# 4. Tap the Knox Capture icon near the top-left of the keyboard to trigger a scan.
#
# 5. Optionally, if using an XCover Pro, trigger a scan with the Scan trigger hardware key instead of tapping the icon.
#
# 6. Test the flashlight by tapping the button near the top-left corner of the screen.
#
# 7. Aim the camera at a barcode to scan it. The barcode will automatically scan once in focus.
#
# 8. Review the scanned data in the test overlay to see the raw and processed values.
#
# 9. Close the Knox Capture app when finished testing.
# ReRanker similarity: 0.999927282333374
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:09.799640 secs
# 50
# Question:  What are the two formats of scanned barcode data that can be inspected in test mode without any keystroke output rules applied?
# GroundTruth:  The scanned barcode data can be viewed in either test mode notation or hexadecimal format without any keystroke output rules applied
# Prediction:   Scanned data - The scanned barcode data in test mode notation without any keystroke output rules applied.
#
# Scanned raw - The scanned barcode data in hexadecimal format without any keystroke output rules applied.
# ReRanker similarity: 0.999573290348053
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:03.638353 secs
# 51
# Question:  What are the steps to export a scanning configuration from Knox Capture?
# GroundTruth:  To export a scanning configuration from Knox Capture, follow these steps:
#
# 1. On the home screen, tap the Share button in the lower-right corner.
# 2. Select Email and select your preferred email app. The configuration file will be attached automatically.
# 3. After sending the email with the configuration file attached, re-launch Knox Capture. A notification confirming the email submission will be displayed, followed by the date and time
# Prediction:   Here are the steps to export a scanning configuration from Knox Capture:
#
# 1. On the home screen, tap the Share button in the lower-right corner.
#
# 2. In the pop-up, select your preferred export method - Email, Save to device, Nearby Share, or QR code.
#
# 3. If selecting Email, select your preferred email app. The configuration file is automatically attached.
#
# 4. After sending the email with the configuration file attached, re-launch Knox Capture. You should see a notification confirming the email submission followed by the date and time.
#
# 5. If selecting Save to device, select a location to save the .txt file to on your device's internal storage.
#
# 6. If selecting Nearby Share, select a nearby device to send the configuration file to.
#
# 7. If selecting QR code, point the camera at the generated QR code to save the configuration file.
# ReRanker similarity: 0.9999276399612427
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:11.793905 secs
# 52
# Question:  How could an IT admin configure the Knox Capture interface to emulate a user tapping Enter on their keyboard after scanning a barcode?
# GroundTruth:  An IT admin could create a keystroke output rule to append an Enter key event after each scan. This would trigger the Knox Capture interface to emulate a user tapping Enter on their keyboard, which would then trigger a specific action or search result based on the scanned barcode
# Prediction:   The IT admin could configure the Knox Capture interface to emulate a user tapping Enter on their keyboard after scanning a barcode by:
#
# - Expanding the Keystroke output options, then tapping Send Enter character as.
#
# - In the pop-up, selecting Key event. This emulates a user hitting the Enter key on their keyboard after they type characters into a field.
#
# - Enabling the Append Enter character option under Basic data formatting by moving the slider to the right. This will append an Enter keystroke to the scanned data.
# ReRanker similarity: 0.9976880550384521
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.387920 secs
# 53
# Question:  - What method can a user employ to select multiple barcodes when using the camera scanning UI in Multi scan mode?
# GroundTruth:  The user can select multiple barcodes using the Batch setting in the camera scanning UI in Multi scan mode
# Prediction:   Batch mode lets the user scan multiple barcodes in a single camera frame using the scan button.
# ReRanker similarity: 0.9978819489479065
# Langchain correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:02.771456 secs
# 54
# Question:  According to the context, what are the two ways to remove a Bluetooth scanner that has been paired with your device?
# GroundTruth:  To remove a Bluetooth scanner, tap the gear icon next to the scanner and select Remove as a scanner. If you don't want to see the scan confirmation pop-up from Knox Capture again, select Unpair instead
# Prediction:   Based on the given context, there are two ways to remove a Bluetooth scanner that has been paired with your device:
#
# 1. Tap the gear icon next to the scanner and select Remove as a scanner.
#
# 2. Tap the gear icon next to the scanner and select Unpair instead. Unpairing will also remove the scanner.
# ReRanker similarity: 0.9998108744621277
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.277896 secs
# 55
# Question:  - How does the user import a configuration file in Knox Capture?
# GroundTruth:  To import a configuration file in Knox Capture, the user must:
# 1. Launch the import configuration menu
# 2. Acknowledge the warning message by tapping Confirm
# 3. Find the configuration file to import
# Knox Capture will import the configuration and display a success message
# Prediction:   Based on the context, to import a configuration file in Knox Capture, the user should:
#
# 1. Tap the more actions menu icon within the home page to the right of the Profiles list label. Then select Import.
#
# 2. After launching the import configuration menu, acknowledge the warning message by tapping Confirm.
#
# 3. Find the configuration file to import.
#
# Knox Capture will import the configuration and display a success message.
# ReRanker similarity: 0.9999268054962158
# Langchain correctness: 1
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:03.885119 secs
