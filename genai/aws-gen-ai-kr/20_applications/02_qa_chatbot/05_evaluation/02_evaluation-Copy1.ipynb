# %% [markdown]
# # Evaluation
# - For retriever
# - For generator

# %% [markdown]
# ## Setting
#  - Auto Reload
#  - path for utils

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
module_path = "../../.."
sys.path.append(os.path.abspath(module_path))

# %% [markdown]
# ## 1. Bedrock Client 생성

# %%
import json
import boto3
from pprint import pprint
from termcolor import colored
from utils import bedrock, print_ww
from utils.bedrock import bedrock_info

# %% [markdown]
# ### ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----
# - os.environ["AWS_DEFAULT_REGION"] = "<REGION_NAME>"  # E.g. "us-east-1"
# - os.environ["AWS_PROFILE"] = "<YOUR_PROFILE>"
# - os.environ["BEDROCK_ASSUME_ROLE"] = "<YOUR_ROLE_ARN>"  # E.g. "arn:aws:..."
# - os.environ["BEDROCK_ENDPOINT_URL"] = "<YOUR_ENDPOINT_URL>"  # E.g. "https://..."

# %%
boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    endpoint_url=os.environ.get("BEDROCK_ENDPOINT_URL", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
)

aws_region = os.environ.get("AWS_DEFAULT_REGION", None)
print (colored("\n== FM lists ==", "green"))
pprint (bedrock_info.get_list_fm_models())
# Out:
# Create new client
#   Using region: None
#   Using profile: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
#
# == FM lists ==
# {'Claude-Instant-V1': 'anthropic.claude-instant-v1',
#  'Claude-V1': 'anthropic.claude-v1',
#  'Claude-V2': 'anthropic.claude-v2',
#  'Claude-V2-1': 'anthropic.claude-v2:1',
#  'Cohere-Embeddings-En': 'cohere.embed-english-v3',
#  'Cohere-Embeddings-Multilingual': 'cohere.embed-multilingual-v3',
#  'Command': 'cohere.command-text-v14',
#  'Command-Light': 'cohere.command-light-text-v14',
#  'Jurassic-2-Mid': 'ai21.j2-mid-v1',
#  'Jurassic-2-Ultra': 'ai21.j2-ultra-v1',
#  'Llama2-13b-Chat': 'meta.llama2-13b-chat-v1',
#  'Titan-Embeddings-G1': 'amazon.titan-embed-text-v1',
#  'Titan-Text-G1': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Light': 'amazon.titan-text-lite-v1'}

# %% [markdown]
# ## 2. Titan Embedding 및 LLM 인 Claude-v2 모델 로딩

# %% [markdown]
# ### LLM 로딩 (Claude-v2)

# %%
from langchain.llms.bedrock import Bedrock
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm_text = Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-V2-1"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

llm_text_light= Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-Instant-V1"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %% [markdown]
# ### Embedding 모델 선택

# %%
from utils.rag import KoSimCSERobertaContentHandler, SagemakerEndpointEmbeddingsJumpStart

# %%
def get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name=None):

    if is_bedrock_embeddings:
        # We will be using the Titan Embeddings Model to generate our Embeddings.
        from langchain.embeddings import BedrockEmbeddings
        llm_emb = BedrockEmbeddings(
            client=boto3_bedrock,
            model_id=bedrock_info.get_model_id(
                model_name="Titan-Embeddings-G1"
                #model_name="Cohere-Embeddings-En"
            )
        )
        print("Bedrock Embeddings Model Loaded")

    elif is_KoSimCSERobert:
        LLMEmbHandler = KoSimCSERobertaContentHandler()
        endpoint_name_emb = endpont_name
        llm_emb = SagemakerEndpointEmbeddingsJumpStart(
            endpoint_name=endpoint_name_emb,
            region_name=aws_region,
            content_handler=LLMEmbHandler,
        )
        print("KoSimCSERobert Embeddings Model Loaded")
    else:
        llm_emb = None
        print("No Embedding Model Selected")

    return llm_emb

# %% [markdown]
# #### [중요] is_KoSimCSERobert == True 일시에 endpoint_name 을 꼭 넣어 주세요.

# %%
is_bedrock_embeddings = True
is_KoSimCSERobert = False
aws_region = os.environ.get("AWS_DEFAULT_REGION", None)

##############################
# Parameters for is_KoSimCSERobert
##############################
if is_KoSimCSERobert: endpont_name = "<endpoint-name>"
else: endpont_name = None
##############################

llm_emb = get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name)
# Out:
# Bedrock Embeddings Model Loaded

# %% [markdown]
# ## 3. Depoly ReRanker model (if needed)

# %%
import json
import sagemaker
from sagemaker.huggingface import HuggingFaceModel
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
depoly = False

# %%
if depoly:

    try:
        role = sagemaker.get_execution_role()
    except ValueError:
        iam = boto3.client('iam')
        role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

    # Hub Model configuration. https://huggingface.co/models
    hub = {
        'HF_MODEL_ID':'BAAI/bge-reranker-large',
        'HF_TASK':'text-classification'
    }

    # create Hugging Face Model Class
    huggingface_model = HuggingFaceModel(
        transformers_version='4.26.0',
        pytorch_version='1.13.1',
        py_version='py39',
        env=hub,
        role=role, 
    )

    # deploy model to SageMaker Inference
    predictor = huggingface_model.deploy(
        initial_instance_count=1, # number of instances
        instance_type='ml.g5.xlarge' # instance type
    )

    print(f'Accept: {predictor.accept}')
    print(f'ContentType: {predictor.content_type}')
    print(f'Endpoint: {predictor.endpoint}')

# %% [markdown]
# ### Reranker

# %%
#endpoint_name = "huggingface-pytorch-inference-2023-11-15-04-37-45-120" # ml.m5.2xlarge
endpoint_name = "huggingface-pytorch-inference-2023-11-15-07-53-21-605" # ml.g5.xlarge

# %%
runtime_client = boto3.Session().client('sagemaker-runtime')
print (f'runtime_client: {runtime_client}')
# Out:
# runtime_client: <botocore.client.SageMakerRuntime object at 0x7fe56177aa40>

# %% [markdown]
# ## 4. LangChainmOpenSearch VectorStore 정의
# ### 선수 조건
# - 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 OpenSearch Index 가 생성이 되어 있어야 합니다.
# #### [중요] 아래에 aws parameter store 에 아래 인증정보가 먼저 입력되어 있어야 합니다.
# - 01_preprocess_docs/01_parameter_store_example.ipynb 참고

# %%
from utils.proc_docs import get_parameter

# %%
ssm = boto3.client("ssm", "us-east-1")

opensearch_domain_endpoint = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_domain_endpoint',
)

opensearch_user_id = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_userid',
)

opensearch_user_password = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_password',
)

http_auth = (opensearch_user_id, opensearch_user_password) # Master username, Master password

# %% [markdown]
# ### Index 이름 셋팅
# - 이전 노트북 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 생성된 OpenSearch Index name 입력

# %%
#index_name = "v13-genai-poc-knox-titan-eval-sample-0.05-1024c-256o"
index_name = "v16-genai-poc-knox-eval-parent-doc-retriever"

# %% [markdown]
# ### OpenSearch Client 생성

# %%
from utils.opensearch import opensearch_utils

# %%
os_client = opensearch_utils.create_aws_opensearch_client(
    aws_region,
    opensearch_domain_endpoint,
    http_auth
)

# %% [markdown]
# ## 5. Retriever 정의

# %%
from utils.rag import OpenSearchHybridSearchRetriever

# %%
opensearch_hybrid_retriever = OpenSearchHybridSearchRetriever(
    os_client=os_client,
    index_name=index_name,
    llm_text=llm_text, # used in rag_fusion, hyde and reranker(num_tokens)
    llm_emb=llm_emb,

    # option for lexical
    minimum_should_match=0,
    filter=[],

    # option for rank fusion
    fusion_algorithm="RRF", # ["RRF", "simple_weighted"], rank fusion 방식 정의
    ensemble_weights=[.5, .5], # [for lexical, for semantic], Lexical, Semantic search 결과에 대한 최종 반영 비율 정의
    reranker=True, # enable reranker with reranker model
    reranker_endpoint_name=endpoint_name, # endpoint name for reranking model
    #rag_fusion=False, # enable rag_fusion
    #query_augmentation_size=3, # query_augmentation_size in rag_fusion

    # option for async search
    async_mode=True,

    # option for output
    k=5, # 최종 Document 수 정의
    verbose=False,
)

# %%
search_hybrid_result = opensearch_hybrid_retriever.get_relevant_documents("knox")
search_hybrid_result
# Out:
# [Document(page_content='What is Knox Suite?. Knox Suite is a bundled offering designed to help enterprise IT admins better manage your fleet of devices. It includes individual services such as Knox Platform for Enterprise, Knox Mobile Enrollment, Knox Manage, Knox E-FOTA, and Knox Asset Intelligence. Key features of Knox Suite include: Secure - Ensure your business data is protected with managed security features at your control. Deploy - Enroll corporate devices to EMM automatically and securely, right out of the box. Manage - Enable comprehensive management over corporate devices and OS versions. Analyze - Strengthen in-depth device analytics for mobile productivity and asset management.', metadata={'source': 'all_processed_data.json', 'seq_num': 74, 'title': ' What is Knox Suite?', 'url': 'https://docs.samsungknox.com/admin/knox-suite/faq/#what-is-knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'parent', 'parent_id': None, 'id': '5c911c77-600b-404f-a343-8a50c44aff9d'}),
#  Document(page_content='Knox Suite. Knox Suite is a bundled offering of Knox solutions for enterprise mobility designed to address organizations\' needs related to security and management throughout the entire device lifecycle. Learn more about Knox Suite #Audience This document is intended for IT Admins. Understand what\'s included in Knox Suite and how you can use it to manage, secure, and maintain enterprise devices. Learn where to find information on how to perform various tasks with Knox"Suite services. About Knox Suite Knox Suite is a bundled offering that includes the following Knox products: Knox Platform for Enterprise - A Knox solution that provides military-grade security to Samsung Android phones, tablets, and Tizen watches for business. Knox Mobile Enrollment - A Knox solution that allows you to enroll thousands of Samsung devices in your EMM at once. When used with a Knox Suite license, Knox Mobile Enrollment provides advanced profiles that offer IT admins additional features such as higher control over locking devices', metadata={'source': 'all_processed_data.json', 'seq_num': 65, 'title': 'Knox Suite', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'child', 'parent_id': '31d8f5b8-2ced-4a02-ba10-d8fac3614439', 'id': 'ce4fc71c-7f39-4390-8079-113a7c26a18d'}),
#  Document(page_content='. With Knox E-FOTA, you create a campaign, specify the campaign period, assign devices to that campaign, and select the firmware update to be pushed to those devices during the campaign period. Knox Capture - An Android solution that lets users transform their Samsung Galaxy smartphones and tablets into powerful barcode scanners that can read, process, and output barcode information to other applications, all without requiring additional hardware or writing a single line of code. Knox Authentication Manager - A managed Android app for shared Samsung devices that provides multiuser facial biometrics and sign-in automation for increased frontline worker productivity and safety. With Knox Suite, a single license key allows you to use all included Knox products on your devices. This means that you can use the same Knox Suite license key in multiple Knox service admin portals. Benefits of Knox Suite 1. All-in-one Knox B2B package - An end-to-end solution that covers every step of your enterprise mobility journey 2', metadata={'source': 'all_processed_data.json', 'seq_num': 65, 'title': 'Knox Suite', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'child', 'parent_id': '31d8f5b8-2ced-4a02-ba10-d8fac3614439', 'id': 'e81f1b75-c144-4b30-914d-83cd4d28664e'}),
#  Document(page_content='Knox Suite. Knox Suite is a bundled offering of Knox solutions for enterprise mobility designed to address organizations\' needs related to security and management throughout the entire device lifecycle. Learn more about Knox Suite #Audience This document is intended for IT Admins. Understand what\'s included in Knox Suite and how you can use it to manage, secure, and maintain enterprise devices. Learn where to find information on how to perform various tasks with Knox"Suite services. About Knox Suite Knox Suite is a bundled offering that includes the following Knox products: Knox Platform for Enterprise - A Knox solution that provides military-grade security to Samsung Android phones, tablets, and Tizen watches for business. Knox Mobile Enrollment - A Knox solution that allows you to enroll thousands of Samsung devices in your EMM at once. When used with a Knox Suite license, Knox Mobile Enrollment provides advanced profiles that offer IT admins additional features such as higher control over locking devices. Knox Manage - A Knox solution that allows you to remotely manage your fleet of mobile devices. With this EMM, you create various policies to control how users can use their devices. Knox Asset Intelligence - A data analytics solution that offers operational visibility and actionable insights to improve the management, productivity, and lifecycle of mobile devices. This solution offers real-time monitoring and management of app performance, battery usage, network connectivity, and asset location. Knox E-FOTA - A Knox solution that allows you to remotely deploy OS and security updates to your devices without requiring user interaction. With Knox E-FOTA, you create a campaign, specify the campaign period, assign devices to that campaign, and select the firmware update to be pushed to those devices during the campaign period. Knox Capture - An Android solution that lets users transform their Samsung Galaxy smartphones and tablets into powerful barcode scanners that can read, process, and output barcode information to other applications, all without requiring additional hardware or writing a single line of code. Knox Authentication Manager - A managed Android app for shared Samsung devices that provides multiuser facial biometrics and sign-in automation for increased frontline worker productivity and safety. With Knox Suite, a single license key allows you to use all included Knox products on your devices. This means that you can use the same Knox Suite license key in multiple Knox service admin portals. Benefits of Knox Suite 1. All-in-one Knox B2B package - An end-to-end solution that covers every step of your enterprise mobility journey 2. Simplified license management - You only need one license key to use all included products. 3. Streamlined onboarding process - Register once and gain access to all included Knox products. 4. Seamless IT admin user experience - IT admin can easily access bundled Knox consoles through single sign-on. To get started, click here.', metadata={'source': 'all_processed_data.json', 'seq_num': 65, 'title': 'Knox Suite', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'parent', 'parent_id': None, 'id': '31d8f5b8-2ced-4a02-ba10-d8fac3614439'}),
#  Document(page_content='Learn more about Knox Suite. This section describes where you can find instructions on how to perform tasks using the different products included in Knox Suite. General documentation for the Knox Suite services Knox Service , See - , - Knox Manage , Knox Manage Admin Guide Knox Platform for Enterprise , Knox Platform for Enterprise Admin Guide Knox Mobile Enrollment , Knox Mobile Enrollment Admin Guide Knox E-FOTA , Knox E-FOTA Admin Guide Knox Asset Intelligence , Knox Asset Intelligence Admin Guide Knox Capture , Knox Capture Admin Guide Knox Authentication Manager , Knox Authentication Manager Admin Guide Knox Suite operations For information on See Knox service How to set up Knox Manage with Knox Suite Workflow:"Set up Knox Manage with a Knox Suite license Knox Manage How to check your Knox Suite license usage View and modify a license Note Alternatively, you can sign in to your SamsungKnox.com dashboard and click Licenses to view all licenses you have for all your Knox services', metadata={'source': 'all_processed_data.json', 'seq_num': 64, 'title': 'Learn more about Knox Suite', 'url': 'https://docs.samsungknox.com/admin/knox-suite/learn-more-about-knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'child', 'parent_id': '5f426c6c-0882-4b3e-aeae-a1792b104b5b', 'id': '2ad1de59-827a-4dad-9093-3a807ed2c1e2'})]

# %% [markdown]
# ## 6. RAG chain 정의

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# %% [markdown]
# ### Prompting
# - [TIP] Prompt의 instruction의 경우 한글보다 영어로 했을 때 더 좋은 결과를 얻을 수 있습니다.

# %%
from utils.rag import prompt_repo

# %%
PROMPT = prompt_repo.get_qa(prompt_type="answer_only") # ["answer_only", "answer_with_ref"]

# %% [markdown]
# ### Update Search Params (Optional)

# %%
opensearch_hybrid_retriever.update_search_params(
    k=5,
    minimum_should_match=0,
    filter=[],
    reranker=True,
    reranker_endpoint_name=endpoint_name,
    rag_fusion=False, # enable rag_fusion
    query_augmentation_size=3, # query_augmentation_size in rag_fusion
    hyde=True, # enable hyde
    hyde_query=["web_search"], # query type in hyde 
    parent_document=True,
    llm_text=llm_text, # used in rag_fusion, hyde and reranker(num_tokens)
    verbose=False
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm_text,
    chain_type="stuff",
    retriever=opensearch_hybrid_retriever,
    return_source_documents=True,
    chain_type_kwargs={
        "prompt": PROMPT,
        "verbose": False,
    },
    verbose=False
)

# %%
query = "How many characters are removed when the start position is 1 and the number of characters to remove is also 1?"
qa_chain(query)
# Out:
# {'query': 'How many characters are removed when the start position is 1 and the number of characters to remove is also 1?',
#  'result': ' <answer>\nWhen the start position is 1 and the number of characters to remove is 1, one character is removed. The context states: "Remove characters When sending data, removes a specific number of characters from the given positions. You must provide the start position and the number of characters to remove." So if the start position is 1 and the number of characters to remove is also 1, then 1 character will be removed.\n</answer>',
#  'source_documents': [Document(page_content=". On the Knox Capture home screen, tap on the profile you want to create a rule for. 2. Under Keystroke output and data formatting, tap Advanced data formatting. 3. In the top right corner of the screen, tap +. 4. Enter a name for the rule, then tap Done. 5. Under Set criteria, configure the below settings as needed: Barcode type - The types of barcodes that the rule applies to. String length - The required length of scanned data to trigger the rule. String - A string that must be present for the rule to trigger. String position - When the cursor reaches this position in the string, the rule executes. 6. Under Set actions in order, tap Add actions. 7. A popup appears, prompting you to select actions you want to add. See the table below for details on each action. Tap Add when you're finished. 8. Configure the actions as necessary, then tap < in the top left to return to the rules list. 9. Repeat Steps 3-8 for any additional rules you want to create, then rearrange them in the order they should be executed. Refer to the advanced data formatting actions below to move the cursor, modify, send, or delay data being sent to business apps. If you add multiple actions to your rule, you can change the order in which they execute. Action Description Options Default Cursor movement Sets the cursor to move to a location in the output data. Skip ahead by characters &mdash; Moves the cursor forward by a specific number of characters. 1 Skip back by characters &mdash; Moves the cursor backwards by a specific number of characters. 1 Skip to start &mdash; Moves the cursor to the beginning of the output data. None Move ahead to substring &mdash; Moves the cursor forward until a specific string is found. None Move past substring &mdash; Moves the cursor past a specific string in the output data. None Data modification Sets the elements for Knox Capture to add, edit, or remove from the data. Remove extra spaces &mdash; Deletes all but one space between words, and removes any blank space at the beginning and end of the data. None Remove all spaces &mdash; Remove all spaces in the data. None Remove leading zeros &mdash; Remove any zeroes at the beginning of the data. None Pad with zeros to the left &mdash; Specify the desired length of the output. Knox Capture pads the left side of the string with zeros until the desired length is reached. 1 Replace string &mdash; Replaces a specific string with a new, specified string. You must specify both strings. None Remove characters When sending data, removes a specific number of characters from the given positions. You must provide the start position and the number of characters to remove. Start position: 1 Number of characters: 1 Data sending Controls a selected amount of data to send to business apps. Send next characters &mdash; Sends a specific number of characters from the current cursor position. 1 Send remaining characters &mdash; Sends all data after the current cursor position. None Send up to substring &mdash; Sends all data up to a specific string. None Send pause &mdash; Pauses all actions for a specific number of milliseconds (max. 120000). 50ms Send string &mdash; Sends a specific string when the corresponding rule is triggered. None Send cha &mdash; Sends a specific ASCII/Unicode character when the corresponding rule is triggered. 32", metadata={'source': 'all_processed_data.json', 'seq_num': 9, 'title': 'Configure keystroke output and data formatting', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/configure-keystroke-output-and-data-formatting', 'project': 'KCAP', 'last_updated': '2023-07-26', 'family_tree': 'parent', 'parent_id': None}),
#   Document(page_content='. #Standard ASCII control character abbreviations , ASCII , Hex , Name , Abbreviation , , - , - , - , - , , 1 , 1 , Start of Heading , SOH , , 2 , 2 , Start of Text , STX , , 3 , 3 , End of Text , ETX , , 4 , 4 , End of Transmission , EOT , , 5 , 5 , Enquiry , ENQ , , 6 , 6 , Acknowledgement , ACK , , 7 , 7 , Bell , BEL , , 8 , 8 , Backspace , BS , , 9 , 9 , Horizontal Tab , HT , , 10 , 0A , Line Feed , LF , , 11 , 0B , Vertical Tab , VT , , 12 , 0C , Form Feed , FF , , 13 , 0D , Carriage Return , CR , , 14 , 0E , Shift Out , SO , , 15 , 0F , Shift In , SI , , 16 , 10 , Data Link Escape , DLE , , 17 , 11 , Device Control 1 , DC1 , , 18 , 12 , Device Control 2 , DC2 , , 19 , 13 , Device Control 3 , DC3 , , 20 , 14 , Device Control 4 , DC4 , , 21 , 15 , Negative Acknowledgement , NAK , , 22 , 16 , Synchronous Idle , SYN , , 23 , 17 , End of Transmission Block , ETB , , 24 , 18 , Cancel , CAN , , 25 , 19 , End of Medium , EM , , 26 , 1A , Substitute , SUB , , 27 , 1B , Escape , ESC , , 28 , 1C , File Separator , FS , , 29 , 1D , Group Separator , GS , , 30 , 1E , Record Separator , RS , , 31 , 1F , Unit Separator , US , #Type interpretation ##String , Printable ASCII or Unicode characters aren\'t modified. For example, "abc" will appear as "abc" in the test overlay. Non-printable ASCII control characters get embedded in curly brackets. For example, a Tab control character will appear as "" in the test overlay if sent as a string. ##Key event Printable and non-printable characters appear in their character representation embedded in angle brackets when sent as key events. For example, if sent as key events, the data `abHT` appears as `` in the test overlay. Example The following example applies test mode notation to scanned barcode data based on a small set of keystroke output rules. Barcode input: `abc\\n123\\teh` This input uses escape sequences for control characters. `\\n` represents Enter and `\\t` represents Tab. Keystroke output rules: Send Enter as String, Send Tab as Key event, Send ASCII Printable characters as String Test mode notation: Scanned data: `abc123eh`, Output : `abc123 eh`', metadata={'source': 'all_processed_data.json', 'seq_num': 19, 'title': 'Use test mode', 'url': 'https://docs.samsungknox.com/admin/knox-capture/how-to-guides/use-test-mode', 'project': 'KCAP', 'last_updated': '2023-07-26', 'family_tree': 'parent', 'parent_id': None}),
#   Document(page_content='Configure keystroke output and data formatting. Knox Capture sends scanned data to business apps as keystrokes, imitating the way a user manually enters data using a keyboard. If you activate a KPE (Knox Platform for Enterprise) Premium license with a Galaxy S20 device in WP-C mode, you must set `AdvancedRestrictionPolicy.allowRemoteControl()` to True in your EMM. Enabling this policy allows keystroke output to function as expected. Keystroke output Refer to the following settings to modify scanned data and format its output: Setting Description Options Default Send Enter character as Sets the output format for all existing and appended Enters Key event &mdash; Sends Enter as a key event. String &mdash; Sends Enter as ASCII Line Feed 0x0A. Both String and Key event &mdash; Sends Enter as ASCII Line Feed 0x0A and key event. None &mdash; Sends no output for Enter. None Send Tab character as Sets the output format for all existing and appended Tabs Key event &mdash; Sends Tab as a key event. String &mdash; Sends Tab as ASCII Horizontal Tab 0x09. Both String and Key event &mdash; Sends Tab as ASCII Horizontal Tab 0x09 and key event. None &mdash; Sends no output for Tab. None Send Carriage Return character as Sets the output format for all Carriage Returns Key event &mdash; Sends Carriage Return as a key event. String &mdash; Sends Carriage Return as ASCII Carriage Return 0x0D. Both String and Key event &mdash; Sends Carriage Return as ASCII Carriage Return 0x0D and key event. None &mdash; Sends no output for Carriage Return. None Send ASCII Control characters as Sets the output format for ASCII characters 1-31 Key event &mdash; Sends ASCII codes 1 through 31 as key events String &mdash; Sends ASCII codes 1 through 31 as strings. Both String and Key event &mdash; Sends ASCII control characters in both string and key event formats. None &mdash; Sends no output for ASCII control characters. String Send ASCII Printable characters as Sets the output format for ASCII characters 32-126 Key event &mdash; Sends ASCII characters 32-126 as key events. This is useful when a text input field, like a password input, requires key events for validation and does not accept pasted strings. String &mdash; Sends ASCII printable characters as strings. Both String and Key event &mdash; Sends ASCII printable characters as both strings and key events. None &mdash; Sends no output for ASCII printable characters. String Key event delay Sets the delay in milliseconds that Knox Capture will wait before sending a key event like Tab. Key events transmit slower than string data, which can cause synchronization problems. If your barcode output is partially cut off, try increasing the key event delay to a higher value. [0, Int32 max value] 0 Basic data formatting Refer to the following basic data formatting information to create rules to add prefixes, suffixes, and append Tab or Enter characters to scanned barcode data before output. If appending a Tab or Enter key to the data output, you must also select an output option in the Send Tab as or Sent Enter as settings above. Setting , Description , Default - , - , - Prefix to data , Prepends a string of characters to the beginning of the scanned data. None Suffix to data , Appends a string of characters to the end of the scanned data. None Append Tab characte , Appends a Tab (ASCII Horizontal Tab character, 0x09) to the end of the scanned barcode data to automate actions like moving to the adjacent cell in a spreadsheet. OFF Append Enter characte , Appends an Enter (ASCII Line Feed character, 0x0A) to the end of the scanned barcode data to automate actions like submitting a form. OFF Send as Hex , Sends the data in hexadecimal format. OFF Advanced data formatting In Knox Capture, you can add one or more rules that modify data based on certain actions and criteria. These rules convert scanned data into various formats, which are then passed to business apps through keystrokes. To create a ru ...

# %% [markdown]
# ## 3.Evaluation
#  - [langchain evaluator](https://python.langchain.com/docs/guides/evaluation/string/criteria_eval_chain)

# %% [markdown]
# ### Load ground truth

# %%
import pandas as pd

# %%
ground_thruth = pd.read_csv("eval_dataset_v16.csv")

# %%
import time
import datetime
from langchain.evaluation import Criteria
from langchain.evaluation import EvaluatorType
from langchain.evaluation import load_evaluator

# %%
Criteria.CORRECTNESS
# Out:
# <Criteria.CORRECTNESS: 'correctness'>

# %%
list(Criteria)
# Out:
# [<Criteria.CONCISENESS: 'conciseness'>,
#  <Criteria.RELEVANCE: 'relevance'>,
#  <Criteria.CORRECTNESS: 'correctness'>,
#  <Criteria.COHERENCE: 'coherence'>,
#  <Criteria.HARMFULNESS: 'harmfulness'>,
#  <Criteria.MALICIOUSNESS: 'maliciousness'>,
#  <Criteria.HELPFULNESS: 'helpfulness'>,
#  <Criteria.CONTROVERSIALITY: 'controversiality'>,
#  <Criteria.MISOGYNY: 'misogyny'>,
#  <Criteria.CRIMINALITY: 'criminality'>,
#  <Criteria.INSENSITIVITY: 'insensitivity'>,
#  <Criteria.DEPTH: 'depth'>,
#  <Criteria.CREATIVITY: 'creativity'>,
#  <Criteria.DETAIL: 'detail'>]

# %%
langchain_evaluator = load_evaluator(
    EvaluatorType.LABELED_CRITERIA,
    llm=llm_text,
    criteria=Criteria.CORRECTNESS
)

# %% [markdown]
# ### Check prompt for evaluation

# %%
print(langchain_evaluator.prompt.partial_variables)
print("==")
print(langchain_evaluator.prompt.template)
# Out:
# {'criteria': 'correctness: Is the submission correct, accurate, and factual?'}
# ==
# You are assessing a submitted answer on a given task or input based on a set of criteria. Here is the data:
# [BEGIN DATA]
# ***
# [Input]: {input}
# ***
# [Submission]: {output}
# ***
# [Criteria]: {criteria}
# ***
# [Reference]: {reference}
# ***
# [END DATA]
# Does the submission meet the Criteria? First, write out in a step by step manner your reasoning about each criterion to be sure that your conclusion is correct. Avoid simply stating the correct answers at the outset. Then print only the single character "Y" or "N" (without quotes or punctuation) on its own line corresponding to the correct answer of whether the submission meets all criteria. At the end, repeat just the letter again by itself on a new line.

# %% [markdown]
# ### [Optional] Custon evaluator

# %%
from langchain.schema.output_parser import StrOutputParser

# %%
EVAL_TEMPLATE = """
\n\nHuman: 
Your job is to rate the accuracy of a generated answer given a query and a reference answer.

Here is query: <query>{query}</query>
Here is generated answer: <generated_answer>{generated_answer}</generated_answer>
Here is reference answer: <reference_answer>{reference_answer}</reference_answer>

Then answer the quality of a generated answer as scores starting with "Score:".
Your score has to be between 1 and 5.
You must return your response in a line with only the score.
Do not return answers in any other format.

\n\nAssistant:
"""

prompt_template_eval = PromptTemplate(
    template=EVAL_TEMPLATE, input_variables=["query", "generated_answer", "reference_answer"]
)

question = "What is the default mode of operation for Knox Capture?"
answer="Admin mode is the default mode of operation for Knox Capture. Therefore, a user cannot switch to Admin mode by activating a Knox Capture license, the app is exported in admin mode"
prediction = "The default mode of operation for Knox Capture is Admin mode."


custom_evaluator = prompt_template_eval | llm_text | StrOutputParser()

# %%
ground_thruth.head()
# Out:
#                                             question  \
# 0  What are the key differences in functionality ...
# 1  What are the intended audience and operation m...
# 2  How can an IT admin configure the scan trigger...
# 3  What barcode type would you add or remove when...
# 4  Describe the key steps involved in a typical K...
#
#                                               answer  \
# 0  In managed mode, Knox Capture functionality is...
# 1  The intended audience for this procedure are I...
# 2  An IT admin can set the camera scan triggers f...
# 3  It is not possible to determine what barcode t...
# 4  A typical Knox Capture workflow for IT admins ...
#
#                                  doc_id  \
# 0  7f17c8ef-7d22-44a7-b92e-b26f4716d3d0
# 1  6a70e00b-0e60-4dfa-a9cf-6d753d3eee7c
# 2  709c077e-5440-4ef4-afc8-d96e4209f659
# 3  2668595c-19a0-4e9a-9e38-25dbd455a85e
# 4  87a9dba8-d3a8-41c4-8fd9-eac0d1d50c61
#
#                                                  doc
# 0  . 3. Export profile settings as a configuratio...
# 1  . Admin mode is the default mode of operation ...
# 2  . Test mode - A feature that lets you test a s...
# 3  . Add or remove a barcode type of your choice....
# 4  . Save the updated settings and deploy. Summar...

# %%
# %%time
evaluation = []
parent_document = True
for idx, row in enumerate(ground_thruth.itertuples()):
    try:
        question, answer, doc, doc_id = getattr(row, "question"), getattr(row, "answer"), getattr(row, "doc"), getattr(row, "doc_id")

        start = time.time()
        response = qa_chain(question)
        elapsed = time.time() - start

        prediction = response["result"]
        retrieved_docs = {doc.page_content: idx+1 for idx, doc in enumerate(response["source_documents"])}
        contexts = "\n\n".join(retrieved_docs.keys())

        payload = json.dumps(
            {
                "inputs": [
                    {"text": answer, "text_pair": prediction},
                ]
            }
        )

        response = runtime_client.invoke_endpoint(
            EndpointName=endpoint_name,
            ContentType="application/json",
            Accept="application/json",
            Body=payload
        )
        out = json.loads(response['Body'].read().decode()) ## for json

        eval_result_langchain = langchain_evaluator.evaluate_strings(
            input=question,
            prediction=prediction,
            reference=answer,
        )
        eval_result_custom = custom_evaluator.invoke(
            {
                "query": question,
                "generated_answer": prediction,
                "reference_answer": answer
            }
        )
        
        reranker_sim = out[0]["score"]
        langchain_correctness = eval_result_langchain["score"]
        custom_correctness = int(eval_result_custom.split("\n")[0].strip().split("Score: ")[1])
        
        if not parent_document:
            if doc in retrieved_docs:
                true_context_rank = retrieved_docs[doc]
                has_right_context = 1
                mrr = 1/true_context_rank
            else:
                true_context_rank = has_right_context = 0
                mrr = 0
        else:
            for retrieved_doc in retrieved_docs:
                
                if doc in retrieved_doc:

                    true_context_rank = retrieved_docs[retrieved_doc]
                    has_right_context = 1
                    mrr = 1/true_context_rank
                    break
                else:
                    true_context_rank = has_right_context = 0
                    mrr = 0

        total_contexts = len(retrieved_docs)
        latency = datetime.timedelta(seconds=elapsed)

        print(idx)
        print(colored("Question: ", "red"), colored(question, "red"))
        print(colored("GroundTruth: ", "green"), colored(answer, "green"))
        print(colored("Prediction: ", "blue"), colored(prediction, "blue"))
        print(f'ReRanker similarity: {reranker_sim}')
        print(f'Langchain correctness: {langchain_correctness}')
        print(f'Custom correctness: {custom_correctness}')
        print(f'has_right_context: {has_right_context}')
        print(f'true_context_rank: {true_context_rank}/{total_contexts}')
        print(f'mrr: {mrr:.3f}')
        print(f'latency: {latency} secs')
        print(f'prediction length: {len(prediction)}')

        evaluation.append([question, answer, prediction, \
                           has_right_context, true_context_rank, total_contexts, mrr, \
                           reranker_sim, langchain_correctness, custom_correctness, elapsed, contexts, len(prediction)])
    except:
        print ("err", idx)

eval_results = pd.DataFrame(
    evaluation,
    columns=["question", "true_answer", "prediction", \
             "has_right_context", "true_context_rank", "total_contexts", "mrr", \
             "reranker_sim", "langchain_correctness", "custom_correctness", "latency", "contexts", "pred_length"]
)
eval_results.to_csv("eval_results_hyde_parent_document.csv", index=False)
#eval_results.to_pickle("eval_results.pkl")
# Out:
# 0
# Question:  What are the key differences in functionality between Knox Capture in Admin mode versus Managed mode?
# GroundTruth:  In managed mode, Knox Capture functionality is limited, as end-users cannot make changes to their scanning profiles, export profile settings, or activate a Knox Capture license to switch to Admin mode.
# Prediction:   <answer>
# The key differences in functionality between Knox Capture in Admin mode versus Managed mode are:
#
# 1. In Admin mode, the IT admin can create scanning profiles, test them, export/import configurations, and switch to Managed mode.
#
# 2. In Managed mode, end users can only review their scanning profile settings and perform barcode scans using their business apps as permitted by the profile. They cannot make changes to profiles, export settings, or switch to Admin mode.
#
# </answer>
# ReRanker similarity: 0.9988479614257812
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:15.572862 secs
# prediction length: 488
# 1
# Question:  What are the intended audience and operation mode covered in the context reading passage?
# GroundTruth:  The intended audience for this procedure are IT admins. The default operation mode covered in the tutorials is the Knox Capture admin mode.
# Prediction:   <answer>
# The intended audience covered in the context reading passage is IT admins. The operation modes covered are:
#
# - Admin mode (Default): Allows IT admins full functionality to create scanning profiles, test profiles, export settings, etc. This is the default mode when Knox Capture is first installed.
#
# - Managed mode: Used by end users after Knox Capture is deployed to their devices by IT admins. Functionality is reduced in this mode - end users can scan barcodes but not change settings or switch to Admin mode.
#
# </answer>
# ReRanker similarity: 0.9995623230934143
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:12.103281 secs
# prediction length: 532
# 2
# Question:  How can an IT admin configure the scan triggers in Knox Capture to allow users to scan either using the hardware button or floating action button or both?
# GroundTruth:  An IT admin can set the camera scan triggers from the admin's as well as end-user's perspective through the Knox dashboard. The admin can configure the Knox Capture to scan using the hardware button, floating action button, or both.
# Prediction:   <answer>
# To configure the scan triggers, an IT admin can:
#
# 1. Go to the Camera scan triggers menu under the more options menu next to Profiles on the home screen.
# 2. Turn on the Hardware key setting to allow scanning using the hardware button (XCover key, Top key, or Side key double press).
# 3. Turn on the Floating action button setting to enable the on-screen floating scan button. Users can then hold and drag this button around the screen.
# </answer>
# ReRanker similarity: 0.999578058719635
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:12.878896 secs
# prediction length: 455
# 3
# Question:  What barcode type would you add or remove when creating a profile for best performance?
# GroundTruth:  It is not possible to determine what barcode type to add or remove when creating a profile for best performance within the given context.
# Prediction:   <answer>When creating a profile, you should only select the barcode types necessary for best performance. The context states: "Add or remove a barcode type of your choice. For best performance, only select the barcode types necessary when creating the profile."</answer>
# ReRanker similarity: 0.9949660897254944
# Langchain correctness: 0
# Custom correctness: 1
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:08.924279 secs
# prediction length: 271
# 4
# Question:  Describe the key steps involved in a typical Knox Capture workflow for IT admins, according to the information provided.
# GroundTruth:  A typical Knox Capture workflow for IT admins involves configuring and deploying the app to managed devices. To do this, the IT admin must first update the Knox Capture settings and then deploy the app to the managed devices. After these steps are completed, the Knox Capture app will be ready for use.
# Prediction:   <answer>
# A typical Knox Capture workflow for IT admins involves:
#
# 1. Downloading, installing, and launching the Knox Capture app
# 2. Editing the default scanning profile or creating a new profile. This involves configuring settings like the apps that can launch scanning, barcode types, keystroke output rules, etc.
# 3. Testing the scanning profile in test mode to ensure apps can launch scanning and data is formatted properly.
# 4. Exporting the scanning profile configuration as a file.
# 5. Using an EMM/UEM to deploy Knox Capture as a managed app to end user devices, using the exported configuration file.
# </answer>
# ReRanker similarity: 0.9988364577293396
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:14.048106 secs
# prediction length: 617
# 5
# Question:  What specific action launches the scanner in step 3 according to the instructions?
# GroundTruth:  Tap the Knox Capture button on the keyboard.
# Prediction:   <answer>In step 3, turning on the "Hardware key" setting launches the scanner.</answer>
# ReRanker similarity: 0.0012765841092914343
# Langchain correctness: 0
# Custom correctness: 1
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:07.443632 secs
# prediction length: 88
# 6
# Question:  What type of configuration settings allow IT admins to append key events after barcode scans in Knox Capture?
# GroundTruth:  Knox Capture includes keystroke output rules that IT admins can use to append key events after a barcode scan.
# Prediction:   <answer>The keystroke output rules in a Knox Capture scanning profile allow IT admins to append key events like Tab and Enter after barcode scans. Specifically, the options under "Keystroke output" in a profile can be used to send Tab, Enter, or other key events after each successful scan.</answer>
# ReRanker similarity: 0.9999276399612427
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 0
# true_context_rank: 0/4
# mrr: 0.000
# latency: 0:00:09.860277 secs
# prediction length: 300
# 7
# Question:  What character is appended to the end of scanned barcode data to automate submitting a form?
# GroundTruth:  Append Enter character (ASCII Line Feed character, 0x0A)
# Prediction:   <answer>The context states that appending an Enter (ASCII Line Feed character, 0x0A) to the end of the scanned barcode data can automate actions like submitting a form.</answer>
# ReRanker similarity: 0.9974516034126282
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:07.382780 secs
# prediction length: 178
# 8
# Question:  What action sends a specific number of characters from the current cursor position?
# GroundTruth:  Send next characters
# Prediction:   <answer>The "Send next characters" action under the "Data sending" category sends a specific number of characters from the current cursor position.</answer>
# ReRanker similarity: 0.997346043586731
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/2
# mrr: 1.000
# latency: 0:00:07.017497 secs
# prediction length: 157
# 9
# Question:  What is the default zoom factor value in Knox Capture and what is the range of values it can take?
# GroundTruth:  The default zoom factor value in Knox Capture is 1.0. It can take any value between 1.0 and 4.0.
# Prediction:   <answer>
# The default zoom factor value in Knox Capture is 1.0, and the range of values it can take is from 1.0 (no zoom) to 4.0 (fully zoomed in).
# </answer>
# ReRanker similarity: 0.9999244213104248
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:05.237068 secs
# prediction length: 157
# 10
# Question:  What steps should you take to pair a new Bluetooth scanner device with Knox Capture?
# GroundTruth:  To pair a new Bluetooth scanner device with Knox Capture, you should first ensure Hardware scanner option under Scanner is enabled in your scanning profile. Then on the main Knox Capture page, tap the more actions menu icon, select Connect scanner, and on the Connect scanner screen, select Pair new device.
# Prediction:   <answer>
# To pair a new Bluetooth scanner device with Knox Capture:
#
# 1. On the Knox Capture main page, next to Profiles, tap the more actions menu icon.
# 2. Select Connect scanner.
# 3. On the Connect scanner screen, select Pair new device.
# 4. If Bluetooth is turned off, you're prompted to turn it on. Afterwards, the Bluetooth connection panel appears. You can use this panel to connect to the scanner or navigate to the device settings to connect.
# 5. A pop-up then appears asking the user to confirm whether they want to use the paired device for scanning with Knox Capture. Select Yes.
# </answer>
# ReRanker similarity: 0.9999276399612427
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 2/3
# mrr: 0.500
# latency: 0:00:16.090172 secs
# prediction length: 598
# 11
# Question:  What steps should you take when assigning the Knox Capture app to a group or organization in order to ensure all devices operate in Managed mode?
# GroundTruth:  When assigning the Knox Capture app to a group or organization, you should ensure that the Knox Capture configuration is added to the Managed Google Play console when updating the license key. This will allow all devices to operate in Managed mode.
# Prediction:   <answer>To ensure all devices operate in Managed mode when assigning the Knox Capture app to a group or organization, you should:
#
# 1. Add the Knox Capture app to your Managed Google Play Store.
# 2. Assign the app to a group or organization and launch the app configuration dialog.
# 3. Activate the license by pasting it into the field within the app configuration (App Config) screen.
# 4. Copy and paste the exported configuration into the provided app configuration field.
# 5. Save the updated settings and deploy.</answer>
# ReRanker similarity: 0.9999099969863892
# Langchain correctness: 0
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:18.391711 secs
# prediction length: 523
# 12
# Question:  What are the two steps you must complete before getting a Knox Suite license for continued use of Knox Capture after the free trial expires?
# GroundTruth:  1. Sign up for a Samsung Knox account if you haven't already. 2. Apply for access to Knox Suite and sign in to the Knox Admin Portal to generate your Knox Capture license.
# Prediction:   <answer>
# The two steps you must complete before getting a Knox Suite license for continued use of Knox Capture after the free trial expires are:
#
# 1. Sign up for a Samsung Knox account if you don't already have one.
#
# 2. Apply for access to Knox Suite.
# </answer>
# ReRanker similarity: 0.999614953994751
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:06.066010 secs
# prediction length: 261
# 13
# Question:  What are two ways to deactivate a Knox Capture license if it was activated through an EMM?
# GroundTruth:  To deactivate a Knox Capture license if it was activated through an EMM, you can send an uninstallation command for the Knox Capture app or edit the existing license field in the Knox Capture app configuration.
# Prediction:   <answer>
# The two ways to deactivate a Knox Capture license if it was activated through an EMM are:
#
# 1. Push an uninstallation command for the Knox Capture app through the EMM. Once the device receives the command, the Knox Capture app is removed and its license seat is unassigned.
#
# 2. Edit the license field in the Knox Capture app configuration in the EMM. Replace the existing license key string with DEACTIVATE and save the changes. Once the Knox Capture agent detects the new string, the license is deactivated.
# </answer>
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:22.559285 secs
# prediction length: 527
# 14
# Question:  What intent output information can be obtained from the bundle according to the code snippet?
# GroundTruth:  The following intent output information can be obtained from the bundle:
# - INTENT_OUTPUT_SCAN_SOURCE
# - INTENT_OUTPUT_SYMBLOGY_TYPE
# - INTENT_OUTPUT_UNPROCESSED_STRING_DATA
# Prediction:   <answer>
# The intent output information that can be obtained from the bundle according to the code snippet includes:
#
# - Test mode status (whether Knox Capture test mode is on)
# - The list of scanned barcode data bundles
# - Symbology type
# - Scan source
# - Scanner type (e.g. camera)
# </answer>
# ReRanker similarity: 0.997326135635376
# Langchain correctness: 0
# Custom correctness: 3
# has_right_context: 1
# true_context_rank: 1/1
# mrr: 1.000
# latency: 0:00:06.841704 secs
# prediction length: 289
# 15
# Question:  What are the 4 steps outlined that Knox Capture admins need to follow to set up intent output?
# GroundTruth:  1. Tap on the profile you want to set up intent output for.
# 2. Under Intent output, tap Select app packages.
# 3. Tap on Select app packages.
# 4. Tap on Select apps for intent output.
# Prediction:   <answer>
# The 4 steps outlined that Knox Capture admins need to follow to set up intent output are:
#
# 1. On the Knox Capture home screen, tap on the profile you want to set intent output for.
# 2. Under Intent output, tap Select app packages and select the apps for intent output.
# 3. Under Intent output, specify an Intent action, Intent category, and Intent delivery method to handle the intent.
# 4. Ensure the intent action, category, and delivery method match the business app's intent filter information in the AndroidManifest.xml file.
# </answer>
# ReRanker similarity: 0.9963263869285583
# Langchain correctness: 1
# Custom correctness: 2
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:13.738935 secs
# prediction length: 547
# 16
# Question:  What gesture must the user perform to enable the scanner overlay feature? The user must tap the Options button represented by three dots, then tap Scanner overlay, and finally toggle the feature On to enable it.
# GroundTruth:  The user must tap the Options button represented by three dots, then tap Scanner overlay, and finally toggle the feature On to enable it.
# Prediction:   <answer>To enable the Scanner overlay feature, the user must:
# 1. Go to the Knox Capture home screen
# 2. Tap the Options button (three dots)
# 3. Tap Scanner overlay
# 4. Toggle the feature On
# </answer>
# ReRanker similarity: 0.9998488426208496
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:04.211358 secs
# prediction length: 197
# err 17
# 18
# Question:  What are two examples provided in the text of how printable and non-printable ASCII characters are represented in the test overlay?
# GroundTruth:  In the test overlay, printable ASCII characters are represented in their native printable format, while non-printable ASCII control characters are represented with standard abbreviations. For instance, a Tab control character appears as "HT" and a Line Feed control character appears as "LF" in the test overlay.
# Prediction:   <answer>
# Two examples provided in the text of how printable and non-printable ASCII characters are represented in the test overlay are:
#
# 1. Printable ASCII or Unicode characters aren't modified. For example, "abc" will appear as "abc" in the test overlay.
#
# 2. Non-printable ASCII control characters get embedded in curly brackets. For example, a Tab control character will appear as "" in the test overlay if sent as a string.
# </answer>
# ReRanker similarity: 0.9982143640518188
# Langchain correctness: 0
# Custom correctness: 2
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:08.329499 secs
# prediction length: 438
# 19
# Question:  What ASCII control code has a decimal value of 27 and a hexadecimal value of 1B, and what does it represent?
# GroundTruth:  Escape (ESC) is ASCII control code with a decimal value of 27 and a hexadecimal value of 1B. It is typically used to abort an operation, such as performing the function of cancelling an escape in a character following a we define in ISO/IEC 6429.
# Prediction:   <answer>The ASCII control code that has a decimal value of 27 and a hexadecimal value of 1B is the Escape (ESC) code. It represents the Escape control character.</answer>
# ReRanker similarity: 0.9998772144317627
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:06.728764 secs
# prediction length: 171
# 20
# Question:  Describe an example use case for the search-and-find AR template. What problem does it help solve?
# GroundTruth:  This AR template can help a retail worker locate a single box from a large wall of boxes in a warehouse. It analyzes each barcode in the camera preview window and overlays a match on the worker's screen for easy identification.
# Prediction:   <answer>
# The search-and-find AR template helps solve the problem of locating a specific item from a group of similar items. For example, it could help a retail worker locate a single box from a large wall of identical boxes in a warehouse.
#
# To use it, the worker would first scan a reference barcode of the item they need to find. Then when they aim the camera at the wall of boxes, Knox Capture AR analyzes the barcodes in view and highlights the one that matches the reference. This makes it easy to visually identify the specific item they need.
# </answer>
# ReRanker similarity: 0.9999046325683594
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:25.211737 secs
# prediction length: 560
# 21
# Question:  What are the two ways mentioned to activate your Knox Capture license?
# GroundTruth:  There are two ways to activate your Knox Capture license: Through your EMM and Through the License menu.
# Prediction:   <answer>
# The two ways mentioned to activate your Knox Capture license are:
#
# 1. Through the License menu in the Knox Capture app
# 2. Through your EMM (enterprise mobility management) console
# </answer>
# ReRanker similarity: 0.9999145269393921
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:07.164322 secs
# prediction length: 199
# 22
# Question:  What steps should you take to enter a Knox Capture license key when prompted after tapping the license text field?
# GroundTruth:  When prompted, one should enter the Knox Capture license key in the text field, and then tap "Done" to confirm.
# Prediction:   <answer>To enter a Knox Capture license key when prompted after tapping the license text field, you should:
#
# 1. Enter your Knox Capture license key
# 2. Tap Done
#
# </answer>
# ReRanker similarity: 0.9997889399528503
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:08.109820 secs
# prediction length: 171
# 23
# Question:  What property can be changed to include barcode lengths not enabled by default or optimize decoding performance for a certain number of symbols?
# GroundTruth:  The active symbol count property can be changed to include barcode lengths not enabled by default or optimize decoding performance for a certain number of symbols. The active symbol count determines the barcode length (active symbol count) to decode.
# Prediction:   <answer>The "Min. length" setting determines the minimum supported barcode length (active symbol count) to decode. This property can be changed to include lengths not enabled by default, or to optimize decoding performance for a certain number of symbols.</answer>
# ReRanker similarity: 0.9995443224906921
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:08.475999 secs
# prediction length: 265
# 24
# Question:  What barcode type typically has optional checksums that can be enforced to help reduce false positives and provide an extra layer of error prevention?
# GroundTruth:  Some barcode types include a mandatory checksum, while others only have optional checksums. Enforcing an optional checksum helps reduce false positives and provides an extra layer of error prevention.
# Prediction:   <answer>Some barcode types include optional checksums that can help reduce false positives and provide an extra layer of error prevention. When enabling a checksum, ensure your barcode data includes the calculated checksum, otherwise the checksum will not match and the barcode data is discarded.</answer>
# ReRanker similarity: 0.9997135996818542
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:10.172775 secs
# prediction length: 306
# 25
# Question:  What are the two Android versions that Knox Capture v1.0.01 now supports on devices like the XCover Pro and Tab Active3?
# GroundTruth:  Android 10 and Android 11.
# Prediction:   <answer>Knox Capture v1.0.01 now supports Android 10 and Android 11 on devices like the XCover Pro and Tab Active3.</answer>
# ReRanker similarity: 0.7771793603897095
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:04.988913 secs
# prediction length: 125
# 26
# Question:  What new capability does Knox Capture v1.1 add to support sending scan data to business apps?
# GroundTruth:  Knox Capture v1.1 adds support for intent output, which allows the scan data to be sent programmatically to a business app when triggered by an Android intent.
# Prediction:   <answer>Knox Capture v1.1 adds support for intent output. As an IT admin, you can configure scan data to be sent programmatically to a business app when triggered by an Android intent. Upon scanning, the app acquires the data and can either consume or process it further.</answer>
# ReRanker similarity: 0.9999276399612427
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:06.334415 secs
# prediction length: 281
# 27
# Question:  What new interface elements indicate when an admin has tested a configuration in Admin mode?
# GroundTruth:  Knox Capture v1.2 adds support for USB and Bluetooth hardware scanners and displays a green checkmark to its right to indicate its tested status.
# Prediction:   <answer>When testing configurations in Admin mode, new indicators for tested app activities are displayed under the profile. Any activity not visible in the list behaves under the default profile. After being tested, each activity displays a green checkmark to its right to indicate its tested status.</answer>
# ReRanker similarity: 0.8659541010856628
# Langchain correctness: 0
# Custom correctness: 2
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:15.649612 secs
# prediction length: 311
# 28
# Question:  What type of notification will the user receive if the IT admin has restricted the camera preview window?
# GroundTruth:  The user will now get a notification asking them to contact their IT admin for more information.
# Prediction:   <answer>If the IT admin has restricted the camera preview window, the user will receive a notification asking them to contact their IT admin for more information.</answer>
# ReRanker similarity: 0.9990179538726807
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:06.201947 secs
# prediction length: 172
# 29
# Question:  How can managed mode be automatically applied to enterprise devices?
# GroundTruth:  To automatically apply managed mode to enterprise devices, Knox Capture must be configured and deployed through an EMM (Enterprise Mobility Management) console.
# Prediction:   <answer>
# Managed mode is automatically applied when Knox Capture is configured and deployed through an EMM console. To ensure devices run Knox Capture in Managed mode, admins need to:
#
# 1. Install and configure Knox Capture on an admin device
# 2. Export the configuration as a text file
# 3. Add Knox Capture to Managed Google Play
# 4. Assign the app to a group/organization
# 5. Paste the exported configuration text into the app configuration dialog
# 6. Deploy Knox Capture with the configuration to devices
# </answer>
# ReRanker similarity: 0.9997895359992981
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:19.168808 secs
# prediction length: 513
# 30
# Question:  What tutorial can users follow to get started with Knox Capture for free?
# GroundTruth:  To get started with Knox Capture for free, users can download the app from Google Play and configure scan settings according to the IT admins: Get started tutorial.
# Prediction:   <answer>To try Knox Capture for free, users can follow the end-user get started tutorial. This tutorial guides end-users through launching the barcode scanner from an app, reviewing scanning profile configurations, and changing camera scan triggers.</answer>
# ReRanker similarity: 0.99394690990448
# Langchain correctness: 0
# Custom correctness: 3
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:09.097104 secs
# prediction length: 259
# 31
# Question:  How would you find more information on managing a Scandit license if using Knox Capture: Scandit Edition?
# GroundTruth:  You would refer to the Manage Scandit license page in the Scandit Edition section for more information.
# Prediction:   <answer>
# To find more information on managing a Scandit license if using Knox Capture: Scandit Edition, refer to the "Manage Scandit license" section. This section describes methods to activate and deactivate your Knox Capture Scandit Edition license.
# </answer>
# ReRanker similarity: 0.9978435039520264
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:08.338781 secs
# prediction length: 262
# 32
# Question:  What are some common reasons why barcode data may not output correctly to a business app?
# GroundTruth:  Most barcode capture issues begin with minor errors in the keystroke output and scan engine settings.
# Prediction:   <answer>Some common reasons why barcode data may not output correctly to a business app include:
#
# - Minor errors in the keystroke output and scan engine settings. Things like incorrect barcode types, length settings, etc. can prevent data from being captured properly.
#
# - The scanning overlay not appearing when launching the camera. This prevents any scanning from occurring.
#
# - Scan data only being partially sent to the business app. This indicates an issue with the data transmission.
#
# - The current device software being unsupported when installing the scanning software. This can lead to compatibility issues.
#
# - Policy or license updates not being applied properly to the scanning app. This can cause features to malfunction.
#
# </answer>
# ReRanker similarity: 0.9859857559204102
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:25.857804 secs
# prediction length: 744
# 33
# Question:  If a user is seeing a "Your current device software is unsupported" message when trying to install Knox Capture, what are two possible reasons for why they are seeing this message?
# GroundTruth:  There are two possible reasons for why a user is seeing this message. One is that the device's current software (operating system) is not currently supported by Knox Capture. The second reason is that the user's wireless carrier has not yet pushed the most recent updates to the device.
# Prediction:   <answer>
# Two possible reasons for seeing the "Your current device software is unsupported" message when trying to install Knox Capture are:
#
# 1. The current device software (OS) version isn't supported by Knox Capture.
#
# 2. The wireless carrier hasn't yet pushed the most recent updates to the device.
# </answer>
# ReRanker similarity: 0.9999266862869263
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.384259 secs
# prediction length: 310
# 34
# Question:  What intent action should be used for the key release event when setting up PTT key mapping on a Samsung Knox device?
# GroundTruth:  com.samsung.android.knox.intent.action.PTT_RELEASE
# Prediction:   <answer>The intent action that should be used for the key release event when setting up PTT key mapping is:
#
# com.samsung.android.knox.intent.action.PTT_RELEASE
#
# </answer>
# ReRanker similarity: 0.9991149306297302
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:05.496522 secs
# prediction length: 171
# 35
# Question:  What setting in the Knox Capture scanning profile results in only partial barcode data being sent to the business app when using keystroke output?
# GroundTruth:  Continuous scanning being enabled and Keystroke output being set to Key events.
# Prediction:   <answer>The setting that results in only partial barcode data being sent to the business app when using keystroke output is the "Set key event delay" under Keystroke output. When this delay is set too low, Knox Capture will switch focus back to the scanner overlay before all the barcode data has been sent to the business app as keystrokes, resulting in only partial data being received by the business app.</answer>
# ReRanker similarity: 0.9360807538032532
# Langchain correctness: 0
# Custom correctness: 2
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:09.258203 secs
# prediction length: 418
# 36
# Question:  According to the passage, what setting should be changed to resolve the issue where undelivered data is sent to the scanner overlay instead of the business app?
# GroundTruth:  In the Knox Capture profile settings, navigate to Keystroke output > Set key event delay and extend the length of time before the foreground focus switches back to the scanner overlay.
# Prediction:   <answer>To resolve the issue where undelivered data is sent to the scanner overlay instead of the business app, the passage recommends going to the Knox Capture profile settings, navigating to Keystroke output > Set key event delay, and extending the length of time before the foreground focus switches back to the scanner overlay. By default, the key event delay is set to 0 ms.</answer>
# ReRanker similarity: 0.999901294708252
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:07.182599 secs
# prediction length: 389
# 37
# Question:  What are some of the common issues that can occur when using Knox Capture, such as problems with scanning overlays or barcode capture?
# GroundTruth:  Some of the common issues that can occur when using Knox Capture include: scanning overlay doesn't appear when launching the camera; outputs scanned barcode data to HTML fields in chromium-based web browsers; and sometimes the scanned data is only partially sent to business app.
# Prediction:   <answer>Some common issues that can occur when using Knox Capture include:
#
# - Scanning overlay doesn't appear when launching the camera
# - Cannot output scanned barcode data to HTML fields in Chromium-based web browsers
# - Scan data is only partially sent to business app
# - Barcode capture not working for business app
# - Current device software is unsupported when installing Knox Capture
# - Out-of-range barcode still scanned successfully by Knox Capture
# - Policy or license updates not applied to Knox Capture app
# - Keystroke output data sent to browser or web app instead of business app
#
# Knox Capture can also have difficulties detecting barcodes under extreme glare conditions or scanning tiny barcodes like Code 93 and Code 128. There can also be issues scanning multiple barcodes at once from far distances.
# </answer>
# ReRanker similarity: 0.9999274015426636
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:20.109561 secs
# prediction length: 822
# 38
# Question:  What license key do you need to upgrade from Knox Manage to Knox Suite?
# GroundTruth:  Knox Manage.
# Prediction:   <answer>To upgrade from Knox Manage to Knox Suite, you need to purchase a Knox Suite license key from an authorized reseller and replace your existing Knox Manage license key with the new Knox Suite license key.</answer>
# ReRanker similarity: 0.6556516289710999
# Langchain correctness: 1
# Custom correctness: 1
# has_right_context: 1
# true_context_rank: 2/3
# mrr: 0.500
# latency: 0:00:04.953995 secs
# prediction length: 221
# 39
# Question:  What are the steps you must perform before you can start generating Knox Suite licenses for your Enterprise Edition devices?
# GroundTruth:  You must: 1. Register for the Knox Admin Portal with your Samsung account. 2. Sign in to the Knox Admin Portal. 3. Click your account icon to view your Knox Customer ID. 4. Purchase EE devices from a Samsung device reseller. Give your customer ID to your reseller. Your device reseller must be a member of the Knox Deployment Program (KDP). 5. Generate a Knox Suite license.
# Prediction:   <answer>
# Before you can start generating Knox Suite licenses for your Enterprise Edition (EE) devices, you must:
#
# 1. Register for the Knox Admin Portal with your Samsung account.
# 2. Sign in to the Knox Admin Portal.
# 3. Click your account icon to view your Knox Customer ID.
# 4. Purchase EE devices from a Samsung device reseller. Give your customer ID to your reseller. Your device reseller must be a member of the Knox Deployment Program (KDP).
# </answer>
# ReRanker similarity: 0.999757707118988
# Langchain correctness: 0
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:08.953300 secs
# prediction length: 456
# 40
# Question:  What are the two ways to open the Enterprise Edition Dashboard from the Knox Admin Portal?
# GroundTruth:  From the Licenses page and from the Additional Solutions tab (only available to Knox Suite users).
# Prediction:   <answer>
# The two ways to open the Enterprise Edition Dashboard from the Knox Admin Portal are:
#
# 1. From the Licenses page - In the navigation pane of the Knox Admin Portal, click Licenses. The consolidated licenses page opens. Click ACTIONS > Get a license > GENERATE KNOX SUITE LICENSE.
#
# 2. From the Additional Solutions tab (only available to Knox Suite users) - First, make sure your dashboard is configured to show the Additional Solutions tab, which is only available for Knox Suite users. Click your account icon > Settings > SHOW/HIDE SERVICES. In the navigation pane, click Additional Solutions. On the Enterprise Edition devices card, click Generate a free Knox Suite license key.
# </answer>
# ReRanker similarity: 0.9987230896949768
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 2/4
# mrr: 0.500
# latency: 0:00:09.746469 secs
# prediction length: 700
# 41
# Question:  What are the two ways you can merge Knox Suite licenses?
# GroundTruth:  There are two ways to merge Knox Suite licenses: by adding a new batch of devices with no license to an existing license, or by merging Knox Suite licenses.
# Prediction:   <answer>
# The two ways to merge Knox Suite licenses are:
#
# 1. By adding a new batch of devices with no license to an existing license
# 2. By merging Knox Suite licenses for Enterprise Edition devices that have 0 seats activated and were issued by the same reseller
# </answer>
# ReRanker similarity: 0.9999276399612427
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:06.709440 secs
# prediction length: 272
# 42
# Question:  What is the difference between licenses generated and devices remaining?
# GroundTruth:  The difference between the licenses generated and devices remaining is that licenses generated shows the number of devices that have a Knox Suite license whereas devices remaining shows the number of devices that do not have a Knox Suite license.
# Prediction:   <answer>
# The difference between licenses generated and devices remaining is:
#
# Licenses generated refers to the number of devices that have a Knox Suite license.
#
# Devices remaining refers to the number of devices that don't have a Knox Suite license.
#
# So licenses generated tracks how many devices have a license, while devices remaining tracks how many still need a license.
# </answer>
# ReRanker similarity: 0.9999271631240845
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:10.625405 secs
# prediction length: 385
# 43
# Question:  Describe the meaning and purpose of the four dates listed regarding security updates (i.e. LATEST, UPCOMING, FINAL, and the date under LATEST).
# GroundTruth:  The LATEST date is the most recent release date for a new security update. The UPCOMING date is the planned release date for the next upcoming security update. The FINAL date is the last planned release date for a security update before the device will stop receiving them. Holding your mouse over the LATEST date will show a pop-up that reads, "Click to view device's Security Maintenance Release (SMR) history."
# Prediction:   <answer>
# The four dates regarding security updates have the following meaning and purpose:
#
# LATEST - The release date of the most recent security update for the device model. This shows when the latest security update was made available.
#
# UPCOMING - The date of the next upcoming security update for the device model. This shows when the next planned security update is scheduled to be released.
#
# FINAL - The date of the final security update for the device model. This shows when security updates for that model are scheduled to end.
#
# The date under LATEST - Clicking on the LATEST date shows the full release history of all security updates for that device model. This allows you to see the entire timeline of security updates that have been released.
# </answer>
# ReRanker similarity: 0.9979740977287292
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:11.664120 secs
# prediction length: 765
# 44
# Question:  What are the two fields that need to be filled out when registering for Knox Services if your organization is not already signed up?
# GroundTruth:  Tenant ID and Organization Domain
# Prediction:   <answer>
# If your organization isn't already signed up for Knox Services, the two fields that need to be filled out when registering for Knox Services are:
#
# 1. Organization Domain
# 2. Prefix
#
# The context states: "If your organization isn't signed up for Knox Services, your organization's domain makes up your unique tenant ID. Confirm that your organization's domain automatically filled the Tenant ID field and click Complete Registration." This indicates the Organization Domain field needs to be filled out.
#
# It then states: "If your organization is already signed up for Knox Services, you need to define a prefix to differentiate your tenant from other tenants in your organization." This indicates the Prefix field needs to be filled out if not already signed up.
# </answer>
# ReRanker similarity: 0.954378068447113
# Langchain correctness: 0
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:09.871383 secs
# prediction length: 780
# 45
# Question:  Here is the generated question without any options or symbols as requested, focused only on the context information provided:
#
# What is the length of the free trial for Knox Suite that supports up to 30 devices on a per-seat basis?
# GroundTruth:  Three months.
# Prediction:   <answer>
# The free, fully-featured, 3-month trial of Knox Suite supports up to 30 devices on a per-seat basis.
# </answer>
# ReRanker similarity: 0.17531609535217285
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:06.485111 secs
# prediction length: 120
# 46
# Question:  According to the information, what platform allows you to define policies and settings that get applied to registered devices?
# GroundTruth:  Knox Suite portal
# Prediction:   <answer>The Knox Admin Portal allows you to define policies and settings that get applied to registered devices.</answer>
# ReRanker similarity: 0.7755012512207031
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:18.172605 secs
# prediction length: 122
# 47
# Question:  What are the minimum OS versions supported by Knox Mobile Enrollment?
# GroundTruth:  Knox Mobile Enrollment supports Samsung devices running Android 8 and higher with Knox 3.0 and higher.
# Prediction:   <answer>The minimum OS version supported by Knox Mobile Enrollment is Android 8.</answer>
# ReRanker similarity: 0.9424912929534912
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:04.880617 secs
# prediction length: 90
# 48
# Question:  What certification does Samsung have to provide assurances around security and reliability for its Knox cloud solutions?
# GroundTruth:  SOC 2 certification
# Prediction:   <answer>Samsung cloud solutions are SOC2-certified, so you can rest assured of the smooth operation, security, and reliability of solutions in the Knox Suite.</answer>
# ReRanker similarity: 0.9599707126617432
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:18.234698 secs
# prediction length: 168
# 49
# Question:  What page do you go to on the Knox Admin Portal to assign a license key that is already in use by another Knox Suite service?
# GroundTruth:  The consolidated Licenses page.
# Prediction:   <answer>To assign an active Knox Suite license key to other services in the Knox Suite bundle, you go to the Licenses page on the Knox Admin Portal. Specifically, you:
#
# 1. On the Knox Admin Portal, go to Licenses. The consolidated Licenses page opens.
#
# 2. Click ACTIONS > Enter license key, then enter a License name and License key in the respective fields.</answer>
# ReRanker similarity: 0.4775473475456238
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:12.119780 secs
# prediction length: 369
# 50
# Question:  What are the steps for receiving a Knox customer ID?
# GroundTruth:  To acquire a Knox customer ID, you need to perform the following actions: 1) Create a Samsung account, 2) Apply for the Knox Suite trial, and 3) Once your account is approved, you will receive your Knox customer ID.
# Prediction:   <answer>
# To receive a Knox customer ID, you need to:
# 1. Create a Samsung account
# 2. Apply for Knox Suite trial
# 3. When your customer account is approved, you'll receive a customer ID
# </answer>
# ReRanker similarity: 0.9999270439147949
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:10.818526 secs
# prediction length: 193
# 51
# Question:  How does Knox Capture send data to applications, making it appear as if someone typed it manually using a keyboard?
# GroundTruth:  Knox Capture acts as a mobile solution built for compatible Android smartphones and tablets. It wedges between an application and the mobile device's on-screen keyboard, allowing end-users to trigger a barcode scan using the device's camera.
# Prediction:   <answer>
# Knox Capture sends scanned barcode data to business apps in the form of keystrokes, similar to how a user would manually type in data using a keyboard. It translates the scanned barcode data into strings and key events that are then input into the business app, making it seem to the app as if someone typed the data by hand. This allows the business app to process the barcode data without needing custom integration or barcode scanning logic built into the app itself.
# </answer>
# ReRanker similarity: 0.9133869409561157
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:08.316936 secs
# prediction length: 490
# 52
# Question:  What feature of Knox Capture allows business apps to process barcode data as if a user had typed the data from the device's keyboard?
# GroundTruth:  Knox Capture translates the barcode data into keystrokes, which then get passed back to the business app for processing.
# Prediction:   <answer>
# Knox Capture acts as a "wedge" between business apps and the mobile device's keyboard. When a barcode is scanned, Knox Capture translates the barcode data into keystrokes, which get passed to the business app. This allows the business app to process the barcode data as if a user had manually typed in the data using the keyboard.
# </answer>
# ReRanker similarity: 0.9999164342880249
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:08.565852 secs
# prediction length: 350
# 53
# Question:  What are the three primary functions available in Knox Capture's default Admin mode?
# GroundTruth:  When Knox Capture is installed on a compatible Android device and a valid license key is activated, the app operates in its default Admin mode. This mode allows the device user to do the following:
# 1. Create scanning profiles (define which apps can launch the barcode scanner, which barcode types can be scanned, and how scanned data is formatted).
# 2. Test scanning profiles (to ensure that appropriate business apps can launch the scanner and receive data back as keystrokes).
# 3. Export profile settings as a configuration file (which can then be deployed by EMM/UEM administrators on end-user devices).
# Prediction:   <answer>
# The three primary functions available in Knox Capture's default Admin mode are:
#
# 1. Create scanning profiles that define which apps can launch the barcode scanner, which barcode types can be scanned, and how scanned data is formatted.
#
# 2. Test scanning profiles to ensure that appropriate business apps can launch the scanner and receive data back as keystrokes.
#
# 3. Export profile settings as a configuration file, which can then be used by EMM/UEM administrators to deploy Knox Capture as a managed app to end-user devices.
# </answer>
# ReRanker similarity: 0.9958218336105347
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:14.246182 secs
# prediction length: 546
# 54
# Question:  How would an IT admin create a new scanning profile for Knox Capture?
# GroundTruth:  An IT admin would get started with Knox Capture by learning how to create a new scanning profile, configure scan engine settings, perform a test scan, and export the scanning configurations for deployment through an EMM/UEM.
# Prediction:   <answer>To create a new scanning profile in Knox Capture, an IT admin can do the following:
#
# 1. Tap the + button near the top of the app UI to open the profile creation options.
# 2. Select "Create profile" to start a profile from scratch, or select "Duplicate existing profile" to copy the settings from an existing (custom or default) profile.
# 3. Provide a profile name, then tap Done. The new profile will then appear in the profiles area below Default scanning profile.
#
# The IT admin can then customize the new profile's apps and activities, scan engine settings, and keystroke output rules as needed.
# </answer>
# ReRanker similarity: 0.9992876648902893
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 3/4
# mrr: 0.333
# latency: 0:00:14.715976 secs
# prediction length: 615
# 55
# Question:  What scanning profile setting defines how barcode data is formatted after each successful scan?
# GroundTruth:  Keystroke output - The scanning profile setting that defines how data is formatted after each successful scan.
# Prediction:   <answer>
# ...
# GroundTruth:  A scanner overlay is available as a feature in Knox Capture v1.5 that enables users to see scanned data entered directly into app fields. This feature works much like the full-screen scanner and appears over business apps.
# Prediction:   <answer>
# In Knox Capture v1.5, a new scanner overlay feature is available. This overlay appears as a scanner preview over business apps, and enables device users to immediately see scanned data entered into an app field.
# </answer>
# ReRanker similarity: 0.999920129776001
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:13.100332 secs
# prediction length: 231
# 129
# Question:  What type of scan engine does the new Samsung Knox Capture use?
# GroundTruth:  Samsung-developed scan engine.
# Prediction:   <answer>The new Samsung Knox Capture uses a brand new, Samsung-developed scan engine that provides the same great feature-set as the Scandit engine. New customers will see an option to select their scan engine preference - either Knox Capture or Knox Capture: Scandit Edition.</answer>
# ReRanker similarity: 0.9942018389701843
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:16.234795 secs
# prediction length: 286
# 130
# Question:  What new feature in Knox Capture version 1.7 allows for displaying an augmented reality overlay when barcodes are scanned?
# GroundTruth:  Knox Capture AR (Augmented Reality).
# Prediction:   <answer>The new feature in Knox Capture version 1.7 that allows for displaying an augmented reality overlay when barcodes are scanned is called "Knox Capture AR (Augmented Reality)". The context states: "Version 1.7 of Knox Capture introduces a new AR (augmented reality) feature that displays an overlay on the device screen whenever one or more barcodes are scanned."</answer>
# ReRanker similarity: 0.9964982271194458
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:21.647807 secs
# prediction length: 379
# 131
# Question:  What recommendations are made for customers using tiny Code 93 or Code 128 barcodes to improve barcode scan success rate with Knox Capture?
# GroundTruth:  It is recommended that customers avoid using tiny barcodes whenever possible to increase the success rate of scans. If tiny barcodes must be used, it is recommended that customers attempt to block or cover any glare on the barcodes before scanning.
# Prediction:   <answer>The context recommends that customers avoid using tiny barcodes whenver possible to increase the success rate of scans with Code 93 and Code 128 barcodes specifically.</answer>
# ReRanker similarity: 0.9955270886421204
# Langchain correctness: 0
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:21.799458 secs
# prediction length: 185
# 132
# Question:  What are the two barcode types that Knox Capture may have issues scanning if they are too small?
# GroundTruth:  Code 93 and Code 128 barcodes
#
# Could not find answer in given contexts.
# Prediction:   <answer>The context indicates that Knox Capture may have difficulties scanning Code 93 and Code 128 barcodes that are too small.</answer>
# ReRanker similarity: 0.9810247421264648
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:08.424873 secs
# prediction length: 138
# 133
# Question:  What new feature allows users to scan inverse colored barcodes?
# GroundTruth:  Inverse color barcode support
# Prediction:   <answer>The new feature that allows users to scan inverse colored barcodes is called "inverse color barcode support". This feature allows Knox Capture to scan barcodes that are colored inversely (with white bars on a dark background instead of black bars on a light background). It currently only works with Data Matrix and QR code barcodes.</answer>
# ReRanker similarity: 0.9983807802200317
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:15.371471 secs
# prediction length: 351
# 134
# Question:  What is the function of a wedge barcode scanner?
# GroundTruth:  A wedge barcode scanner is a physical device that attaches to a keyboard or a computer. It reads barcode data and translates it to a string that is then input into the system, as if a user had manually typed the string using the keyboard.
# Prediction:   <answer>A wedge barcode scanner is a physical device that attaches to a keyboard or a computer. It reads barcode data and translates it to a string that is then input into the system, as if a user had manually typed the string using the keyboard.</answer>
# ReRanker similarity: 0.999927282333374
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:13.138469 secs
# prediction length: 256
# 135
# Question:  What steps should be taken in the EMM console to disable the Verizon PTT key mapping and program the XCover key to trigger a camera scan?
# GroundTruth:  In the EMM console, open the Knox Service Plugin policies. Under Device-wide policies, set Enable device policy controls to True and under Device Key Mapping (Premium), configure the following settings: 1. Set Enable Key Mapping Controls to True, set Disable Key Mapping to All, and under XCover, set Action to Camera_Scan.
# Prediction:   <answer>
# To disable the Verizon PTT key mapping and program the XCover key to trigger a camera scan in the EMM console, you should:
#
# 1. Open the Knox Service Plugin policies in your EMM console.
# 2. Under Device-wide policies, set Enable device policy controls to True.
# 3. Under Device Key Mapping (Premium), set Enable Key Mapping Controls to True and Enable PTT/Side Key Mapping for Microsoft Teams to False.
# 4. For Package Name, enter com.samsung.android.app.smartscan.
# 5. For Intent for Key press, enter com.samsung.android.knox.intent.action.PTT_PRESS.
# 6. For Intent for Key release, enter com.samsung.android.knox.intent.action.PTT_RELEASE.
# 7. Set Enable Key Mapping to Launch & Exit applications to False.
# 8. Save and assign the configured profile to the Verizon XCover Pro devices.
# </answer>
# ReRanker similarity: 0.996593177318573
# Langchain correctness: 0
# Custom correctness: 3
# has_right_context: 1
# true_context_rank: 1/2
# mrr: 1.000
# latency: 0:00:13.040721 secs
# prediction length: 803
# 136
# Question:  What are the two resolutions and one workaround mentioned in the context for scanning barcode data into HTML fields when using Android 11 and Chromium-based browsers?
# GroundTruth:  The two resolutions for scanning barcode data into HTML fields in Chromium-based browsers are using the Advanced data formatting method and the Floating Action Button (FAB) method. Using another web browser is a workaround for this issue.
# Prediction:   <answer>
# The two resolutions mentioned for scanning barcode data into HTML fields when using Android 11 and Chromium-based browsers are:
#
# 1. Using the Advanced data formatting method - This method involves sending a Pause command before sending the barcode data to resolve the issue.
#
# 2. Using the Floating Action Button (FAB) method - This enables scanning by using a Floating Action Button instead of the hardware key.
#
# The one workaround mentioned is:
#
# 1. Using another web browser such as Mozilla Firefox that is built with a different browser engine.
# </answer>
# ReRanker similarity: 0.9999271631240845
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:12.124076 secs
# prediction length: 567
# 137
# Question:  What are the two actions that should be added to the rule screen to resolve the issue of barcode data not being sent properly from the Samsung Galaxy S21, Galaxy XCover Pro, and Galaxy Tab Active3?
# GroundTruth:  To resolve the issue of barcode data not being sent properly from the Samsung Galaxy S21, Galaxy XCover Pro, and Galaxy Tab Active3, you need to add a "Send Pause" command and a "Send remaining characters" command to the rule screen.
# Prediction:   <answer>
# The two actions that should be added to the rule screen are:
#
# 1. Send Pause
# 2. Send remaining characters
# </answer>
# ReRanker similarity: 0.9998641014099121
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:09.668121 secs
# prediction length: 124
# 138
# Question:  What might cause policy or license updates to not be applied to the Knox Capture app on a device?
# GroundTruth:  If the device is already running Knox Capture when you push policy or license updates, the changes can't be applied until the app is relaunched.
# Prediction:   <answer>
# The policy or license updates may not be applied to the Knox Capture app if the app is already running when the updates are pushed. The updates cannot be applied until the Knox Capture app is relaunched.
# </answer>
# ReRanker similarity: 0.9998853206634521
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.635959 secs
# prediction length: 223
# 139
# Question:  What policy must be enabled in the EMM to allow Knox Capture to restore focus to the text view when barcode data is incorrectly sent to a browser or web app instead of the business app?
# GroundTruth:  The Allow remote control policy must be enabled in the EMM to allow Knox Capture to restore focus to the text view when barcode data is incorrectly sent to a browser or web app instead of the business app.
# Prediction:   <answer>To handle barcode data being incorrectly sent to a browser or web app instead of the business app, you must enable the Allow remote control policy in your EMM to allow Knox Capture to restore focus to the text view. You only need to enable this policy if you've activated a Knox Platform for Enterprise Premium license.</answer>
# ReRanker similarity: 0.999927282333374
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:08.861927 secs
# prediction length: 337
# 140
# Question:  What Knox product allows you to use facial biometrics for shared devices to enable multiuser sign-in automation and increased frontline worker productivity?
# GroundTruth:  Knox Authentication Manager
# Prediction:   <answer>Knox Authentication Manager is the Knox product that allows you to use facial biometrics for shared Samsung devices. This enables multiuser sign-in automation for increased frontline worker productivity and safety.</answer>
# ReRanker similarity: 0.999270498752594
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:09.605819 secs
# prediction length: 232
# 141
# Question:  What are the three steps an organization with legacy EE licenses needs to perform before generating a Knox Suite license for their devices?
# GroundTruth:  1. Create a Samsung account and obtain Knox customer ID.2. Provide customer ID to reseller and have them upload devices3. Generate Knox Suite license for EE devices
# Prediction:   <answer>The three steps an organization with legacy EE licenses needs to perform before generating a Knox Suite license for their devices are:
#
# 1. Create a Samsung account if you don't have one.
#
# 2. Obtain a Knox customer ID if you don't have one by applying for a Knox Suite trial.
#
# 3. Provide your customer ID to the reseller that sold you your EE devices so they can upload the devices to SamsungKnox.com under your customer ID.</answer>
# ReRanker similarity: 0.9994138479232788
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:19.927077 secs
# prediction length: 442
# 142
# Question:  What are the two options if you want to add new Enterprise Edition devices instead of generating a new Knox Suite license?
# GroundTruth:  Could not find answer in given contexts.
# Prediction:   <answer>
# The two options if you want to add new Enterprise Edition devices instead of generating a new Knox Suite license are:
#
# 1. Append Enterprise Edition devices to an existing Knox Suite license. This increases the number of seats in the existing license.
#
# 2. Merge Knox Suite for Enterprise Edition licenses. This merges multiple licenses into a single license key, with a total number of seats equal to the sum of the individual licenses.
# </answer>
# ReRanker similarity: 7.647195889148861e-05
# Langchain correctness: 1
# Custom correctness: 5
# has_right_context: 1
# true_context_rank: 2/3
# mrr: 0.500
# latency: 0:00:25.440856 secs
# prediction length: 455
# 143
# Question:  What should you do before you can activate a newly generated Knox license in the Knox Admin Portal?
# GroundTruth:  You should register the newly generated license to your Knox Admin Portal.
# Prediction:   <answer>
# Before you can activate a newly generated Knox license in the Knox Admin Portal, you need to:
#
# 1. Purchase a commercial license from an authorized reseller after your trial license expires.
#
# 2. Sign into the Knox Suite portal and click Licenses > Actions > Enter license key to enter your new commercial license key.
#
# </answer>
# ReRanker similarity: 0.9933611154556274
# Langchain correctness: 0
# Custom correctness: 2
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:56.412697 secs
# prediction length: 338
# 144
# Question:  What are the steps to register for Knox Suite after you have a Samsung Knox account and access to Knox services?
# GroundTruth:  1. Sign in to SamsungKnox.com. 2. On the welcome screen that opens, click Get Started. The Knox Admin Portal opens. 3. Select Knox Suite from the list of Knox cloud solutions and click Confirm.
# Prediction:   <answer>
# The steps to register for Knox Suite after you have a Samsung Knox account and access to Knox services are:
#
# 1. Sign in to SamsungKnox.com.
# 2. On the welcome screen that opens, click Get Started. The Set up your Knox Admin Portal page opens.
# 3. Select Knox Suite from the list of Knox cloud solutions and click Confirm. The Knox Admin Portal opens.
# 4. Complete your registration for Knox Manage. In the navigation pane of the Knox Admin Portal, click Knox Manage. Confirm or fill out your details for your tenant ID in the page that opens.
# 5. Confirm registration details and click Confirm and Complete.
# </answer>
# ReRanker similarity: 0.9995599389076233
# Langchain correctness: 0
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:15.635800 secs
# prediction length: 627
# 145
# Question:  According to the steps listed, where can you confirm that the Knox Suite trial license was automatically generated and registered for you?
# GroundTruth:  In the Knox Admin Portal, you can navigate to the consolidated licenses page or the Licenses page in the dashboard of each Knox service.
# Prediction:   <answer>You can confirm that the Knox Suite trial license was automatically generated and registered for you in the following places:
#
# 1. The consolidated licenses page in the Knox Admin Portal. ("Confirm your Knox Suite license in the Knox Admin Portal
# To confirm your Knox Suite license in the Knox Admin Portal: 1. Click Licenses in the Knox Admin Portal navigation pane. The consolidated licenses page opens.")
#
# 2. The individual Licenses page in the dashboard of each Knox service. ("You can also navigate to the consolidated licenses page through the individual Licenses page in the dashboard of each Knox service.")
#
# 3. The License page in the Setting section of Knox Manage. ("Confirm your Knox Suite license on the Knox Manage console
# To confirm your license on the Knox Manage console: 1. Launch the Knox Manage console. 2. In the navigation pane, go to Setting > License. Confirm that the license key was automatically generated and registered for you.")
# </answer>
# ReRanker similarity: 0.9985023736953735
# Langchain correctness: 1
# Custom correctness: 4
# has_right_context: 1
# true_context_rank: 1/2
# mrr: 1.000
# latency: 0:00:15.141872 secs
# prediction length: 976
