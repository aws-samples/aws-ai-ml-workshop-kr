# %% [markdown]
# # Evaluation
# - For retriever
# - For generator

# %% [markdown]
# ## Setting
#  - Auto Reload
#  - path for utils

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
module_path = "../../.."
sys.path.append(os.path.abspath(module_path))

# %% [markdown]
# ## 1. Bedrock Client 생성

# %%
import json
import boto3
from pprint import pprint
from termcolor import colored
from utils import bedrock, print_ww
from utils.bedrock import bedrock_info

# %% [markdown]
# ### ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----
# - os.environ["AWS_DEFAULT_REGION"] = "<REGION_NAME>"  # E.g. "us-east-1"
# - os.environ["AWS_PROFILE"] = "<YOUR_PROFILE>"
# - os.environ["BEDROCK_ASSUME_ROLE"] = "<YOUR_ROLE_ARN>"  # E.g. "arn:aws:..."
# - os.environ["BEDROCK_ENDPOINT_URL"] = "<YOUR_ENDPOINT_URL>"  # E.g. "https://..."

# %%
boto3_bedrock = bedrock.get_bedrock_client(
    assumed_role=os.environ.get("BEDROCK_ASSUME_ROLE", None),
    endpoint_url=os.environ.get("BEDROCK_ENDPOINT_URL", None),
    region=os.environ.get("AWS_DEFAULT_REGION", None),
)

aws_region = os.environ.get("AWS_DEFAULT_REGION", None)
print (colored("\n== FM lists ==", "green"))
pprint (bedrock_info.get_list_fm_models())
# Out:
# Create new client
#   Using region: None
#   Using profile: None
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)
#
# == FM lists ==
# {'Claude-Instant-V1': 'anthropic.claude-instant-v1',
#  'Claude-V1': 'anthropic.claude-v1',
#  'Claude-V2': 'anthropic.claude-v2',
#  'Claude-V2-1': 'anthropic.claude-v2:1',
#  'Cohere-Embeddings-En': 'cohere.embed-english-v3',
#  'Cohere-Embeddings-Multilingual': 'cohere.embed-multilingual-v3',
#  'Command': 'cohere.command-text-v14',
#  'Command-Light': 'cohere.command-light-text-v14',
#  'Jurassic-2-Mid': 'ai21.j2-mid-v1',
#  'Jurassic-2-Ultra': 'ai21.j2-ultra-v1',
#  'Llama2-13b-Chat': 'meta.llama2-13b-chat-v1',
#  'Titan-Embeddings-G1': 'amazon.titan-embed-text-v1',
#  'Titan-Text-G1': 'amazon.titan-text-express-v1',
#  'Titan-Text-G1-Light': 'amazon.titan-text-lite-v1'}

# %% [markdown]
# ## 2. Titan Embedding 및 LLM 인 Claude-v2.1 모델 로딩

# %% [markdown]
# ### LLM 로딩 (Claude-v2.1)

# %%
from langchain.llms.bedrock import Bedrock
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm_text = Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-V2-1"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

llm_text_light= Bedrock(
    model_id=bedrock_info.get_model_id(model_name="Claude-Instant-V1"),
    client=boto3_bedrock,
    model_kwargs={
        "max_tokens_to_sample": 512
    },
    streaming=False,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %% [markdown]
# ### Embedding 모델 선택

# %%
from utils.rag import KoSimCSERobertaContentHandler, SagemakerEndpointEmbeddingsJumpStart
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
def get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name=None):

    if is_bedrock_embeddings:
        # We will be using the Titan Embeddings Model to generate our Embeddings.
        from langchain.embeddings import BedrockEmbeddings
        llm_emb = BedrockEmbeddings(
            client=boto3_bedrock,
            model_id=bedrock_info.get_model_id(
                model_name="Titan-Embeddings-G1"
                #model_name="Cohere-Embeddings-En"
            )
        )
        print("Bedrock Embeddings Model Loaded")

    elif is_KoSimCSERobert:
        LLMEmbHandler = KoSimCSERobertaContentHandler()
        endpoint_name_emb = endpont_name
        llm_emb = SagemakerEndpointEmbeddingsJumpStart(
            endpoint_name=endpoint_name_emb,
            region_name=aws_region,
            content_handler=LLMEmbHandler,
        )
        print("KoSimCSERobert Embeddings Model Loaded")
    else:
        llm_emb = None
        print("No Embedding Model Selected")

    return llm_emb

# %% [markdown]
# #### [중요] is_KoSimCSERobert == True 일시에 endpoint_name 을 꼭 넣어 주세요.

# %%
is_bedrock_embeddings = True
is_KoSimCSERobert = False
aws_region = os.environ.get("AWS_DEFAULT_REGION", None)

##############################
# Parameters for is_KoSimCSERobert
##############################
if is_KoSimCSERobert: endpont_name = "<endpoint-name>"
else: endpont_name = None
##############################

llm_emb = get_embedding_model(is_bedrock_embeddings, is_KoSimCSERobert, aws_region, endpont_name)
# Out:
# Bedrock Embeddings Model Loaded

# %% [markdown]
# ## 3. Depoly ReRanker model (if needed)

# %%
import json
import sagemaker
from sagemaker.huggingface import HuggingFaceModel
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
depoly = False

# %%
if depoly:

    try:
        role = sagemaker.get_execution_role()
    except ValueError:
        iam = boto3.client('iam')
        role = iam.get_role(RoleName='sagemaker_execution_role')['Role']['Arn']

    # Hub Model configuration. https://huggingface.co/models
    hub = {
        'HF_MODEL_ID':'BAAI/bge-reranker-large',
        'HF_TASK':'text-classification'
    }

    # create Hugging Face Model Class
    huggingface_model = HuggingFaceModel(
        transformers_version='4.26.0',
        pytorch_version='1.13.1',
        py_version='py39',
        env=hub,
        role=role, 
    )

    # deploy model to SageMaker Inference
    predictor = huggingface_model.deploy(
        initial_instance_count=1, # number of instances
        instance_type='ml.g5.xlarge' # instance type
    )

    print(f'Accept: {predictor.accept}')
    print(f'ContentType: {predictor.content_type}')
    print(f'Endpoint: {predictor.endpoint}')

# %% [markdown]
# ### Reranker

# %%
#endpoint_name = "huggingface-pytorch-inference-2023-11-15-07-53-21-605" # ml.g5.xlarge
endpoint_name = "ko-reranker-serve-2023-12-21-23-45-00-200"

# %%
runtime_client = boto3.Session().client('sagemaker-runtime')
print (f'runtime_client: {runtime_client}')
# Out:
# runtime_client: <botocore.client.SageMakerRuntime object at 0x7f1477813310>

# %% [markdown]
# ## 4. LangChainmOpenSearch VectorStore 정의
# ### 선수 조건
# - 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 OpenSearch Index 가 생성이 되어 있어야 합니다.
# #### [중요] 아래에 aws parameter store 에 아래 인증정보가 먼저 입력되어 있어야 합니다.
# - 01_preprocess_docs/01_parameter_store_example.ipynb 참고

# %%
from utils.proc_docs import get_parameter

# %%
ssm = boto3.client("ssm", "us-east-1")

opensearch_domain_endpoint = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_domain_endpoint',
)

opensearch_user_id = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_userid',
)

opensearch_user_password = get_parameter(
    boto3_clinet = ssm,
    parameter_name = 'knox_opensearch_password',
)

http_auth = (opensearch_user_id, opensearch_user_password) # Master username, Master password

# %% [markdown]
# ### Index 이름 셋팅
# - 이전 노트북 01_preprocess_docs/02_load_docs_opensearch.ipynb를 통해서 생성된 OpenSearch Index name 입력

# %%
index_name = "v17-genai-poc-knox-kor-eval-parent-doc-retriever"

# %% [markdown]
# ### OpenSearch Client 생성

# %%
from utils.opensearch import opensearch_utils

# %%
os_client = opensearch_utils.create_aws_opensearch_client(
    aws_region,
    opensearch_domain_endpoint,
    http_auth
)

# %% [markdown]
# ## 5. Retriever 정의

# %%
from utils.rag import OpenSearchHybridSearchRetriever

# %%
opensearch_hybrid_retriever = OpenSearchHybridSearchRetriever(
    os_client=os_client,
    index_name=index_name,
    llm_text=llm_text, # used in rag_fusion, hyde and reranker(num_tokens)
    llm_emb=llm_emb,

    # option for lexical
    minimum_should_match=0,
    filter=[],

    # option for rank fusion
    fusion_algorithm="RRF", # ["RRF", "simple_weighted"], rank fusion 방식 정의
    ensemble_weights=[.5, .5], # [for lexical, for semantic], Lexical, Semantic search 결과에 대한 최종 반영 비율 정의
    reranker=False, # enable reranker with reranker model
    reranker_endpoint_name=endpoint_name, # endpoint name for reranking model
    #rag_fusion=False, # enable rag_fusion
    #query_augmentation_size=3, # query_augmentation_size in rag_fusion

    # option for async search
    async_mode=True,

    # option for output
    k=5, # 최종 Document 수 정의
    verbose=False,
)

# %%
search_hybrid_result = opensearch_hybrid_retriever.get_relevant_documents("knox")
search_hybrid_result
# Out:
# [Document(page_content='Knox Suite에 대한 액세스 권한을 신청하세요.삼성 Knox 계정을 만들고 Knox 서비스에 액세스하면 Knox Suite에 등록할 수 있습니다. 1.SamsungKnox.com에 로그인하세요. 2.시작 화면이 열리면 시작하기를 클릭합니다.Knox 관리 포털 설정 페이지가 열립니다. 3.Knox 클라우드 솔루션 목록에서 Knox Suite를 선택하고 확인을 클릭합니다.Knox 관리 포털이 열립니다. 4.Knox Suite에 등록하는 마지막 단계는 Knox Manage 등록을 완료하는 것입니다.Knox 관리 포털의 탐색 창에서 Knox 관리를 클릭합니다.열리는 페이지에서 테넌트 ID의 세부 정보를 확인하거나 입력합니다.테넌트 ID로 Knox Manage 계정을 식별하고 직접 URL을 통해 Knox Manage에 로그인할 수 있습니다.조직이 Knox Services에 가입하지 않은 경우 조직의 도메인이 고유한 테넌트 ID를 구성합니다.조직의 도메인이 테넌트 ID 필드를 자동으로 채웠는지 확인하고 등록 완료를 클릭합니다.조직이 이미 Knox Services에 가입한 경우 테넌트를 조직의 다른 테넌트와 구별하기 위해 접두사를 정의해야 합니다.조직의 도메인이 조직 도메인 필드를 자동으로 채웠는지 확인하고 접두사 필드에 접두사를 입력합니다.테넌트 ID는 50자를 초과할 수 없습니다.등록 완료를 클릭합니다.팝업이 열리면 확인 및 완료를 클릭합니다. 5.이제 Knox Suite에 등록되었습니다.Knox Suite 액세스를 신청하면 평가판 Knox Suite 라이선스 키가 자동으로 생성됩니다.Knox 관리 포털의 라이선스 탭에서 확인할 수 있습니다.튜토리얼 진행 3단계 중 2단계를 완료했습니다!이전 다음', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 71, 'title': '녹스 스위트 이용 신청', 'url': 'https://docs.samsungknox.com/admin/knox-suite/get-started/apply-for-access-to-knox-suite', 'project': 'KS', 'last_updated': '2023-08-23', 'family_tree': 'child', 'parent_id': '6e2a94d5-d90f-4bfc-9552-54bad32f7950', 'id': 'f00b15e7-2db0-48f3-9a24-2c5dfbb58226'}),
#  Document(page_content='녹스 스위트.Knox Suite는 엔터프라이즈 모빌리티를 위한 Knox 솔루션을 번들로 제공하는 제품으로 전체 디바이스 라이프사이클 전반에 걸쳐 보안 및 관리와 관련된 조직의 요구 사항을 해결하도록 설계되었습니다.Knox Suite #Audience 에 대해 자세히 알아보십시오. 이 문서는 IT 관리자를 대상으로 합니다.Knox Suite에 포함된 기능과 Knox Suite를 사용하여 엔터프라이즈 디바이스를 관리, 보호 및 유지 관리하는 방법을 알아보세요.Knox"Suite 서비스로 다양한 작업을 수행하는 방법에 대한 정보를 어디서 찾을 수 있는지 알아보세요.Knox Suite 소개 Knox Suite는 다음과 같은 Knox 제품을 포함하는 번들 서비스입니다. Knox Platform for Enterprise - 기업용 삼성 안드로이드 폰, 태블릿 및 Tizen 시계에 군사용 수준의 보안을 제공하는 Knox 솔루션입니다.Knox 모바일 등록 - 수천 대의 삼성 디바이스를 EMM에 한 번에 등록할 수 있는 Knox 솔루션입니다.Knox Mobile Enrollment는 Knox Suite 라이선스와 함께 사용할 경우 IT 관리자에게 잠금 장치에 대한 향상된 제어와 같은 추가 기능을 제공하는 고급 프로필을 제공합니다.Knox Manage - 다양한 모바일 디바이스를 원격으로 관리할 수 있는 Knox 솔루션입니다.이 EMM을 사용하면 다양한 정책을 만들어 사용자의 디바이스 사용 방식을 제어할 수 있습니다.Knox Asset Intelligence - 운영 가시성과 실행 가능한 통찰력을 제공하여 모바일 디바이스의 관리, 생산성 및 라이프사이클을 개선하는 데이터 분석 솔루션입니다.이 솔루션은 앱 성능, 배터리 사용량, 네트워크 연결 및 자산 위치를 실시간으로 모니터링하고 관리합니다.Knox E-FOTA - Knox 솔루션을 사용하면 사용자 개입 없이 디바이스에 OS 및 보안 업데이트를 원격으로 배포할 수 있습니다', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 65, 'title': '녹스 스위트', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'child', 'parent_id': 'feb78105-259a-414b-8018-9f4fbcc09b28', 'id': '564d88b7-ab6c-447e-90ae-f31023d5358b'}),
#  Document(page_content='개별 Knox 클라우드 서비스에 가입되어 있습니다.Knox Suite로 전환하거나 업그레이드할 수 있나요?네.개별 Knox 클라우드 서비스를 사용하는 동안 Knox Suite로 업그레이드하거나 전환할 수 있습니다.삼성 Knox 리셀러로부터 Knox Suite 라이선스를 구매한 후 Knox Manage 및 Knox E-FOTA의 경우 라이선스 키를 업데이트해야 합니다.Knox 사용자 관리 - 기존 Knox Manage 라이선스 키를 구입한 새 Knox Suite 라이선스로 교체하세요.조직 또는 사용자 설정 페이지에서 Knox Suite를 선택합니다.자세한 내용은 Knox Manage 설명서의 라이선스 전환을 참조하십시오.Knox E-FOTA 사용자 - 기존 Knox E-FOTA 라이선스를 구매한 새로운 Knox Suite 라이선스로 교체하십시오.라이선스를 교체하려면 Knox 관리 포털의 통합 라이선스 관리 페이지로 이동하여 구매한 새 Knox Suite 라이선스 키를 입력하고 기존 Knox E-FOTA 라이선스 키를 선택한 다음 새 Knox Suite 라이선스 키로 교체를 선택합니다.자세한 내용은 Knox 관리 포털 설명서의 Knox 라이선스 관리를 참조하십시오.Knox Suite는 디바이스 위치 데이터를 기록하나요?네.Knox Suite의 서비스를 통해 관리되는 디바이스의 위치를 추적할 수 있습니다.Knox Manage와 Knox Asset Intelligence를 사용하면 비즈니스 과정에서 디바이스를 찾고 움직임을 분석할 수 있습니다.삼성은 Knox Suite 서비스를 통해 획득한 개인 또는 사업체 데이터를 얼마나 안전하게 처리하나요?삼성은 비즈니스 관행에서 획득한 고객 정보를 안전하게 취급하고 GDPR에서 규정한 모든 데이터 저장 및 처리 요구 사항을 충족하기 위해 최선을 다하고 있습니다.삼성은 데이터 수집이 필요한 경우에만 제한되도록 합니다.삼성 클라우드 솔루션은 SoC2 인증을 받았기 때문에 Knox Suite 솔루션의 원활한 운영, 보안, 안정성을 보장받을 수 있습니다', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 80, 'title': '개별 Knox 클라우드 서비스에 가입되어 있습니다.Knox Suite로 전환하거나 업그레이드할 수 있나요?', 'url': 'https://docs.samsungknox.com/admin/knox-suite/faq/#i-am-subscribed-individual-knox-cloud-service-can-i-switch-upgrade-knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'child', 'parent_id': '2dbd2f6f-0a9b-473a-851b-907f3bb2e19c', 'id': '810ff661-eb50-431c-9f2c-6bfc209152fc'}),
#  Document(page_content='녹스 스위트.Knox Suite는 엔터프라이즈 모빌리티를 위한 Knox 솔루션을 번들로 제공하는 제품으로 전체 디바이스 라이프사이클 전반에 걸쳐 보안 및 관리와 관련된 조직의 요구 사항을 해결하도록 설계되었습니다.Knox Suite #Audience 에 대해 자세히 알아보십시오. 이 문서는 IT 관리자를 대상으로 합니다.Knox Suite에 포함된 기능과 Knox Suite를 사용하여 엔터프라이즈 디바이스를 관리, 보호 및 유지 관리하는 방법을 알아보세요.Knox"Suite 서비스로 다양한 작업을 수행하는 방법에 대한 정보를 어디서 찾을 수 있는지 알아보세요.Knox Suite 소개 Knox Suite는 다음과 같은 Knox 제품을 포함하는 번들 서비스입니다. Knox Platform for Enterprise - 기업용 삼성 안드로이드 폰, 태블릿 및 Tizen 시계에 군사용 수준의 보안을 제공하는 Knox 솔루션입니다.Knox 모바일 등록 - 수천 대의 삼성 디바이스를 EMM에 한 번에 등록할 수 있는 Knox 솔루션입니다.Knox Mobile Enrollment는 Knox Suite 라이선스와 함께 사용할 경우 IT 관리자에게 잠금 장치에 대한 향상된 제어와 같은 추가 기능을 제공하는 고급 프로필을 제공합니다.Knox Manage - 다양한 모바일 디바이스를 원격으로 관리할 수 있는 Knox 솔루션입니다.이 EMM을 사용하면 다양한 정책을 만들어 사용자의 디바이스 사용 방식을 제어할 수 있습니다.Knox Asset Intelligence - 운영 가시성과 실행 가능한 통찰력을 제공하여 모바일 디바이스의 관리, 생산성 및 라이프사이클을 개선하는 데이터 분석 솔루션입니다.이 솔루션은 앱 성능, 배터리 사용량, 네트워크 연결 및 자산 위치를 실시간으로 모니터링하고 관리합니다.Knox E-FOTA - Knox 솔루션을 사용하면 사용자 개입 없이 디바이스에 OS 및 보안 업데이트를 원격으로 배포할 수 있습니다.Knox E-FOTA를 사용하면 캠페인을 생성하고, 캠페인 기간을 지정하고, 해당 캠페인에 디바이스를 할당하고, 캠페인 기간 동안 해당 디바이스에 푸시할 펌웨어 업데이트를 선택할 수 있습니다.Knox Capture - 사용자가 삼성 갤럭시 스마트폰과 태블릿을 강력한 바코드 스캐너로 변환하여 추가 하드웨어나 코드 한 줄 작성 없이 바코드 정보를 읽고, 처리하고, 다른 애플리케이션에 출력할 수 있게 해주는 안드로이드 솔루션입니다.Knox Authentication Manager - 공유 삼성 디바이스용 관리형 Android 앱으로, 다중 사용자 안면 생체인식 및 로그인 자동화를 제공하여 일선 작업자의 생산성과 안전을 향상시킵니다.Knox Suite를 사용하면 단일 라이선스 키로 포함된 모든 Knox 제품을 디바이스에서 사용할 수 있습니다.즉, 여러 Knox 서비스 관리 포털에서 동일한 Knox Suite 라이선스 키를 사용할 수 있습니다.녹스 스위트 1의 이점.올인원 Knox B2B 패키지 - 기업 모빌리티 여정의 모든 단계를 포괄하는 엔드투엔드 솔루션 2.간소화된 라이선스 관리 - 라이선스 키 하나만 있으면 포함된 모든 제품을 사용할 수 있습니다. 3.간소화된 온보딩 프로세스 - 한 번 등록하면 포함된 모든 Knox 제품에 액세스할 수 있습니다. 4.원활한 IT 관리자 사용자 경험 - IT 관리자는 싱글 사인온을 통해 번들로 제공되는 Knox 콘솔에 쉽게 액세스할 수 있습니다.시작하려면 여기를 클릭하세요.', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 65, 'title': '녹스 스위트', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'parent', 'parent_id': None, 'id': 'feb78105-259a-414b-8018-9f4fbcc09b28'}),
#  Document(page_content='.Knox Asset Intelligence - 운영 가시성과 실행 가능한 통찰력을 제공하여 모바일 디바이스의 관리, 생산성 및 라이프사이클을 개선하는 데이터 분석 솔루션입니다.이 솔루션은 앱 성능, 배터리 사용량, 네트워크 연결 및 자산 위치를 실시간으로 모니터링하고 관리합니다.Knox E-FOTA - Knox 솔루션을 사용하면 사용자 개입 없이 디바이스에 OS 및 보안 업데이트를 원격으로 배포할 수 있습니다.Knox E-FOTA를 사용하면 캠페인을 생성하고, 캠페인 기간을 지정하고, 해당 캠페인에 디바이스를 할당하고, 캠페인 기간 동안 해당 디바이스에 푸시할 펌웨어 업데이트를 선택할 수 있습니다.Knox Capture - 사용자가 삼성 갤럭시 스마트폰과 태블릿을 강력한 바코드 스캐너로 변환하여 추가 하드웨어나 코드 한 줄 작성 없이 바코드 정보를 읽고, 처리하고, 다른 애플리케이션에 출력할 수 있게 해주는 안드로이드 솔루션입니다.Knox Authentication Manager - 공유 삼성 디바이스용 관리형 Android 앱으로, 다중 사용자 안면 생체인식 및 로그인 자동화를 제공하여 일선 작업자의 생산성과 안전을 향상시킵니다.Knox Suite를 사용하면 단일 라이선스 키로 포함된 모든 Knox 제품을 디바이스에서 사용할 수 있습니다.즉, 여러 Knox 서비스 관리 포털에서 동일한 Knox Suite 라이선스 키를 사용할 수 있습니다.녹스 스위트 1의 이점.올인원 Knox B2B 패키지 - 기업 모빌리티 여정의 모든 단계를 포괄하는 엔드투엔드 솔루션 2.간소화된 라이선스 관리 - 라이선스 키 하나만 있으면 포함된 모든 제품을 사용할 수 있습니다. 3.간소화된 온보딩 프로세스 - 한 번 등록하면 포함된 모든 Knox 제품에 액세스할 수 있습니다. 4.원활한 IT 관리자 사용자 경험 - IT 관리자는 싱글 사인온을 통해 번들로 제공되는 Knox 콘솔에 쉽게 액세스할 수 있습니다.시작하려면 여기를 클릭하세요.', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 65, 'title': '녹스 스위트', 'url': 'https://docs.samsungknox.com/admin/knox-suite', 'project': 'KS', 'last_updated': '2023-07-26', 'family_tree': 'child', 'parent_id': 'feb78105-259a-414b-8018-9f4fbcc09b28', 'id': '600857f7-6338-448b-99cc-606947ba7079'})]

# %% [markdown]
# ## 6. RAG chain 정의

# %%
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# %% [markdown]
# ### Prompting
# - [TIP] Prompt의 instruction의 경우 한글보다 영어로 했을 때 더 좋은 결과를 얻을 수 있습니다.

# %%
from utils.rag import prompt_repo

# %%
PROMPT = prompt_repo.get_qa(prompt_type="ko_answer_only") # ["answer_only", "answer_with_ref"]

# %% [markdown]
# ### Update Search Params (Optional)

# %%
opensearch_hybrid_retriever.update_search_params(
    k=6,
    minimum_should_match=0,
    filter=[],
    reranker=True,
    reranker_endpoint_name=endpoint_name,
    rag_fusion=False, # enable rag_fusion
    query_augmentation_size=3, # query_augmentation_size in rag_fusion
    hyde=False, # enable hyde
    hyde_query=["web_search"], # query type in hyde 
    parent_document=True,
    llm_text=llm_text, # used in rag_fusion, hyde and reranker(num_tokens)
    verbose=False
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm_text,
    chain_type="stuff",
    retriever=opensearch_hybrid_retriever,
    return_source_documents=True,
    chain_type_kwargs={
        "prompt": PROMPT,
        "verbose": False,
    },
    verbose=False
)

# %%
query = "최종 사용자 입장에서 Knox Capture 기능을 사용하는 데는 어떤 제한 사항이 있나요?"
qa_chain(query)
# Out:
# {'query': '최종 사용자 입장에서 Knox Capture 기능을 사용하는 데는 어떤 제한 사항이 있나요?',
#  'result': '\n\n최종 사용자가 Knox Capture 기능을 사용하는 데는 몇 가지 제한 사항이 있습니다.\n\n1. 관리자 모드의 전체 기능을 사용할 수 없습니다. 최종 사용자는 IT 관리자가 정의한 스캔 프로필 설정 내에서만 스캔을 수행할 수 있습니다.\n\n2. 스캔 프로필을 변경하거나 구성 파일을 내보내거나 Knox Capture 라이선스를 업그레이드하여 관리자 모드로 전환할 수 없습니다.\n\n3. 특정 눈부심이나 미세한 조건에서 바코드 감지율이 낮아질 수 있습니다. 사용자는 스캔 전에 바코드의 눈부심을 차단하거나 가려보는 것이 좋습니다.\n\n4. 멀리 떨어진 여러 바코드를 동시에 스캔할 때 문제가 발생할 수 있습니다. 멀티 바코드 스캔 시에는 가능한 가깝게 다가가 스캔하는 것이 좋습니다.',
#  'source_documents': [Document(page_content='개요.Knox Capture가 무엇이고 어떻게 작동하는지 알아보고 기본 사항부터 시작해 보세요.녹스 캡처란 무엇인가요?녹스 캡처의 기능을 설명하려면 먼저 *웨지* 스캐너가 무엇인지, 그리고 이 스캐너가 Knox Capture 솔루션과 어떤 관련이 있는지 이해하는 것부터 시작하는 것이 도움이 될 수 있습니다.기존의 하드웨어 기반 바코드 스캔 용어로 웨지 스캐너는 키보드와 컴퓨터 사이에 연결하는 물리적 장치입니다.키보드는 스캐너에 연결되고 스캐너는 컴퓨터에 연결됩니다.컴퓨터의 관점에서 보면 스캐너는 마치 추가 키보드처럼 작동합니다.컴퓨터에서 소프트웨어 프로그램 (예: 인벤토리 스프레드시트 앱) 을 실행하고 웨지 스캐너를 사용하여 바코드를 읽으면 키 입력 형태로 스캐너에서 프로그램으로 데이터가 전송됩니다.프로그램의 관점에서 보면 데이터는 마치 누군가가 키보드를 사용하여 수동으로 입력한 것처럼 보입니다.Knox Capture 작동 방식 비슷한 방식으로 Knox Capture는 소프트웨어 프로그램과 키보드 사이의 쐐기 역할을 하기도 합니다.하지만 Knox Capture는 물리적 스캔 디바이스가 아니라 호환되는 Android 스마트폰 및 태블릿용으로 설계된 모바일 솔루션입니다.기업 IT 관리자는 Google Play에서 Knox Capture 앱을 다운로드하거나 Knox Capture SDK (소프트웨어 개발 키트) 를 사용하여 자체 웨지 스캐너 앱을 맞춤 구축할 수 있습니다.Knox Capture가 디바이스에 설치되고 실행되면 애플리케이션 (예: 인벤토리 추적에 사용되는 비즈니스 앱) 과 모바일 디바이스의 온스크린 키보드 사이에서*쐐기*를 이룹니다.최종 사용자가 비즈니스 앱을 실행할 때 화면 버튼을 탭하거나 디바이스의 하드웨어 버튼을 누르기만 하면 디바이스의 카메라를 사용하여 바코드 스캔을 실행할 수 있습니다.카메라가 바코드에 초점을 맞춘 후 Knox Capture는 바코드 데이터를 키 입력으로 변환한 다음 이를 비즈니스 앱으로 다시 전달하여 처리합니다.비즈니스 앱의 관점에서 보면 Knox Capture에서 발생하는 키 입력은 마치 사용자가 디바이스 키보드에서 키를 입력한 것처럼 보입니다.누가 녹스 캡처를 사용할 수 있나요?Knox Capture는 모바일 디바이스를 강력한 바코드 스캐너로 전환하고자 하는 모든 사용자를 위해 설계되었습니다.하지만 관리자가 사용하는지, 최종 사용자가 사용하는지에 따라 기능이 크게 달라집니다.#Admin 모드 (기본값) Google Play에서 Knox Capture를 다운로드하여 호환되는 Android 디바이스에 설치하고 유효한 라이선스 키를 활성화하면 앱이 기본 관리자 모드로 작동합니다.이 모드에서는 기기 사용자 (일반적으로 기업 IT 관리자) 가 앱의 전체 기능을 활용하여 주로 다음과 같은 작업을 수행할 수 있습니다. 1.바코드 스캐너를 실행할 수 있는 앱, 스캔할 수 있는 바코드 유형 (QR, Code 128, EAN8 등), 스캔한 데이터의 형식 지정 방법 (Tab 또는 Enter 키 추가, 데이터 앞이나 뒤에 특수 문자 삽입 등) 을 정의하는 스캔 프로필을 만드세요. 2.스캔 프로필을 테스트하여 적절한 비즈니스 앱이 스캐너를 실행하고 키 입력으로 데이터를 다시 받을 수 있는지 확인하십시오. 3.프로필 설정을 구성 파일로 내보낸 다음 EMM/UEM 관리자가 Knox Capture를 관리형 앱으로 최종 사용자 디바이스에 배포하는 데 사용할 수 있습니다.#Managed 모드 IT 관리자가 EMM/UEM을 사용하여 Knox Capture를 최종 사용자의 디바이스에 관리형 앱으로 배포한 후 디바이스는 관리 모드에서 앱을 시작합니다.관리 모드에서는 Knox Capture 기능이 크게 줄어듭니다.최종 사용자는 스캔 프로필에서 허용하는 대로 비즈니스 앱을 사용하여 스캔 프로필 설정을 검토하고 바코드 스캔을 수행할 수 있지만 스캔 프로필을 변경하거나 프로필 설정을 내보내거나 Knox Capture 라이선스를 활성화하여 관리자 모드로 전환할 수는 없습니다.관리자 모드는 Knox Capture의 기본 작동 모드입니다.이 가이드에 설명된 절차는 IT 관리자를 대상으로 합니다.더 읽어보기 #Getting started 튜토리얼 이 튜토리얼은 신규 관리자와 최종 사용자를 위한 가이드 워크플로우를 제공합니다.Knox Capture를 사용하는 모든 설정이나 시나리오를 다루지는 않지만 앱의 기본 사항을 배우기 위한 좋은 출발점이 될 수 있습니다.IT 관리자: Knox Capture 시작하기 - IT 관리자로서 새 스캔 프로필을 생성하고, 스캔 엔진 설정을 구성하고, 테스트 스캔을 수행하고, EMM/UEM을 통해 배포할 스캔 구성을 내보내는 방법을 알아보세요.최종 사용자: Knox Capture 시작하기 - 디바이스 최종 사용자로서 비즈니스 앱에서 스캔 프로필 설정을 검토하고, 하드웨어 키 설정을 구성하고, 바코드 스캔을 수행하는 방법을 알아봅니다.#How -to 주제 주요 Knox Capture 기능에 대한 자세한 설명과 자세한 설명을 보려면 다음 사용 방법 항목을 참조하십시오. 자세한 내용은 라이선스 관리 - Knox Capture 라이선스 절차에 대해 알아보고 앱에서 Knox Capture와 Knox Capture: Scandit Edition 라이선스 간에 전환하는 방법에 대해 알아보세요.스캔 프로필 - 프로필의 작동 방식, 기본 프로필의 기능, 다양한 스캔 시나리오에 맞게 새 프로필을 만드는 방법을 알아보세요.앱 및 활동 - 카메라 스캐너를 실행할 수 있는 비즈니스 앱을 정의하는 모든 스캔 프로필의 구성 요소입니다.앱과 활동의 작동 방식과 스캔 프로필에서 앱과 활동을 사용자 지정하는 방법을 알아보세요.스캔 엔진 설정 - 이 설정은 바코드 스캔 방법과 각 스캔 후 데이터에 어떤 일이 발생하는지 정의합니다.바코드 유형 설정, 스캔 모드 변경, 뷰파인더 크기 제어 등에 대해 알아보십시오.키스트로크 출력 - 스캔에 성공할 때마다 데이터를 포맷하는 방법을 정의하는 스캔 프로파일 설정입니다.스캔한 데이터에 특수 문자를 추가하거나 앞에 특수 문자를 추가하는 방법 또는 스프레드시트와 양식에서 쉽게 처리할 수 있도록 각 바코드 끝에 ASCII 탭과 Enter 키를 삽입하는 방법을 알아봅니다.테스트 모드 - 배포를 위해 구성을 내보내기 전에 스캔 프로필의 앱, 바코드 유형 및 키 입력 출력 규칙을 테스트할 수 있는 기능입니다.EMM/UEM에 구성 배포 - 다양한 스캔 프로필 내보내기 옵션과 EMM/UEM에서 내보낸 구성 파일을 사용하여 Knox Capture를 최종 사용자에게 배포하는 방법에 대해 알아봅니다.카메라 스캔 트리거 설정 - IT 관리자가 사용자가 기기의 하드웨어 버튼을 사용할지, 화면상의 플로팅 액션 버튼을 사용하여 카메라 스캔을 트리거할 수 있는지 또는 둘 다를 사용하여 카메라 스캔을 트리거할 수 있는지 지정할 수 있는 기능입니다.다양한 버튼 옵션에 대해 알아보고 관리자와 최종 사용자의 관점에서 트리거를 구성하는 방법을 알아보세요.하드웨어 스캐너 연결 - 일부 기업은 Knox Capture와 함께 기존 하드웨어 웨지 스캐너를 사용하고자 할 수 있습니다.Bluetooth 및 USB 스캐너를 Knox Capture를 실행하는 디바이스에 연결하는 방법과 스캐너가 연결된 후 테스트 스캔을 수행하는 방법을 알아보세요.출력 경로 구성 - 일부 조직에서는 스캔한 Knox Capture 데이터를 PC에 연결된 블루투스 키보드로 전송하여 기존 하드웨어 스캐너의 기능을 에뮬레이션하고자 할 수 있습니다.출력 경로의 작동 방식, 디바이스와 블루투스 키보드를 페어링 및 페어링 해제하는 방법을 알아보세요.Knox Capture AR - Knox Capture v1.7에 도입된 기능으로 바코드 스캔 중에 카메라 미리 보기 창 내에 중요한 제품 정보를 제공합니다.Knox Capture의 AR (증강 현실) 이 무엇인지, AR 템플릿을 만드는 방법, 바코드 스캔을 수행할 때 AR을 사용하는 방법을 알아보세요.', metadata={'source': 'all_process ...
#   Document(page_content='녹스 캡처 v1.8 릴리스 노트.새로운 기능 Knox Capture v1.8에는 다음과 같은 새로운 기능이 도입되었습니다. #Continuous 단일 스캔 스캔 스캔 엔진 설정 > 단일 스캔 기본 설정 화면에 새로운 연속 스캔 옵션이 나타납니다.이 옵션을 켜면 기기 사용자는 스캔 사이에 카메라 트리거 버튼을 누르지 않고도 여러 바코드를 순차적으로 스캔하고 각 스캔을 단일 이벤트로 등록할 수 있습니다.연속 스캔 기능에 대해 자세히 알아보려면 단일 스캔 기본 설정을 참조하십시오.#Scanner 오버레이 이번 릴리스에서는 기기 사용자가 비즈니스 앱 상단의 카메라 미리 보기 창을 오버레이로 볼 수 있는 옵션이 제공됩니다.스캐너 오버레이 기능이 활성화되고 스캔이 트리거되면 사용자는 기존 비즈니스 앱 화면 상단에 미니 카메라 미리 보기 창을 보게 됩니다.이 새로운 기능에 대해 자세히 알아보려면 스캐너 오버레이를 참조하십시오.#Inverse 컬러 바코드 지원 이번 릴리스에는 사용자가 역 컬러 바코드를 스캔할 수 있는 새로운 Performance Lab 기능이 추가되었습니다.이 기능은 이번 릴리스의 데이터 매트릭스 및 QR 유형 바코드에서만 작동합니다.이 옵션을 활성화하려면 Knox Capture 메인 화면으로 이동한 다음 옵션 버튼 (점 3개) 을 탭하고 성능 연구소를 탭한 다음 반전 색상 인식을 활성화하세요.개선 사항 Knox Capture v1.8에는 다음과 같은 기존 기능 개선 사항이 포함되어 있습니다. #More USB 장치 연결 시 직관적인 사용자 프롬프트 표시 이전에는 Knox Capture가 포그라운드에서 실행되지 않아도 사용자에게 프롬프트가 표시되곤 했습니다.예를 들어, 사용자는 업무용으로 사용하기 위해 USB 키보드를 연결하고자 할 수 있습니다.키보드를 연결하면 당시에는 Knox Capture를 사용하지 않았더라도 스캔 용도로 USB 키보드를 사용할지 묻는 메시지가 표시됩니다.이번 릴리스는 Knox Capture가 포그라운드에서 사용되는 경우에만 표시되도록 프롬프트를 개선했습니다.프롬프트를 표시하려면 디바이스 사용자가 연결된 디바이스에 대한 시스템 권한을 부여해야 합니다.권한이 부여되지 않으면 어떤 화면에도 프롬프트가 표시되지 않습니다.#Seamlessly 출력 경로에서 페어링된 여러 디바이스 간 전환 사용자가 Knox Capture의 출력 경로에 있는 여러 디바이스와 페어링된 경우 이제 페어링된 각 디바이스 사이를 더 쉽게 전환할 수 있습니다.이전에는 출력 경로에 두 개의 페어링된 디바이스가 있고 Knox Capture가 _device A_에 연결된 경우 사용자는 _device B_에 연결하기 전에 먼저 _device A_와의 연결을 끊어야 했습니다.이번 릴리스에서는 사용자가 _device B_에 연결하기만 하면 됩니다.Knox Capture는 이전에 페어링된 모든 디바이스와의 연결을 자동으로 끊습니다.#Receive IT 관리자가 오버레이를 제한할 때 알림 일부 기기 사용자는 스캔을 트리거한 후 카메라 미리보기 창을 볼 수 없는 문제가 발생할 수 있습니다.이 문제는 IT 관리자가 설정한 제한과 조직의 UEM 정책으로 인해 발생할 수 있습니다.이전에는 제한을 설정하면 사용자가 단순히 미리 보기 창을 볼 수 없었습니다.이번 릴리스에서 사용자는 이제 IT 관리자에게 자세한 내용을 문의하라는 알림을 받게 됩니다.제한 사항에 대해 자세히 알아보려면 이 문제와 관련된 Knox Capture 기술 자료 문서 (KBA) 를 참조하십시오.릴리스 노트로 돌아가기', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 35, 'title': '녹스 캡처 v1.8 릴리즈 노트', 'url': 'https://docs.samsungknox.com/admin/knox-capture/release-notes/v1-8', 'project': 'KCAP', 'last_updated': '2023-07-26', 'family_tree': 'parent', 'parent_id': None}),
#   Document(page_content='녹스 캡처 v1.9 릴리즈 노트새로운 기능 Knox Capture v1.9에는 다음과 같은 새로운 기능이 도입되었습니다. AR 데모 모드용 #Support 이제 실제 서버를 설정하거나 프로필 생성 또는 설정 프로세스를 거치지 않고도 Knox Capture AR 기능을 테스트할 수 있습니다.이 새로운 기능에 대해 자세히 알아보려면 데모 AR 가이드를 참조하십시오.스캔 성공률을 높이기 위한 #On -스크린 제안 바코드 스캔의 성공률을 높이기 위해 Knox Capture는 이제 디바이스가 바코드와 너무 멀리 떨어져 있거나 바코드를 쉽게 읽을 수 없는 각도에 있을 때 최종 사용자에게 이를 알려주는 제안을 화면에 제공합니다.#Ability 기본적으로 손전등 켜기 이제 스캔 엔진 설정에서 세 가지 손전등 옵션 (끄기/켜기/자동) 중에서 선택할 수 있어 장치 사용자가 모든 조명 조건에서 더 쉽게 작업할 수 있습니다.이러한 손전등 옵션에 대한 자세한 내용은 스캔 엔진 설정 구성을 참조하십시오.Knox Capture: Scandit Edition은 손전등 옵션으로 켜기/끄기만 지원합니다.#Official 모든 바코드 유형에서 반전 색상 인식을 지원합니다. Knox Capture v1.8에서는 DataMatrix 및 QR 바코드 유형에 대한 역 색상 인식을 도입했습니다.이번 릴리스에서 사용자는 이제 사용 가능한 모든 바코드 유형에서 반전 색상 바코드를 스캔할 수 있습니다.이 기능을 사용하는 방법을 알아보려면 스캔 엔진 설정 구성을 참조하십시오.#Support for QR 코드 라이선스 스캔 최종 사용자의 라이선스 활성화 워크플로의 속도를 높이기 위해 이제 Knox Suite 라이선스를 QR 코드로 생성한 다음 최종 사용자가 QR 코드를 스캔하여 앱에 라이선스 키를 자동으로 입력하도록 할 수 있습니다.Knox Capture는 사용자를 위해 QR 코드를 생성하지 않습니다.#Knox Capture SDK v1.1.0 이번 Knox Capture v1.9 릴리스에는 자체 맞춤형 스캔 애플리케이션을 개발하려는 고객을 위해 새로운 버전의 녹스 캡처 SDK도 도입되었습니다.SDK v1.1.0은 새로운 미니 스캐너 API를 도입하고 사용 가능한 모든 바코드 유형에서 역 색상 바코드 인식에 대한 지원을 추가합니다.Knox Capture SDK에 대해 자세히 알아보려면 개발자 설명서를 참조하십시오.개선 사항 이번 릴리스에서는 다음과 같은 기능 개선 사항이 도입되었습니다. #Updated UI for Aim and scan 기능 이제 Aim and scan 기능을 사용할 때 바코드가 감지되면 뚜렷한 파란색 선이 표시되고 바코드가 감지되지 않으면 흰색 선이 표시됩니다.이전에는 바코드 감지 전후에 사용자에게 흰색 선이 표시되었습니다.#Improved 지원 메뉴 이제 앱의 지원 메뉴에서 버튼을 눌러 Knox 영업 담당자에게 빠르게 연락할 수 있습니다.릴리스 노트로 돌아가기', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 36, 'title': '녹스 캡처 v1.9 릴리즈 노트', 'url': 'https://docs.samsungknox.com/admin/knox-capture/release-notes/v1-9', 'project': 'KCAP', 'last_updated': '2023-10-16', 'family_tree': 'parent', 'parent_id': None}),
#   Document(page_content='녹스 캡처 v1.7 릴리즈 노트삼성 Knox Capture의 새로운 기능 #Launch Knox Capture v1.7에 추가된 가장 중요한 사항은 삼성에서 개발한 새로운 스캔 엔진의 출시입니다. 이 엔진은 Scandit 엔진과 동일한 뛰어난 기능 세트를 제공하는 동시에 삼성이 향후 릴리스에서 고객에게 흥미진진한 업계 최고의 기능을 제공할 수 있는 기반을 마련합니다.신규 고객은 앱을 처음 실행하고 Knox Capture 파트너 계약을 수락할 때 선호하는 스캔 엔진 (Knox Capture 또는 Knox Capture: Scandit Edition) 을 선택할 수 있는 옵션을 보게 됩니다.신규 고객은 평가 기간 동안 Knox Capture의 기능을 테스트하고 최대 100회의 무료 스캔을 수행할 수 있으며, 그 이후에는 상업적 사용을 위해 유효한 Knox Suite 라이선스가 필요합니다.새로운 Knox Suite 라이선스 요구 사항에 대해 자세히 알아보려면 Knox Capture 라이선스 관리를 참조하십시오.#Knox Capture SDK 이번 릴리스에는 안드로이드 앱 개발자가 자체 바코드 스캔 애플리케이션을 만들 수 있는 완전히 새로운 Knox Capture SDK가 도입되었습니다.Knox Capture SDK에 대해 자세히 알아보려면 개발자 설명서 사이트를 방문하십시오. #Knox Knox Capture의 Capture AR (증강 현실) 버전 1.7에는 하나 이상의 바코드가 스캔될 때마다 디바이스 화면에 오버레이를 표시하는 새로운 AR (증강 현실) 기능이 도입되었습니다.IT 관리자는 AR 템플릿을 만들어 오버레이에 표시되는 정보와 오버레이 동작을 사용자 지정할 수 있습니다.이 흥미로운 새 기능을 시작하려면 Knox Capture AR 가이드에서 자세한 내용을 살펴보세요.#Low 라이트 스캔 알림 저조도 환경에서 카메라를 사용하여 바코드를 스캔할 때 이제 캡처 미리보기 창에 알림이 표시되어 더 나은 스캔 결과를 위해 카메라 플래시를 활성화하라는 메시지가 표시됩니다.이 알림은 기본적으로 활성화되어 있지만 Knox Capture 설정 > 성능 연구소 > 스캐너 토스트 알림으로 이동하여 끌 수 있습니다.#Vibrate -스캔 성공 후 알림 이제 IT 관리자는 바코드 스캔이 성공할 때마다 디바이스를 진동시키도록 Knox Capture를 구성할 수 있습니다.이 동작은 기본적으로 비활성화되어 있지만 프로필의 스캔 엔진 설정 > 스캔 후 진동으로 이동하여 활성화할 수 있습니다.개선 사항 #Output 경로는 페어링된 디바이스 목록을 정확하게 표시합니다. 디바이스를 Bluetooth 웨지 스캐너로 사용하여 PC 또는 호스트 컴퓨터에 연결하는 고객의 경우 이제 Knox Capture는 Bluetooth 웨지 슬라이더 사용이 활성화된 경우에만 페어링된 디바이스 목록을 표시합니다.이전에는 Bluetooth 장치가 페어링되어 있고 슬라이더가 OFF 위치에 있으면 페어링된 장치 목록에 연결이 끊긴 장치 목록이 계속 표시되었습니다.이제 슬라이더가 ON 위치에 있는 경우에만 목록에 페어링된 장치 (연결됨 또는 연결 해제됨) 가 표시됩니다.알려진 문제 #Possible 특정 눈부심이나 미세한 조건에서 바코드 감지율이 낮을 경우 Knox Capture가 극도의 눈부심 조건에서 모든 바코드를 감지하는 데 어려움을 겪을 수 있다고 테스터들은 보고했습니다.사용자는 스캔하기 전에 바코드의 눈부심을 차단하거나 가려보는 것이 좋습니다.특히 코드 93 및 코드 128 바코드를 사용하는 고객의 경우 Knox Capture는 너무 작은 바코드를 스캔하는 데 어려움을 겪을 수 있습니다.고객은 스캔 성공률을 높이기 위해 가능하면 작은 바코드를 사용하지 않는 것이 좋습니다.#Possible 원거리에서 멀티스캔을 사용하는 데 따르는 어려움 테스터들은 16cm (6인치) 이상의 범위에서 여러 바코드 기술을 동시에 스캔하려고 할 때 몇 가지 어려움을 겪는다고 보고했습니다.멀티스캔을 사용할 때는 사용자가 바코드에 더 가까이 다가가는 것이 좋습니다.릴리스 노트로 돌아가기', metadata={'source': 'all_processed_data_ko.json', 'seq_num': 34, 'title': '녹스 캡처 v1.7 릴리즈 노트', 'url': 'https://docs.samsungknox.com/admin/knox-capture/release-notes/v1-7', 'project': 'KCAP', 'last_updated': '2023-07-26', 'family_tree': 'parent', 'parent_id': None})]}

# %% [markdown]
# ## 3.Evaluation
#  - [langchain evaluator](https://python.langchain.com/docs/guides/evaluation/string/criteria_eval_chain)

# %% [markdown]
# ### Load ground truth

# %%
import pandas as pd

# %%
ground_thruth = pd.read_csv("eval_dataset_v17.csv")

# %%
import time
import datetime
from langchain.evaluation import Criteria
from langchain.evaluation import EvaluatorType
from langchain.evaluation import load_evaluator

# %%
Criteria.CORRECTNESS
# Out:
# <Criteria.CORRECTNESS: 'correctness'>

# %%
list(Criteria)
# Out:
# [<Criteria.CONCISENESS: 'conciseness'>,
#  <Criteria.RELEVANCE: 'relevance'>,
#  <Criteria.CORRECTNESS: 'correctness'>,
#  <Criteria.COHERENCE: 'coherence'>,
#  <Criteria.HARMFULNESS: 'harmfulness'>,
#  <Criteria.MALICIOUSNESS: 'maliciousness'>,
#  <Criteria.HELPFULNESS: 'helpfulness'>,
#  <Criteria.CONTROVERSIALITY: 'controversiality'>,
#  <Criteria.MISOGYNY: 'misogyny'>,
#  <Criteria.CRIMINALITY: 'criminality'>,
#  <Criteria.INSENSITIVITY: 'insensitivity'>,
#  <Criteria.DEPTH: 'depth'>,
#  <Criteria.CREATIVITY: 'creativity'>,
#  <Criteria.DETAIL: 'detail'>]

# %%
langchain_evaluator = load_evaluator(
    EvaluatorType.LABELED_CRITERIA,
    llm=llm_text,
    criteria=Criteria.CORRECTNESS
)

# %% [markdown]
# ### Check prompt for evaluation

# %%
print(langchain_evaluator.prompt.partial_variables)
print("==")
print(langchain_evaluator.prompt.template)
# Out:
# {'criteria': 'correctness: Is the submission correct, accurate, and factual?'}
# ==
# You are assessing a submitted answer on a given task or input based on a set of criteria. Here is the data:
# [BEGIN DATA]
# ***
# [Input]: {input}
# ***
# [Submission]: {output}
# ***
# [Criteria]: {criteria}
# ***
# [Reference]: {reference}
# ***
# [END DATA]
# Does the submission meet the Criteria? First, write out in a step by step manner your reasoning about each criterion to be sure that your conclusion is correct. Avoid simply stating the correct answers at the outset. Then print only the single character "Y" or "N" (without quotes or punctuation) on its own line corresponding to the correct answer of whether the submission meets all criteria. At the end, repeat just the letter again by itself on a new line.

# %% [markdown]
# ### [Optional] Custon evaluator

# %%
from langchain.schema.output_parser import StrOutputParser

# %%
EVAL_TEMPLATE = """
\n\nHuman: 
Your job is to rate the accuracy of a generated answer given a query and a reference answer.

Here is query: <query>{query}</query>
Here is generated answer: <generated_answer>{generated_answer}</generated_answer>
Here is reference answer: <reference_answer>{reference_answer}</reference_answer>

Then answer the quality of a generated answer as scores starting with "Score:".
Your score has to be between 1 and 5.
You must return your response in a line with only the score.
Do not return answers in any other format.

\n\nAssistant:
"""

prompt_template_eval = PromptTemplate(
    template=EVAL_TEMPLATE, input_variables=["query", "generated_answer", "reference_answer"]
)

question = "What is the default mode of operation for Knox Capture?"
answer="Admin mode is the default mode of operation for Knox Capture. Therefore, a user cannot switch to Admin mode by activating a Knox Capture license, the app is exported in admin mode"
prediction = "The default mode of operation for Knox Capture is Admin mode."


custom_evaluator = prompt_template_eval | llm_text | StrOutputParser()

# %%
ground_thruth.head()
# Out:
#                                             question  \
# 0  최종 사용자 입장에서 Knox Capture 기능을 사용하는 데는 어떤 제한 사항이...
# 1                앱에서 지원에 액세스하기 위해 누르는 메뉴 아이콘은 무엇인가요?
# 2        스캔 프로필 설정에서 문자 추가 옵션을 활성화하려면 어떤 단계들이 필요한가요?
# 3           Knox Capture 구성 데이터에는 어떤 키와 값이 포함되어 있나요?
# 4   스캐너 연결 화면에서 어떤 아이콘을 탭하여 페어링된 USB 스캐너를 제거할 수 있나요?
#
#                                               answer  \
# 0  최종 사용자가 Knox Capture 기능을 사용하는 데는 IT 관리자가 정의한 스...
# 1             프로필 목록 레이블 오른쪽에 있는 추가 작업 메뉴 아이콘을 누릅니다.
# 2  스캔 프로필 설정에서 문자 추가 옵션을 활성화하려면 아래 단계들이 필요합니다.\n1...
# 3  Knox Capture 구성 데이터에는 smartscan_license 키에 Kno...
# 4  스캐너 옆에 있는 톱니바퀴 아이콘을 탭하여 페어링된 USB 스캐너를 제거할 수 있습...
#
#                                  doc_id  \
# 0  72e988a4-630c-4ccf-be58-1ef4f558188f
# 1  0e7b9978-0cf9-4be5-9971-1f8742a1cece
# 2  7963a938-f370-4766-ae61-56ea2e8b7344
# 3  323a0ce8-38cc-4c9e-aaca-b5fcbbc37540
# 4  0b4f6a3c-c963-4c14-a905-026c169c0044
#
#                                                  doc
# 0  .최종 사용자가 비즈니스 앱을 실행할 때 화면 버튼을 탭하거나 디바이스의 하드웨어 ...
# 1  문제 해결.앱에서 지원에 액세스하세요. 내에서 지원에 액세스하려면 프로필 목록 레이...
# 2  .스캔 엔진 설정을 변경하려면: 1.바코드 유형을 탭한 다음 아래로 스크롤하여 선택...
# 3  .하지만 녹스 캡처 평가판을 사용하는 경우 Knox Suite 라이선스 키도 푸시해...
# 4  . 3.페어링된 USB 스캐너를 제거하려면 스캐너 연결 화면에서 연결된 장치로 이동...

# %%
# %%time
evaluation = []
parent_document_index = True
for idx, row in enumerate(ground_thruth.itertuples()):
    try:
        question, answer, doc, doc_id = getattr(row, "question"), getattr(row, "answer"), getattr(row, "doc"), getattr(row, "doc_id")

        start = time.time()
        response = qa_chain(question)
        elapsed = time.time() - start

        prediction = response["result"]
        retrieved_docs = {doc.page_content: idx+1 for idx, doc in enumerate(response["source_documents"])}
        contexts = "\n\n".join(retrieved_docs.keys())

        payload = json.dumps(
            {
                "inputs": [
                    {"text": answer, "text_pair": prediction},
                ]
            }
        )

        response = runtime_client.invoke_endpoint(
            EndpointName=endpoint_name,
            ContentType="application/json",
            Accept="application/json",
            Body=payload
        )
        out = json.loads(response['Body'].read().decode()) ## for json

        eval_result_langchain = langchain_evaluator.evaluate_strings(
            input=question,
            prediction=prediction,
            reference=answer,
        )
        # eval_result_custom = custom_evaluator.invoke(
        #     {
        #         "query": question,
        #         "generated_answer": prediction,
        #         "reference_answer": answer
        #     }
        # )
        
        reranker_sim = out[0]["score"]
        langchain_correctness = eval_result_langchain["score"]
        #custom_correctness = int(eval_result_custom.split("\n")[0].strip().split("Score: ")[1])
        custom_correctness = 0
        
        if not parent_document_index:
            if doc in retrieved_docs:
                true_context_rank = retrieved_docs[doc]
                has_right_context = 1
                mrr = 1/true_context_rank
            else:
                true_context_rank = has_right_context = 0
                mrr = 0
        else:
            for retrieved_doc in retrieved_docs:
                
                if doc in retrieved_doc:
                    true_context_rank = retrieved_docs[retrieved_doc]
                    has_right_context = 1
                    mrr = 1/true_context_rank
                    break
                else:
                    true_context_rank = has_right_context = 0
                    mrr = 0

        total_contexts = len(retrieved_docs)
        latency = datetime.timedelta(seconds=elapsed)

        print(idx)
        print(colored("Question: ", "red"), colored(question, "red"))
        print(colored("GroundTruth: ", "green"), colored(answer, "green"))
        print(colored("Prediction: ", "blue"), colored(prediction, "blue"))
        print(f'ReRanker similarity: {reranker_sim}')
        print(f'Langchain correctness: {langchain_correctness}')
        print(f'Custom correctness: {custom_correctness}')
        print(f'has_right_context: {has_right_context}')
        print(f'true_context_rank: {true_context_rank}/{total_contexts}')
        print(f'mrr: {mrr:.3f}')
        print(f'latency: {latency} secs')
        print(f'prediction length: {len(prediction)}')

        evaluation.append([question, answer, prediction, \
                           has_right_context, true_context_rank, total_contexts, mrr, \
                           reranker_sim, langchain_correctness, custom_correctness, elapsed, contexts, len(prediction)])
    except:
        print ("err", idx)

eval_results = pd.DataFrame(
    evaluation,
    columns=["question", "true_answer", "prediction", \
             "has_right_context", "true_context_rank", "total_contexts", "mrr", \
             "reranker_sim", "langchain_correctness", "custom_correctness", "latency", "contexts", "pred_length"]
)
eval_results.to_csv("eval_results_hybrid_reranker_g3_b1_gas32_final.csv", index=False)
#eval_results.to_pickle("eval_results.pkl")
# Out:
# 0
# Question:  최종 사용자 입장에서 Knox Capture 기능을 사용하는 데는 어떤 제한 사항이 있나요?
# GroundTruth:  최종 사용자가 Knox Capture 기능을 사용하는 데는 IT 관리자가 정의한 스캔 프로필에 따라 기능이 제한됩니다. 관리 모드에서는 앱 기능이 크게 줄어듭니다.
# Prediction:
#
# 관리자가 Knox Capture를 EMM/UEM을 사용하여 최종 사용자의 디바이스에 관리형 앱으로 배포한 경우 디바이스는 관리 모드에서 앱을 시작합니다.
#
# 관리 모드에서 Knox Capture 기능이 크게 줄어듭니다. 최종 사용자는 스캔 프로필에서 허용하는 대로 비즈니스 앱을 사용하여 스캔 프로필 설정을 검토하고 바코드 스캔을 수행할 수 있지만 스캔 프로필을 변경하거나 프로필 설정을 내보내거나 Knox Capture 라이선스를 활성화하여 관리자 모드로 전환할 수는 없습니다.
#
# 따라서 최종 사용자는 IT 관리자가 정의한 스캔 프로필 내에서만 Knox Capture를 사용할 수 있으며, 프로필 설정을 변경하거나 관리 모드에서 벗어날 수 없습니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:22.668162 secs
# prediction length: 366
# 1
# Question:  앱에서 지원에 액세스하기 위해 누르는 메뉴 아이콘은 무엇인가요?
# GroundTruth:  프로필 목록 레이블 오른쪽에 있는 추가 작업 메뉴 아이콘을 누릅니다.
# Prediction:
#
# 프로필 목록 레이블 오른쪽에 있는 추가 작업 메뉴 아이콘을 누릅니다.
# ReRanker similarity: 0.9999496936798096
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:13.038003 secs
# prediction length: 40
# 2
# Question:  스캔 프로필 설정에서 문자 추가 옵션을 활성화하려면 어떤 단계들이 필요한가요?
# GroundTruth:  스캔 프로필 설정에서 문자 추가 옵션을 활성화하려면 아래 단계들이 필요합니다.
# 1. 기본 데이터 포맷팅으로 이동합니다.
# 2. 옵션을 확장합니다.
# 3. 슬라이더를 오른쪽으로 이동하여 문자 추가 옵션을 활성화합니다.
# Prediction:   To enable the Add character option in the scan profile settings, you need to follow these steps:
#
# 1. 목록에서 기본 데이터 형식 지정 아래의 문자 추가 옵션을 찾습니다.
# 2. 슬라이더를 오른쪽으로 이동하여 옵션을 활성화합니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:12.712193 secs
# prediction length: 172
# 3
# Question:  Knox Capture 구성 데이터에는 어떤 키와 값이 포함되어 있나요?
# GroundTruth:  Knox Capture 구성 데이터에는 smartscan_license 키에 Knox 라이센스 키 값과 smartscan_config 키에 Knox Capture 5에서 내보낸 구성 데이터 값이 포함되어 있습니다.
# Prediction:
#
# Knox Capture 구성 데이터에는 smartscan_license 키와 Knox 라이선스 키 값이 포함되어 있습니다.
# 또한 smartscan_config 키와 Knox Capture 5에서 내보낸 구성 데이터 값이 포함되어 있습니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:18.679175 secs
# prediction length: 135
# 4
# Question:  스캐너 연결 화면에서 어떤 아이콘을 탭하여 페어링된 USB 스캐너를 제거할 수 있나요?
# GroundTruth:  스캐너 옆에 있는 톱니바퀴 아이콘을 탭하여 페어링된 USB 스캐너를 제거할 수 있습니다. 그리고 스캐너로 제거를 선택하시면 됩니다.
# Prediction:
#
# 스캐너 연결 화면에서 페어링된 USB 스캐너를 제거하려면 스캐너 옆에 있는 톱니바퀴 아이콘을 탭하고 스캐너로 제거를 선택합니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:11.338270 secs
# prediction length: 73
# 5
# Question:  기본 검사 프로필을 사용할 때, IT 관리자는 어떤 설정을 변경할 수 있나요?
# GroundTruth:  기본 검사 프로필을 사용할 때, IT 관리자는 프로필의 스캔 엔진 설정 및 데이터 처리 규칙을 변경할 수 있습니다.
# Prediction:   The context says:
#
# 기본 스캔 프로필
# Knox Capture에는 기본적으로 디바이스의 모든 앱과 자동으로 연결되는 기본 스캔 프로필이 포함되어 있습니다. 기본 스캔 프로필을 사용할 때 IT 관리자는 프로필의 스캔 엔진 설정 및 데이터 처리 규칙을 변경할 수 있지만 기본 프로필의 앱 및 활동 동작은 변경할 수 없습니다.
#
# So the answer is:
#
# 기본 스캔 프로필을 사용할 때, IT 관리자는 프로필의 스캔 엔진 설정과 데이터 처리 규칙을 변경할 수 있습니다. 하지만 기본 프로필의 앱 및 활동 동작은 변경할 수 없습니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:18.077378 secs
# prediction length: 306
# 6
# Question:  Knox Capture AR을 사용하는 주요 이점은 무엇인가?
# GroundTruth:  Knox Capture AR을 사용하면 바코드 스캔 시 카메라 미리보기 창에 맞춤형 오버레이가 추가되어 사용자가 실시간으로 바코드 데이터를 보고, 분석하고, 상호작용할 수 있다. 이를 통해 데이터 검토를 위해 비즈니스 앱을 별도로 열지 않고도 제품 정보 등을 확인할 수 있어 효율성이 높아진다.
# Prediction:
#
# Knox Capture AR을 사용하는 주요 이점은 바코드 스캔 중에 카메라 미리 보기 창 내에 중요한 제품 정보를 실시간으로 표시할 수 있다는 것입니다. 이를 통해 사용자는 데이터를 검토하기 위해 비즈니스 앱을 열지 않고도 제품 모델 번호, 판매 가격, 재고 정보 등을 확인할 수 있습니다. 또한 Knox Capture AR을 사용하면 작업자가 적절한 데이터를 캡처하기 위해 바코드를 다시 스캔할 필요가 줄어들 수 있습니다.
# ReRanker similarity: 0.9999487400054932
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:22.694806 secs
# prediction length: 240
# 7
# Question:  제품 세부 정보 팝업에 사용되는 이미지 크기를 결정하는 요인은 무엇인가요?
# GroundTruth:  이미지 크기에 영향을 주는 요인으로 썸네일 이미지, 선택된 크기가 언급되어 있습니다. 썸네일 이미지는 선택한 크기에 관계없이 항상 팝업에 나타나며, 사용자가 선택하는 크기에 따라 제품 세부 정보 팝업의 이미지 크기가 결정됩니다.
# Prediction:
#
# <context>에서 제품 세부 정보 팝업에 사용되는 이미지 크기를 결정하는 요인은 이미지 선택 옵션입니다. 이 옵션을 사용하면 관리자가 썸네일이든 전체 크기 이미지이든 사용자가 제품 세부 정보를 확장할 때 이미지가 표시되는 방식을 선택할 수 있습니다.
# ReRanker similarity: 0.9994238615036011
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:12.558441 secs
# prediction length: 143
# 8
# Question:  바코드 유형 설정에서 활성 기호 수는 무엇을 의미하나요?
# GroundTruth:  바코드에 실제로 데이터를 담고 있는 기호의 수를 의미합니다. 체크섬 문자나 시작/종료 문자 등은 제외합니다. 바코드 유형에 따라 문자-기호 매핑이 다르기 때문에 활성 기호 수를 통해 실제 데이터 길이를 파악할 수 있습니다.
# Prediction:
#
# 바코드 유형 설정에서 활성 기호 수는 디코딩할 지원되는 최소/최대 바코드 길이(활성 기호 수)를 결정합니다. 예를 들어 코드 128 바코드의 기호 수 범위를 7~20으로 설정했다면, 길이가 7 이상 20 이하인 코드 128 바코드만 성공적으로 디코딩합니다.
#
# 문자-기호 매핑은 바코드 유형에 따라 다릅니다. 코드 128은 코드 39와 다르게 세 가지 인코딩 체계를 혼합하여 사용할 수 있기 때문에 문자 수와 기호 수 사이에 차이가 있습니다.
# ReRanker similarity: 0.8499341011047363
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:22.420296 secs
# prediction length: 249
# 9
# Question:  Knox Capture v1.3 버전의 새로운 기능 중 하나를 설명하세요.
# GroundTruth:  Knox Capture v1.3버전에서는 1px 막대가 있는 1D 바코드를 더 쉽게 인식할 수 있게 개선되었습니다. 또한 이제 비트맵 내부의 바코드를 스캔할 수 있습니다. 바코드 이미지 위치 파악 또한 관련된 장치나 기호에 따라 스캔이 어려운 상황에서 개선되었습니다.
# Prediction:   Knox Capture v1.3에는 라이선스를 비활성화하는 세 가지 새로운 방법이 도입되었습니다. Knox Capture 앱을 제거하거나, EMM의 앱 구성 화면에서 라이선스 필드를 수정하거나, Knox 대시보드에 관련 디바이스의 IMEI를 입력하여 라이선스 비활성화를 트리거할 수 있습니다.
# ReRanker similarity: 0.517854630947113
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:19.431139 secs
# prediction length: 164
# 10
# Question:  Knox Capture v1.4에서 지원되는 새로운 스캔 트리거 기능은 무엇인가요?
# GroundTruth:  사이드 키를 두 번 누르면 Knox Capture 스캐너를 시작할 수 있습니다. 이 트리거 옵션은 XCover 키가 없는 기기에서 Knox Capture 사용성을 개선하기 위해 추가되었습니다.
# Prediction:   Knox Capture v1.4에서 지원되는 새로운 스캔 트리거 기능은 사이드 키 더블 프레스입니다.
#
# Knox Capture v1.4에서는 "사이드 키 더블 프레스 스캔 트리거 추가"라는 제목의 단락에서 이 기능을 소개하고 있습니다.
#
# "카메라 스캔 트리거 옵션이 확장되어 이제 IT 관리자와 디바이스 사용자는 이전에 전원 또는 빅스비 버튼이라고 했던 사이드 키를 두 번 눌러 Knox Capture 디바이스 스캐너를 시작하도록 선택할 수 있습니다."
#
# 따라서 Knox Capture v1.4의 새로운 스캔 트리거 기능은 사이드 키를 두 번 눌러 스캔을 시작할 수 있다는 것입니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:20.882701 secs
# prediction length: 328
# 11
# Question:  Knox Capture 앱의 웹 링크가 이전 버전과 비교하여 어떻게 개선되었나요?
# GroundTruth:  Knox Capture 앱의 웹 링크는 이전 버전에서 디바이스의 기본 브라우저를 통해 열렸습니다.
# v1.4 버전부터 웹 링크는 앱 내 웹 보기에서 열리게 되어 사용성이 향상되었습니다.
# Prediction:   The context does not provide enough information to directly answer the question about how Knox Capture app's web links have improved compared to previous versions. No details are given about web links in previous versions or changes made to them in newer versions.
#
# The closest relevant information is:
#
# v1.4에서는 모든 인앱 웹 링크가 브라우저 대신 웹 보기에서 열리므로 앱을 통해 지원 자료에 액세스하는 사용자에게 원활한 환경을 제공합니다.
#
# This states that in v1.4, all in-app web links open in a web view instead of the device browser. This improves the user's access to support materials within the app. But no comparison is made to previous versions, so I cannot conclusively answer how web links have improved.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:16.856112 secs
# prediction length: 660
# 12
# Question:  녹스 캡처 v1.5의 스캐너 오버레이 기능에 대해 설명하세요.
# GroundTruth:  녹스 캡처 v1.5부터 스캐너 오버레이를 사용할 수 있습니다. 이 오버레이는 비즈니스 앱 위에 스캐너 미리보기로 표시되며, 이를 통해 디바이스 사용자는 앱 필드에 입력된 스캔한 데이터를 즉시 확인할 수 있습니다. 스캐너 오버레이는 전체 화면 스캔너와 매우 유사하게 작동합니다.
# Prediction:
#
# 녹스 캡처 v1.5부터 스캐너 오버레이 기능을 사용할 수 있습니다. 이 오버레이는 비즈니스 앱 위에 스캐너 미리보기로 표시되며, 이를 통해 디바이스 사용자는 앱 필드에 입력된 스캔한 데이터를 즉시 확인할 수 있습니다. 기능적으로 스캐너 오버레이는 전체 화면 스캐너와 매우 유사하게 작동합니다. 기기 사용자가 카메라를 바코드에 대면 Knox Capture는 스캔 엔진 설정 구성에 따라 스캔한 데이터를 비즈니스 앱으로 전송합니다.
# ReRanker similarity: 0.9999496936798096
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:21.867841 secs
# prediction length: 241
# 13
# Question:  엔터프라이즈 디바이스에 Knox Capture를 적용하기 위해서는 어떤 절차가 필요한가요?
# GroundTruth:  Knox Capture가 EMM 콘솔을 통해 구성 및 배포될 때 관리 모드가 자동으로 적용됩니다. 관리 모드에서 앱을 배포하는 방법에 대한 자세한 내용은 배포 설명서를 참조하세요.
# Prediction:   엔터프라이즈 디바이스에 Knox Capture를 적용하기 위해 Knox Capture 앱을 구글 플레이에서 다운로드하여 설치하고 라이선스를 활성화해야 합니다. Knox Capture는 모바일 디바이스를 강력한 바코드 스캐너로 전환할 수 있도록 만들어져 있습니다. 관리자 모드에서 IT 관리자들은 앱의 모든 기능을 활용할 수 있습니다.
# ReRanker similarity: 0.5594995021820068
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:10.168864 secs
# prediction length: 187
# 14
# Question:  Knox Capture를 무료로 사용하기 위해서는 무엇이 필요한가요?
# GroundTruth:  Knox Capture를 무료로 사용하려면 Google Play에서 앱을 다운로드하고 IT 관리자의 지시에 따라 스캔 설정을 구성하면 됩니다. 무료 버전의 앱은 기기당 최대 100회의 스캔을 제공합니다.
# Prediction:   No relevant context is provided to answer the question "Knox Capture를 무료로 사용하기 위해서는 무엇이 필요한가요?" The context mostly talks about what Knox Capture is, who can use it, and some features of Knox Capture such as scanning profiles and the AR feature. It does not mention anything about how to use Knox Capture for free. So I would say "Knox Capture를 무료로 사용하기 위한 조건에 대한 관련 컨텍스트가 제공되지 않습니다."
# ReRanker similarity: 0.99588543176651
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:11.530729 secs
# prediction length: 384
# 15
# Question:  Knox Capture 앱의 홈 화면에 표시되는 알림에는 무엇이 포함되어 있나요?
# GroundTruth:  라이선스 만료나 100회 무료 스캔 사용 시 Knox Capture 앱 홈 화면에 라이선스 구매나 다시 활성화 방법에 대한 정보가 포함된 알림이 표시됩니다.
# Prediction:
#
# <context>평가판 또는 유료 라이선스가 만료되거나 100회 무료 스캔이 사용된 경우 Knox Capture 앱의 홈 화면에 라이선스를 구매하거나 다시 활성화하는 방법에 대한 정보가 포함된 알림이 표시됩니다.</context>
#
# 이 문단에서 앱 홈 화면에 표시되는 알림에 대해 설명하고 있습니다.
#
# Knox Capture 앱의 홈 화면에 표시되는 알림에는 라이선스 만료 시 구매나 재활성화 방법에 대한 정보가 포함되어 있습니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:17.611956 secs
# prediction length: 244
# 16
# Question:  XCover 키를 사용자가 다시 매핑할 수 없게 하는 방법은 무엇인가요?
# GroundTruth:  EMM을 통해 xCover 키 재매핑을 비활성화합니다.
# 디바이스 전체 정책에서 디바이스 정책 제어 활성화를 활성화로 설정합니다.
# 키 매핑 제어 활성화를 활성화로 설정하고 Microsoft Teams용 PTT/사이드 키 매핑 활성화를 비활성화합니다.
# Prediction:   To prevent the user from remapping the XCover key:
#
# EMM을 통해 xCover 키 재매핑을 비활성화하세요:
#
# 1. EMM의 Knox 서비스 플러그인 섹션으로 이동하세요.
#
# 2. 디바이스 전체 정책을 선택한 후 디바이스 정책 제어 활성화를 활성화로 설정합니다.
#
# 3. [장치 키 매핑(프리미엄)]을 클릭하고 키 매핑 제어 활성화를 활성화로 설정합니다.
#
# 4. 애플리케이션 실행 및 종료를 위한 키 매핑 활성화를 비활성화로 설정합니다.
#
# 5. 정책을 저장하고 디바이스에 적용합니다.
#
# XCover 키는 더 이상 장치에서 다시 매핑할 수 없습니다.
# ReRanker similarity: 0.9999496936798096
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:23.922156 secs
# prediction length: 332
# 17
# Question:  Knox Capture 앱을 사용하여 스캔한 데이터를 다른 웹 브라우저로 출력할 수 있다고 했습니다. 이를 통해 문제를 완전히 방지할 수 있다고 했는데, 어떤 브라우저를 예로 들었나요?
# GroundTruth:  Mozilla Firefox와 같은 다른 브라우저 엔진으로 구축된 웹 브라우저를 예로 들었습니다.
# Prediction:   The example browser that was mentioned as a workaround to completely avoid the issue was Mozilla Firefox. Other relevant sentences from the context:
#
# 키 입력 출력 데이터는 비즈니스 앱 대신 브라우저 또는 웹 앱으로 전송됩니다.
#
# 해결 방법으로 다른 웹 브라우저 사용하기 이 문제를 완전히 방지하려면 스캔한 데이터를 Mozilla Firefox와 같은 다른 브라우저 엔진으로 구축된 웹 브라우저로 출력할 수 있습니다.
#
# So the example browser given that can completely avoid the issue is Mozilla Firefox.
# ReRanker similarity: 0.9998965263366699
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:10.803098 secs
# prediction length: 386
# 18
# Question:  Knox Capture 앱에서 정책 또는 라이선스 업데이트가 적용되지 않는 이유는 무엇인가요?
# GroundTruth:  정책 또는 라이선스 업데이트를 푸시할 때 Knox Capture 앱이 이미 실행 중이었기 때문에 앱을 다시 시작할 때까지 변경 사항이 적용되지 않습니다. Knox Capture 앱을 다시 시작하면 정책 및 라이선스 업데이트가 적용됩니다.
# Prediction:
#
# 한국어로 답변드리겠습니다. 콘텍스트에서 Knox Capture 앱에 정책 또는 라이선스 업데이트가 적용되지 않는 이유는 정책 또는 라이선스 업데이트를 푸시할 때 디바이스가 Knox Capture를 이미 실행하고 있는 경우입니다. Knox Capture 앱을 다시 시작할 때까지 변경 사항을 적용할 수 없기 때문입니다.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:09.542679 secs
# prediction length: 179
# 19
# Question:  Knox Suite 라이선스를 생성하기 전에 먼저 수행해야 하는 두 가지 사전 요구 사항은 무엇입니까?
# GroundTruth:  시작하기 전에 Knox 고객 ID를 확인하고, 삼성 디바이스 리셀러로부터 EE 디바이스를 구매해야 합니다. 리셀러에게 고객 ID를 제공해야 하며, 리셀러는 Knox 배포 프로그램(KDP) 회원이어야 합니다.
# Prediction:
# <answer>
# 사전 요구 사항 단계에서 먼저 해야 할 일은 다음 두 가지입니다.
# 1. 삼성 계정으로 Knox 관리 포털에 등록하세요.
# 2. Knox 관리 포털에 로그인하세요.
# </answer>
# ReRanker similarity: 0.2827714681625366
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:10.440713 secs
# prediction length: 109
# 20
# Question:  Knox Suite 라이선스에 기존 Enterprise Edition 디바이스를 추가하려는 경우 어떤 단계를 거쳐야 하는가?
# GroundTruth:  기존 Knox Suite 라이선스에 Enterprise Edition 디바이스를 추가하려는 경우, 자세한 내용은 기존 Knox Suite 라이선스에 Enterprise Edition 디바이스 추가를 참조하라고 하였습니다.
# Prediction:   You can follow these steps to add existing Enterprise Edition devices to a Knox Suite license:
#
# 1. Knox 관리 포털에 로그인하세요.
#
# 2. 엔터프라이즈 에디션 대시보드로 이동하세요.
#
# 3. 라이선스 생성을 클릭합니다.
#
# 4. 라이선스 생성 팝업에서 기존 라이선스 키에 추가를 선택합니다.
#
# 5. 추가하려는 기존 라이선스 키를 선택합니다.
#
# 6. Generate를 클릭하여 기존 라이선스 키에 새 디바이스를 추가합니다.
# ReRanker similarity: 0.9999496936798096
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 3/6
# mrr: 0.333
# latency: 0:00:25.644215 secs
# prediction length: 280
# 21
# Question:  Knox Suite 라이선스 생성 시 라이선스 시작 날짜로 선택할 수 있는 기간은 최대 얼마인가요?
# GroundTruth:  라이선스 생성 시점으로부터 최대 90일 이내의 모든 날짜가 가능합니다.
# Prediction:
#
# <context>라이선스 생성 시점으로부터 최대 90일 이내의 모든 날짜가 가능합니다.</context>
#
# Thus, the maximum period from which the license start date can be chosen when generating a Knox Suite license is 90 days from the license generation date.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:08.365035 secs
# prediction length: 216
# 22
# Question:  Knox Suite 라이선스가 만료되면 얼마동안 연장할 수 있나요?
# GroundTruth:  라이선스가 만료된 후 1년 이상 연장할 수 있습니다. 자세한 내용은 리셀러에게 문의하시기 바랍니다.
# Prediction:
#
# 문서에서 직접적으로 라이선스가 만료된 후 연장 기간에 대해 언급하고 있지 않습니다. 하지만 1년 라이선스를 생성한 후 리셀러에 문의하여 라이선스를 연장할 수 있다고 나와 있습니다. "EE용 Knox Suite 라이선스가 만료되면 1년 이상 연장할 수 있습니다."
#
# 따라서 문맥상으로 라이선스가 만료된 후 최소 1년 이상 연장할 수 있다고 추론할 수 있습니다.
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:13.016366 secs
# prediction length: 202
# 23
# Question:  기반으로 문의하여 Knox Suite 라이선스를 구매할 수 있습니까?
# GroundTruth:  해당 국가의 Knox 리셀러에게 문의하여 Knox Suite 라이선스를 구매할 수 있습니다. 해당 지역의 공식 Knox Suite 리셀러를 찾으려면 Knox 리셀러 디렉터리를 참조하세요.
# Prediction:
#
# 콘텍스트에 따르면 Knox Suite 라이선스는 해당 국가의 Knox 리셀러에게 문의하여 구매할 수 있습니다. "해당 국가의 Knox 리셀러에게 문의하여 Knox Suite 라이선스를 구매할 수 있습니다."라고 명시되어 있습니다. 따라서 Knox Suite 라이선스는 Knox 리셀러를 통해 구매할 수 있습니다.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:08.228580 secs
# prediction length: 176
# 24
# Question:  Knox Suite 평가판을 시작하려면 어떤 단계를 밟아야 하나요?
# GroundTruth:  Knox Suite 평가판을 시작하려면 Knox 솔루션 페이지의 Get Started에 이메일 주소를 입력하고 무료 평가판 받기를 클릭하세요. 가입 프로세스를 완료하고 Knox 대시보드에 로그인한 후 사용해 보려는 각 Knox Suite 제품 카드를 클릭하세요.
# Prediction:
#
# Knox Suite 평가판을 시작하려면 다음의 단계들을 밟아야 합니다:
#
# 1. SamsungKnox.com에 로그인하여 Knox 관리 포털에 접속합니다.
# 2. 시작 화면에서 "시작하기"를 클릭합니다. Knox 관리 포털 설정 페이지가 열립니다.
# 3. Knox 클라우드 솔루션 목록에서 Knox Suite를 선택하고 "확인"을 클릭합니다. Knox 관리 포털이 열립니다.
# 4. 사용해 보려는 Knox Suite 제품 카드를 클릭합니다.
# ReRanker similarity: 0.9999492168426514
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:11.516987 secs
# prediction length: 245
# 25
# Question:  Knox Suite가 지원하는 플랫폼과 운영 체제에는 어떤 것들이 있나요?
# GroundTruth:  Knox Suite는 안드로이드, iOS, Windows, Chrome OS 플랫폼을 지원합니다. 안드로이드의 경우 버전 8 이상을 지원하며 삼성 기기에서 Knox 3.0 이상 버전을 설치해야 합니다. iOS의 경우 버전 13 이상을 지원합니다.
# Prediction:
#
# Knox Suite는 안드로이드 및 iOS를 지원하며, 구체적으로 다음과 같은 플랫폼과 OS를 지원합니다:
#
# - 삼성 Knox 3.0 이상이 설치된 안드로이드 8 이상
# - 삼성 Knox 2.4 이상이 설치된 안드로이드 5.0.1 이상
# - Knox 2.6 이상이 설치된 안드로이드 6 이상 및 iOS 13 이상
# - Windows 10 1703 이상
# - Chrome OS 99 이상
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:15.058796 secs
# prediction length: 214
# 26
# Question:  Knox Suite 라이선스가 모든 Knox Suite 서비스를 활성화하지 못하는 이유는 무엇인가요?
# GroundTruth:  활성 Knox Suite 라이선스는 Knox Suite 번들의 개별 서비스 각각에 할당된 경우에만 모든 Knox Suite 서비스에 등록됩니다.
# Prediction:
#
# Knox Suite 라이선스가 모든 Knox Suite 서비스를 활성화하지 못하는 이유는 활성 Knox Suite 라이선스가 Knox Suite 번들의 개별 서비스 각각에 할당되지 않았기 때문입니다. 이를 해결하려면 활성 Knox Suite 라이선스 키를 Knox Suite 번들의 다른 서비스에 할당해야 합니다.
# ReRanker similarity: 0.9998980760574341
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:07.256649 secs
# prediction length: 177
# 27
# Question:  AR 데모 바코드에 있는 바코드를 사용하여 무엇을 테스트할 수 있나요?
# GroundTruth:  녹스 캡처 AR 기능을 테스트할 수 있습니다. 바코드 1, 2, 3, 4, 5, 6이 제공되어 있습니다.
# Prediction:
#
# AR 데모 바코드에 있는 바코드를 사용하여 녹스 캡처 AR 기능을 테스트할 수 있습니다. AR 데모 바코드를 스캔하면 AR 기능을 사용해 볼 수 있고, 샘플 바코드를 사용하여 검색 및 찾기, 보기 및 업데이트 기능을 시연할 수 있습니다.
# ReRanker similarity: 0.9999474287033081
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:07.943411 secs
# prediction length: 134
# 28
# Question:  Knox Capture의 주요 기능 중 스캔 프로필은 무엇을 정의합니까?
# GroundTruth:  스캔 프로필은 카메라 스캐너를 실행할 수 있는 비즈니스 앱을 정의합니다.
# Prediction:
#
# <answer>
# Knox Capture의 스캔 프로필은 앱의 핵심 동작을 정의합니다. 스캔 프로필은 어떤 앱에서 카메라 스캐너를 사용할 수 있는지, 스캔할 바코드 유형, 스캔한 데이터를 해석하는 방법, 데이터를 전달할 비즈니스 애플리케이션 등을 정의합니다.
# </answer>
# ReRanker similarity: 0.9999467134475708
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/4
# mrr: 0.500
# latency: 0:00:15.603599 secs
# prediction length: 156
# 29
# Question:  녹스 캡처는 어떤 기능을 제공하며, 어떤 장치와 국가에서 지원하는가요?
# GroundTruth:  녹스 캡처는 엔터프라이즈 IT 관리자가 조직의 삼성 갤럭시 스마트폰과 태블릿을 강력한 바코드 스캐너로 변환할 수 있는 솔루션입니다. Knox Capture는 일부 Android 기기와 특정 국가에서만 사용할 수 있습니다. 지원하는 최신 디바이스 목록과 국가 목록은 링크를 통해 확인할 수 있습니다.
# Prediction:
#
# 녹스 캡처는 엔터프라이즈 IT 관리자가 조직의 삼성 갤럭시 스마트폰과 태블릿을 강력한 바코드 스캐너로 변환할 수 있습니다. 추가 하드웨어나 코딩 없이 바코드 정보를 읽고 처리하여 다른 애플리케이션에 출력할 수 있습니다.
#
# 녹스 캡처는 일부 Android 기기와 특정 국가에서만 사용할 수 있습니다. 지원하는 최신 기기 목록과 국가 목록은 문맥을 참조하세요.
# ReRanker similarity: 0.9999496936798096
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/6
# mrr: 0.500
# latency: 0:00:16.717414 secs
# prediction length: 202
# 30
# Question:  Knox Capture를 사용하여 블루투스 지원 장치에 연결하려면 어떤 단계가 필요한가요?
# GroundTruth:  Knox Capture를 블루투스 지원 장치에 연결하려면 다음 단계가 필요합니다.
# 1) 추가 작업 메뉴에서 출력 경로 선택
# 2) 블루투스에서 블루투스 웨지 사용을 켜짐으로 설정
# 3) 이 기기를 검색 가능하게 만들기 탭
# Prediction:   Excluding the fact that you have a business need for using Knox Capture’s Bluetooth keyboard emulation feature (called 배지 output), there are a few steps required to use it:
#
# 1. Turn on Bluetooth keyboard emulation in Knox Capture’s settings (called 출력 경로 구성)
# 2. Make your device discoverable to other Bluetooth devices (called 이 기기를 검색 가능하게 만들기)
# 3. On the other Bluetooth device, initiate pairing/connection to your Knox Capture device
# 4. Accept the Bluetooth pairing request on your Knox Capture device when prompted
#
# At that point, the two devices will be paired and connected, with your Knox Capture device acting as an emulated Bluetooth keyboard to the other device. Scanned barcode data will be sent as keystrokes to the connected device.
#
# To disconnect, you can unpair the devices in Knox Capture's output path configuration settings.
# ReRanker similarity: 0.9999469518661499
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:17.489055 secs
# prediction length: 843
# 31
# Question:  블루투스를 통해 스캔된 데이터를 페어링된 기기로 전송하려면 어떤 단계들이 필요한가?
# GroundTruth:  블루투스를 통해 스캔된 데이터를 페어링된 기기로 전송하기 위한 단계를 구체적으로 찾을 수 없습니다. 제공된 정보는 Knox Capture 앱을 사용하여 블루투스 페어링을 설정하는 방법에 대한 것이지만, 데이터 전송을 위한 단계에 대한 언급은 없습니다.
# Prediction:   To send scanned data to a paired device via Bluetooth:
#
# 1. 홈 화면의 프로필 옆에서 추가 작업 메뉴 아이콘을 탭하세요.
# 2. 출력 경로를 선택합니다.
# 3. 블루투스에서 블루투스 웨지 사용을 켜짐 위치로 전환합니다.
# 4. 페어링된 기기에서 이 기기를 검색 가능하게 만들기를 탭하세요.
# 5. 디바이스에서 Bluetooth가 비활성화된 경우 활성화하라는 메시지가 표시됩니다.
# 6. 페어링할 기기를 선택합니다. 두 기기가 연결되었음을 확인하는 상태 메시지가 표시됩니다.
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:19.056806 secs
# prediction length: 287
# 32
# Question:  Knox Capture 애플리케이션에서 블루투스 스캐너를 연결하려면 어떤 단계들이 필요한가?
# GroundTruth:  Knox Capture 애플리케이션에서 블루투스 스캐너를 연결하는 단계를 구체적으로 찾을 수 없습니다. Knox Capture 메인 페이지에서 추가 작업 메뉴를 탭하고 스캐너 연결을 선택한 후 새 장치 페어링을 선택하는 것 외에 자세한 단계가 언급되지 않았습니다.
# Prediction:
# <answer>
# 이 문맥에서는 블루투스 스캐너를 Knox Capture 애플리케이션에 연결하는 단계에 대한 관련 정보가 제공되지 않습니다. "No relevant context"
# </answer>
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:11.357448 secs
# prediction length: 110
# 33
# Question:  Knox Capture를 통해 스캔 구성을 파일로 저장할 때, 파일이 저장되는 위치는 어디인가요?
# GroundTruth:  파일은 내 파일 > 다운로드 내에 저장됩니다.
# Prediction:
#
# <context>
# 구성을 내보낸 후에는 관리 모드에서 앱을 실행하는 다른 장치와 공유할 수 있습니다.파일이 공유되면 수신 디바이스는 다음을 수행하여 구성을 가져올 수 있습니다.
# </context>
#
# 이 문맥에서는 Knox Capture에서 구성 파일을 저장할 때 파일이 저장되는 위치에 대한 정보가 제공되지 않습니다. 문맥에 따르면 "No relevant context"입니다.
# ReRanker similarity: 0.00021021995053160936
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:23.694925 secs
# prediction length: 213
# 34
# Question:  데이터 전송을 위해 사용할 수 있는 세 가지 주요 방법은 무엇인가요?
# GroundTruth:  데이터 전송을 위해 사용할 수 있는 세 가지 주요 방법은
#
# 1. StartActivity를 통해 전송
# 2. StartForeground를 통해 전송
# 3. 브로드캐스트 인텐트
#
# 입니다.
# Prediction:
#
# 데이터 전송을 위한 세 가지 주요 방법은 다음과 같습니다:
#
# 1. StartActivity를 통해 전송
# 2. StartForeground를 통해 전송
# 3. 브로드캐스트 인텐트
# ReRanker similarity: 0.9999485015869141
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:12.761722 secs
# prediction length: 100
# 35
# Question:  Knox Capture의 테스트 모드를 시작하려면 어떻게 해야 하나요?
# GroundTruth:  다음 방법 중 하나로 테스트 모드를 시작할 수 있습니다:
# 홈 화면의 프로필 레이블 옆에 있는 추가 작업 메뉴 아이콘을 누르고 앱 테스트를 선택하거나, 홈 화면 오른쪽 하단에 있는 공유 버튼을 탭하고 공유 구성 메뉴에서 구성 테스트 버튼을 누릅니다.
# Prediction:
#
# 녹스 캡처의 테스트 모드를 시작하려면 다음 두 가지 옵션 중 하나를 사용할 수 있습니다.
#
# 1. 홈 화면에서 오른쪽 상단의 검색 아이콘 옆에 있는 옵션 아이콘을 탭하고 "앱 테스트"를 선택합니다.
#
# 2. 홈 화면 오른쪽 하단에 있는 공유 버튼을 탭한 다음 "구성 테스트" 버튼을 선택합니다.
#
# 테스트 모드가 시작되면 시스템 팝업 알림을 통해 테스트 모드가 켜졌음을 알립니다.
# ReRanker similarity: 0.9999247789382935
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:31.201825 secs
# prediction length: 212
# 36
# Question:  Knox Capture AR 템플릿을 사용하여 바코드 스캔을 수행하는 데 있어 IT 관리자와 일반 사용자간에 차이점은 무엇인가?
# GroundTruth:  IT 관리자는 AR 템플릿 화면으로 이동하여 원하는 템플릿을 선택하고 스캔을 시작할 수 있습니다. 반면 일반 사용자는 Knox Capture 앱을 열고 팝업에서 AR 템플릿을 선택하여 사용할 수 있습니다. 두 경우에 모두 스캔 시작을 누르면 AR 템플릿을 시작할 수 있습니다.
# Prediction:
#
# IT 관리자는 AR 템플릿 화면으로 이동하여 원하는 템플릿 아래의 스캔 시작을 탭하기만 하면 AR 템플릿을 시작할 수 있습니다. 반면 최종 사용자는 디바이스 홈이나 앱 화면에서 Knox Capture 앱을 열고 AR 템플릿 이름을 선택한 다음 스캔 시작을 탭하여 사용을 시작합니다. 결국 IT 관리자는 AR 템플릿을 보다 직접적으로 활성화할 수 있지만 일반 사용자는 추가 단계를 거쳐 AR 템플릿에 액세스해야 합니다.
# ReRanker similarity: 0.9999492168426514
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:30.418467 secs
# prediction length: 235
# 37
# Question:  삼성에서 직접 부품 표시 모드를 사용할 때 권장하는 스캔 영역의 크기는 무엇인가요?
# GroundTruth:  스캔 영역을 화면의 작은 부분으로 제한할 것을 권장합니다.
# Prediction:
# 삼성에서 직접 부품 표시 모드를 사용할 때 성능 향상을 위해 스캔 영역을 화면의 작은 부분으로 제한할 것을 권장하고 있습니다. 문맥에서 구체적인 크기는 언급하고 있지 않습니다.
# ReRanker similarity: 0.9999492168426514
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:12.539676 secs
# prediction length: 99
# 38
# Question:  녹스 캡처 v1.0.01에서 지원하는 안드로이드 버전은 무엇인가요?
# GroundTruth:  녹스 캡처 v1.0.01부터 안드로이드 11을 지원하기 시작했습니다. 또한 안드로이드 10과 안드로이드 11을 실행하는 다양한 삼성 갤럭시 기기들도 지원합니다.
# Prediction:
#
# 녹스 캡처 v1.0.01부터 시작하여 이제 안드로이드 11을 지원합니다. 이전에는 미국, 아일랜드, 영국에서 안드로이드 10을 실행하는 XCover Pro (미국) 및 탭 액티브3가 지원되었습니다. 이번 새 업데이트를 통해 다음 기기에서 사용할 수 있는 기기는 1. 안드로이드 10 2를 실행하는 XCover Pro 미국 기기, 2. 안드로이드 11을 실행하는 모든 엑스커버 프로 기기, 3. Android 10 및 11을 실행하는 모든 Tab Active3 기기입니다.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:15.997494 secs
# prediction length: 266
# 39
# Question:  기본 프로필이 활성화되어 있으면 Knox Capture 구성이 모두 덮어쓰여지나요?
# GroundTruth:  네, 기본 프로필이 활성화되어 있으면 Knox Capture의 다른 모든 프로필 설정을 덮어씁니다. 기본 프로필을 비활성화하면 이 동작을 방지할 수 있습니다.
# Prediction:
#
# 예, 기본 프로필이 활성화되어 있으면 Knox Capture 구성이 모두 덮어쓰여집니다.
# context에 따르면 "여러 응용 프로그램의 프로필을 만들 때 기본 프로필의 동작이 모든 구성을 덮어쓰지 않도록 하려면 기본 프로필을 끄기로 설정하십시오."라고 설명하고 있습니다.
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 3/6
# mrr: 0.333
# latency: 0:00:19.144049 secs
# prediction length: 153
# 40
# Question:  Knox Capture v1.2부터 IT 관리자는 앱 내에서 라이선스를 활성화할 수 있다고 했는데, 어떤 메뉴를 통해서 That인가요?
# GroundTruth:  라이선스 활성화 메뉴를 통해 Knox Capture 라이선스를 활성화할 수 있습니다.
# Prediction:
#
# <context>에 따르면, 이전에는 Knox Capture 라이선스를 MDM을 통해 라이선스를 푸시하는 조직에서만 사용할 수 있었습니다. Knox Capture v1.2부터 이제 IT 관리자는 새로운 라이선스 활성화 메뉴를 사용하여 앱 내에서 Knox Capture 라이선스를 활성화할 수 있습니다. 라이선스 활성화 메뉴는 관리자 모드에서만 사용할 수 있으며, 수동으로 라이선스 키를 입력하거나 QR 코드를 스캔하여 라이선스를 입력할 수 있다고 설명하고 있습니다.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/4
# mrr: 0.500
# latency: 0:00:16.208947 secs
# prediction length: 262
# 41
# Question:  녹스 캡처 v1.6 릴리스 노트에 따르면 Scandit 라이브러리가 어떤 버전으로 업데이트되었나요?
# GroundTruth:  녹스 캡처 v1.6에 Scandit 라이브러리가 버전 6.12로 업데이트되었습니다.
# Prediction:   녹스 캡처 v1.6 릴리스 노트에 따르면 Scandit 라이브러리가 버전 6.12로 업데이트되었습니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:06.236343 secs
# prediction length: 58
# 42
# Question:  녹스 캡처 v1.7의 새로운 스캔 엔진은 무엇입니까?
# GroundTruth:  녹스 캡처 v1.7의 새로운 스캔 엔진은 삼성에서 개발한 새로운 엔진입니다. 이 엔진은 Scandit 엔진과 동일한 뛰어난 기능을 제공합니다. 신규 고객은 스캔 엔진을 선택할 수 있는 옵션이 제공됩니다.
# Prediction:   녹스 캡처 v1.7 릴리즈 노트에 따르면, 새로운 녹스 캡처 v1.7 에 추가된 가장 중요한 사항은 삼성에서 개발한 새로운 스캔 엔진의 출시입니다. 새 엔진은 Scandit 엔진과 동일한 뛰어난 기능 세트를 제공하는 동시에 삼성이 향후 릴리스에서 고객에게 흥미진진한 업계 최고의 기능을 제공할 수 있는 기반을 마련합니다.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:13.107715 secs
# prediction length: 180
# 43
# Question:  기기의 Bluetooth 권한 설정이 충분한지 확인하는 데 어떤 방법이 있나요?
# GroundTruth:  Bluetooth 하드웨어 스캐너가 페어링되어 있지만 여전히 작동하지 않는다면 기기의 Bluetooth 권한이 충분하지 않기 때문일 수 있습니다. 권한 설정을 확인하여 스캐너가 연결할 수 있는지 확인하세요.
# Prediction:
#
# 스캐너 연결 패널이 나타나면 이 패널을 사용하여 스캐너에 연결하거나 장치 설정으로 이동하여 연결할 수 있습니다. 장치 설정에 접속하여 Bluetooth 권한이 스캐너에 연결하는 데 충분한지 확인할 수 있습니다.
# ReRanker similarity: 0.9996767044067383
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:11.492026 secs
# prediction length: 120
# 44
# Question:  Knox Capture 앱을 우리 회사에 도입하기 위해 고려해야 할 사항은 무엇인가요?
# GroundTruth:  Knox Capture 앱을 도입하려면 IT 관리자나 전담 앱 관리자와 같은 전문가의 도움이 필요합니다. 이 앱은 EMM과 함께 사용할 때 가장 잘 작동한다고 합니다. 비즈니스 앱으로 사용하려면 배포, 구성, 라이선스 활성화 등을 위해 관리 지원이 필요할 것입니다.
# Prediction:   The key considerations for adopting the Knox Capture app for your company are:
#
# 1. Knox Capture는 EMM (기업 이동성 관리)과 통합하여 사용할 때 가장 잘 작동합니다. 따라서 EMM 솔루션을 사용할 계획이거나 이미 사용 중이어야 합니다.
#
# 2. 전담 앱 관리자 (예: IT 관리자)가 Knox Capture를 구성하고 관리해야 합니다. 관리자는 스캔 프로필을 만들고 구성한 다음 EMM을 통해 Knox Capture를 사용자에게 배포해야 합니다.
#
# 3. Knox Capture는 Android 기기에서 작동합니다. 따라서 Android 스마트폰이나 태블릿을 사용 중이어야 하며이를 통해 Knox Capture를 배포할 계획이어야 합니다.
#
# 4. Knox Capture 라이선스가 필요합니다. 상업적 사용을 위해 유효한 Knox Suite 라이선스가 있거나 구매해야 합니다.
# ReRanker similarity: 0.9999263286590576
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:34.004097 secs
# prediction length: 477
# 45
# Question:  무료 버전의 앱에서 제공하는 무료 스캔 횟수는 몇 회인가요?
# GroundTruth:  무료 버전의 앱인 녹스 캡처에서는 디바이스당 100회의 무료 스캔을 허용합니다.
# Prediction:   무료 버전의 앱은 디바이스당 100회 무료 스캔을 허용합니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:07.977188 secs
# prediction length: 35
# 46
# Question:  녹스 캡처에 대한 라이선스를 받기 위해서는 어떤 절차를 거쳐야 하나요?
# GroundTruth:  녹스 캡처를 계속 사용하려면 유효한 녹스 스위트 라이선스가 필요합니다. 100회 무료 스캔을 완료한 고객은 라이선스 관리 페이지를 참조하여 녹스 스위트 라이선스를 취득해야 합니다. 라이선스 취득 절차는 라이선스 관리 페이지를 참조하시기 바랍니다.
# Prediction:   You have the option to follow Korean steps to acquire Knox license or get a Scandit Edition evaluation license by referring to the Scandit license management page.
#
# 녹스 캡처에 대한 라이선스를 받기 위해서는 다음과 같은 방법이 있습니다:
#
# 1) 녹스 라이선스 취득 절차를 따릅니다. 자세한 내용은 "라이선스 관리 페이지"를 참조하세요.
#
# 2) Scandit 에디션 평가판 라이선스를 받기 위해서는 "Scandit 라이선스 관리 페이지"를 참조하세요.
# ReRanker similarity: 0.9844837784767151
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:10.348103 secs
# prediction length: 326
# 47
# Question:  Verizon XCover Pro 장치에서 카메라 스캔을 트리거하도록 XCover 키를 설정하기 위해 먼저 수행해야 하는 것은 무엇입니까?
# GroundTruth:  디바이스에서 설정 > 고급 기능 > XCover 키를 탭하고 Verizon PTT의 전원을 끄는 것입니다.
# Prediction:   <context>Verizon XCover Pro 장치에서 카메라 스캔을 트리거하도록 XCover 키를 설정하기 위해 먼저 수행해야 하는 것은 EMM의 Knox 서비스 플러그인 버전이 1.2.74 이상인지 확인하는 것입니다.</context>
# ReRanker similarity: 0.07074087113142014
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:06.053433 secs
# prediction length: 136
# 48
# Question:  Knox Suite에 등록하려면 먼저 무엇을 만들어야 합니까?
# GroundTruth:  먼저 SamsungKnox.com에 로그인하여 Knox 계정을 만들어야 합니다. 그런 다음 Knox 서비스에 액세스하려면 시작 화면에서 시작하기를 클릭하세요. Knox Suite에 등록하는 마지막 단계는 Knox Manage 등록을 완료하는 것입니다.
# Prediction:
#
# Knox Suite에 등록하려면 먼저 삼성 Knox 계정을 만들어야 합니다. 문맥에 따르면,
#
# "삼성 Knox 계정을 만들고 Knox 서비스에 액세스하면 Knox Suite에 등록할 수 있습니다.
#
# 1. SamsungKnox.com에 로그인하세요.
#
# 2. 시작 화면이 열리면 시작하기를 클릭합니다. Knox 관리 포털 설정 페이지가 열립니다."
#
# 따라서 Knox Suite에 등록하려면 먼저 삼성 Knox 계정을 만들어야 합니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 3/6
# mrr: 0.333
# latency: 0:00:10.898097 secs
# prediction length: 245
# 49
# Question:  Knox Suite 라이선스의 유효기간이 만료되면 어떻게 하여 계속 사용할 수 있습니까?
# GroundTruth:  Knox Suite 라이선스의 유효기간이 만료된 후 계속 사용하기 위해서는 공인 리셀러에서 상용 라이선스를 구매하고 Knox Suite 포털에 구매한 라이선스 키를 입력하여 등록하면 됩니다.
# Prediction:
# <response>
# 평가판 라이선스가 만료되면 공인 리셀러로부터 상용 라이선스를 구매하여 Knox Services를 계속 사용할 수 있습니다. Knox 관리 포털 탐색 창에서 라이선스를 클릭하고, 열리는 통합 라이선스 페이지에서 작업 > 라이선스 받기 > 리셀러 찾기를 클릭합니다. 그러면 공인 리셀러 페이지가 열립니다. 위치 및 라이선스 키로 리셀러를 검색할 수 있습니다.
# </response>
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:12.911275 secs
# prediction length: 223
# 50
# Question:  삼성이 Knox Suite 서비스를 통해 수집한 개인 또는 사업체 데이터를 어떻게 안전하게 취급하고 있나요?
# GroundTruth:  삼성은 Knox Suite 서비스를 통해 획득한 개인 및 사업체 데이터를 GDPR 규정에 따라 안전하게 처리하기 위해 최선을 다하고 있습니다. 삼성 클라우드 솔루션은 SoC2 인증을 받아 데이터의 보안성과 안정성을 보장합니다. 자세한 내용은 GDPR과 삼성 Knox 솔루션을 참조하시기 바랍니다.
# Prediction:   답변은 다음과 같습니다:
#
# Knox Suite 서비스를 통해 얻은 고객 정보를 삼성은 안전하게 취급하고 있습니다. GDPR에서 규정한 데이터 저장 및 처리 요구 사항을 충족하도록 최선을 다하고 있습니다. 데이터 수집은 필요한 경우에만 제한되고, Knox Suite 솔루션은 SoC2 인증을 받아 운영, 보안, 안정성이 보장됩니다. 자세한 내용은 GDPR 및 Knox 솔루션 문서를 참고하세요.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:16.565586 secs
# prediction length: 220
# 51
# Question:  Knox Capture에서 기본 검사 프로필을 편집할 때 수행할 수 있는 작업은 무엇입니까?
# GroundTruth:  기본 검사 프로필에서는 앱 목록을 변경할 수 없습니다. 기본 검사 프로필은 기기의 모든 앱에서 작동하기 때문입니다.
#
# 바코드 유형을 추가하거나 제거할 수 있습니다. 지원되는 바코드 유형 목록을 업데이트할 수 있습니다.
#
# 스캔 엔진 설정에서 손전등 버튼을 활성화할 수 있습니다.
# Prediction:
#
# 기본 스캔 프로필을 편집할 때 다음 작업을 수행할 수 있습니다:
#
# - 지원되는 바코드 유형 목록 업데이트
# - 스캔 중에 손전등 버튼 활성화
# - 스캔에 성공할 때 Enter 키스트로크 추가
# - 스캔 데이터에 접두사 또는 접미사 문자 추가
#
# 기본 프로필에서는 앱 및 활동 설정을 변경할 수 없습니다.
# ReRanker similarity: 0.9999268054962158
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/4
# mrr: 0.500
# latency: 0:00:13.941324 secs
# prediction length: 167
# 52
# Question:  Knox Capture에서 키보드 입력을 사용하여 수동으로 데이터를 입력할 수 있는 이유는 무엇인가요?
# GroundTruth:  Knox Capture는 스캔한 데이터를 키 입력으로 변환하여 비즈니스 앱으로 전송합니다. 이를 통해 사용자가 키보드를 사용하여 데이터를 수동으로 입력하는 것처럼 앱이 스캔한 데이터를 입력 값으로 인식할 수 있습니다.
# Prediction:   Knox Capture에서 키보드 입력을 사용하여 수동으로 데이터를 입력하도록 하는 이유는 Knox Capture가 스캔한 바코드 데이터를 키 입력으로 변환하여 비즈니스 앱으로 전송하기 때문입니다. 이렇게 하면 비즈니스 앱에서 스캔한 데이터가 실제 키보드 입력처럼 보입니다. Knox Capture는 사용자가 키보드를 사용하여 수동으로 입력하는 것을 모방합니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 5/5
# mrr: 0.200
# latency: 0:00:13.422860 secs
# prediction length: 203
# 53
# Question:  규칙을 생성하고 실행 순서를 구성하기 위해 수행해야 하는 첫 번째 단계는 무엇입니까?
# GroundTruth:  규칙을 만들기 위한 첫 번째 단계는 Knox Capture 홈 화면에서 규칙을 만들려는 프로필을 탭하는 것입니다.
# Prediction:  내가 질문에 대한 관련된 부분을 찾아본 결과 규칙을 생성하고 실행 순서를 구성하기 위해 수행해야 하는 첫 번째 단계는 Knox Capture 홈 화면에서 규칙을 만들려는 프로필을 탭하는 것입니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:11.890697 secs
# prediction length: 109
# 54
# Question:  Knox Capture 스캔 엔진 설정에서 사용할 수 있는 바코드 유형은 무엇입니까?
# GroundTruth:  스캔 엔진 설정에서 사용할 수 있는 바코드 유형은 다음과 같습니다.
# 코다바, EAN13, EAN8, 인터리브 2/5, UPCA, UPCE, 코드 128, 코드 39, 코드 93, 데이터 매트릭스, PDF417, QR 코드입니다.
# 코다바와 코드 93을 제외한 모든 바코드가 기본적으로 활성화됩니다.
# Prediction:   Please feel free to edit or improve it.
#
# 스캔 엔진 설정에서 Knox Capture는 다음과 같은 바코드 유형을 지원합니다:
#
# 1D 유형: 코다바, 코드 11, 코드 25, 코드 32, 데이터바 14, 데이터바 리미티드, EAN13, EAN8, 인터리브 2/5, MSI-Plessey, UPCA, UPCE
#
# 알파숫자 유형: 코드 128, 코드 39, 코드 93
#
# 2D 유형: 아즈텍, 데이터 매트릭스, 도트코드, 맥시코드, 마이크로 PDF417, 마이크로 QR, PDF417, QR
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 0
# true_context_rank: 0/6
# mrr: 0.000
# latency: 0:00:29.035600 secs
# prediction length: 290
# 55
# Question:  시각적 신호를 사용하는 이유는 무엇인가요?
# GroundTruth:  시각적 신호는 사용자의 주의를 바코드에 집중시키기 위해 사용합니다.
# Prediction:
#
# 시각적 신호는 카메라 스캔 UI의 중심에 있는 뷰파인더 오버레이로, 사용자의 주의를 바코드에 집중시킵니다. 시각적 신호를 사용하는 이유는 스캔 중 사용자의 주의를 보다 잘 끌어 바코드에 집중시키기 위해서입니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:21.308940 secs
# prediction length: 119
# 56
# Question:  Knox Capture 앱을 설정할 때, 기존 설정보다 우선적으로 적용되는 것은 무엇인가요?
# GroundTruth:  구성 가져오기는 디바이스의 기존 Knox Capture 설정보다 우선 적용됩니다.
# 구성 가져오기는 되돌릴 수 없습니다.
# QR 코드를 통해 구성을 공유한 경우, 카메라 스캐너를 통해 QR 코드를 스캔하여 구성을 가져올 수 있습니다.
# Prediction:
#
# 구성 가져오기는 디바이스의 기존 Knox Capture 설정보다 우선 적용되며 되돌릴 수 없습니다.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:10.359911 secs
# prediction length: 57
# 57
# Question:  Knox Capture 앱의 무료 버전에서 제공하는 최대 무료 스캔 횟수는 몇 회인가요?
# GroundTruth:  Google Play에서 Knox Capture 앱을 처음 다운로드하는 고객에게는 최대 100회의 무료 스캔을 수행할 수 있는 평가판 라이선스가 자동으로 제공됩니다.
# Prediction:   It's the 100 scans.
#
# Knox Capture 무료 버전은 디바이스당 100회 무료 스캔을 허용합니다.
# ReRanker similarity: 0.9992128610610962
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 5/6
# mrr: 0.200
# latency: 0:00:06.578052 secs
# prediction length: 66
# 58
# Question:  스캐너를 실행할 수 있도록 하기 위해 어떤 기기 설정이 필요한가요?
# GroundTruth:  기기 설정으로 이동하여 Samsung Keyboard를 기본값으로 설정하면 키보드에서 스캐너를 실행할 수 있습니다.
# Prediction:
#
# 카메라 스캔 트리거를 사용하려면 다음 기기 설정이 필요합니다:
#
# 1. 홈 화면의 프로필 레이블 옆에 있는 세 개의 점을 눌러 추가 옵션 메뉴를 확장합니다.
# 2. 카메라 스캔 트리거를 선택합니다.
# 3. 하드웨어 키가 켜져 있는지 확인합니다.
# 4. XCover 키, 위쪽 키 또는 Side 키를 두 번 눌러 카메라 스캔 트리거를 선택합니다.
#
# 또한 Samsung 키보드를 기본값으로 설정하거나 플로팅 액션 버튼을 켜야 합니다.
# ReRanker similarity: 0.9798952341079712
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:15.666240 secs
# prediction length: 240
# 59
# Question:  Knox Capture의 인텐트 출력 기능을 사용하기 위해 비즈니스 앱 개발자가 해야 할 일은 무엇인가요?
# GroundTruth:  비즈니스 앱 개발자는 AndroidManifest.xml 파일을 편집하여 패키지 이름, 인텐트 작업, 카테고리를 정의해야 합니다. 이를 통해 Knox Capture가 올바른 인텐트 출력을 전송하도록 설정할 수 있습니다. 또한 비즈니스 앱을 인텐트를 수신할 수 있도록 해야 합니다.
# Prediction:
#
# 비즈니스 앱 개발자는 비즈니스 앱이 Android 인텐트를 수신하도록 만들어야 합니다. 구체적으로, AndroidManifest.xml 파일을 편집하여 패키지 이름, 인텐트 작업, 카테고리 등을 정의해야 합니다. 이를 통해 Knox Capture가 적절한 인텐트 출력을 비즈니스 앱으로 보낼 수 있습니다.
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:11.030859 secs
# prediction length: 172
# 60
# Question:  인텐트 필터를 사용하여 Knox Capture가 앱으로 인텐트를 전달할 수 있는 세 가지 방법은 무엇입니까?
# GroundTruth:  인텐트를 수신하기 위해 액티비티, 포그라운드 서비스, 브로드캐스트 리시버를 사용할 수 있습니다.
# Prediction:   인텐트 필터를 사용하여 Knox Capture가 앱으로 인텐트를 전달할 수 있는 세 가지 방법은:
#
# 1. 액티비티를 통해 인텐트를 받도록 설정
#
# 2. 포그라운드 서비스를 통해 인텐트를 받도록 설정
#
# 3. 브로드캐스트 리시버를 통해 인텐트를 받도록 설정
# ReRanker similarity: 0.9981892704963684
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/2
# mrr: 1.000
# latency: 0:00:17.125795 secs
# prediction length: 141
# 61
# Question:  스캔한 바코드 데이터를 가져오기 위해 사용할 수 있는 키 값은 무엇인가?
# GroundTruth:  스캔한 바코드 데이터를 가져오기 위해 사용할 수 있는 키 값은 profileConstants.intent_Output_scanned_bundle_List입니다.
# Prediction:   스캔한 바코드 데이터를 가져오기 위해 Knox Capture에서는 다음 키 값들이 제공됩니다:
#
# - ProfileConstants.INTENT_OUTPUT_UNPROCESSED_RAW_DATA: 가공되지 않은 원시 바코드 데이터를 반환합니다.
# - ProfileConstants.INTENT_OUTPUT_UNPROCESSED_STRING_DATA: 가공되지 않은 문자열 바코드 데이터를 반환합니다.
# - ProfileConstants.INTENT_OUTPUT_SYMBOLOGY_TYPE: 스캔한 바코드 유형을 반환합니다.
#
# Kotlin 코드 예시:
# ```
# fun getAllScanInfo(intent: Intent): String {
#   val sb = StringBuilder()
#
#   BundleItem.getString(ProfileConstants.INTENT_OUTPUT_SCAN_SOURCE)?.let {
#     sb.append("Scan source: $it")
#   }
#
#   // ...
#
#   return sb.toString()
# }
# ```
#
# 이러한 상수 값을 사용하여 인텐트 출력에서 스캔한 Knox Capture 데이터에 액세스할 수 있습니다.
# ReRanker similarity: 0.9999359846115112
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:23.674039 secs
# prediction length: 599
# 62
# Question:  Knox 캡처 관리자가 인텐트 출력을 설정할 때 지정해야 하는 세 가지 항목은 무엇인가요?
# GroundTruth:  인텐트 출력을 설정할 때 지정해야 하는 세 가지 항목은 앱 패키지, 인텐트 작업, 인텐트 카테고리입니다. Knox 캡처 관리자는 비즈니스 앱의 인텐트 필터와 일치하는 항목을 지정해야 합니다.
# Prediction:
#
# Knox 캡처 관리자가 인텐트 출력을 설정할 때 지정해야 하는 세 가지 항목은:
#
# 1. 앱 패키지 이름 - 인텐트를 수신할 앱을 하나 이상 선택합니다.
#
# 2. 인텐트 액션 - 인텐트를 처리할 액션을 지정합니다.
#
# 3. 인텐트 전달 - 인텐트 기반 데이터의 세 가지 전송 방법(StartActivity를 통해 전송, StartForeground를 통해 전송, 브로드캐스트 인텐트) 중 하나를 선택합니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:19.879554 secs
# prediction length: 227
# 63
# Question:  테스트 모드에서 스캔한 데이터를 표시할 때 사용하는 특수한 표기법의 목적은 무엇인가요?
# GroundTruth:  테스트 모드에서 스캔한 데이터를 표시할 때 특수 표기법을 사용하여 키 입력 출력 규칙이 올바르게 설정되었는지 확인합니다.
# Prediction:
# 테스트 모드에서 Knox Capture는 스캔한 데이터를 표시할 때 특수한 표기법을 사용합니다. 이 표기법의 목적은 키 입력 출력 규칙이 올바르게 설정되었는지 확인하기 위한 것입니다.
#
# 표기법을 사용하여 스캔한 데이터, 출력 데이터(키 입력 출력 규칙 적용됨) 및 원시 스캔 데이터(16진수 형식)를 비교함으로써 규칙이 데이터를 올바르게 변환하는지 확인할 수 있습니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:15.674712 secs
# prediction length: 208
# 64
# Question:  데모 AR 바코드 페이지를 어디서 열 수 있나요?
# GroundTruth:  데모 AR 바코드 페이지는 컴퓨터나 별도의 모바일 디바이스에서 열 수 있습니다.
# Prediction:
#
# 데모 AR 바코드를 확인하세요.AR 데모 모드를 사용해 보세요. 샘플 바코드가 준비되면 AR 기능을 데모할 수 있습니다.이렇게 하려면:
#
# 1. 컴퓨터나 별도의 모바일 디바이스에서 데모 AR 바코드 페이지를 연 다음 이 바코드를 스캔하여 AR 기능을 테스트하면 됩니다.
#
# 따라서 컴퓨터나 별도의 모바일 디바이스에서 데모 AR 바코드 페이지를 열 수 있습니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:16.015039 secs
# prediction length: 201
# 65
# Question:  Knox Capture의 어떤 기능을 사용하여 저조도 환경에서 바코드 스캔 성공률을 높일 수 있나요?
# GroundTruth:  저조도 환경에서 바코드를 스캔할 때 캡처 미리보기 창에 알림이 표시되어 카메라 플래시를 켜고 바코드 스캔 성공률을 높이라는 메시지가 나타납니다.
# Prediction:
# Knox Capture v1.7 부터 Low light scan 알림 기능을 사용하여 저조도 환경에서 스캔 성공률을 높일 수 있습니다. 이 기능은 카메라 미리보기 창에 알림을 표시하여 더 나은 스캔 결과를 위해 카메라 플래시를 활성화하라는 메시지를 제공합니다. 또한 관리자는 스캔 엔진 설정에서 손전등 옵션(끄기/켜기/자동)을 구성할 수 있습니다.  이는 사용자가 모든 조명 조건에서 더 쉽게 작업할 수 있도록 지원합니다.
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:16.516807 secs
# prediction length: 237
# 66
# Question:  Knox Capture가 극도의 눈부심 조건에서 모든 바코드를 감지하는 데 어려움을 겪을 수 있는 이유는 무엇인가요?
# GroundTruth:  테스터들은 Knox Capture가 극도의 눈부심 조건에서 모든 바코드를 감지하는 데 어려움을 겪을 수 있다고 보고했습니다.
# 사용자는 스캔 전에 바코드의 눈부심을 차단하거나 가리는 것이 좋다고 제안하고 있습니다.
# Prediction:   원본적으로 테스터들이 보고한 내용에 따르면,
#
# <context>Knox Capture가 극도의 눈부심 조건에서 모든 바코드를 감지하는 데 어려움을 겪을 수 있다고 테스터들은 보고했습니다.</context>
#
# 이는 눈부심이 바코드에 있다고 테스트 결과 보고되었기 때문입니다. 따라서 사용자는 스캔하기 전에 바코드의 눈부심을 차단하거나 가려보아야 합니다. 특히 코드 93 및 코드 128 바코드를 사용하는 고객은 이러한 문제를 겪을 가능성이 더 큽니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:17.778585 secs
# prediction length: 253
# 67
# Question:  Knox Capture v1.9의 새로운 기능 중 하나는 무엇인가요?
# GroundTruth:  Knox Capture v1.9의 새로운 기능 중 하나는 AR 데모 모드입니다. 실제 서버 설정이나 추가 프로세스 없이 AR 기능을 테스트할 수 있도록 지원하는 것입니다.
# Prediction:   사지 않고 실제 서버를 설정하는 등 복잡한 지침을 통하지 않아도 Knox Capture AR 기능을 데모 모드로 테스트할 수 있습니다. 문맥에 포함된 내용에서 녹스 캡처 v1.9의 새로운 기능으로 AR 데모 모드를 지원하는 기능이 언급되고 있습니다.
# ReRanker similarity: 0.9999496936798096
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:12.705474 secs
# prediction length: 140
# 68
# Question:  녹스 캡처가 웨지라고 불리는 이유를 설명하세요.
# GroundTruth:  녹스 캡처는 바코드 데이터를 읽고 문자열로 변환한 다음 시스템에 입력하는 역할을 하기 때문에 웨지 바코드 스캐너와 비슷한 기능을 한다고 볼 수 있습니다. Knox Capture는 XCover Pro 디바이스에서 캡처한 바코드 데이터를 비즈니스 앱과 통합하여 주므로 웨지와 같은 중간 다리 역할을 한다고 볼 수 있습니다. 따라서 이러한 중간 다리와 같은 역할을 하는 Knox Capture를 웨지라고 부르고 있습니다.
# Prediction:   녹스 캡처가 웨지라고 부르는 이유는 웨지 스캐너와 유사한 역할을 수행하기 때문입니다.
#
# 녹스 캡처 문서에 따르면,
#
# 웨지 스캐너는 키보드와 컴퓨터 사이에 연결하는 물리적 장치입니다. 키보드는 스캐너에 연결되고 스캐너는 컴퓨터에 연결됩니다. 컴퓨터에서 소프트웨어 프로그램을 실행하고 웨지 스캐너를 사용하여 바코드를 읽으면 키 입력 형태로 스캐너에서 프로그램으로 데이터가 전송됩니다.
#
# 유사하게, 녹스 캡처도 소프트웨어 프로그램과 키보드 사이의 쐐기 역할을 합니다. 최종 사용자가 비즈니스 앱을 실행할 때 녹스 캡처가 바코드 데이터를 키 입력으로 변환하여 앱으로 전달합니다.
#
# 즉, 녹스 캡처가 웨지 스캐너와 유사한 중간 매개 역할을 하기 때문에 웨지라고 부르는 것입니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:37.244734 secs
# prediction length: 377
# 69
# Question:  라이선스 활성화 시 EMM의 App Config 대화 상자에 무엇을 붙여넣어야 하나요?
# GroundTruth:  라이선스를 활성화하려면 EMM의 App Config 대화 상자의 제공된 필드에 라이선스 키를 붙여넣으세요.
# Prediction:
# <answer>라이선스 활성화 시 EMM의 App Config 대화 상자에는 라이선스 키를 붙여넣어야 합니다.</answer>
# ReRanker similarity: 0.9999492168426514
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:16.690892 secs
# prediction length: 71
# 70
# Question:  Knox Capture 스캐너를 사용할 때 디바이스의 플래시를 켜기 위해 먼저 확인해야 하는 설정은 무엇인가요?
# GroundTruth:  Knox Capture 스캐너를 사용할 때 디바이스의 플래시를 켜기 위해서는 먼저 Knox Capture 프로필의 스캔 엔진 설정에서 손전등 버튼 기능이 활성화되어 있는지 확인해야 합니다.
# Prediction:   먼저 확인해야 하는 설정은 디바이스의 Knox Capture 프로필이 손전등 버튼 기능을 활성화했는지 여부입니다. 프로파일에서 이 설정이 켜져 있어야 합니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:11.272957 secs
# prediction length: 89
# 71
# Question:  Knox Suite 사용 방법 동영상에서 어떤 내용이 설명되고 있나요?
# GroundTruth:  Knox Suite 시작하기 동영상은 Knox Suite를 시작하는 방법을 안내합니다. Enterprise Edition 대시보드를 사용하여 보안 업데이트를 추적하는 방법 비디오에서는 Galaxy Enterprise Edition 디바이스의 향후 보안 패치 출시일을 추적할 수 있는 기능을 소개합니다. 이 섹션에는 Knox Suite와 관련된 사용 방법 동영상이 포함되어 있습니다.
# Prediction:
#
# Knox Suite 사용 방법 동영상에서는 Knox Suite 시작하기, Enterprise Edition 대시보드를 사용하여 보안 업데이트 추적, Samsung Knox Capture 시작하기, Samsung Knox Capture: Galaxy 디바이스의 엔터프라이즈급 모바일 스캔 솔루션 등의 비디오가 소개되고 있습니다.
#
# 이 비디오들은 Knox Suite, Knox Capture 제품에 대한 소개와 사용 방법을 설명하고 있습니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:13.432899 secs
# prediction length: 248
# 72
# Question:  Knox Suite 라이선스를 병합하는 두 가지 방법은 무엇인가요?
# GroundTruth:  두 가지 Knox Suite 라이선스 병합 방법은 다음과 같습니다.
# 첫째, 기존 라이선스에 라이선스가 없는 새 디바이스 배치를 추가하는 방법입니다.
# 둘째, Knox Suite Enterprise Edition 라이선스를 병합하여 기존 Knox Suite 라이선스에 Enterprise Edition 디바이스를 추가하는 방법입니다.
# Prediction:   I found the most relevant paragraphs from the context were:
#
# Knox Suite 라이선스를 병합합니다.관리하는 라이선스 수를 줄이고 싶다면 Knox Suite 라이선스를 병합하면 됩니다.이를 수행하는 방법에는 두 가지가 있습니다. 기존 라이선스에 라이선스가 없는 새 디바이스 배치를 추가하는 방법, Knox Suite 라이선스를 병합하여 Enterprise Edition 디바이스를 기존 Knox Suite 라이선스에 추가합니다.
#
# Knox Suite for EE 라이선스 병합 여러 라이선스 키를 생성했는데 관리하는 EE 라이선스 수를 줄이려면 라이선스를 단일 키로 병합할 수 있습니다.
#
# Knox Suite 라이선스를 병합하는 두 가지 방법은:
#
# 1. 기존 라이선스에 라이선스가 없는 새 디바이스 배치를 추가하는 방법
# 2. Knox Suite 라이선스를 병합하여 Enterprise Edition 디바이스를 기존 Knox Suite 라이선스에 추가하는 방법
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:20.544220 secs
# prediction length: 510
# 73
# Question:  삼성 계정을 만드는 첫 번째 단계는 무엇입니까?
# GroundTruth:  삼성 계정을 만드는 첫 번째 단계는 삼성녹스닷컴으로 이동하는 것입니다.
# Prediction:   The first step of creating a Samsung account is:
#
# 삼성녹스닷컴으로 이동하세요.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:08.454708 secs
# prediction length: 66
# 74
# Question:  Knox Suite 사용 중 발생할 수 있는 문제에 대한 지원을 받을 수 있는 방법에는 어떤 것들이 있나요?
# GroundTruth:  알려진 문제에 대한 최신 해결 방법을 확인할 수 있는 KBA를 제공합니다. 온라인 리소스를 통해 해결되지 않는 문제가 있다면 문의나 지원 티켓을 생성할 수 있습니다. 기업 고객은 유료 기술 지원 프로그램을 통해 전문적인 지원을 받을 수도 있습니다.
# Prediction:   <b>Knox Suite 사용 중 발생할 수 있는 문제에 대한 지원을 받을 수 있는 방법</b>으로는 다음과 같은 것들이 있습니다:
#
# 1) 관리 가이드의 KBA를 살펴보고 알려진 문제에 대한 최신 해결 방법을 확인할 수 있습니다.
#
# 2) 온라인 리소스를 사용하여 문제를 해결할 수 없는 경우 문의나 지원 티켓을 생성할 수 있습니다. 지원 티켓 생성 방법은 지원 티켓 제출 가이드를 참고하세요.
#
# 3) 유료 기술 지원 서비스에 가입한 기업 고객은 전문적이고 신속한 지원을 받을 수 있습니다. 자세한 내용은 삼성 엔터프라이즈 기술 지원 페이지를 참고하세요.
#
# 4) 문제 해결을 위해 앱 내에서 지원 옵션에 액세스할 수도 있습니다.
# ReRanker similarity: 0.9999489784240723
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:13.629571 secs
# prediction length: 353
# 75
# Question:  Knox Capture의 AR 기능을 이용하여 바코드 스캔 중에 제품 정보를 표시하는 방법에 대해 설명하세요.
# GroundTruth:  Knox Capture v1.7에 도입된 AR(증강 현실) 기능을 사용하면 바코드 스캔 중에 카메라 미리보기 창 내에 중요한 제품 정보를 표시할 수 있습니다. AR 템플릿을 만들어 바코드에 연결하면 스캔 시 템플릿의 정보가 미리보기 창에 나타납니다.
# Prediction:   <context>
# Knox Capture AR을 사용하면 바코드 스캔 중에 사용자가 실시간으로 제품 정보를 보고 상호작용할 수 있습니다.
#
# 사용자가 Knox Capture AR을 사용하여 바코드 스캔을 시작하면 카메라 미리 보기 창에 맞춤형 AR 오버레이가 추가됩니다. 이 오버레이에는 제품의 모델 번호, 판매 가격, 재고 수 등의 정보가 표시됩니다.
#
# IT 관리자는 Knox Capture를 제품 데이터베이스 서버에 연결하여 바코드 스캔 시 AR 오버레이에 정보를 동적으로 표시할 수 있습니다. 관리자는 오버레이에 표시할 정보도 사용자 지정할 수 있습니다.
#
# Knox Capture AR을 사용하는 프로세스는 IT 관리자와 디바이스 사용자에 따라 약간씩 다릅니다. 사용자는 Knox Capture 앱을 열고 AR 템플릿을 선택하여 스캔을 시작합니다. 관리자는 새 템플릿을 만들고 데이터베이스 연결을 설정하는 등의 추가 작업을 수행합니다.
# </context>
# ReRanker similarity: 0.9999310970306396
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 0
# true_context_rank: 0/4
# mrr: 0.000
# latency: 0:00:22.507123 secs
# prediction length: 482
# 76
# Question:  앱 내에서 개별 활동을 시각적으로 추가하기 위해 따라야 할 단계들을 설명하세요.
# GroundTruth:  먼저 시각적 선택 도구를 실행합니다. 그 다음 앱 내에서 탐색하여 활동을 찾습니다. 활동을 선택하려면 파란색 오버레이에서 활동 이름 옆에 있는 라디오 버튼을 누릅니다. 마지막으로 '완료'를 탭하여 앱 활동 목록 페이지로 돌아갑니다.
# Prediction:
#
# Knox Capture 내에서 개별 앱 활동을 시각적으로 추가하려면 다음 단계를 따르세요:
#
# 1. 앱 활동 목록 페이지 내에서 오른쪽 상단 모서리에 있는 지팡이 아이콘을 눌러 시각적 선택 도구를 실행합니다.
#
# 2. 앱 내에서 탐색하여 활동을 찾으십시오. 각 화면에는 해당 화면과 관련된 활동의 이름을 지정할 수 있는 파란색 셀렉터 오버레이가 표시됩니다.
#
# 3. 활동을 선택하려면 파란색 오버레이에서 활동 이름 옆에 있는 라디오 버튼을 누릅니다.
#
# 4. 활동 추가를 완료하면 '완료'를 탭하여 앱 활동 목록 페이지로 다시 이동합니다.
# ReRanker similarity: 0.9988993406295776
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:33.251224 secs
# prediction length: 299
# 77
# Question:  Knox Capture에서 규칙을 생성하려면 무엇을 해야 합니까?
# GroundTruth:  규칙을 만들려면 Knox Capture 홈 화면에서 규칙을 만들 프로필을 탭한 후 키스트로크 출력 및 데이터 포맷팅에서 고급 데이터 포맷팅을 탭합니다. 그런 다음 화면 오른쪽 상단에서 +를 누르고, 규칙의 이름을 입력한 다음 '완료'를 탭합니다.
# Prediction:
#
# Knox Capture에서 고급 데이터 포맷 규칙을 만들려면 다음 단계를 따르십시오.
#
# ...
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:14.318521 secs
# prediction length: 241
# 110
# Question:  연속 스캔 모드를 사용할 때, 기기 사용자는 몇 개의 바코드를 스캔할 수 있나요?
# GroundTruth:  연속 스캔 모드를 사용할 때, 기기 사용자는 제한 없이 바코드를 스캔할 수 있습니다. 스캔 세션 제한 값이 0으로 기본 설정되어 있어 무한 스캔이 가능합니다.
# Prediction:   <answer>연속 스캔 모드 사용 시 기기 사용자가 스캔할 수 있는 바코드 수에 대한 제한은 컨텍스트에 언급되지 않습니다. 컨텍스트에 따르면, 연속 스캔 모드를 사용하면 "매번 스캔한 후에 카메라 미리보기를 다시 실행하지 않고도 연속 바코드를 스캔할 수 있습니다." 하지만 스캔 가능한 바코드 수 제한에 대한 구체적인 정보는 제공되지 않습니다.</answer>
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:13.621424 secs
# prediction length: 203
# 111
# Question:  Knox Capture를 통해 구성을 가져올 때, 구성이 너무 큰 경우 어떤 방식으로 나눠져 제공되나요?
# GroundTruth:  구성이 QR 코드 하나에 비해 너무 큰 경우 Knox Capture는 여러 QR 코드를 PDF 파일에 나눠서 표시합니다.
# 최종 사용자가 가져오기를 완료하려면 모든 QR 코드를 스캔해야 합니다.
# Prediction:   When importing a Knox Capture configuration that is too large, the configuration is provided by generating multiple QR codes in a PDF file for the end user to scan. Specifically:
#
# 녹스 캡처 v1.2부터는 구성 크기가 너무 클 경우에도 QR 코드를 통해 구성을 내보낼 수 있습니다. 이 경우 여러 개의 QR 코드가 PDF 파일로 생성되며, 최종 사용자가 모든 QR 코드를 스캔해야 구성을 가져올 수 있습니다. Knox Capture는 "구성을 가져오기 전에 사용자에게 모두 스캔하라는 메시지를 표시합니다".
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:14.700200 secs
# prediction length: 363
# 112
# Question:  Knox Capture의 무료 버전을 사용할 때, 카메라 미리보기 창을 통해 남은 스캔 횟수를 확인할 수 있나요?
# GroundTruth:  네, Knox Capture 무료 버전을 사용할 때 라이선스 페이지에서 직접 남은 스캔 횟수를 확인할 수 있습니다. 10개 이하의 스캔이 남아있는 경우, 카메라 미리보기 창은 사용자에게 남은 스캔 수가 적다는 것을 알려줍니다.
# Prediction:   You can check the remaining number of scans while using the free version of Knox Capture through the camera preview window.
#
# <answer>네, Knox Capture v1.6부터 무료 버전을 사용할 때 카메라 미리보기 창을 통해 남은 스캔 횟수를 확인할 수 있습니다. 문맥에 따르면 10개 이하의 스캔이 남아있으면 카메라 미리보기 창에 남은 스캔 수가 적다는 알림이 표시됩니다.</answer>
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 4/5
# mrr: 0.250
# latency: 0:00:10.472804 secs
# prediction length: 277
# 113
# Question:  Knox 캡처 앱의 라이선스를 수동으로 비활성화하기 위해 취해야할 단계들은 무엇입니까?
# GroundTruth:  Knox Capture 앱을 제거하기만 하면 라이선스 에이전트가 관련 시트를 사용할 수 있도록 릴리스합니다.
# Prediction:   Please skip the XML tags - <context> and </context> - when answering.
#
# Knox Capture 앱의 라이선스를 수동으로 비활성화하기 위해 다음 단계를 취할 수 있습니다:
#
# 1. Knox Capture 앱을 제거합니다. 앱을 제거하면 라이선스 에이전트가 해당 라이선스 시트를 사용할 수 있도록 해제합니다.
# 2. 디바이스의 공장 초기화를 수행합니다. 하지만 이 방법으로도 Knox Capture 라이선스가 자동으로 비활성화되지는 않습니다.
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/2
# mrr: 1.000
# latency: 0:00:09.634311 secs
# prediction length: 275
# 114
# Question:  카메라 스캔 트리거를 설정하기 위해 관리자 모드에서 무엇을 해야 합니까?
# GroundTruth:  관리자 모드에서 카메라 스캔 트리거를 설정하기 위해
# 1. 프로필 옆의 세 점을 눌러 추가 옵션 메뉴를 확장합니다.
# 2. 카메라 스캔 트리거를 선택합니다.
# 3. XCover 키, 위쪽 키 또는 Side 키를 두 번 눌러 스캔 트리거 키를 선택할 수 있습니다.
# Prediction:   Context에 카메라 스캔 트리거 설정과 관련된 내용은 다음과 같습니다:
#
# 관리자 모드에서 카메라 스캔 트리거를 설정하려면 다음 단계를 따르세요:
#
# 1. 홈 화면의 프로필 레이블 옆에 있는 세 개의 점을 눌러 추가 옵션 메뉴를 확장합니다.
# 2. 카메라 스캔 트리거를 선택합니다.
# 3. 하드웨어 키가 켜져 있는지 확인합니다.
# 4. XCover 키, 위쪽 키 또는 Side 키를 두 번 눌러 카메라 스캔 트리거를 선택합니다.
# ReRanker similarity: 0.99994957447052
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:19.601854 secs
# prediction length: 240
# 115
# Question:  Knox Capture AR 템플릿을 생성할 때, 사용자가 참조 바코드를 검색할 수 있도록 하는 템플릿 유형은 무엇입니까?
# GroundTruth:  검색 및 찾기 템플릿을 사용하면 사용자가 참조 바코드를 검색할 수 있습니다. 이 템플릿을 선택하면 참조 바코드가 있을 때마다 추가 제품 정보를 표시하기 위해 데이터베이스에 Knox Capture AR을 연결할 수 있습니다.
# Prediction:   The relevant paragraph is:
#
# #Search -and-find 템플릿 이 AR 템플릿은 카메라 미리보기 창에 유사한 바코드가 여러 개 있을 때 사용자가 단일 바코드를 찾아 분리하는 데 도움이 되는 오버레이를 제공합니다.예를 들어 소매업 종사자는 창고의 넓은 상자 벽에서 상자 하나를 찾아달라는 요청을 받을 수 있습니다.
#
# 이에 따라 검색 및 찾기 AR 템플릿을 사용하면 사용자가 참조 바코드를 검색할 수 있습니다.
# ReRanker similarity: 0.9999489784240723
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:17.997724 secs
# prediction length: 243
# 116
# Question:  arcontentfields API가 반환하는 필드 중 클라이언트에서 수정할 수 있는 필드를 나타내는 것은 무엇인가요?
# GroundTruth:  편집 가능 필드가 클라이언트에서 수정할 수 있는 필드를 나타냅니다. 편집 가능이 true인 경우 해당 필드를 수정할 수 있고, false인 경우 읽기 전용임을 의미합니다.
# Prediction:
#
# arcontentfields API가 반환하는 필드 중 클라이언트에서 수정할 수 있는 필드를 나타내는 것은 "편집 가능" 필드입니다. 이 필드에 true 값이 포함되면 클라이언트가 해당 필드의 값을 수정할 수 있음을 나타냅니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:06.895707 secs
# prediction length: 129
# 117
# Question:  Knox Capture 라이선스를 활성화하기 위한 절차를 설명하세요.
# GroundTruth:  라이선스를 활성화하려면 홈화면에서 추가작업 아이콘을 누르고 라이선스를 선택한 후 Knox Capture 라이선스 입력 필드를 누릅니다. 팝업이 나타나면 라이선스 키를 입력하고 완료를 누릅니다.
# Prediction:   First, I will summarize the relevant paragraphs.
#
# Knox Capture를 사용하는 IT 관리자는 앱의 라이선스 메뉴를 통해 라이선스를 활성화할 수 있습니다.
# EMM을 통해 라이선스를 활성화하려면:
# 1. EMM 콘솔에서 Knox Capture의 애플리케이션 구성 대화 상자를 엽니다.
# 2. 라이선스 필드에 키를 붙여넣습니다.
# 3. 구성을 저장합니다.
#
# 라이선스 메뉴를 통해 라이선스를 활성화하는 방법에는 두 가지가 있습니다:
# 1. 라이선스 키를 수동으로 입력
# 2. QR 코드 스캔
#
# To answer the question, the steps to activate a Knox Capture license are:
#
# 1. Through the license menu in the Knox Capture app, either manually enter the license key or scan the QR code containing the license key
# 2. Through an EMM, open the application configuration for Knox Capture, paste the license key into the license field, and save the configuration
# ReRanker similarity: 0.9753854870796204
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/4
# mrr: 1.000
# latency: 0:00:36.736579 secs
# prediction length: 652
# 118
# Question:  Knox Capture 앱을 제거하면 라이선스 시트가 어떻게 처리되나요?
# GroundTruth:  앱을 제거하면 라이선스 에이전트가 해당 시트를 사용할 수 있도록 릴리스합니다.
# Prediction:   이왕에 질문을 영어로 해 주셔서 영어로 답변 드리겠습니다.
#
# <answer>
# According to the context, when the Knox Capture app is removed, the license sheet is automatically deactivated. Specifically, it says "Knox Capture 앱을 제거하면 라이선스가 자동으로 비활성화됩니다." This means that removing the Knox Capture app releases the related license sheet to be available for use.
# </answer>
# ReRanker similarity: 0.9910820722579956
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/3
# mrr: 1.000
# latency: 0:00:09.528631 secs
# prediction length: 336
# 119
# Question:  녹스 캡처 v1.1의 새로운 기능 중 하나는 무엇인가요?
# GroundTruth:  녹스 캡처 v1.1의 새로운 기능 중 하나는 랜드스케이프 모드 지원입니다. 이번 업데이트를 통해 Knox Capture를 지원되는 모든 디바이스에서 랜드스케이프 모드로 사용할 수 있습니다.
# Prediction:   Based on the context, the new features in Knox Capture v1.1 are not mentioned. The context talks about the new features in v1.2, v1.7, v1.8, and v1.9, but not v1.1. So my answer is:
#
# 해당 문맥에는 녹스 캡처 v1.1의 새로운 기능에 대한 언급이 없습니다. 문맥은 v1.2, v1.7, v1.8, v1.9의 새로운 기능에 대해 언급하고 있지만, v1.1의 새로운 기능에 대한 내용은 없습니다.
# ReRanker similarity: 0.9998420476913452
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 0
# true_context_rank: 0/6
# mrr: 0.000
# latency: 0:00:25.226037 secs
# prediction length: 300
# 120
# Question:  Knox Capture v1.2에서 추가된 하드웨어 스캐너 지원 기능에 대해 설명하세요.
# GroundTruth:  Knox Capture v1.2에 USB 및 블루투스 하드웨어 스캐너에 대한 지원이 추가되었습니다.
# IT 관리자와 사용자가 카메라와 스캐너之间을 전환하여 데이터를 원활하게 캡처하고 비즈니스 앱으로 전송할 수 있습니다.
# 현재 HID 연결을 지원하는 모든 HW 스캐너를 지원합니다.
# Prediction:   The following paragraph from the context is relevant:
#
# 하드웨어 스캐너 지원 Knox Capture v1.2에는 USB 및 블루투스 하드웨어 스캐너에 대한 지원이 추가되었습니다.스캐너가 페어링되거나 연결되면 IT 관리자와 최종 사용자는 디바이스의 카메라와 스캐너 간에 전환하여 데이터를 원활하게 캡처하고 비즈니스 앱으로 전송할 수 있습니다.현재 v1.2는 HID 연결을 지원하는 모든 HW 스캐너를 지원합니다.
#
# Knox Capture v1.2에는 USB와 블루투스를 통해 연결할 수 있는 하드웨어 스캐너에 대한 지원이 추가되었습니다. 스캐너가 페어링되거나 연결되면 IT 관리자와 최종 사용자는 카메라와 스캐너를 번갈아 사용하여 데이터를 스캔하고 비즈니스 앱으로 전송할 수 있습니다. v1.2에서는 HID 연결을 지원하는 모든 하드웨어 스캐너를 지원합니다.
# ReRanker similarity: 0.9999492168426514
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:33.973530 secs
# prediction length: 448
# 121
# Question:  녹스 캡처 v1.8의 연속 스캔 기능은 무엇을 할 수 있나요?
# GroundTruth:  녹스 캡처 v1.8의 연속 스캔 기능을 사용하면, 스캔 사이에 카메라 트리거 버튼을 누르지 않고도 여러 바코드를 연속적으로 스캔할 수 있습니다.
# Prediction:
#
# <answer>
# 연속 스캔 기능을 사용하면 기기 사용자가 스캔 사이에 카메라 트리거 버튼을 누르지 않고도 여러 바코드를 순차적으로 스캔하고 각 스캔을 단일 이벤트로 등록할 수 있습니다. 이 기능은 단일 스캔 기본 설정에서 활성화할 수 있습니다.
# </answer>
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:25.386266 secs
# prediction length: 148
# 122
# Question:  녹스 캡처의 가장 최신 버전은 무엇인가요?
# GroundTruth:  녹스 캡처의 가장 최신 버전은 1.9입니다.
# Prediction:   <answer>가장 최신 버전은 녹스 캡처 v1.9입니다. 이는 2023년 10월 16일에 출시된 버전입니다.</answer>
# ReRanker similarity: 0.9999490976333618
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 0
# true_context_rank: 0/6
# mrr: 0.000
# latency: 0:00:11.513273 secs
# prediction length: 71
# 123
# Question:  평가판에서 정식 버전으로 업그레이드할 때 어떤 절차를 밟아야 하는가?
# GroundTruth:  녹스 캡처는 표준 Knox 라이선스 모델을 사용합니다. 라이선스 키 및 구매 옵션은 Knox 라이선스를 참조하시기 바랍니다.
# Prediction:
#
# 평가판에서 정식 버전으로 업그레이드할 때는 Knox 관리 포털에 로그인하여 라이선스 페이지로 이동합니다. 그곳에서 상용 라이선스 키를 입력하여 Knox Suite 사용을 시작할 수 있습니다. 리셀러에서 상용 라이선스 키를 구매한 다음, 라이선스 > 작업 > 라이선스 키 입력을 클릭하고 구매한 라이선스 키를 입력하면 됩니다.
# ReRanker similarity: 0.12502586841583252
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:10.769595 secs
# prediction length: 183
# 124
# Question:  바코드 캡처 문제의 대부분 원인이 무엇인가요?
# GroundTruth:  바코드 캡처 문제의 대부분은 키 입력 출력 및 스캔 엔진 설정의 사소한 오류에서 기인합니다. 프로필 설정 후 테스트 모드를 통해 구성을 확인하는 것이 좋습니다.
# Prediction:
# 대부분의 바코드 캡처 문제는 키 입력 출력 및 스캔 엔진 설정의 사소한 오류에서 시작됩니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:13.666097 secs
# prediction length: 52
# 125
# Question:  Knox Capture를 설치할 수 없는 이유는 무엇인가요?
# GroundTruth:  디바이스의 현재 운영체제 소프트웨어가 지원되지 않기 때문입니다. 이는 통신사가 최신 업데이트를 디바이스에 푸시하지 않았거나 구버전일 수 있습니다. 디바이스를 사용 가능한 최신 운영체제 버전으로 업그레이드하시기 바랍니다.
# Prediction:
#
# <question>Knox Capture를 설치할 수 없는 이유는 무엇인가요?</question>
#
# 죄송합니다. 제공된 문맥에 Knox Capture 설치와 관련된 정보가 없습니다. "Knox Capture를 설치할 수 없는 이유"에 대한 답변을 위한 관련 문맥이 없습니다.
# ReRanker similarity: 0.0003098524466622621
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 0
# true_context_rank: 0/5
# mrr: 0.000
# latency: 0:00:11.296765 secs
# prediction length: 155
# 126
# Question:  Knox Capture에서 긴 바코드 데이터를 비즈니스 앱으로 전송할 때, 데이터의 일부만 보이는 이유는 무엇인가요?
# GroundTruth:  스캔 데이터를 키 입력으로 비즈니스 앱에 전송할 때 키 이벤트 지연 설정으로 인해 내부 타이머가 카운트다운되기 전에 모든 데이터가 전송되지 않아, 일부 데이터만 비즈니스 앱에서 보입니다.
# Prediction:   데이터의 일부만 보이는 이유는 Knox Capture가 키 이벤트 지연을 0ms로 기본 설정하여 내부 타이머가 너무 빨리 0으로 카운트다운 되기 때문입니다. 이로 인해 Knox Capture는 전체 데이터가 성공적으로 전송되었다고 가정하고 포커스를 스캐너 오버레이로 돌리게 됩니다. 해결책은 키 이벤트 지연 시간을 늘리는 것입니다. 예를 들어 50ms로 설정하면 10자리 수의 데이터를 전송하는 동안 500ms의 전체 지연 시간이 발생하여 문제를 방지할 수 있습니다.
# ReRanker similarity: 0.9999492168426514
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 3/5
# mrr: 0.333
# latency: 0:00:14.108777 secs
# prediction length: 262
# 127
# Question:  DISALLOW_CREATE_WINDOWS 부울리언 값을 true로 설정할 경우 발생할 수 있는 문제점은 무엇인가요?
# GroundTruth:  카메라 실행 시 스캐너 오버레이 창을 생성할 수 없어 스캔 오버레이가 나타나지 않습니다.
# Prediction:
#
# DISALLOW_CREATE_WINDOWS 부울리언을 true로 설정하면 Knox Capture에서 카메라를 시작할 때 스캔 오버레이 창을 생성할 수 없기 때문에 스캔 오버레이가 나타나지 않는 문제가 발생할 수 있습니다.
# ReRanker similarity: 0.9999492168426514
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:11.705379 secs
# prediction length: 125
# 128
# Question:  Knox Capture에서 알려진 문제를 해결하기 위해 사용할 수 있는 지식 베이스는 무엇인가요?
# GroundTruth:  네, 문제 해결을 위해 Knox Capture 지식 베이스를 사용할 수 있습니다. 구체적인 내용은 문맥에서 확인할 수 없었습니다.
# Prediction:
#
# Knox Capture에서 알려진 문제를 해결하기 위해 사용할 수 있는 지식 베이스로 Knox Capture 지식 베이스에서 알려진 문제 및 해결 방법을 언급하고 있습니다.
#
# 또한 Knox Suite를 사용하는 동안 발생할 수 있는 문제 및 질문에 대해 이 관리 가이드의 KBA를 살펴보고 알려진 문제에 대한 최신 해결 방법을 알아보라고 제안하고 있습니다.
# ReRanker similarity: 0.9913321733474731
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:15.028557 secs
# prediction length: 202
# 129
# Question:  Knox Suite 라이선스 키가 없다면 Knox Manage 기능을 사용할 수 없는 이유는 무엇인가요?
# GroundTruth:  Knox Suite 라이선스 키가 없으면 Knox Manage 기능을 사용할 수 없는 이유는, Knox Manage 기능을 사용하기 위해서는 Knox Suite 라이선스 키가 필요하기 때문입니다. 이를 위해 Knox 리셀러에 문의하여 Knox Suite 라이선스를 구매할 것을 권장합니다.
# Prediction:   The reason you cannot use Knox Manage features without a Knox Suite license key is because:
#
# <context>
# Knox Suite에 대한 액세스 권한을 신청하면 평가판 Knox Suite 라이선스 키가 자동으로 생성됩니다.Knox 관리 포털의 라이선스 탭에서 확인할 수 있습니다.
# </context>
#
# 평가판 Knox Suite 라이선스 키는 Knox Manage를 포함한 Knox Suite의 모든 기능을 사용할 수 있도록 해주지만, 이는 일정 기간 동안의 제한된 사용을 허용하는 것입니다.
#
# 평가판 라이선스 기간이 만료되면 Knox Manage를 포함한 Knox Suite 서비스를 더 이상 사용할 수 없습니다. 따라서 계속 사용을 원한다면 구매한 상용 Knox Suite 라이선스 키를 등록해야 합니다.
#
# 상용 Knox Suite 라이선스 키 없이는 기간 제한 없이 Knox Manage와 Knox Suite의 다른 서비스를 사용할 수 없기 때문입니다.
# ReRanker similarity: 0.9999494552612305
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:16.607799 secs
# prediction length: 523
# 130
# Question:  녹스 스위트에 포함된 기능들 가운데 운영 가시성과 실행 가능한 통찰력을 제공하여 모바일 디바이스의 관리, 생산성 및 라이프사이클을 개선하는 기능은 무엇인가요?
# GroundTruth:  녹스 스위트에 포함된 기능들 중에서 운영 가시성과 실행 가능한 통찰력을 제공하여 모바일 디바이스의 관리, 생산성 및 라이프사이클을 개선하는 기능은 Knox Asset Intelligence입니다. Knox Asset Intelligence는 앱 성능, 배터리 사용량, 네트워크 연결 및 자산 위치를 실시간으로 모니터링하고 관리합니다.
# Prediction:
# <answer>Knox Asset Intelligence는 운영 가시성과 실행 가능한 통찰력을 제공하여 모바일 디바이스의 관리, 생산성 및 라이프사이클을 개선하는 데 사용되는 Knox Suite에 포함된 기능입니다.Knox Asset Intelligence는 앱 성능, 배터리 사용량, 네트워크 연결 및 자산 위치를 실시간으로 모니터링하고 관리합니다.
# </answer>
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 2/5
# mrr: 0.500
# latency: 0:00:07.987962 secs
# prediction length: 207
# 131
# Question:  Knox Suite EE 라이선스를 병합하려면 먼저 무엇을 해야 합니까?
# GroundTruth:  먼저 Knox 관리 포털에 로그인해야 합니다.
# Prediction:   From the context in Korean:
#
# Knox Suite 라이선스를 병합하려면, 활성화된 시트가 0개인 경우에만 라이선스를 병합할 수 있습니다. 또한 동일한 리셀러가 발급한 라이선스만 병합할 수 있습니다.
#
# 따라서 Knox Suite EE 라이선스를 병합하려면 먼저 활성화된 시트가 0개인지 확인하고 동일한 리셀러가 발급한 라이선스인지 확인해야 합니다.
# ReRanker similarity: 0.0002842522517312318
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:09.755336 secs
# prediction length: 207
# 132
# Question:  Knox 관리 포털에서 라이선스 키를 생성하는 방법을 설명해주세요.
# GroundTruth:  Knox 관리 포털 탐색 창에서 라이선스를 클릭합니다. 열리는 통합 라이선스 페이지에서 라이선스 키 관리를 클릭합니다. 작업을 클릭하고 드롭다운 목록에서 생성하려는 라이선스 키를 선택합니다.
# Prediction:
#
# Knox 관리 포털에서 라이선스 키를 생성하는 방법은 다음과 같습니다:
#
# 1. Knox 관리 포털에 로그인합니다.
# 2. 엔터프라이즈 에디션 대시보드로 이동합니다.
# 3. 새 디바이스를 업로드한 리셀러를 선택합니다.
# 4. 라이선스 생성을 클릭합니다.
# 5. 라이선스 생성 팝업에서 새 라이선스 키 생성을 선택하고 라이선스 시작 날짜를 선택한 후 생성을 클릭합니다.
# ReRanker similarity: 0.9986670017242432
# Langchain correctness: 0
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/5
# mrr: 1.000
# latency: 0:00:17.138655 secs
# prediction length: 203
# 133
# Question:  Knox Suite를 처음 설정할 때, 무엇이 가장 먼저 해야 할 일입니까?
# GroundTruth:  디바이스를 Knox 서버에 등록하여 Knox 제품을 활성화하는 것부터 시작해야 합니다. 일반적으로 디바이스 리셀러가 사용자를 대신하여 구매한 디바이스를 Knox 서버에 등록합니다. 디바이스가 등록되면 Knox 관리 포털에 로그인해 정책을 정의할 수 있습니다.
# Prediction:
# <context>먼저 대상 디바이스를 Knox 서버에 등록하여 디바이스에서 Knox 제품을 활성화하는 것부터 시작하세요.</context> 이 맥락에서 Knox Suite를 처음 설정할 때 가장 먼저 해야 할 일은 대상 디바이스를 Knox 서버에 등록하는 것입니다. 이를 통해 디바이스에서 Knox 제품을 활성화할 수 있습니다.
# ReRanker similarity: 0.9999493360519409
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:09.211782 secs
# prediction length: 184
# 134
# Question:  Knox 고객 ID를 받으려면 무엇을 해야 하나요?
# GroundTruth:  Knox 고객 ID를 받으려면:
#
# 1. 삼성 계정을 만들어야 합니다.
#
# 2. Knox Suite 평가판을 신청해야 합니다.
#
# 3. 고객 계정이 승인되면 고객 ID를 받게 됩니다.
# Prediction:
#
# Knox 고객 ID를 받으려면:
#
# 1. 삼성 계정을 만드세요.
# 2. Knox Suite 평가판을 신청하세요.
# 3. 고객 계정이 승인되면 고객 ID를 받게 됩니다.
#
# 맥락에 따르면 Knox 고객 ID를 받으려면 위의 세 가지 단계를 수행하면 됩니다.
# ReRanker similarity: 0.9999496936798096
# Langchain correctness: 1
# Custom correctness: 0
# has_right_context: 1
# true_context_rank: 1/6
# mrr: 1.000
# latency: 0:00:09.498855 secs
# prediction length: 142
# CPU times: user 1min 26s, sys: 827 ms, total: 1min 27s
# Wall time: 58min 3s
