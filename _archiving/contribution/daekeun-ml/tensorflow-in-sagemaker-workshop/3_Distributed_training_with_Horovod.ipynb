# %% [markdown]
# # [Module 4] Distributed training with horovod
#
# Horovod는 MPI(Message Passing Interface; 메세지 전달 인터페이스)를 기반으로 하는 분산 학습 프레임워크(distributed training framework)입니다. Horovod는 TensorFlow 버전 1.12 이상에서만 사용할 수 있습니다. 자세한 내용은 [Horovod README](https://github.com/uber/horovod)에서 확인할 수 있습니다.
#
# Horovod를 활성화하려면 학습 스크립트를 약간 수정해야 합니다. 본 실습에서 이를 직접 수행해 보겠습니다.

# %% [markdown]
# ## Create a training script that support Horovod distributed training
#
# `training_script/cifar10_keras_sm.py`의 사본을 생성 후 **<font color='red'>(주의: `training_script/cifar10_keras_pipe.py`의 사본이 아닙니다)</font>**, `training_script/cifar10_keras_dist.py` 로 저장하세요.
#
# 스크립트 사본을 생성하였다면 단계별로 아래의 작업들을 직접 시도합니다.
#
# ----
# ### TODO 1. Start horovod
# Horovod에 대응하기 위해 `main()` 함수에 아래 코드를 추가합니다.
#
# ```python
#     import horovod.keras as hvd
#     hvd.init()
#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     config.gpu_options.visible_device_list = str(hvd.local_rank())
#     K.set_session(tf.Session(config=config))
# ```
#
# ----
# ### TODO 2. Configure callbacks
# `main()` 함수에서 callbacks을 추가합니다.
#
# ```python
#     callbacks.append(hvd.callbacks.BroadcastGlobalVariablesCallback(0))
#     callbacks.append(hvd.callbacks.MetricAverageCallback())
#     callbacks.append(hvd.callbacks.LearningRateWarmupCallback(warmup_epochs=5, verbose=1))
# ```
#
# `hvd.rank () == 0` 에서만 실행되도록 체크포인트 및 TensorBoard 콜백을 변경해 주세요.
# ```python
#     if hvd.rank() == 0:
#         callbacks.append(ModelCheckpoint(args.output_dir + '/checkpoint-{epoch}.h5'))
#         callbacks.append(TensorBoard(log_dir=args.model_output_dir,update_freq='epoch'))
# ```
#
# ----
# ### TODO 3. Configure the optimizer
# Horovod에 대응하기 위해 아래의 절차들을 진행합니다.
#
#
# 1) `keras_model_fn` 함수에 hvd 인수를 추가합니다.
# ```python
# # Add hvd to the function. also add it in the function call
# def keras_model_fn(learning_rate, weight_decay, optimizer, momentum, hvd):
# ```
#
# 2) `size=1`을 `size=hvd.size()`로 변경해 주세요.
#
# 3) 코드를 아래와 같이 수정합니다.
#
# ```python
#  model.compile(loss='categorical_crossentropy',
#                   optimizer=opt,
#                   metrics=['accuracy'])
# ```
# 바로 앞에
# ```python
# opt = hvd.DistributedOptimizer(opt)
# ```
# 라인을 추가해 주세요.
#
# 4) `main()` 함수에서 model 인스턴스를 만들 때 hvd를 인수로 전달하도록 수정합니다.
#
# ```python
# model = keras_model_fn(args.learning_rate, args.weight_decay, args.optimizer, args.momentum, hvd)
# ```
#
# <font color='blue'>**본 노트북 실습에 어려움이 있다면 솔루션 파일 `training_script/cifar10_keras_dist_solution.py`을 참조하시면 됩니다.**</font>

# %% [markdown]
# ## Run Distributed training
# 아래의 설정을 Estimator 객체에 전달하여 Horovod 분산 학습에 대한 설정을 할 수 있습니다.
# ```python
# distributions = {'mpi': {
#                     'enabled': True,
#                     'processes_per_host': # Number of Horovod processes per host
#                         }
#                 }
# ```

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()

# %%
prefix = 'data/DEMO-cifar10'
dataset_location = os.path.join('s3://', sagemaker_session.default_bucket(), prefix)

# %%
metric_definitions = [
    {'Name': 'train:loss', 'Regex': 'loss: (.*?) '},
    {'Name': 'train:accuracy', 'Regex': 'acc: (.*?) '},
    {'Name': 'validation:loss', 'Regex': 'val_loss: (.*?) '},
    {'Name': 'validation:accuracy', 'Regex': 'val_acc: (.*?) '}
]

# %% [markdown]
# `train_instance_count` 인자값을 2로 설정하고 `distribution` 인자값을 추가합니다.<br>
# 이번에는 5 epoch 대신 10 epoch를 학습합니다.

# %%
from sagemaker.tensorflow import TensorFlow

distributions = {
    'mpi': {
        'enabled': True, 
        'custom_mpi_options': '-verbose --NCCL_DEBUG=INFO',
        'processes_per_host': 1
    }
}

# Change base_job_name to 'cifar10-dist' for console visibility
estimator = TensorFlow(base_job_name='cifar10-dist',
                       entry_point='cifar10_keras_dist.py',
                       source_dir='training_script',
                       role=role,
                       framework_version='1.14.0',
                       py_version='py3',
                       script_mode=True,                            
                       hyperparameters={'epochs': 10},
                       train_instance_count=2,   # 변경
                       train_instance_type='ml.p2.xlarge',
                       metric_definitions=metric_definitions, # 1_Monitoring_your_TensorFlow_scripts.ipynb 참조                         
                       distributions=distributions # 추가
                      )

# %% [markdown]
# 학습 완료 후 Billable seconds도 확인해 보세요. Billable seconds는 실제로 학습 수행 시 과금되는 시간입니다.
# ```
# Billable seconds: <time>
# ```
#
# 참고로, `ml.p2.xlarge` 인스턴스로 10 epoch 학습 시 전체 6분~7분이 소요되고, 실제 학습에 소요되는 시간은 3분~4분이 소요됩니다.

# %%
# %%time
estimator.fit({'train':'{}/train'.format(dataset_location),
              'validation':'{}/validation'.format(dataset_location),
              'eval':'{}/eval'.format(dataset_location)})
# Out:
# 2019-10-21 07:59:04 Starting - Starting the training job...
# 2019-10-21 07:59:07 Starting - Launching requested ML instances......
# 2019-10-21 08:00:07 Starting - Preparing the instances for training......
# 2019-10-21 08:01:15 Downloading - Downloading input data...
# 2019-10-21 08:01:58 Training - Downloading the training image...
# 2019-10-21 08:02:30 Training - Training image download completed. Training in progress../usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# I1021 08:02:37.603125 139703768303360 transport.py:1746] Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# I1021 08:02:37.739932 139703768303360 transport.py:1746] Authentication (publickey) successful!
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# I1021 08:02:36.782898 140296995329792 transport.py:1746] Connected (version 2.0, client OpenSSH_7.2p2)
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:39: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   m.add_string(self.Q_C.public_numbers().encode_point())
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:96: CryptographyDeprecationWarning: Support for unsafe construction of public numbers from encoded data will be removed in a future version. Please use EllipticCurvePublicKey.from_encoded_point
#   self.curve, Q_S_bytes
# /usr/local/lib/python3.6/site-packages/paramiko/kex_ecdh_nist.py:111: CryptographyDeprecationWarning: encode_point has been deprecated on EllipticCurvePublicNumbers and will be removed in a future version. Please use EllipticCurvePublicKey.public_bytes to obtain both compressed and uncompressed point encoding.
#   hm.add_string(self.Q_C.public_numbers().encode_point())
# I1021 08:02:36.946610 140296995329792 transport.py:1746] Authentication (publickey) successful!
# Warning: Permanently added 'algo-2,10.2.166.214' (ECDSA) to the list of known hosts.#015
#  Data for JOB [35241,1] offset 0 Total slots allocated 2
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-2-159-196#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [35241,1] App: 0 Process rank: 0 Bound: UNBOUND
#
#  Data for node: algo-2#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [35241,1] App: 0 Process rank: 1 Bound: N/A
#
#  =============================================================
#  Data for JOB [35241,1] offset 0 Total slots allocated 2
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-2-159-196#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [35241,1] App: 0 Process rank: 0 Bound: N/A
#
#  Data for node: algo-2#011Num slots: 1#011Max slots: 0#011Num procs: 1
#  #011Process OMPI jobid: [35241,1] App: 0 Process rank: 1 Bound: UNBOUND
#
#  =============================================================
# --------------------------------------------------------------------------
# WARNING: Open MPI tried to bind a process but failed.  This is a
# warning only; your job will continue, though performance may
# be degraded.
#
#   Local host:        ip-10-2-159-196
#   Application name:  /usr/local/bin/python3.6
#   Error message:     failed to bind memory
#   Location:          rtc_hwloc.c:447
#
# --------------------------------------------------------------------------
# [1,0]<stderr>:Using TensorFlow backend.
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,0]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,0]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,1]<stderr>:Using TensorFlow backend.
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# [1,1]<stderr>:/usr/local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# [1,1]<stderr>:  np_resource = np.dtype([("resource", np.ubyte, 1)])
# [1,1]<stderr>:WARNING: Logging before flag parsing goes to stderr.
# [1,1]<stderr>:W1021 08:02:40.967232 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# [1,1]<stderr>:
# [1,0]<stderr>:WARNING: Logging before flag parsing goes to stderr.
# [1,0]<stderr>:W1021 08:02:40.977781 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:34: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# [1,0]<stderr>:
# [1,1]<stderr>:2019-10-21 08:02:40.998891: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# [1,1]<stderr>:2019-10-21 08:02:41.021444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.022293: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# [1,1]<stderr>:name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8755
# [1,1]<stderr>:pciBusID: 0000:00:1e.0
# [1,1]<stderr>:2019-10-21 08:02:41.025678: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.114500: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.158098: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.171885: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.273152: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.346723: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.520553: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# [1,1]<stderr>:2019-10-21 08:02:41.520774: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.521731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.522508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# [1,1]<stderr>:2019-10-21 08:02:41.677779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.679886: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x53f8000 executing computations on platform CUDA. Devices:
# [1,1]<stderr>:2019-10-21 08:02:41.679916: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# [1,0]<stderr>:W1021 08:02:41.686536 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:38: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:02:41.686948 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:38: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:02:41.713831 139980435289856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:107: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:02:41.714160 139980435289856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:141: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# [1,0]<stderr>:
# [1,1]<stderr>:2019-10-21 08:02:41.737383: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300075000 Hz
# [1,1]<stderr>:2019-10-21 08:02:41.737830: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5467f90 executing computations on platform Host. Devices:
# [1,1]<stderr>:2019-10-21 08:02:41.737869: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# [1,1]<stderr>:2019-10-21 08:02:41.738210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.739011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# [1,1]<stderr>:name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8755
# [1,1]<stderr>:pciBusID: 0000:00:1e.0
# [1,1]<stderr>:2019-10-21 08:02:41.739096: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.739137: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.739170: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.739203: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.739236: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.739267: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.739301: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# [1,1]<stderr>:2019-10-21 08:02:41.739393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.740216: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.740946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# [1,1]<stderr>:2019-10-21 08:02:41.742043: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.744306: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,1]<stderr>:2019-10-21 08:02:41.744337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# [1,1]<stderr>:2019-10-21 08:02:41.744351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# [1,1]<stderr>:2019-10-21 08:02:41.745863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.746662: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.747422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7)
# [1,1]<stderr>:W1021 08:02:41.748371 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:38: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:02:41.748624 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:38: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:02:41.774565 140285834823424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:107: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:02:41.774849 140285834823424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:141: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# [1,1]<stderr>:
# [1,0]<stderr>:W1021 08:02:41.876471 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:210: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# [1,0]<stderr>:
# [1,1]<stderr>:W1021 08:02:41.874317 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:210: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# [1,1]<stderr>:
# [1,1]<stderr>:2019-10-21 08:02:41.875151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.875960: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# [1,1]<stderr>:name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8755
# [1,1]<stderr>:pciBusID: 0000:00:1e.0
# [1,1]<stderr>:2019-10-21 08:02:41.876013: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.876039: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.876054: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.876068: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.876082: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.876104: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:41.876119: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# [1,1]<stderr>:2019-10-21 08:02:41.876182: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.876953: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.877677: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# [1,1]<stderr>:2019-10-21 08:02:41.950851: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# [1,1]<stderr>:2019-10-21 08:02:41.950900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# [1,1]<stderr>:2019-10-21 08:02:41.950911: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# [1,1]<stderr>:2019-10-21 08:02:41.951104: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.951919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# [1,1]<stderr>:2019-10-21 08:02:41.952639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7)
# [1,1]<stderr>:I1021 08:02:41.952820 140285834823424 cifar10_keras_dist.py:215] getting data
# [1,0]<stderr>:I1021 08:02:41.964913 139980435289856 cifar10_keras_dist.py:215] getting data
# [1,1]<stderr>:W1021 08:02:41.980434 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:176: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:02:41.980655 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:180: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
# [1,1]<stderr>:
# [1,0]<stderr>:W1021 08:02:41.994353 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:176: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:02:41.994593 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:180: The name tf.parse_single_example is deprecated. Please use tf.io.parse_single_example instead.
# [1,0]<stderr>:
# [1,1]<stderr>:W1021 08:02:41.992468 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:162: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
# [1,1]<stderr>:
# [1,0]<stderr>:W1021 08:02:42.004977 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:162: The name tf.image.resize_image_with_crop_or_pad is deprecated. Please use tf.image.resize_with_crop_or_pad instead.
# [1,0]<stderr>:
# [1,1]<stderr>:W1021 08:02:42.016918 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:165: The name tf.random_crop is deprecated. Please use tf.image.random_crop instead.
# [1,1]<stderr>:
# [1,0]<stderr>:W1021 08:02:42.024570 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:165: The name tf.random_crop is deprecated. Please use tf.image.random_crop instead.
# [1,0]<stderr>:
# [1,1]<stderr>:W1021 08:02:42.067818 140285834823424 deprecation.py:323] From cifar10_keras_dist.py:153: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# [1,0]<stderr>:W1021 08:02:42.075101 139980435289856 deprecation.py:323] From cifar10_keras_dist.py:153: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# [1,1]<stderr>:I1021 08:02:42.275452 140285834823424 cifar10_keras_dist.py:220] configuring model
# [1,0]<stderr>:I1021 08:02:42.289049 139980435289856 cifar10_keras_dist.py:220] configuring model
# [ip-10-2-159-196.ec2.internal:00036] 1 more process has sent help message help-orte-odls-default.txt / memory not bound
# [ip-10-2-159-196.ec2.internal:00036] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,0]<stderr>:W1021 08:02:43.943424 139980435289856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:02:44.120131 139980435289856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:02:44.127240 139980435289856 deprecation.py:506] From /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# [1,1]<stderr>:W1021 08:02:44.524485 140285834823424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:02:44.711133 140285834823424 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:02:44.717802 140285834823424 deprecation.py:506] From /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# [1,1]<stderr>:I1021 08:02:45.773519 140285834823424 cifar10_keras_dist.py:237] Starting training
# [1,1]<stderr>:W1021 08:02:45.872307 140285834823424 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Use tf.where in 2.0, which has the same broadcast rule as np.where
# [1,1]<stderr>:W1021 08:02:46.386602 140285834823424 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:81: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:Deprecated in favor of operator or tf.math.divide.
# [1,0]<stderr>:I1021 08:02:46.522114 139980435289856 cifar10_keras_dist.py:237] Starting training
# [1,0]<stderr>:W1021 08:02:46.627896 139980435289856 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Use tf.where in 2.0, which has the same broadcast rule as np.where
# [1,0]<stderr>:W1021 08:02:47.245408 139980435289856 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/horovod/tensorflow/__init__.py:81: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:Deprecated in favor of operator or tf.math.divide.
# [1,1]<stdout>:Train on 256 samples, validate on 256 samples
# [1,0]<stdout>:Train on 256 samples, validate on 256 samples
# [1,0]<stderr>:W1021 08:02:48.732598 139980435289856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:02:48.732944 139980435289856 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/site-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# [1,0]<stderr>:
# [1,1]<stdout>:Epoch 1/5
# [1,0]<stdout>:Epoch 1/5
# [1,1]<stderr>:2019-10-21 08:02:51.262181: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# [1,1]<stderr>:2019-10-21 08:02:56.722430: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO NET/Socket : Using [0]eth0:10.2.159.196<0>
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:42:73 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:NCCL version 2.4.7+cuda10.0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO NET/Socket : Using [0]eth0:10.2.166.214<0>
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,1]<stdout>:
# [1,1]<stdout>:algo-2:48:79 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Setting affinity for GPU 0 to 0f
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Setting affinity for GPU 0 to 0f
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO CUDA Dev 0[0], Socket NIC distance :  PHB
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Duplicating rings to 4 per user request.
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Channel 00 :    0   1
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Channel 01 :    0   1
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO CUDA Dev 0[0], Socket NIC distance :  PHB
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Channel 02 :    0   1
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Channel 03 :    0   1
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 00 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 00 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 00 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 00 : 0 -> 1 [send] via NET/Socket/0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 01 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 01 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 01 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 01 : 0 -> 1 [send] via NET/Socket/0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 02 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 02 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 02 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 02 : 0 -> 1 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 03 : 1 -> 0 [receive] via NET/Socket/0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 03 : 0 -> 1 [receive] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Ring 03 : 0 -> 1 [send] via NET/Socket/0
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO Ring 03 : 1 -> 0 [send] via NET/Socket/0
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Using 128 threads, Min Comp Cap 3, Trees disabled
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO comm 0x7f4eac302da0 rank 0 nranks 2 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,1]<stdout>:algo-2:48:79 [0] NCCL INFO comm 0x7f95cc32d430 rank 1 nranks 2 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,0]<stdout>:algo-1:42:73 [0] NCCL INFO Launch mode Parallel
# [1,1]<stdout>:#015[1,1]<stdout>: 1/78 [..............................] - ETA: 11:43 - loss: 3.8809 - acc: 0.1094[1,0]<stdout>:#015[1,0]<stdout>: 1/78 [..............................] - ETA: 11:42 - loss: 3.8795 - acc: 0.0898[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 2/78 [..............................] - ETA: 5:51 - loss: 3.7120 - acc: 0.0918 [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 2/78 [..............................] - ETA: 5:51 - loss: 3.7370 - acc: 0.0996 [1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 3/78 [>.............................] - ETA: 3:54 - loss: 3.5434 - acc: 0.1068[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 3/78 [>.............................] - ETA: 3:54 - loss: 3.6101 - acc: 0.1094[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 4/78 [>.............................] - ETA: 2:56 - loss: 3.3971 - acc: 0.1172[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 4/78 [>.............................] - ETA: 2:56 - loss: 3.4454 - acc: 0.1270[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 5/78 [>.............................] - ETA: 2:21 - loss: 3.2858 - acc: 0.1141[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 5/78 [>.............................] - ETA: 2:21 - loss: 3.3292 - acc: 0.1305[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 6 ...
# ...
# [1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:78/78 [==============================] - 12s 152ms/step - loss: 1.3194 - acc: 0.5251 - val_loss: 2.2328 - val_acc: 0.3296
# [1,1]<stdout>:Epoch 5/5
# [1,0]<stdout>:Epoch 5/5
# [1,1]<stdout>:#015[1,1]<stdout>: 1/78 [..............................] - ETA: 17s - loss: 1.2349 - acc: 0.5938[1,0]<stdout>:#015[1,0]<stdout>: 1/78 [..............................] - ETA: 9s - loss: 1.3091 - acc: 0.4883[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 2/78 [..............................] - ETA: 9s - loss: 1.2642 - acc: 0.5430[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 2/78 [..............................] - ETA: 13s - loss: 1.2249 - acc: 0.5742[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 3/78 [>.............................] - ETA: 12s - loss: 1.2314 - acc: 0.5794[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 3/78 [>.............................] - ETA: 9s - loss: 1.2427 - acc: 0.5430[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 4/78 [>.............................] - ETA: 11s - loss: 1.2670 - acc: 0.5469[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>: 4/78 [>.............................] - ETA: 9s - loss: 1.2464 - acc: 0.5420[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 5/78 [>.............................] - ETA: 11s - loss: 1.2489 - acc: 0.5578[1,0]<stdout>: 5/78 [>.............................] - ETA: 9s - loss: 1.2884 - acc: 0.5266[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>: 6/78 [=>............................] - ETA: 10s - loss: 1.2360 - acc: 0.5599[1, ...
# #010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:46/78 [================>.............] - ETA: 4s - loss: 1.2271 - acc: 0.5592[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:46/78 [================>.............] - ETA: 4s - loss: 1.2230 - acc: 0.5606[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:47/78 [=================>............] - ETA: 4s - loss: 1.2213 - acc: 0.5609[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:47/78 [=================>............] - ETA: 4s - loss: 1.2284 - acc: 0.5596[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:48/78 [=================>............] - ETA: 4s - loss: 1.2264 - acc: 0.5608[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:48/78 [=================>............] - ETA: 4s - loss: 1.2198 - acc: 0.5615[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:49/78 [=================>............] - ETA: 3s - loss: 1.2190 - acc: 0.5621[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:49/78 [=================>............] - ETA: 4s - loss: 1.2259 - acc: 0.5610[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,0]<stdout>:50/78 [==================>...........] - ETA: 3s - loss: 1.2173 - acc: 0.5632[1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:50/78 [==================>...........] - ETA: 3s - loss: 1.2235 - acc: 0.5620[1,0]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# [1,1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015[1,1]<stdout>:78/78 [==============================] - 12s 152ms/step - loss: 1.1992 - acc: 0.5703 - val_loss: 1.2905 - val_acc: 0.5312
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.002.
# [1,1]<stdout>:
# [1,1]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.002.
# [1,1]<stderr>:I1021 08:04:03.898949 140285834823424 cifar10_keras_dist.py:254] Test loss:1.267791929997896
# [1,1]<stderr>:I1021 08:04:03.899198 140285834823424 cifar10_keras_dist.py:255] Test accuracy:0.5448190789473685
# [1,1]<stderr>:W1021 08:04:03.899377 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:193: The name tf.saved_model.signature_def_utils.predict_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.predict_signature_def instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:04:03.899547 140285834823424 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# [1,1]<stderr>:Instructions for updating:
# [1,1]<stderr>:This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# [1,1]<stderr>:W1021 08:04:03.899982 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:196: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
# [1,1]<stderr>:
# [1,1]<stderr>:W1021 08:04:03.900587 140285834823424 deprecation_wrapper.py:119] From cifar10_keras_dist.py:199: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
# [1,1]<stderr>:
# [1,1]<stderr>:I1021 08:04:03.901301 140285834823424 builder_impl.py:636] No assets to save.
# [1,1]<stderr>:I1021 08:04:03.901427 140285834823424 builder_impl.py:456] No assets to write.
# [1,0]<stderr>:I1021 08:04:04.034663 139980435289856 cifar10_keras_dist.py:254] Test loss:1.2697806044628746
# [1,0]<stderr>:I1021 08:04:04.035004 139980435289856 cifar10_keras_dist.py:255] Test accuracy:0.5421463815789473
# [1,0]<stderr>:W1021 08:04:04.035264 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:193: The name tf.saved_model.signature_def_utils.predict_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.predict_signature_def instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:04:04.035518 139980435289856 deprecation.py:323] From /usr/local/lib/python3.6/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# [1,0]<stderr>:W1021 08:04:04.036082 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:196: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
# [1,0]<stderr>:
# [1,0]<stderr>:W1021 08:04:04.036943 139980435289856 deprecation_wrapper.py:119] From cifar10_keras_dist.py:199: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
# [1,0]<stderr>:
# [1,0]<stderr>:I1021 08:04:04.037431 139980435289856 builder_impl.py:636] No assets to save.
# [1,0]<stderr>:I1021 08:04:04.037559 139980435289856 builder_impl.py:456] No assets to write.
# [1,0]<stderr>:2019-10-21 08:04:04.507575: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# [1,1]<stderr>:2019-10-21 08:04:04.505883: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# [1,0]<stderr>:I1021 08:04:04.878396 139980435289856 builder_impl.py:421] SavedModel written to: /opt/ml/model/1/saved_model.pb
# [1,0]<stderr>:I1021 08:04:04.878734 139980435289856 cifar10_keras_dist.py:203] Model successfully saved at: /opt/ml/model
# [1,1]<stderr>:I1021 08:04:04.913870 140285834823424 builder_impl.py:421] SavedModel written to: /opt/ml/model/1/saved_model.pb
# [1,1]<stderr>:I1021 08:04:04.914097 140285834823424 cifar10_keras_dist.py:203] Model successfully saved at: /opt/ml/model
# 2019-10-21 08:04:56 Uploading - Uploading generated training model
# 2019-10-21 08:04:56 Completed - Training job completed
# Training seconds: 442
# Billable seconds: 442
# CPU times: user 926 ms, sys: 71.1 ms, total: 997 ms
# Wall time: 6min 14s

# %% [markdown]
# **잘 하셨습니다.**
#
# 여러 분은 이제 분산 학습에 SageMaker 학습 작업을 사용할 수 있습니다.
# 다음 노트북으로 계속 진행하기 전에 CloudWatch 및 TensorBoard의 distribution job metrics를 살펴 보세요.
# TensorBoard를 사용하여 여러분이 실행한 다른 작업을 비교할 수 있습니다.
#
# TensorBoard 실행 시 아래의 인자값을 참조해 주세요.<br>
# `--logdir dist:dist_model_dir,pipe:pipe_model_dir,file:normal_job_model_dir`
